# %%
from codecarbon import EmissionsTracker
import logging
output_directory = "/fp/homes01/u01/ec-krimhau/thesis_code/"

tracker = EmissionsTracker(output_dir=output_directory)
tracker.start()
# Out:
# [codecarbon INFO @ 09:42:55] [setup] RAM Tracking...
# [codecarbon INFO @ 09:42:55] [setup] GPU Tracking...
# [codecarbon INFO @ 09:42:55] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 09:42:55] [setup] CPU Tracking...
# [codecarbon WARNING @ 09:42:55] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon WARNING @ 09:42:58] We saw that you have a AMD EPYC 7642 48-Core Processor but we don't know it. Please contact us.
# [codecarbon INFO @ 09:42:58] CPU Model on constant consumption mode: AMD EPYC 7642 48-Core Processor
# [codecarbon INFO @ 09:42:58] >>> Tracker's metadata:
# [codecarbon INFO @ 09:42:58]   Platform system: Linux-5.14.0-362.8.1.el9_3.x86_64-x86_64-with-glibc2.34
# [codecarbon INFO @ 09:42:58]   Python version: 3.11.3
# [codecarbon INFO @ 09:42:58]   CodeCarbon version: 2.3.4
# [codecarbon INFO @ 09:42:58]   Available RAM : 256.000 GB
# [codecarbon INFO @ 09:42:58]   CPU count: 24
# [codecarbon INFO @ 09:42:58]   CPU model: AMD EPYC 7642 48-Core Processor
# [codecarbon INFO @ 09:42:58]   GPU count: 1
# [codecarbon INFO @ 09:42:58]   GPU model: 1 x NVIDIA A100-PCIE-40GB

# %%
logging.getLogger('codecarbon').setLevel(logging.WARNING)

# %%
import os
import gc
import copy
import time
import random
import string
import joblib

# For data manipulation
import numpy as np
import pandas as pd

# Pytorch Imports
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import Dataset, DataLoader

# Utils
from tqdm import tqdm
from collections import defaultdict

# Sklearn Imports
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GroupKFold, KFold

# For Transformer Models
from transformers import AutoTokenizer, AutoModel, AutoConfig, AdamW
from transformers import DataCollatorWithPadding
import datasets
# For colored terminal text
from colorama import Fore, Back, Style
b_ = Fore.BLUE
y_ = Fore.YELLOW
sr_ = Style.RESET_ALL

# Suppress warnings
import warnings
warnings.filterwarnings("ignore")

# For descriptive error messages
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
# For reproducibility. Same as when the model was trained
HASH_NAME = "dlrpvayq52ul"

# %%
CONFIG = {"seed": 42,
          "epochs": 3,
          "model_name": "microsoft/deberta-v3-base",
          "train_batch_size": 8,
          "valid_batch_size": 16,
          "max_length": 512,
          "learning_rate": 1e-5,
          "scheduler": 'CosineAnnealingLR',
          "min_lr": 1e-6,
          "T_max": 500,
          "weight_decay": 1e-6,
          "n_fold": 3,
          "n_accumulate": 1,
          "num_classes": 2,
          "device": torch.device("cuda:0" if torch.cuda.is_available() else "cpu"),
          "hash_name": HASH_NAME,
          "_wandb_kernel": "deb",
          }

CONFIG["tokenizer"] = AutoTokenizer.from_pretrained(CONFIG['model_name'])
CONFIG['group'] = f'{HASH_NAME}-Baseline'

# %%
import pandas as pd
project_name = "flutter"

file_name = f"github_clean_{project_name}_testset.csv"

# %%
df = pd.read_csv(file_name)
df
# Out:
#                                              text_clean  label
# 0     breaks flutterplugins ci since the release of ...      1
# 1     some rollers are not triggering all the builde...      1
# 2     flutter web crashes when moving between two sc...      0
# 3     windows gradlepluginlightapktest is flaky meta...      1
# 4     transform widget not working correctly with im...      0
# ...                                                 ...    ...
# 2365  engine roller blocked on ciyaml validation fai...      1
# 2366  whether the customscrollview can save the scro...      1
# 2367  all pr try jobs infra failed i dont see any lo...      1
# 2368  linux frameworktestslibraries is flaky metatag...      1
# 2369  macandroid runreleasetest is failing due to de...      1
#
# [2370 rows x 2 columns]

# %%
df = df.rename(columns={'text_clean': 'text'})
df = df.dropna()  # This will drop any rows with missing values.
df = df.reset_index(drop=True)
df
# Out:
#                                                    text  label
# 0     breaks flutterplugins ci since the release of ...      1
# 1     some rollers are not triggering all the builde...      1
# 2     flutter web crashes when moving between two sc...      0
# 3     windows gradlepluginlightapktest is flaky meta...      1
# 4     transform widget not working correctly with im...      0
# ...                                                 ...    ...
# 2365  engine roller blocked on ciyaml validation fai...      1
# 2366  whether the customscrollview can save the scro...      1
# 2367  all pr try jobs infra failed i dont see any lo...      1
# 2368  linux frameworktestslibraries is flaky metatag...      1
# 2369  macandroid runreleasetest is failing due to de...      1
#
# [2370 rows x 2 columns]

# %%
class MeanPooling(nn.Module):
    def __init__(self):
        super(MeanPooling, self).__init__()
        
    def forward(self, last_hidden_state, attention_mask):
        input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        sum_mask = input_mask_expanded.sum(1)
        sum_mask = torch.clamp(sum_mask, min=1e-9)
        mean_embeddings = sum_embeddings / sum_mask
        return mean_embeddings

# %%
class TD_Model(nn.Module):
    def __init__(self, model_name):
        super(TD_Model, self).__init__()
        self.model = AutoModel.from_pretrained(model_name)
        self.config = AutoConfig.from_pretrained(model_name)
        self.drop = nn.Dropout(p=0.2)
        self.pooler = MeanPooling()
        self.fc = nn.Linear(self.config.hidden_size, CONFIG['num_classes'])
        
    def forward(self, ids, mask):        
        out = self.model(input_ids=ids,attention_mask=mask,
                         output_hidden_states=False)
        out = self.pooler(out.last_hidden_state, mask)
        out = self.drop(out)
        outputs = self.fc(out)
        return outputs

# %% [markdown]
# <h2> Testing Inference </h2>

# %%
import warnings,transformers,logging,torch

warnings.simplefilter('ignore')
logging.disable(logging.WARNING)

# %%
test_df = df

# %%
test_df
# Out:
#                                                    text  label
# 0     breaks flutterplugins ci since the release of ...      1
# 1     some rollers are not triggering all the builde...      1
# 2     flutter web crashes when moving between two sc...      0
# 3     windows gradlepluginlightapktest is flaky meta...      1
# 4     transform widget not working correctly with im...      0
# ...                                                 ...    ...
# 2365  engine roller blocked on ciyaml validation fai...      1
# 2366  whether the customscrollview can save the scro...      1
# 2367  all pr try jobs infra failed i dont see any lo...      1
# 2368  linux frameworktestslibraries is flaky metatag...      1
# 2369  macandroid runreleasetest is failing due to de...      1
#
# [2370 rows x 2 columns]

# %%
class HP_TestDataset(Dataset):
    def __init__(self, df, tokenizer, max_length):
        self.df = df
        self.max_len = max_length
        self.tokenizer = tokenizer
        self.text = df['text'].values
        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, index):
        text = self.text[index]
        inputs = self.tokenizer.encode_plus(
                        text,
                        truncation=True,
                        add_special_tokens=True,
                        max_length=self.max_len
                    )
        
        samples = {
            'input_ids': inputs['input_ids'],
            'attention_mask': inputs['attention_mask'],
            
        }

        if 'token_type_ids' in inputs:
            samples['token_type_ids'] = inputs['token_type_ids']
        
        return samples

# %%
collate_fn = DataCollatorWithPadding(tokenizer=CONFIG['tokenizer'])

softmax = nn.Softmax(dim=1)
model = TD_Model(CONFIG['model_name'])

# %%
def prepare_test_loader(test_df):    
    test_dataset = HP_TestDataset(test_df, 
                                   tokenizer=CONFIG['tokenizer'], 
                                   max_length=CONFIG['max_length'])
    
    test_loader = DataLoader(test_dataset, 
                             batch_size=CONFIG['valid_batch_size'], 
                             collate_fn=collate_fn, 
                             num_workers=2, 
                             shuffle=False, 
                             pin_memory=True, 
                             drop_last=False)
    return test_loader

test_loader = prepare_test_loader(test_df)

# %%
@torch.no_grad()
def inference(test_loader, model, device):
    preds = []
    preds_target = []
    model.eval()
    model.to(device)
    
    bar = tqdm(enumerate(test_loader), total=len(test_loader))
    
    for step, data in bar: 
        ids = data['input_ids'].to(device, dtype = torch.long)
        mask = data['attention_mask'].to(device, dtype = torch.long)
        
        output = model(ids, mask)
        y_preds = softmax(torch.tensor(output.to('cpu'))).numpy()
        pred_target = torch.argmax(output, dim=-1).flatten().tolist()
        
        preds.append(y_preds)
        preds_target.append(pred_target) 
    predictions = np.concatenate(preds)
    predictions_label = np.concatenate(preds_target)
    return predictions , predictions_label

# %%
deberta_predictions = []
deberta_predictions_labels = []



for fold in range(0, CONFIG['n_fold']):
    print("Fold {}".format(fold))
    
    state = torch.load(f'../../01_training/{HASH_NAME}-Loss-Fold-{fold}.bin')
    model.load_state_dict(state)
    
    prediction, predictions_label = inference(test_loader, model, CONFIG['device'])
    deberta_predictions.append(prediction)
    deberta_predictions_labels.append(predictions_label)
    del state, prediction; gc.collect()
    torch.cuda.empty_cache()
del model
# Out:
# Fold 0
# 100%|██████████| 149/149 [01:24<00:00,  1.77it/s]
# Fold 1
# 100%|██████████| 149/149 [01:09<00:00,  2.13it/s]
# Fold 2
# 100%|██████████| 149/149 [00:25<00:00,  5.74it/s]

# %%
deberta_predictions
# Out:
# [array([[0.19179587, 0.8082042 ],
#         [0.08292866, 0.9170714 ],
#         [0.68850493, 0.311495  ],
#         ...,
#         [0.08038133, 0.91961867],
#         [0.38690072, 0.6130993 ],
#         [0.36075214, 0.63924783]], dtype=float32),
#  array([[0.3692891 , 0.63071096],
#         [0.15420085, 0.84579915],
#         [0.58394784, 0.41605216],
#         ...,
#         [0.34179738, 0.6582026 ],
#         [0.25739077, 0.74260926],
#         [0.19843537, 0.80156463]], dtype=float32),
#  array([[0.35153136, 0.6484687 ],
#         [0.15583663, 0.8441633 ],
#         [0.77889967, 0.22110035],
#         ...,
#         [0.33516425, 0.66483575],
#         [0.16692303, 0.833077  ],
#         [0.21598977, 0.7840103 ]], dtype=float32)]

# %%
predictions = np.mean(deberta_predictions, axis=0)
predictions
# Out:
# array([[0.30420545, 0.6957946 ],
#        [0.13098872, 0.8690112 ],
#        [0.6837842 , 0.31621584],
#        ...,
#        [0.25244763, 0.74755234],
#        [0.27040485, 0.7295952 ],
#        [0.25839242, 0.7416076 ]], dtype=float32)

# %%
len(predictions)
# Out:
# 2370

# %%
predictions
# Out:
# array([[0.30420545, 0.6957946 ],
#        [0.13098872, 0.8690112 ],
#        [0.6837842 , 0.31621584],
#        ...,
#        [0.25244763, 0.74755234],
#        [0.27040485, 0.7295952 ],
#        [0.25839242, 0.7416076 ]], dtype=float32)

# %%
test_df["prediction_0"] = predictions[:, 0]

# %%
test_df["prediction_1"] = predictions[:, 1]

# %%
for i in range(0, CONFIG['n_fold']):

    test_df[f"prediction_label_fold_{i}"] = deberta_predictions_labels[i]

# %%
test_df
# Out:
#                                                    text  label  prediction_0  \
# 0     breaks flutterplugins ci since the release of ...      1      0.304205
# 1     some rollers are not triggering all the builde...      1      0.130989
# 2     flutter web crashes when moving between two sc...      0      0.683784
# 3     windows gradlepluginlightapktest is flaky meta...      1      0.357078
# 4     transform widget not working correctly with im...      0      0.713753
# ...                                                 ...    ...           ...
# 2365  engine roller blocked on ciyaml validation fai...      1      0.126250
# 2366  whether the customscrollview can save the scro...      1      0.940425
# 2367  all pr try jobs infra failed i dont see any lo...      1      0.252448
# 2368  linux frameworktestslibraries is flaky metatag...      1      0.270405
# 2369  macandroid runreleasetest is failing due to de...      1      0.258392
#
#       prediction_1  prediction_label_fold_0  prediction_label_fold_1  \
# 0         0.695795                        1                        1
# 1         0.869011                        1                        1
# 2         0.316216                        0                        0
# 3         0.642922                        1                        1
# 4         0.286247                        0                        0
# ...            ...                      ...                      ...
# 2365      0.873750                        1                        1
# 2366      0.059575                        0                        0
# 2367      0.747552                        1                        1
# 2368      0.729595                        1                        1
# 2369      0.741608                        1                        1
#
#       prediction_label_fold_2
# 0                           1
# 1                           1
# 2                           0
# 3                           1
# 4                           0
# ...                       ...
# 2365                        1
# 2366                        0
# 2367                        1
# 2368                        1
# 2369                        1
#
# [2370 rows x 7 columns]

# %%
len(test_df)
# Out:
# 2370

# %%
test_df['Max'] = test_df[['prediction_0','prediction_1']].idxmax(axis=1)

# %%
test_df["pred"] = test_df['Max'].apply(lambda x: x.replace("prediction_0", "0"))

# %%
test_df["pred"] = test_df['pred'].apply(lambda x: x.replace("prediction_1", "1"))

# %%
test_df["pred"] = test_df["pred"].astype(int)

# %%
test_df
# Out:
#                                                    text  label  prediction_0  \
# 0     breaks flutterplugins ci since the release of ...      1      0.304205
# 1     some rollers are not triggering all the builde...      1      0.130989
# 2     flutter web crashes when moving between two sc...      0      0.683784
# 3     windows gradlepluginlightapktest is flaky meta...      1      0.357078
# 4     transform widget not working correctly with im...      0      0.713753
# ...                                                 ...    ...           ...
# 2365  engine roller blocked on ciyaml validation fai...      1      0.126250
# 2366  whether the customscrollview can save the scro...      1      0.940425
# 2367  all pr try jobs infra failed i dont see any lo...      1      0.252448
# 2368  linux frameworktestslibraries is flaky metatag...      1      0.270405
# 2369  macandroid runreleasetest is failing due to de...      1      0.258392
#
#       prediction_1  prediction_label_fold_0  prediction_label_fold_1  \
# 0         0.695795                        1                        1
# 1         0.869011                        1                        1
# 2         0.316216                        0                        0
# 3         0.642922                        1                        1
# 4         0.286247                        0                        0
# ...            ...                      ...                      ...
# 2365      0.873750                        1                        1
# 2366      0.059575                        0                        0
# 2367      0.747552                        1                        1
# 2368      0.729595                        1                        1
# 2369      0.741608                        1                        1
#
#       prediction_label_fold_2           Max  pred
# 0                           1  prediction_1     1
# 1                           1  prediction_1     1
# 2                           0  prediction_0     0
# 3                           1  prediction_1     1
# 4                           0  prediction_0     0
# ...                       ...           ...   ...
# 2365                        1  prediction_1     1
# 2366                        0  prediction_0     0
# 2367                        1  prediction_1     1
# 2368                        1  prediction_1     1
# 2369                        1  prediction_1     1
#
# [2370 rows x 9 columns]

# %%
from sklearn.metrics import confusion_matrix
cf_matrix = confusion_matrix(test_df["label"].values, test_df["pred"].values)

print(cf_matrix)
# Out:
# [[950 235]
#  [353 832]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True, 
            fmt='.2%', cmap='Blues')

ax.set_title('NonHP vs HP \n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False(NonHP)','True(HP)'])
ax.yaxis.set_ticklabels(['False(NonHP)','True(HP)'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
from sklearn.metrics import classification_report


print(classification_report(test_df["label"].values, test_df["pred"].values))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.76      1185
#            1       0.78      0.70      0.74      1185
#
#     accuracy                           0.75      2370
#    macro avg       0.75      0.75      0.75      2370
# weighted avg       0.75      0.75      0.75      2370

# %%
test_df[["text","label","pred"]].to_csv(f"csv/{project_name}_Test_inference.csv")

# %%
test_df
# Out:
#                                                    text  label  prediction_0  \
# 0     breaks flutterplugins ci since the release of ...      1      0.304205
# 1     some rollers are not triggering all the builde...      1      0.130989
# 2     flutter web crashes when moving between two sc...      0      0.683784
# 3     windows gradlepluginlightapktest is flaky meta...      1      0.357078
# 4     transform widget not working correctly with im...      0      0.713753
# ...                                                 ...    ...           ...
# 2365  engine roller blocked on ciyaml validation fai...      1      0.126250
# 2366  whether the customscrollview can save the scro...      1      0.940425
# 2367  all pr try jobs infra failed i dont see any lo...      1      0.252448
# 2368  linux frameworktestslibraries is flaky metatag...      1      0.270405
# 2369  macandroid runreleasetest is failing due to de...      1      0.258392
#
#       prediction_1  prediction_label_fold_0  prediction_label_fold_1  \
# 0         0.695795                        1                        1
# 1         0.869011                        1                        1
# 2         0.316216                        0                        0
# 3         0.642922                        1                        1
# 4         0.286247                        0                        0
# ...            ...                      ...                      ...
# 2365      0.873750                        1                        1
# 2366      0.059575                        0                        0
# 2367      0.747552                        1                        1
# 2368      0.729595                        1                        1
# 2369      0.741608                        1                        1
#
#       prediction_label_fold_2           Max  pred
# 0                           1  prediction_1     1
# 1                           1  prediction_1     1
# 2                           0  prediction_0     0
# 3                           1  prediction_1     1
# 4                           0  prediction_0     0
# ...                       ...           ...   ...
# 2365                        1  prediction_1     1
# 2366                        0  prediction_0     0
# 2367                        1  prediction_1     1
# 2368                        1  prediction_1     1
# 2369                        1  prediction_1     1
#
# [2370 rows x 9 columns]

# %%
tracker.stop()
# Out:
# 0.0005364890053583851
