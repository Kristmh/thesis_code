# %% [markdown]
# # Data cleaning
# We want the class with labels as numerical value and the body with clean text.
#
# This will remove:
# * duplicates
# * NaN entires
# * non english
# * url, html
#
# * make it lowercase
# * combine title and body

# %%
import pandas as pd
import sys
import numpy as np
sys.path.append("../../scripts_shared/")
from preprocess_text import preprocess_text

# %%
# Read CSV into a dataframe
#high_priority = pd.read_csv("csv/high_priority_no_td.csv", index_col=0)
#medium_priority = pd.read_csv("csv/medium_priority_no_td.csv", index_col=0)
low_priority = pd.read_csv("csv/low_priority_no_td.csv", index_col=0)
not_priority = pd.read_csv("csv/not_priority.csv", index_col=0)
# Out:
# /tmp/ipykernel_38653/220004500.py:5: DtypeWarning: Columns (0,2,3,4,5,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   not_priority = pd.read_csv("csv/not_priority.csv", index_col=0)

# %%
# Number or different labels
low_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# enhancement low priority                             5241
# low priority                                         5169
# bug low priority                                     2662
# Low Priority                                         2584
# pri:low pri:lowest                                   2565
# Priority: Low                                        2377
# priority: low                                        1126
# bug priority: low                                    1093
# Priority: Low Type: Enhancement                      1093
# low-priority                                         1085
# auto-migrated Priority-Low Type-Enhancement          1077
# enhancement low-priority                             1074
# enhancement priority:low                              979
# enhancement priority: low                             915
# auto-migrated Priority-Low Type-Defect                853
# priority:low                                          793
# Low priority                                          703
# pri:lowest pri:low                                    688
# Being Redone Low Priority                             671
# Priority: Low Type: Bug                               644
# enhancement Low Priority                              639
# Coverity bug priority: low                            594
# Low Priority enhancement                              570
# priority.low type.story                               565
# Priority-Low Type-Enhancement                         550
# priority-low                                          550
# enhancement priority-low                              543
# feature low priority                                  541
# bug priority:low                                      524
# bug Low Priority                                      479
# bug low-priority                                      476
# request:new-pkg priority:low                          470
# priority.Low type.Story                               461
# pri:high pri:low pri:lowest                           425
# priority.low                                          420
# priority.Low                                          415
# Priority: Low Status: Available Type: Enhancement     398
# Enhancement Low Priority                              379
# enhancement Priority: Low                             353
# 🟩 priority: low 🚦 status: awaiting triage ✨ goa...    332
# priority low                                          322
# Bug Low Priority                                      314
# Priority: Low enhancement                             298
# Low Priority bug                                      290
# bug Priority: Low                                     289
# low-priority bug                                      282
# low prio                                              276
# Low priority enhancement                              265
# priority::low                                         256
# Priority-Low                                          251

# %%
not_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                            count
# labels
# stale-branch                             6827422
# stale branch 🗑️                           348533
# enhancement                               240489
# bug                                       237012
# security vulnerability                     52497
# question                                   34359
# feature                                    20451
# documentation                              17632
# Bug                                        12098
# help wanted                                10727
# wontfix                                     7180
# greenkeeper                                 6767
# stat:awaiting response                      6530
# stale                                       6472
# Sub Task Failing Test Paddle Frontend       6318
# good first issue                            6302
# enhancement help wanted                     6220
# invalid                                     6002
# task                                        5598
# feature request                             5533
# in progress                                 5320
# duplicate                                   5178
# bug enhancement                             4829
# enhancement good first issue                4430
# npm-install-script                          4392
# status monika                               4277
# kind/bug                                    4254
# design                                      4143
# JAX Frontend Sub Task Failing Test          4011
# Enhancement                                 3352
# Feature                                     3218
# watchout                                    3142
# bug help wanted                             3057
# type: bug                                   2911
# triage                                      2668
# frontend                                    2510
# action-needsmoderation                      2492
# new feature                                 2453
# Stale                                       2411
# new-review user-submission                  2392
# Task                                        2348
# Type: Bug                                   2255
# documentation enhancement                   2234
# improvement                                 2197
# weekly-digest                               2173
# todo                                        2165
# enhancement question                        2092
# new-version user-submission                 2061
# Mend: dependency security vulnerability     2049
# stale branch                                2045

# %%
contains_stale = not_priority['labels'].str.contains("stale", case=False, na=False)
not_priority= not_priority[~contains_stale].reset_index(drop=True)
not_priority.reset_index(drop=True, inplace=True)
not_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                           count
# labels
# enhancement                              240489
# bug                                      237012
# security vulnerability                    52497
# question                                  34359
# feature                                   20451
# documentation                             17632
# Bug                                       12098
# help wanted                               10727
# wontfix                                    7180
# greenkeeper                                6767
# stat:awaiting response                     6530
# Sub Task Failing Test Paddle Frontend      6318
# good first issue                           6302
# enhancement help wanted                    6220
# invalid                                    6002
# task                                       5598
# feature request                            5533
# in progress                                5320
# duplicate                                  5178
# bug enhancement                            4829
# enhancement good first issue               4430
# npm-install-script                         4392
# status monika                              4277
# kind/bug                                   4254
# design                                     4143
# JAX Frontend Sub Task Failing Test         4011
# Enhancement                                3352
# Feature                                    3218
# watchout                                   3142
# bug help wanted                            3057
# type: bug                                  2911
# triage                                     2668
# frontend                                   2510
# action-needsmoderation                     2492
# new feature                                2453
# new-review user-submission                 2392
# Task                                       2348
# Type: Bug                                  2255
# documentation enhancement                  2234
# improvement                                2197
# weekly-digest                              2173
# todo                                       2165
# enhancement question                       2092
# new-version user-submission                2061
# Mend: dependency security vulnerability    2049
# feature-request                            1865
# discussion                                 1863
# backend                                    1849
# docs                                       1846
# bug fixed                                  1845

# %%
#Give each priority a label by number.
# 'Label encoding'. Makes is easier for machine learning models to work with categorical data.
low_priority["labels"] = 0
low_priority["class"] = "low_priority"
not_priority["labels"] = 1
not_priority["class"] = "not_priority"

# %%
priority = pd.concat([low_priority, not_priority] , ignore_index = True)

# %%
priority[priority["repo"] == "python/mypy"]
# Out:
#                    id         type           created_at         repo  \
# 210262   1.142706e+10  IssuesEvent  2020-02-03 23:33:27  python/mypy
# 210291   1.142707e+10  IssuesEvent  2020-02-03 23:35:24  python/mypy
# 225547   1.362788e+10  IssuesEvent  2020-09-24 13:13:03  python/mypy
# 234003   1.363241e+10  IssuesEvent  2020-09-24 19:36:27  python/mypy
# 251028   2.407484e+10  IssuesEvent  2022-09-18 17:03:35  python/mypy
# ...               ...          ...                  ...          ...
# 9377824  7.349652e+09  IssuesEvent  2018-03-08 11:27:27  python/mypy
# 9377825  7.349652e+09  IssuesEvent  2018-03-08 11:27:27  python/mypy
# 9378600  7.349972e+09  IssuesEvent  2018-03-08 12:44:13  python/mypy
# 9378613  7.349979e+09  IssuesEvent  2018-03-08 12:45:41  python/mypy
# 9395478  8.109448e+09  IssuesEvent  2018-08-14 07:36:08  python/mypy
#
#                                          repo_url  action  \
# 210262   https://api.github.com/repos/python/mypy  closed
# 210291   https://api.github.com/repos/python/mypy  closed
# 225547   https://api.github.com/repos/python/mypy  opened
# 234003   https://api.github.com/repos/python/mypy  opened
# 251028   https://api.github.com/repos/python/mypy  opened
# ...                                           ...     ...
# 9377824  https://api.github.com/repos/python/mypy  closed
# 9377825  https://api.github.com/repos/python/mypy  closed
# 9378600  https://api.github.com/repos/python/mypy  opened
# 9378613  https://api.github.com/repos/python/mypy  closed
# 9395478  https://api.github.com/repos/python/mypy  closed
#
#                                                      title  labels  \
# 210262            Type of conditional expression is object       1
# 210291     Type inference of Tuples returns object instead       1
# 225547         Daemon support for --follow-imports=silent        1
# 234003   regression: assignment of 'builtins.type' now ...       1
# 251028   stubtest: more concise error for forgotten arg...       1
# ...                                                    ...     ...
# 9377824  Legal Python circular imports result in loss o...       1
# 9377825  Crash when serializing property with forward r...       1
# 9378600  Suggest type annotations for partial types spa...       1
# 9378613  What to do about inferring types from multiple...       1
# 9395478         Multi-line -c flag doesn't work on Windows       1
#
#                                                       body         class
# 210262   The type of the following conditional expressi...  not_priority
# 210291   While interacting with `zip` I encountered a v...  not_priority
# 225547   After #5870 is done, it would be nice to also ...  not_priority
# 234003   \r\n**Bug Report**\r\n\r\n#7963 causes a serio...  not_priority
# 251028   **Feature**\r\n\r\nWhen the implementation add...  not_priority
# ...                                                    ...           ...
# 9377824  Example:\r\n\r\n`test/__init__.py`:\r\n```pyth...  not_priority
# 9377825  This serialization test case fails with a cras...  not_priority
# 9378600  We don't support inferring partial types from ...  not_priority
# 9378613  Typically mypy infers the type of the variable...  not_priority
# 9395478  Simplest reproduction seems to be\n\n``` bash\...  not_priority
#
# [306 rows x 10 columns]

# %%
# Remove mypy from the dataset
priority = priority[priority["repo"] != "python/mypy"]
priority
# Out:
#                    id         type           created_at  \
# 0        1.141755e+10  IssuesEvent  2020-02-03 00:02:50
# 1        1.141766e+10  IssuesEvent  2020-02-03 00:46:42
# 2        1.141777e+10  IssuesEvent  2020-02-03 01:25:06
# 3        1.141780e+10  IssuesEvent  2020-02-03 01:34:56
# 4        1.141786e+10  IssuesEvent  2020-02-03 01:52:04
# ...               ...          ...                  ...
# 9396571  8.109961e+09  IssuesEvent  2018-08-14 09:21:15
# 9396572  8.109961e+09  IssuesEvent  2018-08-14 09:21:16
# 9396573  8.109982e+09  IssuesEvent  2018-08-14 09:25:07
# 9396574  8.109983e+09  IssuesEvent  2018-08-14 09:25:24
# 9396575  8.109984e+09  IssuesEvent  2018-08-14 09:25:29
#
#                                 repo  \
# 0             poissonconsulting/term
# 1                WordPress/gutenberg
# 2                  MarkBind/markbind
# 3                  MarkBind/markbind
# 4             poissonconsulting/term
# ...                              ...
# 9396571                   urbit/arvo
# 9396572  highcharts/highcharts-react
# 9396573         Loriowar/comindivion
# 9396574   TiiQu-Network/TQ-test-page
# 9396575       prominic/Moonshine-IDE
#
#                                                   repo_url    action  \
# 0        https://api.github.com/repos/poissonconsulting...    opened
# 1         https://api.github.com/repos/WordPress/gutenberg    closed
# 2           https://api.github.com/repos/MarkBind/markbind  reopened
# 3           https://api.github.com/repos/MarkBind/markbind    closed
# 4        https://api.github.com/repos/poissonconsulting...    closed
# ...                                                    ...       ...
# 9396571            https://api.github.com/repos/urbit/arvo    opened
# 9396572  https://api.github.com/repos/highcharts/highch...    closed
# 9396573  https://api.github.com/repos/Loriowar/comindivion    opened
# 9396574  https://api.github.com/repos/TiiQu-Network/TQ-...    closed
# 9396575  https://api.github.com/repos/prominic/Moonshin...    closed
#
#                                                      title  labels  \
# 0              Document levels of validation in vld_term()       0
# 1                        Z-index issue using Classic block       0
# 2                    Indicate the language of a code block       0
# 3           Use one attribute name for header, title, name       0
# 4              Document levels of validation in vld_term()       0
# ...                                                    ...     ...
# 9396571            %bad-text trips up hall JSON conversion       1
# 9396572                            HighMaps mapBubble type       1
# 9396573  Add a validation on a belonging of a predicate...       1
# 9396574                     Error on submit with no values       1
# 9396575           Handle unknown tags in Visual Editor XML       1
#
#                                                       body         class
# 0               As this is what other functions reference.  low_priority
# 1        Selecting a link in the classic block and havi...  low_priority
# 2        **Tell us about your environment**\r\n\r\n* **...  low_priority
# 3        May be better to choose one of the three and u...  low_priority
# 4               As this is what other functions reference.  low_priority
# ...                                                    ...           ...
# 9396571  Haven't tested this in detail yet, but pretty ...  not_priority
# 9396572  Hello,\r\nIt is possible to create also HighMa...  not_priority
# 9396573  Now user can change html content of the intera...  not_priority
# 9396574  TypeError: Too few arguments in function sum (...  not_priority
# 9396575  If provided Visual Editor XML brings some unkn...  not_priority
#
# [9396270 rows x 10 columns]

# %%
# Drop duplicates by the content of the title
priority = priority.drop_duplicates(subset=['title'], keep='last')
priority.dropna(inplace=True)
priority.reset_index(inplace=True)
priority.drop(columns=["index"] , inplace= True)
priority["class"].value_counts()
# Out:
# /tmp/ipykernel_38653/1842014761.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority.dropna(inplace=True)
# /tmp/ipykernel_38653/1842014761.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority.drop(columns=["index"] , inplace= True)
# class
# not_priority    1330864
# low_priority     135000
# Name: count, dtype: int64

# %%
# Split the dataframe 
low_priority = priority.loc[priority['class'] == 'low_priority'].copy()
not_priority = priority.loc[priority['class'] == 'not_priority'].copy()

# %%
low_label_counts = low_priority["class"].value_counts()
not_label_counts = not_priority["class"].value_counts()
lp_count = low_label_counts["low_priority"]
print(f"low count: {lp_count}")
not_count = not_label_counts["not_priority"]
print(f"not count: {not_count}")
# Out:
# low count: 135000
# not count: 1330864

# %%
not_priority = not_priority.sample(frac=lp_count/not_count, random_state=42)
low_vs_not = pd.concat([low_priority, not_priority] , ignore_index = True)
low_vs_not["class"].value_counts()
# Out:
# class
# low_priority    135000
# not_priority    135000
# Name: count, dtype: int64

# %%
print(low_vs_not["title"][0])
print(low_vs_not["body"][0])
# Out:
# Z-index issue using Classic block
# Selecting a link in the classic block and having it active then selecting another link in the left sidebar it looked like this:
#
# ![screen shot 2018-05-31 at 18 37 33](https://user-images.githubusercontent.com/5323259/40795551-b05f6796-6502-11e8-8510-65198a4cf7df.png)

# %%
# Copy content of body to a new col named text
low_vs_not["text"] = low_vs_not["title"] + low_vs_not["body"]
low_vs_not.tail()
# Out:
#                   id         type           created_at  \
# 269995  1.576438e+10  IssuesEvent  2021-03-31 13:11:25
# 269996  1.516093e+10  IssuesEvent  2021-02-12 08:07:00
# 269997  1.309422e+10  IssuesEvent  2020-08-03 11:59:27
# 269998  9.816864e+09  IssuesEvent  2019-06-13 15:28:47
# 269999  2.661149e+10  IssuesEvent  2023-01-24 00:49:12
#
#                                repo  \
# 269995   GastonGit/Hot-Twitch-Clips
# 269996              bryntum/support
# 269997             iobio/clin.iobio
# 269998  gotthardp/python-mercuryapi
# 269999         thomasjacquin/allsky
#
#                                                  repo_url  action  \
# 269995  https://api.github.com/repos/GastonGit/Hot-Twi...  closed
# 269996       https://api.github.com/repos/bryntum/support  closed
# 269997      https://api.github.com/repos/iobio/clin.iobio  closed
# 269998  https://api.github.com/repos/gotthardp/python-...  closed
# 269999  https://api.github.com/repos/thomasjacquin/allsky  closed
#
#                                                     title  labels  \
# 269995        Twitch client needs to be able to reconnect       1
# 269996  Icon is not shown for resource time ranges whe...       1
# 269997    Update Frameshift or Mosaic logos on pdf report       1
# 269998                           Read_count staying at 1        1
# 269999  *** WARNING: time to take image () differs fro...       1
#
#                                                      body         class  \
# 269995  Needs to be set as option in "options" argumen...  not_priority
# 269996  https://www.bryntum.com/forum/viewtopic.php?f=...  not_priority
# 269997  ![image](https://user-images.githubusercontent...  not_priority
# 269998  Hello, When I run continous read mode the read...  not_priority
# 269999  <!-- ==================== Section 1 ==========...  not_priority
#
#                                                      text
# 269995  Twitch client needs to be able to reconnectNee...
# 269996  Icon is not shown for resource time ranges whe...
# 269997  Update Frameshift or Mosaic logos on pdf repor...
# 269998  Read_count staying at 1 Hello, When I run cont...
# 269999  *** WARNING: time to take image () differs fro...

# %%
low_vs_not["text"][0]
# Out:
# 'Z-index issue using Classic blockSelecting a link in the classic block and having it active then selecting another link in the left sidebar it looked like this:\r\n\r\n![screen shot 2018-05-31 at 18 37 33](https://user-images.githubusercontent.com/5323259/40795551-b05f6796-6502-11e8-8510-65198a4cf7df.png)\r\n'

# %%
# Make a new dataframe with only text, label and class cols.
all_priority_subset = low_vs_not[["text" , "labels" , "class"]]
all_priority_subset
# Out:
#                                                      text  labels  \
# 0       Z-index issue using Classic blockSelecting a l...       0
# 1       Indicate the language of a code block**Tell us...       0
# 2       Use one attribute name for header, title, name...       0
# 3       Document levels of validation in vld_term()As ...       0
# 4       Support puml files in boilerplatessee [this co...       0
# ...                                                   ...     ...
# 269995  Twitch client needs to be able to reconnectNee...       1
# 269996  Icon is not shown for resource time ranges whe...       1
# 269997  Update Frameshift or Mosaic logos on pdf repor...       1
# 269998  Read_count staying at 1 Hello, When I run cont...       1
# 269999  *** WARNING: time to take image () differs fro...       1
#
#                class
# 0       low_priority
# 1       low_priority
# 2       low_priority
# 3       low_priority
# 4       low_priority
# ...              ...
# 269995  not_priority
# 269996  not_priority
# 269997  not_priority
# 269998  not_priority
# 269999  not_priority
#
# [270000 rows x 3 columns]

# %%
# Convert to string
all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)
# Out:
# /tmp/ipykernel_38653/3106036705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)

# %%
all_priority_subset
# Out:
#                                                      text  labels  \
# 0       Z-index issue using Classic blockSelecting a l...       0
# 1       Indicate the language of a code block**Tell us...       0
# 2       Use one attribute name for header, title, name...       0
# 3       Document levels of validation in vld_term()As ...       0
# 4       Support puml files in boilerplatessee [this co...       0
# ...                                                   ...     ...
# 269995  Twitch client needs to be able to reconnectNee...       1
# 269996  Icon is not shown for resource time ranges whe...       1
# 269997  Update Frameshift or Mosaic logos on pdf repor...       1
# 269998  Read_count staying at 1 Hello, When I run cont...       1
# 269999  *** WARNING: time to take image () differs fro...       1
#
#                class                                           text_str
# 0       low_priority  Z-index issue using Classic blockSelecting a l...
# 1       low_priority  Indicate the language of a code block**Tell us...
# 2       low_priority  Use one attribute name for header, title, name...
# 3       low_priority  Document levels of validation in vld_term()As ...
# 4       low_priority  Support puml files in boilerplatessee [this co...
# ...              ...                                                ...
# 269995  not_priority  Twitch client needs to be able to reconnectNee...
# 269996  not_priority  Icon is not shown for resource time ranges whe...
# 269997  not_priority  Update Frameshift or Mosaic logos on pdf repor...
# 269998  not_priority  Read_count staying at 1 Hello, When I run cont...
# 269999  not_priority  *** WARNING: time to take image () differs fro...
#
# [270000 rows x 4 columns]

# %%
# Clean the data.
all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_38653/63294665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)

# %%
# Make a subset with text_clean and label
priority_label_text = all_priority_subset[["text_clean" , "labels", "class"]]
priority_label_text
# Out:
#                                                text_clean  labels  \
# 0       zindex issue using classic blockselecting a li...       0
# 1       indicate the language of a code blocktell us a...       0
# 2       use one attribute name for header title namema...       0
# 3       document levels of validation in vldtermas thi...       0
# 4       support puml files in boilerplatessee this com...       0
# ...                                                   ...     ...
# 269995  twitch client needs to be able to reconnectnee...       1
# 269996  icon is not shown for resource time ranges whe...       1
# 269997  update frameshift or mosaic logos on pdf repor...       1
# 269998  readcount staying at 1 hello when i run contin...       1
# 269999  warning time to take image differs from reques...       1
#
#                class
# 0       low_priority
# 1       low_priority
# 2       low_priority
# 3       low_priority
# 4       low_priority
# ...              ...
# 269995  not_priority
# 269996  not_priority
# 269997  not_priority
# 269998  not_priority
# 269999  not_priority
#
# [270000 rows x 3 columns]

# %%
# Need to dropna here since cleaning function returns NaN for not english text.
priority_label_text.dropna(inplace=True)
priority_label_text.reset_index(inplace=True)
priority_label_text.drop(columns=["index"] , inplace= True)

priority_label_text
# Out:
# /tmp/ipykernel_38653/239147930.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.dropna(inplace=True)
# /tmp/ipykernel_38653/239147930.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.drop(columns=["index"] , inplace= True)
#                                                text_clean  labels  \
# 0       zindex issue using classic blockselecting a li...       0
# 1       indicate the language of a code blocktell us a...       0
# 2       use one attribute name for header title namema...       0
# 3       document levels of validation in vldtermas thi...       0
# 4       support puml files in boilerplatessee this com...       0
# ...                                                   ...     ...
# 247034  twitch client needs to be able to reconnectnee...       1
# 247035  icon is not shown for resource time ranges whe...       1
# 247036  update frameshift or mosaic logos on pdf repor...       1
# 247037  readcount staying at 1 hello when i run contin...       1
# 247038  warning time to take image differs from reques...       1
#
#                class
# 0       low_priority
# 1       low_priority
# 2       low_priority
# 3       low_priority
# 4       low_priority
# ...              ...
# 247034  not_priority
# 247035  not_priority
# 247036  not_priority
# 247037  not_priority
# 247038  not_priority
#
# [247039 rows x 3 columns]

# %%
# Clean dataset with clean text and labels.
# 0 = high priority, 1 = not high priority
file_name = f"csv/clean_low_vs_not_priority.csv"
priority_label_text.to_csv(file_name, index=False)

# %%
pri = pd.read_csv(file_name)
pri
# Out:
#                                                text_clean  labels  \
# 0       zindex issue using classic blockselecting a li...       0
# 1       indicate the language of a code blocktell us a...       0
# 2       use one attribute name for header title namema...       0
# 3       document levels of validation in vldtermas thi...       0
# 4       support puml files in boilerplatessee this com...       0
# ...                                                   ...     ...
# 247034  twitch client needs to be able to reconnectnee...       1
# 247035  icon is not shown for resource time ranges whe...       1
# 247036  update frameshift or mosaic logos on pdf repor...       1
# 247037  readcount staying at 1 hello when i run contin...       1
# 247038  warning time to take image differs from reques...       1
#
#                class
# 0       low_priority
# 1       low_priority
# 2       low_priority
# 3       low_priority
# 4       low_priority
# ...              ...
# 247034  not_priority
# 247035  not_priority
# 247036  not_priority
# 247037  not_priority
# 247038  not_priority
#
# [247039 rows x 3 columns]
