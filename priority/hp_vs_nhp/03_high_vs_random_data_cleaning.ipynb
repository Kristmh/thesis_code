# %% [markdown]
# # Data cleaning
# We want the class with labels as numerical value and the body with clean text.
#
# This will remove:
# * duplicates
# * NaN entires
# * non english
# * url, html
#
# * make it lowercase
# * combine title and body

# %%
import pandas as pd
import sys
sys.path.append("../../scripts_shared/")
from preprocess_text import preprocess_text

# %%
# Read CSV into a dataframe
high_priority = pd.read_csv("csv/high_priority_full_dataset.csv", index_col=0)
not_high_priority = pd.read_csv("csv/non_high_priority_full.csv", index_col=0)
high_priority
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3       1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4       1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...              ...          ...                  ...
# 373788  7.334924e+09  IssuesEvent  2018-03-06 01:09:12
# 373789  7.334984e+09  IssuesEvent  2018-03-06 01:28:23
# 373790  7.335034e+09  IssuesEvent  2018-03-06 01:44:11
# 373791  7.335035e+09  IssuesEvent  2018-03-06 01:44:26
# 373792  7.335039e+09  IssuesEvent  2018-03-06 01:45:34
#
#                                        repo  \
# 0                 unitystation/unitystation
# 1       zowe/sample-spring-boot-api-service
# 2                        openmsupply/mobile
# 3       UltimateCodeMonkeys/CodeMonkeysMVVM
# 4        wordpress-mobile/WordPress-Android
# ...                                     ...
# 373788           StrangeLoopGames/EcoIssues
# 373789                        asteca/ASteCA
# 373790               wh1ter0se/PowerUp-2018
# 373791               wh1ter0se/PowerUp-2018
# 373792                      xcat2/xcat-core
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/unitystation/unit...  closed
# 1       https://api.github.com/repos/zowe/sample-sprin...  closed
# 2         https://api.github.com/repos/openmsupply/mobile  closed
# 3       https://api.github.com/repos/UltimateCodeMonke...  opened
# 4       https://api.github.com/repos/wordpress-mobile/...  closed
# ...                                                   ...     ...
# 373788  https://api.github.com/repos/StrangeLoopGames/...  closed
# 373789         https://api.github.com/repos/asteca/ASteCA  closed
# 373790  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 373791  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 373792       https://api.github.com/repos/xcat2/xcat-core  closed
#
#                                                     title  \
# 0       Client breaking NRE when using edit field on C...
# 1       The SDK provides a separate Java (no-Spring) l...
# 2                      Auto-log out after some time frame
# 3       Migrate: CodeMonkeys ViewModelNavigationServic...
# 4       IA Reader filter bottom sheet: manage untitled...
# ...                                                   ...
# 373788       Meteor hit - Can no longer join server 6.4.1
# 373789  Improve performance of synth cluster generatio...
# 373790  Get and record refined PID loops for rotation ...
# 373791  Figure out why CyborgCommandSpit() runs early ...
# 373792  error message improvement when adding users in...
#
#                                                    labels  \
# 0                        Bug High Priority In Progress UI
# 1       Feature: API Security Priority: High no-issue-...
# 2       Docs: not needed Effort: small Feature Module:...
# 3       Priority: High Status: In Progress Type: Maint...
# 4                        IA Reader [Pri] High [Type] Task
# ...                                                   ...
# 373788                                      High Priority
# 373789           code_enhance p:high performance synth-cl
# 373790                 IRL development high priority java
# 373791                         R&D bug high priority java
# 373792      priority:high sprint1 status:pending type:bug
#
#                                                      body
# 0       ### Bug:\r\n\r\nIf you use the edit field of t...
# 1       - The commons-spring library is split into:\r\...
# 2       ## Is your feature request related to a proble...
# 3       Migrate the Xamarin.Forms navigation service i...
# 4       In the filter bottom sheet we introduced in th...
# ...                                                   ...
# 373788  Just had the meteor hit on our server and now ...
# 373789  Follow up on #227.\r\n\r\n#### 0. Initial `syn...
# 373790  Pretty simple, and pretty sure we already have...
# 373791  The problem is that when we run autonomous (so...
# 373792  Problem statement: error message when adding x...
#
# [373793 rows x 9 columns]

# %%
not_high_priority
# Out:
#                    id         type           created_at  \
# 0        1.141754e+10  IssuesEvent  2020-02-03 00:00:07
# 1        1.141754e+10  IssuesEvent  2020-02-03 00:00:12
# 2        1.141754e+10  IssuesEvent  2020-02-03 00:00:13
# 3        1.141754e+10  IssuesEvent  2020-02-03 00:00:16
# 4        1.141754e+10  IssuesEvent  2020-02-03 00:00:18
# ...               ...          ...                  ...
# 1992258  8.109961e+09  IssuesEvent  2018-08-14 09:21:15
# 1992259  8.109961e+09  IssuesEvent  2018-08-14 09:21:16
# 1992260  8.109982e+09  IssuesEvent  2018-08-14 09:25:07
# 1992261  8.109983e+09  IssuesEvent  2018-08-14 09:25:24
# 1992262  8.109984e+09  IssuesEvent  2018-08-14 09:25:29
#
#                                   repo  \
# 0        automationbs/testbugreporting
# 1                PowerShell/PowerShell
# 2                  thadiun/hello-world
# 3                PowerShell/PowerShell
# 4                PowerShell/PowerShell
# ...                                ...
# 1992258                     urbit/arvo
# 1992259    highcharts/highcharts-react
# 1992260           Loriowar/comindivion
# 1992261     TiiQu-Network/TQ-test-page
# 1992262         prominic/Moonshine-IDE
#
#                                                   repo_url  action  \
# 0        https://api.github.com/repos/automationbs/test...  opened
# 1        https://api.github.com/repos/PowerShell/PowerS...  closed
# 2         https://api.github.com/repos/thadiun/hello-world  closed
# 3        https://api.github.com/repos/PowerShell/PowerS...  closed
# 4        https://api.github.com/repos/PowerShell/PowerS...  closed
# ...                                                    ...     ...
# 1992258            https://api.github.com/repos/urbit/arvo  opened
# 1992259  https://api.github.com/repos/highcharts/highch...  closed
# 1992260  https://api.github.com/repos/Loriowar/comindivion  opened
# 1992261  https://api.github.com/repos/TiiQu-Network/TQ-...  closed
# 1992262  https://api.github.com/repos/prominic/Moonshin...  closed
#
#                                                      title  \
# 0                                            Default title
# 1                                               Show alias
# 2                   [Test] testing needs-triage (no delay)
# 3                                     $ENV in using module
# 4                Measure-Command does not measure its self
# ...                                                    ...
# 1992258            %bad-text trips up hall JSON conversion
# 1992259                            HighMaps mapBubble type
# 1992260  Add a validation on a belonging of a predicate...
# 1992261                     Error on submit with no values
# 1992262           Handle unknown tags in Visual Editor XML
#
#                                                     labels  \
# 0                                                      bug
# 1                       Issue-Question Resolution-Answered
# 2                                                   triage
# 3         Area-Language Issue-Question Resolution-Answered
# 4        Area-Cmdlets-Utility Issue-Question Resolution...
# ...                                                    ...
# 1992258      :hall / :talk cause known marks web interface
# 1992259                                      pending reply
# 1992260                              bug data manipulation
# 1992261                                                bug
# 1992262               Investigation PrimeFaces enhancement
#
#                                                       body
# 0        default description\n\n|Property | Value|\n|--...
# 1        <!--\r\n\r\nFor Windows PowerShell 5.1 issues,...
# 2                                                      NaN
# 3        # Summary of the new feature/enhancement\r\n\r...
# 4        ## The Issue\r\nI'm pretty sure this was just ...
# ...                                                    ...
# 1992258  Haven't tested this in detail yet, but pretty ...
# 1992259  Hello,\r\nIt is possible to create also HighMa...
# 1992260  Now user can change html content of the intera...
# 1992261  TypeError: Too few arguments in function sum (...
# 1992262  If provided Visual Editor XML brings some unkn...
#
# [1992263 rows x 9 columns]

# %%
contains_stale = not_high_priority['labels'].str.contains("stale", case=False, na=False)
not_high_priority= not_high_priority[~contains_stale].reset_index(drop=True)
not_high_priority.reset_index(drop=True, inplace=True)
not_high_priority
# Out:
#                    id         type           created_at  \
# 0        1.141754e+10  IssuesEvent  2020-02-03 00:00:07
# 1        1.141754e+10  IssuesEvent  2020-02-03 00:00:12
# 2        1.141754e+10  IssuesEvent  2020-02-03 00:00:13
# 3        1.141754e+10  IssuesEvent  2020-02-03 00:00:16
# 4        1.141754e+10  IssuesEvent  2020-02-03 00:00:18
# ...               ...          ...                  ...
# 1992258  8.109961e+09  IssuesEvent  2018-08-14 09:21:15
# 1992259  8.109961e+09  IssuesEvent  2018-08-14 09:21:16
# 1992260  8.109982e+09  IssuesEvent  2018-08-14 09:25:07
# 1992261  8.109983e+09  IssuesEvent  2018-08-14 09:25:24
# 1992262  8.109984e+09  IssuesEvent  2018-08-14 09:25:29
#
#                                   repo  \
# 0        automationbs/testbugreporting
# 1                PowerShell/PowerShell
# 2                  thadiun/hello-world
# 3                PowerShell/PowerShell
# 4                PowerShell/PowerShell
# ...                                ...
# 1992258                     urbit/arvo
# 1992259    highcharts/highcharts-react
# 1992260           Loriowar/comindivion
# 1992261     TiiQu-Network/TQ-test-page
# 1992262         prominic/Moonshine-IDE
#
#                                                   repo_url  action  \
# 0        https://api.github.com/repos/automationbs/test...  opened
# 1        https://api.github.com/repos/PowerShell/PowerS...  closed
# 2         https://api.github.com/repos/thadiun/hello-world  closed
# 3        https://api.github.com/repos/PowerShell/PowerS...  closed
# 4        https://api.github.com/repos/PowerShell/PowerS...  closed
# ...                                                    ...     ...
# 1992258            https://api.github.com/repos/urbit/arvo  opened
# 1992259  https://api.github.com/repos/highcharts/highch...  closed
# 1992260  https://api.github.com/repos/Loriowar/comindivion  opened
# 1992261  https://api.github.com/repos/TiiQu-Network/TQ-...  closed
# 1992262  https://api.github.com/repos/prominic/Moonshin...  closed
#
#                                                      title  \
# 0                                            Default title
# 1                                               Show alias
# 2                   [Test] testing needs-triage (no delay)
# 3                                     $ENV in using module
# 4                Measure-Command does not measure its self
# ...                                                    ...
# 1992258            %bad-text trips up hall JSON conversion
# 1992259                            HighMaps mapBubble type
# 1992260  Add a validation on a belonging of a predicate...
# 1992261                     Error on submit with no values
# 1992262           Handle unknown tags in Visual Editor XML
#
#                                                     labels  \
# 0                                                      bug
# 1                       Issue-Question Resolution-Answered
# 2                                                   triage
# 3         Area-Language Issue-Question Resolution-Answered
# 4        Area-Cmdlets-Utility Issue-Question Resolution...
# ...                                                    ...
# 1992258      :hall / :talk cause known marks web interface
# 1992259                                      pending reply
# 1992260                              bug data manipulation
# 1992261                                                bug
# 1992262               Investigation PrimeFaces enhancement
#
#                                                       body
# 0        default description\n\n|Property | Value|\n|--...
# 1        <!--\r\n\r\nFor Windows PowerShell 5.1 issues,...
# 2                                                      NaN
# 3        # Summary of the new feature/enhancement\r\n\r...
# 4        ## The Issue\r\nI'm pretty sure this was just ...
# ...                                                    ...
# 1992258  Haven't tested this in detail yet, but pretty ...
# 1992259  Hello,\r\nIt is possible to create also HighMa...
# 1992260  Now user can change html content of the intera...
# 1992261  TypeError: Too few arguments in function sum (...
# 1992262  If provided Visual Editor XML brings some unkn...
#
# [1992263 rows x 9 columns]

# %%
# Remove debt from datasets
technical_debt_regex = r'debt|\bTD\b'
contains_debt_high_priority = high_priority['labels'].str.contains(technical_debt_regex, case=False, na=False)
contains_debt_not_high_priority = not_high_priority['labels'].str.contains(technical_debt_regex, case=False, na=False)
debt = high_priority[contains_debt_high_priority].reset_index(drop=True)
debt
# Out:
#                id         type           created_at  \
# 0    2.656199e+10  IssuesEvent  2023-01-20 16:36:45
# 1    2.227510e+10  IssuesEvent  2022-06-10 15:50:10
# 2    8.882455e+09  IssuesEvent  2019-01-14 13:16:54
# 3    2.330166e+10  IssuesEvent  2022-08-07 12:16:49
# 4    2.330180e+10  IssuesEvent  2022-08-07 12:39:55
# ..            ...          ...                  ...
# 679  2.332739e+10  IssuesEvent  2022-08-08 23:04:52
# 680  1.414105e+10  IssuesEvent  2020-11-10 12:07:20
# 681  2.589332e+10  IssuesEvent  2022-12-14 19:57:19
# 682  1.052572e+10  IssuesEvent  2019-09-30 15:35:16
# 683  4.928457e+09  IssuesEvent  2016-11-27 10:10:39
#
#                                            repo  \
# 0                                 bcgov/cas-cif
# 1    department-of-veterans-affairs/va.gov-team
# 2      GoogleCloudPlatform/google-cloud-eclipse
# 3                            KinsonDigital/SWCM
# 4            KinsonDigital/GitHubReleaseChecker
# ..                                          ...
# 679                    KinsonDigital/GitHubData
# 680                              zeebe-io/zeebe
# 681                               bcgov/cas-cif
# 682                              huridocs/uwazi
# 683    GoogleCloudPlatform/google-cloud-eclipse
#
#                                               repo_url  action  \
# 0           https://api.github.com/repos/bcgov/cas-cif  closed
# 1    https://api.github.com/repos/department-of-vet...  closed
# 2    https://api.github.com/repos/GoogleCloudPlatfo...  opened
# 3      https://api.github.com/repos/KinsonDigital/SWCM  closed
# 4    https://api.github.com/repos/KinsonDigital/Git...  closed
# ..                                                 ...     ...
# 679  https://api.github.com/repos/KinsonDigital/Git...  opened
# 680        https://api.github.com/repos/zeebe-io/zeebe  closed
# 681         https://api.github.com/repos/bcgov/cas-cif  opened
# 682        https://api.github.com/repos/huridocs/uwazi  closed
# 683  https://api.github.com/repos/GoogleCloudPlatfo...  closed
#
#                                                  title  \
# 0    Tech Debt: some prod data must be a migration ...
# 1       Remove step from Platform Orientation template
# 2             Upgrade to latest appengine-plugins-core
# 3                       🚧Update issue and PR templates
# 4                       🚧Update issue and PR templates
# ..                                                 ...
# 679     🚧Fix project item and research issue templates
# 680                Use MAPPED storage level by default
# 681  Tech Debt: some prod data must be a migration ...
# 682  Create e2e of custom home-page and custom CSS ...
# 683                           Hamcrest jars in release
#
#                                                 labels  \
# 0                              Tech Debt High Priority
# 1    tech-debt Orientation governance-team Ready hi...
# 2                        Tech Debt high priority ready
# 3    good first issue high priority preview tech de...
# 4    good first issue high priority preview tech de...
# ..                                                 ...
# 679  good first issue high priority tech debt 📝docu...
# 680  Impact: Performance Impact: Tech Debt Priority...
# 681         Backlog Refinement Tech Debt High Priority
# 682            Priority: High Status: Sprint Tech Debt
# 683                      build high priority Tech Debt
#
#                                                   body
# 0    ### Description of the Tech Debt ###\r\n\r\nRi...
# 1    ## User Story\nAs a new VFS team member, I wan...
# 2    The latest release of appengine-plugins-core d...
# 3    ### I have done the items below . . .\n\n- [x]...
# 4    ### I have done the items below . . .\n\n- [x]...
# ..                                                 ...
# 679  ### Complete The Item Below\n\n- [X] I have up...
# 680  **Is your feature request related to a problem...
# 681  ###Description of the Tech Debt###\n\nRight no...
# 682  This is the first page every client sees. If t...
# 683  Our release build bundles in 3 hamcrest jars. ...
#
# [684 rows x 9 columns]

# %%
# Remove debt from the dataset
high_priority = high_priority[~contains_debt_high_priority].reset_index(drop=True)
high_priority.reset_index(drop=True, inplace=True)
high_priority
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3       1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4       1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...              ...          ...                  ...
# 373104  7.334924e+09  IssuesEvent  2018-03-06 01:09:12
# 373105  7.334984e+09  IssuesEvent  2018-03-06 01:28:23
# 373106  7.335034e+09  IssuesEvent  2018-03-06 01:44:11
# 373107  7.335035e+09  IssuesEvent  2018-03-06 01:44:26
# 373108  7.335039e+09  IssuesEvent  2018-03-06 01:45:34
#
#                                        repo  \
# 0                 unitystation/unitystation
# 1       zowe/sample-spring-boot-api-service
# 2                        openmsupply/mobile
# 3       UltimateCodeMonkeys/CodeMonkeysMVVM
# 4        wordpress-mobile/WordPress-Android
# ...                                     ...
# 373104           StrangeLoopGames/EcoIssues
# 373105                        asteca/ASteCA
# 373106               wh1ter0se/PowerUp-2018
# 373107               wh1ter0se/PowerUp-2018
# 373108                      xcat2/xcat-core
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/unitystation/unit...  closed
# 1       https://api.github.com/repos/zowe/sample-sprin...  closed
# 2         https://api.github.com/repos/openmsupply/mobile  closed
# 3       https://api.github.com/repos/UltimateCodeMonke...  opened
# 4       https://api.github.com/repos/wordpress-mobile/...  closed
# ...                                                   ...     ...
# 373104  https://api.github.com/repos/StrangeLoopGames/...  closed
# 373105         https://api.github.com/repos/asteca/ASteCA  closed
# 373106  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 373107  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 373108       https://api.github.com/repos/xcat2/xcat-core  closed
#
#                                                     title  \
# 0       Client breaking NRE when using edit field on C...
# 1       The SDK provides a separate Java (no-Spring) l...
# 2                      Auto-log out after some time frame
# 3       Migrate: CodeMonkeys ViewModelNavigationServic...
# 4       IA Reader filter bottom sheet: manage untitled...
# ...                                                   ...
# 373104       Meteor hit - Can no longer join server 6.4.1
# 373105  Improve performance of synth cluster generatio...
# 373106  Get and record refined PID loops for rotation ...
# 373107  Figure out why CyborgCommandSpit() runs early ...
# 373108  error message improvement when adding users in...
#
#                                                    labels  \
# 0                        Bug High Priority In Progress UI
# 1       Feature: API Security Priority: High no-issue-...
# 2       Docs: not needed Effort: small Feature Module:...
# 3       Priority: High Status: In Progress Type: Maint...
# 4                        IA Reader [Pri] High [Type] Task
# ...                                                   ...
# 373104                                      High Priority
# 373105           code_enhance p:high performance synth-cl
# 373106                 IRL development high priority java
# 373107                         R&D bug high priority java
# 373108      priority:high sprint1 status:pending type:bug
#
#                                                      body
# 0       ### Bug:\r\n\r\nIf you use the edit field of t...
# 1       - The commons-spring library is split into:\r\...
# 2       ## Is your feature request related to a proble...
# 3       Migrate the Xamarin.Forms navigation service i...
# 4       In the filter bottom sheet we introduced in th...
# ...                                                   ...
# 373104  Just had the meteor hit on our server and now ...
# 373105  Follow up on #227.\r\n\r\n#### 0. Initial `syn...
# 373106  Pretty simple, and pretty sure we already have...
# 373107  The problem is that when we run autonomous (so...
# 373108  Problem statement: error message when adding x...
#
# [373109 rows x 9 columns]

# %%
not_high_priority = not_high_priority[~contains_debt_not_high_priority].reset_index(drop=True)
not_high_priority.reset_index(drop=True, inplace=True)
not_high_priority
# Out:
#                    id         type           created_at  \
# 0        1.141754e+10  IssuesEvent  2020-02-03 00:00:07
# 1        1.141754e+10  IssuesEvent  2020-02-03 00:00:12
# 2        1.141754e+10  IssuesEvent  2020-02-03 00:00:13
# 3        1.141754e+10  IssuesEvent  2020-02-03 00:00:16
# 4        1.141754e+10  IssuesEvent  2020-02-03 00:00:18
# ...               ...          ...                  ...
# 1988529  8.109961e+09  IssuesEvent  2018-08-14 09:21:15
# 1988530  8.109961e+09  IssuesEvent  2018-08-14 09:21:16
# 1988531  8.109982e+09  IssuesEvent  2018-08-14 09:25:07
# 1988532  8.109983e+09  IssuesEvent  2018-08-14 09:25:24
# 1988533  8.109984e+09  IssuesEvent  2018-08-14 09:25:29
#
#                                   repo  \
# 0        automationbs/testbugreporting
# 1                PowerShell/PowerShell
# 2                  thadiun/hello-world
# 3                PowerShell/PowerShell
# 4                PowerShell/PowerShell
# ...                                ...
# 1988529                     urbit/arvo
# 1988530    highcharts/highcharts-react
# 1988531           Loriowar/comindivion
# 1988532     TiiQu-Network/TQ-test-page
# 1988533         prominic/Moonshine-IDE
#
#                                                   repo_url  action  \
# 0        https://api.github.com/repos/automationbs/test...  opened
# 1        https://api.github.com/repos/PowerShell/PowerS...  closed
# 2         https://api.github.com/repos/thadiun/hello-world  closed
# 3        https://api.github.com/repos/PowerShell/PowerS...  closed
# 4        https://api.github.com/repos/PowerShell/PowerS...  closed
# ...                                                    ...     ...
# 1988529            https://api.github.com/repos/urbit/arvo  opened
# 1988530  https://api.github.com/repos/highcharts/highch...  closed
# 1988531  https://api.github.com/repos/Loriowar/comindivion  opened
# 1988532  https://api.github.com/repos/TiiQu-Network/TQ-...  closed
# 1988533  https://api.github.com/repos/prominic/Moonshin...  closed
#
#                                                      title  \
# 0                                            Default title
# 1                                               Show alias
# 2                   [Test] testing needs-triage (no delay)
# 3                                     $ENV in using module
# 4                Measure-Command does not measure its self
# ...                                                    ...
# 1988529            %bad-text trips up hall JSON conversion
# 1988530                            HighMaps mapBubble type
# 1988531  Add a validation on a belonging of a predicate...
# 1988532                     Error on submit with no values
# 1988533           Handle unknown tags in Visual Editor XML
#
#                                                     labels  \
# 0                                                      bug
# 1                       Issue-Question Resolution-Answered
# 2                                                   triage
# 3         Area-Language Issue-Question Resolution-Answered
# 4        Area-Cmdlets-Utility Issue-Question Resolution...
# ...                                                    ...
# 1988529      :hall / :talk cause known marks web interface
# 1988530                                      pending reply
# 1988531                              bug data manipulation
# 1988532                                                bug
# 1988533               Investigation PrimeFaces enhancement
#
#                                                       body
# 0        default description\n\n|Property | Value|\n|--...
# 1        <!--\r\n\r\nFor Windows PowerShell 5.1 issues,...
# 2                                                      NaN
# 3        # Summary of the new feature/enhancement\r\n\r...
# 4        ## The Issue\r\nI'm pretty sure this was just ...
# ...                                                    ...
# 1988529  Haven't tested this in detail yet, but pretty ...
# 1988530  Hello,\r\nIt is possible to create also HighMa...
# 1988531  Now user can change html content of the intera...
# 1988532  TypeError: Too few arguments in function sum (...
# 1988533  If provided Visual Editor XML brings some unkn...
#
# [1988534 rows x 9 columns]

# %%
# Number or different labels
high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                   count
# labels
# bug high priority                 10435
# high priority                     10360
# High Priority                      7484
# enhancement high priority          5486
# Priority: High                     4751
# priority.High                      3694
# priority.High type.Task            3685
# priority.high type.task            3209
# priority.High type.Story           2979
# priority.high                      2749
# bug priority: high                 2306
# high-priority                      2262
# priority: high                     2178
# bug high-priority                  2159
# type.Story priority.High           2155
# priority.high type.story           2130
# type.Task priority.High            2022
# bug High Priority                  1888
# High priority                      1815
# Priority: High Type: Bug           1768
# priority:high                      1726
# bug priority:high                  1470
# High Priority bug                  1338
# Priority: High bug                 1200
# Bug High Priority                  1143
# feature high priority              1091
# enhancement priority: high         1090
# enhancement high-priority          1053
# enhancement priority:high           982
# priority-high                       955
# bug priority-high                   927
# enhancement High Priority           902
# bug Priority: High                  837
# Priority: High Type: Enhancement    835
# high priority task                  831
# bug High priority                   744
# priority high                       733
# priority.high type.bug              717
# priority: high type: bug            704
# Type: Bug Priority: High            639
# Bug Priority: High                  620
# High Priority enhancement           611
# documentation priority.High         600
# prio:high                           587
# Bug - High Priority                 562
# priority.High type.Enhancement      562
# bug prio-high                       541
# Priority: High Type: Feature        541
# priority.high type.enhancement      540
# priority/high                       537

# %%
high_priority[high_priority["repo"] == "python/mypy"]
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body]
# Index: []

# %%
# Remove mypy from the dataset
high_priority = high_priority[high_priority["repo"] != "python/mypy"]
high_priority = high_priority[high_priority["repo"] != "rust-lang/rust"]
high_priority = high_priority[high_priority["repo"] != "flutter/flutter"]
# reset index
high_priority.reset_index(drop=True, inplace=True)
high_priority
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3       1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4       1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...              ...          ...                  ...
# 372370  7.334924e+09  IssuesEvent  2018-03-06 01:09:12
# 372371  7.334984e+09  IssuesEvent  2018-03-06 01:28:23
# 372372  7.335034e+09  IssuesEvent  2018-03-06 01:44:11
# 372373  7.335035e+09  IssuesEvent  2018-03-06 01:44:26
# 372374  7.335039e+09  IssuesEvent  2018-03-06 01:45:34
#
#                                        repo  \
# 0                 unitystation/unitystation
# 1       zowe/sample-spring-boot-api-service
# 2                        openmsupply/mobile
# 3       UltimateCodeMonkeys/CodeMonkeysMVVM
# 4        wordpress-mobile/WordPress-Android
# ...                                     ...
# 372370           StrangeLoopGames/EcoIssues
# 372371                        asteca/ASteCA
# 372372               wh1ter0se/PowerUp-2018
# 372373               wh1ter0se/PowerUp-2018
# 372374                      xcat2/xcat-core
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/unitystation/unit...  closed
# 1       https://api.github.com/repos/zowe/sample-sprin...  closed
# 2         https://api.github.com/repos/openmsupply/mobile  closed
# 3       https://api.github.com/repos/UltimateCodeMonke...  opened
# 4       https://api.github.com/repos/wordpress-mobile/...  closed
# ...                                                   ...     ...
# 372370  https://api.github.com/repos/StrangeLoopGames/...  closed
# 372371         https://api.github.com/repos/asteca/ASteCA  closed
# 372372  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 372373  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 372374       https://api.github.com/repos/xcat2/xcat-core  closed
#
#                                                     title  \
# 0       Client breaking NRE when using edit field on C...
# 1       The SDK provides a separate Java (no-Spring) l...
# 2                      Auto-log out after some time frame
# 3       Migrate: CodeMonkeys ViewModelNavigationServic...
# 4       IA Reader filter bottom sheet: manage untitled...
# ...                                                   ...
# 372370       Meteor hit - Can no longer join server 6.4.1
# 372371  Improve performance of synth cluster generatio...
# 372372  Get and record refined PID loops for rotation ...
# 372373  Figure out why CyborgCommandSpit() runs early ...
# 372374  error message improvement when adding users in...
#
#                                                    labels  \
# 0                        Bug High Priority In Progress UI
# 1       Feature: API Security Priority: High no-issue-...
# 2       Docs: not needed Effort: small Feature Module:...
# 3       Priority: High Status: In Progress Type: Maint...
# 4                        IA Reader [Pri] High [Type] Task
# ...                                                   ...
# 372370                                      High Priority
# 372371           code_enhance p:high performance synth-cl
# 372372                 IRL development high priority java
# 372373                         R&D bug high priority java
# 372374      priority:high sprint1 status:pending type:bug
#
#                                                      body
# 0       ### Bug:\r\n\r\nIf you use the edit field of t...
# 1       - The commons-spring library is split into:\r\...
# 2       ## Is your feature request related to a proble...
# 3       Migrate the Xamarin.Forms navigation service i...
# 4       In the filter bottom sheet we introduced in th...
# ...                                                   ...
# 372370  Just had the meteor hit on our server and now ...
# 372371  Follow up on #227.\r\n\r\n#### 0. Initial `syn...
# 372372  Pretty simple, and pretty sure we already have...
# 372373  The problem is that when we run autonomous (so...
# 372374  Problem statement: error message when adding x...
#
# [372375 rows x 9 columns]

# %%
not_high_priority[not_high_priority["repo"] == "python/mypy"]
# Out:
#                    id         type           created_at         repo  \
# 20982    1.142706e+10  IssuesEvent  2020-02-03 23:33:27  python/mypy
# 21011    1.142707e+10  IssuesEvent  2020-02-03 23:35:24  python/mypy
# 36683    1.362788e+10  IssuesEvent  2020-09-24 13:13:03  python/mypy
# 45317    1.363241e+10  IssuesEvent  2020-09-24 19:36:27  python/mypy
# 62973    2.407484e+10  IssuesEvent  2022-09-18 17:03:35  python/mypy
# ...               ...          ...                  ...          ...
# 1969269  7.349652e+09  IssuesEvent  2018-03-08 11:27:27  python/mypy
# 1970054  7.349972e+09  IssuesEvent  2018-03-08 12:44:13  python/mypy
# 1970068  7.349979e+09  IssuesEvent  2018-03-08 12:45:41  python/mypy
# 1974857  1.785710e+10  IssuesEvent  2021-09-05 08:41:21  python/mypy
# 1987414  8.109448e+09  IssuesEvent  2018-08-14 07:36:08  python/mypy
#
#                                          repo_url  action  \
# 20982    https://api.github.com/repos/python/mypy  closed
# 21011    https://api.github.com/repos/python/mypy  closed
# 36683    https://api.github.com/repos/python/mypy  opened
# 45317    https://api.github.com/repos/python/mypy  opened
# 62973    https://api.github.com/repos/python/mypy  opened
# ...                                           ...     ...
# 1969269  https://api.github.com/repos/python/mypy  closed
# 1970054  https://api.github.com/repos/python/mypy  opened
# 1970068  https://api.github.com/repos/python/mypy  closed
# 1974857  https://api.github.com/repos/python/mypy  opened
# 1987414  https://api.github.com/repos/python/mypy  closed
#
#                                                      title  \
# 20982             Type of conditional expression is object
# 21011      Type inference of Tuples returns object instead
# 36683          Daemon support for --follow-imports=silent
# 45317    regression: assignment of 'builtins.type' now ...
# 62973    stubtest: more concise error for forgotten arg...
# ...                                                    ...
# 1969269  Crash when serializing property with forward r...
# 1970054  Suggest type annotations for partial types spa...
# 1970068  What to do about inferring types from multiple...
# 1974857  Name already defined error with warlus operato...
# 1987414         Multi-line -c flag doesn't work on Windows
#
#                                                     labels  \
# 20982    false-positive needs discussion priority-1-nor...
# 21011                   bug false-positive priority-0-high
# 36683                                              feature
# 45317                                                  bug
# 62973                                              feature
# ...                                                    ...
# 1969269            crash priority-0-high topic-incremental
# 1970054  feature priority-2-low topic-fine-grained-incr...
# 1970068  feature priority-0-high topic-fine-grained-inc...
# 1974857                                                bug
# 1987414                                 bug priority-2-low
#
#                                                       body
# 20982    The type of the following conditional expressi...
# 21011    While interacting with `zip` I encountered a v...
# 36683    After #5870 is done, it would be nice to also ...
# 45317    \r\n**Bug Report**\r\n\r\n#7963 causes a serio...
# 62973    **Feature**\r\n\r\nWhen the implementation add...
# ...                                                    ...
# 1969269  This serialization test case fails with a cras...
# 1970054  We don't support inferring partial types from ...
# 1970068  Typically mypy infers the type of the variable...
# 1974857  Invalid error for mypy: Name "x" already defin...
# 1987414  Simplest reproduction seems to be\n\n``` bash\...
#
# [312 rows x 9 columns]

# %%
# Remove mypy from the dataset
not_high_priority = not_high_priority[not_high_priority["repo"] != "python/mypy"]
not_high_priority = not_high_priority[not_high_priority["repo"] != "rust-lang/rust"]
not_high_priority = not_high_priority[not_high_priority["repo"] != "flutter/flutter"]
# reset index
not_high_priority.reset_index(drop=True, inplace=True)
not_high_priority
# Out:
#                    id         type           created_at  \
# 0        1.141754e+10  IssuesEvent  2020-02-03 00:00:07
# 1        1.141754e+10  IssuesEvent  2020-02-03 00:00:12
# 2        1.141754e+10  IssuesEvent  2020-02-03 00:00:13
# 3        1.141754e+10  IssuesEvent  2020-02-03 00:00:16
# 4        1.141754e+10  IssuesEvent  2020-02-03 00:00:18
# ...               ...          ...                  ...
# 1984095  8.109961e+09  IssuesEvent  2018-08-14 09:21:15
# 1984096  8.109961e+09  IssuesEvent  2018-08-14 09:21:16
# 1984097  8.109982e+09  IssuesEvent  2018-08-14 09:25:07
# 1984098  8.109983e+09  IssuesEvent  2018-08-14 09:25:24
# 1984099  8.109984e+09  IssuesEvent  2018-08-14 09:25:29
#
#                                   repo  \
# 0        automationbs/testbugreporting
# 1                PowerShell/PowerShell
# 2                  thadiun/hello-world
# 3                PowerShell/PowerShell
# 4                PowerShell/PowerShell
# ...                                ...
# 1984095                     urbit/arvo
# 1984096    highcharts/highcharts-react
# 1984097           Loriowar/comindivion
# 1984098     TiiQu-Network/TQ-test-page
# 1984099         prominic/Moonshine-IDE
#
#                                                   repo_url  action  \
# 0        https://api.github.com/repos/automationbs/test...  opened
# 1        https://api.github.com/repos/PowerShell/PowerS...  closed
# 2         https://api.github.com/repos/thadiun/hello-world  closed
# 3        https://api.github.com/repos/PowerShell/PowerS...  closed
# 4        https://api.github.com/repos/PowerShell/PowerS...  closed
# ...                                                    ...     ...
# 1984095            https://api.github.com/repos/urbit/arvo  opened
# 1984096  https://api.github.com/repos/highcharts/highch...  closed
# 1984097  https://api.github.com/repos/Loriowar/comindivion  opened
# 1984098  https://api.github.com/repos/TiiQu-Network/TQ-...  closed
# 1984099  https://api.github.com/repos/prominic/Moonshin...  closed
#
#                                                      title  \
# 0                                            Default title
# 1                                               Show alias
# 2                   [Test] testing needs-triage (no delay)
# 3                                     $ENV in using module
# 4                Measure-Command does not measure its self
# ...                                                    ...
# 1984095            %bad-text trips up hall JSON conversion
# 1984096                            HighMaps mapBubble type
# 1984097  Add a validation on a belonging of a predicate...
# 1984098                     Error on submit with no values
# 1984099           Handle unknown tags in Visual Editor XML
#
#                                                     labels  \
# 0                                                      bug
# 1                       Issue-Question Resolution-Answered
# 2                                                   triage
# 3         Area-Language Issue-Question Resolution-Answered
# 4        Area-Cmdlets-Utility Issue-Question Resolution...
# ...                                                    ...
# 1984095      :hall / :talk cause known marks web interface
# 1984096                                      pending reply
# 1984097                              bug data manipulation
# 1984098                                                bug
# 1984099               Investigation PrimeFaces enhancement
#
#                                                       body
# 0        default description\n\n|Property | Value|\n|--...
# 1        <!--\r\n\r\nFor Windows PowerShell 5.1 issues,...
# 2                                                      NaN
# 3        # Summary of the new feature/enhancement\r\n\r...
# 4        ## The Issue\r\nI'm pretty sure this was just ...
# ...                                                    ...
# 1984095  Haven't tested this in detail yet, but pretty ...
# 1984096  Hello,\r\nIt is possible to create also HighMa...
# 1984097  Now user can change html content of the intera...
# 1984098  TypeError: Too few arguments in function sum (...
# 1984099  If provided Visual Editor XML brings some unkn...
#
# [1984100 rows x 9 columns]

# %%
# Number or different labels
not_high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                           count
# labels
# enhancement                              244118
# bug                                      240559
# security vulnerability                    53086
# question                                  34827
# feature                                   20725
# documentation                             17935
# Bug                                       12282
# help wanted                               10875
# wontfix                                    7279
# greenkeeper                                6842
# stat:awaiting response                     6602
# Sub Task Failing Test Paddle Frontend      6463
# good first issue                           6418
# enhancement help wanted                    6290
# invalid                                    6093
# task                                       5668
# feature request                            5605
# in progress                                5372
# duplicate                                  5235
# bug enhancement                            4899
# enhancement good first issue               4516
# npm-install-script                         4452
# status monika                              4372
# kind/bug                                   4335
# design                                     4178
# JAX Frontend Sub Task Failing Test         4099
# Enhancement                                3402
# Feature                                    3266
# watchout                                   3241
# bug help wanted                            3094
# type: bug                                  2958
# triage                                     2701
# action-needsmoderation                     2551
# frontend                                   2536
# new feature                                2493
# new-review user-submission                 2417
# Task                                       2378
# Type: Bug                                  2292
# documentation enhancement                  2277
# improvement                                2225
# weekly-digest                              2211
# todo                                       2190
# enhancement question                       2121
# new-version user-submission                2089
# Mend: dependency security vulnerability    2073
# feature-request                            1898
# discussion                                 1887
# docs                                       1878
# backend                                    1869
# bug fixed                                  1863

# %%
#Give each priority a label by number.
# 'Label encoding'. Makes is easier for machine learning models to work with categorical data.
high_priority["label"] = 1
high_priority["class"] = "high_priority"
high_priority.head()
# Out:
#              id         type           created_at  \
# 0  1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1  1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2  1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3  1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4  1.141756e+10  IssuesEvent  2020-02-03 00:08:03
#
#                                   repo  \
# 0            unitystation/unitystation
# 1  zowe/sample-spring-boot-api-service
# 2                   openmsupply/mobile
# 3  UltimateCodeMonkeys/CodeMonkeysMVVM
# 4   wordpress-mobile/WordPress-Android
#
#                                             repo_url  action  \
# 0  https://api.github.com/repos/unitystation/unit...  closed
# 1  https://api.github.com/repos/zowe/sample-sprin...  closed
# 2    https://api.github.com/repos/openmsupply/mobile  closed
# 3  https://api.github.com/repos/UltimateCodeMonke...  opened
# 4  https://api.github.com/repos/wordpress-mobile/...  closed
#
#                                                title  \
# 0  Client breaking NRE when using edit field on C...
# 1  The SDK provides a separate Java (no-Spring) l...
# 2                 Auto-log out after some time frame
# 3  Migrate: CodeMonkeys ViewModelNavigationServic...
# 4  IA Reader filter bottom sheet: manage untitled...
#
#                                               labels  \
# 0                   Bug High Priority In Progress UI
# 1  Feature: API Security Priority: High no-issue-...
# 2  Docs: not needed Effort: small Feature Module:...
# 3  Priority: High Status: In Progress Type: Maint...
# 4                   IA Reader [Pri] High [Type] Task
#
#                                                 body  label          class
# 0  ### Bug:\r\n\r\nIf you use the edit field of t...      1  high_priority
# 1  - The commons-spring library is split into:\r\...      1  high_priority
# 2  ## Is your feature request related to a proble...      1  high_priority
# 3  Migrate the Xamarin.Forms navigation service i...      1  high_priority
# 4  In the filter bottom sheet we introduced in th...      1  high_priority

# %%
not_high_priority["label"] = 0
not_high_priority["class"] = "not_high_priority" 
not_high_priority.head()
# Out:
#              id         type           created_at  \
# 0  1.141754e+10  IssuesEvent  2020-02-03 00:00:07
# 1  1.141754e+10  IssuesEvent  2020-02-03 00:00:12
# 2  1.141754e+10  IssuesEvent  2020-02-03 00:00:13
# 3  1.141754e+10  IssuesEvent  2020-02-03 00:00:16
# 4  1.141754e+10  IssuesEvent  2020-02-03 00:00:18
#
#                             repo  \
# 0  automationbs/testbugreporting
# 1          PowerShell/PowerShell
# 2            thadiun/hello-world
# 3          PowerShell/PowerShell
# 4          PowerShell/PowerShell
#
#                                             repo_url  action  \
# 0  https://api.github.com/repos/automationbs/test...  opened
# 1  https://api.github.com/repos/PowerShell/PowerS...  closed
# 2   https://api.github.com/repos/thadiun/hello-world  closed
# 3  https://api.github.com/repos/PowerShell/PowerS...  closed
# 4  https://api.github.com/repos/PowerShell/PowerS...  closed
#
#                                        title  \
# 0                              Default title
# 1                                 Show alias
# 2     [Test] testing needs-triage (no delay)
# 3                       $ENV in using module
# 4  Measure-Command does not measure its self
#
#                                               labels  \
# 0                                                bug
# 1                 Issue-Question Resolution-Answered
# 2                                             triage
# 3   Area-Language Issue-Question Resolution-Answered
# 4  Area-Cmdlets-Utility Issue-Question Resolution...
#
#                                                 body  label              class
# 0  default description\n\n|Property | Value|\n|--...      0  not_high_priority
# 1  <!--\r\n\r\nFor Windows PowerShell 5.1 issues,...      0  not_high_priority
# 2                                                NaN      0  not_high_priority
# 3  # Summary of the new feature/enhancement\r\n\r...      0  not_high_priority
# 4  ## The Issue\r\nI'm pretty sure this was just ...      0  not_high_priority

# %%
# Drop duplicates by the content of the title
high_priority = high_priority.drop_duplicates(subset=['title'], keep='last')
high_priority.dropna(inplace=True)
high_priority.reset_index(inplace=True)
high_priority.drop(columns=["index"] , inplace= True)
high_priority["class"].value_counts()
# Out:
# /tmp/ipykernel_115379/3728497997.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_priority.dropna(inplace=True)
# /tmp/ipykernel_115379/3728497997.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_priority.drop(columns=["index"] , inplace= True)
# class
# high_priority    242229
# Name: count, dtype: int64

# %%
# Drop duplicates by the content of the title
not_high_priority = not_high_priority.drop_duplicates(subset=['title'], keep='last')
not_high_priority.dropna(inplace=True)
not_high_priority.reset_index(inplace=True)
not_high_priority.drop(columns=["index"] , inplace= True)
not_high_priority["class"].value_counts()
# Out:
# /tmp/ipykernel_115379/3768055171.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority.dropna(inplace=True)
# /tmp/ipykernel_115379/3768055171.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority.drop(columns=["index"] , inplace= True)
# class
# not_high_priority    1365464
# Name: count, dtype: int64

# %%
high_priority.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242229 entries, 0 to 242228
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          242229 non-null  float64
#  1   type        242229 non-null  object
#  2   created_at  242229 non-null  object
#  3   repo        242229 non-null  object
#  4   repo_url    242229 non-null  object
#  5   action      242229 non-null  object
#  6   title       242229 non-null  object
#  7   labels      242229 non-null  object
#  8   body        242229 non-null  object
#  9   label       242229 non-null  int64
#  10  class       242229 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 20.3+ MB

# %%
label_counts = high_priority["class"].value_counts()
label_counts_nhp = not_high_priority["class"].value_counts()
print(label_counts)
not_high_priority_count = label_counts_nhp["not_high_priority"]
print(not_high_priority_count)
hp_count = label_counts["high_priority"]
hp_count
# Out:
# class
# high_priority    242229
# Name: count, dtype: int64
# 1365464
# 242229

# %%
not_high_priority = not_high_priority.sample(frac=hp_count/not_high_priority_count, random_state=42)
not_high_priority
# Out:
#                    id         type           created_at  \
# 890557   2.336898e+10  IssuesEvent  2022-08-10 17:57:43
# 563403   5.399778e+09  IssuesEvent  2017-02-27 20:19:05
# 801099   1.476169e+10  IssuesEvent  2021-01-09 00:08:26
# 1297719  1.636222e+10  IssuesEvent  2021-05-14 11:18:24
# 853596   5.581179e+09  IssuesEvent  2017-03-28 18:17:26
# ...               ...          ...                  ...
# 447257   1.576155e+10  IssuesEvent  2021-03-31 10:05:56
# 925178   2.914500e+10  IssuesEvent  2023-05-18 01:31:37
# 660225   2.701047e+10  IssuesEvent  2023-02-10 15:01:46
# 497400   7.894383e+09  IssuesEvent  2018-06-28 21:17:08
# 440646   1.575520e+10  IssuesEvent  2021-03-31 01:21:05
#
#                                                       repo  \
# 890557                                        GEOLYTIX/xyz
# 563403                                  projecthydra/sufia
# 801099                  stoolball-england/stoolball-org-uk
# 1297719          MarkusBordihn/adaptive_performance_tweaks
# 853596                         apollographql/apollo-client
# ...                                                    ...
# 447257                                  LemonFace0309/msmr
# 925178                           kubernetes-sigs/kustomize
# 660225   Azure-Samples/app-service-javascript-sap-cloud...
# 497400                                   CuBoulder/express
# 440646                                     bitbar/finka-js
#
#                                                   repo_url  action  \
# 890557           https://api.github.com/repos/GEOLYTIX/xyz  closed
# 563403     https://api.github.com/repos/projecthydra/sufia  closed
# 801099   https://api.github.com/repos/stoolball-england...  opened
# 1297719  https://api.github.com/repos/MarkusBordihn/ada...  closed
# 853596   https://api.github.com/repos/apollographql/apo...  closed
# ...                                                    ...     ...
# 447257     https://api.github.com/repos/LemonFace0309/msmr  closed
# 925178   https://api.github.com/repos/kubernetes-sigs/k...  closed
# 660225   https://api.github.com/repos/Azure-Samples/app...  closed
# 497400      https://api.github.com/repos/CuBoulder/express  closed
# 440646        https://api.github.com/repos/bitbar/finka-js  opened
#
#                                                      title  \
# 890557                                 Missing null filter
# 563403   Confusing screen reader label for Add files bu...
# 801099                Inconsistent indenting on rules page
# 1297719                       Well Idk how to explain this
# 853596   Data reducer requires queries and mutations to...
# ...                                                    ...
# 447257                   Research Page - Responsive Design
# 925178   When Using Openshift route in base layer and a...
# 660225               [FEATURE] Add Terraform as IaC option
# 497400   user_external_invite PHP Notices When Sending ...
# 440646   CVE-2021-23358 (High) detected in underscore-1...
#
#                                  labels  \
# 890557                          Feature
# 563403       enhancement user interface
# 801099                              bug
# 1297719  coremod issue not reproducible
# 853596                      help wanted
# ...                                 ...
# 447257                      enhancement
# 925178            kind/bug needs-triage
# 660225                      enhancement
# 497400                         type:Bug
# 440646           security vulnerability
#
#                                                       body  label  \
# 890557   The boolean filter checks whether a value is t...      0
# 563403   ### Descriptive summary\r\nRelated to Sufia 7....      0
# 801099                   Seen in Firefox on Android tablet      0
# 1297719  Your Mod is causing recipes to stop working on...      0
# 853596   Right now the `data` reducer requires `mutatio...      0
# ...                                                    ...    ...
# 447257   - optimize for xs->m, m->xl, xl++\r\n![image](...      0
# 925178   ### What happened?\r\n\r\ni have the following...      0
# 660225   **Is your feature request related to a problem...      0
# 497400   ## Context\r\n\r\n```\r\nWarning: array_map():...      0
# 440646   ## CVE-2021-23358 - High Severity Vulnerabilit...      0
#
#                      class
# 890557   not_high_priority
# 563403   not_high_priority
# 801099   not_high_priority
# 1297719  not_high_priority
# 853596   not_high_priority
# ...                    ...
# 447257   not_high_priority
# 925178   not_high_priority
# 660225   not_high_priority
# 497400   not_high_priority
# 440646   not_high_priority
#
# [242229 rows x 11 columns]

# %%
all_priority = pd.concat([high_priority,not_high_priority] , ignore_index = True)
all_priority.tail()
# Out:
#                   id         type           created_at  \
# 484453  1.576155e+10  IssuesEvent  2021-03-31 10:05:56
# 484454  2.914500e+10  IssuesEvent  2023-05-18 01:31:37
# 484455  2.701047e+10  IssuesEvent  2023-02-10 15:01:46
# 484456  7.894383e+09  IssuesEvent  2018-06-28 21:17:08
# 484457  1.575520e+10  IssuesEvent  2021-03-31 01:21:05
#
#                                                      repo  \
# 484453                                 LemonFace0309/msmr
# 484454                          kubernetes-sigs/kustomize
# 484455  Azure-Samples/app-service-javascript-sap-cloud...
# 484456                                  CuBoulder/express
# 484457                                    bitbar/finka-js
#
#                                                  repo_url  action  \
# 484453    https://api.github.com/repos/LemonFace0309/msmr  closed
# 484454  https://api.github.com/repos/kubernetes-sigs/k...  closed
# 484455  https://api.github.com/repos/Azure-Samples/app...  closed
# 484456     https://api.github.com/repos/CuBoulder/express  closed
# 484457       https://api.github.com/repos/bitbar/finka-js  opened
#
#                                                     title  \
# 484453                  Research Page - Responsive Design
# 484454  When Using Openshift route in base layer and a...
# 484455              [FEATURE] Add Terraform as IaC option
# 484456  user_external_invite PHP Notices When Sending ...
# 484457  CVE-2021-23358 (High) detected in underscore-1...
#
#                         labels  \
# 484453             enhancement
# 484454   kind/bug needs-triage
# 484455             enhancement
# 484456                type:Bug
# 484457  security vulnerability
#
#                                                      body  label  \
# 484453  - optimize for xs->m, m->xl, xl++\r\n![image](...      0
# 484454  ### What happened?\r\n\r\ni have the following...      0
# 484455  **Is your feature request related to a problem...      0
# 484456  ## Context\r\n\r\n```\r\nWarning: array_map():...      0
# 484457  ## CVE-2021-23358 - High Severity Vulnerabilit...      0
#
#                     class
# 484453  not_high_priority
# 484454  not_high_priority
# 484455  not_high_priority
# 484456  not_high_priority
# 484457  not_high_priority

# %%
# 
all_priority["label"].value_counts()
# Out:
# label
# 1    242229
# 0    242229
# Name: count, dtype: int64

# %%
print(all_priority["title"][0])
print(all_priority["body"][0])
# Out:
# Auto-log out after some time frame
# ## Is your feature request related to a problem? Please describe.
#
# From @craigdrown
#
# IC Requirement: Automatically log a user out after a time frame of X for security reasons. Data should not be lost which was being worked on.
#
# ## Describe the solution you'd like
#
# Log the user out after X time
#
# ## Implementation
#
# Could use store custom data `logoutTimeoutPeriodInSecondsOrMinutes` to set the period..
#
# - Use [AppState](https://facebook.github.io/react-native/docs/appstate#addeventlistener) to hook into the app going into the background - log the user out if so. Android would go to sleep after X amount of time, putting the app into the background (I THINK, UNTESTED)
# - Use a package like https://www.npmjs.com/package/redux-idle-monitor to track activity, have a schedule that is reset each time an event happens.
# - Use the above package but combine it with the current user authentication scheduler (tries to re-auth against the server every X minutes, or the local DB if no connection available) - I think not good
#
# ## Describe alternatives you've considered
#
# Not having this in the dispensary/IC branch 🤣
#
# ## Additional context
#
# @wlthomson @mark-prins @Chris-Petty thoughts?

# %%
# Copy content of body to a new col named text
all_priority["text"] = all_priority["title"] + " " + all_priority["body"]
all_priority.tail()
# Out:
#                   id         type           created_at  \
# 484453  1.576155e+10  IssuesEvent  2021-03-31 10:05:56
# 484454  2.914500e+10  IssuesEvent  2023-05-18 01:31:37
# 484455  2.701047e+10  IssuesEvent  2023-02-10 15:01:46
# 484456  7.894383e+09  IssuesEvent  2018-06-28 21:17:08
# 484457  1.575520e+10  IssuesEvent  2021-03-31 01:21:05
#
#                                                      repo  \
# 484453                                 LemonFace0309/msmr
# 484454                          kubernetes-sigs/kustomize
# 484455  Azure-Samples/app-service-javascript-sap-cloud...
# 484456                                  CuBoulder/express
# 484457                                    bitbar/finka-js
#
#                                                  repo_url  action  \
# 484453    https://api.github.com/repos/LemonFace0309/msmr  closed
# 484454  https://api.github.com/repos/kubernetes-sigs/k...  closed
# 484455  https://api.github.com/repos/Azure-Samples/app...  closed
# 484456     https://api.github.com/repos/CuBoulder/express  closed
# 484457       https://api.github.com/repos/bitbar/finka-js  opened
#
#                                                     title  \
# 484453                  Research Page - Responsive Design
# 484454  When Using Openshift route in base layer and a...
# 484455              [FEATURE] Add Terraform as IaC option
# 484456  user_external_invite PHP Notices When Sending ...
# 484457  CVE-2021-23358 (High) detected in underscore-1...
#
#                         labels  \
# 484453             enhancement
# 484454   kind/bug needs-triage
# 484455             enhancement
# 484456                type:Bug
# 484457  security vulnerability
#
#                                                      body  label  \
# 484453  - optimize for xs->m, m->xl, xl++\r\n![image](...      0
# 484454  ### What happened?\r\n\r\ni have the following...      0
# 484455  **Is your feature request related to a problem...      0
# 484456  ## Context\r\n\r\n```\r\nWarning: array_map():...      0
# 484457  ## CVE-2021-23358 - High Severity Vulnerabilit...      0
#
#                     class                                               text
# 484453  not_high_priority  Research Page - Responsive Design - optimize f...
# 484454  not_high_priority  When Using Openshift route in base layer and a...
# 484455  not_high_priority  [FEATURE] Add Terraform as IaC option **Is you...
# 484456  not_high_priority  user_external_invite PHP Notices When Sending ...
# 484457  not_high_priority  CVE-2021-23358 (High) detected in underscore-1...

# %%
all_priority["text"][0]
# Out:
# "Auto-log out after some time frame ## Is your feature request related to a problem? Please describe.\r\n\r\nFrom @craigdrown \r\n\r\nIC Requirement: Automatically log a user out after a time frame of X for security reasons. Data should not be lost which was being worked on.\r\n\r\n## Describe the solution you'd like\r\n\r\nLog the user out after X time\r\n\r\n## Implementation\r\n\r\nCould use store custom data `logoutTimeoutPeriodInSecondsOrMinutes` to set the period..\r\n\r\n- Use [AppState](https://facebook.github.io/react-native/docs/appstate#addeventlistener) to hook into the app going into the background - log the user out if so. Android would go to sleep after X amount of time, putting the app into the background (I THINK, UNTESTED)\r\n- Use a package like https://www.npmjs.com/package/redux-idle-monitor to track activity, have a schedule that is reset each time an event happens.\r\n- Use the above package but combine it with the current user authentication scheduler (tries to re-auth against the server every X minutes, or the local DB if no connection available) - I think not good\r\n\r\n## Describe alternatives you've considered\r\n\r\nNot having this in the dispensary/IC branch 🤣 \r\n\r\n## Additional context\r\n\r\n@wlthomson @mark-prins @Chris-Petty thoughts?\r\n"

# %%
# Make a new dataframe with only text, label and class cols.
all_priority_subset = all_priority[["text" , "label" , "class"]]
all_priority_subset
# Out:
#                                                      text  label  \
# 0       Auto-log out after some time frame ## Is your ...      1
# 1       Image Picker for Source Implement an Android I...      1
# 2       Fix Video Page ListItem Hovering Behaviour - W...      1
# 3       Escape shuttle reaches ludicrous speed ## Desc...      1
# 4             constructing  virtual router structure \r\n      1
# ...                                                   ...    ...
# 484453  Research Page - Responsive Design - optimize f...      0
# 484454  When Using Openshift route in base layer and a...      0
# 484455  [FEATURE] Add Terraform as IaC option **Is you...      0
# 484456  user_external_invite PHP Notices When Sending ...      0
# 484457  CVE-2021-23358 (High) detected in underscore-1...      0
#
#                     class
# 0           high_priority
# 1           high_priority
# 2           high_priority
# 3           high_priority
# 4           high_priority
# ...                   ...
# 484453  not_high_priority
# 484454  not_high_priority
# 484455  not_high_priority
# 484456  not_high_priority
# 484457  not_high_priority
#
# [484458 rows x 3 columns]

# %%
# Convert to string
all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)
# Out:
# /tmp/ipykernel_115379/3106036705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)

# %%
all_priority_subset
# Out:
#                                                      text  label  \
# 0       Auto-log out after some time frame ## Is your ...      1
# 1       Image Picker for Source Implement an Android I...      1
# 2       Fix Video Page ListItem Hovering Behaviour - W...      1
# 3       Escape shuttle reaches ludicrous speed ## Desc...      1
# 4             constructing  virtual router structure \r\n      1
# ...                                                   ...    ...
# 484453  Research Page - Responsive Design - optimize f...      0
# 484454  When Using Openshift route in base layer and a...      0
# 484455  [FEATURE] Add Terraform as IaC option **Is you...      0
# 484456  user_external_invite PHP Notices When Sending ...      0
# 484457  CVE-2021-23358 (High) detected in underscore-1...      0
#
#                     class                                           text_str
# 0           high_priority  Auto-log out after some time frame ## Is your ...
# 1           high_priority  Image Picker for Source Implement an Android I...
# 2           high_priority  Fix Video Page ListItem Hovering Behaviour - W...
# 3           high_priority  Escape shuttle reaches ludicrous speed ## Desc...
# 4           high_priority        constructing  virtual router structure \r\n
# ...                   ...                                                ...
# 484453  not_high_priority  Research Page - Responsive Design - optimize f...
# 484454  not_high_priority  When Using Openshift route in base layer and a...
# 484455  not_high_priority  [FEATURE] Add Terraform as IaC option **Is you...
# 484456  not_high_priority  user_external_invite PHP Notices When Sending ...
# 484457  not_high_priority  CVE-2021-23358 (High) detected in underscore-1...
#
# [484458 rows x 4 columns]

# %%
# Clean the data.
all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_115379/63294665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)

# %%
# Make a subset with text_clean and label
priority_label_text = all_priority_subset[["text_clean" , "label"]]
priority_label_text
# Out:
#                                                text_clean  label
# 0       autolog out after some time frame is your feat...      1
# 1       image picker for source implement an android i...      1
# 2       fix video page listitem hovering behaviour whe...      1
# 3       escape shuttle reaches ludicrous speed descrip...      1
# 4                                                     NaN      1
# ...                                                   ...    ...
# 484453  research page responsive design optimize for x...      0
# 484454  when using openshift route in base layer and a...      0
# 484455  add terraform as iac option is your feature re...      0
# 484456  userexternalinvite php notices when sending an...      0
# 484457  high detected in high severity vulnerability v...      0
#
# [484458 rows x 2 columns]

# %%
# Row with NaN
priority_label_text[priority_label_text.isna().any(axis=1)]
# Out:
#        text_clean  label
# 4             NaN      1
# 51            NaN      1
# 52            NaN      1
# 53            NaN      1
# 54            NaN      1
# ...           ...    ...
# 484352        NaN      0
# 484407        NaN      0
# 484411        NaN      0
# 484423        NaN      0
# 484435        NaN      0
#
# [42676 rows x 2 columns]

# %%
# Need to dropna here since cleaning function returns NaN for not english text.
priority_label_text.dropna(inplace=True)
priority_label_text.reset_index(drop=True,inplace=True)

priority_label_text
# Out:
# /tmp/ipykernel_115379/2434149455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.dropna(inplace=True)
#                                                text_clean  label
# 0       autolog out after some time frame is your feat...      1
# 1       image picker for source implement an android i...      1
# 2       fix video page listitem hovering behaviour whe...      1
# 3       escape shuttle reaches ludicrous speed descrip...      1
# 4       binder doesnt load notebooks outside of the un...      1
# ...                                                   ...    ...
# 441777  research page responsive design optimize for x...      0
# 441778  when using openshift route in base layer and a...      0
# 441779  add terraform as iac option is your feature re...      0
# 441780  userexternalinvite php notices when sending an...      0
# 441781  high detected in high severity vulnerability v...      0
#
# [441782 rows x 2 columns]

# %%
# Rows with NaN
priority_label_text[priority_label_text.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [text_clean, label]
# Index: []

# %%
from sklearn.utils import resample

# Split the dataset into two based on the label
df_majority = priority_label_text[priority_label_text['label'] == 1]
df_minority = priority_label_text[priority_label_text['label'] == 0]

# Undersample the majority class
df_majority_undersampled = resample(df_majority, 
                                     replace=False,    # sample without replacement
                                     n_samples=len(df_minority),     # to match minority class
                                     random_state=123) # reproducible results

# Combine minority class with downsampled majority class
df_balanced = pd.concat([df_majority_undersampled, df_minority])

# Shuffle the dataset to avoid any ordering bias
df_balanced = df_balanced.sample(frac=1).reset_index(drop=True)
priority_label_text = df_balanced
priority_label_text["label"].value_counts()
# Out:
# label
# 0    215313
# 1    215313
# Name: count, dtype: int64

# %%
priority_label_text[priority_label_text.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [text_clean, label]
# Index: []

# %%
null_rows = priority_label_text[priority_label_text['text_clean'].isnull()]
null_rows
# Out:
# Empty DataFrame
# Columns: [text_clean, label]
# Index: []

# %%
# Clean dataset with clean text and labels.
# 0 = high priority, 1 = not high priority
file_name = f"csv/clean_high_vs_non_high_priority.csv"
priority_label_text.to_csv(file_name, index=False)

# %%
pri = pd.read_csv(file_name)
pri
# Out:
#                                                text_clean  label
# 0       to add link about browser support of copy comm...      0
# 1       improve properties of tasks definition files a...      0
# 2       bug exporting obj only uses one material gantt...      0
# 3       items with a single result in error weapon poi...      1
# 4       cards that are put into shadows with assault f...      0
# ...                                                   ...    ...
# 430621  move resources blog post links and video from ...      0
# 430622  requisition line comments describe the bug req...      1
# 430623  have bug in create in seeds describe the bug h...      0
# 430624                               log in notifications      0
# 430625  announce launch of honeycomb airdrop as a poly...      1
#
# [430626 rows x 2 columns]

# %%
null_rows = pri[pri['text_clean'].isnull()]
null_rows
# Out:
#        text_clean  label
# 3129          NaN      0
# 3531          NaN      0
# 5819          NaN      0
# 6645          NaN      0
# 7862          NaN      0
# ...           ...    ...
# 416671        NaN      0
# 418696        NaN      0
# 426919        NaN      0
# 427334        NaN      0
# 427862        NaN      0
#
# [339 rows x 2 columns]

# %%
# Remove rows with NaN
pri = pri.dropna()
# Reset index
pri.reset_index(drop=True, inplace=True)
pri
# Out:
#                                                text_clean  label
# 0       to add link about browser support of copy comm...      0
# 1       improve properties of tasks definition files a...      0
# 2       bug exporting obj only uses one material gantt...      0
# 3       items with a single result in error weapon poi...      1
# 4       cards that are put into shadows with assault f...      0
# ...                                                   ...    ...
# 430282  move resources blog post links and video from ...      0
# 430283  requisition line comments describe the bug req...      1
# 430284  have bug in create in seeds describe the bug h...      0
# 430285                               log in notifications      0
# 430286  announce launch of honeycomb airdrop as a poly...      1
#
# [430287 rows x 2 columns]

# %%
# save to csv
pri.to_csv("csv/clean_hp_nhp_hmm.csv", index=False)
