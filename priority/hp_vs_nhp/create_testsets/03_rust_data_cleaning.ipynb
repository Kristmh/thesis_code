# %% [markdown]
# # Data cleaning
# We want the class with labels as numerical value and the body with clean text.
#
# This will remove:
# * duplicates
# * NaN entires
# * non english
# * url, html
#
# * make it lowercase
# * combine title and body

# %%
import pandas as pd
import sys
sys.path.append("../../../scripts_shared/")
from preprocess_text import preprocess_text

# %%
# Read CSV into a dataframe
filename = "csv/rust_testset.csv"
df = pd.read_csv(filename)
df
# Out:
#                  id         type           created_at            repo  \
# 0      1.141793e+10  IssuesEvent  2020-02-03 02:13:37  rust-lang/rust
# 1      1.141819e+10  IssuesEvent  2020-02-03 03:28:10  rust-lang/rust
# 2      1.141898e+10  IssuesEvent  2020-02-03 06:38:37  rust-lang/rust
# 3      1.142033e+10  IssuesEvent  2020-02-03 09:54:09  rust-lang/rust
# 4      1.142279e+10  IssuesEvent  2020-02-03 14:49:22  rust-lang/rust
# ...             ...          ...                  ...             ...
# 25187  2.060418e+10  IssuesEvent  2022-03-06 18:28:40  rust-lang/rust
# 25188  2.060495e+10  IssuesEvent  2022-03-06 20:51:18  rust-lang/rust
# 25189  2.060524e+10  IssuesEvent  2022-03-06 21:46:17  rust-lang/rust
# 25190  2.060527e+10  IssuesEvent  2022-03-06 21:52:30  rust-lang/rust
# 25191  7.334739e+09  IssuesEvent  2018-03-06 00:10:18  rust-lang/rust
#
#                                           repo_url    action  \
# 0      https://api.github.com/repos/rust-lang/rust    opened
# 1      https://api.github.com/repos/rust-lang/rust    closed
# 2      https://api.github.com/repos/rust-lang/rust    closed
# 3      https://api.github.com/repos/rust-lang/rust    closed
# 4      https://api.github.com/repos/rust-lang/rust    closed
# ...                                            ...       ...
# 25187  https://api.github.com/repos/rust-lang/rust    opened
# 25188  https://api.github.com/repos/rust-lang/rust    closed
# 25189  https://api.github.com/repos/rust-lang/rust    opened
# 25190  https://api.github.com/repos/rust-lang/rust    closed
# 25191  https://api.github.com/repos/rust-lang/rust  reopened
#
#                                                    title  \
# 0      ICE due to `#[track_caller]` shim with -Z unle...
# 1      assertion failed: bpos.to_u32() >= mbc.pos.to_...
# 2           ice on glacier 26459.rs with -Zsave-analysis
# 3         Compiler performance returning nested closures
# 4      ICE due to `#[track_caller]` shim with -Z unle...
# ...                                                  ...
# 25187                                ICE with generics.i
# 25188  discrepancy between debug and release: panic a...
# 25189             ICE: rustdoc GATs unwrap `None` #94009
# 25190  Compiler crash during doc test with generic_co...
# 25191        Editing proc-macro crate = undefined symbol
#
#                                                   labels  \
# 0      A-codegen A-const-eval A-const-fn F-track_call...
# 1            A-parser C-bug I-ICE I-nominated T-compiler
# 2                 A-save-analysis C-bug I-ICE T-compiler
# 3      A-borrow-checker A-closures I-compiletime T-co...
# 4      A-codegen A-const-eval A-const-fn C-bug F-trac...
# ...                                                  ...
# 25187                             I-ICE T-compiler C-bug
# 25188                                              C-bug
# 25189                             I-ICE T-compiler C-bug
# 25190                             I-ICE T-compiler C-bug
# 25191                                 A-macros-2.0 C-bug
#
#                                                     body
# 0      Reproducer:\r\n\r\n```rust\r\n// compile-flags...
# 1      I'm seeing an internal compiler error on the f...
# 2      ````rust\r\nfn main() {\r\n    match 'a' {\r\n...
# 3      The following takes approximately one year to ...
# 4      Reproducer:\r\n\r\n```rust\r\n// compile-flags...
# ...                                                  ...
# 25187  \r\n\r\n### Code\r\n\r\nhttps://play.rust-lang...
# 25188  <!--\r\nThank you for filing a bug report! 🐛 P...
# 25189  <!--\r\nThank you for finding an Internal Comp...
# 25190  Trying to use `generic_const_exprs` (#76560) t...
# 25191  Note: This is with incremental-comp turned off...
#
# [25192 rows x 9 columns]

# %%
# Number or different labels
df.labels.value_counts().to_frame()[:50]
# Out:
#                                            count
# labels
# C-bug                                       3476
# I-ICE T-compiler C-bug                      1560
# A-diagnostics T-compiler                    1156
# C-bug I-ICE T-compiler                       784
# A-docs                                       480
# I-ICE                                        412
# A-diagnostics                                328
# A-rustdoc                                    195
# C-bug regression-untriaged                   174
# T-rustdoc                                    168
# A-libs                                       166
# T-libs-api C-tracking-issue                  133
# C-tracking-issue                             129
# I-nominated T-compiler                       100
# A-rustbuild                                   95
# C-bug A-miri                                  89
# A-lint                                        85
# A-miri C-bug                                  83
# C-bug T-rustdoc                               82
# A-build                                       79
# I-ICE T-compiler C-bug glacier                79
# T-libs                                        78
# A-typesystem                                  73
# A-diagnostics C-enhancement                   72
# T-rustdoc A-rustdoc-ui                        71
# C-feature-request T-libs                      70
# regression-from-stable-to-beta                67
# I-ICE T-compiler A-incr-comp C-bug            66
# A-diagnostics C-enhancement T-compiler        66
# C-tracking-issue T-libs                       65
# A-rustbuild C-bug                             64
# A-macros                                      62
# B-unstable final-comment-period T-libs        59
# T-compiler                                    55
# T-doc                                         51
# regression-from-stable-to-nightly             51
# T-compiler regression-from-stable-to-beta     50
# C-bug I-ICE                                   50
# E-needstest I-ICE                             50
# A-book A-docs                                 48
# A-debuginfo                                   47
# T-rustdoc C-bug                               47
# I-ICE T-compiler C-bug E-needs-mcve           46
# A-diagnostics C-bug                           39
# A-diagnostics C-bug T-compiler                37
# A-infrastructure                              36
# B-unstable C-tracking-issue T-libs            34
# A-associated-items                            33
# C-enhancement T-libs                          33
# A-intra-doc-links C-bug T-rustdoc             32

# %%
# Split data based on labels. Contains P0 and P1 in one dataframe, the rest in another

pattern = 'P-(high|critical)'
# Check if 'labels' contains the pattern
hp = df[df['labels'].str.contains(pattern)]
# Reset index
hp = hp.reset_index(drop=True)
hp
# Out:
# /tmp/ipykernel_12097/1172060366.py:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   hp = df[df['labels'].str.contains(pattern)]
#                id         type           created_at            repo  \
# 0    1.142354e+10  IssuesEvent  2020-02-03 16:04:59  rust-lang/rust
# 1    7.237073e+09  IssuesEvent  2018-02-13 09:46:10  rust-lang/rust
# 2    1.114081e+10  IssuesEvent  2019-12-21 17:17:43  rust-lang/rust
# 3    1.114085e+10  IssuesEvent  2019-12-21 17:35:10  rust-lang/rust
# 4    5.088671e+09  IssuesEvent  2017-01-01 00:27:23  rust-lang/rust
# ..            ...          ...                  ...             ...
# 855  4.099828e+09  IssuesEvent  2016-06-03 14:08:15  rust-lang/rust
# 856  5.116484e+09  IssuesEvent  2017-01-07 04:02:29  rust-lang/rust
# 857  5.116617e+09  IssuesEvent  2017-01-07 05:59:21  rust-lang/rust
# 858  7.802006e+09  IssuesEvent  2018-06-10 06:40:12  rust-lang/rust
# 859  8.862836e+09  IssuesEvent  2019-01-10 07:44:48  rust-lang/rust
#
#                                         repo_url  action  \
# 0    https://api.github.com/repos/rust-lang/rust  closed
# 1    https://api.github.com/repos/rust-lang/rust  closed
# 2    https://api.github.com/repos/rust-lang/rust  closed
# 3    https://api.github.com/repos/rust-lang/rust  closed
# 4    https://api.github.com/repos/rust-lang/rust  closed
# ..                                           ...     ...
# 855  https://api.github.com/repos/rust-lang/rust  closed
# 856  https://api.github.com/repos/rust-lang/rust  closed
# 857  https://api.github.com/repos/rust-lang/rust  closed
# 858  https://api.github.com/repos/rust-lang/rust  closed
# 859  https://api.github.com/repos/rust-lang/rust  opened
#
#                                                  title  \
# 0    ICE: 'rustc' panicked at 'Box<Any>', src/libru...
# 1    Incremental Compilation needs to rebuild every...
# 2           matches macro conflicts with matches crate
# 3           ICE when using slice patterns in const fn.
# 4    vendored dependendencies are incomplete in the...
# ..                                                 ...
# 855  Glibc lock elision allows a value to be locked...
# 856  ICE; two sources of truth on how stuff is retu...
# 857          rustbuild builds docs for too many crates
# 858  trivial_bounds doesn't see associated type as ...
# 859                   Can't install nightly-2019-01-10
#
#                                                 labels  \
# 0    A-incr-comp C-bug E-needs-mcve I-ICE P-high T-...
# 1                  A-incr-comp C-bug P-high T-compiler
# 2    A-macros A-resolve I-nominated P-high T-libs r...
# 3    A-const-eval A-slice-patterns C-bug F-slice_pa...
# 4    I-nominated P-high regression-from-stable-to-b...
# ..                                                 ...
# 855                    A-linux I-unsound P-high T-libs
# 856  I-ICE P-high regression-from-stable-to-stable ...
# 857  A-rustbuild P-high regression-from-stable-to-b...
# 858  P-high T-compiler regression-from-stable-to-ni...
# 859                               C-bug P-high T-infra
#
#                                                   body
# 0    This may have a duplicate, since there are sim...
# 1    Given this example:\r\n\r\nmain.rs\r\n```rust\...
# 2    cc https://github.com/rust-lang/rust/issues/65...
# 3    The following code ICEs\r\n\r\n```rust\r\n#![f...
# 4    The process of creating the tarballs doesn't i...
# ..                                                 ...
# 855  When running on a processor which support Inte...
# 856  Consider this code:\r\n\r\n```rust\r\n#![featu...
# 857  The Makefiles only build the docs for:\r\n\r\n...
# 858  Regression in rustc 1.27.0-nightly (2f2a11dfc ...
# 859  Installing rust nightly with rustup returns th...
#
# [860 rows x 9 columns]

# %%
# Remove pattern from df
random = df[~df['labels'].str.contains(pattern)]
random = random.reset_index(drop=True)
random
# Out:
# /tmp/ipykernel_12097/2462673340.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   random = df[~df['labels'].str.contains(pattern)]
#                  id         type           created_at            repo  \
# 0      1.141793e+10  IssuesEvent  2020-02-03 02:13:37  rust-lang/rust
# 1      1.141819e+10  IssuesEvent  2020-02-03 03:28:10  rust-lang/rust
# 2      1.141898e+10  IssuesEvent  2020-02-03 06:38:37  rust-lang/rust
# 3      1.142033e+10  IssuesEvent  2020-02-03 09:54:09  rust-lang/rust
# 4      1.142279e+10  IssuesEvent  2020-02-03 14:49:22  rust-lang/rust
# ...             ...          ...                  ...             ...
# 24327  2.060418e+10  IssuesEvent  2022-03-06 18:28:40  rust-lang/rust
# 24328  2.060495e+10  IssuesEvent  2022-03-06 20:51:18  rust-lang/rust
# 24329  2.060524e+10  IssuesEvent  2022-03-06 21:46:17  rust-lang/rust
# 24330  2.060527e+10  IssuesEvent  2022-03-06 21:52:30  rust-lang/rust
# 24331  7.334739e+09  IssuesEvent  2018-03-06 00:10:18  rust-lang/rust
#
#                                           repo_url    action  \
# 0      https://api.github.com/repos/rust-lang/rust    opened
# 1      https://api.github.com/repos/rust-lang/rust    closed
# 2      https://api.github.com/repos/rust-lang/rust    closed
# 3      https://api.github.com/repos/rust-lang/rust    closed
# 4      https://api.github.com/repos/rust-lang/rust    closed
# ...                                            ...       ...
# 24327  https://api.github.com/repos/rust-lang/rust    opened
# 24328  https://api.github.com/repos/rust-lang/rust    closed
# 24329  https://api.github.com/repos/rust-lang/rust    opened
# 24330  https://api.github.com/repos/rust-lang/rust    closed
# 24331  https://api.github.com/repos/rust-lang/rust  reopened
#
#                                                    title  \
# 0      ICE due to `#[track_caller]` shim with -Z unle...
# 1      assertion failed: bpos.to_u32() >= mbc.pos.to_...
# 2           ice on glacier 26459.rs with -Zsave-analysis
# 3         Compiler performance returning nested closures
# 4      ICE due to `#[track_caller]` shim with -Z unle...
# ...                                                  ...
# 24327                                ICE with generics.i
# 24328  discrepancy between debug and release: panic a...
# 24329             ICE: rustdoc GATs unwrap `None` #94009
# 24330  Compiler crash during doc test with generic_co...
# 24331        Editing proc-macro crate = undefined symbol
#
#                                                   labels  \
# 0      A-codegen A-const-eval A-const-fn F-track_call...
# 1            A-parser C-bug I-ICE I-nominated T-compiler
# 2                 A-save-analysis C-bug I-ICE T-compiler
# 3      A-borrow-checker A-closures I-compiletime T-co...
# 4      A-codegen A-const-eval A-const-fn C-bug F-trac...
# ...                                                  ...
# 24327                             I-ICE T-compiler C-bug
# 24328                                              C-bug
# 24329                             I-ICE T-compiler C-bug
# 24330                             I-ICE T-compiler C-bug
# 24331                                 A-macros-2.0 C-bug
#
#                                                     body
# 0      Reproducer:\r\n\r\n```rust\r\n// compile-flags...
# 1      I'm seeing an internal compiler error on the f...
# 2      ````rust\r\nfn main() {\r\n    match 'a' {\r\n...
# 3      The following takes approximately one year to ...
# 4      Reproducer:\r\n\r\n```rust\r\n// compile-flags...
# ...                                                  ...
# 24327  \r\n\r\n### Code\r\n\r\nhttps://play.rust-lang...
# 24328  <!--\r\nThank you for filing a bug report! 🐛 P...
# 24329  <!--\r\nThank you for finding an Internal Comp...
# 24330  Trying to use `generic_const_exprs` (#76560) t...
# 24331  Note: This is with incremental-comp turned off...
#
# [24332 rows x 9 columns]

# %%
random.labels.value_counts().to_frame()[:50]
# Out:
#                                            count
# labels
# C-bug                                       3476
# I-ICE T-compiler C-bug                      1560
# A-diagnostics T-compiler                    1156
# C-bug I-ICE T-compiler                       784
# A-docs                                       480
# I-ICE                                        412
# A-diagnostics                                328
# A-rustdoc                                    195
# C-bug regression-untriaged                   174
# T-rustdoc                                    168
# A-libs                                       166
# T-libs-api C-tracking-issue                  133
# C-tracking-issue                             129
# I-nominated T-compiler                       100
# A-rustbuild                                   95
# C-bug A-miri                                  89
# A-lint                                        85
# A-miri C-bug                                  83
# C-bug T-rustdoc                               82
# A-build                                       79
# I-ICE T-compiler C-bug glacier                79
# T-libs                                        78
# A-typesystem                                  73
# A-diagnostics C-enhancement                   72
# T-rustdoc A-rustdoc-ui                        71
# C-feature-request T-libs                      70
# regression-from-stable-to-beta                67
# A-diagnostics C-enhancement T-compiler        66
# I-ICE T-compiler A-incr-comp C-bug            66
# C-tracking-issue T-libs                       65
# A-rustbuild C-bug                             64
# A-macros                                      62
# B-unstable final-comment-period T-libs        59
# T-compiler                                    55
# T-doc                                         51
# regression-from-stable-to-nightly             51
# C-bug I-ICE                                   50
# T-compiler regression-from-stable-to-beta     50
# E-needstest I-ICE                             50
# A-book A-docs                                 48
# A-debuginfo                                   47
# T-rustdoc C-bug                               47
# I-ICE T-compiler C-bug E-needs-mcve           46
# A-diagnostics C-bug                           39
# A-diagnostics C-bug T-compiler                37
# A-infrastructure                              36
# B-unstable C-tracking-issue T-libs            34
# A-associated-items                            33
# C-enhancement T-libs                          33
# A-intra-doc-links C-bug T-rustdoc             32

# %%
# Number or different labels
hp.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# P-high T-compiler                                      14
# P-high T-compiler regression-from-stable-to-beta       13
# P-high                                                 10
# P-high regression-from-stable-to-beta T-compiler        9
# I-ICE P-high regression-from-stable-to-nightly ...      6
# C-bug I-ICE P-high T-compiler regression-from-s...      6
# P-high T-compiler regression-from-stable-to-stable      6
# C-bug P-high T-compiler regression-from-stable-...      6
# regression-from-stable-to-nightly P-high T-comp...      6
# C-bug I-ICE P-high T-compiler regression-from-s...      6
# A-rustdoc P-high                                        5
# C-bug I-ICE P-high T-compiler regression-from-s...      5
# P-high T-compiler regression-from-stable-to-sta...      5
# P-high regression-from-stable-to-nightly T-comp...      5
# C-bug I-ICE P-high T-compiler                           5
# P-high T-compiler regression-from-stable-to-nig...      5
# A-docs P-high                                           4
# C-bug I-ICE P-high regression-from-stable-to-be...      4
# A-incr-comp C-bug E-needs-mcve I-ICE P-high T-c...      4
# I-ICE P-high regression-from-stable-to-beta T-c...      4
# A-infrastructure P-high                                 4
# T-compiler regression-from-stable-to-stable C-b...      3
# C-bug P-high T-infra                                    3
# A-diagnostics P-high T-compiler regression-from...      3
# regression-from-stable-to-beta C-bug P-critical         3
# C-bug P-high regression-from-stable-to-beta T-c...      3
# I-crash P-high regression-from-stable-to-beta T...      3
# A-libs P-high                                           3
# A-incr-comp C-bug E-needstest I-ICE P-high T-co...      3
# I-ICE regression-from-stable-to-nightly T-compi...      3
# T-compiler C-bug P-critical A-mir-opt-inlining ...      3
# P-high regression-from-stable-to-stable C-bug           3
# A-LLVM A-codegen C-bug I-unsound 💥 P-critical T...      3
# A-dst C-bug I-ICE P-high T-compiler glacier reg...      3
# A-const-eval I-ICE P-high T-compiler regression...      3
# I-ICE P-high regression-from-stable-to-stable T...      3
# T-lang T-compiler regression-from-stable-to-sta...      3
# A-diagnostics C-bug P-high T-compiler regressio...      3
# regression-from-stable-to-nightly T-compiler C-...      3
# A-LLVM T-compiler regression-from-stable-to-sta...      3
# E-needstest P-high T-compiler regression-from-s...      3
# I-wrong P-high                                          2
# P-high regression-from-stable-to-nightly T-tools        2
# I-compiletime P-high T-compiler regression-from...      2
# A-const-fn A-raw-pointers A-stability C-bug P-high      2
# P-high T-compiler T-lang                                2
# A-ffi C-bug I-unsound 💥 O-windows O-windows-msv...      2
# I-ICE regression-from-stable-to-nightly T-compi...      2
# A-codegen A-traits C-bug E-needs-mcve I-ICE P-h...      2
# T-compiler regression-from-stable-to-beta P-cri...      2

# %%
#Give each priority a label by number.
# 'Label encoding'. Makes is easier for machine learning models to work with categorical data.
hp["label"] = 1
hp["class"] = "high_priority"
hp.head()
# Out:
#              id         type           created_at            repo  \
# 0  1.142354e+10  IssuesEvent  2020-02-03 16:04:59  rust-lang/rust
# 1  7.237073e+09  IssuesEvent  2018-02-13 09:46:10  rust-lang/rust
# 2  1.114081e+10  IssuesEvent  2019-12-21 17:17:43  rust-lang/rust
# 3  1.114085e+10  IssuesEvent  2019-12-21 17:35:10  rust-lang/rust
# 4  5.088671e+09  IssuesEvent  2017-01-01 00:27:23  rust-lang/rust
#
#                                       repo_url  action  \
# 0  https://api.github.com/repos/rust-lang/rust  closed
# 1  https://api.github.com/repos/rust-lang/rust  closed
# 2  https://api.github.com/repos/rust-lang/rust  closed
# 3  https://api.github.com/repos/rust-lang/rust  closed
# 4  https://api.github.com/repos/rust-lang/rust  closed
#
#                                                title  \
# 0  ICE: 'rustc' panicked at 'Box<Any>', src/libru...
# 1  Incremental Compilation needs to rebuild every...
# 2         matches macro conflicts with matches crate
# 3         ICE when using slice patterns in const fn.
# 4  vendored dependendencies are incomplete in the...
#
#                                               labels  \
# 0  A-incr-comp C-bug E-needs-mcve I-ICE P-high T-...
# 1                A-incr-comp C-bug P-high T-compiler
# 2  A-macros A-resolve I-nominated P-high T-libs r...
# 3  A-const-eval A-slice-patterns C-bug F-slice_pa...
# 4  I-nominated P-high regression-from-stable-to-b...
#
#                                                 body  label          class
# 0  This may have a duplicate, since there are sim...      1  high_priority
# 1  Given this example:\r\n\r\nmain.rs\r\n```rust\...      1  high_priority
# 2  cc https://github.com/rust-lang/rust/issues/65...      1  high_priority
# 3  The following code ICEs\r\n\r\n```rust\r\n#![f...      1  high_priority
# 4  The process of creating the tarballs doesn't i...      1  high_priority

# %%
random["label"] = 0
random["class"] = "not_high_priority" 
random.head()
# Out:
#              id         type           created_at            repo  \
# 0  1.141793e+10  IssuesEvent  2020-02-03 02:13:37  rust-lang/rust
# 1  1.141819e+10  IssuesEvent  2020-02-03 03:28:10  rust-lang/rust
# 2  1.141898e+10  IssuesEvent  2020-02-03 06:38:37  rust-lang/rust
# 3  1.142033e+10  IssuesEvent  2020-02-03 09:54:09  rust-lang/rust
# 4  1.142279e+10  IssuesEvent  2020-02-03 14:49:22  rust-lang/rust
#
#                                       repo_url  action  \
# 0  https://api.github.com/repos/rust-lang/rust  opened
# 1  https://api.github.com/repos/rust-lang/rust  closed
# 2  https://api.github.com/repos/rust-lang/rust  closed
# 3  https://api.github.com/repos/rust-lang/rust  closed
# 4  https://api.github.com/repos/rust-lang/rust  closed
#
#                                                title  \
# 0  ICE due to `#[track_caller]` shim with -Z unle...
# 1  assertion failed: bpos.to_u32() >= mbc.pos.to_...
# 2       ice on glacier 26459.rs with -Zsave-analysis
# 3     Compiler performance returning nested closures
# 4  ICE due to `#[track_caller]` shim with -Z unle...
#
#                                               labels  \
# 0  A-codegen A-const-eval A-const-fn F-track_call...
# 1        A-parser C-bug I-ICE I-nominated T-compiler
# 2             A-save-analysis C-bug I-ICE T-compiler
# 3  A-borrow-checker A-closures I-compiletime T-co...
# 4  A-codegen A-const-eval A-const-fn C-bug F-trac...
#
#                                                 body  label              class
# 0  Reproducer:\r\n\r\n```rust\r\n// compile-flags...      0  not_high_priority
# 1  I'm seeing an internal compiler error on the f...      0  not_high_priority
# 2  ````rust\r\nfn main() {\r\n    match 'a' {\r\n...      0  not_high_priority
# 3  The following takes approximately one year to ...      0  not_high_priority
# 4  Reproducer:\r\n\r\n```rust\r\n// compile-flags...      0  not_high_priority

# %%
# Drop duplicates by the content of the title
high_priority = hp.drop_duplicates(subset=['title'], keep='last')
high_priority.dropna(inplace=True)
high_priority.reset_index(inplace=True)
high_priority.drop(columns=["index"] , inplace= True)
high_priority["class"].value_counts()
# Out:
# /tmp/ipykernel_12097/1823776403.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_priority.dropna(inplace=True)
# /tmp/ipykernel_12097/1823776403.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_priority.drop(columns=["index"] , inplace= True)
# class
# high_priority    788
# Name: count, dtype: int64

# %%
# Drop duplicates by the content of the title
not_high_priority = random.drop_duplicates(subset=['title'], keep='last')
not_high_priority.dropna(inplace=True)
not_high_priority.reset_index(inplace=True)
not_high_priority.drop(columns=["index"] , inplace= True)
not_high_priority["class"].value_counts()
# Out:
# /tmp/ipykernel_12097/3923262596.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority.dropna(inplace=True)
# /tmp/ipykernel_12097/3923262596.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority.drop(columns=["index"] , inplace= True)
# class
# not_high_priority    19865
# Name: count, dtype: int64

# %%
high_priority.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 788 entries, 0 to 787
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          788 non-null    float64
#  1   type        788 non-null    object
#  2   created_at  788 non-null    object
#  3   repo        788 non-null    object
#  4   repo_url    788 non-null    object
#  5   action      788 non-null    object
#  6   title       788 non-null    object
#  7   labels      788 non-null    object
#  8   body        788 non-null    object
#  9   label       788 non-null    int64
#  10  class       788 non-null    object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 67.8+ KB

# %%
label_counts = high_priority["class"].value_counts()
label_counts_nhp = not_high_priority["class"].value_counts()
print(label_counts)
not_high_priority_count = label_counts_nhp["not_high_priority"]
print(not_high_priority_count)
hp_count = label_counts["high_priority"]
hp_count
# Out:
# class
# high_priority    788
# Name: count, dtype: int64
# 19865
# 788

# %%
not_high_priority = not_high_priority.sample(frac=hp_count/not_high_priority_count, random_state=42)
not_high_priority
# Out:
#                  id         type           created_at            repo  \
# 8387   2.025647e+10  IssuesEvent  2022-02-15 00:03:59  rust-lang/rust
# 4564   2.625521e+10  IssuesEvent  2023-01-05 23:39:34  rust-lang/rust
# 19348  1.357796e+10  IssuesEvent  2020-09-20 04:46:50  rust-lang/rust
# 13702  6.997215e+09  IssuesEvent  2017-12-16 11:54:18  rust-lang/rust
# 9419   2.491293e+10  IssuesEvent  2022-10-30 03:32:39  rust-lang/rust
# ...             ...          ...                  ...             ...
# 15458  3.070998e+10  IssuesEvent  2023-07-27 09:06:05  rust-lang/rust
# 17656  7.327034e+09  IssuesEvent  2018-03-04 04:15:21  rust-lang/rust
# 6153   1.247528e+10  IssuesEvent  2020-05-29 11:16:43  rust-lang/rust
# 3633   7.748851e+09  IssuesEvent  2018-05-30 09:33:59  rust-lang/rust
# 10722  1.222668e+10  IssuesEvent  2020-05-03 12:05:44  rust-lang/rust
#
#                                           repo_url  action  \
# 8387   https://api.github.com/repos/rust-lang/rust  opened
# 4564   https://api.github.com/repos/rust-lang/rust  opened
# 19348  https://api.github.com/repos/rust-lang/rust  opened
# 13702  https://api.github.com/repos/rust-lang/rust  closed
# 9419   https://api.github.com/repos/rust-lang/rust  opened
# ...                                            ...     ...
# 15458  https://api.github.com/repos/rust-lang/rust  opened
# 17656  https://api.github.com/repos/rust-lang/rust  closed
# 6153   https://api.github.com/repos/rust-lang/rust  closed
# 3633   https://api.github.com/repos/rust-lang/rust  opened
# 10722  https://api.github.com/repos/rust-lang/rust  closed
#
#                                                    title  \
# 8387   bootstrap: RUSTFLAGS_*_BOOTSTRAP does not affe...
# 4564   Unexpected "expected function" error with unit...
# 19348  The default overflow behavior of u128 arithmet...
# 13702  Assertion failed in rustc : !(self.has_self &&...
# 9419   ICE: assertion failed: elem.index() < self.dom...
# ...                                                  ...
# 15458  Suggest `by_ref` when taking a reference to an...
# 17656  Type inference regression affecting app_dirs o...
# 6153                           Impl Error for Infallible
# 3633   resolve suggestions do not use `crate::` when ...
# 10722  ICE: rmeta/decoder.rs:1130: impossible case re...
#
#                                                   labels  \
# 8387                                               C-bug
# 4564                                               C-bug
# 19348                                              C-bug
# 13702                              A-resolve C-bug I-ICE
# 9419                              I-ICE T-compiler C-bug
# ...                                                  ...
# 15458                           A-diagnostics T-compiler
# 17656  I-nominated T-libs regression-from-stable-to-beta
# 6153               A-error-handling C-enhancement T-libs
# 3633   A-diagnostics A-rust-2018-preview T-compiler W...
# 10722     A-metadata C-bug E-needs-mcve I-ICE T-compiler
#
#                                                     body  label  \
# 8387   It's unclear if this _should_ be a bug report ...      0
# 4564   <!--\r\nThank you for filing a bug report! 🐛 P...      0
# 19348  <!--\r\nThank you for filing a bug report! 🐛 P...      0
# 13702  When using `cargo build` to build one of my pr...      0
# 9419   ### Code\r\n\r\n```Rust\r\nstruct Apple((Apple...      0
# ...                                                  ...    ...
# 15458  ### Code\n\n```Rust\nfn main() {\r\n    let mu...      0
# 17656  As seen in [this Travis build](https://travis-...      0
# 6153   Is there a reason why `std::convert::Infallibl...      0
# 3633   When you get name resolution suggestions from ...      0
# 10722  <!--\r\nThank you for finding an Internal Comp...      0
#
#                    class
# 8387   not_high_priority
# 4564   not_high_priority
# 19348  not_high_priority
# 13702  not_high_priority
# 9419   not_high_priority
# ...                  ...
# 15458  not_high_priority
# 17656  not_high_priority
# 6153   not_high_priority
# 3633   not_high_priority
# 10722  not_high_priority
#
# [788 rows x 11 columns]

# %%
all_priority = pd.concat([high_priority,not_high_priority] , ignore_index = True)
all_priority.tail()
# Out:
#                 id         type           created_at            repo  \
# 1571  3.070998e+10  IssuesEvent  2023-07-27 09:06:05  rust-lang/rust
# 1572  7.327034e+09  IssuesEvent  2018-03-04 04:15:21  rust-lang/rust
# 1573  1.247528e+10  IssuesEvent  2020-05-29 11:16:43  rust-lang/rust
# 1574  7.748851e+09  IssuesEvent  2018-05-30 09:33:59  rust-lang/rust
# 1575  1.222668e+10  IssuesEvent  2020-05-03 12:05:44  rust-lang/rust
#
#                                          repo_url  action  \
# 1571  https://api.github.com/repos/rust-lang/rust  opened
# 1572  https://api.github.com/repos/rust-lang/rust  closed
# 1573  https://api.github.com/repos/rust-lang/rust  closed
# 1574  https://api.github.com/repos/rust-lang/rust  opened
# 1575  https://api.github.com/repos/rust-lang/rust  closed
#
#                                                   title  \
# 1571  Suggest `by_ref` when taking a reference to an...
# 1572  Type inference regression affecting app_dirs o...
# 1573                          Impl Error for Infallible
# 1574  resolve suggestions do not use `crate::` when ...
# 1575  ICE: rmeta/decoder.rs:1130: impossible case re...
#
#                                                  labels  \
# 1571                           A-diagnostics T-compiler
# 1572  I-nominated T-libs regression-from-stable-to-beta
# 1573              A-error-handling C-enhancement T-libs
# 1574  A-diagnostics A-rust-2018-preview T-compiler W...
# 1575     A-metadata C-bug E-needs-mcve I-ICE T-compiler
#
#                                                    body  label  \
# 1571  ### Code\n\n```Rust\nfn main() {\r\n    let mu...      0
# 1572  As seen in [this Travis build](https://travis-...      0
# 1573  Is there a reason why `std::convert::Infallibl...      0
# 1574  When you get name resolution suggestions from ...      0
# 1575  <!--\r\nThank you for finding an Internal Comp...      0
#
#                   class
# 1571  not_high_priority
# 1572  not_high_priority
# 1573  not_high_priority
# 1574  not_high_priority
# 1575  not_high_priority

# %%
# 
all_priority["label"].value_counts()
# Out:
# label
# 1    788
# 0    788
# Name: count, dtype: int64

# %%
print(all_priority["title"][0])
print(all_priority["body"][0])
# Out:
# ICE: 'rustc' panicked at 'Box<Any>', src/librustc_errors/lib.rs:931:9
# This may have a duplicate, since there are similar panics already reported, but this is on a different line number.
#
# The compilation log and source code are listed below
#
# ```rust
# pub mod client;
# pub mod msg;
#
# use std::collections::HashMap;
# use std::sync::Arc;
# use tokio::sync::broadcast::{channel, Receiver, Sender};
#
# /**
#  * A channel is named and typed with the type of messages it should be carrying
#  */
# struct Channel {
#     name: String,
#     send: Sender<Message>,
#     recv: Receiver<Message>,
# }
#
# struct Message {}
#
# impl Channel {
#     fn send(&self, msg: Message) {}
#     fn recv(&self, msg: Message) {}
# }
#
# struct Bus {
#     /**
#      * Channels are named and can implement a number of different types. This should
#      * allow the Bus to handle different channels with different message payloads
#      * while still taking advantage of compile-time checks
#      */
#     channels: HashMap<String, Channel>,
# }
#
# #[cfg(test)]
# mod tests {
#     use super::*;
# }
# ```
#
# [compile.log](https://github.com/rust-lang/rust/files/4083271/compile.log)

# %%
# Copy content of body to a new col named text
all_priority["text"] = all_priority["title"] + " " + all_priority["body"]
all_priority.tail()
# Out:
#                 id         type           created_at            repo  \
# 1571  3.070998e+10  IssuesEvent  2023-07-27 09:06:05  rust-lang/rust
# 1572  7.327034e+09  IssuesEvent  2018-03-04 04:15:21  rust-lang/rust
# 1573  1.247528e+10  IssuesEvent  2020-05-29 11:16:43  rust-lang/rust
# 1574  7.748851e+09  IssuesEvent  2018-05-30 09:33:59  rust-lang/rust
# 1575  1.222668e+10  IssuesEvent  2020-05-03 12:05:44  rust-lang/rust
#
#                                          repo_url  action  \
# 1571  https://api.github.com/repos/rust-lang/rust  opened
# 1572  https://api.github.com/repos/rust-lang/rust  closed
# 1573  https://api.github.com/repos/rust-lang/rust  closed
# 1574  https://api.github.com/repos/rust-lang/rust  opened
# 1575  https://api.github.com/repos/rust-lang/rust  closed
#
#                                                   title  \
# 1571  Suggest `by_ref` when taking a reference to an...
# 1572  Type inference regression affecting app_dirs o...
# 1573                          Impl Error for Infallible
# 1574  resolve suggestions do not use `crate::` when ...
# 1575  ICE: rmeta/decoder.rs:1130: impossible case re...
#
#                                                  labels  \
# 1571                           A-diagnostics T-compiler
# 1572  I-nominated T-libs regression-from-stable-to-beta
# 1573              A-error-handling C-enhancement T-libs
# 1574  A-diagnostics A-rust-2018-preview T-compiler W...
# 1575     A-metadata C-bug E-needs-mcve I-ICE T-compiler
#
#                                                    body  label  \
# 1571  ### Code\n\n```Rust\nfn main() {\r\n    let mu...      0
# 1572  As seen in [this Travis build](https://travis-...      0
# 1573  Is there a reason why `std::convert::Infallibl...      0
# 1574  When you get name resolution suggestions from ...      0
# 1575  <!--\r\nThank you for finding an Internal Comp...      0
#
#                   class                                               text
# 1571  not_high_priority  Suggest `by_ref` when taking a reference to an...
# 1572  not_high_priority  Type inference regression affecting app_dirs o...
# 1573  not_high_priority  Impl Error for Infallible Is there a reason wh...
# 1574  not_high_priority  resolve suggestions do not use `crate::` when ...
# 1575  not_high_priority  ICE: rmeta/decoder.rs:1130: impossible case re...

# %%
all_priority["text"][0]
# Out:
# "ICE: 'rustc' panicked at 'Box<Any>', src/librustc_errors/lib.rs:931:9 This may have a duplicate, since there are similar panics already reported, but this is on a different line number.\r\n\r\nThe compilation log and source code are listed below\r\n\r\n```rust\r\npub mod client;\r\npub mod msg;\r\n\r\nuse std::collections::HashMap;\r\nuse std::sync::Arc;\r\nuse tokio::sync::broadcast::{channel, Receiver, Sender};\r\n\r\n/**\r\n * A channel is named and typed with the type of messages it should be carrying\r\n */\r\nstruct Channel {\r\n    name: String,\r\n    send: Sender<Message>,\r\n    recv: Receiver<Message>,\r\n}\r\n\r\nstruct Message {}\r\n\r\nimpl Channel {\r\n    fn send(&self, msg: Message) {}\r\n    fn recv(&self, msg: Message) {}\r\n}\r\n\r\nstruct Bus {\r\n    /**\r\n     * Channels are named and can implement a number of different types. This should\r\n     * allow the Bus to handle different channels with different message payloads\r\n     * while still taking advantage of compile-time checks\r\n     */\r\n    channels: HashMap<String, Channel>,\r\n}\r\n\r\n#[cfg(test)]\r\nmod tests {\r\n    use super::*;\r\n}\r\n```\r\n\r\n[compile.log](https://github.com/rust-lang/rust/files/4083271/compile.log)\r\n"

# %%
# Make a new dataframe with only text, label and class cols.
all_priority_subset = all_priority[["text" , "label" , "class"]]
all_priority_subset
# Out:
#                                                    text  label  \
# 0     ICE: 'rustc' panicked at 'Box<Any>', src/libru...      1
# 1     Incremental Compilation needs to rebuild every...      1
# 2     matches macro conflicts with matches crate cc ...      1
# 3     ICE when using slice patterns in const fn. The...      1
# 4     vendored dependendencies are incomplete in the...      1
# ...                                                 ...    ...
# 1571  Suggest `by_ref` when taking a reference to an...      0
# 1572  Type inference regression affecting app_dirs o...      0
# 1573  Impl Error for Infallible Is there a reason wh...      0
# 1574  resolve suggestions do not use `crate::` when ...      0
# 1575  ICE: rmeta/decoder.rs:1130: impossible case re...      0
#
#                   class
# 0         high_priority
# 1         high_priority
# 2         high_priority
# 3         high_priority
# 4         high_priority
# ...                 ...
# 1571  not_high_priority
# 1572  not_high_priority
# 1573  not_high_priority
# 1574  not_high_priority
# 1575  not_high_priority
#
# [1576 rows x 3 columns]

# %%
# Convert to string
all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)
# Out:
# /tmp/ipykernel_12097/3106036705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)

# %%
all_priority_subset
# Out:
#                                                    text  label  \
# 0     ICE: 'rustc' panicked at 'Box<Any>', src/libru...      1
# 1     Incremental Compilation needs to rebuild every...      1
# 2     matches macro conflicts with matches crate cc ...      1
# 3     ICE when using slice patterns in const fn. The...      1
# 4     vendored dependendencies are incomplete in the...      1
# ...                                                 ...    ...
# 1571  Suggest `by_ref` when taking a reference to an...      0
# 1572  Type inference regression affecting app_dirs o...      0
# 1573  Impl Error for Infallible Is there a reason wh...      0
# 1574  resolve suggestions do not use `crate::` when ...      0
# 1575  ICE: rmeta/decoder.rs:1130: impossible case re...      0
#
#                   class                                           text_str
# 0         high_priority  ICE: 'rustc' panicked at 'Box<Any>', src/libru...
# 1         high_priority  Incremental Compilation needs to rebuild every...
# 2         high_priority  matches macro conflicts with matches crate cc ...
# 3         high_priority  ICE when using slice patterns in const fn. The...
# 4         high_priority  vendored dependendencies are incomplete in the...
# ...                 ...                                                ...
# 1571  not_high_priority  Suggest `by_ref` when taking a reference to an...
# 1572  not_high_priority  Type inference regression affecting app_dirs o...
# 1573  not_high_priority  Impl Error for Infallible Is there a reason wh...
# 1574  not_high_priority  resolve suggestions do not use `crate::` when ...
# 1575  not_high_priority  ICE: rmeta/decoder.rs:1130: impossible case re...
#
# [1576 rows x 4 columns]

# %%
# Clean the data.
all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_12097/63294665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)

# %%
# Make a subset with text_clean and label
priority_label_text = all_priority_subset[["text_clean" , "label"]]
priority_label_text
# Out:
#                                              text_clean  label
# 0     ice rustc panicked at box this may have a dupl...      1
# 1     incremental compilation needs to rebuild every...      1
# 2     matches macro conflicts with matches crate cc ...      1
# 3     ice when using slice patterns in const fn the ...      1
# 4     vendored dependendencies are incomplete in the...      1
# ...                                                 ...    ...
# 1571  suggest byref when taking a reference to an it...      0
# 1572  type inference regression affecting appdirs on...      0
# 1573  impl error for infallible is there a reason wh...      0
# 1574  resolve suggestions do not use crate when enab...      0
# 1575  ice impossible case reached thank you for find...      0
#
# [1576 rows x 2 columns]

# %%
# Need to dropna here since cleaning function returns NaN for not english text.
priority_label_text.dropna(inplace=True)
priority_label_text.reset_index(inplace=True)
priority_label_text.drop(columns=["index"] , inplace= True)

priority_label_text
# Out:
# /tmp/ipykernel_12097/239147930.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.dropna(inplace=True)
# /tmp/ipykernel_12097/239147930.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.drop(columns=["index"] , inplace= True)
#                                              text_clean  label
# 0     ice rustc panicked at box this may have a dupl...      1
# 1     incremental compilation needs to rebuild every...      1
# 2     matches macro conflicts with matches crate cc ...      1
# 3     ice when using slice patterns in const fn the ...      1
# 4     vendored dependendencies are incomplete in the...      1
# ...                                                 ...    ...
# 1568  suggest byref when taking a reference to an it...      0
# 1569  type inference regression affecting appdirs on...      0
# 1570  impl error for infallible is there a reason wh...      0
# 1571  resolve suggestions do not use crate when enab...      0
# 1572  ice impossible case reached thank you for find...      0
#
# [1573 rows x 2 columns]

# %%
from sklearn.utils import resample

# Split the dataset into two based on the label
df_majority = priority_label_text[priority_label_text['label'] == 0]
df_minority = priority_label_text[priority_label_text['label'] == 1]

# Undersample the majority class
df_majority_undersampled = resample(df_majority, 
                                     replace=False,    # sample without replacement
                                     n_samples=len(df_minority),     # to match minority class
                                     random_state=123) # reproducible results

# Combine minority class with downsampled majority class
df_balanced = pd.concat([df_majority_undersampled, df_minority])

# Shuffle the dataset to avoid any ordering bias
df_balanced = df_balanced.sample(frac=1).reset_index(drop=True)
priority_label_text = df_balanced
priority_label_text["label"].value_counts()
# Out:
# label
# 0    786
# 1    786
# Name: count, dtype: int64

# %%
# Clean dataset with clean text and labels.
# 0 = high priority, 1 = not high priority
file_name = f"csv/clean_rust_testset.csv"
priority_label_text.to_csv(file_name, index=False)

# %%
pri = pd.read_csv(file_name)
pri
# Out:
#                                              text_clean  label
# 0     verify that backported commits are backports t...      0
# 1     two different versions of a crate interacting ...      0
# 2     ice when using impl trait with an infinity rec...      1
# 3     compiler error while compiling winrt trying to...      1
# 4     rust segmentation fault related to const gener...      1
# ...                                                 ...    ...
# 1567            tracking issue for stdfs extensions rfc      1
# 1568  assertion failed error on trying to bench with...      1
# 1569  ice caused by llvm assertion assertion sgettyp...      0
# 1570  add a build container for the target was recen...      0
# 1571  regression matching on function pointers fails...      1
#
# [1572 rows x 2 columns]
