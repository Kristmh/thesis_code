# %% [markdown]
# # Data cleaning
# We want the class with labels as numerical value and the body with clean text.
#
# This will remove:
# * duplicates
# * NaN entires
# * non english
# * url, html
#
# * make it lowercase
# * combine title and body

# %%
import pandas as pd
import sys
sys.path.append("../../../scripts_shared/")
from preprocess_text import preprocess_text

# %%
# Read CSV into a dataframe
filename = "csv/flutter_testset.csv"
df = pd.read_csv(filename)
df
# Out:
#                  id         type           created_at             repo  \
# 0      1.141754e+10  IssuesEvent  2020-02-03 00:02:35  flutter/flutter
# 1      1.141766e+10  IssuesEvent  2020-02-03 00:48:37  flutter/flutter
# 2      1.141771e+10  IssuesEvent  2020-02-03 01:04:00  flutter/flutter
# 3      1.141780e+10  IssuesEvent  2020-02-03 01:34:27  flutter/flutter
# 4      1.141915e+10  IssuesEvent  2020-02-03 07:10:13  flutter/flutter
# ...             ...          ...                  ...              ...
# 45012  2.060417e+10  IssuesEvent  2022-03-06 18:26:25  flutter/flutter
# 45013  2.060462e+10  IssuesEvent  2022-03-06 19:49:39  flutter/flutter
# 45014  2.060486e+10  IssuesEvent  2022-03-06 20:33:15  flutter/flutter
# 45015  7.334872e+09  IssuesEvent  2018-03-06 00:52:29  flutter/flutter
# 45016  7.334882e+09  IssuesEvent  2018-03-06 00:55:47  flutter/flutter
#
#                                            repo_url  action  \
# 0      https://api.github.com/repos/flutter/flutter  opened
# 1      https://api.github.com/repos/flutter/flutter  opened
# 2      https://api.github.com/repos/flutter/flutter  opened
# 3      https://api.github.com/repos/flutter/flutter  closed
# 4      https://api.github.com/repos/flutter/flutter  closed
# ...                                             ...     ...
# 45012  https://api.github.com/repos/flutter/flutter  closed
# 45013  https://api.github.com/repos/flutter/flutter  closed
# 45014  https://api.github.com/repos/flutter/flutter  closed
# 45015  https://api.github.com/repos/flutter/flutter  opened
# 45016  https://api.github.com/repos/flutter/flutter  opened
#
#                                                    title  \
# 0      Keyboard flashes briefly when dismissing multi...
# 1      ChocieChip's default "selected" style in dark ...
# 2      Flutter apps restart when you toggle "Invert C...
# 3                           flutter build output unclear
# 4      Ink.image keeps cache of the image somewhere else
# ...                                                  ...
# 45012                                                Yea
# 45013       [Impeller] Get rid of //impeller/third_party
# 45014             Install log handler for macOS embedder
# 45015                           a11y of fancy text field
# 45016  Textfield placeholder not announced in a11y on...
#
#                                               labels  \
# 0        a: quality a: text input f: focus framework
# 1      a: accessibility f: material design framework
# 2      dependency: android engine ▣ platform-android
# 3                                               tool
# 4                                     p: third party
# ...                                              ...
# 45012                                    team: infra
# 45013                             engine P4 impeller
# 45014    engine platform-mac a: desktop P4 tech-debt
# 45015                a11y review prod: accessibility
# 45016                a11y review prod: accessibility
#
#                                                     body
# 0      ```dart\r\nimport 'package:flutter/material.da...
# 1      ![flutter_01](https://user-images.githubuserco...
# 2      Doesn't look like `android:configChanges` lets...
# 3      Some friction using `flutter build`\r\n\r\n1- ...
# 4      I don't know why, but it seems that Ink.image ...
# ...                                                  ...
# 45012  <!--  Thank you for contributing to Flutter!\n...
# 45013  The only dependency there is is STB which is o...
# 45014  Rather than relying on the engine's fallback l...
# 45015  ![image](https://user-images.githubusercontent...
# 45016  On iOS go to the text field demo of the Flutte...
#
# [45017 rows x 9 columns]

# %%
# Number or different labels
df.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# in triage                                            6961
# waiting for customer response in triage              2248
# in triage waiting for customer response              1719
# team: infra                                          1185
# waiting for customer response                        1041
# created via support template                          607
# created via performance template                      469
# tool                                                  348
# f: material design framework                          247
# engine                                                213
# cp: review                                            178
# team: infra device-lab                                159
# r: invalid                                            155
# framework                                             149
# team: infra P0                                        125
# engine P4 impeller                                    124
# P1                                                    121
# dev: tool                                             119
# tool team: flakes P1 severe: flake                    118
# ☸ platform-web                                        118
# engine impeller                                       106
# severe: crash tool                                    105
# dev: docs - website                                   104
# engine team: flakes P1 severe: flake                  104
# d: stackoverflow                                      104
# r: duplicate                                           96
# framework f: material design                           95
# team team: infra                                       95
# severe: performance                                    93
# team: infra P3                                         92
# plugin                                                 81
# ⚠ clear documentation                                  79
# passed secondary triage team: infra                    76
# prod: framework                                        75
# team                                                   72
# infra: device lab                                      69
# f: material design framework waiting for custom...     65
# team: flakes P1 severe: flake                          63
# a: text input f: material design framework             62
# impeller                                               62
# P0 team: infra                                         61
# f: material design framework severe: new feature       60
# d: website - content                                   58
# P0                                                     57
# ⌺‬ platform-ios                                        57
# affects: tools                                         56
# P1 team: infra                                         52
# team: infra passed secondary triage                    50
# customer: gallery                                      50
# prod: accessibility                                    50

# %%
# Split data based on labels. Contains P0 and P1 in one dataframe, the rest in another

pattern = 'P(1|0)'
# Check if 'labels' contains the pattern
hp = df[df['labels'].str.contains(pattern)]
# Reset index
hp = hp.reset_index(drop=True)
hp
# Out:
# /tmp/ipykernel_340011/1635278008.py:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   hp = df[df['labels'].str.contains(pattern)]
#                 id         type           created_at             repo  \
# 0     1.362189e+10  IssuesEvent  2020-09-24 02:01:56  flutter/flutter
# 1     1.362223e+10  IssuesEvent  2020-09-24 03:00:37  flutter/flutter
# 2     1.362854e+10  IssuesEvent  2020-09-24 14:02:05  flutter/flutter
# 3     1.363092e+10  IssuesEvent  2020-09-24 17:10:38  flutter/flutter
# 4     1.363372e+10  IssuesEvent  2020-09-24 22:01:59  flutter/flutter
# ...            ...          ...                  ...              ...
# 1710  2.686740e+10  IssuesEvent  2023-02-04 02:57:55  flutter/flutter
# 1711  2.687401e+10  IssuesEvent  2023-02-04 20:29:38  flutter/flutter
# 1712  2.687437e+10  IssuesEvent  2023-02-04 21:27:31  flutter/flutter
# 1713  2.687452e+10  IssuesEvent  2023-02-04 21:51:38  flutter/flutter
# 1714  2.687511e+10  IssuesEvent  2023-02-04 23:36:05  flutter/flutter
#
#                                           repo_url    action  \
# 0     https://api.github.com/repos/flutter/flutter  reopened
# 1     https://api.github.com/repos/flutter/flutter    closed
# 2     https://api.github.com/repos/flutter/flutter    closed
# 3     https://api.github.com/repos/flutter/flutter  reopened
# 4     https://api.github.com/repos/flutter/flutter    opened
# ...                                            ...       ...
# 1710  https://api.github.com/repos/flutter/flutter    opened
# 1711  https://api.github.com/repos/flutter/flutter    opened
# 1712  https://api.github.com/repos/flutter/flutter    opened
# 1713  https://api.github.com/repos/flutter/flutter    opened
# 1714  https://api.github.com/repos/flutter/flutter    closed
#
#                                                   title  \
# 0                     I can't view build dashboard logs
# 1     worst_frame_build_time_millis \tcubic_bezier_p...
# 2     iOS 14 release Invalid Binary related to Inval...
# 3     iOS 14 release Invalid Binary related to Inval...
# 4     [infra] Mac ios engine builds failing on beta ...
# ...                                                 ...
# 1710  Review request for Revert PR flutter/flutter#1...
# 1711        Dart SDK roller blocked on persistent crash
# 1712  High flake rate on web hot reload test `packag...
# 1713   High flake rate on `test/integration.shard/de...
# 1714   High flake rate on `test/integration.shard/de...
#
#                                                  labels  \
# 0     P1 passed first triage passed secondary triage...
# 1     P1 f: material design framework passed first t...
# 2     P1 a: release cp: 1.22 e: OS Version specific ...
# 3     P1 a: release cp: 1.22 e: OS Version specific ...
# 4                                   P1 team team: infra
# ...                                                 ...
# 1710                                                 P1
# 1711                         engine dependency: dart P0
# 1712                                   P0 severe: flake
# 1713                                   P0 severe: flake
# 1714                                   P0 severe: flake
#
#                                                    body
# 0     I'm trying to debug https://github.com/flutter...
# 1     https://flutter-flutter-perf.skia.org/e/?begin...
# 2     I've a problem with publishing app to App Stor...
# 3     I've a problem with publishing app to App Stor...
# 4     <!-- Thank you for using Flutter!\r\n\r\n     ...
# ...                                                 ...
# 1710  Pull request flutter/flutter#119981 was submit...
# 1711  Rolls:\r\n* https://github.com/flutter/engine/...
# 1712  The high flake rate began around 1PM PST on Fe...
# 1713  Causing many framework tree failures over the ...
# 1714  Causing many framework tree failures over the ...
#
# [1715 rows x 9 columns]

# %%
# Remove pattern from df
random = df[~df['labels'].str.contains(pattern)]
random = random.reset_index(drop=True)
random
# Out:
# /tmp/ipykernel_340011/2462673340.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   random = df[~df['labels'].str.contains(pattern)]
#                  id         type           created_at             repo  \
# 0      1.141754e+10  IssuesEvent  2020-02-03 00:02:35  flutter/flutter
# 1      1.141766e+10  IssuesEvent  2020-02-03 00:48:37  flutter/flutter
# 2      1.141771e+10  IssuesEvent  2020-02-03 01:04:00  flutter/flutter
# 3      1.141780e+10  IssuesEvent  2020-02-03 01:34:27  flutter/flutter
# 4      1.141915e+10  IssuesEvent  2020-02-03 07:10:13  flutter/flutter
# ...             ...          ...                  ...              ...
# 43297  2.060417e+10  IssuesEvent  2022-03-06 18:26:25  flutter/flutter
# 43298  2.060462e+10  IssuesEvent  2022-03-06 19:49:39  flutter/flutter
# 43299  2.060486e+10  IssuesEvent  2022-03-06 20:33:15  flutter/flutter
# 43300  7.334872e+09  IssuesEvent  2018-03-06 00:52:29  flutter/flutter
# 43301  7.334882e+09  IssuesEvent  2018-03-06 00:55:47  flutter/flutter
#
#                                            repo_url  action  \
# 0      https://api.github.com/repos/flutter/flutter  opened
# 1      https://api.github.com/repos/flutter/flutter  opened
# 2      https://api.github.com/repos/flutter/flutter  opened
# 3      https://api.github.com/repos/flutter/flutter  closed
# 4      https://api.github.com/repos/flutter/flutter  closed
# ...                                             ...     ...
# 43297  https://api.github.com/repos/flutter/flutter  closed
# 43298  https://api.github.com/repos/flutter/flutter  closed
# 43299  https://api.github.com/repos/flutter/flutter  closed
# 43300  https://api.github.com/repos/flutter/flutter  opened
# 43301  https://api.github.com/repos/flutter/flutter  opened
#
#                                                    title  \
# 0      Keyboard flashes briefly when dismissing multi...
# 1      ChocieChip's default "selected" style in dark ...
# 2      Flutter apps restart when you toggle "Invert C...
# 3                           flutter build output unclear
# 4      Ink.image keeps cache of the image somewhere else
# ...                                                  ...
# 43297                                                Yea
# 43298       [Impeller] Get rid of //impeller/third_party
# 43299             Install log handler for macOS embedder
# 43300                           a11y of fancy text field
# 43301  Textfield placeholder not announced in a11y on...
#
#                                               labels  \
# 0        a: quality a: text input f: focus framework
# 1      a: accessibility f: material design framework
# 2      dependency: android engine ▣ platform-android
# 3                                               tool
# 4                                     p: third party
# ...                                              ...
# 43297                                    team: infra
# 43298                             engine P4 impeller
# 43299    engine platform-mac a: desktop P4 tech-debt
# 43300                a11y review prod: accessibility
# 43301                a11y review prod: accessibility
#
#                                                     body
# 0      ```dart\r\nimport 'package:flutter/material.da...
# 1      ![flutter_01](https://user-images.githubuserco...
# 2      Doesn't look like `android:configChanges` lets...
# 3      Some friction using `flutter build`\r\n\r\n1- ...
# 4      I don't know why, but it seems that Ink.image ...
# ...                                                  ...
# 43297  <!--  Thank you for contributing to Flutter!\n...
# 43298  The only dependency there is is STB which is o...
# 43299  Rather than relying on the engine's fallback l...
# 43300  ![image](https://user-images.githubusercontent...
# 43301  On iOS go to the text field demo of the Flutte...
#
# [43302 rows x 9 columns]

# %%
# Removing in triage since these issues are not assigned a priority
pattern = 'in triage'
# Remove pattern from df
random = random[~random['labels'].str.contains(pattern)]
random = random.reset_index(drop=True)
random
# Out:
#                  id         type           created_at             repo  \
# 0      1.141754e+10  IssuesEvent  2020-02-03 00:02:35  flutter/flutter
# 1      1.141766e+10  IssuesEvent  2020-02-03 00:48:37  flutter/flutter
# 2      1.141771e+10  IssuesEvent  2020-02-03 01:04:00  flutter/flutter
# 3      1.141780e+10  IssuesEvent  2020-02-03 01:34:27  flutter/flutter
# 4      1.141915e+10  IssuesEvent  2020-02-03 07:10:13  flutter/flutter
# ...             ...          ...                  ...              ...
# 32112  2.060417e+10  IssuesEvent  2022-03-06 18:26:25  flutter/flutter
# 32113  2.060462e+10  IssuesEvent  2022-03-06 19:49:39  flutter/flutter
# 32114  2.060486e+10  IssuesEvent  2022-03-06 20:33:15  flutter/flutter
# 32115  7.334872e+09  IssuesEvent  2018-03-06 00:52:29  flutter/flutter
# 32116  7.334882e+09  IssuesEvent  2018-03-06 00:55:47  flutter/flutter
#
#                                            repo_url  action  \
# 0      https://api.github.com/repos/flutter/flutter  opened
# 1      https://api.github.com/repos/flutter/flutter  opened
# 2      https://api.github.com/repos/flutter/flutter  opened
# 3      https://api.github.com/repos/flutter/flutter  closed
# 4      https://api.github.com/repos/flutter/flutter  closed
# ...                                             ...     ...
# 32112  https://api.github.com/repos/flutter/flutter  closed
# 32113  https://api.github.com/repos/flutter/flutter  closed
# 32114  https://api.github.com/repos/flutter/flutter  closed
# 32115  https://api.github.com/repos/flutter/flutter  opened
# 32116  https://api.github.com/repos/flutter/flutter  opened
#
#                                                    title  \
# 0      Keyboard flashes briefly when dismissing multi...
# 1      ChocieChip's default "selected" style in dark ...
# 2      Flutter apps restart when you toggle "Invert C...
# 3                           flutter build output unclear
# 4      Ink.image keeps cache of the image somewhere else
# ...                                                  ...
# 32112                                                Yea
# 32113       [Impeller] Get rid of //impeller/third_party
# 32114             Install log handler for macOS embedder
# 32115                           a11y of fancy text field
# 32116  Textfield placeholder not announced in a11y on...
#
#                                               labels  \
# 0        a: quality a: text input f: focus framework
# 1      a: accessibility f: material design framework
# 2      dependency: android engine ▣ platform-android
# 3                                               tool
# 4                                     p: third party
# ...                                              ...
# 32112                                    team: infra
# 32113                             engine P4 impeller
# 32114    engine platform-mac a: desktop P4 tech-debt
# 32115                a11y review prod: accessibility
# 32116                a11y review prod: accessibility
#
#                                                     body
# 0      ```dart\r\nimport 'package:flutter/material.da...
# 1      ![flutter_01](https://user-images.githubuserco...
# 2      Doesn't look like `android:configChanges` lets...
# 3      Some friction using `flutter build`\r\n\r\n1- ...
# 4      I don't know why, but it seems that Ink.image ...
# ...                                                  ...
# 32112  <!--  Thank you for contributing to Flutter!\n...
# 32113  The only dependency there is is STB which is o...
# 32114  Rather than relying on the engine's fallback l...
# 32115  ![image](https://user-images.githubusercontent...
# 32116  On iOS go to the text field demo of the Flutte...
#
# [32117 rows x 9 columns]

# %%
random.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# team: infra                                          1185
# waiting for customer response                        1041
# created via support template                          607
# created via performance template                      469
# tool                                                  348
# f: material design framework                          247
# engine                                                213
# cp: review                                            178
# team: infra device-lab                                159
# r: invalid                                            155
# framework                                             149
# engine P4 impeller                                    124
# dev: tool                                             119
# ☸ platform-web                                        118
# engine impeller                                       106
# severe: crash tool                                    105
# dev: docs - website                                   104
# d: stackoverflow                                      104
# r: duplicate                                           96
# team team: infra                                       95
# framework f: material design                           95
# severe: performance                                    93
# team: infra P3                                         92
# plugin                                                 81
# ⚠ clear documentation                                  79
# passed secondary triage team: infra                    76
# prod: framework                                        75
# team                                                   72
# infra: device lab                                      69
# f: material design framework waiting for custom...     65
# impeller                                               62
# a: text input f: material design framework             62
# f: material design framework severe: new feature       60
# d: website - content                                   58
# ⌺‬ platform-ios                                        57
# affects: tools                                         56
# customer: gallery                                      50
# prod: accessibility                                    50
# team: infra passed secondary triage                    50
# t: gradle tool                                         49
# team-infra                                             48
# a: tests                                               48
# team: infra P2                                         46
# d: website - infra                                     45
# passed first triage team: infra                        44
# team tool                                              43
# customer: fuchsia engine                               42
# framework waiting for customer response                40
# dev: docs                                              40
# a: text input framework                                39

# %%
# Number or different labels
hp.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# team: infra P0                                        125
# P1                                                    121
# tool team: flakes P1 severe: flake                    118
# engine team: flakes P1 severe: flake                  104
# team: flakes P1 severe: flake                          63
# P0 team: infra                                         61
# P0                                                     57
# P1 team: infra                                         52
# engine P0                                              30
# framework team: flakes P1 severe: flake                28
# team: infra P1                                         27
# dependency: dart P0                                    26
# P0 c: flake team-web                                   21
# team: infra passed secondary triage P0                 16
# team: flakes platform-web P1 severe: flake             15
# engine dependency: dart P0                             15
# P0 c: flake team-tool                                  14
# team: infra passed secondary triage P1                 14
# team: flakes team: infra P1 severe: flake              14
# P1 passed secondary triage team: infra                 12
# P1 team team: infra                                    11
# P0 engine                                              11
# P1 passed first triage passed secondary triage ...     10
# engine P1 e: impeller team-engine triaged-engine       10
# P1 e: impeller team-engine triaged-engine              10
# P0 team team: infra                                    10
# P1 severe: flake team: flakes                           9
# P0 engine perf: speed severe: performance sever...      7
# dependency: dart P1                                     7
# team-infra P0 triaged-infra                             6
# tool P0                                                 6
# team-infra P0                                           6
# P0 c: flake team-framework                              6
# engine dependency: dart P1                              6
# engine P1 e: impeller                                   5
# P1 passed first triage team: infra                      5
# P0 dependency: dart                                     5
# team: flakes team: infra passed secondary triag...      5
# tool platform-web P1                                    5
# P1 team: release                                        5
# platform-ios team: flakes P1 severe: flake              5
# P0 dependency: dart engine passed first triage ...      4
# team-infra P1                                           4
# P0 passed first triage team: infra                      4
# P0 c: flake team-engine                                 4
# P1 a: null-safety                                       4
# package P0                                              4
# P0 package                                              4
# P1 customer: bytedance e: OS Version specific e...      4
# P0 passed first triage team team: infra                 4

# %%
#Give each priority a label by number.
# 'Label encoding'. Makes is easier for machine learning models to work with categorical data.
hp["label"] = 1
hp["class"] = "high_priority"
hp.head()
# Out:
#              id         type           created_at             repo  \
# 0  1.362189e+10  IssuesEvent  2020-09-24 02:01:56  flutter/flutter
# 1  1.362223e+10  IssuesEvent  2020-09-24 03:00:37  flutter/flutter
# 2  1.362854e+10  IssuesEvent  2020-09-24 14:02:05  flutter/flutter
# 3  1.363092e+10  IssuesEvent  2020-09-24 17:10:38  flutter/flutter
# 4  1.363372e+10  IssuesEvent  2020-09-24 22:01:59  flutter/flutter
#
#                                        repo_url    action  \
# 0  https://api.github.com/repos/flutter/flutter  reopened
# 1  https://api.github.com/repos/flutter/flutter    closed
# 2  https://api.github.com/repos/flutter/flutter    closed
# 3  https://api.github.com/repos/flutter/flutter  reopened
# 4  https://api.github.com/repos/flutter/flutter    opened
#
#                                                title  \
# 0                  I can't view build dashboard logs
# 1  worst_frame_build_time_millis \tcubic_bezier_p...
# 2  iOS 14 release Invalid Binary related to Inval...
# 3  iOS 14 release Invalid Binary related to Inval...
# 4  [infra] Mac ios engine builds failing on beta ...
#
#                                               labels  \
# 0  P1 passed first triage passed secondary triage...
# 1  P1 f: material design framework passed first t...
# 2  P1 a: release cp: 1.22 e: OS Version specific ...
# 3  P1 a: release cp: 1.22 e: OS Version specific ...
# 4                                P1 team team: infra
#
#                                                 body  label          class
# 0  I'm trying to debug https://github.com/flutter...      1  high_priority
# 1  https://flutter-flutter-perf.skia.org/e/?begin...      1  high_priority
# 2  I've a problem with publishing app to App Stor...      1  high_priority
# 3  I've a problem with publishing app to App Stor...      1  high_priority
# 4  <!-- Thank you for using Flutter!\r\n\r\n     ...      1  high_priority

# %%
random["label"] = 0
random["class"] = "not_high_priority" 
random.head()
# Out:
#              id         type           created_at             repo  \
# 0  1.141754e+10  IssuesEvent  2020-02-03 00:02:35  flutter/flutter
# 1  1.141766e+10  IssuesEvent  2020-02-03 00:48:37  flutter/flutter
# 2  1.141771e+10  IssuesEvent  2020-02-03 01:04:00  flutter/flutter
# 3  1.141780e+10  IssuesEvent  2020-02-03 01:34:27  flutter/flutter
# 4  1.141915e+10  IssuesEvent  2020-02-03 07:10:13  flutter/flutter
#
#                                        repo_url  action  \
# 0  https://api.github.com/repos/flutter/flutter  opened
# 1  https://api.github.com/repos/flutter/flutter  opened
# 2  https://api.github.com/repos/flutter/flutter  opened
# 3  https://api.github.com/repos/flutter/flutter  closed
# 4  https://api.github.com/repos/flutter/flutter  closed
#
#                                                title  \
# 0  Keyboard flashes briefly when dismissing multi...
# 1  ChocieChip's default "selected" style in dark ...
# 2  Flutter apps restart when you toggle "Invert C...
# 3                       flutter build output unclear
# 4  Ink.image keeps cache of the image somewhere else
#
#                                           labels  \
# 0    a: quality a: text input f: focus framework
# 1  a: accessibility f: material design framework
# 2  dependency: android engine ▣ platform-android
# 3                                           tool
# 4                                 p: third party
#
#                                                 body  label              class
# 0  ```dart\r\nimport 'package:flutter/material.da...      0  not_high_priority
# 1  ![flutter_01](https://user-images.githubuserco...      0  not_high_priority
# 2  Doesn't look like `android:configChanges` lets...      0  not_high_priority
# 3  Some friction using `flutter build`\r\n\r\n1- ...      0  not_high_priority
# 4  I don't know why, but it seems that Ink.image ...      0  not_high_priority

# %%
# Drop duplicates by the content of the title
high_priority = hp.drop_duplicates(subset=['title'], keep='last')
high_priority.dropna(inplace=True)
high_priority.reset_index(inplace=True)
high_priority.drop(columns=["index"] , inplace= True)
high_priority["class"].value_counts()
# Out:
# /tmp/ipykernel_340011/1823776403.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_priority.dropna(inplace=True)
# /tmp/ipykernel_340011/1823776403.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_priority.drop(columns=["index"] , inplace= True)
# class
# high_priority    1190
# Name: count, dtype: int64

# %%
# Drop duplicates by the content of the title
not_high_priority = random.drop_duplicates(subset=['title'], keep='last')
not_high_priority.dropna(inplace=True)
not_high_priority.reset_index(inplace=True)
not_high_priority.drop(columns=["index"] , inplace= True)
not_high_priority["class"].value_counts()
# Out:
# /tmp/ipykernel_340011/3923262596.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority.dropna(inplace=True)
# /tmp/ipykernel_340011/3923262596.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority.drop(columns=["index"] , inplace= True)
# class
# not_high_priority    26115
# Name: count, dtype: int64

# %%
high_priority.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1190 non-null   float64
#  1   type        1190 non-null   object
#  2   created_at  1190 non-null   object
#  3   repo        1190 non-null   object
#  4   repo_url    1190 non-null   object
#  5   action      1190 non-null   object
#  6   title       1190 non-null   object
#  7   labels      1190 non-null   object
#  8   body        1190 non-null   object
#  9   label       1190 non-null   int64
#  10  class       1190 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 102.4+ KB

# %%
label_counts = high_priority["class"].value_counts()
label_counts_nhp = not_high_priority["class"].value_counts()
print(label_counts)
not_high_priority_count = label_counts_nhp["not_high_priority"]
print(not_high_priority_count)
hp_count = label_counts["high_priority"]
hp_count
# Out:
# class
# high_priority    1190
# Name: count, dtype: int64
# 26115
# 1190

# %%
not_high_priority = not_high_priority.sample(frac=hp_count/not_high_priority_count, random_state=42)
not_high_priority
# Out:
#                  id         type           created_at             repo  \
# 9453   2.809583e+10  IssuesEvent  2023-03-30 15:43:44  flutter/flutter
# 7826   9.995683e+09  IssuesEvent  2019-07-11 20:54:53  flutter/flutter
# 14649  1.020933e+10  IssuesEvent  2019-08-14 12:27:55  flutter/flutter
# 10947  1.282326e+10  IssuesEvent  2020-07-06 11:21:56  flutter/flutter
# 20220  1.055266e+10  IssuesEvent  2019-10-03 15:35:01  flutter/flutter
# ...             ...          ...                  ...              ...
# 10863  7.174676e+09  IssuesEvent  2018-01-31 00:51:45  flutter/flutter
# 25824  1.031519e+10  IssuesEvent  2019-08-30 06:47:12  flutter/flutter
# 23239  2.646927e+10  IssuesEvent  2023-01-17 05:07:02  flutter/flutter
# 280    2.523019e+10  IssuesEvent  2022-11-14 19:07:52  flutter/flutter
# 20339  2.412155e+10  IssuesEvent  2022-09-20 19:11:56  flutter/flutter
#
#                                            repo_url    action  \
# 9453   https://api.github.com/repos/flutter/flutter    closed
# 7826   https://api.github.com/repos/flutter/flutter    closed
# 14649  https://api.github.com/repos/flutter/flutter    closed
# 10947  https://api.github.com/repos/flutter/flutter    closed
# 20220  https://api.github.com/repos/flutter/flutter    closed
# ...                                             ...       ...
# 10863  https://api.github.com/repos/flutter/flutter    closed
# 25824  https://api.github.com/repos/flutter/flutter    closed
# 23239  https://api.github.com/repos/flutter/flutter    closed
# 280    https://api.github.com/repos/flutter/flutter    closed
# 20339  https://api.github.com/repos/flutter/flutter  reopened
#
#                                                    title  \
# 9453   Transition animation curves used by Cupertino ...
# 7826     Table widget doesn't work with Hero animations.
# 14649  Content Overflows when using NestedScrollView ...
# 10947  Error connecting to the service protocol: fail...
# 20220                 Firestore Calculations not working
# ...                                                  ...
# 10863  Gallery, Scrollable tabs: Open and Close miss ...
# 25824  TextEditingController.clear() makes keyboard u...
# 23239  DeviceOrientation.landscapeRight is upside dow...
# 280    Exception: Failed to access the internal image...
# 20339  [pigeon] Can't be tested on stable channel as ...
#
#                                                   labels  \
# 9453   framework f: cupertino has reproducible steps ...
# 7826           customer: payouts framework severe: crash
# 14649          f: material design f: scrolling framework
# 10947        P4 platform-ios severe: crash t: xcode tool
# 20220                          p: cloud_firestore plugin
# ...                                                  ...
# 10863  customer blocker performance prod: framework t...
# 25824         a: text input framework severe: regression
# 23239  platform-android engine a: layout has reproduc...
# 280    severe: crash engine a: images has reproducibl...
# 20339  platform-android platform-ios passed first tri...
#
#                                                     body  label  \
# 9453   CupertinoPageRoute animations are now outdated...      0
# 7826   ## Steps to reproduce\r\n\r\nRun the following...      0
# 14649  In the below code, the `_menuPage()` returns a...      0
# 10947  App launch fails: physical device-6th Gen iPad...      0
# 20220  ### Objective\r\nI've got a Firestore app that...      0
# ...                                                  ...    ...
# 10863  Many of the component demos open and close qui...      0
# 25824  <!-- Thank you for using Flutter!\r\n\r\n     ...      0
# 23239  <!-- Thank you for using Flutter!\r\n\r\n     ...      0
# 280    I encountered the following error trying use t...      0
# 20339  Due to unrecognized version to the Dart SDK on...      0
#
#                    class
# 9453   not_high_priority
# 7826   not_high_priority
# 14649  not_high_priority
# 10947  not_high_priority
# 20220  not_high_priority
# ...                  ...
# 10863  not_high_priority
# 25824  not_high_priority
# 23239  not_high_priority
# 280    not_high_priority
# 20339  not_high_priority
#
# [1190 rows x 11 columns]

# %%
all_priority = pd.concat([high_priority,not_high_priority] , ignore_index = True)
all_priority.tail()
# Out:
#                 id         type           created_at             repo  \
# 2375  7.174676e+09  IssuesEvent  2018-01-31 00:51:45  flutter/flutter
# 2376  1.031519e+10  IssuesEvent  2019-08-30 06:47:12  flutter/flutter
# 2377  2.646927e+10  IssuesEvent  2023-01-17 05:07:02  flutter/flutter
# 2378  2.523019e+10  IssuesEvent  2022-11-14 19:07:52  flutter/flutter
# 2379  2.412155e+10  IssuesEvent  2022-09-20 19:11:56  flutter/flutter
#
#                                           repo_url    action  \
# 2375  https://api.github.com/repos/flutter/flutter    closed
# 2376  https://api.github.com/repos/flutter/flutter    closed
# 2377  https://api.github.com/repos/flutter/flutter    closed
# 2378  https://api.github.com/repos/flutter/flutter    closed
# 2379  https://api.github.com/repos/flutter/flutter  reopened
#
#                                                   title  \
# 2375  Gallery, Scrollable tabs: Open and Close miss ...
# 2376  TextEditingController.clear() makes keyboard u...
# 2377  DeviceOrientation.landscapeRight is upside dow...
# 2378  Exception: Failed to access the internal image...
# 2379  [pigeon] Can't be tested on stable channel as ...
#
#                                                  labels  \
# 2375  customer blocker performance prod: framework t...
# 2376         a: text input framework severe: regression
# 2377  platform-android engine a: layout has reproduc...
# 2378  severe: crash engine a: images has reproducibl...
# 2379  platform-android platform-ios passed first tri...
#
#                                                    body  label  \
# 2375  Many of the component demos open and close qui...      0
# 2376  <!-- Thank you for using Flutter!\r\n\r\n     ...      0
# 2377  <!-- Thank you for using Flutter!\r\n\r\n     ...      0
# 2378  I encountered the following error trying use t...      0
# 2379  Due to unrecognized version to the Dart SDK on...      0
#
#                   class
# 2375  not_high_priority
# 2376  not_high_priority
# 2377  not_high_priority
# 2378  not_high_priority
# 2379  not_high_priority

# %%
# 
all_priority["label"].value_counts()
# Out:
# label
# 1    1190
# 0    1190
# Name: count, dtype: int64

# %%
print(all_priority["title"][0])
print(all_priority["body"][0])
# Out:
# worst_frame_build_time_millis 	cubic_bezier_perf__e2e_summary regression
# https://flutter-flutter-perf.skia.org/e/?begin=1600207024&end=1600291175&keys=X197f56aeb2671ed26940c2a2de56e74d&num_commits=50&request_type=1&xbaroffset=21489.
#
# Looks like this commit: https://github.com/flutter/flutter/pull/65900. I suspect given the commit that this is expected?
#
# /cc @HansMuller

# %%
# Copy content of body to a new col named text
all_priority["text"] = all_priority["title"] + all_priority["body"]
all_priority.tail()
# Out:
#                 id         type           created_at             repo  \
# 2375  7.174676e+09  IssuesEvent  2018-01-31 00:51:45  flutter/flutter
# 2376  1.031519e+10  IssuesEvent  2019-08-30 06:47:12  flutter/flutter
# 2377  2.646927e+10  IssuesEvent  2023-01-17 05:07:02  flutter/flutter
# 2378  2.523019e+10  IssuesEvent  2022-11-14 19:07:52  flutter/flutter
# 2379  2.412155e+10  IssuesEvent  2022-09-20 19:11:56  flutter/flutter
#
#                                           repo_url    action  \
# 2375  https://api.github.com/repos/flutter/flutter    closed
# 2376  https://api.github.com/repos/flutter/flutter    closed
# 2377  https://api.github.com/repos/flutter/flutter    closed
# 2378  https://api.github.com/repos/flutter/flutter    closed
# 2379  https://api.github.com/repos/flutter/flutter  reopened
#
#                                                   title  \
# 2375  Gallery, Scrollable tabs: Open and Close miss ...
# 2376  TextEditingController.clear() makes keyboard u...
# 2377  DeviceOrientation.landscapeRight is upside dow...
# 2378  Exception: Failed to access the internal image...
# 2379  [pigeon] Can't be tested on stable channel as ...
#
#                                                  labels  \
# 2375  customer blocker performance prod: framework t...
# 2376         a: text input framework severe: regression
# 2377  platform-android engine a: layout has reproduc...
# 2378  severe: crash engine a: images has reproducibl...
# 2379  platform-android platform-ios passed first tri...
#
#                                                    body  label  \
# 2375  Many of the component demos open and close qui...      0
# 2376  <!-- Thank you for using Flutter!\r\n\r\n     ...      0
# 2377  <!-- Thank you for using Flutter!\r\n\r\n     ...      0
# 2378  I encountered the following error trying use t...      0
# 2379  Due to unrecognized version to the Dart SDK on...      0
#
#                   class                                               text
# 2375  not_high_priority  Gallery, Scrollable tabs: Open and Close miss ...
# 2376  not_high_priority  TextEditingController.clear() makes keyboard u...
# 2377  not_high_priority  DeviceOrientation.landscapeRight is upside dow...
# 2378  not_high_priority  Exception: Failed to access the internal image...
# 2379  not_high_priority  [pigeon] Can't be tested on stable channel as ...

# %%
all_priority["text"][0]
# Out:
# 'worst_frame_build_time_millis \tcubic_bezier_perf__e2e_summary regressionhttps://flutter-flutter-perf.skia.org/e/?begin=1600207024&end=1600291175&keys=X197f56aeb2671ed26940c2a2de56e74d&num_commits=50&request_type=1&xbaroffset=21489.\r\n\r\nLooks like this commit: https://github.com/flutter/flutter/pull/65900. I suspect given the commit that this is expected?\r\n\r\n/cc @HansMuller \r\n\r\n'

# %%
# Make a new dataframe with only text, label and class cols.
all_priority_subset = all_priority[["text" , "label" , "class"]]
all_priority_subset
# Out:
#                                                    text  label  \
# 0     worst_frame_build_time_millis \tcubic_bezier_p...      1
# 1     iOS 14 release Invalid Binary related to Inval...      1
# 2     [infra] Mac ios engine builds failing on beta ...      1
# 3     Review request for Revert PR flutter/flutter#1...      1
# 4     Flutter to Plugin Roll broken by removal of `F...      1
# ...                                                 ...    ...
# 2375  Gallery, Scrollable tabs: Open and Close miss ...      0
# 2376  TextEditingController.clear() makes keyboard u...      0
# 2377  DeviceOrientation.landscapeRight is upside dow...      0
# 2378  Exception: Failed to access the internal image...      0
# 2379  [pigeon] Can't be tested on stable channel as ...      0
#
#                   class
# 0         high_priority
# 1         high_priority
# 2         high_priority
# 3         high_priority
# 4         high_priority
# ...                 ...
# 2375  not_high_priority
# 2376  not_high_priority
# 2377  not_high_priority
# 2378  not_high_priority
# 2379  not_high_priority
#
# [2380 rows x 3 columns]

# %%
# Convert to string
all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)
# Out:
# /tmp/ipykernel_340011/3106036705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)

# %%
all_priority_subset
# Out:
#                                                    text  label  \
# 0     worst_frame_build_time_millis \tcubic_bezier_p...      1
# 1     iOS 14 release Invalid Binary related to Inval...      1
# 2     [infra] Mac ios engine builds failing on beta ...      1
# 3     Review request for Revert PR flutter/flutter#1...      1
# 4     Flutter to Plugin Roll broken by removal of `F...      1
# ...                                                 ...    ...
# 2375  Gallery, Scrollable tabs: Open and Close miss ...      0
# 2376  TextEditingController.clear() makes keyboard u...      0
# 2377  DeviceOrientation.landscapeRight is upside dow...      0
# 2378  Exception: Failed to access the internal image...      0
# 2379  [pigeon] Can't be tested on stable channel as ...      0
#
#                   class                                           text_str
# 0         high_priority  worst_frame_build_time_millis \tcubic_bezier_p...
# 1         high_priority  iOS 14 release Invalid Binary related to Inval...
# 2         high_priority  [infra] Mac ios engine builds failing on beta ...
# 3         high_priority  Review request for Revert PR flutter/flutter#1...
# 4         high_priority  Flutter to Plugin Roll broken by removal of `F...
# ...                 ...                                                ...
# 2375  not_high_priority  Gallery, Scrollable tabs: Open and Close miss ...
# 2376  not_high_priority  TextEditingController.clear() makes keyboard u...
# 2377  not_high_priority  DeviceOrientation.landscapeRight is upside dow...
# 2378  not_high_priority  Exception: Failed to access the internal image...
# 2379  not_high_priority  [pigeon] Can't be tested on stable channel as ...
#
# [2380 rows x 4 columns]

# %%
# Clean the data.
all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_340011/63294665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)

# %%
# Make a subset with text_clean and label
priority_label_text = all_priority_subset[["text_clean" , "label"]]
priority_label_text
# Out:
#                                              text_clean  label
# 0     worstframebuildtimemillis regression looks lik...      1
# 1     ios release invalid binary related to invalid ...      1
# 2     mac ios engine builds failing on beta branch t...      1
# 3     review request for revert pr request was submi...      1
# 4     flutter to plugin roll broken by removal of fl...      1
# ...                                                 ...    ...
# 2375  gallery scrollable tabs open and close miss fr...      0
# 2376  texteditingcontrollerclear makes keyboard unre...      0
# 2377  deviceorientationlandscaperight is upside down...      0
# 2378  exception failed to access the internal image ...      0
# 2379  cant be tested on stable channel as of due to ...      0
#
# [2380 rows x 2 columns]

# %%
# Need to dropna here since cleaning function returns NaN for not english text.
priority_label_text.dropna(inplace=True)
priority_label_text.reset_index(inplace=True)
priority_label_text.drop(columns=["index"] , inplace= True)

priority_label_text
# Out:
# /tmp/ipykernel_340011/239147930.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.dropna(inplace=True)
# /tmp/ipykernel_340011/239147930.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.drop(columns=["index"] , inplace= True)
#                                              text_clean  label
# 0     worstframebuildtimemillis regression looks lik...      1
# 1     ios release invalid binary related to invalid ...      1
# 2     mac ios engine builds failing on beta branch t...      1
# 3     review request for revert pr request was submi...      1
# 4     flutter to plugin roll broken by removal of fl...      1
# ...                                                 ...    ...
# 2368  gallery scrollable tabs open and close miss fr...      0
# 2369  texteditingcontrollerclear makes keyboard unre...      0
# 2370  deviceorientationlandscaperight is upside down...      0
# 2371  exception failed to access the internal image ...      0
# 2372  cant be tested on stable channel as of due to ...      0
#
# [2373 rows x 2 columns]

# %%
from sklearn.utils import resample

# Split the dataset into two based on the label
df_majority = priority_label_text[priority_label_text['label'] == 1]
df_minority = priority_label_text[priority_label_text['label'] == 0]

# Undersample the majority class
df_majority_undersampled = resample(df_majority, 
                                     replace=False,    # sample without replacement
                                     n_samples=len(df_minority),     # to match minority class
                                     random_state=123) # reproducible results

# Combine minority class with downsampled majority class
df_balanced = pd.concat([df_majority_undersampled, df_minority])

# Shuffle the dataset to avoid any ordering bias
df_balanced = df_balanced.sample(frac=1).reset_index(drop=True)
priority_label_text = df_balanced
priority_label_text["label"].value_counts()
# Out:
# label
# 0    1186
# 1    1186
# Name: count, dtype: int64

# %%
# Clean dataset with clean text and labels.
# 0 = high priority, 1 = not high priority
file_name = f"csv/clean_flutter_testset.csv"
priority_label_text.to_csv(file_name, index=False)

# %%
pri = pd.read_csv(file_name)
pri
# Out:
#                                              text_clean  label
# 0     some errors are silencedi need some help in fi...      0
# 1     flutter not rendering text after sitting idle ...      1
# 2     windows frameworktestslibraries is flaky metat...      1
# 3     reverse listview scrolls to bottom when tappin...      0
# 4     iconbutton doc link point to the wrong website...      0
# ...                                                 ...    ...
# 2367  we should crash if you both enableimpeller and...      1
# 2368           tree closed on infra failuresfor example      1
# 2369  temporarily disable windows tests try and prod...      1
# 2370  linux routingtest infra failurei cant tell wha...      1
# 2371  cupertinotabbar change tab index programatical...      0
#
# [2372 rows x 2 columns]
