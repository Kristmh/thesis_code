# %% [markdown]
# # Dataset creation
# This notebook will:
# * Remove Technical debt labels
# * Extract 5% to make testing set.
# * It will produce 3 different dataset:
#   1. High/med/priority dataset with no debt
#   2. Test dataset
#   3. Debt dataset

# %%
import pandas as pd

# %%
# Read in the full dataset
file_name = "low_priority"
priority_file_name = f'csv/{file_name}_full_dataset.csv'
priority = pd.read_csv(priority_file_name, index_col=0)
priority
# Out:
#                   id         type           created_at  \
# 0       1.141755e+10  IssuesEvent  2020-02-03 00:02:50
# 1       1.141766e+10  IssuesEvent  2020-02-03 00:46:42
# 2       1.141777e+10  IssuesEvent  2020-02-03 01:25:06
# 3       1.141780e+10  IssuesEvent  2020-02-03 01:34:56
# 4       1.141786e+10  IssuesEvent  2020-02-03 01:52:04
# ...              ...          ...                  ...
# 200475  2.060586e+10  IssuesEvent  2022-03-06 23:45:23
# 200476  7.334740e+09  IssuesEvent  2018-03-06 00:10:40
# 200477  7.334876e+09  IssuesEvent  2018-03-06 00:53:49
# 200478  7.335047e+09  IssuesEvent  2018-03-06 01:48:07
# 200479  7.335050e+09  IssuesEvent  2018-03-06 01:49:10
#
#                              repo  \
# 0          poissonconsulting/term
# 1             WordPress/gutenberg
# 2               MarkBind/markbind
# 3               MarkBind/markbind
# 4          poissonconsulting/term
# ...                           ...
# 200475  bounswe/bounswe2022group1
# 200476            hoodedice/notes
# 200477  zephyrproject-rtos/zephyr
# 200478         uwnrg/minotaur-cpp
# 200479         uwnrg/minotaur-cpp
#
#                                                  repo_url    action  \
# 0       https://api.github.com/repos/poissonconsulting...    opened
# 1        https://api.github.com/repos/WordPress/gutenberg    closed
# 2          https://api.github.com/repos/MarkBind/markbind  reopened
# 3          https://api.github.com/repos/MarkBind/markbind    closed
# 4       https://api.github.com/repos/poissonconsulting...    closed
# ...                                                   ...       ...
# 200475  https://api.github.com/repos/bounswe/bounswe20...    closed
# 200476       https://api.github.com/repos/hoodedice/notes    opened
# 200477  https://api.github.com/repos/zephyrproject-rto...    closed
# 200478    https://api.github.com/repos/uwnrg/minotaur-cpp    closed
# 200479    https://api.github.com/repos/uwnrg/minotaur-cpp    closed
#
#                                                     title  \
# 0             Document levels of validation in vld_term()
# 1                       Z-index issue using Classic block
# 2                   Indicate the language of a code block
# 3          Use one attribute name for header, title, name
# 4             Document levels of validation in vld_term()
# ...                                                   ...
# 200475                        Editing Navigator of  Wiki
# 200476                           Check if passwords match
# 200477  Add doc to samples/bluetooth/mesh & samples/bl...
# 200478                   Fix the photo in about dialog xd
# 200479  Move Record Video/Screenshot and camera select...
#
#                                                    labels  \
# 0       Difficulty: 1 Novice Effort: 1 Low Priority: 2...
# 1               [Block] Classic [Priority] Low [Type] Bug
# 2                        c.Enhancement f-CodeBlocks p.Low
# 3                                 a-AuthorUsability p.Low
# 4       Difficulty: 1 Novice Effort: 1 Low Priority: 2...
# ...                                                   ...
# 200475                                       Priority-Low
# 200476                           enhancement low priority
# 200477  area: Bluetooth area: Documentation area: Samp...
# 200478                           enhancement low priority
# 200479                           enhancement low priority
#
#                                                      body
# 0              As this is what other functions reference.
# 1       Selecting a link in the classic block and havi...
# 2       **Tell us about your environment**\r\n\r\n* **...
# 3       May be better to choose one of the three and u...
# 4              As this is what other functions reference.
# ...                                                   ...
# 200475  The navigator of the wiki should be edited and...
# 200476  JavaScript code (or see if possible without) t...
# 200477  We should document what exactly the sample is ...
# 200478                                                NaN
# 200479            that can be opened from a dropdown menu
#
# [200480 rows x 9 columns]

# %%
# Create debt dataframe
technical_debt_regex = r'debt|\bTD\b'
contains_debt_high_priority = priority['labels'].str.contains(technical_debt_regex, case=False, na=False)
debt = priority[contains_debt_high_priority].reset_index(drop=True)
debt
# Out:
#                id         type           created_at  \
# 0    1.142348e+10  IssuesEvent  2020-02-03 15:58:14
# 1    2.354159e+10  IssuesEvent  2022-08-20 13:32:35
# 2    2.655708e+10  IssuesEvent  2023-01-20 12:58:50
# 3    2.656401e+10  IssuesEvent  2023-01-20 18:19:32
# 4    2.656403e+10  IssuesEvent  2023-01-20 18:21:07
# ..            ...          ...                  ...
# 717  1.225663e+10  IssuesEvent  2020-05-06 12:25:53
# 718  1.226098e+10  IssuesEvent  2020-05-06 19:15:06
# 719  2.060379e+10  IssuesEvent  2022-03-06 17:19:57
# 720  2.060510e+10  IssuesEvent  2022-03-06 21:18:43
# 721  2.060510e+10  IssuesEvent  2022-03-06 21:18:56
#
#                                            repo  \
# 0                   mit-cml/appinventor-sources
# 1                Eonasdan/static-site-generator
# 2               Automattic/woocommerce-services
# 3    department-of-veterans-affairs/va.gov-team
# 4    department-of-veterans-affairs/va.gov-team
# ..                                          ...
# 717          wordpress-mobile/WordPress-Android
# 718                             goharbor/harbor
# 719                      KinsonDigital/Velaptor
# 720                    hackforla/expunge-assist
# 721                    hackforla/expunge-assist
#
#                                               repo_url    action  \
# 0    https://api.github.com/repos/mit-cml/appinvent...    opened
# 1    https://api.github.com/repos/Eonasdan/static-s...    closed
# 2    https://api.github.com/repos/Automattic/woocom...    closed
# 3    https://api.github.com/repos/department-of-vet...    closed
# 4    https://api.github.com/repos/department-of-vet...    closed
# ..                                                 ...       ...
# 717  https://api.github.com/repos/wordpress-mobile/...    closed
# 718       https://api.github.com/repos/goharbor/harbor  reopened
# 719  https://api.github.com/repos/KinsonDigital/Vel...    opened
# 720  https://api.github.com/repos/hackforla/expunge...    closed
# 721  https://api.github.com/repos/hackforla/expunge...  reopened
#
#                                                  title  \
# 0            Block definitions should declare variants
# 1                                       Editor toast.
# 2    Warning (class-wc-connect-taxjar-integration.p...
# 3    PagerDuty should include Salesforce as an exte...
# 4      Investigate lift for abstracting error handling
# ..                                                 ...
# 717  Remove usages of Coroutine's GlobalScope in St...
# 718  docker login error due to key format on centos...
# 719                         🚧Remove Mouse Scroll Speed
# 720                           review dependabot alerts
# 721                           review dependabot alerts
#
#                                                 labels  \
# 0    affects: master help wanted issue: noted for f...
# 1            Type: Tech Debt Priority: Low Area: Build
# 2                      [Pri] Low [Type] Technical Debt
# 3    tech-debt needs-info needs-review low priority...
# 4    discovery tech-debt low priority platform-cop-...
# ..                                                 ...
# 717             Tech debt [Pri] Low [Type] Enhancement
# 718                             kind/debt priority/low
# 719                             tech debt low priority
# 720  role: development priority: low tech debt feat...
# 721  role: development priority: low tech debt feat...
#
#                                                   body
# 0    **Describe the issue**\r\n\r\nCurrently, we de...
# 1    Need to make a function to allow custom messag...
# 2    Warning: Trying to access array offset on valu...
# 3    ## Background\n\nThis Slack thread has more de...
# 4    ## Background\r\n\r\nIn VSP BE engineering dis...
# ..                                                 ...
# 717  `GlobalScope.launch(..)` is used in some of th...
# 718  If you are reporting a problem, please make su...
# 719  ### I have done the items below . . .\n\n- [X]...
# 720  See which issues are critical and resolve them...
# 721  See which issues are critical and resolve them...
#
# [722 rows x 9 columns]

# %%
debt.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# low priority preview tech debt                         38
# priority: low type: technical debt                     33
# low-priority technical debt                            20
# Priority: Low Type: Technical debt                     17
# area / backend priority / low type / technical ...     16
# low priority tech debt                                 14
# tech debt low priority preview                         13
# consensus priority low technical debt                  13
# Priority: Low Tech Debt                                12
# Priority: Low Type: Technical Debt                     12
# low priority Tech Debt                                 10
# Priority: Low Tech Debt :hammer_and_wrench:             8
# [Pri] Low [Type] Technical Debt                         7
# area / devOps priority / low type / technical debt      6
# technical debt low-prio                                 6
# area / database priority / low type / technical...      6
# priority:low technical debt                             5
# C: Chain Registry C: Contract Registry C: Hashi...      5
# Chain Registry Contract Reg DocOps Epic Hashico...      5
# low priority tech-debt                                  5
# area / nova priority / low type / technical debt        5
# tech debt low priority                                  5
# meta: codeclimate meta: tech-debt priority: low...      5
# priority: low tech-debt                                 4
# Low Priority Tech Debt ui ux                            4
# Tech Debt low priority                                  4
# low priority technical debt                             4
# Priority: Low [Type] Technical Debt                     4
# low priority preview tech debt 📝documentation/p...      4
# debt frontend low priority                              4
# enhancement Technical Debt priority-low                 4
# area / frontend priority / low type / technical...      4
# priority/low refactoring ooni/probe-engine tech...      4
# Category: Technical Debt Priority: Low                  4
# kind: ux debt priority: low                             4
# role: development priority: low tech debt featu...      3
# priority / low type / technical debt area / nova        3
# Priority: Low technical debt                            3
# API good first issue priority - low tech-debt           3
# pipeline tech-debt Low Priority                         3
# Tech Debt help wanted low priority ready                3
# low-priority technical-debt                             3
# priority-low status-ready type-technical-debt           3
# good first issue type: technical debt priority:...      3
# area / API priority / low type / technical debt         3
# config low priority organizational tech debt            3
# area/debt priority/low                                  3
# priority / low area / devOps type / technical debt      3
# low priority low complexity task tech debt              2
# bug priority - low tech-debt                            2

# %%
# Dataset with debt and the given priority
debt_file_name = f"csv/{file_name}_with_td.csv"
debt.to_csv(debt_file_name)

# %%
# To labels
priority.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# enhancement low priority                             5496
# low priority                                         5485
# bug low priority                                     2798
# Low Priority                                         2732
# pri:low pri:lowest                                   2692
# Priority: Low                                        2504
# priority: low                                        1191
# Priority: Low Type: Enhancement                      1155
# bug priority: low                                    1154
# auto-migrated Priority-Low Type-Enhancement          1150
# low-priority                                         1140
# enhancement low-priority                             1116
# enhancement priority:low                             1021
# enhancement priority: low                             968
# auto-migrated Priority-Low Type-Defect                889
# priority:low                                          829
# Low priority                                          741
# pri:lowest pri:low                                    725
# Being Redone Low Priority                             705
# Priority: Low Type: Bug                               674
# enhancement Low Priority                              673
# Coverity bug priority: low                            637
# Low Priority enhancement                              602
# priority.low type.story                               591
# priority-low                                          585
# feature low priority                                  565
# Priority-Low Type-Enhancement                         565
# enhancement priority-low                              565
# bug priority:low                                      553
# bug Low Priority                                      509
# bug low-priority                                      500
# request:new-pkg priority:low                          490
# priority.Low type.Story                               490
# pri:high pri:low pri:lowest                           446
# priority.Low                                          444
# priority.low                                          440
# Priority: Low Status: Available Type: Enhancement     425
# Enhancement Low Priority                              406
# enhancement Priority: Low                             368
# priority low                                          345
# 🟩 priority: low 🚦 status: awaiting triage ✨ goa...    345
# Bug Low Priority                                      333
# Priority: Low enhancement                             315
# low-priority bug                                      308
# Low Priority bug                                      305
# bug Priority: Low                                     300
# low prio                                              284
# Low priority enhancement                              279
# priority::low                                         272
# Priority-Low                                          263

# %%
# Remove debt from the dataset
priority_no_debt = priority[~contains_debt_high_priority].reset_index(drop=True)
priority_no_debt.reset_index(drop=True, inplace=True)
priority_no_debt
# Out:
#                   id         type           created_at  \
# 0       1.141755e+10  IssuesEvent  2020-02-03 00:02:50
# 1       1.141766e+10  IssuesEvent  2020-02-03 00:46:42
# 2       1.141777e+10  IssuesEvent  2020-02-03 01:25:06
# 3       1.141780e+10  IssuesEvent  2020-02-03 01:34:56
# 4       1.141786e+10  IssuesEvent  2020-02-03 01:52:04
# ...              ...          ...                  ...
# 199753  2.060586e+10  IssuesEvent  2022-03-06 23:45:23
# 199754  7.334740e+09  IssuesEvent  2018-03-06 00:10:40
# 199755  7.334876e+09  IssuesEvent  2018-03-06 00:53:49
# 199756  7.335047e+09  IssuesEvent  2018-03-06 01:48:07
# 199757  7.335050e+09  IssuesEvent  2018-03-06 01:49:10
#
#                              repo  \
# 0          poissonconsulting/term
# 1             WordPress/gutenberg
# 2               MarkBind/markbind
# 3               MarkBind/markbind
# 4          poissonconsulting/term
# ...                           ...
# 199753  bounswe/bounswe2022group1
# 199754            hoodedice/notes
# 199755  zephyrproject-rtos/zephyr
# 199756         uwnrg/minotaur-cpp
# 199757         uwnrg/minotaur-cpp
#
#                                                  repo_url    action  \
# 0       https://api.github.com/repos/poissonconsulting...    opened
# 1        https://api.github.com/repos/WordPress/gutenberg    closed
# 2          https://api.github.com/repos/MarkBind/markbind  reopened
# 3          https://api.github.com/repos/MarkBind/markbind    closed
# 4       https://api.github.com/repos/poissonconsulting...    closed
# ...                                                   ...       ...
# 199753  https://api.github.com/repos/bounswe/bounswe20...    closed
# 199754       https://api.github.com/repos/hoodedice/notes    opened
# 199755  https://api.github.com/repos/zephyrproject-rto...    closed
# 199756    https://api.github.com/repos/uwnrg/minotaur-cpp    closed
# 199757    https://api.github.com/repos/uwnrg/minotaur-cpp    closed
#
#                                                     title  \
# 0             Document levels of validation in vld_term()
# 1                       Z-index issue using Classic block
# 2                   Indicate the language of a code block
# 3          Use one attribute name for header, title, name
# 4             Document levels of validation in vld_term()
# ...                                                   ...
# 199753                        Editing Navigator of  Wiki
# 199754                           Check if passwords match
# 199755  Add doc to samples/bluetooth/mesh & samples/bl...
# 199756                   Fix the photo in about dialog xd
# 199757  Move Record Video/Screenshot and camera select...
#
#                                                    labels  \
# 0       Difficulty: 1 Novice Effort: 1 Low Priority: 2...
# 1               [Block] Classic [Priority] Low [Type] Bug
# 2                        c.Enhancement f-CodeBlocks p.Low
# 3                                 a-AuthorUsability p.Low
# 4       Difficulty: 1 Novice Effort: 1 Low Priority: 2...
# ...                                                   ...
# 199753                                       Priority-Low
# 199754                           enhancement low priority
# 199755  area: Bluetooth area: Documentation area: Samp...
# 199756                           enhancement low priority
# 199757                           enhancement low priority
#
#                                                      body
# 0              As this is what other functions reference.
# 1       Selecting a link in the classic block and havi...
# 2       **Tell us about your environment**\r\n\r\n* **...
# 3       May be better to choose one of the three and u...
# 4              As this is what other functions reference.
# ...                                                   ...
# 199753  The navigator of the wiki should be edited and...
# 199754  JavaScript code (or see if possible without) t...
# 199755  We should document what exactly the sample is ...
# 199756                                                NaN
# 199757            that can be opened from a dropdown menu
#
# [199758 rows x 9 columns]

# %%
# Sanity check
should_be_empty=priority_no_debt[priority_no_debt['labels'].str.contains(technical_debt_regex, case=False, na=False)]
should_be_empty
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body]
# Index: []

# %%
# Splitting the DataFrame
test_df = priority_no_debt.sample(frac=0.05, random_state=1)  # Select 5% of the data
priority_df = priority_no_debt.drop(test_df.index) 
priority_df.reset_index(drop=True, inplace=True)
priority_df
# Out:
#                   id         type           created_at  \
# 0       1.141755e+10  IssuesEvent  2020-02-03 00:02:50
# 1       1.141766e+10  IssuesEvent  2020-02-03 00:46:42
# 2       1.141777e+10  IssuesEvent  2020-02-03 01:25:06
# 3       1.141780e+10  IssuesEvent  2020-02-03 01:34:56
# 4       1.141786e+10  IssuesEvent  2020-02-03 01:52:04
# ...              ...          ...                  ...
# 189765  2.060584e+10  IssuesEvent  2022-03-06 23:40:48
# 189766  2.060586e+10  IssuesEvent  2022-03-06 23:45:23
# 189767  7.334740e+09  IssuesEvent  2018-03-06 00:10:40
# 189768  7.334876e+09  IssuesEvent  2018-03-06 00:53:49
# 189769  7.335047e+09  IssuesEvent  2018-03-06 01:48:07
#
#                                                repo  \
# 0                            poissonconsulting/term
# 1                               WordPress/gutenberg
# 2                                 MarkBind/markbind
# 3                                 MarkBind/markbind
# 4                            poissonconsulting/term
# ...                                             ...
# 189765  CafeteriaGuild/DeepMobLearning-Refabricated
# 189766                    bounswe/bounswe2022group1
# 189767                              hoodedice/notes
# 189768                    zephyrproject-rtos/zephyr
# 189769                           uwnrg/minotaur-cpp
#
#                                                  repo_url    action  \
# 0       https://api.github.com/repos/poissonconsulting...    opened
# 1        https://api.github.com/repos/WordPress/gutenberg    closed
# 2          https://api.github.com/repos/MarkBind/markbind  reopened
# 3          https://api.github.com/repos/MarkBind/markbind    closed
# 4       https://api.github.com/repos/poissonconsulting...    closed
# ...                                                   ...       ...
# 189765  https://api.github.com/repos/CafeteriaGuild/De...    closed
# 189766  https://api.github.com/repos/bounswe/bounswe20...    closed
# 189767       https://api.github.com/repos/hoodedice/notes    opened
# 189768  https://api.github.com/repos/zephyrproject-rto...    closed
# 189769    https://api.github.com/repos/uwnrg/minotaur-cpp    closed
#
#                                                     title  \
# 0             Document levels of validation in vld_term()
# 1                       Z-index issue using Classic block
# 2                   Indicate the language of a code block
# 3          Use one attribute name for header, title, name
# 4             Document levels of validation in vld_term()
# ...                                                   ...
# 189765   Thunderstrike during Trials destroying the loot.
# 189766                        Editing Navigator of  Wiki
# 189767                           Check if passwords match
# 189768  Add doc to samples/bluetooth/mesh & samples/bl...
# 189769                   Fix the photo in about dialog xd
#
#                                                    labels  \
# 0       Difficulty: 1 Novice Effort: 1 Low Priority: 2...
# 1               [Block] Classic [Priority] Low [Type] Bug
# 2                        c.Enhancement f-CodeBlocks p.Low
# 3                                 a-AuthorUsability p.Low
# 4       Difficulty: 1 Novice Effort: 1 Low Priority: 2...
# ...                                                   ...
# 189765                           enhancement Low Priority
# 189766                                       Priority-Low
# 189767                           enhancement low priority
# 189768  area: Bluetooth area: Documentation area: Samp...
# 189769                           enhancement low priority
#
#                                                      body
# 0              As this is what other functions reference.
# 1       Selecting a link in the classic block and havi...
# 2       **Tell us about your environment**\r\n\r\n* **...
# 3       May be better to choose one of the three and u...
# 4              As this is what other functions reference.
# ...                                                   ...
# 189765  When you run the trial, it will set areas on f...
# 189766  The navigator of the wiki should be edited and...
# 189767  JavaScript code (or see if possible without) t...
# 189768  We should document what exactly the sample is ...
# 189769                                                NaN
#
# [189770 rows x 9 columns]

# %%
test_df.reset_index(drop=True, inplace=True)
test_df
# Out:
#                 id         type           created_at  \
# 0     2.152570e+10  IssuesEvent  2022-04-28 18:12:36
# 1     4.586743e+09  IssuesEvent  2016-09-20 00:21:35
# 2     1.717407e+10  IssuesEvent  2021-07-15 09:12:40
# 3     6.599272e+09  IssuesEvent  2017-09-16 17:33:26
# 4     1.085615e+10  IssuesEvent  2019-11-13 19:57:07
# ...            ...          ...                  ...
# 9983  6.413069e+09  IssuesEvent  2017-08-08 06:22:44
# 9984  8.270949e+09  IssuesEvent  2018-09-16 01:37:51
# 9985  3.933559e+09  IssuesEvent  2016-04-25 19:33:26
# 9986  2.050944e+10  IssuesEvent  2022-03-01 03:44:39
# 9987  2.669658e+10  IssuesEvent  2023-01-27 10:52:34
#
#                                   repo  \
# 0               Matocolotoe/Skript-1.8
# 1                        koding/koding
# 2     FunProjectsForSoul/TractorMoving
# 3                     Caleydo/lineupjs
# 4              INN/umbrella-citylimits
# ...                                ...
# 9983           projectcalico/libcalico
# 9984             der-On/XPlane2Blender
# 9985                 ghutchis/avogadro
# 9986             ZcashFoundation/zebra
# 9987                 dodona-edu/dodona
#
#                                                repo_url    action  \
# 0     https://api.github.com/repos/Matocolotoe/Skrip...  reopened
# 1            https://api.github.com/repos/koding/koding    opened
# 2     https://api.github.com/repos/FunProjectsForSou...    opened
# 3         https://api.github.com/repos/Caleydo/lineupjs    opened
# 4     https://api.github.com/repos/INN/umbrella-city...    opened
# ...                                                 ...       ...
# 9983  https://api.github.com/repos/projectcalico/lib...    closed
# 9984  https://api.github.com/repos/der-On/XPlane2Ble...    closed
# 9985     https://api.github.com/repos/ghutchis/avogadro    closed
# 9986  https://api.github.com/repos/ZcashFoundation/z...    closed
# 9987     https://api.github.com/repos/dodona-edu/dodona    opened
#
#                                                   title  \
# 0                          SkLimeQuery 1.8 doesn't work
# 1     There should be some space between progress ba...
# 2                  [FEATURE] Initial information input.
# 3     As a <user>, I want to <aggregate all groups> ...
# 4                         Search Box hover/focus styles
# ...                                                 ...
# 9983  Specifying etcd endpoints doesn't work with fqdns
# 9984  Test Regex needs to be able to put in unescape...
# 9985                    Linux crash with multiple views
# 9986  Automatically support references in Zebra trai...
# 9987     Show exercise visibility on exercise info page
#
#                                                  labels  \
# 0                                    bug priority : low
# 1     A-Bug Component-Dashboard Component-UX Priorit...
# 2       priority: low status: backlog type: enhancement
# 3                        priority: low type: user story
# 4                            Estimate: <2 Priority: Low
# ...                                                 ...
# 9983         help wanted kind/enhancement Priority: Low
# 9984                           Improvement priority low
# 9985  auto-migrated low priority Multiple Views v_1.1.0
# 9986  A-rust C-enhancement C-cleanup P-Low :snowflak...
# 9987                           low priority enhancement
#
#                                                    body
# 0     ### Skript Version\n\n![image](https://user-im...
# 1     ## Current Behavior\r\n![image](https://cloud....
# 2     **Description of functionality**\r\nInitial in...
# 3     **Definition of Done**\r\nFlag that allows the...
# 4     Copied from #113 \r\n\r\nthe search box in the...
# ...                                                 ...
# 9983  I'm calling calicoctl with:\n\n```\nETCD_ENDPO...
# 9984  Currently something like export_path.*\Custom ...
# 9985  Upon attempting to see another view (from the ...
# 9986  ## Motivation\r\n\r\nIf we made Zebra traits l...
# 9987                                                NaN
#
# [9988 rows x 9 columns]

# %%
test_df.labels.value_counts().to_frame()[:50]
# Out:
#                                                    count
# labels
# low priority                                         316
# enhancement low priority                             255
# Low Priority                                         148
# bug low priority                                     136
# pri:low pri:lowest                                   127
# Priority: Low                                        127
# auto-migrated Priority-Low Type-Enhancement           73
# priority: low                                         65
# Priority: Low Type: Enhancement                       62
# bug priority: low                                     61
# low-priority                                          55
# enhancement priority: low                             53
# Coverity bug priority: low                            43
# enhancement low-priority                              42
# enhancement priority:low                              42
# Low priority                                          38
# pri:lowest pri:low                                    37
# priority:low                                          36
# auto-migrated Priority-Low Type-Defect                36
# priority-low                                          35
# enhancement Low Priority                              34
# Being Redone Low Priority                             34
# Low Priority enhancement                              32
# bug Low Priority                                      30
# Priority: Low Type: Bug                               30
# bug priority:low                                      29
# priority.Low type.Story                               29
# priority.Low                                          29
# Priority: Low Status: Available Type: Enhancement     27
# Enhancement Low Priority                              27
# low-priority bug                                      26
# priority.low type.story                               26
# bug low-priority                                      24
# feature low priority                                  24
# priority low                                          23
# enhancement priority-low                              22
# pri:high pri:low pri:lowest                           21
# priority.low                                          20
# request:new-pkg priority:low                          20
# feature priority: low                                 19
# Bug Low Priority                                      19
# prio:low                                              18
# enhancement prio:low                                  17
# Priority: Low enhancement                             17
# priority::low                                         16
# Low Priority bug                                      15
# Priority-Low Type-Enhancement                         15
# enhancement Priority: Low                             15
# Priority: Low Type: Feature                           14
# enhancement prio-low                                  14

# %%
# Convert to csv
priority_file_name = f"csv/{file_name}_no_td.csv"
priority_df.to_csv(priority_file_name)

# %%
test_set_file_name = f"csv/{file_name}_test_set.csv"
test_df.to_csv(test_set_file_name)

# %%
pri = pd.read_csv(priority_file_name, index_col=0)
pri
# Out:
#                   id         type           created_at  \
# 0       1.141755e+10  IssuesEvent  2020-02-03 00:02:50
# 1       1.141766e+10  IssuesEvent  2020-02-03 00:46:42
# 2       1.141777e+10  IssuesEvent  2020-02-03 01:25:06
# 3       1.141780e+10  IssuesEvent  2020-02-03 01:34:56
# 4       1.141786e+10  IssuesEvent  2020-02-03 01:52:04
# ...              ...          ...                  ...
# 189765  2.060584e+10  IssuesEvent  2022-03-06 23:40:48
# 189766  2.060586e+10  IssuesEvent  2022-03-06 23:45:23
# 189767  7.334740e+09  IssuesEvent  2018-03-06 00:10:40
# 189768  7.334876e+09  IssuesEvent  2018-03-06 00:53:49
# 189769  7.335047e+09  IssuesEvent  2018-03-06 01:48:07
#
#                                                repo  \
# 0                            poissonconsulting/term
# 1                               WordPress/gutenberg
# 2                                 MarkBind/markbind
# 3                                 MarkBind/markbind
# 4                            poissonconsulting/term
# ...                                             ...
# 189765  CafeteriaGuild/DeepMobLearning-Refabricated
# 189766                    bounswe/bounswe2022group1
# 189767                              hoodedice/notes
# 189768                    zephyrproject-rtos/zephyr
# 189769                           uwnrg/minotaur-cpp
#
#                                                  repo_url    action  \
# 0       https://api.github.com/repos/poissonconsulting...    opened
# 1        https://api.github.com/repos/WordPress/gutenberg    closed
# 2          https://api.github.com/repos/MarkBind/markbind  reopened
# 3          https://api.github.com/repos/MarkBind/markbind    closed
# 4       https://api.github.com/repos/poissonconsulting...    closed
# ...                                                   ...       ...
# 189765  https://api.github.com/repos/CafeteriaGuild/De...    closed
# 189766  https://api.github.com/repos/bounswe/bounswe20...    closed
# 189767       https://api.github.com/repos/hoodedice/notes    opened
# 189768  https://api.github.com/repos/zephyrproject-rto...    closed
# 189769    https://api.github.com/repos/uwnrg/minotaur-cpp    closed
#
#                                                     title  \
# 0             Document levels of validation in vld_term()
# 1                       Z-index issue using Classic block
# 2                   Indicate the language of a code block
# 3          Use one attribute name for header, title, name
# 4             Document levels of validation in vld_term()
# ...                                                   ...
# 189765   Thunderstrike during Trials destroying the loot.
# 189766                        Editing Navigator of  Wiki
# 189767                           Check if passwords match
# 189768  Add doc to samples/bluetooth/mesh & samples/bl...
# 189769                   Fix the photo in about dialog xd
#
#                                                    labels  \
# 0       Difficulty: 1 Novice Effort: 1 Low Priority: 2...
# 1               [Block] Classic [Priority] Low [Type] Bug
# 2                        c.Enhancement f-CodeBlocks p.Low
# 3                                 a-AuthorUsability p.Low
# 4       Difficulty: 1 Novice Effort: 1 Low Priority: 2...
# ...                                                   ...
# 189765                           enhancement Low Priority
# 189766                                       Priority-Low
# 189767                           enhancement low priority
# 189768  area: Bluetooth area: Documentation area: Samp...
# 189769                           enhancement low priority
#
#                                                      body
# 0              As this is what other functions reference.
# 1       Selecting a link in the classic block and havi...
# 2       **Tell us about your environment**\r\n\r\n* **...
# 3       May be better to choose one of the three and u...
# 4              As this is what other functions reference.
# ...                                                   ...
# 189765  When you run the trial, it will set areas on f...
# 189766  The navigator of the wiki should be edited and...
# 189767  JavaScript code (or see if possible without) t...
# 189768  We should document what exactly the sample is ...
# 189769                                                NaN
#
# [189770 rows x 9 columns]

# %%
test_set = pd.read_csv(test_set_file_name, index_col=0)
test_set
# Out:
#                 id         type           created_at  \
# 0     2.152570e+10  IssuesEvent  2022-04-28 18:12:36
# 1     4.586743e+09  IssuesEvent  2016-09-20 00:21:35
# 2     1.717407e+10  IssuesEvent  2021-07-15 09:12:40
# 3     6.599272e+09  IssuesEvent  2017-09-16 17:33:26
# 4     1.085615e+10  IssuesEvent  2019-11-13 19:57:07
# ...            ...          ...                  ...
# 9983  6.413069e+09  IssuesEvent  2017-08-08 06:22:44
# 9984  8.270949e+09  IssuesEvent  2018-09-16 01:37:51
# 9985  3.933559e+09  IssuesEvent  2016-04-25 19:33:26
# 9986  2.050944e+10  IssuesEvent  2022-03-01 03:44:39
# 9987  2.669658e+10  IssuesEvent  2023-01-27 10:52:34
#
#                                   repo  \
# 0               Matocolotoe/Skript-1.8
# 1                        koding/koding
# 2     FunProjectsForSoul/TractorMoving
# 3                     Caleydo/lineupjs
# 4              INN/umbrella-citylimits
# ...                                ...
# 9983           projectcalico/libcalico
# 9984             der-On/XPlane2Blender
# 9985                 ghutchis/avogadro
# 9986             ZcashFoundation/zebra
# 9987                 dodona-edu/dodona
#
#                                                repo_url    action  \
# 0     https://api.github.com/repos/Matocolotoe/Skrip...  reopened
# 1            https://api.github.com/repos/koding/koding    opened
# 2     https://api.github.com/repos/FunProjectsForSou...    opened
# 3         https://api.github.com/repos/Caleydo/lineupjs    opened
# 4     https://api.github.com/repos/INN/umbrella-city...    opened
# ...                                                 ...       ...
# 9983  https://api.github.com/repos/projectcalico/lib...    closed
# 9984  https://api.github.com/repos/der-On/XPlane2Ble...    closed
# 9985     https://api.github.com/repos/ghutchis/avogadro    closed
# 9986  https://api.github.com/repos/ZcashFoundation/z...    closed
# 9987     https://api.github.com/repos/dodona-edu/dodona    opened
#
#                                                   title  \
# 0                          SkLimeQuery 1.8 doesn't work
# 1     There should be some space between progress ba...
# 2                  [FEATURE] Initial information input.
# 3     As a <user>, I want to <aggregate all groups> ...
# 4                         Search Box hover/focus styles
# ...                                                 ...
# 9983  Specifying etcd endpoints doesn't work with fqdns
# 9984  Test Regex needs to be able to put in unescape...
# 9985                    Linux crash with multiple views
# 9986  Automatically support references in Zebra trai...
# 9987     Show exercise visibility on exercise info page
#
#                                                  labels  \
# 0                                    bug priority : low
# 1     A-Bug Component-Dashboard Component-UX Priorit...
# 2       priority: low status: backlog type: enhancement
# 3                        priority: low type: user story
# 4                            Estimate: <2 Priority: Low
# ...                                                 ...
# 9983         help wanted kind/enhancement Priority: Low
# 9984                           Improvement priority low
# 9985  auto-migrated low priority Multiple Views v_1.1.0
# 9986  A-rust C-enhancement C-cleanup P-Low :snowflak...
# 9987                           low priority enhancement
#
#                                                    body
# 0     ### Skript Version\n\n![image](https://user-im...
# 1     ## Current Behavior\r\n![image](https://cloud....
# 2     **Description of functionality**\r\nInitial in...
# 3     **Definition of Done**\r\nFlag that allows the...
# 4     Copied from #113 \r\n\r\nthe search box in the...
# ...                                                 ...
# 9983  I'm calling calicoctl with:\n\n```\nETCD_ENDPO...
# 9984  Currently something like export_path.*\Custom ...
# 9985  Upon attempting to see another view (from the ...
# 9986  ## Motivation\r\n\r\nIf we made Zebra traits l...
# 9987                                                NaN
#
# [9988 rows x 9 columns]

# %%
debt = pd.read_csv(debt_file_name, index_col=0)
debt
# Out:
#                id         type           created_at  \
# 0    1.142348e+10  IssuesEvent  2020-02-03 15:58:14
# 1    2.354159e+10  IssuesEvent  2022-08-20 13:32:35
# 2    2.655708e+10  IssuesEvent  2023-01-20 12:58:50
# 3    2.656401e+10  IssuesEvent  2023-01-20 18:19:32
# 4    2.656403e+10  IssuesEvent  2023-01-20 18:21:07
# ..            ...          ...                  ...
# 717  1.225663e+10  IssuesEvent  2020-05-06 12:25:53
# 718  1.226098e+10  IssuesEvent  2020-05-06 19:15:06
# 719  2.060379e+10  IssuesEvent  2022-03-06 17:19:57
# 720  2.060510e+10  IssuesEvent  2022-03-06 21:18:43
# 721  2.060510e+10  IssuesEvent  2022-03-06 21:18:56
#
#                                            repo  \
# 0                   mit-cml/appinventor-sources
# 1                Eonasdan/static-site-generator
# 2               Automattic/woocommerce-services
# 3    department-of-veterans-affairs/va.gov-team
# 4    department-of-veterans-affairs/va.gov-team
# ..                                          ...
# 717          wordpress-mobile/WordPress-Android
# 718                             goharbor/harbor
# 719                      KinsonDigital/Velaptor
# 720                    hackforla/expunge-assist
# 721                    hackforla/expunge-assist
#
#                                               repo_url    action  \
# 0    https://api.github.com/repos/mit-cml/appinvent...    opened
# 1    https://api.github.com/repos/Eonasdan/static-s...    closed
# 2    https://api.github.com/repos/Automattic/woocom...    closed
# 3    https://api.github.com/repos/department-of-vet...    closed
# 4    https://api.github.com/repos/department-of-vet...    closed
# ..                                                 ...       ...
# 717  https://api.github.com/repos/wordpress-mobile/...    closed
# 718       https://api.github.com/repos/goharbor/harbor  reopened
# 719  https://api.github.com/repos/KinsonDigital/Vel...    opened
# 720  https://api.github.com/repos/hackforla/expunge...    closed
# 721  https://api.github.com/repos/hackforla/expunge...  reopened
#
#                                                  title  \
# 0            Block definitions should declare variants
# 1                                       Editor toast.
# 2    Warning (class-wc-connect-taxjar-integration.p...
# 3    PagerDuty should include Salesforce as an exte...
# 4      Investigate lift for abstracting error handling
# ..                                                 ...
# 717  Remove usages of Coroutine's GlobalScope in St...
# 718  docker login error due to key format on centos...
# 719                         🚧Remove Mouse Scroll Speed
# 720                           review dependabot alerts
# 721                           review dependabot alerts
#
#                                                 labels  \
# 0    affects: master help wanted issue: noted for f...
# 1            Type: Tech Debt Priority: Low Area: Build
# 2                      [Pri] Low [Type] Technical Debt
# 3    tech-debt needs-info needs-review low priority...
# 4    discovery tech-debt low priority platform-cop-...
# ..                                                 ...
# 717             Tech debt [Pri] Low [Type] Enhancement
# 718                             kind/debt priority/low
# 719                             tech debt low priority
# 720  role: development priority: low tech debt feat...
# 721  role: development priority: low tech debt feat...
#
#                                                   body
# 0    **Describe the issue**\r\n\r\nCurrently, we de...
# 1    Need to make a function to allow custom messag...
# 2    Warning: Trying to access array offset on valu...
# 3    ## Background\n\nThis Slack thread has more de...
# 4    ## Background\r\n\r\nIn VSP BE engineering dis...
# ..                                                 ...
# 717  `GlobalScope.launch(..)` is used in some of th...
# 718  If you are reporting a problem, please make su...
# 719  ### I have done the items below . . .\n\n- [X]...
# 720  See which issues are critical and resolve them...
# 721  See which issues are critical and resolve them...
#
# [722 rows x 9 columns]
