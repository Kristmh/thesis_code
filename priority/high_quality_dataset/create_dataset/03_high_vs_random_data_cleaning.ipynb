# %% [markdown]
# # Data cleaning
# We want the class with labels as numerical value and the body with clean text.
#
# This will remove:
# * duplicates
# * NaN entires
# * non english
# * url, html
#
# * make it lowercase
# * combine title and body

# %%
import pandas as pd
import sys
sys.path.append("../../../scripts_shared/")
from preprocess_text import preprocess_text

# %%
# Read CSV into a dataframe
high_priority = pd.read_csv("csv/high_priority_min_repos.csv", index_col=0)
not_high_priority = pd.read_csv("csv/random_per_repo_no_td.csv", index_col=0)
high_priority
# Out:
#                   id         type           created_at  \
# 0       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3       1.141797e+10  IssuesEvent  2020-02-03 02:25:22
# 4       1.141798e+10  IssuesEvent  2020-02-03 02:28:57
# 8       1.141825e+10  IssuesEvent  2020-02-03 03:46:09
# 10      1.141832e+10  IssuesEvent  2020-02-03 04:04:30
# ...              ...          ...                  ...
# 242894  7.334777e+09  IssuesEvent  2018-03-06 00:22:10
# 242898  7.334886e+09  IssuesEvent  2018-03-06 00:56:47
# 242902  7.334924e+09  IssuesEvent  2018-03-06 01:08:55
# 242903  7.334924e+09  IssuesEvent  2018-03-06 01:09:12
# 242907  7.335039e+09  IssuesEvent  2018-03-06 01:45:34
#
#                                      repo  \
# 0                      openmsupply/mobile
# 3               unitystation/unitystation
# 4                         qlcchain/go-qlc
# 8       ballerina-platform/ballerina-lang
# 10                            zulip/zulip
# ...                                   ...
# 242894         StrangeLoopGames/EcoIssues
# 242898         StrangeLoopGames/EcoIssues
# 242902         StrangeLoopGames/EcoIssues
# 242903         StrangeLoopGames/EcoIssues
# 242907                    xcat2/xcat-core
#
#                                                  repo_url  action  \
# 0         https://api.github.com/repos/openmsupply/mobile  closed
# 3       https://api.github.com/repos/unitystation/unit...  closed
# 4            https://api.github.com/repos/qlcchain/go-qlc  closed
# 8       https://api.github.com/repos/ballerina-platfor...  closed
# 10               https://api.github.com/repos/zulip/zulip  closed
# ...                                                   ...     ...
# 242894  https://api.github.com/repos/StrangeLoopGames/...  closed
# 242898  https://api.github.com/repos/StrangeLoopGames/...  closed
# 242902  https://api.github.com/repos/StrangeLoopGames/...  closed
# 242903  https://api.github.com/repos/StrangeLoopGames/...  closed
# 242907       https://api.github.com/repos/xcat2/xcat-core  closed
#
#                                                     title  \
# 0                      Auto-log out after some time frame
# 3                  Escape shuttle reaches ludicrous speed
# 4                  constructing  virtual router structure
# 8           Create local variable code action breaks code
# 10      Add rate limiting to the login and password ch...
# ...                                                   ...
# 242894  Scoring items and Industry Items (that will br...
# 242898           USER ISSUE: Currency exchanges dont work
# 242902             USER ISSUE: Unable to set up contracts
# 242903       Meteor hit - Can no longer join server 6.4.1
# 242907  error message improvement when adding users in...
#
#                                                    labels  \
# 0       Docs: not needed Effort: small Feature Module:...
# 3                                   Bug High Priority lol
# 4       Priority: High Type: Enhancement Type: Mainten...
# 8       Area/Tooling Component/LanguageServer Points/1...
# 10      area: authentication enhancement good first is...
# ...                                                   ...
# 242894                                      High Priority
# 242898                                      High Priority
# 242902                                      High Priority
# 242903                                      High Priority
# 242907      priority:high sprint1 status:pending type:bug
#
#                                                      body
# 0       ## Is your feature request related to a proble...
# 3       ## Description\r\n\r\nEscape shuttle accelerat...
# 4                                                    \r\n
# 8       <img width="558" alt="Screen Shot 2019-10-29 a...
# 10      Zulip historically has relied on strong passwo...
# ...                                                   ...
# 242894  we had this information in previous release 6....
# 242898  **Version:** 0.7.0.8 beta\r\n\r\n**Steps to Re...
# 242902  **Version:** 0.6.4.2 alpha\r\n\r\n**Steps to R...
# 242903  Just had the meteor hit on our server and now ...
# 242907  Problem statement: error message when adding x...
#
# [61374 rows x 9 columns]

# %%
contains_stale = not_high_priority['labels'].str.contains("stale", case=False, na=False)
not_high_priority= not_high_priority[~contains_stale].reset_index(drop=True)
not_high_priority.reset_index(drop=True, inplace=True)
not_high_priority
# Out:
#                   id         type           created_at  \
# 0       1.141785e+10  IssuesEvent  2020-02-03 01:49:58
# 1       1.141798e+10  IssuesEvent  2020-02-03 02:28:16
# 2       1.141799e+10  IssuesEvent  2020-02-03 02:30:32
# 3       1.141799e+10  IssuesEvent  2020-02-03 02:31:03
# 4       1.141774e+10  IssuesEvent  2020-02-03 01:15:24
# ...              ...          ...                  ...
# 641369  7.335053e+09  IssuesEvent  2018-03-06 01:50:25
# 641370  7.335070e+09  IssuesEvent  2018-03-06 01:55:53
# 641371  7.335074e+09  IssuesEvent  2018-03-06 01:57:10
# 641372  7.334815e+09  IssuesEvent  2018-03-06 00:34:07
# 641373  7.334824e+09  IssuesEvent  2018-03-06 00:36:39
#
#                              repo  \
# 0              openmsupply/mobile
# 1              openmsupply/mobile
# 2              openmsupply/mobile
# 3              openmsupply/mobile
# 4       unitystation/unitystation
# ...                           ...
# 641369            xcat2/xcat-core
# 641370            xcat2/xcat-core
# 641371            xcat2/xcat-core
# 641372              dart-lang/sdk
# 641373              dart-lang/sdk
#
#                                                  repo_url  action  \
# 0         https://api.github.com/repos/openmsupply/mobile  opened
# 1         https://api.github.com/repos/openmsupply/mobile  closed
# 2         https://api.github.com/repos/openmsupply/mobile  closed
# 3         https://api.github.com/repos/openmsupply/mobile  closed
# 4       https://api.github.com/repos/unitystation/unit...  opened
# ...                                                   ...     ...
# 641369       https://api.github.com/repos/xcat2/xcat-core  closed
# 641370       https://api.github.com/repos/xcat2/xcat-core  closed
# 641371       https://api.github.com/repos/xcat2/xcat-core  closed
# 641372         https://api.github.com/repos/dart-lang/sdk  closed
# 641373         https://api.github.com/repos/dart-lang/sdk  closed
#
#                                                     title  \
# 0         Update cash register to use new payment options
# 1                           Add cash register page toggle
# 2                    Add remaining indicator localisation
# 3                                 Enforce indicator types
# 4                             Cargo Console No Categories
# ...                                                   ...
# 641369  [fvt][xcat-inventory] xcat-inventory return su...
# 641370  [fvt] configure ssh in cumulus switch is not s...
# 641371                xCAT database on remote DB server ?
# 641372  Add Dart 2.0 migration stubs to packages that ...
# 641373  Add Dart 2.0 migration stubs to packages that ...
#
#                                                    labels  \
# 0                                                 Feature
# 1       Docs: not needed Effort: small Feature Module:...
# 2                Effort: small Feature Module: indicators
# 3       Effort: medium Feature Module: indicators Prio...
# 4                                               Bug Cargo
# ...                                                   ...
# 641369                    sprint2 status:pending type:bug
# 641370                    sprint2 status:pending type:bug
# 641371                                 type:documentation
# 641372                                       area-library
# 641373                                       area-library
#
#                                                      body
# 0       ## Is your feature request related to a proble...
# 1       ## Is your feature request related to a proble...
# 2       ## Is your feature request related to a proble...
# 3       ## Is your feature request related to a proble...
# 4       ## Description\r\n\r\nCargo console doesn't sh...
# ...                                                   ...
# 641369  when assigning a wrong attirbute to option ``o...
# 641370  Configuring ssh in cumulus switch by ``switchd...
# 641371  Hi \r\n\r\nDoes xCAT support the DB to be exis...
# 641372  Dart 2.0 adds several instance members to a nu...
# 641373  To help with the migration and changes to the ...
#
# [641374 rows x 9 columns]

# %%
# Number or different labels
high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# High Priority                                        1165
# bug high priority                                     786
# Priority: High                                        773
# bug priority: high                                    519
# Priority: High Type: Bug                              388
# Priority: High bug                                    387
# NEXT UPDATE [Priority: HIGH] bug                      364
# high priority                                         343
# [P: HIGH] bug                                         301
# bug P: high S: normal                                 298
# enhancement high priority                             297
# bug Priority: High                                    212
# bug prio-high                                         197
# Type: Bug Priority: High                              196
# browser-firefox engine-gecko ml-needsdiagnosis-...    193
# done priority: High                                   179
# bug done priority: High                               176
# Bug Priority: High                                    168
# enhancement priority: high                            165
# [Priority: HIGH] bug                                  160
# kind/bug priority/high                                157
# High Priority bug                                     149
# [Pri] High [Type] Bug                                 142
# Priority-High                                         140
# Priority - High Type -Task                            133
# priority: high                                        129
# Bug S1 High prio                                      124
# bug high-prio                                         124
# Bug Needed for V2 launch Priority: High               120
# Priority: High Type: Enhancement                      118
# bug high-priority                                     113
# Fixed High Priority                                   112
# Needed for V2 launch Priority: High                   109
# browser-firefox engine-gecko ml-needsdiagnosis-...    109
# browser-firefox engine-gecko ml-needsdiagnosis-...    106
# bug P: high                                           105
# enhancement prio-high                                 105
# 👹Bug Priority: high                                   105
# [P: HIGH] enhancement                                 102
# feature High Priority                                 102
# Felamimail bug high priority                          102
# bug High priority                                     100
# priority/high type/bug                                100
# NEED FAST REVIEW [Priority: HIGH] bug                  99
# bug High Priority                                      98
# priority:high type:bug                                 94
# bug high priority easy                                 90
# Tinebase bug high priority                             89
# Calendar bug high priority                             89
# priority:High                                          88

# %%
high_priority[high_priority["repo"] == "python/mypy"]
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body]
# Index: []

# %%
# Remove mypy from the dataset
high_priority = high_priority[high_priority["repo"] != "python/mypy"]
high_priority = high_priority[high_priority["repo"] != "rust-lang/rust"]
high_priority = high_priority[high_priority["repo"] != "flutter/flutter"]
# reset index
high_priority.reset_index(drop=True, inplace=True)
high_priority
# Out:
#                  id         type           created_at  \
# 0      1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 1      1.141797e+10  IssuesEvent  2020-02-03 02:25:22
# 2      1.141798e+10  IssuesEvent  2020-02-03 02:28:57
# 3      1.141825e+10  IssuesEvent  2020-02-03 03:46:09
# 4      1.141832e+10  IssuesEvent  2020-02-03 04:04:30
# ...             ...          ...                  ...
# 60690  7.334777e+09  IssuesEvent  2018-03-06 00:22:10
# 60691  7.334886e+09  IssuesEvent  2018-03-06 00:56:47
# 60692  7.334924e+09  IssuesEvent  2018-03-06 01:08:55
# 60693  7.334924e+09  IssuesEvent  2018-03-06 01:09:12
# 60694  7.335039e+09  IssuesEvent  2018-03-06 01:45:34
#
#                                     repo  \
# 0                     openmsupply/mobile
# 1              unitystation/unitystation
# 2                        qlcchain/go-qlc
# 3      ballerina-platform/ballerina-lang
# 4                            zulip/zulip
# ...                                  ...
# 60690         StrangeLoopGames/EcoIssues
# 60691         StrangeLoopGames/EcoIssues
# 60692         StrangeLoopGames/EcoIssues
# 60693         StrangeLoopGames/EcoIssues
# 60694                    xcat2/xcat-core
#
#                                                 repo_url  action  \
# 0        https://api.github.com/repos/openmsupply/mobile  closed
# 1      https://api.github.com/repos/unitystation/unit...  closed
# 2           https://api.github.com/repos/qlcchain/go-qlc  closed
# 3      https://api.github.com/repos/ballerina-platfor...  closed
# 4               https://api.github.com/repos/zulip/zulip  closed
# ...                                                  ...     ...
# 60690  https://api.github.com/repos/StrangeLoopGames/...  closed
# 60691  https://api.github.com/repos/StrangeLoopGames/...  closed
# 60692  https://api.github.com/repos/StrangeLoopGames/...  closed
# 60693  https://api.github.com/repos/StrangeLoopGames/...  closed
# 60694       https://api.github.com/repos/xcat2/xcat-core  closed
#
#                                                    title  \
# 0                     Auto-log out after some time frame
# 1                 Escape shuttle reaches ludicrous speed
# 2                 constructing  virtual router structure
# 3          Create local variable code action breaks code
# 4      Add rate limiting to the login and password ch...
# ...                                                  ...
# 60690  Scoring items and Industry Items (that will br...
# 60691           USER ISSUE: Currency exchanges dont work
# 60692             USER ISSUE: Unable to set up contracts
# 60693       Meteor hit - Can no longer join server 6.4.1
# 60694  error message improvement when adding users in...
#
#                                                   labels  \
# 0      Docs: not needed Effort: small Feature Module:...
# 1                                  Bug High Priority lol
# 2      Priority: High Type: Enhancement Type: Mainten...
# 3      Area/Tooling Component/LanguageServer Points/1...
# 4      area: authentication enhancement good first is...
# ...                                                  ...
# 60690                                      High Priority
# 60691                                      High Priority
# 60692                                      High Priority
# 60693                                      High Priority
# 60694      priority:high sprint1 status:pending type:bug
#
#                                                     body
# 0      ## Is your feature request related to a proble...
# 1      ## Description\r\n\r\nEscape shuttle accelerat...
# 2                                                   \r\n
# 3      <img width="558" alt="Screen Shot 2019-10-29 a...
# 4      Zulip historically has relied on strong passwo...
# ...                                                  ...
# 60690  we had this information in previous release 6....
# 60691  **Version:** 0.7.0.8 beta\r\n\r\n**Steps to Re...
# 60692  **Version:** 0.6.4.2 alpha\r\n\r\n**Steps to R...
# 60693  Just had the meteor hit on our server and now ...
# 60694  Problem statement: error message when adding x...
#
# [60695 rows x 9 columns]

# %%
not_high_priority[not_high_priority["repo"] == "python/mypy"]
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body]
# Index: []

# %%
# Remove mypy from the dataset
not_high_priority = not_high_priority[not_high_priority["repo"] != "python/mypy"]
not_high_priority = not_high_priority[not_high_priority["repo"] != "rust-lang/rust"]
not_high_priority = not_high_priority[not_high_priority["repo"] != "flutter/flutter"]
# reset index
not_high_priority.reset_index(drop=True, inplace=True)
not_high_priority
# Out:
#                   id         type           created_at  \
# 0       1.141785e+10  IssuesEvent  2020-02-03 01:49:58
# 1       1.141798e+10  IssuesEvent  2020-02-03 02:28:16
# 2       1.141799e+10  IssuesEvent  2020-02-03 02:30:32
# 3       1.141799e+10  IssuesEvent  2020-02-03 02:31:03
# 4       1.141774e+10  IssuesEvent  2020-02-03 01:15:24
# ...              ...          ...                  ...
# 617999  7.335053e+09  IssuesEvent  2018-03-06 01:50:25
# 618000  7.335070e+09  IssuesEvent  2018-03-06 01:55:53
# 618001  7.335074e+09  IssuesEvent  2018-03-06 01:57:10
# 618002  7.334815e+09  IssuesEvent  2018-03-06 00:34:07
# 618003  7.334824e+09  IssuesEvent  2018-03-06 00:36:39
#
#                              repo  \
# 0              openmsupply/mobile
# 1              openmsupply/mobile
# 2              openmsupply/mobile
# 3              openmsupply/mobile
# 4       unitystation/unitystation
# ...                           ...
# 617999            xcat2/xcat-core
# 618000            xcat2/xcat-core
# 618001            xcat2/xcat-core
# 618002              dart-lang/sdk
# 618003              dart-lang/sdk
#
#                                                  repo_url  action  \
# 0         https://api.github.com/repos/openmsupply/mobile  opened
# 1         https://api.github.com/repos/openmsupply/mobile  closed
# 2         https://api.github.com/repos/openmsupply/mobile  closed
# 3         https://api.github.com/repos/openmsupply/mobile  closed
# 4       https://api.github.com/repos/unitystation/unit...  opened
# ...                                                   ...     ...
# 617999       https://api.github.com/repos/xcat2/xcat-core  closed
# 618000       https://api.github.com/repos/xcat2/xcat-core  closed
# 618001       https://api.github.com/repos/xcat2/xcat-core  closed
# 618002         https://api.github.com/repos/dart-lang/sdk  closed
# 618003         https://api.github.com/repos/dart-lang/sdk  closed
#
#                                                     title  \
# 0         Update cash register to use new payment options
# 1                           Add cash register page toggle
# 2                    Add remaining indicator localisation
# 3                                 Enforce indicator types
# 4                             Cargo Console No Categories
# ...                                                   ...
# 617999  [fvt][xcat-inventory] xcat-inventory return su...
# 618000  [fvt] configure ssh in cumulus switch is not s...
# 618001                xCAT database on remote DB server ?
# 618002  Add Dart 2.0 migration stubs to packages that ...
# 618003  Add Dart 2.0 migration stubs to packages that ...
#
#                                                    labels  \
# 0                                                 Feature
# 1       Docs: not needed Effort: small Feature Module:...
# 2                Effort: small Feature Module: indicators
# 3       Effort: medium Feature Module: indicators Prio...
# 4                                               Bug Cargo
# ...                                                   ...
# 617999                    sprint2 status:pending type:bug
# 618000                    sprint2 status:pending type:bug
# 618001                                 type:documentation
# 618002                                       area-library
# 618003                                       area-library
#
#                                                      body
# 0       ## Is your feature request related to a proble...
# 1       ## Is your feature request related to a proble...
# 2       ## Is your feature request related to a proble...
# 3       ## Is your feature request related to a proble...
# 4       ## Description\r\n\r\nCargo console doesn't sh...
# ...                                                   ...
# 617999  when assigning a wrong attirbute to option ``o...
# 618000  Configuring ssh in cumulus switch by ``switchd...
# 618001  Hi \r\n\r\nDoes xCAT support the DB to be exis...
# 618002  Dart 2.0 adds several instance members to a nu...
# 618003  To help with the migration and changes to the ...
#
# [618004 rows x 9 columns]

# %%
# Number or different labels
not_high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                            count
# labels
# action-needsmoderation                     41205
# bug                                        22383
# Bug                                        11102
# browser-fixme action-needsmoderation       10742
# enhancement                                 7336
# type: dependency-upgrade                    6841
# Type: Bug                                   4485
# action-needsmoderation browser-fixme        3927
# community triage                            3425
# browser-firefox engine-gecko                2933
# Runtime Error                               2777
# browser-fenix engine-gecko                  2619
# status: waiting-for-triage                  2530
# browser-firefox-mobile engine-gecko         2133
# kind/bug                                    2009
# browser-focus-geckoview engine-gecko        1954
# bugbug-probability-high                     1839
# type: task                                  1775
# Bug S2 Middle prio                          1772
# Icon Request                                1689
# runtime error ☢                             1659
# [Type] Bug                                  1649
# bug needs triage                            1635
# Bug Code                                    1596
# type: bug                                   1585
# invalid                                     1552
# Type/Bug                                    1538
# Enhancement                                 1521
# itype:bug                                   1430
# Priority/Normal Type/Bug                    1401
# Feature Request                             1395
# browser-firefox status-needstriage          1379
# feature                                     1287
# question                                    1201
# bug topic:editor                            1170
# type:bug                                    1116
# area-vm                                     1105
# Unconfirmed bug                             1100
# bug topic:core                              1033
# type: enhancement                           1016
# browser-firefox-mobile                       973
# [Type] Bug User Report                       952
# type/bug needs-triage                        947
# Feature request                              924
# area/docdb status/awaiting-triage            914
# browser-firefox priority-normal              906
# browser-firefox-mobile status-needstriage    902
# type/enhancement                             879
# type:enhancement                             872
# browser-firefox                              853

# %%
#Give each priority a label by number.
# 'Label encoding'. Makes is easier for machine learning models to work with categorical data.
high_priority["label"] = 0
high_priority["class"] = "high_priority"
high_priority.head()
# Out:
#              id         type           created_at  \
# 0  1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 1  1.141797e+10  IssuesEvent  2020-02-03 02:25:22
# 2  1.141798e+10  IssuesEvent  2020-02-03 02:28:57
# 3  1.141825e+10  IssuesEvent  2020-02-03 03:46:09
# 4  1.141832e+10  IssuesEvent  2020-02-03 04:04:30
#
#                                 repo  \
# 0                 openmsupply/mobile
# 1          unitystation/unitystation
# 2                    qlcchain/go-qlc
# 3  ballerina-platform/ballerina-lang
# 4                        zulip/zulip
#
#                                             repo_url  action  \
# 0    https://api.github.com/repos/openmsupply/mobile  closed
# 1  https://api.github.com/repos/unitystation/unit...  closed
# 2       https://api.github.com/repos/qlcchain/go-qlc  closed
# 3  https://api.github.com/repos/ballerina-platfor...  closed
# 4           https://api.github.com/repos/zulip/zulip  closed
#
#                                                title  \
# 0                 Auto-log out after some time frame
# 1             Escape shuttle reaches ludicrous speed
# 2             constructing  virtual router structure
# 3      Create local variable code action breaks code
# 4  Add rate limiting to the login and password ch...
#
#                                               labels  \
# 0  Docs: not needed Effort: small Feature Module:...
# 1                              Bug High Priority lol
# 2  Priority: High Type: Enhancement Type: Mainten...
# 3  Area/Tooling Component/LanguageServer Points/1...
# 4  area: authentication enhancement good first is...
#
#                                                 body  label          class
# 0  ## Is your feature request related to a proble...      0  high_priority
# 1  ## Description\r\n\r\nEscape shuttle accelerat...      0  high_priority
# 2                                               \r\n      0  high_priority
# 3  <img width="558" alt="Screen Shot 2019-10-29 a...      0  high_priority
# 4  Zulip historically has relied on strong passwo...      0  high_priority

# %%
not_high_priority["label"] = 1
not_high_priority["class"] = "not_high_priority" 
not_high_priority.head()
# Out:
#              id         type           created_at                       repo  \
# 0  1.141785e+10  IssuesEvent  2020-02-03 01:49:58         openmsupply/mobile
# 1  1.141798e+10  IssuesEvent  2020-02-03 02:28:16         openmsupply/mobile
# 2  1.141799e+10  IssuesEvent  2020-02-03 02:30:32         openmsupply/mobile
# 3  1.141799e+10  IssuesEvent  2020-02-03 02:31:03         openmsupply/mobile
# 4  1.141774e+10  IssuesEvent  2020-02-03 01:15:24  unitystation/unitystation
#
#                                             repo_url  action  \
# 0    https://api.github.com/repos/openmsupply/mobile  opened
# 1    https://api.github.com/repos/openmsupply/mobile  closed
# 2    https://api.github.com/repos/openmsupply/mobile  closed
# 3    https://api.github.com/repos/openmsupply/mobile  closed
# 4  https://api.github.com/repos/unitystation/unit...  opened
#
#                                              title  \
# 0  Update cash register to use new payment options
# 1                    Add cash register page toggle
# 2             Add remaining indicator localisation
# 3                          Enforce indicator types
# 4                      Cargo Console No Categories
#
#                                               labels  \
# 0                                            Feature
# 1  Docs: not needed Effort: small Feature Module:...
# 2           Effort: small Feature Module: indicators
# 3  Effort: medium Feature Module: indicators Prio...
# 4                                          Bug Cargo
#
#                                                 body  label              class
# 0  ## Is your feature request related to a proble...      1  not_high_priority
# 1  ## Is your feature request related to a proble...      1  not_high_priority
# 2  ## Is your feature request related to a proble...      1  not_high_priority
# 3  ## Is your feature request related to a proble...      1  not_high_priority
# 4  ## Description\r\n\r\nCargo console doesn't sh...      1  not_high_priority

# %%
# Drop duplicates by the content of the title
high_priority = high_priority.drop_duplicates(subset=['title'], keep='last')
high_priority.dropna(inplace=True)
high_priority.reset_index(inplace=True)
high_priority.drop(columns=["index"] , inplace= True)
high_priority["class"].value_counts()
# Out:
# class
# high_priority    60695
# Name: count, dtype: int64

# %%
# Drop duplicates by the content of the title
not_high_priority = not_high_priority.drop_duplicates(subset=['title'], keep='last')
not_high_priority.dropna(inplace=True)
not_high_priority.reset_index(inplace=True)
not_high_priority.drop(columns=["index"] , inplace= True)
not_high_priority["class"].value_counts()
# Out:
# /tmp/ipykernel_287126/3768055171.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority.dropna(inplace=True)
# /tmp/ipykernel_287126/3768055171.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority.drop(columns=["index"] , inplace= True)
# class
# not_high_priority    425959
# Name: count, dtype: int64

# %%
high_priority.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60695 entries, 0 to 60694
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          60695 non-null  float64
#  1   type        60695 non-null  object
#  2   created_at  60695 non-null  object
#  3   repo        60695 non-null  object
#  4   repo_url    60695 non-null  object
#  5   action      60695 non-null  object
#  6   title       60695 non-null  object
#  7   labels      60695 non-null  object
#  8   body        60695 non-null  object
#  9   label       60695 non-null  int64
#  10  class       60695 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 5.1+ MB

# %%
label_counts = high_priority["class"].value_counts()
label_counts_nhp = not_high_priority["class"].value_counts()
print(label_counts)
not_high_priority_count = label_counts_nhp["not_high_priority"]
print(not_high_priority_count)
hp_count = label_counts["high_priority"]
hp_count
# Out:
# class
# high_priority    60695
# Name: count, dtype: int64
# 425959
# 60695

# %%
not_high_priority = not_high_priority.sample(frac=hp_count/not_high_priority_count, random_state=42)
not_high_priority
# Out:
#                   id         type           created_at  \
# 378186  1.176086e+10  IssuesEvent  2020-03-13 20:32:47
# 225907  1.496314e+10  IssuesEvent  2021-01-27 10:10:38
# 142734  1.718954e+10  IssuesEvent  2021-07-16 08:58:01
# 31716   1.423801e+10  IssuesEvent  2020-11-18 18:00:22
# 109607  1.041105e+10  IssuesEvent  2019-09-13 13:01:04
# ...              ...          ...                  ...
# 305418  2.101087e+10  IssuesEvent  2022-03-30 06:23:12
# 348267  2.503145e+10  IssuesEvent  2022-11-04 12:44:53
# 234017  7.301850e+09  IssuesEvent  2018-02-27 07:28:25
# 90011   1.161562e+10  IssuesEvent  2020-02-26 14:29:40
# 253466  8.216697e+09  IssuesEvent  2018-09-05 09:58:04
#
#                              repo  \
# 378186              oncokb/oncokb
# 225907     red-hat-storage/ocs-ci
# 142734         webcompat/web-bugs
# 31716            abpframework/abp
# 109607         webcompat/web-bugs
# ...                           ...
# 305418                zulip/zulip
# 348267             OpenNebula/one
# 234017            wso2/product-is
# 90011   Templarian/MaterialDesign
# 253466  handsontable/handsontable
#
#                                                  repo_url  action  \
# 378186         https://api.github.com/repos/oncokb/oncokb  closed
# 225907  https://api.github.com/repos/red-hat-storage/o...  closed
# 142734    https://api.github.com/repos/webcompat/web-bugs  closed
# 31716       https://api.github.com/repos/abpframework/abp  opened
# 109607    https://api.github.com/repos/webcompat/web-bugs  closed
# ...                                                   ...     ...
# 305418           https://api.github.com/repos/zulip/zulip  opened
# 348267        https://api.github.com/repos/OpenNebula/one  opened
# 234017       https://api.github.com/repos/wso2/product-is  opened
# 90011   https://api.github.com/repos/Templarian/Materi...  closed
# 253466  https://api.github.com/repos/handsontable/hand...  closed
#
#                                                     title  \
# 378186                    Error on page with latest data
# 225907  Add support for Azure platform in ceph osd tre...
# 142734                 www.bperx.com - site is not usable
# 31716                           AlertManager Improvements
# 109607                    ubuntu.com - site is not usable
# ...                                                   ...
# 305418  Default user settings incorrectly shows "mobil...
# 348267                    Evaluate removing iSCSI drivers
# 234017  Script errors can be seen when you source the ...
# 90011                                    Add Youtube Icon
# 253466  Consecutive double quotes are not  pasted corr...
#
#                                                    labels  \
# 378186                                 bug public website
# 225907                                                RFE
# 142734                         browser-firefox-ios os-ios
# 31716                             abp-framework ui-blazor
# 109607  browser-firefox engine-gecko os-linux priority...
# ...                                                   ...
# 305418   help wanted area: settings UI backport candidate
# 348267  Category: Drivers - Storage Type: Feature Stat...
# 234017    Affected/5.5.0-Alpha2 Priority/Highest Type/Bug
# 90011                           Contribution Icon Request
# 253466                                          Type: Bug
#
#                                                      body  label  \
# 378186  We no longer can load the user info\r\nhttps:/...      1
# 225907  Curently, [check_ceph_osd_tree()](https://gith...      1
# 142734  <!-- @browser: Firefox iOS 34.2 -->\n<!-- @ua_...      1
# 31716   Move `IAlertManager` to the `Volo.Abp.Aspnetco...      1
# 109607  <!-- @browser: Firefox 71.0 -->\n<!-- @ua_head...      1
# ...                                                   ...    ...
# 305418  In organization settings, under "Default user ...      1
# 348267  **Description**\r\n\r\nThey serve a very speci...      1
# 234017  Script errors can be seen when you source the ...      1
# 90011   <!--\r\nWe are no longer accepting brand icons...      1
# 253466  ### Description\r\n<!--- Tell us what happens ...      1
#
#                     class
# 378186  not_high_priority
# 225907  not_high_priority
# 142734  not_high_priority
# 31716   not_high_priority
# 109607  not_high_priority
# ...                   ...
# 305418  not_high_priority
# 348267  not_high_priority
# 234017  not_high_priority
# 90011   not_high_priority
# 253466  not_high_priority
#
# [60695 rows x 11 columns]

# %%
all_priority = pd.concat([high_priority,not_high_priority] , ignore_index = True)
all_priority.tail()
# Out:
#                   id         type           created_at  \
# 121385  2.101087e+10  IssuesEvent  2022-03-30 06:23:12
# 121386  2.503145e+10  IssuesEvent  2022-11-04 12:44:53
# 121387  7.301850e+09  IssuesEvent  2018-02-27 07:28:25
# 121388  1.161562e+10  IssuesEvent  2020-02-26 14:29:40
# 121389  8.216697e+09  IssuesEvent  2018-09-05 09:58:04
#
#                              repo  \
# 121385                zulip/zulip
# 121386             OpenNebula/one
# 121387            wso2/product-is
# 121388  Templarian/MaterialDesign
# 121389  handsontable/handsontable
#
#                                                  repo_url  action  \
# 121385           https://api.github.com/repos/zulip/zulip  opened
# 121386        https://api.github.com/repos/OpenNebula/one  opened
# 121387       https://api.github.com/repos/wso2/product-is  opened
# 121388  https://api.github.com/repos/Templarian/Materi...  closed
# 121389  https://api.github.com/repos/handsontable/hand...  closed
#
#                                                     title  \
# 121385  Default user settings incorrectly shows "mobil...
# 121386                    Evaluate removing iSCSI drivers
# 121387  Script errors can be seen when you source the ...
# 121388                                   Add Youtube Icon
# 121389  Consecutive double quotes are not  pasted corr...
#
#                                                    labels  \
# 121385   help wanted area: settings UI backport candidate
# 121386  Category: Drivers - Storage Type: Feature Stat...
# 121387    Affected/5.5.0-Alpha2 Priority/Highest Type/Bug
# 121388                          Contribution Icon Request
# 121389                                          Type: Bug
#
#                                                      body  label  \
# 121385  In organization settings, under "Default user ...      1
# 121386  **Description**\r\n\r\nThey serve a very speci...      1
# 121387  Script errors can be seen when you source the ...      1
# 121388  <!--\r\nWe are no longer accepting brand icons...      1
# 121389  ### Description\r\n<!--- Tell us what happens ...      1
#
#                     class
# 121385  not_high_priority
# 121386  not_high_priority
# 121387  not_high_priority
# 121388  not_high_priority
# 121389  not_high_priority

# %%
# 
all_priority["label"].value_counts()
# Out:
# label
# 0    60695
# 1    60695
# Name: count, dtype: int64

# %%
print(all_priority["title"][0])
print(all_priority["body"][0])
# Out:
# Auto-log out after some time frame
# ## Is your feature request related to a problem? Please describe.
#
# From @craigdrown
#
# IC Requirement: Automatically log a user out after a time frame of X for security reasons. Data should not be lost which was being worked on.
#
# ## Describe the solution you'd like
#
# Log the user out after X time
#
# ## Implementation
#
# Could use store custom data `logoutTimeoutPeriodInSecondsOrMinutes` to set the period..
#
# - Use [AppState](https://facebook.github.io/react-native/docs/appstate#addeventlistener) to hook into the app going into the background - log the user out if so. Android would go to sleep after X amount of time, putting the app into the background (I THINK, UNTESTED)
# - Use a package like https://www.npmjs.com/package/redux-idle-monitor to track activity, have a schedule that is reset each time an event happens.
# - Use the above package but combine it with the current user authentication scheduler (tries to re-auth against the server every X minutes, or the local DB if no connection available) - I think not good
#
# ## Describe alternatives you've considered
#
# Not having this in the dispensary/IC branch 🤣
#
# ## Additional context
#
# @wlthomson @mark-prins @Chris-Petty thoughts?

# %%
# Copy content of body to a new col named text
all_priority["text"] = all_priority["title"] + all_priority["body"]
all_priority.tail()
# Out:
#                   id         type           created_at  \
# 121385  2.101087e+10  IssuesEvent  2022-03-30 06:23:12
# 121386  2.503145e+10  IssuesEvent  2022-11-04 12:44:53
# 121387  7.301850e+09  IssuesEvent  2018-02-27 07:28:25
# 121388  1.161562e+10  IssuesEvent  2020-02-26 14:29:40
# 121389  8.216697e+09  IssuesEvent  2018-09-05 09:58:04
#
#                              repo  \
# 121385                zulip/zulip
# 121386             OpenNebula/one
# 121387            wso2/product-is
# 121388  Templarian/MaterialDesign
# 121389  handsontable/handsontable
#
#                                                  repo_url  action  \
# 121385           https://api.github.com/repos/zulip/zulip  opened
# 121386        https://api.github.com/repos/OpenNebula/one  opened
# 121387       https://api.github.com/repos/wso2/product-is  opened
# 121388  https://api.github.com/repos/Templarian/Materi...  closed
# 121389  https://api.github.com/repos/handsontable/hand...  closed
#
#                                                     title  \
# 121385  Default user settings incorrectly shows "mobil...
# 121386                    Evaluate removing iSCSI drivers
# 121387  Script errors can be seen when you source the ...
# 121388                                   Add Youtube Icon
# 121389  Consecutive double quotes are not  pasted corr...
#
#                                                    labels  \
# 121385   help wanted area: settings UI backport candidate
# 121386  Category: Drivers - Storage Type: Feature Stat...
# 121387    Affected/5.5.0-Alpha2 Priority/Highest Type/Bug
# 121388                          Contribution Icon Request
# 121389                                          Type: Bug
#
#                                                      body  label  \
# 121385  In organization settings, under "Default user ...      1
# 121386  **Description**\r\n\r\nThey serve a very speci...      1
# 121387  Script errors can be seen when you source the ...      1
# 121388  <!--\r\nWe are no longer accepting brand icons...      1
# 121389  ### Description\r\n<!--- Tell us what happens ...      1
#
#                     class                                               text
# 121385  not_high_priority  Default user settings incorrectly shows "mobil...
# 121386  not_high_priority  Evaluate removing iSCSI drivers**Description**...
# 121387  not_high_priority  Script errors can be seen when you source the ...
# 121388  not_high_priority  Add Youtube Icon<!--\r\nWe are no longer accep...
# 121389  not_high_priority  Consecutive double quotes are not  pasted corr...

# %%
all_priority["text"][0]
# Out:
# "Auto-log out after some time frame## Is your feature request related to a problem? Please describe.\r\n\r\nFrom @craigdrown \r\n\r\nIC Requirement: Automatically log a user out after a time frame of X for security reasons. Data should not be lost which was being worked on.\r\n\r\n## Describe the solution you'd like\r\n\r\nLog the user out after X time\r\n\r\n## Implementation\r\n\r\nCould use store custom data `logoutTimeoutPeriodInSecondsOrMinutes` to set the period..\r\n\r\n- Use [AppState](https://facebook.github.io/react-native/docs/appstate#addeventlistener) to hook into the app going into the background - log the user out if so. Android would go to sleep after X amount of time, putting the app into the background (I THINK, UNTESTED)\r\n- Use a package like https://www.npmjs.com/package/redux-idle-monitor to track activity, have a schedule that is reset each time an event happens.\r\n- Use the above package but combine it with the current user authentication scheduler (tries to re-auth against the server every X minutes, or the local DB if no connection available) - I think not good\r\n\r\n## Describe alternatives you've considered\r\n\r\nNot having this in the dispensary/IC branch 🤣 \r\n\r\n## Additional context\r\n\r\n@wlthomson @mark-prins @Chris-Petty thoughts?\r\n"

# %%
# Make a new dataframe with only text, label and class cols.
all_priority_subset = all_priority[["text" , "label" , "class"]]
all_priority_subset
# Out:
#                                                      text  label  \
# 0       Auto-log out after some time frame## Is your f...      0
# 1       Escape shuttle reaches ludicrous speed## Descr...      0
# 2              constructing  virtual router structure\r\n      0
# 3       Create local variable code action breaks code<...      0
# 4       Add rate limiting to the login and password ch...      0
# ...                                                   ...    ...
# 121385  Default user settings incorrectly shows "mobil...      1
# 121386  Evaluate removing iSCSI drivers**Description**...      1
# 121387  Script errors can be seen when you source the ...      1
# 121388  Add Youtube Icon<!--\r\nWe are no longer accep...      1
# 121389  Consecutive double quotes are not  pasted corr...      1
#
#                     class
# 0           high_priority
# 1           high_priority
# 2           high_priority
# 3           high_priority
# 4           high_priority
# ...                   ...
# 121385  not_high_priority
# 121386  not_high_priority
# 121387  not_high_priority
# 121388  not_high_priority
# 121389  not_high_priority
#
# [121390 rows x 3 columns]

# %%
# Convert to string
all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)
# Out:
# /tmp/ipykernel_287126/3106036705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)

# %%
all_priority_subset
# Out:
#                                                      text  label  \
# 0       Auto-log out after some time frame## Is your f...      0
# 1       Escape shuttle reaches ludicrous speed## Descr...      0
# 2              constructing  virtual router structure\r\n      0
# 3       Create local variable code action breaks code<...      0
# 4       Add rate limiting to the login and password ch...      0
# ...                                                   ...    ...
# 121385  Default user settings incorrectly shows "mobil...      1
# 121386  Evaluate removing iSCSI drivers**Description**...      1
# 121387  Script errors can be seen when you source the ...      1
# 121388  Add Youtube Icon<!--\r\nWe are no longer accep...      1
# 121389  Consecutive double quotes are not  pasted corr...      1
#
#                     class                                           text_str
# 0           high_priority  Auto-log out after some time frame## Is your f...
# 1           high_priority  Escape shuttle reaches ludicrous speed## Descr...
# 2           high_priority         constructing  virtual router structure\r\n
# 3           high_priority  Create local variable code action breaks code<...
# 4           high_priority  Add rate limiting to the login and password ch...
# ...                   ...                                                ...
# 121385  not_high_priority  Default user settings incorrectly shows "mobil...
# 121386  not_high_priority  Evaluate removing iSCSI drivers**Description**...
# 121387  not_high_priority  Script errors can be seen when you source the ...
# 121388  not_high_priority  Add Youtube Icon<!--\r\nWe are no longer accep...
# 121389  not_high_priority  Consecutive double quotes are not  pasted corr...
#
# [121390 rows x 4 columns]

# %%
# Clean the data.
all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_287126/63294665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)

# %%
# Make a subset with text_clean and label
priority_label_text = all_priority_subset[["text_clean" , "label"]]
priority_label_text
# Out:
#                                                text_clean  label
# 0       autolog out after some time frame is your feat...      0
# 1       escape shuttle reaches ludicrous speed descrip...      0
# 2                                                     NaN      0
# 3       create local variable code action breaks codei...      0
# 4       add rate limiting to the login and password ch...      0
# ...                                                   ...    ...
# 121385  default user settings incorrectly shows mobile...      1
# 121386  evaluate removing iscsi driversdescription the...      1
# 121387  script errors can be seen when you source the ...      1
# 121388  add youtube icon we are no longer accepting br...      1
# 121389  consecutive double quotes are not pasted corre...      1
#
# [121390 rows x 2 columns]

# %%
# Need to dropna here since cleaning function returns NaN for not english text.
priority_label_text.dropna(inplace=True)
priority_label_text.reset_index(inplace=True)
priority_label_text.drop(columns=["index"] , inplace= True)

priority_label_text
# Out:
# /tmp/ipykernel_287126/239147930.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.dropna(inplace=True)
# /tmp/ipykernel_287126/239147930.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.drop(columns=["index"] , inplace= True)
#                                                text_clean  label
# 0       autolog out after some time frame is your feat...      0
# 1       escape shuttle reaches ludicrous speed descrip...      0
# 2       create local variable code action breaks codei...      0
# 3       add rate limiting to the login and password ch...      0
# 4       error with awx 700hello im testing integration...      0
# ...                                                   ...    ...
# 118006  default user settings incorrectly shows mobile...      1
# 118007  evaluate removing iscsi driversdescription the...      1
# 118008  script errors can be seen when you source the ...      1
# 118009  add youtube icon we are no longer accepting br...      1
# 118010  consecutive double quotes are not pasted corre...      1
#
# [118011 rows x 2 columns]

# %%
from sklearn.utils import resample

# Split the dataset into two based on the label
df_majority = priority_label_text[priority_label_text['label'] == 1]
df_minority = priority_label_text[priority_label_text['label'] == 0]

# Undersample the majority class
df_majority_undersampled = resample(df_majority, 
                                     replace=False,    # sample without replacement
                                     n_samples=len(df_minority),     # to match minority class
                                     random_state=123) # reproducible results

# Combine minority class with downsampled majority class
df_balanced = pd.concat([df_majority_undersampled, df_minority])

# Shuffle the dataset to avoid any ordering bias
df_balanced = df_balanced.sample(frac=1).reset_index(drop=True)
priority_label_text = df_balanced
priority_label_text["label"].value_counts()
# Out:
# label
# 0    58401
# 1    58401
# Name: count, dtype: int64

# %%
# Clean dataset with clean text and labels.
# 0 = high priority, 1 = not high priority
file_name = f"csv/clean_high_vs_random.csv"
priority_label_text.to_csv(file_name)

# %%
pri = pd.read_csv(file_name)
pri
# Out:
#         Unnamed: 0                                         text_clean  label
# 0                0  tools mode layout issuesdescribe the bug some ...      0
# 1                1  version control enhancement for osimagephase 2...      0
# 2                2  actor future is immediately completed if the a...      1
# 3                3  pub should more efficiently serialize barback ...      0
# 4                4  hu editor hu status different in grid view sin...      1
# ...            ...                                                ...    ...
# 116797      116797  qgis 310 ltr 316 not connecting to odbc source...      1
# 116798      116798  active theme is not foundhello every 15 second...      1
# 116799      116799  crash at usedproduct report creation scenario ...      1
# 116800      116800  optimization api 在线文档在生产环境隐藏加权限 permissionclas...      0
# 116801      116801  zoey webbfirecage as an animal survivedbasical...      1
#
# [116802 rows x 3 columns]
