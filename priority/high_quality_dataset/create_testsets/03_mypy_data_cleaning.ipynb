# %% [markdown]
# # Data cleaning
# We want the class with labels as numerical value and the body with clean text.
#
# This will remove:
# * duplicates
# * NaN entires
# * non english
# * url, html
#
# * make it lowercase
# * combine title and body

# %%
import pandas as pd
import sys
sys.path.append("../../../scripts_shared/")
from preprocess_text import preprocess_text

# %%
# Read CSV into a dataframe
filename = "csv/mypy_testset.csv"
df = pd.read_csv(filename)
df
# Out:
#                 id         type           created_at         repo  \
# 0     1.142706e+10  IssuesEvent  2020-02-03 23:33:27  python/mypy
# 1     1.142707e+10  IssuesEvent  2020-02-03 23:35:24  python/mypy
# 2     1.362788e+10  IssuesEvent  2020-09-24 13:13:03  python/mypy
# 3     1.363241e+10  IssuesEvent  2020-09-24 19:36:27  python/mypy
# 4     2.407484e+10  IssuesEvent  2022-09-18 17:03:35  python/mypy
# ...            ...          ...                  ...          ...
# 5009  2.060497e+10  IssuesEvent  2022-03-06 20:54:33  python/mypy
# 5010  2.060505e+10  IssuesEvent  2022-03-06 21:09:50  python/mypy
# 5011  2.060518e+10  IssuesEvent  2022-03-06 21:33:34  python/mypy
# 5012  2.060562e+10  IssuesEvent  2022-03-06 23:01:04  python/mypy
# 5013  2.060567e+10  IssuesEvent  2022-03-06 23:08:52  python/mypy
#
#                                       repo_url    action  \
# 0     https://api.github.com/repos/python/mypy    closed
# 1     https://api.github.com/repos/python/mypy    closed
# 2     https://api.github.com/repos/python/mypy    opened
# 3     https://api.github.com/repos/python/mypy    opened
# 4     https://api.github.com/repos/python/mypy    opened
# ...                                        ...       ...
# 5009  https://api.github.com/repos/python/mypy    closed
# 5010  https://api.github.com/repos/python/mypy  reopened
# 5011  https://api.github.com/repos/python/mypy    opened
# 5012  https://api.github.com/repos/python/mypy    closed
# 5013  https://api.github.com/repos/python/mypy    closed
#
#                                                   title  \
# 0              Type of conditional expression is object
# 1       Type inference of Tuples returns object instead
# 2           Daemon support for --follow-imports=silent
# 3     regression: assignment of 'builtins.type' now ...
# 4     stubtest: more concise error for forgotten arg...
# ...                                                 ...
# 5009  Color output missing when errors redrected (wi...
# 5010  Color output missing when errors redrected (wi...
# 5011  Getting Invalid "type: ignore" comment reports...
# 5012  Wrong type inference with unpacking and enumer...
# 5013  Color output missing when errors redrected (wi...
#
#                                                  labels  \
# 0     false-positive needs discussion priority-1-nor...
# 1                    bug false-positive priority-0-high
# 2                                               feature
# 3                                                   bug
# 4                                               feature
# ...                                                 ...
# 5009                                                bug
# 5010                                                bug
# 5011                                                bug
# 5012                              bug priority-1-normal
# 5013                                                bug
#
#                                                    body
# 0     The type of the following conditional expressi...
# 1     While interacting with `zip` I encountered a v...
# 2     After #5870 is done, it would be nice to also ...
# 3     \r\n**Bug Report**\r\n\r\n#7963 causes a serio...
# 4     **Feature**\r\n\r\nWhen the implementation add...
# ...                                                 ...
# 5009  <!--\r\n  If you're new to mypy and you're not...
# 5010  <!--\r\n  If you're new to mypy and you're not...
# 5011  **Bug Report**\r\n\r\n3rd party library I am u...
# 5012  Mypy infers that the type of `[*enumerate(["x"...
# 5013  <!--\r\n  If you're new to mypy and you're not...
#
# [5014 rows x 9 columns]

# %%
# Number or different labels
df.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# bug                                                  2266
# feature                                               443
# crash                                                 190
# question                                               93
# documentation                                          89
# bug priority-1-normal                                  52
# bug priority-0-high                                    46
# crash priority-0-high                                  39
# needs discussion                                       39
# feature priority-1-normal                              30
# bug topic-paramspec                                    26
# feature priority-0-high                                22
# bug false-positive priority-0-high                     19
# bug false-positive priority-1-normal                   18
# bug topic-type-narrowing                               18
# feature priority-2-low                                 17
# bug priority-2-low                                     16
# priority-0-high                                        16
# bug topic-stubtest                                     16
# topic-fine-grained-incremental                         13
# bug topic-protocols                                    12
# topic-daemon                                           12
# bug topic-fine-grained-incremental                     11
# feature needs discussion priority-2-low                11
# priority-1-normal refactoring                          11
# documentation priority-0-high                          11
# feature needs discussion                               11
# affects/strict-optional                                10
# bug priority-1-normal topic-union-types                10
# bug priority-1-normal false-positive                   10
# crash topic-match-statement                            10
# bug topic-typed-dict                                   10
# task                                                    9
# bug topic-overloads                                     9
# Crash                                                   9
# bug topic-type-variables                                9
# crash priority-0-high topic-fine-grained-increm...      9
# topic-usability                                         9
# documentation priority-1-normal                         9
# feature topic-partially-defined                         9
# crash new-semantic-analyzer priority-0-high             9
# feature priority-1-normal topic-usability               9
# bug topic-stubgen                                       9
# crash priority-1-normal                                 9
# crash topic-fine-grained-incremental                    8
# feature needs discussion priority-1-normal              8
# meta                                                    8
# priority-1-normal topic-usability                       8
# refactoring                                             8
# good-first-issue priority-1-normal topic-usability      8

# %%
# Split data based on labels. Contains P0 and P1 in one dataframe, the rest in another

pattern = 'priority-0-high'
# Check if 'labels' contains the pattern
hp = df[df['labels'].str.contains(pattern)]
# Reset index
hp = hp.reset_index(drop=True)
hp
# Out:
#                id         type           created_at         repo  \
# 0    1.142707e+10  IssuesEvent  2020-02-03 23:35:24  python/mypy
# 1    2.655427e+10  IssuesEvent  2023-01-20 10:36:13  python/mypy
# 2    2.656236e+10  IssuesEvent  2023-01-20 16:54:26  python/mypy
# 3    5.439713e+09  IssuesEvent  2017-03-06 14:10:37  python/mypy
# 4    8.708969e+09  IssuesEvent  2018-12-06 12:35:33  python/mypy
# ..            ...          ...                  ...          ...
# 434  1.003922e+10  IssuesEvent  2019-07-18 16:50:07  python/mypy
# 435  2.322156e+10  IssuesEvent  2022-08-02 18:45:12  python/mypy
# 436  8.837451e+09  IssuesEvent  2019-01-05 04:59:35  python/mypy
# 437  8.527242e+09  IssuesEvent  2018-11-02 18:50:03  python/mypy
# 438  1.225942e+10  IssuesEvent  2020-05-06 16:34:12  python/mypy
#
#                                      repo_url  action  \
# 0    https://api.github.com/repos/python/mypy  closed
# 1    https://api.github.com/repos/python/mypy  opened
# 2    https://api.github.com/repos/python/mypy  closed
# 3    https://api.github.com/repos/python/mypy  closed
# 4    https://api.github.com/repos/python/mypy  closed
# ..                                        ...     ...
# 434  https://api.github.com/repos/python/mypy  opened
# 435  https://api.github.com/repos/python/mypy  closed
# 436  https://api.github.com/repos/python/mypy  closed
# 437  https://api.github.com/repos/python/mypy  closed
# 438  https://api.github.com/repos/python/mypy  closed
#
#                                                  title  \
# 0      Type inference of Tuples returns object instead
# 1    Unbound type variable false positive with six....
# 2    Unbound type variable false positive with six....
# 3                    Crash in super() outside a method
# 4                  TypedDict missing many dict methods
# ..                                                 ...
# 434  Support error codes and ignoring only specific...
# 435  Should concrete implementations be required to...
# 436                            Windows dmypy CI flakes
# 437  Add plugin API to specify fine grained depende...
# 438  Bytes TypedDict keys don't always generate errors
#
#                                                 labels  \
# 0                   bug false-positive priority-0-high
# 1             bug topic-type-variables priority-0-high
# 2             bug topic-type-variables priority-0-high
# 3                                crash priority-0-high
# 4    bug false-positive priority-0-high topic-typed...
# ..                                                 ...
# 434                            feature priority-0-high
# 435                bug priority-0-high topic-protocols
# 436                 crash priority-0-high topic-daemon
# 437  priority-0-high topic-fine-grained-incremental...
# 438               bug priority-0-high topic-typed-dict
#
#                                                   body
# 0    While interacting with `zip` I encountered a v...
# 1    This code generates a false positive:\r\n```py...
# 2    This code generates a false positive:\r\n```py...
# 3    The simplest repro:\r\n```python\r\nclass C:\r...
# 4    mypy isn't recognizing methods of TypedDict.\r...
# ..                                                 ...
# 434  It would be handy to support error codes to al...
# 435  * Are you reporting a bug, or opening a featur...
# 436  We've seen some failures of the daemon tests o...
# 437  Currently plugins can add type information tha...
# 438  The expression `d[b'x']` does not generate an ...
#
# [439 rows x 9 columns]

# %%
# Remove pattern from df
random = df[~df['labels'].str.contains(pattern)]
random = random.reset_index(drop=True)
random
# Out:
#                 id         type           created_at         repo  \
# 0     1.142706e+10  IssuesEvent  2020-02-03 23:33:27  python/mypy
# 1     1.362788e+10  IssuesEvent  2020-09-24 13:13:03  python/mypy
# 2     1.363241e+10  IssuesEvent  2020-09-24 19:36:27  python/mypy
# 3     2.407484e+10  IssuesEvent  2022-09-18 17:03:35  python/mypy
# 4     7.238785e+09  IssuesEvent  2018-02-13 15:37:22  python/mypy
# ...            ...          ...                  ...          ...
# 4570  2.060497e+10  IssuesEvent  2022-03-06 20:54:33  python/mypy
# 4571  2.060505e+10  IssuesEvent  2022-03-06 21:09:50  python/mypy
# 4572  2.060518e+10  IssuesEvent  2022-03-06 21:33:34  python/mypy
# 4573  2.060562e+10  IssuesEvent  2022-03-06 23:01:04  python/mypy
# 4574  2.060567e+10  IssuesEvent  2022-03-06 23:08:52  python/mypy
#
#                                       repo_url    action  \
# 0     https://api.github.com/repos/python/mypy    closed
# 1     https://api.github.com/repos/python/mypy    opened
# 2     https://api.github.com/repos/python/mypy    opened
# 3     https://api.github.com/repos/python/mypy    opened
# 4     https://api.github.com/repos/python/mypy    closed
# ...                                        ...       ...
# 4570  https://api.github.com/repos/python/mypy    closed
# 4571  https://api.github.com/repos/python/mypy  reopened
# 4572  https://api.github.com/repos/python/mypy    opened
# 4573  https://api.github.com/repos/python/mypy    closed
# 4574  https://api.github.com/repos/python/mypy    closed
#
#                                                   title  \
# 0              Type of conditional expression is object
# 1           Daemon support for --follow-imports=silent
# 2     regression: assignment of 'builtins.type' now ...
# 3     stubtest: more concise error for forgotten arg...
# 4                  Typechecking attrs-generated classes
# ...                                                 ...
# 4570  Color output missing when errors redrected (wi...
# 4571  Color output missing when errors redrected (wi...
# 4572  Getting Invalid "type: ignore" comment reports...
# 4573  Wrong type inference with unpacking and enumer...
# 4574  Color output missing when errors redrected (wi...
#
#                                                  labels  \
# 0     false-positive needs discussion priority-1-nor...
# 1                                               feature
# 2                                                   bug
# 3                                               feature
# 4                feature needs discussion topic-plugins
# ...                                                 ...
# 4570                                                bug
# 4571                                                bug
# 4572                                                bug
# 4573                              bug priority-1-normal
# 4574                                                bug
#
#                                                    body
# 0     The type of the following conditional expressi...
# 1     After #5870 is done, it would be nice to also ...
# 2     \r\n**Bug Report**\r\n\r\n#7963 causes a serio...
# 3     **Feature**\r\n\r\nWhen the implementation add...
# 4     [attrs](https://github.com/hynek/attrs) remove...
# ...                                                 ...
# 4570  <!--\r\n  If you're new to mypy and you're not...
# 4571  <!--\r\n  If you're new to mypy and you're not...
# 4572  **Bug Report**\r\n\r\n3rd party library I am u...
# 4573  Mypy infers that the type of `[*enumerate(["x"...
# 4574  <!--\r\n  If you're new to mypy and you're not...
#
# [4575 rows x 9 columns]

# %%
# Removing P1 and P2 since these are medium and low priority
pattern = 'priority-1-normal|priority-2-low'
# Remove pattern from df
random = random[~random['labels'].str.contains(pattern)]
random = random.reset_index(drop=True)
random
# Out:
#                 id         type           created_at         repo  \
# 0     1.362788e+10  IssuesEvent  2020-09-24 13:13:03  python/mypy
# 1     1.363241e+10  IssuesEvent  2020-09-24 19:36:27  python/mypy
# 2     2.407484e+10  IssuesEvent  2022-09-18 17:03:35  python/mypy
# 3     7.238785e+09  IssuesEvent  2018-02-13 15:37:22  python/mypy
# 4     3.912026e+09  IssuesEvent  2016-04-20 08:51:12  python/mypy
# ...            ...          ...                  ...          ...
# 3981  2.060491e+10  IssuesEvent  2022-03-06 20:42:52  python/mypy
# 3982  2.060497e+10  IssuesEvent  2022-03-06 20:54:33  python/mypy
# 3983  2.060505e+10  IssuesEvent  2022-03-06 21:09:50  python/mypy
# 3984  2.060518e+10  IssuesEvent  2022-03-06 21:33:34  python/mypy
# 3985  2.060567e+10  IssuesEvent  2022-03-06 23:08:52  python/mypy
#
#                                       repo_url    action  \
# 0     https://api.github.com/repos/python/mypy    opened
# 1     https://api.github.com/repos/python/mypy    opened
# 2     https://api.github.com/repos/python/mypy    opened
# 3     https://api.github.com/repos/python/mypy    closed
# 4     https://api.github.com/repos/python/mypy    closed
# ...                                        ...       ...
# 3981  https://api.github.com/repos/python/mypy    opened
# 3982  https://api.github.com/repos/python/mypy    closed
# 3983  https://api.github.com/repos/python/mypy  reopened
# 3984  https://api.github.com/repos/python/mypy    opened
# 3985  https://api.github.com/repos/python/mypy    closed
#
#                                                   title  \
# 0           Daemon support for --follow-imports=silent
# 1     regression: assignment of 'builtins.type' now ...
# 2     stubtest: more concise error for forgotten arg...
# 3                  Typechecking attrs-generated classes
# 4        Improve unification of conditional expressions
# ...                                                 ...
# 3981  Color output missing when errors redrected (wi...
# 3982  Color output missing when errors redrected (wi...
# 3983  Color output missing when errors redrected (wi...
# 3984  Getting Invalid "type: ignore" comment reports...
# 3985  Color output missing when errors redrected (wi...
#
#                                       labels  \
# 0                                    feature
# 1                                        bug
# 2                                    feature
# 3     feature needs discussion topic-plugins
# 4                                        bug
# ...                                      ...
# 3981                                     bug
# 3982                                     bug
# 3983                                     bug
# 3984                                     bug
# 3985                                     bug
#
#                                                    body
# 0     After #5870 is done, it would be nice to also ...
# 1     \r\n**Bug Report**\r\n\r\n#7963 causes a serio...
# 2     **Feature**\r\n\r\nWhen the implementation add...
# 3     [attrs](https://github.com/hynek/attrs) remove...
# 4     I have this snippet of code\r\n\r\n```python\r...
# ...                                                 ...
# 3981  <!--\r\n  If you're new to mypy and you're not...
# 3982  <!--\r\n  If you're new to mypy and you're not...
# 3983  <!--\r\n  If you're new to mypy and you're not...
# 3984  **Bug Report**\r\n\r\n3rd party library I am u...
# 3985  <!--\r\n  If you're new to mypy and you're not...
#
# [3986 rows x 9 columns]

# %%
random.labels.value_counts().to_frame()[:50]
# Out:
#                                       count
# labels
# bug                                    2266
# feature                                 443
# crash                                   190
# question                                 93
# documentation                            89
# needs discussion                         39
# bug topic-paramspec                      26
# bug topic-type-narrowing                 18
# bug topic-stubtest                       16
# topic-fine-grained-incremental           13
# topic-daemon                             12
# bug topic-protocols                      12
# feature needs discussion                 11
# bug topic-fine-grained-incremental       11
# affects/strict-optional                  10
# crash topic-match-statement              10
# bug topic-typed-dict                     10
# bug topic-type-variables                  9
# Crash                                     9
# bug topic-stubgen                         9
# feature topic-partially-defined           9
# bug topic-overloads                       9
# topic-usability                           9
# task                                      9
# crash topic-fine-grained-incremental      8
# refactoring                               8
# feature topic-type-narrowing              8
# meta                                      8
# bug topic-dataclasses                     7
# feature topic-configuration               7
# topic-new-parser                          6
# bug topic-inheritance                     6
# bug topic-reachability                    6
# stubs                                     6
# bug topic-enum                            6
# new-semantic-analyzer                     6
# feature topic-stubtest                    6
# crash topic-protocols                     5
# bug needs discussion                      5
# bug topic-type-ignore                     5
# difficulty/easy documentation             5
# crash topic-dataclasses                   5
# bug topic-self-types                      5
# topic-developer                           5
# feature topic-dataclasses                 5
# feature pep484                            5
# bug easy                                  5
# bug topic-join-v-union                    5
# bug topic-type-alias                      5
# Import Cycle                              5

# %%
# Number or different labels
hp.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# bug priority-0-high                                    46
# crash priority-0-high                                  39
# feature priority-0-high                                22
# bug false-positive priority-0-high                     19
# priority-0-high                                        16
# documentation priority-0-high                          11
# crash new-semantic-analyzer priority-0-high             9
# crash priority-0-high topic-fine-grained-increm...      9
# priority-0-high topic-usability                         7
# feature priority-0-high topic-usability                 7
# bug priority-0-high topic-fine-grained-incremental      6
# bug priority-0-high topic-daemon                        6
# priority-0-high topic-developer                         5
# bug false-positive priority-0-high topic-overloads      5
# bug false-positive new-semantic-analyzer priori...      5
# crash priority-0-high topic-daemon                      5
# priority-0-high meta                                    5
# bug crash priority-0-high                               5
# bug priority-0-high topic-type-variables                4
# bug priority-0-high topic-usability                     4
# performance priority-0-high                             4
# feature needs discussion priority-0-high                4
# bug priority-0-high affects-typeshed                    4
# bug priority-0-high topic-typed-dict                    4
# new-semantic-analyzer priority-0-high                   4
# good-first-issue priority-0-high topic-usability        4
# bug topic-type-variables priority-0-high                3
# bug priority-0-high topic-overloads topic-union...      3
# bug priority-0-high topic-protocols                     3
# bug false-positive priority-0-high topic-typed-...      3
# bug new-semantic-analyzer priority-0-high               3
# feature priority-0-high topic-typed-dict                3
# bug new-semantic-analyzer priority-0-high topic...      3
# crash priority-0-high topic-type-variables              2
# false-positive new-semantic-analyzer priority-0...      2
# feature needs discussion priority-0-high topic-...      2
# crash new-semantic-analyzer priority-0-high top...      2
# crash new-semantic-analyzer priority-0-high top...      2
# bug false-positive new-semantic-analyzer priori...      2
# bug needs discussion priority-0-high                    2
# false-positive priority-0-high                          2
# bug crash priority-0-high topic-daemon                  2
# bug false-positive priority-0-high topic-daemon         2
# priority-0-high topic-daemon                            2
# crash priority-0-high topic-pep-572                     2
# priority-0-high topic-typed-dict                        2
# bug priority-0-high topic-union-types                   2
# priority-0-high topic-parser                            2
# topic-incremental crash priority-0-high                 2
# priority-0-high refactoring                             2

# %%
#Give each priority a label by number.
# 'Label encoding'. Makes is easier for machine learning models to work with categorical data.
hp["label"] = 0
hp["class"] = "high_priority"
hp.head()
# Out:
#              id         type           created_at         repo  \
# 0  1.142707e+10  IssuesEvent  2020-02-03 23:35:24  python/mypy
# 1  2.655427e+10  IssuesEvent  2023-01-20 10:36:13  python/mypy
# 2  2.656236e+10  IssuesEvent  2023-01-20 16:54:26  python/mypy
# 3  5.439713e+09  IssuesEvent  2017-03-06 14:10:37  python/mypy
# 4  8.708969e+09  IssuesEvent  2018-12-06 12:35:33  python/mypy
#
#                                    repo_url  action  \
# 0  https://api.github.com/repos/python/mypy  closed
# 1  https://api.github.com/repos/python/mypy  opened
# 2  https://api.github.com/repos/python/mypy  closed
# 3  https://api.github.com/repos/python/mypy  closed
# 4  https://api.github.com/repos/python/mypy  closed
#
#                                                title  \
# 0    Type inference of Tuples returns object instead
# 1  Unbound type variable false positive with six....
# 2  Unbound type variable false positive with six....
# 3                  Crash in super() outside a method
# 4                TypedDict missing many dict methods
#
#                                               labels  \
# 0                 bug false-positive priority-0-high
# 1           bug topic-type-variables priority-0-high
# 2           bug topic-type-variables priority-0-high
# 3                              crash priority-0-high
# 4  bug false-positive priority-0-high topic-typed...
#
#                                                 body  label          class
# 0  While interacting with `zip` I encountered a v...      0  high_priority
# 1  This code generates a false positive:\r\n```py...      0  high_priority
# 2  This code generates a false positive:\r\n```py...      0  high_priority
# 3  The simplest repro:\r\n```python\r\nclass C:\r...      0  high_priority
# 4  mypy isn't recognizing methods of TypedDict.\r...      0  high_priority

# %%
random["label"] = 1
random["class"] = "not_high_priority" 
random.head()
# Out:
#              id         type           created_at         repo  \
# 0  1.362788e+10  IssuesEvent  2020-09-24 13:13:03  python/mypy
# 1  1.363241e+10  IssuesEvent  2020-09-24 19:36:27  python/mypy
# 2  2.407484e+10  IssuesEvent  2022-09-18 17:03:35  python/mypy
# 3  7.238785e+09  IssuesEvent  2018-02-13 15:37:22  python/mypy
# 4  3.912026e+09  IssuesEvent  2016-04-20 08:51:12  python/mypy
#
#                                    repo_url  action  \
# 0  https://api.github.com/repos/python/mypy  opened
# 1  https://api.github.com/repos/python/mypy  opened
# 2  https://api.github.com/repos/python/mypy  opened
# 3  https://api.github.com/repos/python/mypy  closed
# 4  https://api.github.com/repos/python/mypy  closed
#
#                                                title  \
# 0        Daemon support for --follow-imports=silent
# 1  regression: assignment of 'builtins.type' now ...
# 2  stubtest: more concise error for forgotten arg...
# 3               Typechecking attrs-generated classes
# 4     Improve unification of conditional expressions
#
#                                    labels  \
# 0                                 feature
# 1                                     bug
# 2                                 feature
# 3  feature needs discussion topic-plugins
# 4                                     bug
#
#                                                 body  label              class
# 0  After #5870 is done, it would be nice to also ...      1  not_high_priority
# 1  \r\n**Bug Report**\r\n\r\n#7963 causes a serio...      1  not_high_priority
# 2  **Feature**\r\n\r\nWhen the implementation add...      1  not_high_priority
# 3  [attrs](https://github.com/hynek/attrs) remove...      1  not_high_priority
# 4  I have this snippet of code\r\n\r\n```python\r...      1  not_high_priority

# %%
# Drop duplicates by the content of the title
high_priority = hp.drop_duplicates(subset=['title'], keep='last')
high_priority.dropna(inplace=True)
high_priority.reset_index(inplace=True)
high_priority.drop(columns=["index"] , inplace= True)
high_priority["class"].value_counts()
# Out:
# /tmp/ipykernel_166753/1823776403.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_priority.dropna(inplace=True)
# /tmp/ipykernel_166753/1823776403.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_priority.drop(columns=["index"] , inplace= True)
# class
# high_priority    368
# Name: count, dtype: int64

# %%
# Drop duplicates by the content of the title
not_high_priority = random.drop_duplicates(subset=['title'], keep='last')
not_high_priority.dropna(inplace=True)
not_high_priority.reset_index(inplace=True)
not_high_priority.drop(columns=["index"] , inplace= True)
not_high_priority["class"].value_counts()
# Out:
# /tmp/ipykernel_166753/3923262596.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority.dropna(inplace=True)
# /tmp/ipykernel_166753/3923262596.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority.drop(columns=["index"] , inplace= True)
# class
# not_high_priority    3096
# Name: count, dtype: int64

# %%
high_priority.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          368 non-null    float64
#  1   type        368 non-null    object
#  2   created_at  368 non-null    object
#  3   repo        368 non-null    object
#  4   repo_url    368 non-null    object
#  5   action      368 non-null    object
#  6   title       368 non-null    object
#  7   labels      368 non-null    object
#  8   body        368 non-null    object
#  9   label       368 non-null    int64
#  10  class       368 non-null    object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 31.8+ KB

# %%
label_counts = high_priority["class"].value_counts()
label_counts_nhp = not_high_priority["class"].value_counts()
print(label_counts)
not_high_priority_count = label_counts_nhp["not_high_priority"]
print(not_high_priority_count)
hp_count = label_counts["high_priority"]
hp_count
# Out:
# class
# high_priority    368
# Name: count, dtype: int64
# 3096
# 368

# %%
not_high_priority = not_high_priority.sample(frac=hp_count/not_high_priority_count, random_state=42)
not_high_priority
# Out:
#                 id         type           created_at         repo  \
# 1947  4.343434e+09  IssuesEvent  2016-07-29 01:46:13  python/mypy
# 1309  2.531361e+10  IssuesEvent  2022-11-17 19:33:57  python/mypy
# 1606  2.677817e+10  IssuesEvent  2023-01-31 18:49:00  python/mypy
# 2626  2.503724e+10  IssuesEvent  2022-11-04 17:04:02  python/mypy
# 2440  1.473940e+10  IssuesEvent  2021-01-07 07:07:46  python/mypy
# ...            ...          ...                  ...          ...
# 1064  1.495171e+10  IssuesEvent  2021-01-26 14:43:02  python/mypy
# 2856  2.462657e+10  IssuesEvent  2022-10-16 15:47:13  python/mypy
# 486   2.429792e+10  IssuesEvent  2022-09-29 11:40:24  python/mypy
# 2196  2.635768e+10  IssuesEvent  2023-01-11 10:56:55  python/mypy
# 1206  2.949752e+10  IssuesEvent  2023-06-02 18:20:21  python/mypy
#
#                                       repo_url  action  \
# 1947  https://api.github.com/repos/python/mypy  opened
# 1309  https://api.github.com/repos/python/mypy  opened
# 1606  https://api.github.com/repos/python/mypy  closed
# 2626  https://api.github.com/repos/python/mypy  opened
# 2440  https://api.github.com/repos/python/mypy  closed
# ...                                        ...     ...
# 1064  https://api.github.com/repos/python/mypy  opened
# 2856  https://api.github.com/repos/python/mypy  opened
# 486   https://api.github.com/repos/python/mypy  opened
# 2196  https://api.github.com/repos/python/mypy  opened
# 1206  https://api.github.com/repos/python/mypy  opened
#
#                                                   title  \
# 1947  Spurious error on Callables returning None, un...
# 1309                    Support __call__ on metaclasses
# 1606                   Gradual typing with a .lock file
# 2626  Using Generic and __new__ in class def, mypy m...
# 2440  Optional with a test still think it could be None
# ...                                                 ...
# 1064  Cannot suppress python_version-related errors ...
# 2856  Mypy uses installed Python version even when e...
# 486   A function returning TypeVar should receive at...
# 2196  Use mypy to check arrow.get().today() method p...
# 1206  Generic function parameter `type[T]` does not ...
#
#                        labels  \
# 1947  affects/strict-optional
# 1309                      bug
# 1606                  feature
# 2626                      bug
# 2440                      bug
# ...                       ...
# 1064                      bug
# 2856                      bug
# 486             documentation
# 2196                      bug
# 1206                      bug
#
#                                                    body  label  \
# 1947  Under `--strict-optional`, something goes wron...      1
# 1309  Currently we don't handle `__call__()` on meta...      1
# 1606  **Feature**\r\n\r\nIn existing untyped project...      1
# 2626  \r\n**Bug Report**\r\n\r\nThis came up in pand...      1
# 2440  <!--\r\n  If you're new to mypy and you're not...      1
# ...                                                 ...    ...
# 1064  **Bug Report**\r\n\r\nIf i have `python_versio...      1
# 2856  When running mypy under Python 3.8, I'm gettin...      1
# 486   **Documentation**\r\n\r\nmypy recently (first ...      1
# 2196  <!--\r\nIf you're not sure whether what you're...      1
# 1206  ### Bug Report\r\n\r\nA generic function with ...      1
#
#                   class
# 1947  not_high_priority
# 1309  not_high_priority
# 1606  not_high_priority
# 2626  not_high_priority
# 2440  not_high_priority
# ...                 ...
# 1064  not_high_priority
# 2856  not_high_priority
# 486   not_high_priority
# 2196  not_high_priority
# 1206  not_high_priority
#
# [368 rows x 11 columns]

# %%
all_priority = pd.concat([high_priority,not_high_priority] , ignore_index = True)
all_priority.tail()
# Out:
#                id         type           created_at         repo  \
# 731  1.495171e+10  IssuesEvent  2021-01-26 14:43:02  python/mypy
# 732  2.462657e+10  IssuesEvent  2022-10-16 15:47:13  python/mypy
# 733  2.429792e+10  IssuesEvent  2022-09-29 11:40:24  python/mypy
# 734  2.635768e+10  IssuesEvent  2023-01-11 10:56:55  python/mypy
# 735  2.949752e+10  IssuesEvent  2023-06-02 18:20:21  python/mypy
#
#                                      repo_url  action  \
# 731  https://api.github.com/repos/python/mypy  opened
# 732  https://api.github.com/repos/python/mypy  opened
# 733  https://api.github.com/repos/python/mypy  opened
# 734  https://api.github.com/repos/python/mypy  opened
# 735  https://api.github.com/repos/python/mypy  opened
#
#                                                  title         labels  \
# 731  Cannot suppress python_version-related errors ...            bug
# 732  Mypy uses installed Python version even when e...            bug
# 733  A function returning TypeVar should receive at...  documentation
# 734  Use mypy to check arrow.get().today() method p...            bug
# 735  Generic function parameter `type[T]` does not ...            bug
#
#                                                   body  label  \
# 731  **Bug Report**\r\n\r\nIf i have `python_versio...      1
# 732  When running mypy under Python 3.8, I'm gettin...      1
# 733  **Documentation**\r\n\r\nmypy recently (first ...      1
# 734  <!--\r\nIf you're not sure whether what you're...      1
# 735  ### Bug Report\r\n\r\nA generic function with ...      1
#
#                  class
# 731  not_high_priority
# 732  not_high_priority
# 733  not_high_priority
# 734  not_high_priority
# 735  not_high_priority

# %%
# 
all_priority["label"].value_counts()
# Out:
# label
# 0    368
# 1    368
# Name: count, dtype: int64

# %%
print(all_priority["title"][0])
print(all_priority["body"][0])
# Out:
# Type inference of Tuples returns object instead
# While interacting with `zip` I encountered a variant of the following error:
# ```
# error: No overload variant of "zip" matches argument types [builtins.list[builtins.int*], builtins.object*]
# ```
# which is emitted by mypy on the case of
# ```py
# out = list(
#     list(zip([1, 2], ordered_item))
#     for item in [(1, 2), (4, 5)]
#     for ordered_item in [item, tuple(reversed(item))]
#     )
# print(out)
# ```
# This code runs normally on python 3.6.5, outputting:
# ```
# [[(1, 1), (2, 2)], [(1, 2), (2, 1)], [(1, 4), (2, 5)], [(1, 5), (2, 4)]]
# ```
#
# ## Expected Behavior
# Mypy should infer that `ordered_item` is a tuple, or at least an iterable so that `zip` can be applied on it.
#
# It may also be interesting to consider the case where `ordered_item` is heterogenous over different `Iterables` (i.e. not only tuples). Would Iterable be inferred then?
#
# ## Actual Behavior
# Mypy infers the `object` type on `ordered_item` which you understandably cannot zip.
#
# By explicitly casting `item` to tuple the error message is resolved:
# ```py
# out = list(
#     list(zip([1, 2], ordered_item))
#     for item in [(1, 2), (4, 5)]
#     for ordered_item in [tuple(item), tuple(reversed(item))]
#     )
# print(out)
# ```
#
# ## Environment
# OS: macOS 10.13
# Python: 3.6.5
# mypy: 0.590

# %%
# Copy content of body to a new col named text
all_priority["text"] = all_priority["title"] + all_priority["body"]
all_priority.tail()
# Out:
#                id         type           created_at         repo  \
# 731  1.495171e+10  IssuesEvent  2021-01-26 14:43:02  python/mypy
# 732  2.462657e+10  IssuesEvent  2022-10-16 15:47:13  python/mypy
# 733  2.429792e+10  IssuesEvent  2022-09-29 11:40:24  python/mypy
# 734  2.635768e+10  IssuesEvent  2023-01-11 10:56:55  python/mypy
# 735  2.949752e+10  IssuesEvent  2023-06-02 18:20:21  python/mypy
#
#                                      repo_url  action  \
# 731  https://api.github.com/repos/python/mypy  opened
# 732  https://api.github.com/repos/python/mypy  opened
# 733  https://api.github.com/repos/python/mypy  opened
# 734  https://api.github.com/repos/python/mypy  opened
# 735  https://api.github.com/repos/python/mypy  opened
#
#                                                  title         labels  \
# 731  Cannot suppress python_version-related errors ...            bug
# 732  Mypy uses installed Python version even when e...            bug
# 733  A function returning TypeVar should receive at...  documentation
# 734  Use mypy to check arrow.get().today() method p...            bug
# 735  Generic function parameter `type[T]` does not ...            bug
#
#                                                   body  label  \
# 731  **Bug Report**\r\n\r\nIf i have `python_versio...      1
# 732  When running mypy under Python 3.8, I'm gettin...      1
# 733  **Documentation**\r\n\r\nmypy recently (first ...      1
# 734  <!--\r\nIf you're not sure whether what you're...      1
# 735  ### Bug Report\r\n\r\nA generic function with ...      1
#
#                  class                                               text
# 731  not_high_priority  Cannot suppress python_version-related errors ...
# 732  not_high_priority  Mypy uses installed Python version even when e...
# 733  not_high_priority  A function returning TypeVar should receive at...
# 734  not_high_priority  Use mypy to check arrow.get().today() method p...
# 735  not_high_priority  Generic function parameter `type[T]` does not ...

# %%
all_priority["text"][0]
# Out:
# 'Type inference of Tuples returns object insteadWhile interacting with `zip` I encountered a variant of the following error:\r\n```\r\nerror: No overload variant of "zip" matches argument types [builtins.list[builtins.int*], builtins.object*]\r\n```\r\nwhich is emitted by mypy on the case of\r\n```py\r\nout = list(\r\n    list(zip([1, 2], ordered_item))\r\n    for item in [(1, 2), (4, 5)]\r\n    for ordered_item in [item, tuple(reversed(item))]\r\n    )\r\nprint(out)\r\n```\r\nThis code runs normally on python 3.6.5, outputting:\r\n```\r\n[[(1, 1), (2, 2)], [(1, 2), (2, 1)], [(1, 4), (2, 5)], [(1, 5), (2, 4)]]\r\n```\r\n\r\n## Expected Behavior\r\nMypy should infer that `ordered_item` is a tuple, or at least an iterable so that `zip` can be applied on it.\r\n\r\nIt may also be interesting to consider the case where `ordered_item` is heterogenous over different `Iterables` (i.e. not only tuples). Would Iterable be inferred then?\r\n\r\n## Actual Behavior\r\nMypy infers the `object` type on `ordered_item` which you understandably cannot zip.\r\n\r\nBy explicitly casting `item` to tuple the error message is resolved:\r\n```py\r\nout = list(\r\n    list(zip([1, 2], ordered_item))\r\n    for item in [(1, 2), (4, 5)]\r\n    for ordered_item in [tuple(item), tuple(reversed(item))]\r\n    )\r\nprint(out)\r\n```\r\n\r\n## Environment\r\nOS: macOS 10.13\r\nPython: 3.6.5\r\nmypy: 0.590\r\n'

# %%
# Make a new dataframe with only text, label and class cols.
all_priority_subset = all_priority[["text" , "label" , "class"]]
all_priority_subset
# Out:
#                                                   text  label  \
# 0    Type inference of Tuples returns object instea...      0
# 1    Unbound type variable false positive with six....      0
# 2    Crash in super() outside a methodThe simplest ...      0
# 3    TypedDict missing many dict methodsmypy isn't ...      0
# 4    TypedDict and delMypy disallows `del td[key]` ...      0
# ..                                                 ...    ...
# 731  Cannot suppress python_version-related errors ...      1
# 732  Mypy uses installed Python version even when e...      1
# 733  A function returning TypeVar should receive at...      1
# 734  Use mypy to check arrow.get().today() method p...      1
# 735  Generic function parameter `type[T]` does not ...      1
#
#                  class
# 0        high_priority
# 1        high_priority
# 2        high_priority
# 3        high_priority
# 4        high_priority
# ..                 ...
# 731  not_high_priority
# 732  not_high_priority
# 733  not_high_priority
# 734  not_high_priority
# 735  not_high_priority
#
# [736 rows x 3 columns]

# %%
# Convert to string
all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)
# Out:
# /tmp/ipykernel_166753/3106036705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)

# %%
all_priority_subset
# Out:
#                                                   text  label  \
# 0    Type inference of Tuples returns object instea...      0
# 1    Unbound type variable false positive with six....      0
# 2    Crash in super() outside a methodThe simplest ...      0
# 3    TypedDict missing many dict methodsmypy isn't ...      0
# 4    TypedDict and delMypy disallows `del td[key]` ...      0
# ..                                                 ...    ...
# 731  Cannot suppress python_version-related errors ...      1
# 732  Mypy uses installed Python version even when e...      1
# 733  A function returning TypeVar should receive at...      1
# 734  Use mypy to check arrow.get().today() method p...      1
# 735  Generic function parameter `type[T]` does not ...      1
#
#                  class                                           text_str
# 0        high_priority  Type inference of Tuples returns object instea...
# 1        high_priority  Unbound type variable false positive with six....
# 2        high_priority  Crash in super() outside a methodThe simplest ...
# 3        high_priority  TypedDict missing many dict methodsmypy isn't ...
# 4        high_priority  TypedDict and delMypy disallows `del td[key]` ...
# ..                 ...                                                ...
# 731  not_high_priority  Cannot suppress python_version-related errors ...
# 732  not_high_priority  Mypy uses installed Python version even when e...
# 733  not_high_priority  A function returning TypeVar should receive at...
# 734  not_high_priority  Use mypy to check arrow.get().today() method p...
# 735  not_high_priority  Generic function parameter `type[T]` does not ...
#
# [736 rows x 4 columns]

# %%
# Clean the data.
all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_166753/63294665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)

# %%
# Make a subset with text_clean and label
priority_label_text = all_priority_subset[["text_clean" , "label"]]
priority_label_text
# Out:
#                                             text_clean  label
# 0    type inference of tuples returns object instea...      0
# 1    unbound type variable false positive with sixw...      0
# 2    crash in super outside a methodthe simplest re...      0
# 3    typeddict missing many dict methodsmypy isnt r...      0
# 4    typeddict and delmypy disallows del tdkey for ...      0
# ..                                                 ...    ...
# 731  cannot suppress pythonversionrelated errors in...      1
# 732  mypy uses installed python version even when e...      1
# 733  a function returning typevar should receive at...      1
# 734  use mypy to check arrowgettoday method prompt ...      1
# 735  generic function parameter typet does not allo...      1
#
# [736 rows x 2 columns]

# %%
# Need to dropna here since cleaning function returns NaN for not english text.
priority_label_text.dropna(inplace=True)
priority_label_text.reset_index(inplace=True)
priority_label_text.drop(columns=["index"] , inplace= True)

priority_label_text
# Out:
# /tmp/ipykernel_166753/239147930.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.dropna(inplace=True)
# /tmp/ipykernel_166753/239147930.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.drop(columns=["index"] , inplace= True)
#                                             text_clean  label
# 0    type inference of tuples returns object instea...      0
# 1    unbound type variable false positive with sixw...      0
# 2    crash in super outside a methodthe simplest re...      0
# 3    typeddict missing many dict methodsmypy isnt r...      0
# 4    typeddict and delmypy disallows del tdkey for ...      0
# ..                                                 ...    ...
# 730  cannot suppress pythonversionrelated errors in...      1
# 731  mypy uses installed python version even when e...      1
# 732  a function returning typevar should receive at...      1
# 733  use mypy to check arrowgettoday method prompt ...      1
# 734  generic function parameter typet does not allo...      1
#
# [735 rows x 2 columns]

# %%
from sklearn.utils import resample

# Split the dataset into two based on the label
df_majority = priority_label_text[priority_label_text['label'] == 1]
df_minority = priority_label_text[priority_label_text['label'] == 0]

# Undersample the majority class
df_majority_undersampled = resample(df_majority, 
                                     replace=False,    # sample without replacement
                                     n_samples=len(df_minority),     # to match minority class
                                     random_state=123) # reproducible results

# Combine minority class with downsampled majority class
df_balanced = pd.concat([df_majority_undersampled, df_minority])

# Shuffle the dataset to avoid any ordering bias
df_balanced = df_balanced.sample(frac=1).reset_index(drop=True)
priority_label_text = df_balanced
priority_label_text["label"].value_counts()
# Out:
# label
# 1    367
# 0    367
# Name: count, dtype: int64

# %%
# Clean dataset with clean text and labels.
# 0 = high priority, 1 = not high priority
file_name = f"csv/clean_mypy_testset.csv"
priority_label_text.to_csv(file_name, index=False)

# %%
pri = pd.read_csv(file_name)
pri
# Out:
#                                             text_clean  label
# 0    callable with a concrete subtype as a paramete...      1
# 1    regression lambda within class body causes a c...      0
# 2    ignore specific importsfeature apologies if th...      1
# 3    performance regression 0770 0780after upgradin...      0
# 4    support type aliases in finegrained incrementa...      0
# ..                                                 ...    ...
# 729  slow incremental run when single module has er...      0
# 730  metaclass doesnt work across import cyclei hav...      0
# 731  new semantic analyser establish and document t...      0
# 732  mypy doesnt realize none is an instance of typ...      1
# 733  internal error when enabling reports note if t...      1
#
# [734 rows x 2 columns]
