# %% [markdown]
# # Data cleaning
# We want the class with labels as numerical value and the body with clean text.
#
# This will:
# * Remove duplicates
# * Remove NaN entires

# %%
import pandas as pd
import re
from string import punctuation
import numpy as np
import emoji
import sys
sys.path.append("../../scripts_shared/")
from preprocess_text import preprocess_text

# %%
priority = pd.read_csv("full_dataset_priority_high_med_low.csv" , index_col=0)
priority
# Out:
#                  id         type           created_at  \
# 0      1.675131e+10  IssuesEvent  2021-06-12 00:20:05
# 1      1.675179e+10  IssuesEvent  2021-06-12 02:13:44
# 2      1.675179e+10  IssuesEvent  2021-06-12 02:14:42
# 3      1.675189e+10  IssuesEvent  2021-06-12 02:40:12
# 4      1.675203e+10  IssuesEvent  2021-06-12 03:17:18
# ...             ...          ...                  ...
# 26371  1.593657e+10  IssuesEvent  2021-04-14 11:20:08
# 26372  1.593706e+10  IssuesEvent  2021-04-14 11:59:33
# 26373  1.593712e+10  IssuesEvent  2021-04-14 12:03:28
# 26374  1.593712e+10  IssuesEvent  2021-04-14 12:04:08
# 26375  1.593760e+10  IssuesEvent  2021-04-14 12:40:00
#
#                                          repo  \
# 0                NoahOrtega/Blue-Coin-Tracker
# 1                        adirh3/Fluent-Search
# 2                        adirh3/Fluent-Search
# 3                                 SwatInc/CD4
# 4      eclipse/che-che4z-explorer-for-endevor
# ...                                       ...
# 26371             inf112-v21/Trivial-Solution
# 26372             Gird-the-Grid/Grid-the-Grid
# 26373             Gird-the-Grid/Grid-the-Grid
# 26374             Gird-the-Grid/Grid-the-Grid
# 26375                   brian-team/brian2cuda
#
#                                                 repo_url  action  \
# 0      https://api.github.com/repos/NoahOrtega/Blue-C...  closed
# 1      https://api.github.com/repos/adirh3/Fluent-Search  closed
# 2      https://api.github.com/repos/adirh3/Fluent-Search  closed
# 3               https://api.github.com/repos/SwatInc/CD4  closed
# 4      https://api.github.com/repos/eclipse/che-che4z...  opened
# ...                                                  ...     ...
# 26371  https://api.github.com/repos/inf112-v21/Trivia...  closed
# 26372  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 26373  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 26374  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 26375  https://api.github.com/repos/brian-team/brian2...  closed
#
#                                                    title  \
# 0      Setting darkmode during launch causes crash on...
# 1              Context Prioritization Ignore not working
# 2                                   Search text glitches
# 3                      Generate report by Episode number
# 4      Error files.encoding generate ï¿½ or � and tha...
# ...                                                  ...
# 26371  Som spiller vil jeg ha flere forskjellige kart...
# 26372                            Catch general exception
# 26373                       Backend reset password route
# 26374                            Frontend reset password
# 26375  Sort EventMonitor data by index within each ti...
#
#                                     labels  \
# 0                        bug high priority
# 1                        High Priority bug
# 2                  High Priority UI/UX bug
# 3      High Priority Reporting enhancement
# 4                            High Priority
# ...                                    ...
# 26371              Low priority User Story
# 26372   good practices low priority repair
# 26373             enhancement low priority
# 26374             enhancement low priority
# 26375               low priority usability
#
#                                                     body  index          class
# 0      Setting dark mode in onCreate() in the main ac...    1.0  high_priority
# 1      **Describe the bug**\r\nWhen I add a folder pa...    1.0  high_priority
# 2      **Describe the bug**\r\nAfter invoking the sea...    1.0  high_priority
# 3      The current reports are all, generated by samp...    1.0  high_priority
# 4      We have an issue when we browse or retrieve an...    1.0  high_priority
# ...                                                  ...    ...            ...
# 26371  Krav:\r\n- Antall maps i mappen 'maps' skal væ...    1.0   low_priority
# 26372  * some routes do throw exceptions other than t...    1.0   low_priority
# 26373  * Add `POST /auth/reset_request` route which r...    1.0   low_priority
# 26374  * Add `Forgot Password` button on login page\r...    1.0   low_priority
# 26375  Currently our `EventMonitor` (~ `SpikeMonitor`...    1.0   low_priority
#
# [26372 rows x 11 columns]

# %%
#Number of issues per class
priority["class"].value_counts()
# Out:
# class
# high_priority      14334
# low_priority        7379
# medium_priority     4659
# Name: count, dtype: int64

# %%
# Split the dataframe 
high_priority = priority.loc[priority['class'] == 'high_priority'].copy()
medium_priority = priority.loc[priority['class'] == 'medium_priority'].copy()
low_priority = priority.loc[priority['class'] == 'low_priority'].copy()

# %%
high_priority.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14334 entries, 0 to 14337
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          14334 non-null  float64
#  1   type        14334 non-null  object
#  2   created_at  14334 non-null  object
#  3   repo        14334 non-null  object
#  4   repo_url    14334 non-null  object
#  5   action      14334 non-null  object
#  6   title       14334 non-null  object
#  7   labels      14334 non-null  object
#  8   body        12376 non-null  object
#  9   index       14334 non-null  float64
#  10  class       14334 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 1.3+ MB

# %%
#Give each priority a label by number.
# 'Label encoding'. Makes is easier for machine learning models to work with categorical data.
high_priority["label"] = 0
high_priority.head()
# Out:
#              id         type           created_at  \
# 0  1.675131e+10  IssuesEvent  2021-06-12 00:20:05
# 1  1.675179e+10  IssuesEvent  2021-06-12 02:13:44
# 2  1.675179e+10  IssuesEvent  2021-06-12 02:14:42
# 3  1.675189e+10  IssuesEvent  2021-06-12 02:40:12
# 4  1.675203e+10  IssuesEvent  2021-06-12 03:17:18
#
#                                      repo  \
# 0            NoahOrtega/Blue-Coin-Tracker
# 1                    adirh3/Fluent-Search
# 2                    adirh3/Fluent-Search
# 3                             SwatInc/CD4
# 4  eclipse/che-che4z-explorer-for-endevor
#
#                                             repo_url  action  \
# 0  https://api.github.com/repos/NoahOrtega/Blue-C...  closed
# 1  https://api.github.com/repos/adirh3/Fluent-Search  closed
# 2  https://api.github.com/repos/adirh3/Fluent-Search  closed
# 3           https://api.github.com/repos/SwatInc/CD4  closed
# 4  https://api.github.com/repos/eclipse/che-che4z...  opened
#
#                                                title  \
# 0  Setting darkmode during launch causes crash on...
# 1          Context Prioritization Ignore not working
# 2                               Search text glitches
# 3                  Generate report by Episode number
# 4  Error files.encoding generate ï¿½ or � and tha...
#
#                                 labels  \
# 0                    bug high priority
# 1                    High Priority bug
# 2              High Priority UI/UX bug
# 3  High Priority Reporting enhancement
# 4                        High Priority
#
#                                                 body  index          class  \
# 0  Setting dark mode in onCreate() in the main ac...    1.0  high_priority
# 1  **Describe the bug**\r\nWhen I add a folder pa...    1.0  high_priority
# 2  **Describe the bug**\r\nAfter invoking the sea...    1.0  high_priority
# 3  The current reports are all, generated by samp...    1.0  high_priority
# 4  We have an issue when we browse or retrieve an...    1.0  high_priority
#
#    label
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
medium_priority["label"] = 1
medium_priority.head()
# Out:
#                  id         type           created_at  \
# 14338  1.675181e+10  IssuesEvent  2021-06-12 02:18:55
# 14339  1.675184e+10  IssuesEvent  2021-06-12 02:27:07
# 14340  1.612969e+10  IssuesEvent  2021-04-29 01:16:17
# 14341  1.612976e+10  IssuesEvent  2021-04-29 01:27:17
# 14342  1.612978e+10  IssuesEvent  2021-04-29 01:31:03
#
#                             repo  \
# 14338       adirh3/Fluent-Search
# 14339       adirh3/Fluent-Search
# 14340     StatisticsNZ/simplevis
# 14341  KingSupernova31/RulesGuru
# 14342  KingSupernova31/RulesGuru
#
#                                                 repo_url  action  \
# 14338  https://api.github.com/repos/adirh3/Fluent-Search  closed
# 14339  https://api.github.com/repos/adirh3/Fluent-Search  closed
# 14340  https://api.github.com/repos/StatisticsNZ/simp...  opened
# 14341  https://api.github.com/repos/KingSupernova31/R...  opened
# 14342  https://api.github.com/repos/KingSupernova31/R...  opened
#
#                                                    title  \
# 14338     Drag and drop often shows restricted icon (🚫)
# 14339                                        Ignore Tags
# 14340  numeric breaks: log or log10 trans does not wo...
# 14341                   Add a "notes" field on questions
# 14342  Don't allow a question to have the same editor...
#
#                             labels  \
# 14338          Medium Priority bug
# 14339          Medium Priority bug
# 14340              medium priority
# 14341  enhancement medium priority
# 14342  enhancement medium priority
#
#                                                     body  index  \
# 14338  **Describe the bug**\r\nWhile trying to drag a...    1.0
# 14339  There is a lot of tags which I don't know what...    1.0
# 14340                                                NaN    1.0
# 14341  Questions should have a "notes" field. This fi...    1.0
# 14342  Right now, if an admin has both the "Editor" a...    1.0
#
#                  class  label
# 14338  medium_priority      1
# 14339  medium_priority      1
# 14340  medium_priority      1
# 14341  medium_priority      1
# 14342  medium_priority      1

# %%
low_priority["label"] = 2
low_priority.head()
# Out:
#                  id         type           created_at  \
# 18997  1.675160e+10  IssuesEvent  2021-06-12 01:26:20
# 18998  1.675165e+10  IssuesEvent  2021-06-12 01:37:40
# 18999  1.612979e+10  IssuesEvent  2021-04-29 01:32:47
# 19000  1.612980e+10  IssuesEvent  2021-04-29 01:34:02
# 19001  1.613008e+10  IssuesEvent  2021-04-29 02:19:14
#
#                                  repo  \
# 18997           Sequel-Ace/Sequel-Ace
# 18998                    DoobDev/Doob
# 18999       KingSupernova31/RulesGuru
# 19000       KingSupernova31/RulesGuru
# 19001  inaturalist/iNaturalistAndroid
#
#                                                 repo_url    action  \
# 18997  https://api.github.com/repos/Sequel-Ace/Sequel...    closed
# 18998          https://api.github.com/repos/DoobDev/Doob  reopened
# 18999  https://api.github.com/repos/KingSupernova31/R...    opened
# 19000  https://api.github.com/repos/KingSupernova31/R...    opened
# 19001  https://api.github.com/repos/inaturalist/iNatu...    closed
#
#                                                    title  \
# 18997                       slow to connect via proxysql
# 18998                                Redo the Help menu!
# 18999        Have discord bot automatically assign roles
# 19000          Jumping to editor forgets question number
# 19001  Prevent crashes from encoding problems in the ...
#
#                                               labels  \
# 18997  Feature Request Low priority PR Welcome stale
# 18998                   Low Priority feature_request
# 18999                       enhancement low priority
# 19000              bug good first issue low priority
# 19001                               Low Priority bug
#
#                                                     body  index         class  \
# 18997  \r\n- Sequel Ace Version (including build numb...    1.0  low_priority
# 18998  It's ugly right now.\r\n\r\n- [ ] Separate com...    1.0  low_priority
# 18999  RG has internal roles for all its admins, and ...    1.0  low_priority
# 19000  Typing the sequence of characters "admin" on a...    1.0  low_priority
# 19001  https://console.firebase.google.com/u/2/projec...    1.0  low_priority
#
#        label
# 18997      2
# 18998      2
# 18999      2
# 19000      2
# 19001      2

# %%
#Non_priority = Non_priority.sample(frac=0.15)

# %%
priority = pd.concat([high_priority, medium_priority, low_priority] , ignore_index = True)
priority.tail()
# Out:
#                  id         type           created_at  \
# 26367  1.593657e+10  IssuesEvent  2021-04-14 11:20:08
# 26368  1.593706e+10  IssuesEvent  2021-04-14 11:59:33
# 26369  1.593712e+10  IssuesEvent  2021-04-14 12:03:28
# 26370  1.593712e+10  IssuesEvent  2021-04-14 12:04:08
# 26371  1.593760e+10  IssuesEvent  2021-04-14 12:40:00
#
#                               repo  \
# 26367  inf112-v21/Trivial-Solution
# 26368  Gird-the-Grid/Grid-the-Grid
# 26369  Gird-the-Grid/Grid-the-Grid
# 26370  Gird-the-Grid/Grid-the-Grid
# 26371        brian-team/brian2cuda
#
#                                                 repo_url  action  \
# 26367  https://api.github.com/repos/inf112-v21/Trivia...  closed
# 26368  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 26369  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 26370  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 26371  https://api.github.com/repos/brian-team/brian2...  closed
#
#                                                    title  \
# 26367  Som spiller vil jeg ha flere forskjellige kart...
# 26368                            Catch general exception
# 26369                       Backend reset password route
# 26370                            Frontend reset password
# 26371  Sort EventMonitor data by index within each ti...
#
#                                    labels  \
# 26367             Low priority User Story
# 26368  good practices low priority repair
# 26369            enhancement low priority
# 26370            enhancement low priority
# 26371              low priority usability
#
#                                                     body  index         class  \
# 26367  Krav:\r\n- Antall maps i mappen 'maps' skal væ...    1.0  low_priority
# 26368  * some routes do throw exceptions other than t...    1.0  low_priority
# 26369  * Add `POST /auth/reset_request` route which r...    1.0  low_priority
# 26370  * Add `Forgot Password` button on login page\r...    1.0  low_priority
# 26371  Currently our `EventMonitor` (~ `SpikeMonitor`...    1.0  low_priority
#
#        label
# 26367      2
# 26368      2
# 26369      2
# 26370      2
# 26371      2

# %%
#data[data["repo"] == "microsoft/vscode"]

# %%
# Drop duplicates by the content of the body
all_priority = priority.drop_duplicates(subset=['body'], keep='last')

# %%
all_priority.dropna(inplace=True)
# Out:
# /tmp/ipykernel_88890/2768040423.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority.dropna(inplace=True)

# %%
all_priority
# Out:
#                  id         type           created_at  \
# 1      1.675179e+10  IssuesEvent  2021-06-12 02:13:44
# 2      1.675179e+10  IssuesEvent  2021-06-12 02:14:42
# 3      1.675189e+10  IssuesEvent  2021-06-12 02:40:12
# 5      1.675205e+10  IssuesEvent  2021-06-12 03:20:33
# 6      1.612937e+10  IssuesEvent  2021-04-29 00:27:52
# ...             ...          ...                  ...
# 26367  1.593657e+10  IssuesEvent  2021-04-14 11:20:08
# 26368  1.593706e+10  IssuesEvent  2021-04-14 11:59:33
# 26369  1.593712e+10  IssuesEvent  2021-04-14 12:03:28
# 26370  1.593712e+10  IssuesEvent  2021-04-14 12:04:08
# 26371  1.593760e+10  IssuesEvent  2021-04-14 12:40:00
#
#                                          repo  \
# 1                        adirh3/Fluent-Search
# 2                        adirh3/Fluent-Search
# 3                                 SwatInc/CD4
# 5      eclipse/che-che4z-explorer-for-endevor
# 6         CredentialEngine/CredentialRegistry
# ...                                       ...
# 26367             inf112-v21/Trivial-Solution
# 26368             Gird-the-Grid/Grid-the-Grid
# 26369             Gird-the-Grid/Grid-the-Grid
# 26370             Gird-the-Grid/Grid-the-Grid
# 26371                   brian-team/brian2cuda
#
#                                                 repo_url  action  \
# 1      https://api.github.com/repos/adirh3/Fluent-Search  closed
# 2      https://api.github.com/repos/adirh3/Fluent-Search  closed
# 3               https://api.github.com/repos/SwatInc/CD4  closed
# 5      https://api.github.com/repos/eclipse/che-che4z...  opened
# 6      https://api.github.com/repos/CredentialEngine/...  opened
# ...                                                  ...     ...
# 26367  https://api.github.com/repos/inf112-v21/Trivia...  closed
# 26368  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 26369  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 26370  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 26371  https://api.github.com/repos/brian-team/brian2...  closed
#
#                                                    title  \
# 1              Context Prioritization Ignore not working
# 2                                   Search text glitches
# 3                      Generate report by Episode number
# 5      Generate  issue with the plugin Broadcom Explo...
# 6             Sandbox has been unresponsive a lot today
# ...                                                  ...
# 26367  Som spiller vil jeg ha flere forskjellige kart...
# 26368                            Catch general exception
# 26369                       Backend reset password route
# 26370                            Frontend reset password
# 26371  Sort EventMonitor data by index within each ti...
#
#                                     labels  \
# 1                        High Priority bug
# 2                  High Priority UI/UX bug
# 3      High Priority Reporting enhancement
# 5                            High Priority
# 6                            High Priority
# ...                                    ...
# 26367              Low priority User Story
# 26368   good practices low priority repair
# 26369             enhancement low priority
# 26370             enhancement low priority
# 26371               low priority usability
#
#                                                     body  index  \
# 1      **Describe the bug**\r\nWhen I add a folder pa...    1.0
# 2      **Describe the bug**\r\nAfter invoking the sea...    1.0
# 3      The current reports are all, generated by samp...    1.0
# 5      E4E is generating in place. If I have an eleme...    1.0
# 6      @excelsior @edgarf \r\nThe sandbox server is n...    1.0
# ...                                                  ...    ...
# 26367  Krav:\r\n- Antall maps i mappen 'maps' skal væ...    1.0
# 26368  * some routes do throw exceptions other than t...    1.0
# 26369  * Add `POST /auth/reset_request` route which r...    1.0
# 26370  * Add `Forgot Password` button on login page\r...    1.0
# 26371  Currently our `EventMonitor` (~ `SpikeMonitor`...    1.0
#
#                class  label
# 1      high_priority      0
# 2      high_priority      0
# 3      high_priority      0
# 5      high_priority      0
# 6      high_priority      0
# ...              ...    ...
# 26367   low_priority      2
# 26368   low_priority      2
# 26369   low_priority      2
# 26370   low_priority      2
# 26371   low_priority      2
#
# [19611 rows x 12 columns]

# %%
# Resets the index
all_priority.reset_index(inplace=True)
all_priority
# Out:
#        level_0            id         type           created_at  \
# 0            1  1.675179e+10  IssuesEvent  2021-06-12 02:13:44
# 1            2  1.675179e+10  IssuesEvent  2021-06-12 02:14:42
# 2            3  1.675189e+10  IssuesEvent  2021-06-12 02:40:12
# 3            5  1.675205e+10  IssuesEvent  2021-06-12 03:20:33
# 4            6  1.612937e+10  IssuesEvent  2021-04-29 00:27:52
# ...        ...           ...          ...                  ...
# 19606    26367  1.593657e+10  IssuesEvent  2021-04-14 11:20:08
# 19607    26368  1.593706e+10  IssuesEvent  2021-04-14 11:59:33
# 19608    26369  1.593712e+10  IssuesEvent  2021-04-14 12:03:28
# 19609    26370  1.593712e+10  IssuesEvent  2021-04-14 12:04:08
# 19610    26371  1.593760e+10  IssuesEvent  2021-04-14 12:40:00
#
#                                          repo  \
# 0                        adirh3/Fluent-Search
# 1                        adirh3/Fluent-Search
# 2                                 SwatInc/CD4
# 3      eclipse/che-che4z-explorer-for-endevor
# 4         CredentialEngine/CredentialRegistry
# ...                                       ...
# 19606             inf112-v21/Trivial-Solution
# 19607             Gird-the-Grid/Grid-the-Grid
# 19608             Gird-the-Grid/Grid-the-Grid
# 19609             Gird-the-Grid/Grid-the-Grid
# 19610                   brian-team/brian2cuda
#
#                                                 repo_url  action  \
# 0      https://api.github.com/repos/adirh3/Fluent-Search  closed
# 1      https://api.github.com/repos/adirh3/Fluent-Search  closed
# 2               https://api.github.com/repos/SwatInc/CD4  closed
# 3      https://api.github.com/repos/eclipse/che-che4z...  opened
# 4      https://api.github.com/repos/CredentialEngine/...  opened
# ...                                                  ...     ...
# 19606  https://api.github.com/repos/inf112-v21/Trivia...  closed
# 19607  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 19608  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 19609  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 19610  https://api.github.com/repos/brian-team/brian2...  closed
#
#                                                    title  \
# 0              Context Prioritization Ignore not working
# 1                                   Search text glitches
# 2                      Generate report by Episode number
# 3      Generate  issue with the plugin Broadcom Explo...
# 4             Sandbox has been unresponsive a lot today
# ...                                                  ...
# 19606  Som spiller vil jeg ha flere forskjellige kart...
# 19607                            Catch general exception
# 19608                       Backend reset password route
# 19609                            Frontend reset password
# 19610  Sort EventMonitor data by index within each ti...
#
#                                     labels  \
# 0                        High Priority bug
# 1                  High Priority UI/UX bug
# 2      High Priority Reporting enhancement
# 3                            High Priority
# 4                            High Priority
# ...                                    ...
# 19606              Low priority User Story
# 19607   good practices low priority repair
# 19608             enhancement low priority
# 19609             enhancement low priority
# 19610               low priority usability
#
#                                                     body  index  \
# 0      **Describe the bug**\r\nWhen I add a folder pa...    1.0
# 1      **Describe the bug**\r\nAfter invoking the sea...    1.0
# 2      The current reports are all, generated by samp...    1.0
# 3      E4E is generating in place. If I have an eleme...    1.0
# 4      @excelsior @edgarf \r\nThe sandbox server is n...    1.0
# ...                                                  ...    ...
# 19606  Krav:\r\n- Antall maps i mappen 'maps' skal væ...    1.0
# 19607  * some routes do throw exceptions other than t...    1.0
# 19608  * Add `POST /auth/reset_request` route which r...    1.0
# 19609  * Add `Forgot Password` button on login page\r...    1.0
# 19610  Currently our `EventMonitor` (~ `SpikeMonitor`...    1.0
#
#                class  label
# 0      high_priority      0
# 1      high_priority      0
# 2      high_priority      0
# 3      high_priority      0
# 4      high_priority      0
# ...              ...    ...
# 19606   low_priority      2
# 19607   low_priority      2
# 19608   low_priority      2
# 19609   low_priority      2
# 19610   low_priority      2
#
# [19611 rows x 13 columns]

# %%
# Does this need to be more balanced?
all_priority["label"].value_counts()
# Out:
# label
# 0    10497
# 2     5683
# 1     3431
# Name: count, dtype: int64

# %%
all_priority.drop(columns=["index"] , inplace= True)
# Out:
# /tmp/ipykernel_88890/2269905686.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority.drop(columns=["index"] , inplace= True)

# %%
# Copy content of body to a new col named text
# Why?
all_priority["text"] = all_priority["body"]
all_priority.tail()
# Out:
# /tmp/ipykernel_88890/1678713137.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority["text"] = all_priority["body"]
#        level_0            id         type           created_at  \
# 19606    26367  1.593657e+10  IssuesEvent  2021-04-14 11:20:08
# 19607    26368  1.593706e+10  IssuesEvent  2021-04-14 11:59:33
# 19608    26369  1.593712e+10  IssuesEvent  2021-04-14 12:03:28
# 19609    26370  1.593712e+10  IssuesEvent  2021-04-14 12:04:08
# 19610    26371  1.593760e+10  IssuesEvent  2021-04-14 12:40:00
#
#                               repo  \
# 19606  inf112-v21/Trivial-Solution
# 19607  Gird-the-Grid/Grid-the-Grid
# 19608  Gird-the-Grid/Grid-the-Grid
# 19609  Gird-the-Grid/Grid-the-Grid
# 19610        brian-team/brian2cuda
#
#                                                 repo_url  action  \
# 19606  https://api.github.com/repos/inf112-v21/Trivia...  closed
# 19607  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 19608  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 19609  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 19610  https://api.github.com/repos/brian-team/brian2...  closed
#
#                                                    title  \
# 19606  Som spiller vil jeg ha flere forskjellige kart...
# 19607                            Catch general exception
# 19608                       Backend reset password route
# 19609                            Frontend reset password
# 19610  Sort EventMonitor data by index within each ti...
#
#                                    labels  \
# 19606             Low priority User Story
# 19607  good practices low priority repair
# 19608            enhancement low priority
# 19609            enhancement low priority
# 19610              low priority usability
#
#                                                     body         class  label  \
# 19606  Krav:\r\n- Antall maps i mappen 'maps' skal væ...  low_priority      2
# 19607  * some routes do throw exceptions other than t...  low_priority      2
# 19608  * Add `POST /auth/reset_request` route which r...  low_priority      2
# 19609  * Add `Forgot Password` button on login page\r...  low_priority      2
# 19610  Currently our `EventMonitor` (~ `SpikeMonitor`...  low_priority      2
#
#                                                     text
# 19606  Krav:\r\n- Antall maps i mappen 'maps' skal væ...
# 19607  * some routes do throw exceptions other than t...
# 19608  * Add `POST /auth/reset_request` route which r...
# 19609  * Add `Forgot Password` button on login page\r...
# 19610  Currently our `EventMonitor` (~ `SpikeMonitor`...

# %%
# Make a new dataframe with only text, label and class cols.
all_priority_subset = all_priority[["text" , "label" , "class"]]

# %%
all_priority_subset
# Out:
#                                                     text  label          class
# 0      **Describe the bug**\r\nWhen I add a folder pa...      0  high_priority
# 1      **Describe the bug**\r\nAfter invoking the sea...      0  high_priority
# 2      The current reports are all, generated by samp...      0  high_priority
# 3      E4E is generating in place. If I have an eleme...      0  high_priority
# 4      @excelsior @edgarf \r\nThe sandbox server is n...      0  high_priority
# ...                                                  ...    ...            ...
# 19606  Krav:\r\n- Antall maps i mappen 'maps' skal væ...      2   low_priority
# 19607  * some routes do throw exceptions other than t...      2   low_priority
# 19608  * Add `POST /auth/reset_request` route which r...      2   low_priority
# 19609  * Add `Forgot Password` button on login page\r...      2   low_priority
# 19610  Currently our `EventMonitor` (~ `SpikeMonitor`...      2   low_priority
#
# [19611 rows x 3 columns]

# %%
# What is this for?
all_priority_subset.to_csv("subset_priority_dataset.csv")

# %%
# Convert to string
all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)
# Out:
# /tmp/ipykernel_88890/3106036705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)

# %%
all_priority_subset
# Out:
#                                                     text  label  \
# 0      **Describe the bug**\r\nWhen I add a folder pa...      0
# 1      **Describe the bug**\r\nAfter invoking the sea...      0
# 2      The current reports are all, generated by samp...      0
# 3      E4E is generating in place. If I have an eleme...      0
# 4      @excelsior @edgarf \r\nThe sandbox server is n...      0
# ...                                                  ...    ...
# 19606  Krav:\r\n- Antall maps i mappen 'maps' skal væ...      2
# 19607  * some routes do throw exceptions other than t...      2
# 19608  * Add `POST /auth/reset_request` route which r...      2
# 19609  * Add `Forgot Password` button on login page\r...      2
# 19610  Currently our `EventMonitor` (~ `SpikeMonitor`...      2
#
#                class                                           text_str
# 0      high_priority  **Describe the bug**\r\nWhen I add a folder pa...
# 1      high_priority  **Describe the bug**\r\nAfter invoking the sea...
# 2      high_priority  The current reports are all, generated by samp...
# 3      high_priority  E4E is generating in place. If I have an eleme...
# 4      high_priority  @excelsior @edgarf \r\nThe sandbox server is n...
# ...              ...                                                ...
# 19606   low_priority  Krav:\r\n- Antall maps i mappen 'maps' skal væ...
# 19607   low_priority  * some routes do throw exceptions other than t...
# 19608   low_priority  * Add `POST /auth/reset_request` route which r...
# 19609   low_priority  * Add `Forgot Password` button on login page\r...
# 19610   low_priority  Currently our `EventMonitor` (~ `SpikeMonitor`...
#
# [19611 rows x 4 columns]

# %%
# Clean the data.
all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_88890/2393042031.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)

# %%
# Make a subset with text_clean and label
priority_label_text = all_priority_subset[["text_clean" , "label"]]
priority_label_text
# Out:
#                                               text_clean  label
# 0      describe the bug when i add a folder path and ...      0
# 1      describe the bug after invoking the search bar...      0
# 2      the current reports are all generated by sampl...      0
# 3      e4e is generating in place if i have an elemen...      0
# 4      excelsior edgarf the sandbox server is not res...      0
# ...                                                  ...    ...
# 19606                                                NaN      2
# 19607  some routes do throw exceptions other than the...      2
# 19608  add post authresetrequest route which receives...      2
# 19609  add forgot password button on login page add r...      2
# 19610  currently our eventmonitor spikemonitor return...      2
#
# [19611 rows x 2 columns]

# %%
priority_label_text.dropna(inplace=True)
priority_label_text.reset_index(inplace=True)
priority_label_text.drop(columns=["index"] , inplace= True)

priority_label_text
# Out:
# /tmp/ipykernel_88890/1038009599.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.dropna(inplace=True)
# /tmp/ipykernel_88890/1038009599.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.drop(columns=["index"] , inplace= True)
#                                               text_clean  label
# 0      describe the bug when i add a folder path and ...      0
# 1      describe the bug after invoking the search bar...      0
# 2      the current reports are all generated by sampl...      0
# 3      e4e is generating in place if i have an elemen...      0
# 4      excelsior edgarf the sandbox server is not res...      0
# ...                                                  ...    ...
# 18453  device iphone 12 mini chromesafari case 2 in 4...      2
# 18454  some routes do throw exceptions other than the...      2
# 18455  add post authresetrequest route which receives...      2
# 18456  add forgot password button on login page add r...      2
# 18457  currently our eventmonitor spikemonitor return...      2
#
# [18458 rows x 2 columns]

# %%
# Clean dataset with clean text and labels.
# 0 = high priority, 1 = medium priority, 2 low priority.
priority_label_text.to_csv("priority_high_med_low_dataset_clean.csv")

# %%
df2 = pd.read_csv("priority_high_med_low_dataset_clean.csv", index_col=0)
df2
# Out:
#                                               text_clean  label
# 0      describe the bug when i add a folder path and ...      0
# 1      describe the bug after invoking the search bar...      0
# 2      the current reports are all generated by sampl...      0
# 3      e4e is generating in place if i have an elemen...      0
# 4      excelsior edgarf the sandbox server is not res...      0
# ...                                                  ...    ...
# 18453  device iphone 12 mini chromesafari case 2 in 4...      2
# 18454  some routes do throw exceptions other than the...      2
# 18455  add post authresetrequest route which receives...      2
# 18456  add forgot password button on login page add r...      2
# 18457  currently our eventmonitor spikemonitor return...      2
#
# [18458 rows x 2 columns]
