# %%
import pandas as pd

# %%
# Read CSV into a dataframe
high_priority = pd.read_csv("final_high_priority_dataset.csv", index_col=0)
medium_priority = pd.read_csv("final_medium_priority_dataset.csv", index_col=0)
low_priority = pd.read_csv("final_low_priority_dataset.csv", index_col=0)

# %%
high_priority
# Out:
#                  id         type           created_at  \
# 0      1.675131e+10  IssuesEvent  2021-06-12 00:20:05
# 1      1.675179e+10  IssuesEvent  2021-06-12 02:13:44
# 2      1.675179e+10  IssuesEvent  2021-06-12 02:14:42
# 3      1.675189e+10  IssuesEvent  2021-06-12 02:40:12
# 4      1.675203e+10  IssuesEvent  2021-06-12 03:17:18
# ...             ...          ...                  ...
# 14333  1.593779e+10  IssuesEvent  2021-04-14 12:53:49
# 14334  1.593804e+10  IssuesEvent  2021-04-14 13:10:25
# 14335  1.593805e+10  IssuesEvent  2021-04-14 13:10:47
# 14336  1.593812e+10  IssuesEvent  2021-04-14 13:15:42
# 14337  1.593812e+10  IssuesEvent  2021-04-14 13:15:49
#
#                                                     repo  \
# 0                           NoahOrtega/Blue-Coin-Tracker
# 1                                   adirh3/Fluent-Search
# 2                                   adirh3/Fluent-Search
# 3                                            SwatInc/CD4
# 4                 eclipse/che-che4z-explorer-for-endevor
# ...                                                  ...
# 14333                        Gird-the-Grid/Grid-the-Grid
# 14334  Psychoanalytic-Electronic-Publishing/PEP-Web-U...
# 14335                Fabio-Git-dev/Programming_Languages
# 14336          indianapublicmedia/indianapublicmedia-web
# 14337                                       Kotlin/dokka
#
#                                                 repo_url  action  \
# 0      https://api.github.com/repos/NoahOrtega/Blue-C...  closed
# 1      https://api.github.com/repos/adirh3/Fluent-Search  closed
# 2      https://api.github.com/repos/adirh3/Fluent-Search  closed
# 3               https://api.github.com/repos/SwatInc/CD4  closed
# 4      https://api.github.com/repos/eclipse/che-che4z...  opened
# ...                                                  ...     ...
# 14333  https://api.github.com/repos/Gird-the-Grid/Gri...  closed
# 14334  https://api.github.com/repos/Psychoanalytic-El...  closed
# 14335  https://api.github.com/repos/Fabio-Git-dev/Pro...  opened
# 14336  https://api.github.com/repos/indianapublicmedi...  closed
# 14337          https://api.github.com/repos/Kotlin/dokka  closed
#
#                                                    title  \
# 0      Setting darkmode during launch causes crash on...
# 1              Context Prioritization Ignore not working
# 2                                   Search text glitches
# 3                      Generate report by Episode number
# 4      Error files.encoding generate ï¿½ or � and tha...
# ...                                                  ...
# 14333                                 Naming conventions
# 14334            Expert Pick Graphics, Queue not working
# 14335                         Add examples with matrixes
# 14336                    Data loss during move operation
# 14337        HTML comments in markdown files are visible
#
#                                           labels  \
# 0                              bug high priority
# 1                              High Priority bug
# 2                        High Priority UI/UX bug
# 3            High Priority Reporting enhancement
# 4                                  High Priority
# ...                                          ...
# 14333        good practices high priority repair
# 14334                          Bug High Priority
# 14335  C High priority documentation help wanted
# 14336                          bug high priority
# 14337            bug high priority libs feedback
#
#                                                     body  index
# 0      Setting dark mode in onCreate() in the main ac...    1.0
# 1      **Describe the bug**\r\nWhen I add a folder pa...    1.0
# 2      **Describe the bug**\r\nAfter invoking the sea...    1.0
# 3      The current reports are all, generated by samp...    1.0
# 4      We have an issue when we browse or retrieve an...    1.0
# ...                                                  ...    ...
# 14333  * Either change rows that use `x` to one-liner...    1.0
# 14334  I tried to push your latest merge/build to Sta...    1.0
# 14335                                                NaN    1.0
# 14336  Uuuuggghhhhhh... _cascade_\r\n\r\nThere was (i...    1.0
# 14337  **Describe the bug**\r\nHTML comments in markd...    1.0
#
# [14338 rows x 10 columns]

# %%
# Number or different labels
high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# high priority                                        1291
# bug high priority                                    1200
# enhancement high priority                             712
# high priority task                                    655
# High Priority                                         516
# High Priority bug                                     238
# High priority                                         234
# feature High Priority                                 135
# browser-firefox engine-gecko ml-needsdiagnosis-...    134
# Bug High Priority                                     130
# High Priority enhancement                             116
# bug High Priority                                     103
# documentation high priority                            93
# feature high priority                                  91
# bug high priority easy                                 77
# browser-firefox engine-gecko ml-needsdiagnosis-...     76
# Feature High Priority                                  72
# enhancement High Priority                              69
# High Priority task                                     69
# browser-fenix engine-gecko ml-needsdiagnosis-fa...     67
# bug easy high priority                                 62
# bug high priority major                                56
# frontend high priority                                 50
# high priority feat                                     49
# HIGH PRIORITY                                          48
# browser-firefox engine-gecko ml-needsdiagnosis-...     45
# High priority enhancement                              43
# high priority user story                               40
# High priority bug                                      39
# Frontend high priority task                            39
# Enhancement High Priority                              38
# high priority priority high                            37
# High priority react                                    35
# bug High priority                                      34
# Bug High priority                                      32
# High priority Implementation                           31
# easy enhancement high priority                         31
# browser-fenix engine-gecko ml-needsdiagnosis-fa...     31
# bug help wanted high priority                          30
# chore easy high priority                               30
# Guide High Priority                                    29
# P1: High Priority Type: Feature Request WG: sto...     29
# high priority removed task                             28
# Priority: High Priority: Urgent bug                    28
# HIGH priority                                          27
# browser-fenix engine-gecko ml-needsdiagnosis-fa...     26
# BE high priority                                       25
# bug high priority support                              24
# High Priority style/component update                   22
# backend high priority                                  22

# %%
medium_priority
# Out:
#                 id         type           created_at  \
# 0     1.675181e+10  IssuesEvent  2021-06-12 02:18:55
# 1     1.675184e+10  IssuesEvent  2021-06-12 02:27:07
# 2     1.612969e+10  IssuesEvent  2021-04-29 01:16:17
# 3     1.612976e+10  IssuesEvent  2021-04-29 01:27:17
# 4     1.612978e+10  IssuesEvent  2021-04-29 01:31:03
# ...            ...          ...                  ...
# 4654  1.593761e+10  IssuesEvent  2021-04-14 12:40:51
# 4655  1.593762e+10  IssuesEvent  2021-04-14 12:41:39
# 4656  1.593765e+10  IssuesEvent  2021-04-14 12:43:32
# 4657  1.593766e+10  IssuesEvent  2021-04-14 12:44:28
# 4658  1.593767e+10  IssuesEvent  2021-04-14 12:45:00
#
#                                                  repo  \
# 0                                adirh3/Fluent-Search
# 1                                adirh3/Fluent-Search
# 2                              StatisticsNZ/simplevis
# 3                           KingSupernova31/RulesGuru
# 4                           KingSupernova31/RulesGuru
# ...                                               ...
# 4654  Software-Engineering-2-Pixel-Studio/pixelstudio
# 4655  Software-Engineering-2-Pixel-Studio/pixelstudio
# 4656                  DXHeroes/knowledge-base-content
# 4657  Software-Engineering-2-Pixel-Studio/pixelstudio
# 4658  Software-Engineering-2-Pixel-Studio/pixelstudio
#
#                                                repo_url  action  \
# 0     https://api.github.com/repos/adirh3/Fluent-Search  closed
# 1     https://api.github.com/repos/adirh3/Fluent-Search  closed
# 2     https://api.github.com/repos/StatisticsNZ/simp...  opened
# 3     https://api.github.com/repos/KingSupernova31/R...  opened
# 4     https://api.github.com/repos/KingSupernova31/R...  opened
# ...                                                 ...     ...
# 4654  https://api.github.com/repos/Software-Engineer...  opened
# 4655  https://api.github.com/repos/Software-Engineer...  closed
# 4656  https://api.github.com/repos/DXHeroes/knowledg...  closed
# 4657  https://api.github.com/repos/Software-Engineer...  opened
# 4658  https://api.github.com/repos/Software-Engineer...  closed
#
#                                                   title  \
# 0        Drag and drop often shows restricted icon (🚫)
# 1                                           Ignore Tags
# 2     numeric breaks: log or log10 trans does not wo...
# 3                      Add a "notes" field on questions
# 4     Don't allow a question to have the same editor...
# ...                                                 ...
# 4654  [TASK] Cosmetic upgrades, enemy HP display, bu...
# 4655  [TASK] Cosmetic upgrades, enemy HP display, bu...
# 4656                 Article: Finger pointing & blaming
# 4657                             [TASK] Update Tile Map
# 4658                             [TASK] Update Tile Map
#
#                                                  labels  \
# 0                                   Medium Priority bug
# 1                                   Medium Priority bug
# 2                                       medium priority
# 3                           enhancement medium priority
# 4                           enhancement medium priority
# ...                                                 ...
# 4654           Medium Priority enhancement feature game
# 4655           Medium Priority enhancement feature game
# 4656  Difficulty: Medium Priority: Low Status: Avail...
# 4657                   Medium Priority enhancement game
# 4658                   Medium Priority enhancement game
#
#                                                    body  index
# 0     **Describe the bug**\r\nWhile trying to drag a...    1.0
# 1     There is a lot of tags which I don't know what...    1.0
# 2                                                   NaN    1.0
# 3     Questions should have a "notes" field. This fi...    1.0
# 4     Right now, if an admin has both the "Editor" a...    1.0
# ...                                                 ...    ...
# 4654  - Changed the look of texts\r\n- Changed the l...    1.0
# 4655  - Changed the look of texts\r\n- Changed the l...    1.0
# 4656                                                NaN    1.0
# 4657  - Edit the way the Map looks so that the writi...    1.0
# 4658  - Edit the way the Map looks so that the writi...    1.0
#
# [4659 rows x 10 columns]

# %%
# Number or different labels
medium_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# medium priority                                       394
# enhancement medium priority                           276
# medium priority task                                  205
# bug medium priority                                   171
# Medium Priority                                       167
# Medium priority                                        98
# Medium Priority bug                                    66
# Bug Medium Priority                                    53
# documentation medium priority                          50
# Medium Priority enhancement                            50
# enhancement Medium Priority                            48
# feature medium priority                                40
# Guide Medium Priority                                  40
# bug Medium Priority                                    37
# medium priority user story                             28
# QA bug medium priority                                 24
# bug Medium priority                                    20
# Difficulty: [2] Intermediate Effort: [2] Medium...     19
# Criticality Medium Priority Low                        19
# P2: Medium priority enhancement                        18
# MEDIUM PRIORITY veracode                               17
# Medium Priority task                                   17
# Medium Priority feature                                17
# Medium priority bug                                    16
# P2: Medium priority bug                                15
# Medium Priority 🥈                                      15
# medium priority removed task                           15
# Difficulty: [2] Intermediate Effort: [2] Medium...     14
# Medium priority enhancement                            14
# Anima Guide Medium Priority                            14
# feature request medium priority                        12
# Implementation Medium priority                         12
# P2: Medium priority enhancement stale                  11
# Difficulty: [2] Intermediate Effort: [2] Medium...     11
# ux medium priority                                     10
# Criticality Medium Priority Medium                     10
# enhancement Medium priority                            10
# enhancement medium priority support                    10
# P2: Medium priority bug stale                           9
# Medium priority Difficulty 3                            9
# Improvement :chart_with_upwards_trend: Medium p...      9
# Difficulty: 2 - Medium Priority: 2-medium Size:...      9
# Medium priority feature                                 9
# Difficulty: 2 - Medium Priority: 3-low Size: 2 ...      9
# feature 3 medium priority user story                    9
# easy medium priority                                    8
# medium medium priority                                  8
# Medium Priority - Must                                  8
# enhancement medium priority no-issue-activity           8
# medium priority hop-node                                8

# %%
low_priority
# Out:
#                 id         type           created_at  \
# 0     1.675160e+10  IssuesEvent  2021-06-12 01:26:20
# 1     1.675165e+10  IssuesEvent  2021-06-12 01:37:40
# 2     1.612979e+10  IssuesEvent  2021-04-29 01:32:47
# 3     1.612980e+10  IssuesEvent  2021-04-29 01:34:02
# 4     1.613008e+10  IssuesEvent  2021-04-29 02:19:14
# ...            ...          ...                  ...
# 7374  1.593657e+10  IssuesEvent  2021-04-14 11:20:08
# 7375  1.593706e+10  IssuesEvent  2021-04-14 11:59:33
# 7376  1.593712e+10  IssuesEvent  2021-04-14 12:03:28
# 7377  1.593712e+10  IssuesEvent  2021-04-14 12:04:08
# 7378  1.593760e+10  IssuesEvent  2021-04-14 12:40:00
#
#                                 repo  \
# 0              Sequel-Ace/Sequel-Ace
# 1                       DoobDev/Doob
# 2          KingSupernova31/RulesGuru
# 3          KingSupernova31/RulesGuru
# 4     inaturalist/iNaturalistAndroid
# ...                              ...
# 7374     inf112-v21/Trivial-Solution
# 7375     Gird-the-Grid/Grid-the-Grid
# 7376     Gird-the-Grid/Grid-the-Grid
# 7377     Gird-the-Grid/Grid-the-Grid
# 7378           brian-team/brian2cuda
#
#                                                repo_url    action  \
# 0     https://api.github.com/repos/Sequel-Ace/Sequel...    closed
# 1             https://api.github.com/repos/DoobDev/Doob  reopened
# 2     https://api.github.com/repos/KingSupernova31/R...    opened
# 3     https://api.github.com/repos/KingSupernova31/R...    opened
# 4     https://api.github.com/repos/inaturalist/iNatu...    closed
# ...                                                 ...       ...
# 7374  https://api.github.com/repos/inf112-v21/Trivia...    closed
# 7375  https://api.github.com/repos/Gird-the-Grid/Gri...    opened
# 7376  https://api.github.com/repos/Gird-the-Grid/Gri...    opened
# 7377  https://api.github.com/repos/Gird-the-Grid/Gri...    opened
# 7378  https://api.github.com/repos/brian-team/brian2...    closed
#
#                                                   title  \
# 0                          slow to connect via proxysql
# 1                                   Redo the Help menu!
# 2           Have discord bot automatically assign roles
# 3             Jumping to editor forgets question number
# 4     Prevent crashes from encoding problems in the ...
# ...                                                 ...
# 7374  Som spiller vil jeg ha flere forskjellige kart...
# 7375                            Catch general exception
# 7376                       Backend reset password route
# 7377                            Frontend reset password
# 7378  Sort EventMonitor data by index within each ti...
#
#                                              labels  \
# 0     Feature Request Low priority PR Welcome stale
# 1                      Low Priority feature_request
# 2                          enhancement low priority
# 3                 bug good first issue low priority
# 4                                  Low Priority bug
# ...                                             ...
# 7374                        Low priority User Story
# 7375             good practices low priority repair
# 7376                       enhancement low priority
# 7377                       enhancement low priority
# 7378                         low priority usability
#
#                                                    body  index
# 0     \r\n- Sequel Ace Version (including build numb...    1.0
# 1     It's ugly right now.\r\n\r\n- [ ] Separate com...    1.0
# 2     RG has internal roles for all its admins, and ...    1.0
# 3     Typing the sequence of characters "admin" on a...    1.0
# 4     https://console.firebase.google.com/u/2/projec...    1.0
# ...                                                 ...    ...
# 7374  Krav:\r\n- Antall maps i mappen 'maps' skal væ...    1.0
# 7375  * some routes do throw exceptions other than t...    1.0
# 7376  * Add `POST /auth/reset_request` route which r...    1.0
# 7377  * Add `Forgot Password` button on login page\r...    1.0
# 7378  Currently our `EventMonitor` (~ `SpikeMonitor`...    1.0
#
# [7379 rows x 10 columns]

# %%
# Number or different labels
low_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# enhancement low priority                              784
# low priority                                          775
# bug low priority                                      358
# Low Priority                                          204
# low priority task                                     191
# Low Priority bug                                       98
# Low priority                                           86
# Bug Low Priority                                       82
# feature low priority                                   71
# Low Priority enhancement                               67
# Guide Low Priority                                     49
# Low priority enhancement                               49
# documentation low priority                             48
# QA bug low priority                                    41
# enhancement good first issue low priority              40
# enhancement Low Priority                               38
# feature request low priority                           36
# good first issue low priority                          35
# Framework Low Priority Stale                           34
# Enhancement Low Priority                               29
# bug Low Priority                                       27
# Feature Request Low Priority                           26
# Low priority bug                                       24
# Low Priority 🥉                                         24
# bug low priority ui                                    23
# bug Low priority                                       22
# Enhancement Low priority                               21
# Feature Request Low priority PR Welcome stale          21
# bug good first issue low priority                      21
# enhancement help wanted low priority                   20
# Feature Low Priority                                   18
# enhancement P4 - Low Priority Serial Programs          18
# frontend low priority                                  18
# backend low priority                                   17
# UI tests low priority                                  17
# enhancement Low priority                               16
# Low Priority MantidPlot Stale                          14
# low priority bug                                       14
# low priority removed task                              14
# enhancement P4 - Low Priority Serial Programs D...     14
# Low Priority UI/UX bug                                 14
# Low Priority task                                      13
# bug enhancement low priority                           13
# Map issue low priority                                 13
# 2021-03 Low Priority                                   13
# Being Redone Low Priority                              12
# bug Low Priority UI/UX                                 12
# feature Low Priority                                   12
# Benchmarks Feature - Low Priority                      12
# Vanilla bug cosmetic low priority                      12

# %%
# Add a new column
high_priority["class"] = "high_priority"

# %%
high_priority
# Out:
#                  id         type           created_at  \
# 0      1.675131e+10  IssuesEvent  2021-06-12 00:20:05
# 1      1.675179e+10  IssuesEvent  2021-06-12 02:13:44
# 2      1.675179e+10  IssuesEvent  2021-06-12 02:14:42
# 3      1.675189e+10  IssuesEvent  2021-06-12 02:40:12
# 4      1.675203e+10  IssuesEvent  2021-06-12 03:17:18
# ...             ...          ...                  ...
# 14333  1.593779e+10  IssuesEvent  2021-04-14 12:53:49
# 14334  1.593804e+10  IssuesEvent  2021-04-14 13:10:25
# 14335  1.593805e+10  IssuesEvent  2021-04-14 13:10:47
# 14336  1.593812e+10  IssuesEvent  2021-04-14 13:15:42
# 14337  1.593812e+10  IssuesEvent  2021-04-14 13:15:49
#
#                                                     repo  \
# 0                           NoahOrtega/Blue-Coin-Tracker
# 1                                   adirh3/Fluent-Search
# 2                                   adirh3/Fluent-Search
# 3                                            SwatInc/CD4
# 4                 eclipse/che-che4z-explorer-for-endevor
# ...                                                  ...
# 14333                        Gird-the-Grid/Grid-the-Grid
# 14334  Psychoanalytic-Electronic-Publishing/PEP-Web-U...
# 14335                Fabio-Git-dev/Programming_Languages
# 14336          indianapublicmedia/indianapublicmedia-web
# 14337                                       Kotlin/dokka
#
#                                                 repo_url  action  \
# 0      https://api.github.com/repos/NoahOrtega/Blue-C...  closed
# 1      https://api.github.com/repos/adirh3/Fluent-Search  closed
# 2      https://api.github.com/repos/adirh3/Fluent-Search  closed
# 3               https://api.github.com/repos/SwatInc/CD4  closed
# 4      https://api.github.com/repos/eclipse/che-che4z...  opened
# ...                                                  ...     ...
# 14333  https://api.github.com/repos/Gird-the-Grid/Gri...  closed
# 14334  https://api.github.com/repos/Psychoanalytic-El...  closed
# 14335  https://api.github.com/repos/Fabio-Git-dev/Pro...  opened
# 14336  https://api.github.com/repos/indianapublicmedi...  closed
# 14337          https://api.github.com/repos/Kotlin/dokka  closed
#
#                                                    title  \
# 0      Setting darkmode during launch causes crash on...
# 1              Context Prioritization Ignore not working
# 2                                   Search text glitches
# 3                      Generate report by Episode number
# 4      Error files.encoding generate ï¿½ or � and tha...
# ...                                                  ...
# 14333                                 Naming conventions
# 14334            Expert Pick Graphics, Queue not working
# 14335                         Add examples with matrixes
# 14336                    Data loss during move operation
# 14337        HTML comments in markdown files are visible
#
#                                           labels  \
# 0                              bug high priority
# 1                              High Priority bug
# 2                        High Priority UI/UX bug
# 3            High Priority Reporting enhancement
# 4                                  High Priority
# ...                                          ...
# 14333        good practices high priority repair
# 14334                          Bug High Priority
# 14335  C High priority documentation help wanted
# 14336                          bug high priority
# 14337            bug high priority libs feedback
#
#                                                     body  index          class
# 0      Setting dark mode in onCreate() in the main ac...    1.0  high_priority
# 1      **Describe the bug**\r\nWhen I add a folder pa...    1.0  high_priority
# 2      **Describe the bug**\r\nAfter invoking the sea...    1.0  high_priority
# 3      The current reports are all, generated by samp...    1.0  high_priority
# 4      We have an issue when we browse or retrieve an...    1.0  high_priority
# ...                                                  ...    ...            ...
# 14333  * Either change rows that use `x` to one-liner...    1.0  high_priority
# 14334  I tried to push your latest merge/build to Sta...    1.0  high_priority
# 14335                                                NaN    1.0  high_priority
# 14336  Uuuuggghhhhhh... _cascade_\r\n\r\nThere was (i...    1.0  high_priority
# 14337  **Describe the bug**\r\nHTML comments in markd...    1.0  high_priority
#
# [14338 rows x 11 columns]

# %%
medium_priority["class"] = "medium_priority"
medium_priority
# Out:
#                 id         type           created_at  \
# 0     1.675181e+10  IssuesEvent  2021-06-12 02:18:55
# 1     1.675184e+10  IssuesEvent  2021-06-12 02:27:07
# 2     1.612969e+10  IssuesEvent  2021-04-29 01:16:17
# 3     1.612976e+10  IssuesEvent  2021-04-29 01:27:17
# 4     1.612978e+10  IssuesEvent  2021-04-29 01:31:03
# ...            ...          ...                  ...
# 4654  1.593761e+10  IssuesEvent  2021-04-14 12:40:51
# 4655  1.593762e+10  IssuesEvent  2021-04-14 12:41:39
# 4656  1.593765e+10  IssuesEvent  2021-04-14 12:43:32
# 4657  1.593766e+10  IssuesEvent  2021-04-14 12:44:28
# 4658  1.593767e+10  IssuesEvent  2021-04-14 12:45:00
#
#                                                  repo  \
# 0                                adirh3/Fluent-Search
# 1                                adirh3/Fluent-Search
# 2                              StatisticsNZ/simplevis
# 3                           KingSupernova31/RulesGuru
# 4                           KingSupernova31/RulesGuru
# ...                                               ...
# 4654  Software-Engineering-2-Pixel-Studio/pixelstudio
# 4655  Software-Engineering-2-Pixel-Studio/pixelstudio
# 4656                  DXHeroes/knowledge-base-content
# 4657  Software-Engineering-2-Pixel-Studio/pixelstudio
# 4658  Software-Engineering-2-Pixel-Studio/pixelstudio
#
#                                                repo_url  action  \
# 0     https://api.github.com/repos/adirh3/Fluent-Search  closed
# 1     https://api.github.com/repos/adirh3/Fluent-Search  closed
# 2     https://api.github.com/repos/StatisticsNZ/simp...  opened
# 3     https://api.github.com/repos/KingSupernova31/R...  opened
# 4     https://api.github.com/repos/KingSupernova31/R...  opened
# ...                                                 ...     ...
# 4654  https://api.github.com/repos/Software-Engineer...  opened
# 4655  https://api.github.com/repos/Software-Engineer...  closed
# 4656  https://api.github.com/repos/DXHeroes/knowledg...  closed
# 4657  https://api.github.com/repos/Software-Engineer...  opened
# 4658  https://api.github.com/repos/Software-Engineer...  closed
#
#                                                   title  \
# 0        Drag and drop often shows restricted icon (🚫)
# 1                                           Ignore Tags
# 2     numeric breaks: log or log10 trans does not wo...
# 3                      Add a "notes" field on questions
# 4     Don't allow a question to have the same editor...
# ...                                                 ...
# 4654  [TASK] Cosmetic upgrades, enemy HP display, bu...
# 4655  [TASK] Cosmetic upgrades, enemy HP display, bu...
# 4656                 Article: Finger pointing & blaming
# 4657                             [TASK] Update Tile Map
# 4658                             [TASK] Update Tile Map
#
#                                                  labels  \
# 0                                   Medium Priority bug
# 1                                   Medium Priority bug
# 2                                       medium priority
# 3                           enhancement medium priority
# 4                           enhancement medium priority
# ...                                                 ...
# 4654           Medium Priority enhancement feature game
# 4655           Medium Priority enhancement feature game
# 4656  Difficulty: Medium Priority: Low Status: Avail...
# 4657                   Medium Priority enhancement game
# 4658                   Medium Priority enhancement game
#
#                                                    body  index  \
# 0     **Describe the bug**\r\nWhile trying to drag a...    1.0
# 1     There is a lot of tags which I don't know what...    1.0
# 2                                                   NaN    1.0
# 3     Questions should have a "notes" field. This fi...    1.0
# 4     Right now, if an admin has both the "Editor" a...    1.0
# ...                                                 ...    ...
# 4654  - Changed the look of texts\r\n- Changed the l...    1.0
# 4655  - Changed the look of texts\r\n- Changed the l...    1.0
# 4656                                                NaN    1.0
# 4657  - Edit the way the Map looks so that the writi...    1.0
# 4658  - Edit the way the Map looks so that the writi...    1.0
#
#                 class
# 0     medium_priority
# 1     medium_priority
# 2     medium_priority
# 3     medium_priority
# 4     medium_priority
# ...               ...
# 4654  medium_priority
# 4655  medium_priority
# 4656  medium_priority
# 4657  medium_priority
# 4658  medium_priority
#
# [4659 rows x 11 columns]

# %%
low_priority["class"] = "low_priority"
low_priority
# Out:
#                 id         type           created_at  \
# 0     1.675160e+10  IssuesEvent  2021-06-12 01:26:20
# 1     1.675165e+10  IssuesEvent  2021-06-12 01:37:40
# 2     1.612979e+10  IssuesEvent  2021-04-29 01:32:47
# 3     1.612980e+10  IssuesEvent  2021-04-29 01:34:02
# 4     1.613008e+10  IssuesEvent  2021-04-29 02:19:14
# ...            ...          ...                  ...
# 7374  1.593657e+10  IssuesEvent  2021-04-14 11:20:08
# 7375  1.593706e+10  IssuesEvent  2021-04-14 11:59:33
# 7376  1.593712e+10  IssuesEvent  2021-04-14 12:03:28
# 7377  1.593712e+10  IssuesEvent  2021-04-14 12:04:08
# 7378  1.593760e+10  IssuesEvent  2021-04-14 12:40:00
#
#                                 repo  \
# 0              Sequel-Ace/Sequel-Ace
# 1                       DoobDev/Doob
# 2          KingSupernova31/RulesGuru
# 3          KingSupernova31/RulesGuru
# 4     inaturalist/iNaturalistAndroid
# ...                              ...
# 7374     inf112-v21/Trivial-Solution
# 7375     Gird-the-Grid/Grid-the-Grid
# 7376     Gird-the-Grid/Grid-the-Grid
# 7377     Gird-the-Grid/Grid-the-Grid
# 7378           brian-team/brian2cuda
#
#                                                repo_url    action  \
# 0     https://api.github.com/repos/Sequel-Ace/Sequel...    closed
# 1             https://api.github.com/repos/DoobDev/Doob  reopened
# 2     https://api.github.com/repos/KingSupernova31/R...    opened
# 3     https://api.github.com/repos/KingSupernova31/R...    opened
# 4     https://api.github.com/repos/inaturalist/iNatu...    closed
# ...                                                 ...       ...
# 7374  https://api.github.com/repos/inf112-v21/Trivia...    closed
# 7375  https://api.github.com/repos/Gird-the-Grid/Gri...    opened
# 7376  https://api.github.com/repos/Gird-the-Grid/Gri...    opened
# 7377  https://api.github.com/repos/Gird-the-Grid/Gri...    opened
# 7378  https://api.github.com/repos/brian-team/brian2...    closed
#
#                                                   title  \
# 0                          slow to connect via proxysql
# 1                                   Redo the Help menu!
# 2           Have discord bot automatically assign roles
# 3             Jumping to editor forgets question number
# 4     Prevent crashes from encoding problems in the ...
# ...                                                 ...
# 7374  Som spiller vil jeg ha flere forskjellige kart...
# 7375                            Catch general exception
# 7376                       Backend reset password route
# 7377                            Frontend reset password
# 7378  Sort EventMonitor data by index within each ti...
#
#                                              labels  \
# 0     Feature Request Low priority PR Welcome stale
# 1                      Low Priority feature_request
# 2                          enhancement low priority
# 3                 bug good first issue low priority
# 4                                  Low Priority bug
# ...                                             ...
# 7374                        Low priority User Story
# 7375             good practices low priority repair
# 7376                       enhancement low priority
# 7377                       enhancement low priority
# 7378                         low priority usability
#
#                                                    body  index         class
# 0     \r\n- Sequel Ace Version (including build numb...    1.0  low_priority
# 1     It's ugly right now.\r\n\r\n- [ ] Separate com...    1.0  low_priority
# 2     RG has internal roles for all its admins, and ...    1.0  low_priority
# 3     Typing the sequence of characters "admin" on a...    1.0  low_priority
# 4     https://console.firebase.google.com/u/2/projec...    1.0  low_priority
# ...                                                 ...    ...           ...
# 7374  Krav:\r\n- Antall maps i mappen 'maps' skal væ...    1.0  low_priority
# 7375  * some routes do throw exceptions other than t...    1.0  low_priority
# 7376  * Add `POST /auth/reset_request` route which r...    1.0  low_priority
# 7377  * Add `Forgot Password` button on login page\r...    1.0  low_priority
# 7378  Currently our `EventMonitor` (~ `SpikeMonitor`...    1.0  low_priority
#
# [7379 rows x 11 columns]

# %%
all_data = pd.concat([high_priority, medium_priority, low_priority] , ignore_index= True)

# %%
all_data
# Out:
#                  id         type           created_at  \
# 0      1.675131e+10  IssuesEvent  2021-06-12 00:20:05
# 1      1.675179e+10  IssuesEvent  2021-06-12 02:13:44
# 2      1.675179e+10  IssuesEvent  2021-06-12 02:14:42
# 3      1.675189e+10  IssuesEvent  2021-06-12 02:40:12
# 4      1.675203e+10  IssuesEvent  2021-06-12 03:17:18
# ...             ...          ...                  ...
# 26371  1.593657e+10  IssuesEvent  2021-04-14 11:20:08
# 26372  1.593706e+10  IssuesEvent  2021-04-14 11:59:33
# 26373  1.593712e+10  IssuesEvent  2021-04-14 12:03:28
# 26374  1.593712e+10  IssuesEvent  2021-04-14 12:04:08
# 26375  1.593760e+10  IssuesEvent  2021-04-14 12:40:00
#
#                                          repo  \
# 0                NoahOrtega/Blue-Coin-Tracker
# 1                        adirh3/Fluent-Search
# 2                        adirh3/Fluent-Search
# 3                                 SwatInc/CD4
# 4      eclipse/che-che4z-explorer-for-endevor
# ...                                       ...
# 26371             inf112-v21/Trivial-Solution
# 26372             Gird-the-Grid/Grid-the-Grid
# 26373             Gird-the-Grid/Grid-the-Grid
# 26374             Gird-the-Grid/Grid-the-Grid
# 26375                   brian-team/brian2cuda
#
#                                                 repo_url  action  \
# 0      https://api.github.com/repos/NoahOrtega/Blue-C...  closed
# 1      https://api.github.com/repos/adirh3/Fluent-Search  closed
# 2      https://api.github.com/repos/adirh3/Fluent-Search  closed
# 3               https://api.github.com/repos/SwatInc/CD4  closed
# 4      https://api.github.com/repos/eclipse/che-che4z...  opened
# ...                                                  ...     ...
# 26371  https://api.github.com/repos/inf112-v21/Trivia...  closed
# 26372  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 26373  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 26374  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 26375  https://api.github.com/repos/brian-team/brian2...  closed
#
#                                                    title  \
# 0      Setting darkmode during launch causes crash on...
# 1              Context Prioritization Ignore not working
# 2                                   Search text glitches
# 3                      Generate report by Episode number
# 4      Error files.encoding generate ï¿½ or � and tha...
# ...                                                  ...
# 26371  Som spiller vil jeg ha flere forskjellige kart...
# 26372                            Catch general exception
# 26373                       Backend reset password route
# 26374                            Frontend reset password
# 26375  Sort EventMonitor data by index within each ti...
#
#                                     labels  \
# 0                        bug high priority
# 1                        High Priority bug
# 2                  High Priority UI/UX bug
# 3      High Priority Reporting enhancement
# 4                            High Priority
# ...                                    ...
# 26371              Low priority User Story
# 26372   good practices low priority repair
# 26373             enhancement low priority
# 26374             enhancement low priority
# 26375               low priority usability
#
#                                                     body  index          class
# 0      Setting dark mode in onCreate() in the main ac...    1.0  high_priority
# 1      **Describe the bug**\r\nWhen I add a folder pa...    1.0  high_priority
# 2      **Describe the bug**\r\nAfter invoking the sea...    1.0  high_priority
# 3      The current reports are all, generated by samp...    1.0  high_priority
# 4      We have an issue when we browse or retrieve an...    1.0  high_priority
# ...                                                  ...    ...            ...
# 26371  Krav:\r\n- Antall maps i mappen 'maps' skal væ...    1.0   low_priority
# 26372  * some routes do throw exceptions other than t...    1.0   low_priority
# 26373  * Add `POST /auth/reset_request` route which r...    1.0   low_priority
# 26374  * Add `Forgot Password` button on login page\r...    1.0   low_priority
# 26375  Currently our `EventMonitor` (~ `SpikeMonitor`...    1.0   low_priority
#
# [26376 rows x 11 columns]

# %%
all_data_no_dupes = all_data.drop_duplicates()
all_data_no_dupes
# Out:
#                  id         type           created_at  \
# 0      1.675131e+10  IssuesEvent  2021-06-12 00:20:05
# 1      1.675179e+10  IssuesEvent  2021-06-12 02:13:44
# 2      1.675179e+10  IssuesEvent  2021-06-12 02:14:42
# 3      1.675189e+10  IssuesEvent  2021-06-12 02:40:12
# 4      1.675203e+10  IssuesEvent  2021-06-12 03:17:18
# ...             ...          ...                  ...
# 26371  1.593657e+10  IssuesEvent  2021-04-14 11:20:08
# 26372  1.593706e+10  IssuesEvent  2021-04-14 11:59:33
# 26373  1.593712e+10  IssuesEvent  2021-04-14 12:03:28
# 26374  1.593712e+10  IssuesEvent  2021-04-14 12:04:08
# 26375  1.593760e+10  IssuesEvent  2021-04-14 12:40:00
#
#                                          repo  \
# 0                NoahOrtega/Blue-Coin-Tracker
# 1                        adirh3/Fluent-Search
# 2                        adirh3/Fluent-Search
# 3                                 SwatInc/CD4
# 4      eclipse/che-che4z-explorer-for-endevor
# ...                                       ...
# 26371             inf112-v21/Trivial-Solution
# 26372             Gird-the-Grid/Grid-the-Grid
# 26373             Gird-the-Grid/Grid-the-Grid
# 26374             Gird-the-Grid/Grid-the-Grid
# 26375                   brian-team/brian2cuda
#
#                                                 repo_url  action  \
# 0      https://api.github.com/repos/NoahOrtega/Blue-C...  closed
# 1      https://api.github.com/repos/adirh3/Fluent-Search  closed
# 2      https://api.github.com/repos/adirh3/Fluent-Search  closed
# 3               https://api.github.com/repos/SwatInc/CD4  closed
# 4      https://api.github.com/repos/eclipse/che-che4z...  opened
# ...                                                  ...     ...
# 26371  https://api.github.com/repos/inf112-v21/Trivia...  closed
# 26372  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 26373  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 26374  https://api.github.com/repos/Gird-the-Grid/Gri...  opened
# 26375  https://api.github.com/repos/brian-team/brian2...  closed
#
#                                                    title  \
# 0      Setting darkmode during launch causes crash on...
# 1              Context Prioritization Ignore not working
# 2                                   Search text glitches
# 3                      Generate report by Episode number
# 4      Error files.encoding generate ï¿½ or � and tha...
# ...                                                  ...
# 26371  Som spiller vil jeg ha flere forskjellige kart...
# 26372                            Catch general exception
# 26373                       Backend reset password route
# 26374                            Frontend reset password
# 26375  Sort EventMonitor data by index within each ti...
#
#                                     labels  \
# 0                        bug high priority
# 1                        High Priority bug
# 2                  High Priority UI/UX bug
# 3      High Priority Reporting enhancement
# 4                            High Priority
# ...                                    ...
# 26371              Low priority User Story
# 26372   good practices low priority repair
# 26373             enhancement low priority
# 26374             enhancement low priority
# 26375               low priority usability
#
#                                                     body  index          class
# 0      Setting dark mode in onCreate() in the main ac...    1.0  high_priority
# 1      **Describe the bug**\r\nWhen I add a folder pa...    1.0  high_priority
# 2      **Describe the bug**\r\nAfter invoking the sea...    1.0  high_priority
# 3      The current reports are all, generated by samp...    1.0  high_priority
# 4      We have an issue when we browse or retrieve an...    1.0  high_priority
# ...                                                  ...    ...            ...
# 26371  Krav:\r\n- Antall maps i mappen 'maps' skal væ...    1.0   low_priority
# 26372  * some routes do throw exceptions other than t...    1.0   low_priority
# 26373  * Add `POST /auth/reset_request` route which r...    1.0   low_priority
# 26374  * Add `Forgot Password` button on login page\r...    1.0   low_priority
# 26375  Currently our `EventMonitor` (~ `SpikeMonitor`...    1.0   low_priority
#
# [26372 rows x 11 columns]

# %%
# Convert dataframe to a CSV file.
all_data_no_dupes.to_csv("full_dataset_priority_high_med_low.csv")
