# %% [markdown]
# # Data cleaning
# We want the class with labels as numerical value and the body with clean text.
#
# This will remove:
# * duplicates
# * NaN entires
# * non english
# * url, html
#
# * make it lowercase
# * combine title and body

# %%
import pandas as pd
import sys
sys.path.append("../../../scripts_shared/")
from preprocess_text import preprocess_text

# %%
# Read CSV into a dataframe
high_priority = pd.read_csv("csv/high/high_priority_no_td.csv", index_col=0)
not_high_priority = pd.read_csv("csv/random/random_no_td.csv", index_col=0)

# %%
contains_stale = not_high_priority['labels'].str.contains("stale", case=False, na=False)
not_high_priority= not_high_priority[~contains_stale].reset_index(drop=True)
not_high_priority.reset_index(drop=True, inplace=True)
not_high_priority
# Out:
#                    id         type           created_at  \
# 0        1.141754e+10  IssuesEvent  2020-02-03 00:00:07
# 1        1.141754e+10  IssuesEvent  2020-02-03 00:00:12
# 2        1.141754e+10  IssuesEvent  2020-02-03 00:00:13
# 3        1.141754e+10  IssuesEvent  2020-02-03 00:00:16
# 4        1.141754e+10  IssuesEvent  2020-02-03 00:00:18
# ...               ...          ...                  ...
# 1957914  8.109961e+09  IssuesEvent  2018-08-14 09:21:15
# 1957915  8.109961e+09  IssuesEvent  2018-08-14 09:21:16
# 1957916  8.109982e+09  IssuesEvent  2018-08-14 09:25:07
# 1957917  8.109983e+09  IssuesEvent  2018-08-14 09:25:24
# 1957918  8.109984e+09  IssuesEvent  2018-08-14 09:25:29
#
#                                   repo  \
# 0        automationbs/testbugreporting
# 1                PowerShell/PowerShell
# 2                  thadiun/hello-world
# 3                PowerShell/PowerShell
# 4                PowerShell/PowerShell
# ...                                ...
# 1957914                     urbit/arvo
# 1957915    highcharts/highcharts-react
# 1957916           Loriowar/comindivion
# 1957917     TiiQu-Network/TQ-test-page
# 1957918         prominic/Moonshine-IDE
#
#                                                   repo_url  action  \
# 0        https://api.github.com/repos/automationbs/test...  opened
# 1        https://api.github.com/repos/PowerShell/PowerS...  closed
# 2         https://api.github.com/repos/thadiun/hello-world  closed
# 3        https://api.github.com/repos/PowerShell/PowerS...  closed
# 4        https://api.github.com/repos/PowerShell/PowerS...  closed
# ...                                                    ...     ...
# 1957914            https://api.github.com/repos/urbit/arvo  opened
# 1957915  https://api.github.com/repos/highcharts/highch...  closed
# 1957916  https://api.github.com/repos/Loriowar/comindivion  opened
# 1957917  https://api.github.com/repos/TiiQu-Network/TQ-...  closed
# 1957918  https://api.github.com/repos/prominic/Moonshin...  closed
#
#                                                      title  \
# 0                                            Default title
# 1                                               Show alias
# 2                   [Test] testing needs-triage (no delay)
# 3                                     $ENV in using module
# 4                Measure-Command does not measure its self
# ...                                                    ...
# 1957914            %bad-text trips up hall JSON conversion
# 1957915                            HighMaps mapBubble type
# 1957916  Add a validation on a belonging of a predicate...
# 1957917                     Error on submit with no values
# 1957918           Handle unknown tags in Visual Editor XML
#
#                                                     labels  \
# 0                                                      bug
# 1                       Issue-Question Resolution-Answered
# 2                                                   triage
# 3         Area-Language Issue-Question Resolution-Answered
# 4        Area-Cmdlets-Utility Issue-Question Resolution...
# ...                                                    ...
# 1957914      :hall / :talk cause known marks web interface
# 1957915                                      pending reply
# 1957916                              bug data manipulation
# 1957917                                                bug
# 1957918               Investigation PrimeFaces enhancement
#
#                                                       body
# 0        default description\n\n|Property | Value|\n|--...
# 1        <!--\r\n\r\nFor Windows PowerShell 5.1 issues,...
# 2                                                      NaN
# 3        # Summary of the new feature/enhancement\r\n\r...
# 4        ## The Issue\r\nI'm pretty sure this was just ...
# ...                                                    ...
# 1957914  Haven't tested this in detail yet, but pretty ...
# 1957915  Hello,\r\nIt is possible to create also HighMa...
# 1957916  Now user can change html content of the intera...
# 1957917  TypeError: Too few arguments in function sum (...
# 1957918  If provided Visual Editor XML brings some unkn...
#
# [1957919 rows x 9 columns]

# %%
# Number or different labels
high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                   count
# labels
# bug high priority                 10435
# high priority                     10360
# High Priority                      7484
# enhancement high priority          5486
# Priority: High                     4751
# priority.High                      3694
# priority.High type.Task            3685
# priority.high type.task            3209
# priority.High type.Story           2979
# priority.high                      2749
# bug priority: high                 2306
# high-priority                      2262
# priority: high                     2178
# bug high-priority                  2159
# type.Story priority.High           2155
# priority.high type.story           2130
# type.Task priority.High            2022
# bug High Priority                  1888
# High priority                      1815
# Priority: High Type: Bug           1768
# priority:high                      1726
# bug priority:high                  1470
# High Priority bug                  1338
# Priority: High bug                 1200
# Bug High Priority                  1143
# feature high priority              1091
# enhancement priority: high         1090
# enhancement high-priority          1053
# enhancement priority:high           982
# priority-high                       955
# bug priority-high                   927
# enhancement High Priority           902
# bug Priority: High                  837
# Priority: High Type: Enhancement    835
# high priority task                  831
# bug High priority                   744
# priority high                       733
# priority.high type.bug              717
# priority: high type: bug            704
# Type: Bug Priority: High            639
# Bug Priority: High                  620
# High Priority enhancement           611
# documentation priority.High         600
# prio:high                           587
# Bug - High Priority                 562
# priority.High type.Enhancement      562
# Priority: High Type: Feature        541
# bug prio-high                       541
# priority.high type.enhancement      540
# priority/high                       537

# %%
high_priority[high_priority["repo"] == "python/mypy"]
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body]
# Index: []

# %%
high_priority[high_priority["repo"] == "microsoft/vscode"]
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body]
# Index: []

# %%
high_priority[high_priority["repo"] == "rust-lang/rust"]
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body]
# Index: []

# %%
not_high_priority[not_high_priority["repo"] == "python/mypy"]
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body]
# Index: []

# %%
not_high_priority[not_high_priority["repo"] == "microsoft/vscode"]
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body]
# Index: []

# %%
not_high_priority[not_high_priority["repo"] == "rust-lang/rust"]
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body]
# Index: []

# %%
# Number or different labels
not_high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                           count
# labels
# enhancement                              244118
# bug                                      240523
# security vulnerability                    53086
# question                                  34827
# feature                                   20725
# documentation                             17936
# Bug                                       12282
# help wanted                               10874
# wontfix                                    7279
# greenkeeper                                6842
# stat:awaiting response                     6602
# Sub Task Failing Test Paddle Frontend      6463
# good first issue                           6418
# enhancement help wanted                    6290
# invalid                                    6060
# task                                       5668
# feature request                            5605
# in progress                                5372
# duplicate                                  5235
# bug enhancement                            4899
# enhancement good first issue               4516
# npm-install-script                         4452
# status monika                              4372
# kind/bug                                   4335
# design                                     4178
# JAX Frontend Sub Task Failing Test         4099
# Enhancement                                3402
# Feature                                    3266
# watchout                                   3241
# bug help wanted                            3094
# type: bug                                  2958
# triage                                     2701
# action-needsmoderation                     2551
# frontend                                   2536
# new feature                                2493
# new-review user-submission                 2417
# Task                                       2378
# Type: Bug                                  2292
# documentation enhancement                  2277
# improvement                                2225
# weekly-digest                              2211
# todo                                       2190
# enhancement question                       2121
# new-version user-submission                2089
# Mend: dependency security vulnerability    2073
# feature-request                            1887
# discussion                                 1887
# docs                                       1878
# backend                                    1869
# bug fixed                                  1863

# %%
#Give each priority a label by number.
# 'Label encoding'. Makes is easier for machine learning models to work with categorical data.
high_priority["label"] = 0
high_priority["class"] = "high_priority"
high_priority.head()
# Out:
#              id         type           created_at  \
# 0  1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1  1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2  1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3  1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4  1.141756e+10  IssuesEvent  2020-02-03 00:08:03
#
#                                   repo  \
# 0            unitystation/unitystation
# 1  zowe/sample-spring-boot-api-service
# 2                   openmsupply/mobile
# 3  UltimateCodeMonkeys/CodeMonkeysMVVM
# 4   wordpress-mobile/WordPress-Android
#
#                                             repo_url  action  \
# 0  https://api.github.com/repos/unitystation/unit...  closed
# 1  https://api.github.com/repos/zowe/sample-sprin...  closed
# 2    https://api.github.com/repos/openmsupply/mobile  closed
# 3  https://api.github.com/repos/UltimateCodeMonke...  opened
# 4  https://api.github.com/repos/wordpress-mobile/...  closed
#
#                                                title  \
# 0  Client breaking NRE when using edit field on C...
# 1  The SDK provides a separate Java (no-Spring) l...
# 2                 Auto-log out after some time frame
# 3  Migrate: CodeMonkeys ViewModelNavigationServic...
# 4  IA Reader filter bottom sheet: manage untitled...
#
#                                               labels  \
# 0                   Bug High Priority In Progress UI
# 1  Feature: API Security Priority: High no-issue-...
# 2  Docs: not needed Effort: small Feature Module:...
# 3  Priority: High Status: In Progress Type: Maint...
# 4                   IA Reader [Pri] High [Type] Task
#
#                                                 body  label          class
# 0  ### Bug:\r\n\r\nIf you use the edit field of t...      0  high_priority
# 1  - The commons-spring library is split into:\r\...      0  high_priority
# 2  ## Is your feature request related to a proble...      0  high_priority
# 3  Migrate the Xamarin.Forms navigation service i...      0  high_priority
# 4  In the filter bottom sheet we introduced in th...      0  high_priority

# %%
not_high_priority["label"] = 1
not_high_priority["class"] = "not_high_priority" 
not_high_priority.head()
# Out:
#              id         type           created_at  \
# 0  1.141754e+10  IssuesEvent  2020-02-03 00:00:07
# 1  1.141754e+10  IssuesEvent  2020-02-03 00:00:12
# 2  1.141754e+10  IssuesEvent  2020-02-03 00:00:13
# 3  1.141754e+10  IssuesEvent  2020-02-03 00:00:16
# 4  1.141754e+10  IssuesEvent  2020-02-03 00:00:18
#
#                             repo  \
# 0  automationbs/testbugreporting
# 1          PowerShell/PowerShell
# 2            thadiun/hello-world
# 3          PowerShell/PowerShell
# 4          PowerShell/PowerShell
#
#                                             repo_url  action  \
# 0  https://api.github.com/repos/automationbs/test...  opened
# 1  https://api.github.com/repos/PowerShell/PowerS...  closed
# 2   https://api.github.com/repos/thadiun/hello-world  closed
# 3  https://api.github.com/repos/PowerShell/PowerS...  closed
# 4  https://api.github.com/repos/PowerShell/PowerS...  closed
#
#                                        title  \
# 0                              Default title
# 1                                 Show alias
# 2     [Test] testing needs-triage (no delay)
# 3                       $ENV in using module
# 4  Measure-Command does not measure its self
#
#                                               labels  \
# 0                                                bug
# 1                 Issue-Question Resolution-Answered
# 2                                             triage
# 3   Area-Language Issue-Question Resolution-Answered
# 4  Area-Cmdlets-Utility Issue-Question Resolution...
#
#                                                 body  label              class
# 0  default description\n\n|Property | Value|\n|--...      1  not_high_priority
# 1  <!--\r\n\r\nFor Windows PowerShell 5.1 issues,...      1  not_high_priority
# 2                                                NaN      1  not_high_priority
# 3  # Summary of the new feature/enhancement\r\n\r...      1  not_high_priority
# 4  ## The Issue\r\nI'm pretty sure this was just ...      1  not_high_priority

# %%
# Drop duplicates by the content of the body
high_priority = high_priority.drop_duplicates(subset=['title'], keep='last')
high_priority.dropna(inplace=True)
high_priority.reset_index(inplace=True)
high_priority.drop(columns=["index"] , inplace= True)
high_priority["class"].value_counts()
# Out:
# class
# high_priority    242229
# Name: count, dtype: int64

# %%
# Drop duplicates by the content of the title
not_high_priority = not_high_priority.drop_duplicates(subset=['title'], keep='last')
not_high_priority.dropna(inplace=True)
not_high_priority.reset_index(inplace=True)
not_high_priority.drop(columns=["index"] , inplace= True)
not_high_priority["class"].value_counts()
# Out:
# /tmp/ipykernel_932825/3768055171.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority.dropna(inplace=True)
# /tmp/ipykernel_932825/3768055171.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority.drop(columns=["index"] , inplace= True)
# class
# not_high_priority    1344895
# Name: count, dtype: int64

# %%
high_priority.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242229 entries, 0 to 242228
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          242229 non-null  float64
#  1   type        242229 non-null  object
#  2   created_at  242229 non-null  object
#  3   repo        242229 non-null  object
#  4   repo_url    242229 non-null  object
#  5   action      242229 non-null  object
#  6   title       242229 non-null  object
#  7   labels      242229 non-null  object
#  8   body        242229 non-null  object
#  9   label       242229 non-null  int64
#  10  class       242229 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 20.3+ MB

# %%
def filter_texts_by_length(df, column_name='body', min_length=1000):
    """
    Filters a DataFrame to keep only rows where the specified column's text length is at least the given minimum.

    Parameters:
    - df: pandas.DataFrame, the DataFrame to filter.
    - column_name: str, the name of the column containing text to check length.
    - min_length: int, the minimum length of text to keep.

    Returns:
    - pandas.DataFrame, filtered DataFrame.
    """
    length_before = len(df)
    # Calculate the length of each string in the specified column
    df['text_length'] = df[column_name].str.len()

    # Filter the DataFrame to keep only rows where text length meets the minimum requirement
    filtered_df = df[df['text_length'] >= min_length]

    # Drop the temporary 'text_length' column
    filtered_df = filtered_df.drop(columns=['text_length'])
    length_after = len(filtered_df)
    print(f"Number of rows before: {length_before}")
    print(f"Number of rows after: {length_after}")
    print(f"Difference: {length_before - length_after}")

    return filtered_df

# %%
high_priority = filter_texts_by_length(high_priority, column_name='body', min_length=500) 
high_priority.head()
# Out:
# Number of rows before: 242229
# Number of rows after: 87396
# Difference: 154833
#               id         type           created_at                repo  \
# 0   1.141755e+10  IssuesEvent  2020-02-03 00:02:58  openmsupply/mobile
# 9   1.141828e+10  IssuesEvent  2020-02-03 03:52:24       nhn/tui.chart
# 10  1.141832e+10  IssuesEvent  2020-02-03 04:04:30         zulip/zulip
# 11  1.141839e+10  IssuesEvent  2020-02-03 04:21:05         zulip/zulip
# 14  1.141845e+10  IssuesEvent  2020-02-03 04:38:09     pyvista/pyvista
#
#                                            repo_url  action  \
# 0   https://api.github.com/repos/openmsupply/mobile  closed
# 9        https://api.github.com/repos/nhn/tui.chart  closed
# 10         https://api.github.com/repos/zulip/zulip  closed
# 11         https://api.github.com/repos/zulip/zulip  closed
# 14     https://api.github.com/repos/pyvista/pyvista  closed
#
#                                                 title  \
# 0                  Auto-log out after some time frame
# 9                       feat: improving tooltip event
# 10  Add rate limiting to the login and password ch...
# 11                               Error with AWX 7.0.0
# 14   SegFault when closing session after pyvista.plot
#
#                                                labels  \
# 0   Docs: not needed Effort: small Feature Module:...
# 9   Category: Event NHN Priority: High Type: Enhan...
# 10  area: authentication enhancement good first is...
# 11              area: integrations bug priority: high
# 14                                  bug priority-high
#
#                                                  body  label          class
# 0   ## Is your feature request related to a proble...      0  high_priority
# 9   <!--\r\nThank you for your contribution.\r\n\r...      0  high_priority
# 10  Zulip historically has relied on strong passwo...      0  high_priority
# 11  Hello.\r\nI'm testing integration between **AW...      0  high_priority
# 14  **Describe the bug, what's wrong, and what you...      0  high_priority

# %%
not_high_priority = filter_texts_by_length(not_high_priority, column_name='body', min_length=500)
not_high_priority.head()
# Out:
# Number of rows before: 1344895
# Number of rows after: 544158
# Difference: 800737
# /tmp/ipykernel_932825/2273182604.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text_length'] = df[column_name].str.len()
#              id         type           created_at  \
# 0  1.141754e+10  IssuesEvent  2020-02-03 00:00:12
# 1  1.141754e+10  IssuesEvent  2020-02-03 00:00:16
# 2  1.141754e+10  IssuesEvent  2020-02-03 00:00:18
# 3  1.141754e+10  IssuesEvent  2020-02-03 00:00:18
# 4  1.141754e+10  IssuesEvent  2020-02-03 00:00:22
#
#                                     repo  \
# 0                  PowerShell/PowerShell
# 1                  PowerShell/PowerShell
# 2                  PowerShell/PowerShell
# 3  fjmorant/react-native-nested-listview
# 4                  PowerShell/PowerShell
#
#                                             repo_url  action  \
# 0  https://api.github.com/repos/PowerShell/PowerS...  closed
# 1  https://api.github.com/repos/PowerShell/PowerS...  closed
# 2  https://api.github.com/repos/PowerShell/PowerS...  closed
# 3  https://api.github.com/repos/fjmorant/react-na...  closed
# 4  https://api.github.com/repos/PowerShell/PowerS...  closed
#
#                                                title  \
# 0                                         Show alias
# 1                               $ENV in using module
# 2          Measure-Command does not measure its self
# 3              List collapses on state (data) change
# 4  ArrayList conversion from one element Json thr...
#
#                                               labels  \
# 0                 Issue-Question Resolution-Answered
# 1   Area-Language Issue-Question Resolution-Answered
# 2  Area-Cmdlets-Utility Issue-Question Resolution...
# 3                                  no-issue-activity
# 4                 Issue-Question Resolution-Answered
#
#                                                 body  label              class
# 0  <!--\r\n\r\nFor Windows PowerShell 5.1 issues,...      1  not_high_priority
# 1  # Summary of the new feature/enhancement\r\n\r...      1  not_high_priority
# 2  ## The Issue\r\nI'm pretty sure this was just ...      1  not_high_priority
# 3  Hey,\r\n\r\nreally neat library you got here! ...      1  not_high_priority
# 4  # Steps to reproduce\r\nIn 7.0.0-preview.6-ubu...      1  not_high_priority

# %%
label_counts = high_priority["class"].value_counts()
label_counts_nhp = not_high_priority["class"].value_counts()
print(label_counts)
not_high_priority_count = label_counts_nhp["not_high_priority"]
print(not_high_priority_count)
hp_count = label_counts["high_priority"]
hp_count
# Out:
# class
# high_priority    87396
# Name: count, dtype: int64
# 544158
# 87396

# %%
not_high_priority = not_high_priority.sample(frac=hp_count/not_high_priority_count, random_state=42)
not_high_priority
# Out:
#                    id         type           created_at  \
# 1025626  2.485701e+10  IssuesEvent  2022-10-27 03:51:52
# 671272   3.062459e+10  IssuesEvent  2023-07-24 10:33:08
# 372078   3.205842e+10  IssuesEvent  2023-09-24 11:20:27
# 70637    6.517380e+09  IssuesEvent  2017-08-27 22:36:50
# 1166544  1.195870e+10  IssuesEvent  2020-04-04 19:03:19
# ...               ...          ...                  ...
# 1249801  9.106555e+09  IssuesEvent  2019-02-21 00:21:41
# 1221441  9.307246e+09  IssuesEvent  2019-03-25 11:46:33
# 873957   2.336514e+10  IssuesEvent  2022-08-10 14:47:36
# 1314406  1.275286e+10  IssuesEvent  2020-06-27 18:44:45
# 881449   2.337271e+10  IssuesEvent  2022-08-10 21:35:50
#
#                                  repo  \
# 1025626                       ppy/osu
# 671272   databricks/databricks-vscode
# 372078              Sinytra/Connector
# 70637              webcompat/web-bugs
# 1166544     deathlyrage/pot-demo-bugs
# ...                               ...
# 1249801                  mozilla/send
# 1221441             composer/composer
# 873957   jgeraigery/HubSpot-Test-Repo
# 1314406         Laravel-Backpack/CRUD
# 881449     AdguardTeam/AdguardFilters
#
#                                                   repo_url  action  \
# 1025626               https://api.github.com/repos/ppy/osu  closed
# 671272   https://api.github.com/repos/databricks/databr...  closed
# 372078      https://api.github.com/repos/Sinytra/Connector  closed
# 70637      https://api.github.com/repos/webcompat/web-bugs  closed
# 1166544  https://api.github.com/repos/deathlyrage/pot-d...  opened
# ...                                                    ...     ...
# 1249801          https://api.github.com/repos/mozilla/send  closed
# 1221441     https://api.github.com/repos/composer/composer  closed
# 873957   https://api.github.com/repos/jgeraigery/HubSpo...  opened
# 1314406  https://api.github.com/repos/Laravel-Backpack/...  closed
# 881449   https://api.github.com/repos/AdguardTeam/Adgua...  closed
#
#                                                      title  \
# 1025626           Toggle Mute key bind broken if held down
# 671272                                Can't load .env file
# 372078           [1.20.1] Fabric - Custom Piglin Bartering
# 70637                     google.com - see bug description
# 1166544                      Rock clipping through terrain
# ...                                                    ...
# 1249801  [Send v2] Several buttons can not be focused w...
# 1221441         The "discard-changes" option does not work
# 873957   hibernate-validator-5.4.3.Final.jar: 1 vulnera...
# 1314406   [Help] Pulling quantity of a material 'selected'
# 881449                                     comic-pureri.jp
#
#                                               labels  \
# 1025626                     type:UX good-first-issue
# 671272                                           bug
# 372078                                        compat
# 70637      browser-firefox-mobile status-needstriage
# 1166544                                          bug
# ...                                              ...
# 1249801                            [QA]:Normal issue
# 1221441                                      Support
# 873957                        security vulnerability
# 1314406                                          Bug
# 881449   T: Social Widget P4: Low N: AdGuard for iOS
#
#                                                       body  label  \
# 1025626  ### Type\n\nGame behaviour\n\n### Bug descript...      1
# 671272   When running the databricks extension on windo...      1
# 372078   ### Mod Name\n\nCustom Piglin Bartering (open-...      1
# 70637    <!-- @browser: Firefox Mobile 57.0 -->\n<!-- @...      1
# 1166544  ## Expected Behavior\r\nFor terrain to be leve...      1
# ...                                                    ...    ...
# 1249801  **[Notes]:**\r\n- This issue is reproducible w...      1
# 1221441  Composer JSON schema mentions an option called...      1
# 873957   <details><summary><img src='https://whitesourc...      1
# 1314406  I have a requirement where in I have two field...      1
# 881449   \r\n### Issue URL (Social Widget)\r\n [https:/...      1
#
#                      class
# 1025626  not_high_priority
# 671272   not_high_priority
# 372078   not_high_priority
# 70637    not_high_priority
# 1166544  not_high_priority
# ...                    ...
# 1249801  not_high_priority
# 1221441  not_high_priority
# 873957   not_high_priority
# 1314406  not_high_priority
# 881449   not_high_priority
#
# [87396 rows x 11 columns]

# %%
all_priority = pd.concat([high_priority,not_high_priority] , ignore_index = True)
all_priority.tail()
# Out:
#                   id         type           created_at  \
# 174787  9.106555e+09  IssuesEvent  2019-02-21 00:21:41
# 174788  9.307246e+09  IssuesEvent  2019-03-25 11:46:33
# 174789  2.336514e+10  IssuesEvent  2022-08-10 14:47:36
# 174790  1.275286e+10  IssuesEvent  2020-06-27 18:44:45
# 174791  2.337271e+10  IssuesEvent  2022-08-10 21:35:50
#
#                                 repo  \
# 174787                  mozilla/send
# 174788             composer/composer
# 174789  jgeraigery/HubSpot-Test-Repo
# 174790         Laravel-Backpack/CRUD
# 174791    AdguardTeam/AdguardFilters
#
#                                                  repo_url  action  \
# 174787          https://api.github.com/repos/mozilla/send  closed
# 174788     https://api.github.com/repos/composer/composer  closed
# 174789  https://api.github.com/repos/jgeraigery/HubSpo...  opened
# 174790  https://api.github.com/repos/Laravel-Backpack/...  closed
# 174791  https://api.github.com/repos/AdguardTeam/Adgua...  closed
#
#                                                     title  \
# 174787  [Send v2] Several buttons can not be focused w...
# 174788         The "discard-changes" option does not work
# 174789  hibernate-validator-5.4.3.Final.jar: 1 vulnera...
# 174790   [Help] Pulling quantity of a material 'selected'
# 174791                                    comic-pureri.jp
#
#                                              labels  \
# 174787                            [QA]:Normal issue
# 174788                                      Support
# 174789                       security vulnerability
# 174790                                          Bug
# 174791  T: Social Widget P4: Low N: AdGuard for iOS
#
#                                                      body  label  \
# 174787  **[Notes]:**\r\n- This issue is reproducible w...      1
# 174788  Composer JSON schema mentions an option called...      1
# 174789  <details><summary><img src='https://whitesourc...      1
# 174790  I have a requirement where in I have two field...      1
# 174791  \r\n### Issue URL (Social Widget)\r\n [https:/...      1
#
#                     class
# 174787  not_high_priority
# 174788  not_high_priority
# 174789  not_high_priority
# 174790  not_high_priority
# 174791  not_high_priority

# %%
# Does this need to be more balanced?
all_priority["label"].value_counts()
# Out:
# label
# 0    87396
# 1    87396
# Name: count, dtype: int64

# %%
print(all_priority["title"][0])
print(all_priority["body"][0])
# Out:
# Auto-log out after some time frame
# ## Is your feature request related to a problem? Please describe.
#
# From @craigdrown
#
# IC Requirement: Automatically log a user out after a time frame of X for security reasons. Data should not be lost which was being worked on.
#
# ## Describe the solution you'd like
#
# Log the user out after X time
#
# ## Implementation
#
# Could use store custom data `logoutTimeoutPeriodInSecondsOrMinutes` to set the period..
#
# - Use [AppState](https://facebook.github.io/react-native/docs/appstate#addeventlistener) to hook into the app going into the background - log the user out if so. Android would go to sleep after X amount of time, putting the app into the background (I THINK, UNTESTED)
# - Use a package like https://www.npmjs.com/package/redux-idle-monitor to track activity, have a schedule that is reset each time an event happens.
# - Use the above package but combine it with the current user authentication scheduler (tries to re-auth against the server every X minutes, or the local DB if no connection available) - I think not good
#
# ## Describe alternatives you've considered
#
# Not having this in the dispensary/IC branch 🤣
#
# ## Additional context
#
# @wlthomson @mark-prins @Chris-Petty thoughts?

# %%
# Copy content of body to a new col named text
all_priority["text"] = all_priority["title"] + all_priority["body"]
all_priority.tail()
# Out:
#                   id         type           created_at  \
# 174787  9.106555e+09  IssuesEvent  2019-02-21 00:21:41
# 174788  9.307246e+09  IssuesEvent  2019-03-25 11:46:33
# 174789  2.336514e+10  IssuesEvent  2022-08-10 14:47:36
# 174790  1.275286e+10  IssuesEvent  2020-06-27 18:44:45
# 174791  2.337271e+10  IssuesEvent  2022-08-10 21:35:50
#
#                                 repo  \
# 174787                  mozilla/send
# 174788             composer/composer
# 174789  jgeraigery/HubSpot-Test-Repo
# 174790         Laravel-Backpack/CRUD
# 174791    AdguardTeam/AdguardFilters
#
#                                                  repo_url  action  \
# 174787          https://api.github.com/repos/mozilla/send  closed
# 174788     https://api.github.com/repos/composer/composer  closed
# 174789  https://api.github.com/repos/jgeraigery/HubSpo...  opened
# 174790  https://api.github.com/repos/Laravel-Backpack/...  closed
# 174791  https://api.github.com/repos/AdguardTeam/Adgua...  closed
#
#                                                     title  \
# 174787  [Send v2] Several buttons can not be focused w...
# 174788         The "discard-changes" option does not work
# 174789  hibernate-validator-5.4.3.Final.jar: 1 vulnera...
# 174790   [Help] Pulling quantity of a material 'selected'
# 174791                                    comic-pureri.jp
#
#                                              labels  \
# 174787                            [QA]:Normal issue
# 174788                                      Support
# 174789                       security vulnerability
# 174790                                          Bug
# 174791  T: Social Widget P4: Low N: AdGuard for iOS
#
#                                                      body  label  \
# 174787  **[Notes]:**\r\n- This issue is reproducible w...      1
# 174788  Composer JSON schema mentions an option called...      1
# 174789  <details><summary><img src='https://whitesourc...      1
# 174790  I have a requirement where in I have two field...      1
# 174791  \r\n### Issue URL (Social Widget)\r\n [https:/...      1
#
#                     class                                               text
# 174787  not_high_priority  [Send v2] Several buttons can not be focused w...
# 174788  not_high_priority  The "discard-changes" option does not workComp...
# 174789  not_high_priority  hibernate-validator-5.4.3.Final.jar: 1 vulnera...
# 174790  not_high_priority  [Help] Pulling quantity of a material 'selecte...
# 174791  not_high_priority  comic-pureri.jp\r\n### Issue URL (Social Widge...

# %%
all_priority["text"][0]
# Out:
# "Auto-log out after some time frame## Is your feature request related to a problem? Please describe.\r\n\r\nFrom @craigdrown \r\n\r\nIC Requirement: Automatically log a user out after a time frame of X for security reasons. Data should not be lost which was being worked on.\r\n\r\n## Describe the solution you'd like\r\n\r\nLog the user out after X time\r\n\r\n## Implementation\r\n\r\nCould use store custom data `logoutTimeoutPeriodInSecondsOrMinutes` to set the period..\r\n\r\n- Use [AppState](https://facebook.github.io/react-native/docs/appstate#addeventlistener) to hook into the app going into the background - log the user out if so. Android would go to sleep after X amount of time, putting the app into the background (I THINK, UNTESTED)\r\n- Use a package like https://www.npmjs.com/package/redux-idle-monitor to track activity, have a schedule that is reset each time an event happens.\r\n- Use the above package but combine it with the current user authentication scheduler (tries to re-auth against the server every X minutes, or the local DB if no connection available) - I think not good\r\n\r\n## Describe alternatives you've considered\r\n\r\nNot having this in the dispensary/IC branch 🤣 \r\n\r\n## Additional context\r\n\r\n@wlthomson @mark-prins @Chris-Petty thoughts?\r\n"

# %%
# Make a new dataframe with only text, label and class cols.
all_priority_subset = all_priority[["text" , "label" , "class"]]
all_priority_subset
# Out:
#                                                      text  label  \
# 0       Auto-log out after some time frame## Is your f...      0
# 1       feat: improving tooltip event<!--\r\nThank you...      0
# 2       Add rate limiting to the login and password ch...      0
# 3       Error with AWX 7.0.0Hello.\r\nI'm testing inte...      0
# 4       SegFault when closing session after pyvista.pl...      0
# ...                                                   ...    ...
# 174787  [Send v2] Several buttons can not be focused w...      1
# 174788  The "discard-changes" option does not workComp...      1
# 174789  hibernate-validator-5.4.3.Final.jar: 1 vulnera...      1
# 174790  [Help] Pulling quantity of a material 'selecte...      1
# 174791  comic-pureri.jp\r\n### Issue URL (Social Widge...      1
#
#                     class
# 0           high_priority
# 1           high_priority
# 2           high_priority
# 3           high_priority
# 4           high_priority
# ...                   ...
# 174787  not_high_priority
# 174788  not_high_priority
# 174789  not_high_priority
# 174790  not_high_priority
# 174791  not_high_priority
#
# [174792 rows x 3 columns]

# %%
# Convert to string
all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)
# Out:
# /tmp/ipykernel_932825/3106036705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)

# %%
all_priority_subset
# Out:
#                                                      text  label  \
# 0       Auto-log out after some time frame## Is your f...      0
# 1       feat: improving tooltip event<!--\r\nThank you...      0
# 2       Add rate limiting to the login and password ch...      0
# 3       Error with AWX 7.0.0Hello.\r\nI'm testing inte...      0
# 4       SegFault when closing session after pyvista.pl...      0
# ...                                                   ...    ...
# 174787  [Send v2] Several buttons can not be focused w...      1
# 174788  The "discard-changes" option does not workComp...      1
# 174789  hibernate-validator-5.4.3.Final.jar: 1 vulnera...      1
# 174790  [Help] Pulling quantity of a material 'selecte...      1
# 174791  comic-pureri.jp\r\n### Issue URL (Social Widge...      1
#
#                     class                                           text_str
# 0           high_priority  Auto-log out after some time frame## Is your f...
# 1           high_priority  feat: improving tooltip event<!--\r\nThank you...
# 2           high_priority  Add rate limiting to the login and password ch...
# 3           high_priority  Error with AWX 7.0.0Hello.\r\nI'm testing inte...
# 4           high_priority  SegFault when closing session after pyvista.pl...
# ...                   ...                                                ...
# 174787  not_high_priority  [Send v2] Several buttons can not be focused w...
# 174788  not_high_priority  The "discard-changes" option does not workComp...
# 174789  not_high_priority  hibernate-validator-5.4.3.Final.jar: 1 vulnera...
# 174790  not_high_priority  [Help] Pulling quantity of a material 'selecte...
# 174791  not_high_priority  comic-pureri.jp\r\n### Issue URL (Social Widge...
#
# [174792 rows x 4 columns]

# %%
# Clean the data.
all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_932825/63294665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)

# %%
# Make a subset with text_clean and label
priority_label_text = all_priority_subset[["text_clean" , "label"]]
priority_label_text
# Out:
#                                                text_clean  label
# 0       autolog out after some time frame is your feat...      0
# 1       feat improving tooltip event thank you for you...      0
# 2       add rate limiting to the login and password ch...      0
# 3       error with awx 700hello im testing integration...      0
# 4       segfault when closing session after pyvistaplo...      0
# ...                                                   ...    ...
# 174787  send v2 several buttons can not be focused wit...      1
# 174788  the discardchanges option does not workcompose...      1
# 174789  hibernatevalidator543finaljar 1 vulnerabilitie...      1
# 174790  help pulling quantity of a material selectedi ...      1
# 174791  comicpurerijp issue url social widget httpscom...      1
#
# [174792 rows x 2 columns]

# %%
# Need to dropna here since cleaning function returns NaN for not english text.
priority_label_text.dropna(inplace=True)
priority_label_text.reset_index(inplace=True)
priority_label_text.drop(columns=["index"] , inplace= True)

priority_label_text
# Out:
# /tmp/ipykernel_932825/239147930.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.dropna(inplace=True)
# /tmp/ipykernel_932825/239147930.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.drop(columns=["index"] , inplace= True)
#                                                text_clean  label
# 0       autolog out after some time frame is your feat...      0
# 1       feat improving tooltip event thank you for you...      0
# 2       add rate limiting to the login and password ch...      0
# 3       error with awx 700hello im testing integration...      0
# 4       segfault when closing session after pyvistaplo...      0
# ...                                                   ...    ...
# 168651  send v2 several buttons can not be focused wit...      1
# 168652  the discardchanges option does not workcompose...      1
# 168653  hibernatevalidator543finaljar 1 vulnerabilitie...      1
# 168654  help pulling quantity of a material selectedi ...      1
# 168655  comicpurerijp issue url social widget httpscom...      1
#
# [168656 rows x 2 columns]

# %%
priority_label_text["label"].value_counts()
# Out:
# label
# 0    85002
# 1    83654
# Name: count, dtype: int64

# %%
from sklearn.utils import resample

# Split the dataset into two based on the label
df_majority = priority_label_text[priority_label_text['label'] == 0]
df_minority = priority_label_text[priority_label_text['label'] == 1]

# Undersample the majority class
df_majority_undersampled = resample(df_majority, 
                                     replace=False,    # sample without replacement
                                     n_samples=len(df_minority),     # to match minority class
                                     random_state=123) # reproducible results

# Combine minority class with downsampled majority class
df_balanced = pd.concat([df_majority_undersampled, df_minority])

# Shuffle the dataset to avoid any ordering bias
df_balanced = df_balanced.sample(frac=1).reset_index(drop=True)
priority_label_text = df_balanced
priority_label_text["label"].value_counts()
# Out:
# label
# 0    83654
# 1    83654
# Name: count, dtype: int64

# %%
# Splitting the DataFrame
test_df = priority_label_text.sample(frac=0.05, random_state=1)  # Select 5% of the data
test_file_name = f"csv/clean_test_high_vs_random.csv"
test_df.to_csv(test_file_name, index=False)
priority_df = priority_label_text.drop(test_df.index)
priority_df.reset_index(drop=True, inplace=True)
priority_df
# Out:
#                                                text_clean  label
# 0       valueerror too many values to unpack during st...      0
# 1       provide details on how to proceed with setting...      0
# 2       cve201812896 medium detected in linuxlinux46 a...      1
# 3       incorrect recoloring of the background color o...      1
# 4       csw data source australianinstituteofmarinesci...      0
# ...                                                   ...    ...
# 158938  support passing of idictionarystring object as...      1
# 158939  editor overflow menu not shown on api17 expect...      0
# 158940  client message cant detect virtualbox because ...      1
# 158941  feature gate story why do we need the feature ...      0
# 158942  genotype selectorfor those case that we have m...      0
#
# [158943 rows x 2 columns]

# %%
# Clean dataset with clean text and labels.
# 0 = high priority, 1 = not high priority
file_name = f"csv/clean_high_vs_random.csv"
priority_df.to_csv(file_name)

# %%
pri = pd.read_csv(file_name)
pri
# Out:
#         Unnamed: 0                                         text_clean  label
# 0                0  valueerror too many values to unpack during st...      0
# 1                1  provide details on how to proceed with setting...      0
# 2                2  cve201812896 medium detected in linuxlinux46 a...      1
# 3                3  incorrect recoloring of the background color o...      1
# 4                4  csw data source australianinstituteofmarinesci...      0
# ...            ...                                                ...    ...
# 158938      158938  support passing of idictionarystring object as...      1
# 158939      158939  editor overflow menu not shown on api17 expect...      0
# 158940      158940  client message cant detect virtualbox because ...      1
# 158941      158941  feature gate story why do we need the feature ...      0
# 158942      158942  genotype selectorfor those case that we have m...      0
#
# [158943 rows x 3 columns]
