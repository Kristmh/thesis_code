# %% [markdown]
# # Data cleaning
# We want the class with labels as numerical value and the body with clean text.
#
# This will remove:
# * duplicates
# * NaN entires
# * non english
# * url, html
#
# * make it lowercase
# * combine title and body

# %%
import pandas as pd
import sys
import numpy as np
sys.path.append("../../../scripts_shared/")
from preprocess_text import preprocess_text

# %%
# Read CSV into a dataframe
high_priority = pd.read_csv("csv/high/high_priority_no_td.csv", index_col=0)
medium_priority = pd.read_csv("csv/medium/medium_priority_no_td.csv", index_col=0)
low_priority = pd.read_csv("csv/low/low_priority_no_td.csv", index_col=0)

# %%
# Number or different labels
high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                   count
# labels
# bug high priority                 10435
# high priority                     10360
# High Priority                      7484
# enhancement high priority          5486
# Priority: High                     4751
# priority.High                      3694
# priority.High type.Task            3685
# priority.high type.task            3209
# priority.High type.Story           2979
# priority.high                      2749
# bug priority: high                 2306
# high-priority                      2262
# priority: high                     2178
# bug high-priority                  2159
# type.Story priority.High           2155
# priority.high type.story           2130
# type.Task priority.High            2022
# bug High Priority                  1888
# High priority                      1815
# Priority: High Type: Bug           1768
# priority:high                      1726
# bug priority:high                  1470
# High Priority bug                  1338
# Priority: High bug                 1200
# Bug High Priority                  1143
# feature high priority              1091
# enhancement priority: high         1090
# enhancement high-priority          1053
# enhancement priority:high           982
# priority-high                       955
# bug priority-high                   927
# enhancement High Priority           902
# bug Priority: High                  837
# Priority: High Type: Enhancement    835
# high priority task                  831
# bug High priority                   744
# priority high                       733
# priority.high type.bug              717
# priority: high type: bug            704
# Type: Bug Priority: High            639
# Bug Priority: High                  620
# High Priority enhancement           611
# documentation priority.High         600
# prio:high                           587
# Bug - High Priority                 562
# priority.High type.Enhancement      562
# bug prio-high                       541
# Priority: High Type: Feature        541
# priority.high type.enhancement      540
# priority/high                       537

# %%
#Give each priority a label by number.
# 'Label encoding'. Makes is easier for machine learning models to work with categorical data.
high_priority["labels"] = 0
high_priority["class"] = "high_priority"
medium_priority["labels"] = 1
medium_priority["class"] = "medium_priority"
low_priority["labels"] = 2
low_priority["class"] = "low_priority"
high_priority.head()
# Out:
#              id         type           created_at  \
# 0  1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1  1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2  1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3  1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4  1.141756e+10  IssuesEvent  2020-02-03 00:08:03
#
#                                   repo  \
# 0            unitystation/unitystation
# 1  zowe/sample-spring-boot-api-service
# 2                   openmsupply/mobile
# 3  UltimateCodeMonkeys/CodeMonkeysMVVM
# 4   wordpress-mobile/WordPress-Android
#
#                                             repo_url  action  \
# 0  https://api.github.com/repos/unitystation/unit...  closed
# 1  https://api.github.com/repos/zowe/sample-sprin...  closed
# 2    https://api.github.com/repos/openmsupply/mobile  closed
# 3  https://api.github.com/repos/UltimateCodeMonke...  opened
# 4  https://api.github.com/repos/wordpress-mobile/...  closed
#
#                                                title  labels  \
# 0  Client breaking NRE when using edit field on C...       0
# 1  The SDK provides a separate Java (no-Spring) l...       0
# 2                 Auto-log out after some time frame       0
# 3  Migrate: CodeMonkeys ViewModelNavigationServic...       0
# 4  IA Reader filter bottom sheet: manage untitled...       0
#
#                                                 body          class
# 0  ### Bug:\r\n\r\nIf you use the edit field of t...  high_priority
# 1  - The commons-spring library is split into:\r\...  high_priority
# 2  ## Is your feature request related to a proble...  high_priority
# 3  Migrate the Xamarin.Forms navigation service i...  high_priority
# 4  In the filter bottom sheet we introduced in th...  high_priority

# %%
priority = pd.concat([high_priority, medium_priority, low_priority] , ignore_index = True)

# %%
priority[priority["repo"] == "python/mypy"]
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body, class]
# Index: []

# %%
# Remove mypy from the dataset
priority = priority[priority["repo"] != "python/mypy"]
priority
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3       1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4       1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...              ...          ...                  ...
# 821952  2.060586e+10  IssuesEvent  2022-03-06 23:45:23
# 821953  7.334740e+09  IssuesEvent  2018-03-06 00:10:40
# 821954  7.334876e+09  IssuesEvent  2018-03-06 00:53:49
# 821955  7.335047e+09  IssuesEvent  2018-03-06 01:48:07
# 821956  7.335050e+09  IssuesEvent  2018-03-06 01:49:10
#
#                                        repo  \
# 0                 unitystation/unitystation
# 1       zowe/sample-spring-boot-api-service
# 2                        openmsupply/mobile
# 3       UltimateCodeMonkeys/CodeMonkeysMVVM
# 4        wordpress-mobile/WordPress-Android
# ...                                     ...
# 821952            bounswe/bounswe2022group1
# 821953                      hoodedice/notes
# 821954            zephyrproject-rtos/zephyr
# 821955                   uwnrg/minotaur-cpp
# 821956                   uwnrg/minotaur-cpp
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/unitystation/unit...  closed
# 1       https://api.github.com/repos/zowe/sample-sprin...  closed
# 2         https://api.github.com/repos/openmsupply/mobile  closed
# 3       https://api.github.com/repos/UltimateCodeMonke...  opened
# 4       https://api.github.com/repos/wordpress-mobile/...  closed
# ...                                                   ...     ...
# 821952  https://api.github.com/repos/bounswe/bounswe20...  closed
# 821953       https://api.github.com/repos/hoodedice/notes  opened
# 821954  https://api.github.com/repos/zephyrproject-rto...  closed
# 821955    https://api.github.com/repos/uwnrg/minotaur-cpp  closed
# 821956    https://api.github.com/repos/uwnrg/minotaur-cpp  closed
#
#                                                     title  labels  \
# 0       Client breaking NRE when using edit field on C...       0
# 1       The SDK provides a separate Java (no-Spring) l...       0
# 2                      Auto-log out after some time frame       0
# 3       Migrate: CodeMonkeys ViewModelNavigationServic...       0
# 4       IA Reader filter bottom sheet: manage untitled...       0
# ...                                                   ...     ...
# 821952                        Editing Navigator of  Wiki        2
# 821953                           Check if passwords match       2
# 821954  Add doc to samples/bluetooth/mesh & samples/bl...       2
# 821955                   Fix the photo in about dialog xd       2
# 821956  Move Record Video/Screenshot and camera select...       2
#
#                                                      body          class
# 0       ### Bug:\r\n\r\nIf you use the edit field of t...  high_priority
# 1       - The commons-spring library is split into:\r\...  high_priority
# 2       ## Is your feature request related to a proble...  high_priority
# 3       Migrate the Xamarin.Forms navigation service i...  high_priority
# 4       In the filter bottom sheet we introduced in th...  high_priority
# ...                                                   ...            ...
# 821952  The navigator of the wiki should be edited and...   low_priority
# 821953  JavaScript code (or see if possible without) t...   low_priority
# 821954  We should document what exactly the sample is ...   low_priority
# 821955                                                NaN   low_priority
# 821956            that can be opened from a dropdown menu   low_priority
#
# [821957 rows x 10 columns]

# %%
# Drop duplicates by the content of the body
priority = priority.drop_duplicates(subset=['title'], keep='last')
priority.dropna(inplace=True)
priority.reset_index(inplace=True)
priority.drop(columns=["index"] , inplace= True)
priority["class"].value_counts()
# Out:
# /tmp/ipykernel_267477/2859834588.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority.dropna(inplace=True)
# /tmp/ipykernel_267477/2859834588.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority.drop(columns=["index"] , inplace= True)
# class
# high_priority      236610
# medium_priority    160163
# low_priority       143121
# Name: count, dtype: int64

# %%
# Split the dataframe 
high_priority = priority.loc[priority['class'] == 'high_priority'].copy()
medium_priority = priority.loc[priority['class'] == 'medium_priority'].copy()
low_priority = priority.loc[priority['class'] == 'low_priority'].copy()

# %%
high_label_counts = high_priority["class"].value_counts()
medium_label_counts = medium_priority["class"].value_counts()
low_label_counts = low_priority["class"].value_counts()
hp_count = high_label_counts["high_priority"]
print(f"hp count: {hp_count}")
mp_count = medium_label_counts["medium_priority"]
print(f"med count: {mp_count}")
lp_count = low_label_counts["low_priority"]
print(f"low count: {lp_count}")
# Out:
# hp count: 236610
# med count: 160163
# low count: 143121

# %%
high_priority = high_priority.sample(frac=lp_count/hp_count, random_state=42)
high_and_low_priority = pd.concat([high_priority, low_priority] , ignore_index = True)
high_and_low_priority["class"].value_counts()
# Out:
# class
# high_priority    143121
# low_priority     143121
# Name: count, dtype: int64

# %%
high_and_low_priority["labels"] = 1
medium_priority["labels"] = 0
high_and_low_priority["class"] = "high_and_low_priority"
high_and_low_priority["class"].value_counts()
# Out:
# class
# high_and_low_priority    286242
# Name: count, dtype: int64

# %%
high_and_low_label_counts = high_and_low_priority["class"].value_counts()
hl_count = high_and_low_label_counts["high_and_low_priority"]
hl_count
# Out:
# 286242

# %%
high_and_low_priority = high_and_low_priority.sample(frac=mp_count/hl_count, random_state=42)
all_priority = pd.concat([medium_priority, high_and_low_priority] , ignore_index = True)
all_priority["class"].value_counts()
# Out:
# class
# medium_priority          160163
# high_and_low_priority    160163
# Name: count, dtype: int64

# %%
print(all_priority["title"][0])
print(all_priority["body"][0])
# Out:
# Increase Indent of ListItem
# ListItems should have greater indent to differentiate them from ListTitle

# %%
# Copy content of body to a new col named text
all_priority["text"] = all_priority["title"] + all_priority["body"]
all_priority.tail()
# Out:
#                   id         type           created_at  \
# 320321  2.507081e+10  IssuesEvent  2022-11-07 12:00:35
# 320322  7.177764e+09  IssuesEvent  2018-01-31 14:39:59
# 320323  1.595200e+10  IssuesEvent  2021-04-15 10:32:06
# 320324  1.890955e+10  IssuesEvent  2021-11-16 12:46:46
# 320325  1.356535e+10  IssuesEvent  2020-09-18 11:33:12
#
#                                repo  \
# 320321        zeitgeistpm/zeitgeist
# 320322                  CCAFS/MARLO
# 320323        ContinualAI/avalanche
# 320324                  epam/Indigo
# 320325  itggot-TE4/Fabulous_Pirates
#
#                                                  repo_url  action  \
# 320321  https://api.github.com/repos/zeitgeistpm/zeitg...  closed
# 320322           https://api.github.com/repos/CCAFS/MARLO  closed
# 320323  https://api.github.com/repos/ContinualAI/avala...  closed
# 320324           https://api.github.com/repos/epam/Indigo  closed
# 320325  https://api.github.com/repos/itggot-TE4/Fabulo...  closed
#
#                                                     title  labels  \
# 320321  Oracle bond is not slashed when market resolve...       1
# 320322  Develop a summary report that generates the PO...       1
# 320323  Synaptic Intelligence implementation differs f...       1
# 320324                           Modernize Indigo Service       1
# 320325  Teachers can play a "game" based on the select...       1
#
#                                                      body  \
# 320321  This is a bug in `on_resolution` which can eas...
# 320322  - [x] Create template with Pentaho Report Desi...
# 320323  I was looking at Synaptic Intelligence impleme...
# 320324  We need to:\r\n\r\n- [x] Update from Flask to ...
# 320325  - [x] Loads images from backend\r\n\r\n- [x] T...
#
#                         class  \
# 320321  high_and_low_priority
# 320322  high_and_low_priority
# 320323  high_and_low_priority
# 320324  high_and_low_priority
# 320325  high_and_low_priority
#
#                                                      text
# 320321  Oracle bond is not slashed when market resolve...
# 320322  Develop a summary report that generates the PO...
# 320323  Synaptic Intelligence implementation differs f...
# 320324  Modernize Indigo ServiceWe need to:\r\n\r\n- [...
# 320325  Teachers can play a "game" based on the select...

# %%
all_priority["text"][0]
# Out:
# 'Increase Indent of ListItemListItems should have greater indent to differentiate them from ListTitle'

# %%
# Make a new dataframe with only text, label and class cols.
all_priority_subset = all_priority[["text" , "labels" , "class"]]
all_priority_subset
# Out:
#                                                      text  labels  \
# 0       Increase Indent of ListItemListItems should ha...       0
# 1       Add as_mcmc and as_mcmc_list wrappers on as.mc...       0
# 2       Create New Option For Dropdown Scriptable Obje...       0
# 3       Header takes too much vertical space on wide s...       0
# 4       PageBody extends past html containerWhen navig...       0
# ...                                                   ...     ...
# 320321  Oracle bond is not slashed when market resolve...       1
# 320322  Develop a summary report that generates the PO...       1
# 320323  Synaptic Intelligence implementation differs f...       1
# 320324  Modernize Indigo ServiceWe need to:\r\n\r\n- [...       1
# 320325  Teachers can play a "game" based on the select...       1
#
#                         class
# 0             medium_priority
# 1             medium_priority
# 2             medium_priority
# 3             medium_priority
# 4             medium_priority
# ...                       ...
# 320321  high_and_low_priority
# 320322  high_and_low_priority
# 320323  high_and_low_priority
# 320324  high_and_low_priority
# 320325  high_and_low_priority
#
# [320326 rows x 3 columns]

# %%
# Convert to string
all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)
# Out:
# /tmp/ipykernel_267477/3106036705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)

# %%
all_priority_subset
# Out:
#                                                      text  labels  \
# 0       Increase Indent of ListItemListItems should ha...       0
# 1       Add as_mcmc and as_mcmc_list wrappers on as.mc...       0
# 2       Create New Option For Dropdown Scriptable Obje...       0
# 3       Header takes too much vertical space on wide s...       0
# 4       PageBody extends past html containerWhen navig...       0
# ...                                                   ...     ...
# 320321  Oracle bond is not slashed when market resolve...       1
# 320322  Develop a summary report that generates the PO...       1
# 320323  Synaptic Intelligence implementation differs f...       1
# 320324  Modernize Indigo ServiceWe need to:\r\n\r\n- [...       1
# 320325  Teachers can play a "game" based on the select...       1
#
#                         class  \
# 0             medium_priority
# 1             medium_priority
# 2             medium_priority
# 3             medium_priority
# 4             medium_priority
# ...                       ...
# 320321  high_and_low_priority
# 320322  high_and_low_priority
# 320323  high_and_low_priority
# 320324  high_and_low_priority
# 320325  high_and_low_priority
#
#                                                  text_str
# 0       Increase Indent of ListItemListItems should ha...
# 1       Add as_mcmc and as_mcmc_list wrappers on as.mc...
# 2       Create New Option For Dropdown Scriptable Obje...
# 3       Header takes too much vertical space on wide s...
# 4       PageBody extends past html containerWhen navig...
# ...                                                   ...
# 320321  Oracle bond is not slashed when market resolve...
# 320322  Develop a summary report that generates the PO...
# 320323  Synaptic Intelligence implementation differs f...
# 320324  Modernize Indigo ServiceWe need to:\r\n\r\n- [...
# 320325  Teachers can play a "game" based on the select...
#
# [320326 rows x 4 columns]

# %%
# Clean the data.
all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_267477/63294665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)

# %%
# Make a subset with text_clean and label
priority_label_text = all_priority_subset[["text_clean" , "labels", "class"]]
priority_label_text
# Out:
#                                                text_clean  labels  \
# 0       increase indent of listitemlistitems should ha...       0
# 1       add asmcmc and asmcmclist wrappers on asmcmc a...       0
# 2       create new option for dropdown scriptable obje...       0
# 3       header takes too much vertical space on wide s...       0
# 4       pagebody extends past html containerwhen navig...       0
# ...                                                   ...     ...
# 320321  oracle bond is not slashed when market resolve...       1
# 320322  develop a summary report that generates the po...       1
# 320323  synaptic intelligence implementation differs f...       1
# 320324  modernize indigo servicewe need to x update fr...       1
# 320325  teachers can play a game based on the selected...       1
#
#                         class
# 0             medium_priority
# 1             medium_priority
# 2             medium_priority
# 3             medium_priority
# 4             medium_priority
# ...                       ...
# 320321  high_and_low_priority
# 320322  high_and_low_priority
# 320323  high_and_low_priority
# 320324  high_and_low_priority
# 320325  high_and_low_priority
#
# [320326 rows x 3 columns]

# %%
# Need to dropna here since cleaning function returns NaN for not english text.
priority_label_text.dropna(inplace=True)
priority_label_text.reset_index(inplace=True)
priority_label_text.drop(columns=["index"] , inplace= True)

priority_label_text
# Out:
# /tmp/ipykernel_267477/239147930.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.dropna(inplace=True)
# /tmp/ipykernel_267477/239147930.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.drop(columns=["index"] , inplace= True)
#                                                text_clean  labels  \
# 0       increase indent of listitemlistitems should ha...       0
# 1       add asmcmc and asmcmclist wrappers on asmcmc a...       0
# 2       create new option for dropdown scriptable obje...       0
# 3       header takes too much vertical space on wide s...       0
# 4       pagebody extends past html containerwhen navig...       0
# ...                                                   ...     ...
# 298197  oracle bond is not slashed when market resolve...       1
# 298198  develop a summary report that generates the po...       1
# 298199  synaptic intelligence implementation differs f...       1
# 298200  modernize indigo servicewe need to x update fr...       1
# 298201  teachers can play a game based on the selected...       1
#
#                         class
# 0             medium_priority
# 1             medium_priority
# 2             medium_priority
# 3             medium_priority
# 4             medium_priority
# ...                       ...
# 298197  high_and_low_priority
# 298198  high_and_low_priority
# 298199  high_and_low_priority
# 298200  high_and_low_priority
# 298201  high_and_low_priority
#
# [298202 rows x 3 columns]

# %%
# Splitting the DataFrame
test_df = priority_label_text.sample(frac=0.05, random_state=1)  # Select 5% of the data
test_file_name = f"csv/clean_test_med_vs_high_low_priority.csv"
test_df.to_csv(test_file_name, index=False)
priority_df = priority_label_text.drop(test_df.index)
priority_df.reset_index(drop=True, inplace=True)
priority_df
# Out:
#                                                text_clean  labels  \
# 0       increase indent of listitemlistitems should ha...       0
# 1       add asmcmc and asmcmclist wrappers on asmcmc a...       0
# 2       create new option for dropdown scriptable obje...       0
# 3       header takes too much vertical space on wide s...       0
# 4       pagebody extends past html containerwhen navig...       0
# ...                                                   ...     ...
# 283287  oracle bond is not slashed when market resolve...       1
# 283288  develop a summary report that generates the po...       1
# 283289  synaptic intelligence implementation differs f...       1
# 283290  modernize indigo servicewe need to x update fr...       1
# 283291  teachers can play a game based on the selected...       1
#
#                         class
# 0             medium_priority
# 1             medium_priority
# 2             medium_priority
# 3             medium_priority
# 4             medium_priority
# ...                       ...
# 283287  high_and_low_priority
# 283288  high_and_low_priority
# 283289  high_and_low_priority
# 283290  high_and_low_priority
# 283291  high_and_low_priority
#
# [283292 rows x 3 columns]

# %%
# Clean dataset with clean text and labels.
# 0 = high priority, 1 = not high priority
file_name = f"csv/clean_med_vs_high_and_low_priority.csv"
priority_df.to_csv(file_name, index=False)

# %%
pri = pd.read_csv(file_name)
pri
# Out:
#                                                text_clean  labels  \
# 0       increase indent of listitemlistitems should ha...       0
# 1       add asmcmc and asmcmclist wrappers on asmcmc a...       0
# 2       create new option for dropdown scriptable obje...       0
# 3       header takes too much vertical space on wide s...       0
# 4       pagebody extends past html containerwhen navig...       0
# ...                                                   ...     ...
# 283287  oracle bond is not slashed when market resolve...       1
# 283288  develop a summary report that generates the po...       1
# 283289  synaptic intelligence implementation differs f...       1
# 283290  modernize indigo servicewe need to x update fr...       1
# 283291  teachers can play a game based on the selected...       1
#
#                         class
# 0             medium_priority
# 1             medium_priority
# 2             medium_priority
# 3             medium_priority
# 4             medium_priority
# ...                       ...
# 283287  high_and_low_priority
# 283288  high_and_low_priority
# 283289  high_and_low_priority
# 283290  high_and_low_priority
# 283291  high_and_low_priority
#
# [283292 rows x 3 columns]

# %%
test_df = pd.read_csv(test_file_name)
test_df
# Out:
#                                               text_clean  labels  \
# 0      how can jooq sql without table name the jooq g...       0
# 1      as a user with income i can set recurring inco...       0
# 2      proposal backend lock session after survey is ...       0
# 3      no live d3200 what steps will reproduce the pr...       0
# 4      improve the cithis is a mini roadmap for the c...       0
# ...                                                  ...     ...
# 14905  a user can be shown autocomplete information f...       0
# 14906  avoid line break within a breadcrumb itemsee l...       1
# 14907  investigate issue with oppiabots commentsoppia...       0
# 14908  korean with comment keyword makes unicodeencod...       0
# 14909  validate user owns icons when adding them to a...       1
#
#                        class
# 0            medium_priority
# 1            medium_priority
# 2            medium_priority
# 3            medium_priority
# 4            medium_priority
# ...                      ...
# 14905        medium_priority
# 14906  high_and_low_priority
# 14907        medium_priority
# 14908        medium_priority
# 14909  high_and_low_priority
#
# [14910 rows x 3 columns]
