# %%
import pandas as pd

# %%
# Read CSV into a dataframe
high_priority = pd.read_csv("csv/final_high_dataset.csv", index_col=0)
not_high_priority = pd.read_csv("csv/final_not_high_dataset.csv", index_col=0)

# %%
high_priority
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3       1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4       1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...              ...          ...                  ...
# 373788  7.334924e+09  IssuesEvent  2018-03-06 01:09:12
# 373789  7.334984e+09  IssuesEvent  2018-03-06 01:28:23
# 373790  7.335034e+09  IssuesEvent  2018-03-06 01:44:11
# 373791  7.335035e+09  IssuesEvent  2018-03-06 01:44:26
# 373792  7.335039e+09  IssuesEvent  2018-03-06 01:45:34
#
#                                        repo  \
# 0                 unitystation/unitystation
# 1       zowe/sample-spring-boot-api-service
# 2                        openmsupply/mobile
# 3       UltimateCodeMonkeys/CodeMonkeysMVVM
# 4        wordpress-mobile/WordPress-Android
# ...

# %%
# Number or different labels
high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                   count
# labels
# bug high priority                 10435
# high priority                     10360
# High Priority                      7484
# enhancement high priority          5486
# Priority: High                     4751
# priority.High                      3694
# priority.High type.Task            3685
# priority.high type.task            3209
# priority.High type.Story           2979
# priority.high                      2749
# bug priority: high                 2306
# high-priority                      2262
# priority: high                     2178
# bug high-priority                  2159
# type.Story priority.High           2155
# priority.high type.story           2130
# type.Task priority.High            2022
# bug High Priority                  1888
# High priority                      1815
# Priority: High Type: Bug           1768
# priority:high                      1726
# bug priority:high                  1470
# ...

# %%
not_high_priority
# Out:
#                   id         type           created_at  \
# 0       1.675120e+10  IssuesEvent  2021-06-12 00:00:03
# 1       1.675120e+10  IssuesEvent  2021-06-12 00:00:15
# 2       1.675120e+10  IssuesEvent  2021-06-12 00:00:21
# 3       1.675120e+10  IssuesEvent  2021-06-12 00:00:26
# 4       1.675120e+10  IssuesEvent  2021-06-12 00:00:27
# ...              ...          ...                  ...
# 796632  1.475140e+10  IssuesEvent  2021-01-08 05:00:49
# 796633  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 796634  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 796635  1.475140e+10  IssuesEvent  2021-01-08 05:01:02
# 796636  1.475140e+10  IssuesEvent  2021-01-08 05:01:04
#
#                                            repo  \
# 0                        SFDO-Tooling/CumulusCI
# 1                          atatkin/milos-uptime
# 2                            longturn/freeciv21
# 3                              microsoft/vscode
# 4       hashicorp/terraform-provider-kubernetes
# ...

# %%
# Number or different labels
not_high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                            count
# labels
# bug                                        98108
# enhancement                                94219
# security vulnerability                     16071
# question                                   13304
# documentation                              10017
# feature                                     6763
# Bug                                         5836
# monika status                               5652
# watchout                                    4382
# stale                                       3876
# wontfix                                     3608
# help wanted                                 3370
# action-needsmoderation                      3292
# good first issue                            3169
# signature                                   2999
# alert:boom: environment/moc/zero            2979
# Stale                                       2814
# alert:boom: environment/moc/zero resolved   2798
# ...

# %%
# Add a new column
high_priority["class"] = "high_priority"
high_priority
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3       1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4       1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...              ...          ...                  ...
# 373788  7.334924e+09  IssuesEvent  2018-03-06 01:09:12
# 373789  7.334984e+09  IssuesEvent  2018-03-06 01:28:23
# 373790  7.335034e+09  IssuesEvent  2018-03-06 01:44:11
# 373791  7.335035e+09  IssuesEvent  2018-03-06 01:44:26
# 373792  7.335039e+09  IssuesEvent  2018-03-06 01:45:34
#
#                                        repo  \
# 0                 unitystation/unitystation
# 1       zowe/sample-spring-boot-api-service
# 2                        openmsupply/mobile
# 3       UltimateCodeMonkeys/CodeMonkeysMVVM
# 4        wordpress-mobile/WordPress-Android
# ...

# %%
not_high_priority["class"] = "not_high_priority"
not_high_priority
# Out:
#                   id         type           created_at  \
# 0       1.675120e+10  IssuesEvent  2021-06-12 00:00:03
# 1       1.675120e+10  IssuesEvent  2021-06-12 00:00:15
# 2       1.675120e+10  IssuesEvent  2021-06-12 00:00:21
# 3       1.675120e+10  IssuesEvent  2021-06-12 00:00:26
# 4       1.675120e+10  IssuesEvent  2021-06-12 00:00:27
# ...              ...          ...                  ...
# 796632  1.475140e+10  IssuesEvent  2021-01-08 05:00:49
# 796633  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 796634  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 796635  1.475140e+10  IssuesEvent  2021-01-08 05:01:02
# 796636  1.475140e+10  IssuesEvent  2021-01-08 05:01:04
#
#                                            repo  \
# 0                        SFDO-Tooling/CumulusCI
# 1                          atatkin/milos-uptime
# 2                            longturn/freeciv21
# 3                              microsoft/vscode
# 4       hashicorp/terraform-provider-kubernetes
# ...

# %%
all_data = pd.concat([high_priority, not_high_priority] , ignore_index= True)

# %%
all_data
# Out:
#                    id         type           created_at  \
# 0        1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1        1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2        1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3        1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4        1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...               ...          ...                  ...
# 1170425  1.475140e+10  IssuesEvent  2021-01-08 05:00:49
# 1170426  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 1170427  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 1170428  1.475140e+10  IssuesEvent  2021-01-08 05:01:02
# 1170429  1.475140e+10  IssuesEvent  2021-01-08 05:01:04
#
#                                         repo  \
# 0                  unitystation/unitystation
# 1        zowe/sample-spring-boot-api-service
# 2                         openmsupply/mobile
# 3        UltimateCodeMonkeys/CodeMonkeysMVVM
# 4         wordpress-mobile/WordPress-Android
# ...

# %%
all_data_no_dupes = all_data.drop_duplicates()
all_data_no_dupes
# Out:
#                    id         type           created_at  \
# 0        1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1        1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2        1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3        1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4        1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...               ...          ...                  ...
# 1170425  1.475140e+10  IssuesEvent  2021-01-08 05:00:49
# 1170426  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 1170427  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 1170428  1.475140e+10  IssuesEvent  2021-01-08 05:01:02
# 1170429  1.475140e+10  IssuesEvent  2021-01-08 05:01:04
#
#                                         repo  \
# 0                  unitystation/unitystation
# 1        zowe/sample-spring-boot-api-service
# 2                         openmsupply/mobile
# 3        UltimateCodeMonkeys/CodeMonkeysMVVM
# 4         wordpress-mobile/WordPress-Android
# ...

# %%
all_data_no_dupes[all_data_no_dupes["repo"] == "microsoft/vscode"]
# Out:
#                    id         type           created_at              repo  \
# 373796   1.675120e+10  IssuesEvent  2021-06-12 00:00:26  microsoft/vscode
# 373955   1.675125e+10  IssuesEvent  2021-06-12 00:08:21  microsoft/vscode
# 374048   1.675127e+10  IssuesEvent  2021-06-12 00:12:02  microsoft/vscode
# 374063   1.675127e+10  IssuesEvent  2021-06-12 00:13:02  microsoft/vscode
# 374109   1.675130e+10  IssuesEvent  2021-06-12 00:18:31  microsoft/vscode
# ...               ...          ...                  ...               ...
# 1166386  1.750116e+10  IssuesEvent  2021-08-10 09:33:49  microsoft/vscode
# 1168379  1.475027e+10  IssuesEvent  2021-01-08 01:41:31  microsoft/vscode
# 1169351  1.475079e+10  IssuesEvent  2021-01-08 03:10:35  microsoft/vscode
# 1169353  1.475079e+10  IssuesEvent  2021-01-08 03:10:38  microsoft/vscode
# 1169436  1.475084e+10  IssuesEvent  2021-01-08 03:19:17  microsoft/vscode
#
#                                               repo_url    action  \
# ...

# %%
all_data_no_dupes[all_data_no_dupes["repo"] == "python/mypy"]
# Out:
#                    id         type           created_at         repo  \
# 391163   1.666354e+10  IssuesEvent  2021-06-06 19:16:24  python/mypy
# 398431   1.476311e+10  IssuesEvent  2021-01-09 07:47:19  python/mypy
# 407030   1.753812e+10  IssuesEvent  2021-08-12 08:51:46  python/mypy
# 414950   1.637587e+10  IssuesEvent  2021-05-16 04:13:23  python/mypy
# 416525   1.637651e+10  IssuesEvent  2021-05-16 07:52:38  python/mypy
# ...               ...          ...                  ...          ...
# 1152427  1.758189e+10  IssuesEvent  2021-08-16 08:33:57  python/mypy
# 1154332  1.469256e+10  IssuesEvent  2021-01-03 02:58:44  python/mypy
# 1157634  1.469362e+10  IssuesEvent  2021-01-03 10:02:04  python/mypy
# 1166840  1.750149e+10  IssuesEvent  2021-08-10 09:57:14  python/mypy
# 1166855  1.750150e+10  IssuesEvent  2021-08-10 09:58:23  python/mypy
#
#                                          repo_url  action  \
# 391163   https://api.github.com/repos/python/mypy  opened
# ...

# %%
all_data_no_dupes = all_data_no_dupes[all_data_no_dupes["repo"] != "python/mypy"]
all_data_no_dupes
# Out:
#                    id         type           created_at  \
# 0        1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1        1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2        1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3        1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4        1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...               ...          ...                  ...
# 1170425  1.475140e+10  IssuesEvent  2021-01-08 05:00:49
# 1170426  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 1170427  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 1170428  1.475140e+10  IssuesEvent  2021-01-08 05:01:02
# 1170429  1.475140e+10  IssuesEvent  2021-01-08 05:01:04
#
#                                         repo  \
# 0                  unitystation/unitystation
# 1        zowe/sample-spring-boot-api-service
# 2                         openmsupply/mobile
# 3        UltimateCodeMonkeys/CodeMonkeysMVVM
# 4         wordpress-mobile/WordPress-Android
# ...

# %%
all_data_no_dupes[all_data_no_dupes["repo"] == "python/mypy"]
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body, class]
# Index: []

# %%
# Convert dataframe to a CSV file.
all_data_no_dupes.to_csv("csv/full_dataset_priority_high_or_not_high.csv")
