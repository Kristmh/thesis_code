# %% [markdown]
# # Dataset creation
# This notebook will:
# * Find github issues by label
# * Remove Technical debt labels
# * Make a test set
# It will produce 4 different dataset:
# 1. High/med/priority dataset
# 2. Test dataset
# 3. Debt dataset
# 4. Full dataset with nothing removed

# %%
import pandas as pd
import re
import os

# %%
# folder path
dir_path = r'../../csv/all_issues' ## Point to the extracted folder containing all the issues csv files

# list to store files
res = []

# Iterate directory
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        res.append(path)
print(res)
# Out:
# ['issues_all_2020-02-03.csv', 'issues_all_2016-09-19.csv', 'issues_all_2023-09-11.csv', 'issues_all_2020-09-24.csv', 'issues_all_2023-05-07.csv', 'issues_all_2022-09-18.csv', 'issues_all_2018-02-13.csv', 'issues_all_2019-12-22.csv', 'issues_all_2016-04-20.csv', 'issues_all_2017-01-01.csv', 'issues_all_2017-08-27.csv', 'issues_all_2022-08-20.csv', 'issues_all_2016-11-23.csv', 'issues_all_2018-12-12.csv', 'issues_all_2019-06-06.csv', 'issues_all_2023-01-20.csv', 'issues_all_2022-04-13.csv', 'issues_all_2022-06-10.csv', 'issues_all_2021-06-12.csv', 'issues_all_2019-07-13.csv', 'issues_all_2019-01-24.csv', 'issues_all_2017-03-06.csv', 'issues_all_2015-01-01.csv', 'issues_all_2022-05-03.csv', 'issues_all_2020-02-16.csv', 'issues_all_2015-06-09.csv', 'issues_all_2022-11-23.csv', 'issues_all_2017-02-08.csv', 'issues_all_2020-11-26.csv', 'issues_all_2016-08-11.csv', 'issues_all_2023-04-24.csv', 'issues_all_2019-01-14.csv', 'issues_all_2017-04-30.csv', 'issues_all_2018-12-06.csv', 'issues_all_2019-11-18.csv', 'issues_all_2018-11-09.csv', 'issues_all_2015-07-07.csv', 'issues_all_2022-08-07.csv', 'issues_all_2017-04-16.csv', 'issues_all_2022-11-14.csv', 'issues_all_2020-11-22.csv', 'issues_all_2015-05-29.csv', 'issues_all_2019-11-22.csv', 'issues_all_2021-04-29.csv', 'issues_all_2018-07-07.csv', 'issues_all_2021-04-23.csv', 'issues_all_2017-06-30.csv', 'issues_all_2018-07-08.csv', 'issues_all_2017-07-26.csv', 'issues_all_2017-05-20.csv', 'issues_all_2016-08-07.csv', 'issues_all_2021-05-05.csv', 'issues_all_2022-06-17.csv', 'issues_all_2019-08-21.csv', 'issues_all_2019-12-24.csv', 'issues_all_2020-01-29.csv', 'issues_all_2016-09-07.csv', 'issues_all_2017-12-17.csv', 'issues_all_2016-03-09.csv', 'issues_all_2023-07-25.csv', 'issues_all_2019-09-06.csv', 'issues_all_2015-04-26.csv', 'issues_all_2023-09-24.csv', 'issues_all_2015-07-23.csv', 'issues_all_2018-09-15.csv', 'issues_all_2017-11-19.csv', 'issues_all_2015-05-11.csv', 'issues_all_2023-01-24.csv', 'issues_all_2015-06-18.csv', 'issues_all_2018-12-30.csv', 'issues_all_2021-03-31.csv', 'issues_all_2017-03-19.csv', 'issues_all_2017-10-31.csv', 'issues_all_2016-03-31.csv', 'issues_all_2021-10-09.csv', 'issues_all_2019-06-08.csv', 'issues_all_2019-02-04.csv', 'issues_all_2018-06-28.csv', 'issues_all_2017-12-23.csv', 'issues_all_2023-03-15.csv', 'issues_all_2016-06-23.csv', 'issues_all_2018-04-08.csv', 'issues_all_2018-06-06.csv', 'issues_all_2016-09-09.csv', 'issues_all_2017-02-27.csv', 'issues_all_2018-12-28.csv', 'issues_all_2021-04-30.csv', 'issues_all_2015-12-07.csv', 'issues_all_2019-12-02.csv', 'issues_all_2015-03-27.csv', 'issues_all_2015-01-10.csv', 'issues_all_2018-02-26.csv', 'issues_all_2019-04-22.csv', 'issues_all_2021-12-24.csv', 'issues_all_2022-05-22.csv', 'issues_all_2016-06-15.csv', 'issues_all_2020-08-03.csv', 'issues_all_2015-02-14.csv', 'issues_all_2017-07-16.csv', 'issues_all_2023-02-10.csv', 'issues_all_2017-03-18.csv', 'issues_all_2016-01-17.csv', 'issues_all_2023-07-24.csv', 'issues_all_2018-11-19.csv', 'issues_all_2022-07-08.csv', 'issues_all_2022-05-30.csv', 'issues_all_2020-08-05.csv', 'issues_all_2020-06-04.csv', 'issues_all_2021-06-24.csv', 'issues_all_2020-12-31.csv', 'issues_all_2019-06-21.csv', 'issues_all_2021-06-06.csv', 'issues_all_2022-04-17.csv', 'issues_all_2022-08-12.csv', 'issues_all_2017-09-08.csv', 'issues_all_2021-01-09.csv', 'issues_all_2023-06-07.csv', 'issues_all_2020-11-09.csv', 'issues_all_2015-03-13.csv', 'issues_all_2017-03-08.csv', 'issues_all_2020-11-19.csv', 'issues_all_2021-08-12.csv', 'issues_all_2016-05-06.csv', 'issues_all_2020-02-15.csv', 'issues_all_2018-03-30.csv', 'issues_all_2017-03-28.csv', 'issues_all_2015-10-30.csv', 'issues_all_2017-06-21.csv', 'issues_all_2017-09-25.csv', 'issues_all_2016-07-20.csv', 'issues_all_2022-08-10.csv', 'issues_all_2021-04-09.csv', 'issues_all_2016-01-16.csv', 'issues_all_2021-09-13.csv', 'issues_all_2023-05-18.csv', 'issues_all_2016-04-23.csv', 'issues_all_2016-11-14.csv', 'issues_all_2021-03-21.csv ...

# %%
appended_data = []
# Regular expression to capture various variations of "high priority"
high_priority = r"\bhigh\W*p(?:ri(?:o(?:rity)?)?)?\b|\bp(?:ri(?:o(?:rity)?)?)?\W*high\b"

not_high_priority = r"\b(?:high\W*|critical\W*|severe\W*|important\W*|urgent\W*|essential\W*|imperative\W*|paramount\W*|pressing\W*|crucial\W*|vital\W*|mandatory\W*|top\W*priority\W*|compulsory\W*|expedient\W*)(?:p(?:ri(?:o(?:rity)?)?)?|\burgent\b|\bsevere\b)\b|\b(?:p(?:ri(?:o(?:rity)?)?)?|\burgent\b|\bsevere\b)\W*(?:high|critical|severe|important|urgent|essential|imperative|paramount|pressing|crucial|vital|mandatory|top\W*priority|compulsory|expedient)\b"
medium_priority = r"\b(?:medium|mid)\W*p(?:ri(?:o(?:rity)?)?)?\b|\bp(?:ri(?:o(?:rity)?)?)?\W*(?:medium|mid)\b"

low_priority = r"\blow\W*p(?:ri(?:o(?:rity)?)?)?\b|\bp(?:ri(?:o(?:rity)?)?)?\W*low\b"

pattern=not_high_priority
file_name = "not_high"
length_res = len(res)
for i, r in enumerate(res):
    if i > 200:
        break
    try:
        file_path = f"{dir_path}/{r}"
        df = pd.read_csv(file_path, index_col=0)
        
        # Make sure the dataframe is not empty 
        df = df[df['labels'].notnull() & df['labels'].str.strip().astype(bool)]


        # ~ Finds NOT in regex
        df = df[
           ~df["labels"].str.contains(pattern, case=False, na=False, regex=True)
        ]

        if not df.empty:  # Append non-empty dataframes to the list
           appended_data.append(df)


        print(f"{i}/{length_res} Processed: {r} ")
    except Exception as e:
        print(f"{i}/{length_res} Error processing {r}: {e}")

appended_data = pd.concat(appended_data, ignore_index=True)
# Out:
# 0/3137 Processed: issues_all_2020-02-03.csv
# 1/3137 Processed: issues_all_2016-09-19.csv
# 2/3137 Error processing issues_all_2023-09-11.csv: Error tokenizing data. C error: Buffer overflow caught - possible malformed input file.
#
# 3/3137 Processed: issues_all_2020-09-24.csv
# 4/3137 Processed: issues_all_2023-05-07.csv
# 5/3137 Processed: issues_all_2022-09-18.csv
# 6/3137 Processed: issues_all_2018-02-13.csv
# 7/3137 Processed: issues_all_2019-12-22.csv
# 8/3137 Processed: issues_all_2016-04-20.csv
# 9/3137 Processed: issues_all_2017-01-01.csv
# 10/3137 Processed: issues_all_2017-08-27.csv
# 11/3137 Processed: issues_all_2022-08-20.csv
# 12/3137 Processed: issues_all_2016-11-23.csv
# 13/3137 Processed: issues_all_2018-12-12.csv
# 14/3137 Processed: issues_all_2019-06-06.csv
# /tmp/ipykernel_2852/3779673896.py:18: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, index_col=0)
# 15/3137 Processed: issues_all_2023-01-20.csv
# 16/3137 Processed: issues_all_2022-04-13.csv
# 17/3137 Processed: issues_all_2022-06-10.csv
# 18/3137 Processed: issues_all_2021-06-12.csv
# 19/3137 Processed: issues_all_2019-07-13.csv
# 20/3137 Processed: issues_all_2019-01-24.csv
# 21/3137 Processed: issues_all_2017-03-06.csv
# 22/3137 Processed: issues_all_2015-01-01.csv
# 23/3137 Processed: issues_all_2022-05-03.csv
# 24/3137 Processed: issues_all_2020-02-16.csv
# 25/3137 Processed: issues_all_2015-06-09.csv
# 26/3137 Error processing issues_all_2022-11-23.csv: Error tokenizing data. C error: Buffer overflow caught - possible malformed input file.
#
# 27/3137 Processed: issues_all_2017-02-08.csv
# 28/3137 Processed: issues_all_2020-11-26.csv
# 29/3137 Processed: issues_all_2016-08-11.csv
# 30/3137 Processed: issues_all_2023-04-24.csv
# 31/3137 Processed: issues_all_2019-01-14.csv
# 32/3137 Processed: issues_all_2017-04-30.csv
# 33/3137 Processed: issues_all_2018-12-06.csv
# 34/3137 Processed: issues_all_2019-11-18.csv
# 35/3137 Processed: issues_all_2018-11-09.csv
# 36/3137 Processed: issues_all_2015-07-07.csv
# 37/3137 Processed: issues_all_2022-08-07.csv
# 38/3137 Processed: issues_all_2017-04-16.csv
# 39/3137 Processed: issues_all_2022-11-14.csv
# 40/3137 Processed: issues_all_2020-11-22.csv
# 41/3137 Processed: issues_all_2015-05-29.csv
# 42/3137 Processed: issues_all_2019-11-22.csv
# 43/3137 Processed: issues_all_2021-04-29.csv
# 44/3137 Processed: issues_all_2018-07-07.csv
# /tmp/ipykernel_2852/3779673896.py:18: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, index_col=0)
# 45/3137 Processed: issues_all_2021-04-23.csv
# 46/3137 Processed: issues_all_2017-06-30.csv
# 47/3137 Processed: issues_all_2018-07-08.csv
# 48/3137 Processed: issues_all_2017-07-26.csv
# 49/3137 Processed: issues_all_2017-05-20.csv
# 50/3137 Processed: issues_all_2016-08-07.csv
# 51/3137 Processed: issues_all_2021-05-05.csv
# 52/3137 Processed: issues_all_2022-06-17.csv
# 53/3137 Processed: issues_all_2019-08-21.csv
# 54/3137 Processed: issues_all_2019-12-24.csv
# 55/3137 Processed: issues_all_2020-01-29.csv
# 56/3137 Processed: issues_all_2016-09-07.csv
# 57/3137 Processed: issues_all_2017-12-17.csv
# 58/3137 Processed: issues_all_2016-03-09.csv
# 59/3137 Processed: issues_all_2023-07-25.csv
# 60/3137 Processed: issues_all_2019-09-06.csv
# 61/3137 Processed: issues_all_2015-04-26.csv
# 62/3137 Processed: issues_all_2023-09-24.csv
# 63/3137 Processed: issues_all_2015-07-23.csv
# 64/3137 Processed: issues_all_2018-09-15.csv
# 65/3137 Processed: issues_all_2017-11-19.csv
# 66/3137 Processed: issues_all_2015-05-11.csv
# /tmp/ipykernel_2852/3779673896.py:18: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, index_col=0)
# 67/3137 Processed: issues_all_2023-01-24.csv
# 68/3137 Processed: issues_all_2015-06-18.csv
# 69/3137 Processed: issues_all_2018-12-30.csv
# 70/3137 Processed: issues_all_2021-03-31.csv
# 71/3137 Processed: issues_all_2017-03-19.csv
# 72/3137 Processed: issues_all_2017-10-31.csv
# 73/3137 Processed: issues_all_2016-03-31.csv
# 74/3137 Processed: issues_all_2021-10-09.csv
# 75/3137 Processed: issues_all_2019-06-08.csv
# 76/3137 Processed: issues_all_2019-02-04.csv
# 77/3137 Processed: issues_all_2018-06-28.csv
# 78/3137 Processed: issues_all_2017-12-23.csv
# /tmp/ipykernel_2852/3779673896.py:18: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, index_col=0)
# 79/3137 Processed: issues_all_2023-03-15.csv
# /tmp/ipykernel_2852/3779673896.py:18: DtypeWarning: Columns (0,2,3,4,5,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, index_col=0)
# 80/3137 Processed: issues_all_2016-06-23.csv
# 81/3137 Processed: issues_all_2018-04-08.csv
# 82/3137 Processed: issues_all_2018-06-06.csv
# 83/3137 Processed: issues_all_2016-09-09.csv
# 84/3137 Processed: issues_all_2017-02-27.csv
# 85/3137 Processed: issues_all_2018-12-28.csv
# 86/3137 Processed: issues_all_2021-04-30.csv
# 87/3137 Processed: issues_all_2015-12-07.csv
# 88/3137 Processed: issues_all_2019-12-02.csv
# 89/3137 Processed: issues_all_2015-03-27.csv
# 90/3137 Processed: issues_all_2015-01-10.csv
# 91/3137 Processed: issues_all_2018-02-26.csv
# 92/3137 Processed: issues_all_2019-04-22.csv
# 93/3137 Processed: issues_all_2021-12-24.csv
# 94/3137 Processed: issues_all_2022-05-22.csv
# 95/3137 Processed: issues_all_2016-06-15.csv
# 96/3137 Processed: issues_all_2020-08-03.csv
# 97/3137 Processed: issues_all_2015-02-14.csv
# 98/3137 Processed: issues_all_2017-07-16.csv
# /tmp/ipykernel_2852/3779673896.py:18: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, index_col=0)
# 99/3137 Processed: issues_all_2023-02-10.csv
# 100/3137 Processed: issues_all_2017-03-18.csv
# 101/3137 Processed: issues_all_2016-01-17.csv
# 102/3137 Processed: issues_all_2023-07-24.csv
# 103/3137 Processed: issues_all_2018-11-19.csv
# /tmp/ipykernel_2852/3779673896.py:18: DtypeWarning: Columns (0,2,3,4,5,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, index_col=0)
# 104/3137 Processed: issues_all_2022-07-08.csv
# 105/3137 Processed: issues_all_2022-05-30.csv
# 106/3137 Processed: issues_all_2020-08-05.csv
# 107/3137 Processed: issues_all_2020-06-04.csv
# 108/3137 Processed: issues_all_2021-06-24.csv
# 109/3137 Processed: issues_all_2020-12-31.csv
# 110/3137 Processed: issues_all_2019-06-21.csv
# 111/3137 Processed: issues_all_2021-06-06.csv
# 112/3137 Processed: issues_all_2022-04-17.csv
# 113/3137 Processed: issues_all_2022-08-12.csv
# 114/3137 Processed: issues_all_2017-09-08.csv
# 115/3137 Processed: issues_all_2021-01-09.csv
# 116/3137 Processed: issues_all_2023-06-07.csv
# 117/3137 Processed: issues_all_2020-11-09.csv
# 118/3137 Processed: issues_all_2015-03-13.csv
# 119/3137 Processed: issues_all_2017-03-08.csv
# 120/3137 Processed: issues_all_2020-11-19.csv
# 121/3137 Processed: issues_all_2021-08-12.csv
# 122/3137 Processed: issues_all_2016-05-06.csv
# 123/3137 Processed: issues_all_2020-02-15.csv
# 124/3137 Processed: issues_all_2018-03-30.csv
# 125/3137 Processed: issues_all_2017-03-28.csv
# 126/3137 Processed: issues_all_2015-10-30.csv
# 127/3137 Processed: issues_all_2017-06-21.csv
# 128/3137 Processed: issues_all_2017-09-25.csv
# 129/3137 Processed: issues_all_2016-07-20.csv
# 130/3137 Processed: issues_all_2022-08-10.csv
# 131/3137 Processed: issues_all_2021-04-09.csv
# 132/3137 Processed: issues_all_2016-01-16.csv
# 133/3137 Processed: issues_all_2021-09-13.csv
# 134/3137 Processed: issues_all_2023-05-18.csv
# 135/3137 Processed: issues_all_2016-04-23.csv
# 136/3137 Processed: issues_all_2016-11-14.csv
# 137/3137 Processed: issues_all_2021-03-21.csv
# 138/3137 Processed: issues_all_2016-09-10.csv
# 139/3137 Processed: issues_all_2019-06-14.csv
# 140/3137 Processed: issues_all_2022-06-09.csv
# 141/3137 Processed: issues_all_2019-04-10.csv
# 142/3137 Processed: issues_all_2016-03-08.csv
# 143/3137 Processed: issues_all_2019-01-08.csv
# 144/3137 Processed: issues_all_2017-11-23.csv
# 145/3137 Processed: issues_all_2015-01-03.csv
# /tmp/ipykernel_2852/3779673896.py:18: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, index_col=0)
# 146/3137 Processed: issues_all_2023-02-16.csv
# 147/3137 Processed: issues_all_2021-05-16.csv
# 148/3137 Processed: issues_all_2018-02-21.csv
# 149/3137 Processed: issues_all_2022-10-27.csv
# 150/3137 Processed: issues_all_2022-01-30.csv
# 151/3137 Processed: issues_all_2022-01-09.csv
# 152/3137 Processed: issues_all_2018-08-07.csv
# 153/3137 Processed: issues_all_2023-08-18.csv
# 154/3137 Processed: issues_all_2016-08-15.csv
# 155/3137 Processed: issues_all_2018-08-25.csv
# 156/3137 Processed: issues_all_2021-08-08.csv
# 157/3137 Processed: issues_all_2021-02-12.csv
# 158/3137 Processed: issues_all_2018-12-14.csv
# 159/3137 Processed: issues_all_2015-08-05.csv
# 160/3137 Processed: issues_all_2019-05-04.csv
# 161/3137 Processed: issues_all_2015-06-19.csv
# 162/3137 Processed: issues_all_2019-09-28.csv
# 163/3137 Processed: issues_all_2017-08-29.csv
# 164/3137 Processed: issues_all_2016-12-23.csv
# 165/3137 Processed: issues_all_2018-10-16.csv
# 166/3137 Processed: issues_all_2020-01-23.csv
# 167/3137 Processed: issues_all_2022-12-26.csv
# 168/3137 Processed: issues_all_2015-04-04.csv
# 169/3137 Processed: issues_all_2015-07-25.csv
# 170/3137 Processed: issues_all_2019-12-23.csv
# 171/3137 Processed: issues_all_2023-05-02.csv
# 172/3137 Processed: issues_all_2021-05-03.csv
# 173/3137 Processed: issues_all_2020-04-05.csv
# 174/3137 Processed: issues_all_2017-12-13.csv
# 175/3137 Processed: issues_all_2021-10-05.csv
# 176/3137 Processed: issues_all_2018-10-19.csv
# 177/3137 Processed: issues_all_2020-01-06.csv
# 178/3137 Processed: issues_all_2017-04-28.csv
# 179/3137 Processed: issues_all_2019-12-18.csv
# 180/3137 Processed: issues_all_2015-06-16.csv
# 181/3137 Processed: issues_all_2017-08-06.csv
# 182/3137 Processed: issues_all_2019-03-25.csv
# 183/3137 Processed: issues_all_2021-10-31.csv
# 184/3137 Processed: issues_all_2018-01-19.csv
# 185/3137 Processed: issues_all_2019-02-21.csv
# 186/3137 Processed: issues_all_2016-10-16.csv
# 187/3137 Processed: issues_all_2022-06-07.csv
# 188/3137 Processed: issues_all_2021-05-14.csv
# 189/3137 Processed: issues_all_2015-04-22.csv
# 190/3137 Processed: issues_all_2018-11-14.csv
# 191/3137 Processed: issues_all_2016-03-04.csv
# 192/3137 Processed: issues_all_2020-08-02.csv
# 193/3137 Processed: issues_all_2017-07-06.csv
# 194/3137 Processed: issues_all_2020-06-24.csv
# 195/3137 Processed: issues_all_2020-06-27.csv
# 196/3137 Processed: issues_all_2017-11-22.csv
# 197/3137 Processed: issues_all_2017-06-15.csv
# 198/3137 Processed: issues_all_2018-03-08.csv
# 199/3137 Processed: issues_all_2021-09-05.csv
# 200/3137 Processed: issues_all_2018-08-14.csv

# %%
appended_data = pd.DataFrame(appended_data)
appended_data
# Out:
#                   id         type           created_at  \
# 0        11417537389  IssuesEvent  2020-02-03 00:00:07
# 1        11417537804  IssuesEvent  2020-02-03 00:00:12
# 2        11417537835  IssuesEvent  2020-02-03 00:00:13
# 3        11417538003  IssuesEvent  2020-02-03 00:00:16
# 4        11417538116  IssuesEvent  2020-02-03 00:00:18
# ...              ...          ...                  ...
# 2029982   8109961054  IssuesEvent  2018-08-14 09:21:15
# 2029983   8109961116  IssuesEvent  2018-08-14 09:21:16
# 2029984   8109981673  IssuesEvent  2018-08-14 09:25:07
# 2029985   8109983220  IssuesEvent  2018-08-14 09:25:24
# 2029986   8109983622  IssuesEvent  2018-08-14 09:25:29
#
#                                   repo  \
# 0        automationbs/testbugreporting
# 1                PowerShell/PowerShell
# 2                  thadiun/hello-world
# 3                PowerShell/PowerShell
# 4                PowerShell/PowerShell
# ...                                ...
# 2029982                     urbit/arvo
# 2029983    highcharts/highcharts-react
# 2029984           Loriowar/comindivion
# 2029985     TiiQu-Network/TQ-test-page
# 2029986         prominic/Moonshine-IDE
#
#                                                   repo_url  action  \
# 0        https://api.github.com/repos/automationbs/test...  opened
# 1        https://api.github.com/repos/PowerShell/PowerS...  closed
# 2         https://api.github.com/repos/thadiun/hello-world  closed
# 3        https://api.github.com/repos/PowerShell/PowerS...  closed
# 4        https://api.github.com/repos/PowerShell/PowerS...  closed
# ...                                                    ...     ...
# 2029982            https://api.github.com/repos/urbit/arvo  opened
# 2029983  https://api.github.com/repos/highcharts/highch...  closed
# 2029984  https://api.github.com/repos/Loriowar/comindivion  opened
# 2029985  https://api.github.com/repos/TiiQu-Network/TQ-...  closed
# 2029986  https://api.github.com/repos/prominic/Moonshin...  closed
#
#                                                      title  \
# 0                                            Default title
# 1                                               Show alias
# 2                   [Test] testing needs-triage (no delay)
# 3                                     $ENV in using module
# 4                Measure-Command does not measure its self
# ...                                                    ...
# 2029982            %bad-text trips up hall JSON conversion
# 2029983                            HighMaps mapBubble type
# 2029984  Add a validation on a belonging of a predicate...
# 2029985                     Error on submit with no values
# 2029986           Handle unknown tags in Visual Editor XML
#
#                                                     labels  \
# 0                                                      bug
# 1                       Issue-Question Resolution-Answered
# 2                                                   triage
# 3         Area-Language Issue-Question Resolution-Answered
# 4        Area-Cmdlets-Utility Issue-Question Resolution...
# ...                                                    ...
# 2029982      :hall / :talk cause known marks web interface
# 2029983                                      pending reply
# 2029984                              bug data manipulation
# 2029985                                                bug
# 2029986               Investigation PrimeFaces enhancement
#
#                                                       body
# 0        default description\n\n|Property | Value|\n|--...
# 1        <!--\r\n\r\nFor Windows PowerShell 5.1 issues,...
# 2                                                      NaN
# 3        # Summary of the new feature/enhancement\r\n\r...
# 4        ## The Issue\r\nI'm pretty sure this was just ...
# ...                                                    ...
# 2029982  Haven't tested this in detail yet, but pretty ...
# 2029983  Hello,\r\nIt is possible to create also HighMa...
# 2029984  Now user can change html content of the intera...
# 2029985  TypeError: Too few arguments in function sum (...
# 2029986  If provided Visual Editor XML brings some unkn...
#
# [2029987 rows x 9 columns]

# %%
# Remove medium priority issues
appended_data = appended_data[
   ~appended_data["labels"].str.contains(medium_priority, case=False, na=False, regex=True)
]

# Remove low priority issues
appended_data = appended_data[
   ~appended_data["labels"].str.contains(low_priority, case=False, na=False, regex=True)
]
appended_data.reset_index(drop=True, inplace=True)

appended_data
# Out:
#                   id         type           created_at  \
# 0        11417537389  IssuesEvent  2020-02-03 00:00:07
# 1        11417537804  IssuesEvent  2020-02-03 00:00:12
# 2        11417537835  IssuesEvent  2020-02-03 00:00:13
# 3        11417538003  IssuesEvent  2020-02-03 00:00:16
# 4        11417538116  IssuesEvent  2020-02-03 00:00:18
# ...              ...          ...                  ...
# 2003584   8109961054  IssuesEvent  2018-08-14 09:21:15
# 2003585   8109961116  IssuesEvent  2018-08-14 09:21:16
# 2003586   8109981673  IssuesEvent  2018-08-14 09:25:07
# 2003587   8109983220  IssuesEvent  2018-08-14 09:25:24
# 2003588   8109983622  IssuesEvent  2018-08-14 09:25:29
#
#                                   repo  \
# 0        automationbs/testbugreporting
# 1                PowerShell/PowerShell
# 2                  thadiun/hello-world
# 3                PowerShell/PowerShell
# 4                PowerShell/PowerShell
# ...                                ...
# 2003584                     urbit/arvo
# 2003585    highcharts/highcharts-react
# 2003586           Loriowar/comindivion
# 2003587     TiiQu-Network/TQ-test-page
# 2003588         prominic/Moonshine-IDE
#
#                                                   repo_url  action  \
# 0        https://api.github.com/repos/automationbs/test...  opened
# 1        https://api.github.com/repos/PowerShell/PowerS...  closed
# 2         https://api.github.com/repos/thadiun/hello-world  closed
# 3        https://api.github.com/repos/PowerShell/PowerS...  closed
# 4        https://api.github.com/repos/PowerShell/PowerS...  closed
# ...                                                    ...     ...
# 2003584            https://api.github.com/repos/urbit/arvo  opened
# 2003585  https://api.github.com/repos/highcharts/highch...  closed
# 2003586  https://api.github.com/repos/Loriowar/comindivion  opened
# 2003587  https://api.github.com/repos/TiiQu-Network/TQ-...  closed
# 2003588  https://api.github.com/repos/prominic/Moonshin...  closed
#
#                                                      title  \
# 0                                            Default title
# 1                                               Show alias
# 2                   [Test] testing needs-triage (no delay)
# 3                                     $ENV in using module
# 4                Measure-Command does not measure its self
# ...                                                    ...
# 2003584            %bad-text trips up hall JSON conversion
# 2003585                            HighMaps mapBubble type
# 2003586  Add a validation on a belonging of a predicate...
# 2003587                     Error on submit with no values
# 2003588           Handle unknown tags in Visual Editor XML
#
#                                                     labels  \
# 0                                                      bug
# 1                       Issue-Question Resolution-Answered
# 2                                                   triage
# 3         Area-Language Issue-Question Resolution-Answered
# 4        Area-Cmdlets-Utility Issue-Question Resolution...
# ...                                                    ...
# 2003584      :hall / :talk cause known marks web interface
# 2003585                                      pending reply
# 2003586                              bug data manipulation
# 2003587                                                bug
# 2003588               Investigation PrimeFaces enhancement
#
#                                                       body
# 0        default description\n\n|Property | Value|\n|--...
# 1        <!--\r\n\r\nFor Windows PowerShell 5.1 issues,...
# 2                                                      NaN
# 3        # Summary of the new feature/enhancement\r\n\r...
# 4        ## The Issue\r\nI'm pretty sure this was just ...
# ...                                                    ...
# 2003584  Haven't tested this in detail yet, but pretty ...
# 2003585  Hello,\r\nIt is possible to create also HighMa...
# 2003586  Now user can change html content of the intera...
# 2003587  TypeError: Too few arguments in function sum (...
# 2003588  If provided Visual Editor XML brings some unkn...
#
# [2003589 rows x 9 columns]

# %%
# Create debt dataframe
technical_debt_regex = r'debt|\bTD\b'
contains_debt_high_priority = appended_data['labels'].str.contains(technical_debt_regex, case=False, na=False)
debt = appended_data[contains_debt_high_priority].reset_index(drop=True)
debt
# Out:
#                id         type           created_at  \
# 0     11417553790  IssuesEvent  2020-02-03 00:05:55
# 1     11418032700  IssuesEvent  2020-02-03 02:43:22
# 2     11418809688  IssuesEvent  2020-02-03 06:03:33
# 3     11419464215  IssuesEvent  2020-02-03 08:02:43
# 4     11419744108  IssuesEvent  2020-02-03 08:42:02
# ...           ...          ...                  ...
# 3715   8109276248  IssuesEvent  2018-08-14 06:53:54
# 3716   8109490286  IssuesEvent  2018-08-14 07:45:55
# 3717   8109490292  IssuesEvent  2018-08-14 07:45:55
# 3718   8109508676  IssuesEvent  2018-08-14 07:49:59
# 3719   8109556394  IssuesEvent  2018-08-14 08:00:40
#
#                                     repo  \
# 0                            voces/fixus
# 1                       BeeStation/NSV13
# 2                    skbkontur/retail-ui
# 3                    skbkontur/retail-ui
# 4             monarc-project/MonarcAppFO
# ...                                  ...
# 3715  spring-cloud/spring-cloud-dataflow
# 3716                  tsoding/ray-tracer
# 3717                  tsoding/ray-tracer
# 3718                  tsoding/ray-tracer
# 3719                  tsoding/ray-tracer
#
#                                                repo_url  action  \
# 0              https://api.github.com/repos/voces/fixus  closed
# 1         https://api.github.com/repos/BeeStation/NSV13  opened
# 2      https://api.github.com/repos/skbkontur/retail-ui  closed
# 3      https://api.github.com/repos/skbkontur/retail-ui  closed
# 4     https://api.github.com/repos/monarc-project/Mo...  opened
# ...                                                 ...     ...
# 3715  https://api.github.com/repos/spring-cloud/spri...  closed
# 3716    https://api.github.com/repos/tsoding/ray-tracer  closed
# 3717    https://api.github.com/repos/tsoding/ray-tracer  closed
# 3718    https://api.github.com/repos/tsoding/ray-tracer  closed
# 3719    https://api.github.com/repos/tsoding/ray-tracer  closed
#
#                                                   title  \
# 0                     Refactor into semantic TypeScript
# 1     Snowflake engine depends on same area to conne...
# 2     [retail-ui] Перевести сборку библиотеки на bab...
# 3                    [retail-ui] warnings в компонентах
# 4     Improve the import speed of analyses and insta...
# ...                                                 ...
# 3715  Move stream aggregate state calculation logic ...
# 3716                                       CI is broken
# 3717                  gcc is not supported on Travis CI
# 3718                                            LICENSE
# 3719               Travis build doesn't supported clang
#
#                                labels  \
# 0                            techdebt
# 1                       National Debt
# 2          in progress technical debt
# 3                minor technical debt
# 4     Technical debt important-for-v3
# ...                               ...
# 3715             in pr technical-debt
# 3716                         techdebt
# 3717                         techdebt
# 3718                         techdebt
# 3719                         techdebt
#
#                                                    body
# 0     The code is ported to TypeScript, but it does ...
# 1     this is dumb. why do we do this? There's only ...
# 2     - [ ] TS → Babel@7 #1129\r\n  - [ ] Remove all...
# 3     Компоненты генерят много сообщений в консоль -...
# 4     Currently the medium size analyses import can ...
# ...                                                 ...
# 3715  Currently, the stream aggregate state calculat...
# 3716                                     Caused by #43
# 3717                                 introduced in #20
# 3718                                                NaN
# 3719                                 introduced in #46
#
# [3720 rows x 9 columns]

# %%
# Dataset with debt and not priority
debt_file_name = f"csv/{file_name}_priority_with_debt_only.csv"
debt.to_csv(debt_file_name)

# %%
debt.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# technical debt                                        593
# tech debt                                             286
# tech-debt                                             130
# debt                                                  111
# techdebt                                               95
# Technical Debt                                         90
# Tech Debt                                              73
# technical-debt                                         52
# Technical debt                                         47
# enhancement technical debt                             38
# backlog technical debt                                 21
# tech debt deprecation no stalebot                      20
# Tech debt                                              16
# frontend tech-debt vaos                                15
# debt P2 qa runtime                                     13
# must techdebt                                          12
# bug tech debt                                          12
# vsa-debt                                               11
# experience tech-debt needs-refinement engineering      10
# bug technical debt                                     10
# enhancement tech debt                                   9
# :money_mouth_face: tech debt :warning: P2               8
# wontfix Tech Debt Deletion Candidate                    8
# type: technical debt                                    8
# nicetohave techdebt                                     7
# topic:tech-debt                                         7
# 1. to develop technical debt                            7
# technical_debt                                          7
# experience tech-debt engineering                        7
# enhancement tech-debt                                   7
# type: technical-debt                                    7
# good first issue technical-debt                         7
# TechDebt                                                7
# technical-debt tests                                    6
# technical debt requirement 5                            6
# component: runtime meta: triaged skill: C++ sta...      6
# tech_debt                                               6
# debt engineering                                        6
# Type: Technical Debt                                    6
# debt integrated-terminal                                6
# Tech-debt 🚧                                             6
# design research vsa-debt                                6
# bug debt                                                6
# Traffic Ops tech debt                                   6
# backend vsa-debt CombinedFSR                            5
# bug tech-debt                                           5
# Debt Letters MVP design vsa vsa-benefits-2              5
# Tech Debt max priority                                  5
# Documentation Release 3.3.0 TechnicalDebt               5
# good first issue tech-debt                              5

# %%
# To labels
appended_data.labels.value_counts().to_frame()[:50]
# Out:
#                                           count
# labels
# enhancement                              244118
# bug                                      240687
# security vulnerability                    53086
# question                                  34833
# feature                                   20745
# documentation                             17938
# Bug                                       12282
# help wanted                               10875
# stale branch                               8274
# wontfix                                    7279
# greenkeeper                                6842
# stale                                      6638
# stat:awaiting response                     6602
# Sub Task Failing Test Paddle Frontend      6463
# good first issue                           6418
# enhancement help wanted                    6290
# invalid                                    6093
# task                                       5668
# feature request                            5605
# in progress                                5372
# duplicate                                  5236
# bug enhancement                            4899
# enhancement good first issue               4516
# npm-install-script                         4452
# status monika                              4372
# kind/bug                                   4335
# design                                     4178
# JAX Frontend Sub Task Failing Test         4099
# Enhancement                                3402
# Feature                                    3266
# watchout                                   3241
# bug help wanted                            3094
# type: bug                                  2958
# triage                                     2701
# action-needsmoderation                     2551
# frontend                                   2536
# Stale                                      2493
# new feature                                2493
# new-review user-submission                 2417
# Task                                       2378
# Type: Bug                                  2292
# documentation enhancement                  2277
# improvement                                2225
# weekly-digest                              2211
# todo                                       2190
# enhancement question                       2121
# new-version user-submission                2089
# Mend: dependency security vulnerability    2073
# feature-request                            1898
# discussion                                 1887

# %%
# Remove debt from the dataset
appended_data_no_debt = appended_data[~contains_debt_high_priority].reset_index(drop=True)
appended_data_no_debt.reset_index(drop=True, inplace=True)
appended_data_no_debt
# Out:
#                   id         type           created_at  \
# 0        11417537389  IssuesEvent  2020-02-03 00:00:07
# 1        11417537804  IssuesEvent  2020-02-03 00:00:12
# 2        11417537835  IssuesEvent  2020-02-03 00:00:13
# 3        11417538003  IssuesEvent  2020-02-03 00:00:16
# 4        11417538116  IssuesEvent  2020-02-03 00:00:18
# ...              ...          ...                  ...
# 1999864   8109961054  IssuesEvent  2018-08-14 09:21:15
# 1999865   8109961116  IssuesEvent  2018-08-14 09:21:16
# 1999866   8109981673  IssuesEvent  2018-08-14 09:25:07
# 1999867   8109983220  IssuesEvent  2018-08-14 09:25:24
# 1999868   8109983622  IssuesEvent  2018-08-14 09:25:29
#
#                                   repo  \
# 0        automationbs/testbugreporting
# 1                PowerShell/PowerShell
# 2                  thadiun/hello-world
# 3                PowerShell/PowerShell
# 4                PowerShell/PowerShell
# ...                                ...
# 1999864                     urbit/arvo
# 1999865    highcharts/highcharts-react
# 1999866           Loriowar/comindivion
# 1999867     TiiQu-Network/TQ-test-page
# 1999868         prominic/Moonshine-IDE
#
#                                                   repo_url  action  \
# 0        https://api.github.com/repos/automationbs/test...  opened
# 1        https://api.github.com/repos/PowerShell/PowerS...  closed
# 2         https://api.github.com/repos/thadiun/hello-world  closed
# 3        https://api.github.com/repos/PowerShell/PowerS...  closed
# 4        https://api.github.com/repos/PowerShell/PowerS...  closed
# ...                                                    ...     ...
# 1999864            https://api.github.com/repos/urbit/arvo  opened
# 1999865  https://api.github.com/repos/highcharts/highch...  closed
# 1999866  https://api.github.com/repos/Loriowar/comindivion  opened
# 1999867  https://api.github.com/repos/TiiQu-Network/TQ-...  closed
# 1999868  https://api.github.com/repos/prominic/Moonshin...  closed
#
#                                                      title  \
# 0                                            Default title
# 1                                               Show alias
# 2                   [Test] testing needs-triage (no delay)
# 3                                     $ENV in using module
# 4                Measure-Command does not measure its self
# ...                                                    ...
# 1999864            %bad-text trips up hall JSON conversion
# 1999865                            HighMaps mapBubble type
# 1999866  Add a validation on a belonging of a predicate...
# 1999867                     Error on submit with no values
# 1999868           Handle unknown tags in Visual Editor XML
#
#                                                     labels  \
# 0                                                      bug
# 1                       Issue-Question Resolution-Answered
# 2                                                   triage
# 3         Area-Language Issue-Question Resolution-Answered
# 4        Area-Cmdlets-Utility Issue-Question Resolution...
# ...                                                    ...
# 1999864      :hall / :talk cause known marks web interface
# 1999865                                      pending reply
# 1999866                              bug data manipulation
# 1999867                                                bug
# 1999868               Investigation PrimeFaces enhancement
#
#                                                       body
# 0        default description\n\n|Property | Value|\n|--...
# 1        <!--\r\n\r\nFor Windows PowerShell 5.1 issues,...
# 2                                                      NaN
# 3        # Summary of the new feature/enhancement\r\n\r...
# 4        ## The Issue\r\nI'm pretty sure this was just ...
# ...                                                    ...
# 1999864  Haven't tested this in detail yet, but pretty ...
# 1999865  Hello,\r\nIt is possible to create also HighMa...
# 1999866  Now user can change html content of the intera...
# 1999867  TypeError: Too few arguments in function sum (...
# 1999868  If provided Visual Editor XML brings some unkn...
#
# [1999869 rows x 9 columns]

# %%
# Sanity check
should_be_empty=appended_data_no_debt[appended_data_no_debt['labels'].str.contains(technical_debt_regex, case=False, na=False)]
should_be_empty
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body]
# Index: []

# %%
contains_stale = appended_data['labels'].str.contains("stale", case=False, na=False)
appended_data_no_debt = appended_data_no_debt[~contains_stale].reset_index(drop=True)
appended_data_no_debt.reset_index(drop=True, inplace=True)
appended_data_no_debt
# Out:
# /tmp/ipykernel_2852/1560700614.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   appended_data_no_debt = appended_data_no_debt[~contains_stale].reset_index(drop=True)
#                   id         type           created_at  \
# 0        11417537389  IssuesEvent  2020-02-03 00:00:07
# 1        11417537804  IssuesEvent  2020-02-03 00:00:12
# 2        11417537835  IssuesEvent  2020-02-03 00:00:13
# 3        11417538003  IssuesEvent  2020-02-03 00:00:16
# 4        11417538116  IssuesEvent  2020-02-03 00:00:18
# ...              ...          ...                  ...
# 1962483   8109961054  IssuesEvent  2018-08-14 09:21:15
# 1962484   8109961116  IssuesEvent  2018-08-14 09:21:16
# 1962485   8109981673  IssuesEvent  2018-08-14 09:25:07
# 1962486   8109983220  IssuesEvent  2018-08-14 09:25:24
# 1962487   8109983622  IssuesEvent  2018-08-14 09:25:29
#
#                                   repo  \
# 0        automationbs/testbugreporting
# 1                PowerShell/PowerShell
# 2                  thadiun/hello-world
# 3                PowerShell/PowerShell
# 4                PowerShell/PowerShell
# ...                                ...
# 1962483                     urbit/arvo
# 1962484    highcharts/highcharts-react
# 1962485           Loriowar/comindivion
# 1962486     TiiQu-Network/TQ-test-page
# 1962487         prominic/Moonshine-IDE
#
#                                                   repo_url  action  \
# 0        https://api.github.com/repos/automationbs/test...  opened
# 1        https://api.github.com/repos/PowerShell/PowerS...  closed
# 2         https://api.github.com/repos/thadiun/hello-world  closed
# 3        https://api.github.com/repos/PowerShell/PowerS...  closed
# 4        https://api.github.com/repos/PowerShell/PowerS...  closed
# ...                                                    ...     ...
# 1962483            https://api.github.com/repos/urbit/arvo  opened
# 1962484  https://api.github.com/repos/highcharts/highch...  closed
# 1962485  https://api.github.com/repos/Loriowar/comindivion  opened
# 1962486  https://api.github.com/repos/TiiQu-Network/TQ-...  closed
# 1962487  https://api.github.com/repos/prominic/Moonshin...  closed
#
#                                                      title  \
# 0                                            Default title
# 1                                               Show alias
# 2                   [Test] testing needs-triage (no delay)
# 3                                     $ENV in using module
# 4                Measure-Command does not measure its self
# ...                                                    ...
# 1962483            %bad-text trips up hall JSON conversion
# 1962484                            HighMaps mapBubble type
# 1962485  Add a validation on a belonging of a predicate...
# 1962486                     Error on submit with no values
# 1962487           Handle unknown tags in Visual Editor XML
#
#                                                     labels  \
# 0                                                      bug
# 1                       Issue-Question Resolution-Answered
# 2                                                   triage
# 3         Area-Language Issue-Question Resolution-Answered
# 4        Area-Cmdlets-Utility Issue-Question Resolution...
# ...                                                    ...
# 1962483      :hall / :talk cause known marks web interface
# 1962484                                      pending reply
# 1962485                              bug data manipulation
# 1962486                                                bug
# 1962487               Investigation PrimeFaces enhancement
#
#                                                       body
# 0        default description\n\n|Property | Value|\n|--...
# 1        <!--\r\n\r\nFor Windows PowerShell 5.1 issues,...
# 2                                                      NaN
# 3        # Summary of the new feature/enhancement\r\n\r...
# 4        ## The Issue\r\nI'm pretty sure this was just ...
# ...                                                    ...
# 1962483  Haven't tested this in detail yet, but pretty ...
# 1962484  Hello,\r\nIt is possible to create also HighMa...
# 1962485  Now user can change html content of the intera...
# 1962486  TypeError: Too few arguments in function sum (...
# 1962487  If provided Visual Editor XML brings some unkn...
#
# [1962488 rows x 9 columns]

# %%
appended_data_no_debt.labels.value_counts().to_frame()[:50]
# Out:
#                                           count
# labels
# enhancement                              240489
# bug                                      237012
# security vulnerability                    52497
# question                                  34359
# feature                                   20451
# documentation                             17632
# Bug                                       12098
# help wanted                               10727
# wontfix                                    7180
# greenkeeper                                6767
# stat:awaiting response                     6530
# stale                                      6472
# Sub Task Failing Test Paddle Frontend      6318
# good first issue                           6302
# enhancement help wanted                    6220
# invalid                                    6002
# task                                       5598
# feature request                            5533
# in progress                                5320
# duplicate                                  5178
# bug enhancement                            4829
# enhancement good first issue               4430
# npm-install-script                         4392
# status monika                              4277
# kind/bug                                   4254
# design                                     4143
# JAX Frontend Sub Task Failing Test         4011
# Enhancement                                3352
# Feature                                    3218
# watchout                                   3142
# bug help wanted                            3057
# type: bug                                  2911
# triage                                     2668
# frontend                                   2510
# action-needsmoderation                     2492
# new feature                                2453
# Stale                                      2411
# new-review user-submission                 2392
# Task                                       2348
# Type: Bug                                  2255
# documentation enhancement                  2234
# improvement                                2197
# weekly-digest                              2173
# todo                                       2165
# enhancement question                       2092
# new-version user-submission                2061
# Mend: dependency security vulnerability    2049
# stale branch                               2045
# feature-request                            1865
# discussion                                 1863

# %%
# Convert to csv
not_hp_no_debt_file_name = f"csv/{file_name}_no_td1.csv"
appended_data_no_debt.to_csv(not_hp_no_debt_file_name)

# %% [markdown]
# ## Test if file is not corrupted

# %%
debt = pd.read_csv(debt_file_name, index_col=0)
debt
# Out:
#                 id         type           created_at  \
# 0     1.141755e+10  IssuesEvent  2020-02-03 00:05:55
# 1     1.141803e+10  IssuesEvent  2020-02-03 02:43:22
# 2     1.141881e+10  IssuesEvent  2020-02-03 06:03:33
# 3     1.141946e+10  IssuesEvent  2020-02-03 08:02:43
# 4     1.141974e+10  IssuesEvent  2020-02-03 08:42:02
# ...            ...          ...                  ...
# 3715  8.109276e+09  IssuesEvent  2018-08-14 06:53:54
# 3716  8.109490e+09  IssuesEvent  2018-08-14 07:45:55
# 3717  8.109490e+09  IssuesEvent  2018-08-14 07:45:55
# 3718  8.109509e+09  IssuesEvent  2018-08-14 07:49:59
# 3719  8.109556e+09  IssuesEvent  2018-08-14 08:00:40
#
#                                     repo  \
# 0                            voces/fixus
# 1                       BeeStation/NSV13
# 2                    skbkontur/retail-ui
# 3                    skbkontur/retail-ui
# 4             monarc-project/MonarcAppFO
# ...                                  ...
# 3715  spring-cloud/spring-cloud-dataflow
# 3716                  tsoding/ray-tracer
# 3717                  tsoding/ray-tracer
# 3718                  tsoding/ray-tracer
# 3719                  tsoding/ray-tracer
#
#                                                repo_url  action  \
# 0              https://api.github.com/repos/voces/fixus  closed
# 1         https://api.github.com/repos/BeeStation/NSV13  opened
# 2      https://api.github.com/repos/skbkontur/retail-ui  closed
# 3      https://api.github.com/repos/skbkontur/retail-ui  closed
# 4     https://api.github.com/repos/monarc-project/Mo...  opened
# ...                                                 ...     ...
# 3715  https://api.github.com/repos/spring-cloud/spri...  closed
# 3716    https://api.github.com/repos/tsoding/ray-tracer  closed
# 3717    https://api.github.com/repos/tsoding/ray-tracer  closed
# 3718    https://api.github.com/repos/tsoding/ray-tracer  closed
# 3719    https://api.github.com/repos/tsoding/ray-tracer  closed
#
#                                                   title  \
# 0                     Refactor into semantic TypeScript
# 1     Snowflake engine depends on same area to conne...
# 2     [retail-ui] Перевести сборку библиотеки на bab...
# 3                    [retail-ui] warnings в компонентах
# 4     Improve the import speed of analyses and insta...
# ...                                                 ...
# 3715  Move stream aggregate state calculation logic ...
# 3716                                       CI is broken
# 3717                  gcc is not supported on Travis CI
# 3718                                            LICENSE
# 3719               Travis build doesn't supported clang
#
#                                labels  \
# 0                            techdebt
# 1                       National Debt
# 2          in progress technical debt
# 3                minor technical debt
# 4     Technical debt important-for-v3
# ...                               ...
# 3715             in pr technical-debt
# 3716                         techdebt
# 3717                         techdebt
# 3718                         techdebt
# 3719                         techdebt
#
#                                                    body
# 0     The code is ported to TypeScript, but it does ...
# 1     this is dumb. why do we do this? There's only ...
# 2     - [ ] TS → Babel@7 #1129\r\n  - [ ] Remove all...
# 3     Компоненты генерят много сообщений в консоль -...
# 4     Currently the medium size analyses import can ...
# ...                                                 ...
# 3715  Currently, the stream aggregate state calculat...
# 3716                                     Caused by #43
# 3717                                 introduced in #20
# 3718                                                NaN
# 3719                                 introduced in #46
#
# [3720 rows x 9 columns]

# %%
not_hp_no_debt = pd.read_csv(not_hp_no_debt_file_name, index_col=0)
not_hp_no_debt
# Out:
# /tmp/ipykernel_2852/552021253.py:1: DtypeWarning: Columns (0,2,3,4,5,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   not_hp_no_debt = pd.read_csv(not_hp_no_debt_file_name, index_col=0)
#                    id         type           created_at  \
# 0        1.141754e+10  IssuesEvent  2020-02-03 00:00:07
# 1        1.141754e+10  IssuesEvent  2020-02-03 00:00:12
# 2        1.141754e+10  IssuesEvent  2020-02-03 00:00:13
# 3        1.141754e+10  IssuesEvent  2020-02-03 00:00:16
# 4        1.141754e+10  IssuesEvent  2020-02-03 00:00:18
# ...               ...          ...                  ...
# 1962483  8.109961e+09  IssuesEvent  2018-08-14 09:21:15
# 1962484  8.109961e+09  IssuesEvent  2018-08-14 09:21:16
# 1962485  8.109982e+09  IssuesEvent  2018-08-14 09:25:07
# 1962486  8.109983e+09  IssuesEvent  2018-08-14 09:25:24
# 1962487  8.109984e+09  IssuesEvent  2018-08-14 09:25:29
#
#                                   repo  \
# 0        automationbs/testbugreporting
# 1                PowerShell/PowerShell
# 2                  thadiun/hello-world
# 3                PowerShell/PowerShell
# 4                PowerShell/PowerShell
# ...                                ...
# 1962483                     urbit/arvo
# 1962484    highcharts/highcharts-react
# 1962485           Loriowar/comindivion
# 1962486     TiiQu-Network/TQ-test-page
# 1962487         prominic/Moonshine-IDE
#
#                                                   repo_url  action  \
# 0        https://api.github.com/repos/automationbs/test...  opened
# 1        https://api.github.com/repos/PowerShell/PowerS...  closed
# 2         https://api.github.com/repos/thadiun/hello-world  closed
# 3        https://api.github.com/repos/PowerShell/PowerS...  closed
# 4        https://api.github.com/repos/PowerShell/PowerS...  closed
# ...                                                    ...     ...
# 1962483            https://api.github.com/repos/urbit/arvo  opened
# 1962484  https://api.github.com/repos/highcharts/highch...  closed
# 1962485  https://api.github.com/repos/Loriowar/comindivion  opened
# 1962486  https://api.github.com/repos/TiiQu-Network/TQ-...  closed
# 1962487  https://api.github.com/repos/prominic/Moonshin...  closed
#
#                                                      title  \
# 0                                            Default title
# 1                                               Show alias
# 2                   [Test] testing needs-triage (no delay)
# 3                                     $ENV in using module
# 4                Measure-Command does not measure its self
# ...                                                    ...
# 1962483            %bad-text trips up hall JSON conversion
# 1962484                            HighMaps mapBubble type
# 1962485  Add a validation on a belonging of a predicate...
# 1962486                     Error on submit with no values
# 1962487           Handle unknown tags in Visual Editor XML
#
#                                                     labels  \
# 0                                                      bug
# 1                       Issue-Question Resolution-Answered
# 2                                                   triage
# 3         Area-Language Issue-Question Resolution-Answered
# 4        Area-Cmdlets-Utility Issue-Question Resolution...
# ...                                                    ...
# 1962483      :hall / :talk cause known marks web interface
# 1962484                                      pending reply
# 1962485                              bug data manipulation
# 1962486                                                bug
# 1962487               Investigation PrimeFaces enhancement
#
#                                                       body
# 0        default description\n\n|Property | Value|\n|--...
# 1        <!--\r\n\r\nFor Windows PowerShell 5.1 issues,...
# 2                                                      NaN
# 3        # Summary of the new feature/enhancement\r\n\r...
# 4        ## The Issue\r\nI'm pretty sure this was just ...
# ...                                                    ...
# 1962483  Haven't tested this in detail yet, but pretty ...
# 1962484  Hello,\r\nIt is possible to create also HighMa...
# 1962485  Now user can change html content of the intera...
# 1962486  TypeError: Too few arguments in function sum (...
# 1962487  If provided Visual Editor XML brings some unkn...
#
# [16412913 rows x 9 columns]

# %%
not_hp_no_debt.labels.value_counts().to_frame()[:50]
# Out:
#                                            count
# labels
# stale-branch                             6827422
# stale branch 🗑️                           348533
# enhancement                               240489
# bug                                       237012
# security vulnerability                     52497
# question                                   34359
# feature                                    20451
# documentation                              17632
# Bug                                        12098
# help wanted                                10727
# wontfix                                     7180
# greenkeeper                                 6767
# stat:awaiting response                      6530
# stale                                       6472
# Sub Task Failing Test Paddle Frontend       6318
# good first issue                            6302
# enhancement help wanted                     6220
# invalid                                     6002
# task                                        5598
# feature request                             5533
# in progress                                 5320
# duplicate                                   5178
# bug enhancement                             4829
# enhancement good first issue                4430
# npm-install-script                          4392
# status monika                               4277
# kind/bug                                    4254
# design                                      4143
# JAX Frontend Sub Task Failing Test          4011
# Enhancement                                 3352
# Feature                                     3218
# watchout                                    3142
# bug help wanted                             3057
# type: bug                                   2911
# triage                                      2668
# frontend                                    2510
# action-needsmoderation                      2492
# new feature                                 2453
# Stale                                       2411
# new-review user-submission                  2392
# Task                                        2348
# Type: Bug                                   2255
# documentation enhancement                   2234
# improvement                                 2197
# weekly-digest                               2173
# todo                                        2165
# enhancement question                        2092
# new-version user-submission                 2061
# Mend: dependency security vulnerability     2049
# stale branch                                2045
