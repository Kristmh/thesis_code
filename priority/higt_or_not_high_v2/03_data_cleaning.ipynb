# %% [markdown]
# # Data cleaning
# We want the class with labels as numerical value and the body with clean text.
#
# This will:
# * Remove duplicates
# * Remove NaN entires

# %%
import pandas as pd
import sys
sys.path.append("../../scripts_shared/")
from preprocess_text import preprocess_text

# %%
priority = pd.read_csv("csv/full_dataset_priority_high_or_not_high.csv" , index_col=0)
priority
# Out:
#                    id         type           created_at  \
# 0        1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1        1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2        1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3        1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4        1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...               ...          ...                  ...
# 1170425  1.475140e+10  IssuesEvent  2021-01-08 05:00:49
# 1170426  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 1170427  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 1170428  1.475140e+10  IssuesEvent  2021-01-08 05:01:02
# 1170429  1.475140e+10  IssuesEvent  2021-01-08 05:01:04
#
#                                         repo  \
# 0                  unitystation/unitystation
# 1        zowe/sample-spring-boot-api-service
# 2                         openmsupply/mobile
# 3        UltimateCodeMonkeys/CodeMonkeysMVVM
# 4         wordpress-mobile/WordPress-Android
# ...                                      ...
# 1170425      nvim-treesitter/nvim-treesitter
# 1170426                          supabase/ui
# 1170427                          supabase/ui
# 1170428          tristanjohnson849/card-demo
# 1170429                      nushell/nushell
#
#                                                   repo_url  action  \
# 0        https://api.github.com/repos/unitystation/unit...  closed
# 1        https://api.github.com/repos/zowe/sample-sprin...  closed
# 2          https://api.github.com/repos/openmsupply/mobile  closed
# 3        https://api.github.com/repos/UltimateCodeMonke...  opened
# 4        https://api.github.com/repos/wordpress-mobile/...  closed
# ...                                                    ...     ...
# 1170425  https://api.github.com/repos/nvim-treesitter/n...  opened
# 1170426           https://api.github.com/repos/supabase/ui  closed
# 1170427           https://api.github.com/repos/supabase/ui  closed
# 1170428  https://api.github.com/repos/tristanjohnson849...  closed
# 1170429       https://api.github.com/repos/nushell/nushell  closed
#
#                                                      title  \
# 0        Client breaking NRE when using edit field on C...
# 1        The SDK provides a separate Java (no-Spring) l...
# 2                       Auto-log out after some time frame
# 3        Migrate: CodeMonkeys ViewModelNavigationServic...
# 4        IA Reader filter bottom sheet: manage untitled...
# ...                                                    ...
# 1170425  highlighting works as unexpected after attach ...
# 1170426          Input component has an extra grid space y
# 1170427                   Button to support Ref forwarding
# 1170428                 We need to merge type 1 and type 2
# 1170429                            Release #4 - Nu Scripts
#
#                                                     labels  \
# 0                         Bug High Priority In Progress UI
# 1        Feature: API Security Priority: High no-issue-...
# 2        Docs: not needed Effort: small Feature Module:...
# 3        Priority: High Status: In Progress Type: Maint...
# 4                         IA Reader [Pri] High [Type] Task
# ...                                                    ...
# 1170425                                                bug
# 1170426                                                bug
# 1170427                                        enhancement
# 1170428                                   good first issue
# 1170429                                  enhancement pri-1
#
#                                                       body              class
# 0        ### Bug:\r\n\r\nIf you use the edit field of t...      high_priority
# 1        - The commons-spring library is split into:\r\...      high_priority
# 2        ## Is your feature request related to a proble...      high_priority
# 3        Migrate the Xamarin.Forms navigation service i...      high_priority
# 4        In the filter bottom sheet we introduced in th...      high_priority
# ...                                                    ...                ...
# 1170425  **Describe the bug**\r\nsee reproduce.\r\n\r\n...  not_high_priority
# 1170426  # Bug report\r\n\r\nI noticed that the Input c...  not_high_priority
# 1170427  # Feature request\r\n\r\n## Is your feature re...  not_high_priority
# 1170428                This is purely for practice and fun  not_high_priority
# 1170429  # Requirements for Nu scripts\r\n- [x] variabl...  not_high_priority
#
# [1170013 rows x 10 columns]

# %%
#Number of issues per class
priority["class"].value_counts()
# Out:
# class
# not_high_priority    796236
# high_priority        373777
# Name: count, dtype: int64

# %%
# Drop duplicates by the content of the body
priority = priority.drop_duplicates(subset=['body'], keep='last')
priority.dropna(inplace=True)
priority.reset_index(inplace=True)
priority.drop(columns=["index"] , inplace= True)
priority["class"].value_counts()
# Out:
# /tmp/ipykernel_361870/2519026987.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority.dropna(inplace=True)
# /tmp/ipykernel_361870/2519026987.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority.drop(columns=["index"] , inplace= True)
# class
# not_high_priority    596655
# high_priority        252445
# Name: count, dtype: int64

# %%
priority
# Out:
#                   id         type           created_at  \
# 0       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 1       1.141776e+10  IssuesEvent  2020-02-03 01:22:41
# 2       1.141780e+10  IssuesEvent  2020-02-03 01:35:11
# 3       1.141797e+10  IssuesEvent  2020-02-03 02:25:22
# 4       1.141809e+10  IssuesEvent  2020-02-03 02:58:51
# ...              ...          ...                  ...
# 849095  1.475140e+10  IssuesEvent  2021-01-08 05:00:49
# 849096  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 849097  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 849098  1.475140e+10  IssuesEvent  2021-01-08 05:01:02
# 849099  1.475140e+10  IssuesEvent  2021-01-08 05:01:04
#
#                                    repo  \
# 0                    openmsupply/mobile
# 1                    SolerSoft/TaskeRGB
# 2             ericauv/ericauv-portfolio
# 3             unitystation/unitystation
# 4             RussTedrake/underactuated
# ...                                 ...
# 849095  nvim-treesitter/nvim-treesitter
# 849096                      supabase/ui
# 849097                      supabase/ui
# 849098      tristanjohnson849/card-demo
# 849099                  nushell/nushell
#
#                                                  repo_url  action  \
# 0         https://api.github.com/repos/openmsupply/mobile  closed
# 1         https://api.github.com/repos/SolerSoft/TaskeRGB  closed
# 2       https://api.github.com/repos/ericauv/ericauv-p...  closed
# 3       https://api.github.com/repos/unitystation/unit...  closed
# 4       https://api.github.com/repos/RussTedrake/under...  closed
# ...                                                   ...     ...
# 849095  https://api.github.com/repos/nvim-treesitter/n...  opened
# 849096           https://api.github.com/repos/supabase/ui  closed
# 849097           https://api.github.com/repos/supabase/ui  closed
# 849098  https://api.github.com/repos/tristanjohnson849...  closed
# 849099       https://api.github.com/repos/nushell/nushell  closed
#
#                                                     title  \
# 0                      Auto-log out after some time frame
# 1                                 Image Picker for Source
# 2              Fix Video Page ListItem Hovering Behaviour
# 3                  Escape shuttle reaches ludicrous speed
# 4       Binder doesn't load notebooks outside of the u...
# ...                                                   ...
# 849095  highlighting works as unexpected after attach ...
# 849096          Input component has an extra grid space y
# 849097                   Button to support Ref forwarding
# 849098                 We need to merge type 1 and type 2
# 849099                            Release #4 - Nu Scripts
#
#                                                    labels  \
# 0       Docs: not needed Effort: small Feature Module:...
# 1                config enhancement palette priority-high
# 2                                           High Priority
# 3                                   Bug High Priority lol
# 4                                          priority: high
# ...                                                   ...
# 849095                                                bug
# 849096                                                bug
# 849097                                        enhancement
# 849098                                   good first issue
# 849099                                  enhancement pri-1
#
#                                                      body              class
# 0       ## Is your feature request related to a proble...      high_priority
# 1       Implement an Android Image Picker to browse Im...      high_priority
# 2       - When a video is not playing:\r\n    - Hover ...      high_priority
# 3       ## Description\r\n\r\nEscape shuttle accelerat...      high_priority
# 4       https://notebooks.gesis.org/binder/jupyter/use...      high_priority
# ...                                                   ...                ...
# 849095  **Describe the bug**\r\nsee reproduce.\r\n\r\n...  not_high_priority
# 849096  # Bug report\r\n\r\nI noticed that the Input c...  not_high_priority
# 849097  # Feature request\r\n\r\n## Is your feature re...  not_high_priority
# 849098                This is purely for practice and fun  not_high_priority
# 849099  # Requirements for Nu scripts\r\n- [x] variabl...  not_high_priority
#
# [849100 rows x 10 columns]

# %%
# Split the dataframe 
high_priority = priority.loc[priority['class'] == 'high_priority'].copy()
not_high_priority = priority.loc[priority['class'] == 'not_high_priority'].copy()

# %%
high_priority.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 252445 entries, 0 to 252444
# Data columns (total 10 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          252445 non-null  float64
#  1   type        252445 non-null  object
#  2   created_at  252445 non-null  object
#  3   repo        252445 non-null  object
#  4   repo_url    252445 non-null  object
#  5   action      252445 non-null  object
#  6   title       252445 non-null  object
#  7   labels      252445 non-null  object
#  8   body        252445 non-null  object
#  9   class       252445 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 21.2+ MB

# %%
#Give each priority a label by number.
# 'Label encoding'. Makes is easier for machine learning models to work with categorical data.
high_priority["label"] = 0
high_priority.head()
# Out:
#              id         type           created_at                       repo  \
# 0  1.141755e+10  IssuesEvent  2020-02-03 00:02:58         openmsupply/mobile
# 1  1.141776e+10  IssuesEvent  2020-02-03 01:22:41         SolerSoft/TaskeRGB
# 2  1.141780e+10  IssuesEvent  2020-02-03 01:35:11  ericauv/ericauv-portfolio
# 3  1.141797e+10  IssuesEvent  2020-02-03 02:25:22  unitystation/unitystation
# 4  1.141809e+10  IssuesEvent  2020-02-03 02:58:51  RussTedrake/underactuated
#
#                                             repo_url  action  \
# 0    https://api.github.com/repos/openmsupply/mobile  closed
# 1    https://api.github.com/repos/SolerSoft/TaskeRGB  closed
# 2  https://api.github.com/repos/ericauv/ericauv-p...  closed
# 3  https://api.github.com/repos/unitystation/unit...  closed
# 4  https://api.github.com/repos/RussTedrake/under...  closed
#
#                                                title  \
# 0                 Auto-log out after some time frame
# 1                            Image Picker for Source
# 2         Fix Video Page ListItem Hovering Behaviour
# 3             Escape shuttle reaches ludicrous speed
# 4  Binder doesn't load notebooks outside of the u...
#
#                                               labels  \
# 0  Docs: not needed Effort: small Feature Module:...
# 1           config enhancement palette priority-high
# 2                                      High Priority
# 3                              Bug High Priority lol
# 4                                     priority: high
#
#                                                 body          class  label
# 0  ## Is your feature request related to a proble...  high_priority      0
# 1  Implement an Android Image Picker to browse Im...  high_priority      0
# 2  - When a video is not playing:\r\n    - Hover ...  high_priority      0
# 3  ## Description\r\n\r\nEscape shuttle accelerat...  high_priority      0
# 4  https://notebooks.gesis.org/binder/jupyter/use...  high_priority      0

# %%
not_high_priority["label"] = 1
not_high_priority.head()
# Out:
#                   id         type           created_at  \
# 252445  1.675120e+10  IssuesEvent  2021-06-12 00:00:03
# 252446  1.675120e+10  IssuesEvent  2021-06-12 00:00:15
# 252447  1.675120e+10  IssuesEvent  2021-06-12 00:00:21
# 252448  1.675120e+10  IssuesEvent  2021-06-12 00:00:26
# 252449  1.675120e+10  IssuesEvent  2021-06-12 00:00:27
#
#                                            repo  \
# 252445                   SFDO-Tooling/CumulusCI
# 252446                     atatkin/milos-uptime
# 252447                       longturn/freeciv21
# 252448                         microsoft/vscode
# 252449  hashicorp/terraform-provider-kubernetes
#
#                                                  repo_url  action  \
# 252445  https://api.github.com/repos/SFDO-Tooling/Cumu...  closed
# 252446  https://api.github.com/repos/atatkin/milos-uptime  closed
# 252447    https://api.github.com/repos/longturn/freeciv21  closed
# 252448      https://api.github.com/repos/microsoft/vscode  closed
# 252449  https://api.github.com/repos/hashicorp/terrafo...  closed
#
#                                                     title  \
# 252445     Add installation info section to release notes
# 252446                             🛑 Minted HTTPS is down
# 252447  Client crashes when trying to load the aviatio...
# 252448  Native Notebooks - Changing kernel causes mark...
# 252449  Feature Request: Generate Resources from Kuber...
#
#                                 labels  \
# 252445                     enhancement
# 252446             minted-https status
# 252447                             bug
# 252448          bug candidate notebook
# 252449  acknowledged enhancement stale
#
#                                                      body              class  \
# 252445  Currently we generate release notes and then m...  not_high_priority
# 252446  In [`03a8446`](https://github.com/atatkin/milo...  not_high_priority
# 252447  More specifically, [this version](https://raw....  not_high_priority
# 252448  - VS Code Version: 1.57.0 & 1.57.0-insider\r\n...  not_high_priority
# 252449  At this point in time, the terraform provider ...  not_high_priority
#
#         label
# 252445      1
# 252446      1
# 252447      1
# 252448      1
# 252449      1

# %%
label_counts = priority["class"].value_counts()
print(label_counts)
not_high_priority_count = label_counts["not_high_priority"]
print(not_high_priority_count)
hp_count = label_counts["high_priority"]
hp_count
# Out:
# class
# not_high_priority    596655
# high_priority        252445
# Name: count, dtype: int64
# 596655
# 252445

# %%
not_high_priority = not_high_priority.sample(frac=hp_count/not_high_priority_count, random_state=42)
not_high_priority
# Out:
#                   id         type           created_at  \
# 669200  1.473040e+10  IssuesEvent  2021-01-06 13:09:20
# 757598  1.523901e+10  IssuesEvent  2021-02-19 03:20:51
# 768286  1.597785e+10  IssuesEvent  2021-04-17 07:10:40
# 496760  1.688880e+10  IssuesEvent  2021-06-23 06:28:21
# 353481  1.553188e+10  IssuesEvent  2021-03-14 02:11:00
# ...              ...          ...                  ...
# 420090  1.522932e+10  IssuesEvent  2021-02-18 12:45:04
# 679331  1.544449e+10  IssuesEvent  2021-03-08 10:28:26
# 339300  1.706743e+10  IssuesEvent  2021-07-07 09:05:16
# 769126  1.597823e+10  IssuesEvent  2021-04-17 08:57:39
# 559115  1.526511e+10  IssuesEvent  2021-02-22 06:44:44
#
#                                           repo  \
# 669200                    NosWings/bug-reports
# 757598                       Agoric/agoric-sdk
# 768286                        littleflute/blog
# 496760                         lcimeni/youtube
# 353481                       nextcloud/desktop
# ...                                        ...
# 420090  remote-job-boards/software-engineering
# 679331                   nnstreamer/nnstreamer
# 339300                          BaguaSys/bagua
# 769126                xezon/GeneralsRankedMaps
# 559115                    mafischer/trader-bot
#
#                                                  repo_url  action  \
# 669200  https://api.github.com/repos/NosWings/bug-reports  closed
# 757598     https://api.github.com/repos/Agoric/agoric-sdk  opened
# 768286      https://api.github.com/repos/littleflute/blog  closed
# 496760       https://api.github.com/repos/lcimeni/youtube  opened
# 353481     https://api.github.com/repos/nextcloud/desktop  closed
# ...                                                   ...     ...
# 420090  https://api.github.com/repos/remote-job-boards...  opened
# 679331  https://api.github.com/repos/nnstreamer/nnstre...  opened
# 339300        https://api.github.com/repos/BaguaSys/bagua  closed
# 769126  https://api.github.com/repos/xezon/GeneralsRan...  closed
# 559115  https://api.github.com/repos/mafischer/trader-bot  opened
#
#                                                     title  \
# 669200                             Dead Pet get attacked
# 757598        Design solo-to-solo communications protocol
# 768286  m1: 【刘谦魔术课】只要一副牌，魔术随手来！！！ One ahead principle ...
# 496760     NowSecure dynamic analysis: Network Data Flows
# 353481  The new version 3.0.1 / 3.0.2 does not start o...
# ...                                                   ...
# 420090  Retail E Commerce Ventures: PHP MySQL HTML CSS...
# 679331             Sharing Model Representation with CAPI
# 339300                           autotune service: naming
# 769126  [Candidate 1v1 Glacial Horses V1] Shadows have...
# 559115                                  Add alpaca broker
#
#                                       labels  \
# 669200                                   bug
# 757598           cosmic-swingset enhancement
# 768286            36.9k littleflute m1 moShu
# 496760                             nowsecure
# 353481  0. Needs triage bug needs info stale
# ...                                      ...
# 420090  lang-javascript lang-php remoteok.io
# 679331                Open for Participation
# 339300                  autotune enhancement
# 769126                        blocker design
# 559115                        P2 enhancement
#
#                                                      body              class  \
# 669200  Dead Pet get attacked \r\n\r\n## **To Reproduc...  not_high_priority
# 757598  ## What is the Problem Being Solved?\r\n\r\nWe...  not_high_priority
# 768286   https://www.youtube.com/watch?v=iTSEypQR42w&t=6s  not_high_priority
# 496760  ### Finding Description\n\nSensitive data was ...  not_high_priority
# 353481  The new version 3.0.1 / 3.0.2 does not start o...  not_high_priority
# ...                                                   ...                ...
# 420090  **Tags:** #javascript #css #php #html #sql #cs...  not_high_priority
# 679331  We can access a specific TFLite model through ...  not_high_priority
# 339300  - `autotune_client.register_models` should be ...  not_high_priority
# 769126  **Issue Description**\r\nShadows have strong m...  not_high_priority
# 559115                            https://alpaca.markets/  not_high_priority
#
#         label
# 669200      1
# 757598      1
# 768286      1
# 496760      1
# 353481      1
# ...       ...
# 420090      1
# 679331      1
# 339300      1
# 769126      1
# 559115      1
#
# [252445 rows x 11 columns]

# %%
all_priority = pd.concat([high_priority,not_high_priority] , ignore_index = True)
all_priority.tail()
# Out:
#                   id         type           created_at  \
# 504885  1.522932e+10  IssuesEvent  2021-02-18 12:45:04
# 504886  1.544449e+10  IssuesEvent  2021-03-08 10:28:26
# 504887  1.706743e+10  IssuesEvent  2021-07-07 09:05:16
# 504888  1.597823e+10  IssuesEvent  2021-04-17 08:57:39
# 504889  1.526511e+10  IssuesEvent  2021-02-22 06:44:44
#
#                                           repo  \
# 504885  remote-job-boards/software-engineering
# 504886                   nnstreamer/nnstreamer
# 504887                          BaguaSys/bagua
# 504888                xezon/GeneralsRankedMaps
# 504889                    mafischer/trader-bot
#
#                                                  repo_url  action  \
# 504885  https://api.github.com/repos/remote-job-boards...  opened
# 504886  https://api.github.com/repos/nnstreamer/nnstre...  opened
# 504887        https://api.github.com/repos/BaguaSys/bagua  closed
# 504888  https://api.github.com/repos/xezon/GeneralsRan...  closed
# 504889  https://api.github.com/repos/mafischer/trader-bot  opened
#
#                                                     title  \
# 504885  Retail E Commerce Ventures: PHP MySQL HTML CSS...
# 504886             Sharing Model Representation with CAPI
# 504887                           autotune service: naming
# 504888  [Candidate 1v1 Glacial Horses V1] Shadows have...
# 504889                                  Add alpaca broker
#
#                                       labels  \
# 504885  lang-javascript lang-php remoteok.io
# 504886                Open for Participation
# 504887                  autotune enhancement
# 504888                        blocker design
# 504889                        P2 enhancement
#
#                                                      body              class  \
# 504885  **Tags:** #javascript #css #php #html #sql #cs...  not_high_priority
# 504886  We can access a specific TFLite model through ...  not_high_priority
# 504887  - `autotune_client.register_models` should be ...  not_high_priority
# 504888  **Issue Description**\r\nShadows have strong m...  not_high_priority
# 504889                            https://alpaca.markets/  not_high_priority
#
#         label
# 504885      1
# 504886      1
# 504887      1
# 504888      1
# 504889      1

# %%
# Does this need to be more balanced?
all_priority["label"].value_counts()
# Out:
# label
# 0    252445
# 1    252445
# Name: count, dtype: int64

# %%
# Copy content of body to a new col named text
# Why?
all_priority["text"] = all_priority["body"]
all_priority.tail()
# Out:
#                   id         type           created_at  \
# 504885  1.522932e+10  IssuesEvent  2021-02-18 12:45:04
# 504886  1.544449e+10  IssuesEvent  2021-03-08 10:28:26
# 504887  1.706743e+10  IssuesEvent  2021-07-07 09:05:16
# 504888  1.597823e+10  IssuesEvent  2021-04-17 08:57:39
# 504889  1.526511e+10  IssuesEvent  2021-02-22 06:44:44
#
#                                           repo  \
# 504885  remote-job-boards/software-engineering
# 504886                   nnstreamer/nnstreamer
# 504887                          BaguaSys/bagua
# 504888                xezon/GeneralsRankedMaps
# 504889                    mafischer/trader-bot
#
#                                                  repo_url  action  \
# 504885  https://api.github.com/repos/remote-job-boards...  opened
# 504886  https://api.github.com/repos/nnstreamer/nnstre...  opened
# 504887        https://api.github.com/repos/BaguaSys/bagua  closed
# 504888  https://api.github.com/repos/xezon/GeneralsRan...  closed
# 504889  https://api.github.com/repos/mafischer/trader-bot  opened
#
#                                                     title  \
# 504885  Retail E Commerce Ventures: PHP MySQL HTML CSS...
# 504886             Sharing Model Representation with CAPI
# 504887                           autotune service: naming
# 504888  [Candidate 1v1 Glacial Horses V1] Shadows have...
# 504889                                  Add alpaca broker
#
#                                       labels  \
# 504885  lang-javascript lang-php remoteok.io
# 504886                Open for Participation
# 504887                  autotune enhancement
# 504888                        blocker design
# 504889                        P2 enhancement
#
#                                                      body              class  \
# 504885  **Tags:** #javascript #css #php #html #sql #cs...  not_high_priority
# 504886  We can access a specific TFLite model through ...  not_high_priority
# 504887  - `autotune_client.register_models` should be ...  not_high_priority
# 504888  **Issue Description**\r\nShadows have strong m...  not_high_priority
# 504889                            https://alpaca.markets/  not_high_priority
#
#         label                                               text
# 504885      1  **Tags:** #javascript #css #php #html #sql #cs...
# 504886      1  We can access a specific TFLite model through ...
# 504887      1  - `autotune_client.register_models` should be ...
# 504888      1  **Issue Description**\r\nShadows have strong m...
# 504889      1                            https://alpaca.markets/

# %%
# Make a new dataframe with only text, label and class cols.
all_priority_subset = all_priority[["text" , "label" , "class"]]
all_priority_subset
# Out:
#                                                      text  label  \
# 0       ## Is your feature request related to a proble...      0
# 1       Implement an Android Image Picker to browse Im...      0
# 2       - When a video is not playing:\r\n    - Hover ...      0
# 3       ## Description\r\n\r\nEscape shuttle accelerat...      0
# 4       https://notebooks.gesis.org/binder/jupyter/use...      0
# ...                                                   ...    ...
# 504885  **Tags:** #javascript #css #php #html #sql #cs...      1
# 504886  We can access a specific TFLite model through ...      1
# 504887  - `autotune_client.register_models` should be ...      1
# 504888  **Issue Description**\r\nShadows have strong m...      1
# 504889                            https://alpaca.markets/      1
#
#                     class
# 0           high_priority
# 1           high_priority
# 2           high_priority
# 3           high_priority
# 4           high_priority
# ...                   ...
# 504885  not_high_priority
# 504886  not_high_priority
# 504887  not_high_priority
# 504888  not_high_priority
# 504889  not_high_priority
#
# [504890 rows x 3 columns]

# %%
all_priority_subset
# Out:
#                                                      text  label  \
# 0       ## Is your feature request related to a proble...      0
# 1       Implement an Android Image Picker to browse Im...      0
# 2       - When a video is not playing:\r\n    - Hover ...      0
# 3       ## Description\r\n\r\nEscape shuttle accelerat...      0
# 4       https://notebooks.gesis.org/binder/jupyter/use...      0
# ...                                                   ...    ...
# 504885  **Tags:** #javascript #css #php #html #sql #cs...      1
# 504886  We can access a specific TFLite model through ...      1
# 504887  - `autotune_client.register_models` should be ...      1
# 504888  **Issue Description**\r\nShadows have strong m...      1
# 504889                            https://alpaca.markets/      1
#
#                     class
# 0           high_priority
# 1           high_priority
# 2           high_priority
# 3           high_priority
# 4           high_priority
# ...                   ...
# 504885  not_high_priority
# 504886  not_high_priority
# 504887  not_high_priority
# 504888  not_high_priority
# 504889  not_high_priority
#
# [504890 rows x 3 columns]

# %%
# What is this for?
# all_priority_subset.to_csv("subset_priority_dataset.csv")

# %%
# Convert to string
all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)
# Out:
# /tmp/ipykernel_361870/3106036705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)

# %%
all_priority_subset
# Out:
#                                                      text  label  \
# 0       ## Is your feature request related to a proble...      0
# 1       Implement an Android Image Picker to browse Im...      0
# 2       - When a video is not playing:\r\n    - Hover ...      0
# 3       ## Description\r\n\r\nEscape shuttle accelerat...      0
# 4       https://notebooks.gesis.org/binder/jupyter/use...      0
# ...                                                   ...    ...
# 504885  **Tags:** #javascript #css #php #html #sql #cs...      1
# 504886  We can access a specific TFLite model through ...      1
# 504887  - `autotune_client.register_models` should be ...      1
# 504888  **Issue Description**\r\nShadows have strong m...      1
# 504889                            https://alpaca.markets/      1
#
#                     class                                           text_str
# 0           high_priority  ## Is your feature request related to a proble...
# 1           high_priority  Implement an Android Image Picker to browse Im...
# 2           high_priority  - When a video is not playing:\r\n    - Hover ...
# 3           high_priority  ## Description\r\n\r\nEscape shuttle accelerat...
# 4           high_priority  https://notebooks.gesis.org/binder/jupyter/use...
# ...                   ...                                                ...
# 504885  not_high_priority  **Tags:** #javascript #css #php #html #sql #cs...
# 504886  not_high_priority  We can access a specific TFLite model through ...
# 504887  not_high_priority  - `autotune_client.register_models` should be ...
# 504888  not_high_priority  **Issue Description**\r\nShadows have strong m...
# 504889  not_high_priority                            https://alpaca.markets/
#
# [504890 rows x 4 columns]

# %%
# Clean the data.
all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_361870/63294665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)

# %%
# Make a subset with text_clean and label
priority_label_text = all_priority_subset[["text_clean" , "label"]]
priority_label_text
# Out:
#                                                text_clean  label
# 0       is your feature request related to a problem p...      0
# 1       implement an android image picker to browse im...      0
# 2       when a video is not playing hover should displ...      0
# 3       description escape shuttle accelerates faster ...      0
# 4       httpsnotebooksgesisorgbinderjupyteruserrussted...      0
# ...                                                   ...    ...
# 504885  tags javascript css php html sql css php html ...      1
# 504886  we can access a specific tflite model through ...      1
# 504887  autotuneclientregistermodels should be autotun...      1
# 504888  issue description shadows have strong magenta ...      1
# 504889                                                NaN      1
#
# [504890 rows x 2 columns]

# %%
# Need to dropna here since cleaning function returns NaN for not english text.
priority_label_text.dropna(inplace=True)
priority_label_text.reset_index(inplace=True)
priority_label_text.drop(columns=["index"] , inplace= True)

priority_label_text
# Out:
# /tmp/ipykernel_361870/1038009599.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.dropna(inplace=True)
# /tmp/ipykernel_361870/1038009599.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.drop(columns=["index"] , inplace= True)
#                                                text_clean  label
# 0       is your feature request related to a problem p...      0
# 1       implement an android image picker to browse im...      0
# 2       when a video is not playing hover should displ...      0
# 3       description escape shuttle accelerates faster ...      0
# 4       httpsnotebooksgesisorgbinderjupyteruserrussted...      0
# ...                                                   ...    ...
# 444474  cve202024977 medium severity vulnerability det...      1
# 444475  tags javascript css php html sql css php html ...      1
# 444476  we can access a specific tflite model through ...      1
# 444477  autotuneclientregistermodels should be autotun...      1
# 444478  issue description shadows have strong magenta ...      1
#
# [444479 rows x 2 columns]

# %%
# Clean dataset with clean text and labels.
# 0 = high priority, 1 = medium priority, 2 low priority.
priority_label_text.to_csv("csv/priority_high_low_clean.csv")

# %%
df2 = pd.read_csv("csv/priority_high_low_clean.csv", index_col=0)
df2
# Out:
#                                                text_clean  label
# 0       is your feature request related to a problem p...      0
# 1       implement an android image picker to browse im...      0
# 2       when a video is not playing hover should displ...      0
# 3       description escape shuttle accelerates faster ...      0
# 4       httpsnotebooksgesisorgbinderjupyteruserrussted...      0
# ...                                                   ...    ...
# 444474  cve202024977 medium severity vulnerability det...      1
# 444475  tags javascript css php html sql css php html ...      1
# 444476  we can access a specific tflite model through ...      1
# 444477  autotuneclientregistermodels should be autotun...      1
# 444478  issue description shadows have strong magenta ...      1
#
# [444479 rows x 2 columns]
