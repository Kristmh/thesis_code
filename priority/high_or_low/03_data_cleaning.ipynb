# %% [markdown]
# # Data cleaning
# We want the class with labels as numerical value and the body with clean text.
#
# This will:
# * Remove duplicates
# * Remove NaN entires

# %%
import pandas as pd
import sys
sys.path.append("../../scripts_shared/")
from preprocess_text import preprocess_text

# %%
priority = pd.read_csv("csv/full_dataset_priority_high_low.csv" , index_col=0)
priority
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3       1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4       1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...              ...          ...                  ...
# 574268  2.060586e+10  IssuesEvent  2022-03-06 23:45:23
# 574269  7.334740e+09  IssuesEvent  2018-03-06 00:10:40
# 574270  7.334876e+09  IssuesEvent  2018-03-06 00:53:49
# 574271  7.335047e+09  IssuesEvent  2018-03-06 01:48:07
# 574272  7.335050e+09  IssuesEvent  2018-03-06 01:49:10
#
#                                        repo  \
# 0                 unitystation/unitystation
# 1       zowe/sample-spring-boot-api-service
# 2                        openmsupply/mobile
# 3       UltimateCodeMonkeys/CodeMonkeysMVVM
# 4        wordpress-mobile/WordPress-Android
# ...                                     ...
# 574268            bounswe/bounswe2022group1
# 574269                      hoodedice/notes
# 574270            zephyrproject-rtos/zephyr
# 574271                   uwnrg/minotaur-cpp
# 574272                   uwnrg/minotaur-cpp
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/unitystation/unit...  closed
# 1       https://api.github.com/repos/zowe/sample-sprin...  closed
# 2         https://api.github.com/repos/openmsupply/mobile  closed
# 3       https://api.github.com/repos/UltimateCodeMonke...  opened
# 4       https://api.github.com/repos/wordpress-mobile/...  closed
# ...                                                   ...     ...
# 574268  https://api.github.com/repos/bounswe/bounswe20...  closed
# 574269       https://api.github.com/repos/hoodedice/notes  opened
# 574270  https://api.github.com/repos/zephyrproject-rto...  closed
# 574271    https://api.github.com/repos/uwnrg/minotaur-cpp  closed
# 574272    https://api.github.com/repos/uwnrg/minotaur-cpp  closed
#
#                                                     title  \
# 0       Client breaking NRE when using edit field on C...
# 1       The SDK provides a separate Java (no-Spring) l...
# 2                      Auto-log out after some time frame
# 3       Migrate: CodeMonkeys ViewModelNavigationServic...
# 4       IA Reader filter bottom sheet: manage untitled...
# ...                                                   ...
# 574268                        Editing Navigator of  Wiki
# 574269                           Check if passwords match
# 574270  Add doc to samples/bluetooth/mesh & samples/bl...
# 574271                   Fix the photo in about dialog xd
# 574272  Move Record Video/Screenshot and camera select...
#
#                                                    labels  \
# 0                        Bug High Priority In Progress UI
# 1       Feature: API Security Priority: High no-issue-...
# 2       Docs: not needed Effort: small Feature Module:...
# 3       Priority: High Status: In Progress Type: Maint...
# 4                        IA Reader [Pri] High [Type] Task
# ...                                                   ...
# 574268                                       Priority-Low
# 574269                           enhancement low priority
# 574270  area: Bluetooth area: Documentation area: Samp...
# 574271                           enhancement low priority
# 574272                           enhancement low priority
#
#                                                      body          class
# 0       ### Bug:\r\n\r\nIf you use the edit field of t...  high_priority
# 1       - The commons-spring library is split into:\r\...  high_priority
# 2       ## Is your feature request related to a proble...  high_priority
# 3       Migrate the Xamarin.Forms navigation service i...  high_priority
# 4       In the filter bottom sheet we introduced in th...  high_priority
# ...                                                   ...            ...
# 574268  The navigator of the wiki should be edited and...   low_priority
# 574269  JavaScript code (or see if possible without) t...   low_priority
# 574270  We should document what exactly the sample is ...   low_priority
# 574271                                                NaN   low_priority
# 574272            that can be opened from a dropdown menu   low_priority
#
# [574248 rows x 10 columns]

# %%
#Number of issues per class
priority["class"].value_counts()
# Out:
# class
# high_priority    373777
# low_priority     200471
# Name: count, dtype: int64

# %%
# Drop duplicates by the content of the body
priority = priority.drop_duplicates(subset=['body'], keep='last')
priority.dropna(inplace=True)
priority.reset_index(inplace=True)
priority.drop(columns=["index"] , inplace= True)
priority["class"].value_counts()
# Out:
# /tmp/ipykernel_374288/2519026987.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority.dropna(inplace=True)
# /tmp/ipykernel_374288/2519026987.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority.drop(columns=["index"] , inplace= True)
# class
# high_priority    251096
# low_priority     147145
# Name: count, dtype: int64

# %%
priority
# Out:
#                   id         type           created_at  \
# 0       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 1       1.141776e+10  IssuesEvent  2020-02-03 01:22:41
# 2       1.141780e+10  IssuesEvent  2020-02-03 01:35:11
# 3       1.141797e+10  IssuesEvent  2020-02-03 02:25:22
# 4       1.141809e+10  IssuesEvent  2020-02-03 02:58:51
# ...              ...          ...                  ...
# 398236  2.060584e+10  IssuesEvent  2022-03-06 23:40:48
# 398237  2.060586e+10  IssuesEvent  2022-03-06 23:45:23
# 398238  7.334740e+09  IssuesEvent  2018-03-06 00:10:40
# 398239  7.334876e+09  IssuesEvent  2018-03-06 00:53:49
# 398240  7.335050e+09  IssuesEvent  2018-03-06 01:49:10
#
#                                                repo  \
# 0                                openmsupply/mobile
# 1                                SolerSoft/TaskeRGB
# 2                         ericauv/ericauv-portfolio
# 3                         unitystation/unitystation
# 4                         RussTedrake/underactuated
# ...                                             ...
# 398236  CafeteriaGuild/DeepMobLearning-Refabricated
# 398237                    bounswe/bounswe2022group1
# 398238                              hoodedice/notes
# 398239                    zephyrproject-rtos/zephyr
# 398240                           uwnrg/minotaur-cpp
#
#                                                  repo_url  action  \
# 0         https://api.github.com/repos/openmsupply/mobile  closed
# 1         https://api.github.com/repos/SolerSoft/TaskeRGB  closed
# 2       https://api.github.com/repos/ericauv/ericauv-p...  closed
# 3       https://api.github.com/repos/unitystation/unit...  closed
# 4       https://api.github.com/repos/RussTedrake/under...  closed
# ...                                                   ...     ...
# 398236  https://api.github.com/repos/CafeteriaGuild/De...  closed
# 398237  https://api.github.com/repos/bounswe/bounswe20...  closed
# 398238       https://api.github.com/repos/hoodedice/notes  opened
# 398239  https://api.github.com/repos/zephyrproject-rto...  closed
# 398240    https://api.github.com/repos/uwnrg/minotaur-cpp  closed
#
#                                                     title  \
# 0                      Auto-log out after some time frame
# 1                                 Image Picker for Source
# 2              Fix Video Page ListItem Hovering Behaviour
# 3                  Escape shuttle reaches ludicrous speed
# 4       Binder doesn't load notebooks outside of the u...
# ...                                                   ...
# 398236   Thunderstrike during Trials destroying the loot.
# 398237                        Editing Navigator of  Wiki
# 398238                           Check if passwords match
# 398239  Add doc to samples/bluetooth/mesh & samples/bl...
# 398240  Move Record Video/Screenshot and camera select...
#
#                                                    labels  \
# 0       Docs: not needed Effort: small Feature Module:...
# 1                config enhancement palette priority-high
# 2                                           High Priority
# 3                                   Bug High Priority lol
# 4                                          priority: high
# ...                                                   ...
# 398236                           enhancement Low Priority
# 398237                                       Priority-Low
# 398238                           enhancement low priority
# 398239  area: Bluetooth area: Documentation area: Samp...
# 398240                           enhancement low priority
#
#                                                      body          class
# 0       ## Is your feature request related to a proble...  high_priority
# 1       Implement an Android Image Picker to browse Im...  high_priority
# 2       - When a video is not playing:\r\n    - Hover ...  high_priority
# 3       ## Description\r\n\r\nEscape shuttle accelerat...  high_priority
# 4       https://notebooks.gesis.org/binder/jupyter/use...  high_priority
# ...                                                   ...            ...
# 398236  When you run the trial, it will set areas on f...   low_priority
# 398237  The navigator of the wiki should be edited and...   low_priority
# 398238  JavaScript code (or see if possible without) t...   low_priority
# 398239  We should document what exactly the sample is ...   low_priority
# 398240            that can be opened from a dropdown menu   low_priority
#
# [398241 rows x 10 columns]

# %%
# Split the dataframe 
high_priority = priority.loc[priority['class'] == 'high_priority'].copy()
low_priority = priority.loc[priority['class'] == 'low_priority'].copy()

# %%
high_priority.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 251096 entries, 0 to 251095
# Data columns (total 10 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          251096 non-null  float64
#  1   type        251096 non-null  object
#  2   created_at  251096 non-null  object
#  3   repo        251096 non-null  object
#  4   repo_url    251096 non-null  object
#  5   action      251096 non-null  object
#  6   title       251096 non-null  object
#  7   labels      251096 non-null  object
#  8   body        251096 non-null  object
#  9   class       251096 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 21.1+ MB

# %%
#Give each priority a label by number.
# 'Label encoding'. Makes is easier for machine learning models to work with categorical data.
high_priority["label"] = 0
high_priority.head()
# Out:
#              id         type           created_at                       repo  \
# 0  1.141755e+10  IssuesEvent  2020-02-03 00:02:58         openmsupply/mobile
# 1  1.141776e+10  IssuesEvent  2020-02-03 01:22:41         SolerSoft/TaskeRGB
# 2  1.141780e+10  IssuesEvent  2020-02-03 01:35:11  ericauv/ericauv-portfolio
# 3  1.141797e+10  IssuesEvent  2020-02-03 02:25:22  unitystation/unitystation
# 4  1.141809e+10  IssuesEvent  2020-02-03 02:58:51  RussTedrake/underactuated
#
#                                             repo_url  action  \
# 0    https://api.github.com/repos/openmsupply/mobile  closed
# 1    https://api.github.com/repos/SolerSoft/TaskeRGB  closed
# 2  https://api.github.com/repos/ericauv/ericauv-p...  closed
# 3  https://api.github.com/repos/unitystation/unit...  closed
# 4  https://api.github.com/repos/RussTedrake/under...  closed
#
#                                                title  \
# 0                 Auto-log out after some time frame
# 1                            Image Picker for Source
# 2         Fix Video Page ListItem Hovering Behaviour
# 3             Escape shuttle reaches ludicrous speed
# 4  Binder doesn't load notebooks outside of the u...
#
#                                               labels  \
# 0  Docs: not needed Effort: small Feature Module:...
# 1           config enhancement palette priority-high
# 2                                      High Priority
# 3                              Bug High Priority lol
# 4                                     priority: high
#
#                                                 body          class  label
# 0  ## Is your feature request related to a proble...  high_priority      0
# 1  Implement an Android Image Picker to browse Im...  high_priority      0
# 2  - When a video is not playing:\r\n    - Hover ...  high_priority      0
# 3  ## Description\r\n\r\nEscape shuttle accelerat...  high_priority      0
# 4  https://notebooks.gesis.org/binder/jupyter/use...  high_priority      0

# %%
low_priority["label"] = 1
low_priority.head()
# Out:
#                   id         type           created_at  \
# 251096  1.141766e+10  IssuesEvent  2020-02-03 00:46:42
# 251097  1.141777e+10  IssuesEvent  2020-02-03 01:25:06
# 251098  1.141780e+10  IssuesEvent  2020-02-03 01:34:56
# 251099  1.141786e+10  IssuesEvent  2020-02-03 01:52:04
# 251100  1.141809e+10  IssuesEvent  2020-02-03 02:59:10
#
#                           repo  \
# 251096     WordPress/gutenberg
# 251097       MarkBind/markbind
# 251098       MarkBind/markbind
# 251099  poissonconsulting/term
# 251100       MarkBind/markbind
#
#                                                  repo_url    action  \
# 251096   https://api.github.com/repos/WordPress/gutenberg    closed
# 251097     https://api.github.com/repos/MarkBind/markbind  reopened
# 251098     https://api.github.com/repos/MarkBind/markbind    closed
# 251099  https://api.github.com/repos/poissonconsulting...    closed
# 251100     https://api.github.com/repos/MarkBind/markbind    closed
#
#                                                  title  \
# 251096               Z-index issue using Classic block
# 251097           Indicate the language of a code block
# 251098  Use one attribute name for header, title, name
# 251099     Document levels of validation in vld_term()
# 251100              Support puml files in boilerplates
#
#                                                    labels  \
# 251096          [Block] Classic [Priority] Low [Type] Bug
# 251097                   c.Enhancement f-CodeBlocks p.Low
# 251098                            a-AuthorUsability p.Low
# 251099  Difficulty: 1 Novice Effort: 1 Low Priority: 2...
# 251100            c.Bug 🐛 f-Boilerplates f-Diagrams p.Low
#
#                                                      body         class  label
# 251096  Selecting a link in the classic block and havi...  low_priority      1
# 251097  **Tell us about your environment**\r\n\r\n* **...  low_priority      1
# 251098  May be better to choose one of the three and u...  low_priority      1
# 251099         As this is what other functions reference.  low_priority      1
# 251100  see [this comment](https://github.com/MarkBind...  low_priority      1

# %%
label_counts = priority["class"].value_counts()
print(label_counts)
low_priority_count = label_counts["low_priority"]
print(low_priority_count)
hp_count = label_counts["high_priority"]
hp_count
# Out:
# class
# high_priority    251096
# low_priority     147145
# Name: count, dtype: int64
# 147145
# 251096

# %%
high_priority = high_priority.sample(frac=low_priority_count/hp_count, random_state=42)
high_priority
# Out:
#                   id         type           created_at  \
# 194880  1.055297e+10  IssuesEvent  2019-10-03 16:11:17
# 158706  1.544203e+10  IssuesEvent  2021-03-08 07:02:33
# 24470   1.270423e+10  IssuesEvent  2020-06-23 00:44:57
# 72791   1.884629e+10  IssuesEvent  2021-11-11 15:17:27
# 44061   3.410387e+09  IssuesEvent  2015-12-04 19:55:41
# ...              ...          ...                  ...
# 30301   1.376081e+10  IssuesEvent  2020-10-07 06:37:14
# 113149  5.345467e+09  IssuesEvent  2017-02-17 17:01:39
# 139260  2.000895e+10  IssuesEvent  2022-02-01 02:16:44
# 118983  2.374970e+10  IssuesEvent  2022-08-31 19:21:54
# 164126  2.583471e+09  IssuesEvent  2015-02-16 06:33:32
#
#                                           repo  \
# 194880           Treylatic/Kivett_Escape_Class
# 158706               AY2021S2-CS2113T-W09-2/tp
# 24470                          certbot/certbot
# 72791   kaiwalyakoparkar/classroom-monitor-bot
# 44061                   crcn/interface-builder
# ...                                        ...
# 30301                AY2021S1-CS2113T-T12-1/tp
# 113149                       clarat-org/clarat
# 139260     Climate-Refugee-Stories/crs-website
# 118983                     AkjoStudios/AkjoNav
# 164126                    epsilonz/shoggoth.rs
#
#                                                  repo_url  action  \
# 194880  https://api.github.com/repos/Treylatic/Kivett_...  opened
# 158706  https://api.github.com/repos/AY2021S2-CS2113T-...  opened
# 24470        https://api.github.com/repos/certbot/certbot  opened
# 72791   https://api.github.com/repos/kaiwalyakoparkar/...  closed
# 44061   https://api.github.com/repos/crcn/interface-bu...  opened
# ...                                                   ...     ...
# 30301   https://api.github.com/repos/AY2021S1-CS2113T-...  opened
# 113149     https://api.github.com/repos/clarat-org/clarat  closed
# 139260  https://api.github.com/repos/Climate-Refugee-S...  closed
# 118983   https://api.github.com/repos/AkjoStudios/AkjoNav  opened
# 164126  https://api.github.com/repos/epsilonz/shoggoth.rs  opened
#
#                                                     title  \
# 194880                               Design Traps/Puzzles
# 158706  Create classes for core, elective, math and GE...
# 24470   Make each DNS plugin respect EXCLUDE_CERTBOT_DEPS
# 72791               [Bug]: Profane Warning on wrong words
# 44061                                         transitions
# ...                                                   ...
# 30301   As a NUS student, I want to bookmark all the i...
# 113149                  Geolocation Möglichkeiten checken
# 139260                                          Home Page
# 118983  [Feature Enhancement] Migrate everything to Mi...
# 164126                             Fix list macro imports
#
#                                                    labels  \
# 194880                             High Priority Point: 2
# 158706                     priority.High type.Enhancement
# 24470   area: code health area: dns area: snaps easy-f...
# 72791                                    🟧 priority: high
# 44061                               feature high priority
# ...                                                   ...
# 30301                            priority.High type.Story
# 113149                                  Feature High Prio
# 139260                                      high priority
# 118983  priority: high status: planned type: enhanceme...
# 164126                   A-macros E-easy I-cleanup P-high
#
#                                                      body          class  \
# 194880  The game is based on escape mechanics and need...  high_priority
# 158706  For example, a core module should be contained...  high_priority
# 24470   This was done for one plugin in https://github...  high_priority
# 72791   ### Describe the bug\r\n\r\nThe bot is throwin...  high_priority
# 44061     ability to transition from one state to another  high_priority
# ...                                                   ...            ...
# 30301                      ... to access them more easily  high_priority
# 113149  Da Berlin als default zusehends keinen Sinn me...  high_priority
# 139260  - [x]  Logo background - needs to stay a circl...  high_priority
# 118983  ### In which module is the feature you want to...  high_priority
# 164126  There are problems importing the list macros b...  high_priority
#
#         label
# 194880      0
# 158706      0
# 24470       0
# 72791       0
# 44061       0
# ...       ...
# 30301       0
# 113149      0
# 139260      0
# 118983      0
# 164126      0
#
# [147145 rows x 11 columns]

# %%
all_priority = pd.concat([high_priority,low_priority] , ignore_index = True)
all_priority.tail()
# Out:
#                   id         type           created_at  \
# 294285  2.060584e+10  IssuesEvent  2022-03-06 23:40:48
# 294286  2.060586e+10  IssuesEvent  2022-03-06 23:45:23
# 294287  7.334740e+09  IssuesEvent  2018-03-06 00:10:40
# 294288  7.334876e+09  IssuesEvent  2018-03-06 00:53:49
# 294289  7.335050e+09  IssuesEvent  2018-03-06 01:49:10
#
#                                                repo  \
# 294285  CafeteriaGuild/DeepMobLearning-Refabricated
# 294286                    bounswe/bounswe2022group1
# 294287                              hoodedice/notes
# 294288                    zephyrproject-rtos/zephyr
# 294289                           uwnrg/minotaur-cpp
#
#                                                  repo_url  action  \
# 294285  https://api.github.com/repos/CafeteriaGuild/De...  closed
# 294286  https://api.github.com/repos/bounswe/bounswe20...  closed
# 294287       https://api.github.com/repos/hoodedice/notes  opened
# 294288  https://api.github.com/repos/zephyrproject-rto...  closed
# 294289    https://api.github.com/repos/uwnrg/minotaur-cpp  closed
#
#                                                     title  \
# 294285   Thunderstrike during Trials destroying the loot.
# 294286                        Editing Navigator of  Wiki
# 294287                           Check if passwords match
# 294288  Add doc to samples/bluetooth/mesh & samples/bl...
# 294289  Move Record Video/Screenshot and camera select...
#
#                                                    labels  \
# 294285                           enhancement Low Priority
# 294286                                       Priority-Low
# 294287                           enhancement low priority
# 294288  area: Bluetooth area: Documentation area: Samp...
# 294289                           enhancement low priority
#
#                                                      body         class  label
# 294285  When you run the trial, it will set areas on f...  low_priority      1
# 294286  The navigator of the wiki should be edited and...  low_priority      1
# 294287  JavaScript code (or see if possible without) t...  low_priority      1
# 294288  We should document what exactly the sample is ...  low_priority      1
# 294289            that can be opened from a dropdown menu  low_priority      1

# %%
# Does this need to be more balanced?
all_priority["label"].value_counts()
# Out:
# label
# 0    147145
# 1    147145
# Name: count, dtype: int64

# %%
# Copy content of body to a new col named text
# Why?
all_priority["text"] = all_priority["body"]
all_priority.tail()
# Out:
#                   id         type           created_at  \
# 294285  2.060584e+10  IssuesEvent  2022-03-06 23:40:48
# 294286  2.060586e+10  IssuesEvent  2022-03-06 23:45:23
# 294287  7.334740e+09  IssuesEvent  2018-03-06 00:10:40
# 294288  7.334876e+09  IssuesEvent  2018-03-06 00:53:49
# 294289  7.335050e+09  IssuesEvent  2018-03-06 01:49:10
#
#                                                repo  \
# 294285  CafeteriaGuild/DeepMobLearning-Refabricated
# 294286                    bounswe/bounswe2022group1
# 294287                              hoodedice/notes
# 294288                    zephyrproject-rtos/zephyr
# 294289                           uwnrg/minotaur-cpp
#
#                                                  repo_url  action  \
# 294285  https://api.github.com/repos/CafeteriaGuild/De...  closed
# 294286  https://api.github.com/repos/bounswe/bounswe20...  closed
# 294287       https://api.github.com/repos/hoodedice/notes  opened
# 294288  https://api.github.com/repos/zephyrproject-rto...  closed
# 294289    https://api.github.com/repos/uwnrg/minotaur-cpp  closed
#
#                                                     title  \
# 294285   Thunderstrike during Trials destroying the loot.
# 294286                        Editing Navigator of  Wiki
# 294287                           Check if passwords match
# 294288  Add doc to samples/bluetooth/mesh & samples/bl...
# 294289  Move Record Video/Screenshot and camera select...
#
#                                                    labels  \
# 294285                           enhancement Low Priority
# 294286                                       Priority-Low
# 294287                           enhancement low priority
# 294288  area: Bluetooth area: Documentation area: Samp...
# 294289                           enhancement low priority
#
#                                                      body         class  \
# 294285  When you run the trial, it will set areas on f...  low_priority
# 294286  The navigator of the wiki should be edited and...  low_priority
# 294287  JavaScript code (or see if possible without) t...  low_priority
# 294288  We should document what exactly the sample is ...  low_priority
# 294289            that can be opened from a dropdown menu  low_priority
#
#         label                                               text
# 294285      1  When you run the trial, it will set areas on f...
# 294286      1  The navigator of the wiki should be edited and...
# 294287      1  JavaScript code (or see if possible without) t...
# 294288      1  We should document what exactly the sample is ...
# 294289      1            that can be opened from a dropdown menu

# %%
# Make a new dataframe with only text, label and class cols.
all_priority_subset = all_priority[["text" , "label" , "class"]]
all_priority_subset
# Out:
#                                                      text  label  \
# 0       The game is based on escape mechanics and need...      0
# 1       For example, a core module should be contained...      0
# 2       This was done for one plugin in https://github...      0
# 3       ### Describe the bug\r\n\r\nThe bot is throwin...      0
# 4         ability to transition from one state to another      0
# ...                                                   ...    ...
# 294285  When you run the trial, it will set areas on f...      1
# 294286  The navigator of the wiki should be edited and...      1
# 294287  JavaScript code (or see if possible without) t...      1
# 294288  We should document what exactly the sample is ...      1
# 294289            that can be opened from a dropdown menu      1
#
#                 class
# 0       high_priority
# 1       high_priority
# 2       high_priority
# 3       high_priority
# 4       high_priority
# ...               ...
# 294285   low_priority
# 294286   low_priority
# 294287   low_priority
# 294288   low_priority
# 294289   low_priority
#
# [294290 rows x 3 columns]

# %%
all_priority_subset
# Out:
#                                                      text  label  \
# 0       The game is based on escape mechanics and need...      0
# 1       For example, a core module should be contained...      0
# 2       This was done for one plugin in https://github...      0
# 3       ### Describe the bug\r\n\r\nThe bot is throwin...      0
# 4         ability to transition from one state to another      0
# ...                                                   ...    ...
# 294285  When you run the trial, it will set areas on f...      1
# 294286  The navigator of the wiki should be edited and...      1
# 294287  JavaScript code (or see if possible without) t...      1
# 294288  We should document what exactly the sample is ...      1
# 294289            that can be opened from a dropdown menu      1
#
#                 class
# 0       high_priority
# 1       high_priority
# 2       high_priority
# 3       high_priority
# 4       high_priority
# ...               ...
# 294285   low_priority
# 294286   low_priority
# 294287   low_priority
# 294288   low_priority
# 294289   low_priority
#
# [294290 rows x 3 columns]

# %%
# What is this for?
# all_priority_subset.to_csv("subset_priority_dataset.csv")

# %%
# Convert to string
all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)
# Out:
# /tmp/ipykernel_374288/3106036705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)

# %%
all_priority_subset
# Out:
#                                                      text  label  \
# 0       The game is based on escape mechanics and need...      0
# 1       For example, a core module should be contained...      0
# 2       This was done for one plugin in https://github...      0
# 3       ### Describe the bug\r\n\r\nThe bot is throwin...      0
# 4         ability to transition from one state to another      0
# ...                                                   ...    ...
# 294285  When you run the trial, it will set areas on f...      1
# 294286  The navigator of the wiki should be edited and...      1
# 294287  JavaScript code (or see if possible without) t...      1
# 294288  We should document what exactly the sample is ...      1
# 294289            that can be opened from a dropdown menu      1
#
#                 class                                           text_str
# 0       high_priority  The game is based on escape mechanics and need...
# 1       high_priority  For example, a core module should be contained...
# 2       high_priority  This was done for one plugin in https://github...
# 3       high_priority  ### Describe the bug\r\n\r\nThe bot is throwin...
# 4       high_priority    ability to transition from one state to another
# ...               ...                                                ...
# 294285   low_priority  When you run the trial, it will set areas on f...
# 294286   low_priority  The navigator of the wiki should be edited and...
# 294287   low_priority  JavaScript code (or see if possible without) t...
# 294288   low_priority  We should document what exactly the sample is ...
# 294289   low_priority            that can be opened from a dropdown menu
#
# [294290 rows x 4 columns]

# %%
# Clean the data.
all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_374288/63294665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)

# %%
# Make a subset with text_clean and label
priority_label_text = all_priority_subset[["text_clean" , "label"]]
priority_label_text
# Out:
#                                                text_clean  label
# 0       the game is based on escape mechanics and need...      0
# 1       for example a core module should be contained ...      0
# 2       this was done for one plugin in httpsgithubcom...      0
# 3       describe the bug the bot is throwing profane w...      0
# 4         ability to transition from one state to another      0
# ...                                                   ...    ...
# 294285  when you run the trial it will set areas on fi...      1
# 294286  the navigator of the wiki should be edited and...      1
# 294287  javascript code or see if possible without tha...      1
# 294288  we should document what exactly the sample is ...      1
# 294289            that can be opened from a dropdown menu      1
#
# [294290 rows x 2 columns]

# %%
priority_label_text.dropna(inplace=True)
priority_label_text.reset_index(inplace=True)
priority_label_text.drop(columns=["index"] , inplace= True)

priority_label_text
# Out:
# /tmp/ipykernel_374288/1038009599.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.dropna(inplace=True)
# /tmp/ipykernel_374288/1038009599.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.drop(columns=["index"] , inplace= True)
#                                                text_clean  label
# 0       the game is based on escape mechanics and need...      0
# 1       for example a core module should be contained ...      0
# 2       this was done for one plugin in httpsgithubcom...      0
# 3       describe the bug the bot is throwing profane w...      0
# 4         ability to transition from one state to another      0
# ...                                                   ...    ...
# 269572  when you run the trial it will set areas on fi...      1
# 269573  the navigator of the wiki should be edited and...      1
# 269574  javascript code or see if possible without tha...      1
# 269575  we should document what exactly the sample is ...      1
# 269576            that can be opened from a dropdown menu      1
#
# [269577 rows x 2 columns]

# %%
# Clean dataset with clean text and labels.
# 0 = high priority, 1 = medium priority, 2 low priority.
priority_label_text.to_csv("csv/priority_high_low_clean.csv")

# %%
df2 = pd.read_csv("csv/priority_high_low_clean.csv", index_col=0)
df2
# Out:
#                                                text_clean  label
# 0       the game is based on escape mechanics and need...      0
# 1       for example a core module should be contained ...      0
# 2       this was done for one plugin in httpsgithubcom...      0
# 3       describe the bug the bot is throwing profane w...      0
# 4         ability to transition from one state to another      0
# ...                                                   ...    ...
# 269572  when you run the trial it will set areas on fi...      1
# 269573  the navigator of the wiki should be edited and...      1
# 269574  javascript code or see if possible without tha...      1
# 269575  we should document what exactly the sample is ...      1
# 269576            that can be opened from a dropdown menu      1
#
# [269577 rows x 2 columns]
