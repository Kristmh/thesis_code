# %%
import pandas as pd

# %%
# Read CSV into a dataframe
high_priority = pd.read_csv("csv/final_high_dataset.csv", index_col=0)
low_priority = pd.read_csv("csv/final_low_dataset.csv", index_col=0)

# %%
high_priority
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3       1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4       1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...              ...          ...                  ...
# 373788  7.334924e+09  IssuesEvent  2018-03-06 01:09:12
# 373789  7.334984e+09  IssuesEvent  2018-03-06 01:28:23
# 373790  7.335034e+09  IssuesEvent  2018-03-06 01:44:11
# 373791  7.335035e+09  IssuesEvent  2018-03-06 01:44:26
# 373792  7.335039e+09  IssuesEvent  2018-03-06 01:45:34
#
#                                        repo  \
# 0                 unitystation/unitystation
# 1       zowe/sample-spring-boot-api-service
# 2                        openmsupply/mobile
# 3       UltimateCodeMonkeys/CodeMonkeysMVVM
# 4        wordpress-mobile/WordPress-Android
# ...                                     ...
# 373788           StrangeLoopGames/EcoIssues
# 373789                        asteca/ASteCA
# 373790               wh1ter0se/PowerUp-2018
# 373791               wh1ter0se/PowerUp-2018
# 373792                      xcat2/xcat-core
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/unitystation/unit...  closed
# 1       https://api.github.com/repos/zowe/sample-sprin...  closed
# 2         https://api.github.com/repos/openmsupply/mobile  closed
# 3       https://api.github.com/repos/UltimateCodeMonke...  opened
# 4       https://api.github.com/repos/wordpress-mobile/...  closed
# ...                                                   ...     ...
# 373788  https://api.github.com/repos/StrangeLoopGames/...  closed
# 373789         https://api.github.com/repos/asteca/ASteCA  closed
# 373790  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 373791  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 373792       https://api.github.com/repos/xcat2/xcat-core  closed
#
#                                                     title  \
# 0       Client breaking NRE when using edit field on C...
# 1       The SDK provides a separate Java (no-Spring) l...
# 2                      Auto-log out after some time frame
# 3       Migrate: CodeMonkeys ViewModelNavigationServic...
# 4       IA Reader filter bottom sheet: manage untitled...
# ...                                                   ...
# 373788       Meteor hit - Can no longer join server 6.4.1
# 373789  Improve performance of synth cluster generatio...
# 373790  Get and record refined PID loops for rotation ...
# 373791  Figure out why CyborgCommandSpit() runs early ...
# 373792  error message improvement when adding users in...
#
#                                                    labels  \
# 0                        Bug High Priority In Progress UI
# 1       Feature: API Security Priority: High no-issue-...
# 2       Docs: not needed Effort: small Feature Module:...
# 3       Priority: High Status: In Progress Type: Maint...
# 4                        IA Reader [Pri] High [Type] Task
# ...                                                   ...
# 373788                                      High Priority
# 373789           code_enhance p:high performance synth-cl
# 373790                 IRL development high priority java
# 373791                         R&D bug high priority java
# 373792      priority:high sprint1 status:pending type:bug
#
#                                                      body
# 0       ### Bug:\r\n\r\nIf you use the edit field of t...
# 1       - The commons-spring library is split into:\r\...
# 2       ## Is your feature request related to a proble...
# 3       Migrate the Xamarin.Forms navigation service i...
# 4       In the filter bottom sheet we introduced in th...
# ...                                                   ...
# 373788  Just had the meteor hit on our server and now ...
# 373789  Follow up on #227.\r\n\r\n#### 0. Initial `syn...
# 373790  Pretty simple, and pretty sure we already have...
# 373791  The problem is that when we run autonomous (so...
# 373792  Problem statement: error message when adding x...
#
# [373793 rows x 9 columns]

# %%
# Number or different labels
high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                   count
# labels
# bug high priority                 10435
# high priority                     10360
# High Priority                      7484
# enhancement high priority          5486
# Priority: High                     4751
# priority.High                      3694
# priority.High type.Task            3685
# priority.high type.task            3209
# priority.High type.Story           2979
# priority.high                      2749
# bug priority: high                 2306
# high-priority                      2262
# priority: high                     2178
# bug high-priority                  2159
# type.Story priority.High           2155
# priority.high type.story           2130
# type.Task priority.High            2022
# bug High Priority                  1888
# High priority                      1815
# Priority: High Type: Bug           1768
# priority:high                      1726
# bug priority:high                  1470
# High Priority bug                  1338
# Priority: High bug                 1200
# Bug High Priority                  1143
# feature high priority              1091
# enhancement priority: high         1090
# enhancement high-priority          1053
# enhancement priority:high           982
# priority-high                       955
# bug priority-high                   927
# enhancement High Priority           902
# bug Priority: High                  837
# Priority: High Type: Enhancement    835
# high priority task                  831
# bug High priority                   744
# priority high                       733
# priority.high type.bug              717
# priority: high type: bug            704
# Type: Bug Priority: High            639
# Bug Priority: High                  620
# High Priority enhancement           611
# documentation priority.High         600
# prio:high                           587
# priority.High type.Enhancement      562
# Bug - High Priority                 562
# Priority: High Type: Feature        541
# bug prio-high                       541
# priority.high type.enhancement      540
# priority/high                       537

# %%
low_priority
# Out:
#                   id         type           created_at  \
# 0       1.141755e+10  IssuesEvent  2020-02-03 00:02:50
# 1       1.141766e+10  IssuesEvent  2020-02-03 00:46:42
# 2       1.141777e+10  IssuesEvent  2020-02-03 01:25:06
# 3       1.141780e+10  IssuesEvent  2020-02-03 01:34:56
# 4       1.141786e+10  IssuesEvent  2020-02-03 01:52:04
# ...              ...          ...                  ...
# 200475  2.060586e+10  IssuesEvent  2022-03-06 23:45:23
# 200476  7.334740e+09  IssuesEvent  2018-03-06 00:10:40
# 200477  7.334876e+09  IssuesEvent  2018-03-06 00:53:49
# 200478  7.335047e+09  IssuesEvent  2018-03-06 01:48:07
# 200479  7.335050e+09  IssuesEvent  2018-03-06 01:49:10
#
#                              repo  \
# 0          poissonconsulting/term
# 1             WordPress/gutenberg
# 2               MarkBind/markbind
# 3               MarkBind/markbind
# 4          poissonconsulting/term
# ...                           ...
# 200475  bounswe/bounswe2022group1
# 200476            hoodedice/notes
# 200477  zephyrproject-rtos/zephyr
# 200478         uwnrg/minotaur-cpp
# 200479         uwnrg/minotaur-cpp
#
#                                                  repo_url    action  \
# 0       https://api.github.com/repos/poissonconsulting...    opened
# 1        https://api.github.com/repos/WordPress/gutenberg    closed
# 2          https://api.github.com/repos/MarkBind/markbind  reopened
# 3          https://api.github.com/repos/MarkBind/markbind    closed
# 4       https://api.github.com/repos/poissonconsulting...    closed
# ...                                                   ...       ...
# 200475  https://api.github.com/repos/bounswe/bounswe20...    closed
# 200476       https://api.github.com/repos/hoodedice/notes    opened
# 200477  https://api.github.com/repos/zephyrproject-rto...    closed
# 200478    https://api.github.com/repos/uwnrg/minotaur-cpp    closed
# 200479    https://api.github.com/repos/uwnrg/minotaur-cpp    closed
#
#                                                     title  \
# 0             Document levels of validation in vld_term()
# 1                       Z-index issue using Classic block
# 2                   Indicate the language of a code block
# 3          Use one attribute name for header, title, name
# 4             Document levels of validation in vld_term()
# ...                                                   ...
# 200475                        Editing Navigator of  Wiki
# 200476                           Check if passwords match
# 200477  Add doc to samples/bluetooth/mesh & samples/bl...
# 200478                   Fix the photo in about dialog xd
# 200479  Move Record Video/Screenshot and camera select...
#
#                                                    labels  \
# 0       Difficulty: 1 Novice Effort: 1 Low Priority: 2...
# 1               [Block] Classic [Priority] Low [Type] Bug
# 2                        c.Enhancement f-CodeBlocks p.Low
# 3                                 a-AuthorUsability p.Low
# 4       Difficulty: 1 Novice Effort: 1 Low Priority: 2...
# ...                                                   ...
# 200475                                       Priority-Low
# 200476                           enhancement low priority
# 200477  area: Bluetooth area: Documentation area: Samp...
# 200478                           enhancement low priority
# 200479                           enhancement low priority
#
#                                                      body
# 0              As this is what other functions reference.
# 1       Selecting a link in the classic block and havi...
# 2       **Tell us about your environment**\r\n\r\n* **...
# 3       May be better to choose one of the three and u...
# 4              As this is what other functions reference.
# ...                                                   ...
# 200475  The navigator of the wiki should be edited and...
# 200476  JavaScript code (or see if possible without) t...
# 200477  We should document what exactly the sample is ...
# 200478                                                NaN
# 200479            that can be opened from a dropdown menu
#
# [200480 rows x 9 columns]

# %%
# Number or different labels
low_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# enhancement low priority                             5496
# low priority                                         5485
# bug low priority                                     2798
# Low Priority                                         2732
# pri:low pri:lowest                                   2692
# Priority: Low                                        2504
# priority: low                                        1191
# Priority: Low Type: Enhancement                      1155
# bug priority: low                                    1154
# auto-migrated Priority-Low Type-Enhancement          1150
# low-priority                                         1140
# enhancement low-priority                             1116
# enhancement priority:low                             1021
# enhancement priority: low                             968
# auto-migrated Priority-Low Type-Defect                889
# priority:low                                          829
# Low priority                                          741
# pri:lowest pri:low                                    725
# Being Redone Low Priority                             705
# Priority: Low Type: Bug                               674
# enhancement Low Priority                              673
# Coverity bug priority: low                            637
# Low Priority enhancement                              602
# priority.low type.story                               591
# priority-low                                          585
# feature low priority                                  565
# Priority-Low Type-Enhancement                         565
# enhancement priority-low                              565
# bug priority:low                                      553
# bug Low Priority                                      509
# bug low-priority                                      500
# request:new-pkg priority:low                          490
# priority.Low type.Story                               490
# pri:high pri:low pri:lowest                           446
# priority.Low                                          444
# priority.low                                          440
# Priority: Low Status: Available Type: Enhancement     425
# Enhancement Low Priority                              406
# enhancement Priority: Low                             368
# priority low                                          345
# 🟩 priority: low 🚦 status: awaiting triage ✨ goa...    345
# Bug Low Priority                                      333
# Priority: Low enhancement                             315
# low-priority bug                                      308
# Low Priority bug                                      305
# bug Priority: Low                                     300
# low prio                                              284
# Low priority enhancement                              279
# priority::low                                         272
# Priority-Low                                          263

# %%
# Add a new column
high_priority["class"] = "high_priority"
high_priority
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3       1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4       1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...              ...          ...                  ...
# 373788  7.334924e+09  IssuesEvent  2018-03-06 01:09:12
# 373789  7.334984e+09  IssuesEvent  2018-03-06 01:28:23
# 373790  7.335034e+09  IssuesEvent  2018-03-06 01:44:11
# 373791  7.335035e+09  IssuesEvent  2018-03-06 01:44:26
# 373792  7.335039e+09  IssuesEvent  2018-03-06 01:45:34
#
#                                        repo  \
# 0                 unitystation/unitystation
# 1       zowe/sample-spring-boot-api-service
# 2                        openmsupply/mobile
# 3       UltimateCodeMonkeys/CodeMonkeysMVVM
# 4        wordpress-mobile/WordPress-Android
# ...                                     ...
# 373788           StrangeLoopGames/EcoIssues
# 373789                        asteca/ASteCA
# 373790               wh1ter0se/PowerUp-2018
# 373791               wh1ter0se/PowerUp-2018
# 373792                      xcat2/xcat-core
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/unitystation/unit...  closed
# 1       https://api.github.com/repos/zowe/sample-sprin...  closed
# 2         https://api.github.com/repos/openmsupply/mobile  closed
# 3       https://api.github.com/repos/UltimateCodeMonke...  opened
# 4       https://api.github.com/repos/wordpress-mobile/...  closed
# ...                                                   ...     ...
# 373788  https://api.github.com/repos/StrangeLoopGames/...  closed
# 373789         https://api.github.com/repos/asteca/ASteCA  closed
# 373790  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 373791  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 373792       https://api.github.com/repos/xcat2/xcat-core  closed
#
#                                                     title  \
# 0       Client breaking NRE when using edit field on C...
# 1       The SDK provides a separate Java (no-Spring) l...
# 2                      Auto-log out after some time frame
# 3       Migrate: CodeMonkeys ViewModelNavigationServic...
# 4       IA Reader filter bottom sheet: manage untitled...
# ...                                                   ...
# 373788       Meteor hit - Can no longer join server 6.4.1
# 373789  Improve performance of synth cluster generatio...
# 373790  Get and record refined PID loops for rotation ...
# 373791  Figure out why CyborgCommandSpit() runs early ...
# 373792  error message improvement when adding users in...
#
#                                                    labels  \
# 0                        Bug High Priority In Progress UI
# 1       Feature: API Security Priority: High no-issue-...
# 2       Docs: not needed Effort: small Feature Module:...
# 3       Priority: High Status: In Progress Type: Maint...
# 4                        IA Reader [Pri] High [Type] Task
# ...                                                   ...
# 373788                                      High Priority
# 373789           code_enhance p:high performance synth-cl
# 373790                 IRL development high priority java
# 373791                         R&D bug high priority java
# 373792      priority:high sprint1 status:pending type:bug
#
#                                                      body          class
# 0       ### Bug:\r\n\r\nIf you use the edit field of t...  high_priority
# 1       - The commons-spring library is split into:\r\...  high_priority
# 2       ## Is your feature request related to a proble...  high_priority
# 3       Migrate the Xamarin.Forms navigation service i...  high_priority
# 4       In the filter bottom sheet we introduced in th...  high_priority
# ...                                                   ...            ...
# 373788  Just had the meteor hit on our server and now ...  high_priority
# 373789  Follow up on #227.\r\n\r\n#### 0. Initial `syn...  high_priority
# 373790  Pretty simple, and pretty sure we already have...  high_priority
# 373791  The problem is that when we run autonomous (so...  high_priority
# 373792  Problem statement: error message when adding x...  high_priority
#
# [373793 rows x 10 columns]

# %%
low_priority["class"] = "low_priority"
low_priority
# Out:
#                   id         type           created_at  \
# 0       1.141755e+10  IssuesEvent  2020-02-03 00:02:50
# 1       1.141766e+10  IssuesEvent  2020-02-03 00:46:42
# 2       1.141777e+10  IssuesEvent  2020-02-03 01:25:06
# 3       1.141780e+10  IssuesEvent  2020-02-03 01:34:56
# 4       1.141786e+10  IssuesEvent  2020-02-03 01:52:04
# ...              ...          ...                  ...
# 200475  2.060586e+10  IssuesEvent  2022-03-06 23:45:23
# 200476  7.334740e+09  IssuesEvent  2018-03-06 00:10:40
# 200477  7.334876e+09  IssuesEvent  2018-03-06 00:53:49
# 200478  7.335047e+09  IssuesEvent  2018-03-06 01:48:07
# 200479  7.335050e+09  IssuesEvent  2018-03-06 01:49:10
#
#                              repo  \
# 0          poissonconsulting/term
# 1             WordPress/gutenberg
# 2               MarkBind/markbind
# 3               MarkBind/markbind
# 4          poissonconsulting/term
# ...                           ...
# 200475  bounswe/bounswe2022group1
# 200476            hoodedice/notes
# 200477  zephyrproject-rtos/zephyr
# 200478         uwnrg/minotaur-cpp
# 200479         uwnrg/minotaur-cpp
#
#                                                  repo_url    action  \
# 0       https://api.github.com/repos/poissonconsulting...    opened
# 1        https://api.github.com/repos/WordPress/gutenberg    closed
# 2          https://api.github.com/repos/MarkBind/markbind  reopened
# 3          https://api.github.com/repos/MarkBind/markbind    closed
# 4       https://api.github.com/repos/poissonconsulting...    closed
# ...                                                   ...       ...
# 200475  https://api.github.com/repos/bounswe/bounswe20...    closed
# 200476       https://api.github.com/repos/hoodedice/notes    opened
# 200477  https://api.github.com/repos/zephyrproject-rto...    closed
# 200478    https://api.github.com/repos/uwnrg/minotaur-cpp    closed
# 200479    https://api.github.com/repos/uwnrg/minotaur-cpp    closed
#
#                                                     title  \
# 0             Document levels of validation in vld_term()
# 1                       Z-index issue using Classic block
# 2                   Indicate the language of a code block
# 3          Use one attribute name for header, title, name
# 4             Document levels of validation in vld_term()
# ...                                                   ...
# 200475                        Editing Navigator of  Wiki
# 200476                           Check if passwords match
# 200477  Add doc to samples/bluetooth/mesh & samples/bl...
# 200478                   Fix the photo in about dialog xd
# 200479  Move Record Video/Screenshot and camera select...
#
#                                                    labels  \
# 0       Difficulty: 1 Novice Effort: 1 Low Priority: 2...
# 1               [Block] Classic [Priority] Low [Type] Bug
# 2                        c.Enhancement f-CodeBlocks p.Low
# 3                                 a-AuthorUsability p.Low
# 4       Difficulty: 1 Novice Effort: 1 Low Priority: 2...
# ...                                                   ...
# 200475                                       Priority-Low
# 200476                           enhancement low priority
# 200477  area: Bluetooth area: Documentation area: Samp...
# 200478                           enhancement low priority
# 200479                           enhancement low priority
#
#                                                      body         class
# 0              As this is what other functions reference.  low_priority
# 1       Selecting a link in the classic block and havi...  low_priority
# 2       **Tell us about your environment**\r\n\r\n* **...  low_priority
# 3       May be better to choose one of the three and u...  low_priority
# 4              As this is what other functions reference.  low_priority
# ...                                                   ...           ...
# 200475  The navigator of the wiki should be edited and...  low_priority
# 200476  JavaScript code (or see if possible without) t...  low_priority
# 200477  We should document what exactly the sample is ...  low_priority
# 200478                                                NaN  low_priority
# 200479            that can be opened from a dropdown menu  low_priority
#
# [200480 rows x 10 columns]

# %%
all_data = pd.concat([high_priority, low_priority] , ignore_index= True)

# %%
all_data
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3       1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4       1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...              ...          ...                  ...
# 574268  2.060586e+10  IssuesEvent  2022-03-06 23:45:23
# 574269  7.334740e+09  IssuesEvent  2018-03-06 00:10:40
# 574270  7.334876e+09  IssuesEvent  2018-03-06 00:53:49
# 574271  7.335047e+09  IssuesEvent  2018-03-06 01:48:07
# 574272  7.335050e+09  IssuesEvent  2018-03-06 01:49:10
#
#                                        repo  \
# 0                 unitystation/unitystation
# 1       zowe/sample-spring-boot-api-service
# 2                        openmsupply/mobile
# 3       UltimateCodeMonkeys/CodeMonkeysMVVM
# 4        wordpress-mobile/WordPress-Android
# ...                                     ...
# 574268            bounswe/bounswe2022group1
# 574269                      hoodedice/notes
# 574270            zephyrproject-rtos/zephyr
# 574271                   uwnrg/minotaur-cpp
# 574272                   uwnrg/minotaur-cpp
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/unitystation/unit...  closed
# 1       https://api.github.com/repos/zowe/sample-sprin...  closed
# 2         https://api.github.com/repos/openmsupply/mobile  closed
# 3       https://api.github.com/repos/UltimateCodeMonke...  opened
# 4       https://api.github.com/repos/wordpress-mobile/...  closed
# ...                                                   ...     ...
# 574268  https://api.github.com/repos/bounswe/bounswe20...  closed
# 574269       https://api.github.com/repos/hoodedice/notes  opened
# 574270  https://api.github.com/repos/zephyrproject-rto...  closed
# 574271    https://api.github.com/repos/uwnrg/minotaur-cpp  closed
# 574272    https://api.github.com/repos/uwnrg/minotaur-cpp  closed
#
#                                                     title  \
# 0       Client breaking NRE when using edit field on C...
# 1       The SDK provides a separate Java (no-Spring) l...
# 2                      Auto-log out after some time frame
# 3       Migrate: CodeMonkeys ViewModelNavigationServic...
# 4       IA Reader filter bottom sheet: manage untitled...
# ...                                                   ...
# 574268                        Editing Navigator of  Wiki
# 574269                           Check if passwords match
# 574270  Add doc to samples/bluetooth/mesh & samples/bl...
# 574271                   Fix the photo in about dialog xd
# 574272  Move Record Video/Screenshot and camera select...
#
#                                                    labels  \
# 0                        Bug High Priority In Progress UI
# 1       Feature: API Security Priority: High no-issue-...
# 2       Docs: not needed Effort: small Feature Module:...
# 3       Priority: High Status: In Progress Type: Maint...
# 4                        IA Reader [Pri] High [Type] Task
# ...                                                   ...
# 574268                                       Priority-Low
# 574269                           enhancement low priority
# 574270  area: Bluetooth area: Documentation area: Samp...
# 574271                           enhancement low priority
# 574272                           enhancement low priority
#
#                                                      body          class
# 0       ### Bug:\r\n\r\nIf you use the edit field of t...  high_priority
# 1       - The commons-spring library is split into:\r\...  high_priority
# 2       ## Is your feature request related to a proble...  high_priority
# 3       Migrate the Xamarin.Forms navigation service i...  high_priority
# 4       In the filter bottom sheet we introduced in th...  high_priority
# ...                                                   ...            ...
# 574268  The navigator of the wiki should be edited and...   low_priority
# 574269  JavaScript code (or see if possible without) t...   low_priority
# 574270  We should document what exactly the sample is ...   low_priority
# 574271                                                NaN   low_priority
# 574272            that can be opened from a dropdown menu   low_priority
#
# [574273 rows x 10 columns]

# %%
all_data_no_dupes = all_data.drop_duplicates()
all_data_no_dupes
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3       1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4       1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...              ...          ...                  ...
# 574268  2.060586e+10  IssuesEvent  2022-03-06 23:45:23
# 574269  7.334740e+09  IssuesEvent  2018-03-06 00:10:40
# 574270  7.334876e+09  IssuesEvent  2018-03-06 00:53:49
# 574271  7.335047e+09  IssuesEvent  2018-03-06 01:48:07
# 574272  7.335050e+09  IssuesEvent  2018-03-06 01:49:10
#
#                                        repo  \
# 0                 unitystation/unitystation
# 1       zowe/sample-spring-boot-api-service
# 2                        openmsupply/mobile
# 3       UltimateCodeMonkeys/CodeMonkeysMVVM
# 4        wordpress-mobile/WordPress-Android
# ...                                     ...
# 574268            bounswe/bounswe2022group1
# 574269                      hoodedice/notes
# 574270            zephyrproject-rtos/zephyr
# 574271                   uwnrg/minotaur-cpp
# 574272                   uwnrg/minotaur-cpp
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/unitystation/unit...  closed
# 1       https://api.github.com/repos/zowe/sample-sprin...  closed
# 2         https://api.github.com/repos/openmsupply/mobile  closed
# 3       https://api.github.com/repos/UltimateCodeMonke...  opened
# 4       https://api.github.com/repos/wordpress-mobile/...  closed
# ...                                                   ...     ...
# 574268  https://api.github.com/repos/bounswe/bounswe20...  closed
# 574269       https://api.github.com/repos/hoodedice/notes  opened
# 574270  https://api.github.com/repos/zephyrproject-rto...  closed
# 574271    https://api.github.com/repos/uwnrg/minotaur-cpp  closed
# 574272    https://api.github.com/repos/uwnrg/minotaur-cpp  closed
#
#                                                     title  \
# 0       Client breaking NRE when using edit field on C...
# 1       The SDK provides a separate Java (no-Spring) l...
# 2                      Auto-log out after some time frame
# 3       Migrate: CodeMonkeys ViewModelNavigationServic...
# 4       IA Reader filter bottom sheet: manage untitled...
# ...                                                   ...
# 574268                        Editing Navigator of  Wiki
# 574269                           Check if passwords match
# 574270  Add doc to samples/bluetooth/mesh & samples/bl...
# 574271                   Fix the photo in about dialog xd
# 574272  Move Record Video/Screenshot and camera select...
#
#                                                    labels  \
# 0                        Bug High Priority In Progress UI
# 1       Feature: API Security Priority: High no-issue-...
# 2       Docs: not needed Effort: small Feature Module:...
# 3       Priority: High Status: In Progress Type: Maint...
# 4                        IA Reader [Pri] High [Type] Task
# ...                                                   ...
# 574268                                       Priority-Low
# 574269                           enhancement low priority
# 574270  area: Bluetooth area: Documentation area: Samp...
# 574271                           enhancement low priority
# 574272                           enhancement low priority
#
#                                                      body          class
# 0       ### Bug:\r\n\r\nIf you use the edit field of t...  high_priority
# 1       - The commons-spring library is split into:\r\...  high_priority
# 2       ## Is your feature request related to a proble...  high_priority
# 3       Migrate the Xamarin.Forms navigation service i...  high_priority
# 4       In the filter bottom sheet we introduced in th...  high_priority
# ...                                                   ...            ...
# 574268  The navigator of the wiki should be edited and...   low_priority
# 574269  JavaScript code (or see if possible without) t...   low_priority
# 574270  We should document what exactly the sample is ...   low_priority
# 574271                                                NaN   low_priority
# 574272            that can be opened from a dropdown menu   low_priority
#
# [574248 rows x 10 columns]

# %%
# Convert dataframe to a CSV file.
# all_data_no_dupes.to_csv("csv/full_dataset_priority_high_low.csv")

# %%
all_data_no_dupes[all_data_no_dupes["repo"] == "microsoft/vscode"]
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body, class]
# Index: []

# %%
all_data_no_dupes[all_data_no_dupes["repo"] == "python/mypy"]
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body, class]
# Index: []
