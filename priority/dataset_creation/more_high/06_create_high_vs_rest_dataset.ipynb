# %%
path_to_files = "/fp/projects01/ec307/ec-krimhau/github_datasets"
file_name = "clean_github_repos_with_priority_issues.csv"
full_path = f'{path_to_files}/{file_name}'

# %%
import pandas as pd

# Save the combined DataFrame to a new CSV file
df = pd.read_csv(f'{path_to_files}/{file_name}')
df
# Out:
#                                         repo  \
# 0                  unitystation/unitystation
# 1                paris-saclay-cds/ramp-board
# 2                         mikemaddem/BearCAD
# 3                            gatsbyjs/gatsby
# 4        zowe/sample-spring-boot-api-service
# ...                                      ...
# 7704701                 turnkeylinux/tracker
# 7704702                            gocd/gocd
# 7704703                          istio/istio
# 7704704                    kubeflow/kubeflow
# 7704705               Azure/azure-powershell
#
#                                                     labels         class  \
# 0                         Bug High Priority In Progress UI          high
# 1                                             bug frontend  non_priority
# 2                                        no-issue-activity  non_priority
# 3                             type: question or discussion  non_priority
# 4        Feature: API Security Priority: High no-issue-...          high
# ...                                                    ...           ...
# 7704701                              core feature security  non_priority
# 7704702                                  dashboard wontfix  non_priority
# 7704703                        area/policies and telemetry  non_priority
# 7704704                                          inference  non_priority
# 7704705                          Azure PS Team Investigate  non_priority
#
#                                                       text
# 0        client breaking nre when using edit field on c...
# 1        log for failed submissions no longer accessibl...
# 2        new documentation will happen once the project...
# 3        build and develop inconsistent styling please ...
# 4        the sdk provides a separate java nospring libr...
# ...                                                    ...
# 7704701  extend coverage to webmin webshell and other s...
# 7704702  dashboard api build cause material revision is...
# 7704703  istio dashboard does not currently display con...
# 7704704  tfserving component should add an ambassador r...
# 7704705  on machine with only azurerm after installing ...
#
# [7704706 rows x 4 columns]

# %%
df['class'].value_counts()
# Out:
# class
# non_priority    5907837
# high             581664
# low              322452
# in_triage        322172
# medium           260807
# critical         173979
# p2               113309
# p2_high           22486
# Name: count, dtype: int64

# %%
# Dropping duplicate issues. 
df = df.drop_duplicates(subset='text')
df
# Out:
#                                         repo  \
# 0                  unitystation/unitystation
# 1                paris-saclay-cds/ramp-board
# 2                         mikemaddem/BearCAD
# 3                            gatsbyjs/gatsby
# 4        zowe/sample-spring-boot-api-service
# ...                                      ...
# 7704698                kubernetes/kubernetes
# 7704699                        SETI/pds-opus
# 7704701                 turnkeylinux/tracker
# 7704704                    kubeflow/kubeflow
# 7704705               Azure/azure-powershell
#
#                                                     labels         class  \
# 0                         Bug High Priority In Progress UI          high
# 1                                             bug frontend  non_priority
# 2                                        no-issue-activity  non_priority
# 3                             type: question or discussion  non_priority
# 4        Feature: API Security Priority: High no-issue-...          high
# ...                                                    ...           ...
# 7704698                 area/kubeadm sig/cluster-lifecycle  non_priority
# 7704699                 Bug Effort-Easy Priority 3 Z-Debby  non_priority
# 7704701                              core feature security  non_priority
# 7704704                                          inference  non_priority
# 7704705                          Azure PS Team Investigate  non_priority
#
#                                                       text
# 0        client breaking nre when using edit field on c...
# 1        log for failed submissions no longer accessibl...
# 2        new documentation will happen once the project...
# 3        build and develop inconsistent styling please ...
# 4        the sdk provides a separate java nospring libr...
# ...                                                    ...
# 7704698  this might take a minute or longer hi people s...
# 7704699  in lists on main search page switch meaning ex...
# 7704701  extend coverage to webmin webshell and other s...
# 7704704  tfserving component should add an ambassador r...
# 7704705  on machine with only azurerm after installing ...
#
# [6061597 rows x 4 columns]

# %%
df['class'].value_counts()
# Out:
# class
# non_priority    4690735
# high             441600
# in_triage        259038
# low              246138
# medium           195347
# critical         123601
# p2                91723
# p2_high           13415
# Name: count, dtype: int64

# %%
bad_repos = ['AdguardTeam/AdguardFilters']
df = df[~df['repo'].isin(bad_repos)]
# Drop missing values from df
df.dropna(inplace=True)

# Reset the index of df
df.reset_index(drop=True, inplace=True)
df
# Out:
# /localscratch/489533/ipykernel_1653110/3309875012.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
#                                         repo  \
# 0                  unitystation/unitystation
# 1                paris-saclay-cds/ramp-board
# 2                         mikemaddem/BearCAD
# 3                            gatsbyjs/gatsby
# 4        zowe/sample-spring-boot-api-service
# ...                                      ...
# 5969582                kubernetes/kubernetes
# 5969583                        SETI/pds-opus
# 5969584                 turnkeylinux/tracker
# 5969585                    kubeflow/kubeflow
# 5969586               Azure/azure-powershell
#
#                                                     labels         class  \
# 0                         Bug High Priority In Progress UI          high
# 1                                             bug frontend  non_priority
# 2                                        no-issue-activity  non_priority
# 3                             type: question or discussion  non_priority
# 4        Feature: API Security Priority: High no-issue-...          high
# ...                                                    ...           ...
# 5969582                 area/kubeadm sig/cluster-lifecycle  non_priority
# 5969583                 Bug Effort-Easy Priority 3 Z-Debby  non_priority
# 5969584                              core feature security  non_priority
# 5969585                                          inference  non_priority
# 5969586                          Azure PS Team Investigate  non_priority
#
#                                                       text
# 0        client breaking nre when using edit field on c...
# 1        log for failed submissions no longer accessibl...
# 2        new documentation will happen once the project...
# 3        build and develop inconsistent styling please ...
# 4        the sdk provides a separate java nospring libr...
# ...                                                    ...
# 5969582  this might take a minute or longer hi people s...
# 5969583  in lists on main search page switch meaning ex...
# 5969584  extend coverage to webmin webshell and other s...
# 5969585  tfserving component should add an ambassador r...
# 5969586  on machine with only azurerm after installing ...
#
# [5969587 rows x 4 columns]

# %%
# p2
df.loc[df["class"] == "p2", 'labels'].value_counts().to_frame().head(50)
# Out:
#                                              count
# labels
# P2                                            4763
# bug P2                                        1884
# P2 bug                                        1286
# kind/bug priority/P2                           978
# priority: p2 type: bug                         955
# bug p2                                         891
# p2                                             842
# type: bug priority: p2                         809
# P2 enhancement                                 763
# enhancement P2                                 751
# enhancement p2                                 447
# kind/flake priority/P2                         420
# Bug P2                                         381
# kind/flake priority/P2 team/test-infra         347
# Priority: P2                                   269
# kind/bug priority/p2                           241
# kind/enhancement priority/P2                   224
# kind/bug lang/Python priority/P2               218
# bug_report P2                                  215
# feature request P2                             199
# priority: p2 type: feature request             190
# priority/P2                                    188
# feature p2                                     185
# feature P2                                     168
# P2 feature                                     168
# kind/bug severity/P2                           165
# P2 Source - Docs.ms                            156
# type: cleanup priority: p2                     146
# kind/bug lang/c++ priority/P2 untriaged        146
# type: feature request priority: p2             118
# p2p                                            117
# kind/bug lang/C# priority/P2                   107
# P2 Type: Enhancement                           104
# priority: p2                                   103
# type: bug priority: p2 flakybot: issue         101
# priority/p2                                     94
# Bug P2 Study builder                            93
# auto-migrated Priority-P2 Type-Bug              91
# api: storage priority: p2 type: bug             90
# Diagram Group2-2018                             90
# :rotating_light: priority: p2 type: bug         89
# 1 star Type-Sample imported priority: p2        85
# 2–5 stars Type-Sample imported priority: p2     82
# priority: p2 type: bug flakybot: issue          82
# kind/bug lang/core priority/P2 untriaged        81
# P2 enhancement NEW                              78
# P2: required                                    76
# priority: p2 type: cleanup                      74
# bug next-release p2                             71
# P2 - Low                                        71

# %%
# Critical value count
df.loc[df['class'] == 'critical', 'labels'].value_counts().to_frame().head(50)
# Out:
#                                                     count
# labels
# Severe Urgent                                        6471
# bug urgent                                           5736
# bug critical                                         4706
# critical                                             2687
# urgent                                               1753
# Critical                                             1304
# C-test-failure O-robot O-roachtest branch-maste...   1229
# C-test-failure O-roachtest O-robot branch-maste...    917
# browser-firefox engine-gecko priority-critical        886
# browser-firefox-mobile engine-gecko priority-cr...    845
# browser-fenix engine-gecko priority-critical          809
# bug Critical                                          804
# browser-firefox priority-critical engine-gecko        782
# Urgent                                                731
# critical enhancement                                  646
# browser-firefox-mobile priority-critical              601
# Priority: Critical                                    586
# enhancement urgent                                    573
# browser-firefox priority-critical                     550
# Priority: Critical Type: Bug                          533
# blocker bug                                           529
# Critical bug                                          505
# critical bug                                          495
# blocker                                               481
# Bug Critical                                          462
# priority-critical browser-fenix engine-gecko          405
# C-test-failure O-roachtest O-robot branch-relea...    373
# browser-focus-geckoview engine-gecko priority-c...    365
# bug Urgent                                            355
# URGENT                                                333
# CRITICAL                                              324
# type:critical                                         324
# C-test-failure O-robot O-roachtest branch-maste...    293
# kind/bug priority/critical-urgent                     228
# C-test-failure O-robot O-roachtest release-bloc...    223
# browser-fenix engine-gecko ml-needsdiagnosis-fa...    217
# Critical Fix Released                                 208
# Urgent bug                                            202
# browser-firefox-mobile priority-critical engine...    195
# C-test-failure O-roachtest O-robot branch-relea...    191
# priority-critical browser-focus-geckoview engin...    188
# bug URGENT                                            187
# bug blocker                                           186
# enhancement critical                                  182
# C-test-failure O-robot O-roachtest release-bloc...    177
# release-blocker                                       174
# bug CRITICAL                                          172
# C-test-failure O-robot O-roachtest branch-maste...    172
# Blocker                                               155
# Critical enhancement                                  147

# %%
# Top labels for each priority level
df.loc[df['class'] == 'high', 'labels'].value_counts().to_frame().head(50)
# Print all labels for high priority
#pd.set_option('display.max_rows', None)
#df.loc[df['class'] == 'High', 'labels'].value_counts().to_frame()
# Out:
#                                                     count
# labels
# bug high priority                                    7317
# high priority                                        6842
# P1                                                   6258
# High Priority                                        4861
# enhancement high priority                            3644
# Priority: High                                       3204
# important                                            2854
# type: bug priority: p1 flakybot: issue               2440
# bug important                                        2364
# autosynth failure priority: p1 type: bug             2313
# bug P1                                               1985
# P0                                                   1952
# P1 bug                                               1900
# bug priority: high                                   1697
# p1                                                   1619
# high-priority                                        1558
# bug high-priority                                    1531
# priority.High type.Story                             1496
# priority: high                                       1489
# buildcop: issue priority: p1 type: bug               1431
# enhancement important                                1344
# priority.High                                        1315
# type.Story priority.High                             1262
# bug High Priority                                    1261
# Priority: High Type: Bug                             1253
# priority.high type.story                             1181
# High priority                                        1118
# priority:high                                        1107
# priority.High type.Task                              1101
# bug p1                                               1072
# bug priority:high                                    1052
# flakybot: issue priority: p1 type: bug                933
# High Priority bug                                     921
# Important                                             862
# Priority: High bug                                    851
# enhancement P1                                        838
# priority: p1 type: bug flakybot: issue                831
# P1 enhancement                                        800
# type: bug priority: p1 nightly failure                768
# Bug High Priority                                     766
# enhancement priority: high                            749
# priority.high type.task                               745
# enhancement high-priority                             693
# priority.high                                         691
# browser-fenix engine-gecko priority-important         679
# priority-high                                         662
# lang/zh priority/P0 sync/update version/master ...    662
# bug P0                                                659
# bug priority-high                                     647
# enhancement priority:high                             645

# %%
# Medium
df.loc[df['class'] == 'medium', 'labels'].value_counts().to_frame().head(50)
# Out:
#                                                     count
# labels
# auto-migrated Priority-Medium Type-Defect            4173
# Medium Priority                                      2306
# Priority: Medium                                     2032
# bug priority: medium                                 1519
# bug imported Priority-Medium                         1418
# Priority/Normal Type/Bug                             1399
# medium priority                                      1302
# enhancement medium priority                          1208
# bug medium priority                                  1103
# priority: medium                                      951
# Priority: Medium Type: Bug                            893
# browser-firefox priority-normal                       879
# browser-fenix engine-gecko priority-normal            777
# Type/Bug Priority/Normal                              755
# priority.Medium type.Story                            749
# browser-firefox engine-gecko priority-normal          743
# Priority: Medium Type: Enhancement                    733
# priority.Medium                                       703
# browser-firefox-mobile priority-normal                688
# enhancement priority: medium                          667
# auto-migrated Priority-Medium Type-Enhancement        629
# browser-firefox-mobile engine-gecko priority-no...    622
# Priority-Medium Type-Defect                           601
# type.Story priority.Medium                            591
# C: MOOSE P: normal T: task                            580
# priority.medium type.story                            570
# C: Modules P: normal T: task                          498
# enhancement priority:medium                           481
# C: Functionality E: All Editions P: Medium T: E...    481
# browser-firefox priority-normal engine-gecko          480
# migrated Priority: Medium Type: Bug                   478
# bug prio-medium                                       473
# P: normal T: task                                     464
# normal                                                462
# priority:medium                                       427
# kind/bug area/docdb priority/medium                   413
# Category: metacat Component: Bugzilla-Id Priori...    412
# Medium priority                                       387
# priority.Medium type.Task                             382
# bug priority:medium                                   374
# C: Functionality P: Medium T: Enhancement             362
# browser-focus-geckoview engine-gecko priority-n...    351
# priority.medium                                       347
# enhancement prio-medium                               328
# Priority: Normal                                      320
# priority-normal browser-fenix engine-gecko            316
# bug Medium Priority                                   314
# Priority/Normal Type/Improvement                      310
# auto-migrated Priority-Medium Type-Sample             309
# bug:normal                                            298

# %%
# Low
df.loc[df['class'] == 'low', 'labels'].value_counts().to_frame().head(50)
# Out:
#                                                    count
# labels
# low priority                                        2513
# enhancement low priority                            2456
# P3                                                  2111
# Low Priority                                        1634
# Priority: Low                                       1619
# minor                                               1474
# bug low priority                                    1464
# bug minor                                           1376
# bug priority: low                                    864
# priority: low                                        748
# enhancement minor                                    668
# enhancement priority:low                             656
# enhancement priority: low                            627
# bug P3                                               574
# Priority: Low Type: Enhancement                      548
# enhancement low-priority                             518
# P3 bug                                               513
# low-priority                                         507
# priority:low                                         494
# enhancement P3                                       492
# Priority: Low Type: Bug                              452
# bug p3                                               443
# C-Bug P-Minor                                        438
# Coverity bug priority: low                           421
# type: question priority: p3                          404
# type: feature request priority: p3                   394
# enhancement Low Priority                             392
# bug priority:low                                     391
# enhancement p3                                       391
# Low priority                                         368
# auto-migrated Priority-Low Type-Defect               361
# Priority-Low Type-Enhancement                        357
# P3 enhancement                                       356
# enhancement priority-low                             351
# p3                                                   342
# priority.low type.story                              339
# Minor bug                                            339
# auto-migrated Priority-Low Type-Enhancement          338
# priority-low                                         323
# Low Priority enhancement                             321
# P3: Medium bug                                       320
# bug Low Priority                                     310
# request:new-pkg priority:low                         310
# Priority: Low Status: Available Type: Enhancement    293
# priority.Low type.Story                              286
# minor bug                                            282
# bug Minor                                            281
# bug low-priority                                     279
# feature low priority                                 272
# enhancement Priority: Low                            244

# %%
# non_priority
df.loc[df['class'] == 'non_priority', 'labels'].value_counts().to_frame().head(50)
# Out:
#                                count
# labels
# bug                           437084
# enhancement                   234406
# Bug                            64997
# question                       57010
# kind/bug                       45929
# feature                        29848
# stale                          24518
# documentation                  20910
# type: bug                      20591
# Type: Bug                      18125
# feature request                17118
# type/bug                       15801
# kind/feature                   14170
# Enhancement                    13986
# wontfix                        10460
# C-bug                          10429
# invalid                        10175
# duplicate                       9979
# help wanted                     9717
# kind/enhancement                9618
# needs more info                 9241
# feature-request                 8825
# type:bug                        7957
# Stale                           7458
# good first issue                7053
# in progress                     7014
# Feature                         6855
# task                            6662
# lifecycle/rotten                6526
# Question                        6336
# Type: Enhancement               6205
# type: enhancement               5805
# Feature Request                 5791
# discussion                      5765
# docs                            5758
# type/enhancement                5699
# C-bug O-sentry                  5536
# enhancement help wanted         5481
# kind/question                   5280
# template: bug                   5079
# improvement                     4919
# bug enhancement                 4779
# 🐞 bug                           4528
# Feature request                 4479
# enhancement good first issue    4458
# support                         4424
# new feature                     4242
# todo                            4176
# Epic                            4083
# Documentation                   4069

# %%
# in_triage
df.loc[df['class'] == 'in_triage', 'labels'].value_counts().to_frame().head(50)
# Out:
#                                                 count
# labels
# bug triage                                       8858
# triage                                           8232
# bug needs-triage                                 8027
# bug needs triage                                 7168
# in triage                                        6734
# status: needs triage                             6105
# needs-triage                                     5017
# kind/bug needs-triage                            4829
# needs triage                                     4614
# pending triage                                   4427
# Needs: Triage :mag:                              3795
# Bug Needs Triage                                 3365
# community triage                                 2935
# status: waiting-for-triage                       2886
# enhancement triage                               2595
# feature-request needs-triage                     2521
# kind/bug status/triage                           2306
# waiting for customer response in triage          2102
# Type: bugMinor Status: Triage                    1775
# in triage waiting for customer response          1666
# type: bug status: needs triage                   1615
# need/triage                                      1413
# triage/support                                   1282
# Needs Triage                                     1226
# needs:triage                                     1192
# browser-firefox status-needstriage               1126
# needs-triage bug                                 1100
# NeedsTriage                                      1094
# bug: pending triage                              1062
# enhancement needs triage                         1062
# 3.x pending triage                               1054
# 🐞 bug needs:triage                               1020
# requires triage                                  1005
# kind/bug needs-sig needs-triage                   996
# triage-needed                                     996
# >bug needs:triage                                 951
# Type:Bug .Needs Triage                            920
# kind/bug need/triage                              906
# guidance needs-triage                             905
# feature request needs triage                      899
# area/docdb status/awaiting-triage                 881
# i: bug i: needs triage                            871
# Needs-triage Type: Bug                            864
# type/bug needs-triage                             854
# site-bug triage                                   851
# Bug needs-triage                                  813
# kind/bug triage/untriaged difficulty/tbd          797
# kind/bug triage/accepted                          776
# type:bug status:requirements priority-5-triage    768
# .Needs Triage Type:Bug                            755

# %%
# Unique repo
df['repo'].nunique()
# Out:
# 56276

# %%
# Count of issues per repo
df['repo'].value_counts().to_frame()[:50]
# Out:
#                                             count
# repo
# webcompat/web-bugs                          57557
# microsoft/vscode                            46284
# cockroachdb/cockroach                       38353
# department-of-veterans-affairs/va.gov-team  37630
# flutter/flutter                             37466
# elastic/kibana                              35054
# Microsoft/vscode                            28250
# kubernetes/kubernetes                       27409
# rust-lang/rust                              21648
# mozilla-mobile/fenix                        19318
# brave/brave-browser                         18575
# dotnet/runtime                              18221
# Automattic/wp-calypso                       17728
# godotengine/godot                           17298
# dart-lang/sdk                               15396
# elastic/elasticsearch                       14910
# dotnet/roslyn                               13757
# WordPress/gutenberg                         13225
# ansible/ansible                             13090
# facebook/react-native                       12814
# magento/magento2                            12113
# CleverRaven/Cataclysm-DDA                   11974
# ballerina-platform/ballerina-lang           11885
# zephyrproject-rtos/zephyr                   11883
# pytorch/pytorch                             11877
# pingcap/tidb                                11871
# eclipse/che                                 11843
# sourcegraph/sourcegraph                     11446
# quarkusio/quarkus                           11152
# appsmithorg/appsmith                        11123
# grafana/grafana                             11075
# spring-projects/spring-boot                 10572
# dotnet/aspnetcore                           10075
# ray-project/ray                             10058
# pandas-dev/pandas                           10057
# aws/aws-cdk                                  9582
# StrangeLoopGames/EcoIssues                   9573
# airbytehq/airbyte                            9546
# istio/istio                                  9504
# saltstack/salt                               9474
# mantidproject/mantid                         9409
# yugabyte/yugabyte-db                         9147
# dbeaver/dbeaver                              9122
# qgis/QGIS                                    8849
# vercel/next.js                               8635
# metabase/metabase                            8336
# Thy-Vipe/BeastsOfBermuda-issues              8035
# ampproject/amphtml                           7815
# gatsbyjs/gatsby                              7541
# milvus-io/milvus                             7500

# %%
# Value count labels
df["labels"].value_counts().to_frame()[:50]
# Out:
#                           count
# labels
# bug                      437084
# enhancement              234406
# Bug                       64997
# question                  57010
# kind/bug                  45929
# feature                   29848
# stale                     24518
# documentation             20910
# type: bug                 20591
# Type: Bug                 18125
# feature request           17118
# type/bug                  15801
# kind/feature              14170
# Enhancement               13986
# wontfix                   10460
# C-bug                     10429
# invalid                   10175
# duplicate                  9979
# help wanted                9717
# kind/enhancement           9618
# needs more info            9241
# bug triage                 8858
# feature-request            8825
# triage                     8232
# bug needs-triage           8027
# type:bug                   7957
# Stale                      7458
# bug high priority          7317
# bug needs triage           7168
# good first issue           7053
# in progress                7014
# Feature                    6855
# high priority              6842
# in triage                  6734
# task                       6662
# lifecycle/rotten           6526
# Severe Urgent              6471
# Question                   6336
# P1                         6258
# Type: Enhancement          6205
# status: needs triage       6105
# type: enhancement          5805
# Feature Request            5791
# discussion                 5765
# docs                       5758
# bug urgent                 5736
# type/enhancement           5699
# C-bug O-sentry             5536
# enhancement help wanted    5481
# kind/question              5280

# %%
df.value_counts('class').to_frame()
# Out:
# The history saving thread hit an unexpected error (OperationalError('disk I/O error')).History will not be written to the database.
#                 count
# class
# non_priority  4652524
# high           426407
# in_triage      259038
# low            219141
# medium         195347
# critical       123288
# p2              91460
# p2_high          2382

# %%
df
# Out:
#                                         repo  \
# 0                  unitystation/unitystation
# 1                paris-saclay-cds/ramp-board
# 2                         mikemaddem/BearCAD
# 3                            gatsbyjs/gatsby
# 4        zowe/sample-spring-boot-api-service
# ...                                      ...
# 5969582                kubernetes/kubernetes
# 5969583                        SETI/pds-opus
# 5969584                 turnkeylinux/tracker
# 5969585                    kubeflow/kubeflow
# 5969586               Azure/azure-powershell
#
#                                                     labels         class  \
# 0                         Bug High Priority In Progress UI          high
# 1                                             bug frontend  non_priority
# 2                                        no-issue-activity  non_priority
# 3                             type: question or discussion  non_priority
# 4        Feature: API Security Priority: High no-issue-...          high
# ...                                                    ...           ...
# 5969582                 area/kubeadm sig/cluster-lifecycle  non_priority
# 5969583                 Bug Effort-Easy Priority 3 Z-Debby  non_priority
# 5969584                              core feature security  non_priority
# 5969585                                          inference  non_priority
# 5969586                          Azure PS Team Investigate  non_priority
#
#                                                       text
# 0        client breaking nre when using edit field on c...
# 1        log for failed submissions no longer accessibl...
# 2        new documentation will happen once the project...
# 3        build and develop inconsistent styling please ...
# 4        the sdk provides a separate java nospring libr...
# ...                                                    ...
# 5969582  this might take a minute or longer hi people s...
# 5969583  in lists on main search page switch meaning ex...
# 5969584  extend coverage to webmin webshell and other s...
# 5969585  tfserving component should add an ambassador r...
# 5969586  on machine with only azurerm after installing ...
#
# [5969587 rows x 4 columns]

# %%
high = df[df['class'] == 'high']
high
# Out:
#                                         repo  \
# 0                  unitystation/unitystation
# 4        zowe/sample-spring-boot-api-service
# 10                        openmsupply/mobile
# 15       UltimateCodeMonkeys/CodeMonkeysMVVM
# 31        wordpress-mobile/WordPress-Android
# ...                                      ...
# 5969492           StrangeLoopGames/EcoIssues
# 5969493           StrangeLoopGames/EcoIssues
# 5969515                        asteca/ASteCA
# 5969545                      xcat2/xcat-core
# 5969574                   runconduit/conduit
#
#                                                     labels class  \
# 0                         Bug High Priority In Progress UI  high
# 4        Feature: API Security Priority: High no-issue-...  high
# 10       Docs: not needed Effort: small Feature Module:...  high
# 15       Priority: High Status: In Progress Type: Maint...  high
# 31                        IA Reader [Pri] High [Type] Task  high
# ...                                                    ...   ...
# 5969492                                      High Priority  high
# 5969493                                      High Priority  high
# 5969515           code_enhance p:high performance synth-cl  high
# 5969545      priority:high sprint1 status:pending type:bug  high
# 5969574                                P0 proxy review web  high
#
#                                                       text
# 0        client breaking nre when using edit field on c...
# 4        the sdk provides a separate java nospring libr...
# 10       autolog out after some time frame is your feat...
# 15       migrate codemonkeys viewmodelnavigationservice...
# 31       ia reader filter bottom sheet manage untitled ...
# ...                                                    ...
# 5969492  user issue unable to set up contracts version ...
# 5969493  meteor hit can no longer join server just had ...
# 5969515  improve performance of synth cluster generatio...
# 5969545  error message improvement when adding users in...
# 5969574  control pod stats appear in web ui when proxy ...
#
# [426407 rows x 4 columns]

# %%
critical = df[df['class'] == 'critical']
critical
# Out:
#                                                       repo  \
# 114                                       appf-anu/tickets
# 117                                       appf-anu/tickets
# 136                                      AFTERWAKE/IRCBots
# 152      ConsumerDataStandardsAustralia/standards-maint...
# 184                                       appf-anu/tickets
# ...                                                    ...
# 5969122                       Sasha-hk/Appointment-website
# 5969213                            gather-community/gather
# 5969226                    GamerFlix/effective-transferral
# 5969245                                cs481-ekh/s22-beima
# 5969566                              three-plus-three/itsm
#
#                                                     labels     class  \
# 114                                               CRITICAL  critical
# 117                                               CRITICAL  critical
# 136                             !!!critical!!! enhancement  critical
# 152                         change request security urgent  critical
# 184                                               CRITICAL  critical
# ...                                                    ...       ...
# 5969122  bug documentation enhancement invalid wontfix ...  critical
# 5969213                   type:enhancement priority:urgent  critical
# 5969226                                   bug non-critical  critical
# 5969245                                        task URGENT  critical
# 5969566                                Blocker bug 【3.3.1】  critical
#
#                                                       text
# 114      temporal par difference temporal par differenc...
# 117      chamber deadman chamber deadman chamber deadma...
# 136                               new magic conch response
# 152      removal of requirement for cdr ca certificate ...
# 184      spc camera numfilescreated spc camera numfiles...
# ...                                                    ...
# 5969122  master schedule without timezone task descript...
# 5969213  ability to change child to adult cant do this ...
# 5969226  opening effect configuration of effects embedd...
# 5969245                   add photosfiles to device schema
# 5969566            安装新版本后、菜单栏中点击“服务管理” 安装新版本后、菜单栏中点击“服务管理”
#
# [123288 rows x 4 columns]

# %%
p2_high = df[df['class'] == 'p2_high']
p2_high
# Out:
#                                         repo  \
# 1446               AdguardTeam/AdguardForiOS
# 12342                              ONRR/nrrd
# 18417    AdguardTeam/AdguardBrowserExtension
# 18754                          owncloud/core
# 23694                           owncloud/web
# ...                                      ...
# 5952334                         owncloud/ios
# 5961667  AdguardTeam/AdguardBrowserExtension
# 5963406                            ONRR/nrrd
# 5964869                    etlegacy/etlegacy
# 5964936                    etlegacy/etlegacy
#
#                                                labels    class  \
# 1446                                     Bug P2: High  p2_high
# 12342                                        P2: High  p2_high
# 18417                            Bug Firefox P2: High  p2_high
# 18754                                     bug p2-high  p2_high
# 23694                       Type:Bug Priority:p2-high  p2_high
# ...                                               ...      ...
# 5952334  Enhancement blue-ticket iOS 11 image p2-high  p2_high
# 5961667                                  Bug P2: High  p2_high
# 5963406                     Explore Data P2: High bug  p2_high
# 5964869               Feature P2: High cat: mod CGAME  p2_high
# 5964936                      P2: High Task cat: other  p2_high
#
#                                                       text
# 1446     encrypted dns poor connectivity causing timeou...
# 12342    year slide bar disappears when using links wit...
# 18417    html filtering rule does not work on exampleor...
# 18754    themeservice cant handle themes in separate ap...
# 23694    paste here button breaks into next line steps ...
# ...                                                    ...
# 5952334  can‘t display heic images heic shot with ios b...
# 5961667  stealth mode settings shouldnt be applied in t...
# 5963406  explore data nationwide summary onshore royalt...
# 5964869  rework explosion and particles effects particl...
# 5964936  provide snapshot builds for public testing at ...
#
# [2382 rows x 4 columns]

# %%
low = df[df['class'] == 'low']
low
# Out:
#                                                 repo  \
# 8                             poissonconsulting/term
# 12                       BBj-Plugins/BBjGridExWidget
# 72                               WordPress/gutenberg
# 115                                MarkBind/markbind
# 134                                MarkBind/markbind
# ...                                              ...
# 5969349                        vector-im/element-web
# 5969354  CafeteriaGuild/DeepMobLearning-Refabricated
# 5969363                    bounswe/bounswe2022group1
# 5969470     silverstripe/silverstripe-fulltextsearch
# 5969473                    zephyrproject-rtos/zephyr
#
#                                                     labels class  \
# 8        Difficulty: 1 Novice Effort: 1 Low Priority: 2...   low
# 12       Area: Documentations Change: Minor Type:  Enha...   low
# 72               [Block] Classic [Priority] Low [Type] Bug   low
# 115                       c.Enhancement f-CodeBlocks p.Low   low
# 134                                a-AuthorUsability p.Low   low
# ...                                                    ...   ...
# 5969349  T-Defect S-Minor X-Needs-Design O-Frequent A-T...   low
# 5969354                           enhancement Low Priority   low
# 5969363                                       Priority-Low   low
# 5969470  affects/v3 affects/v4 change/minor effort/hard...   low
# 5969473  area: Bluetooth area: Documentation area: Samp...   low
#
#                                                       text
# 8        document levels of validation in vldterm as th...
# 12       extend the public plugin description describe ...
# 72       zindex issue using classic block selecting a l...
# 115      indicate the language of a code block tell us ...
# 134      use one attribute name for header title name m...
# ...                                                    ...
# 5969349  thread list lacks a loading state steps to rep...
# 5969354  thunderstrike during trials destroying the loo...
# 5969363  editing navigator of wiki the navigator of the...
# 5969470  solr searching fails when not searching versio...
# 5969473  add doc to samplesbluetoothmesh samplesbluetoo...
#
# [219141 rows x 4 columns]

# %%
medium = df[df['class'] == 'medium']
medium
# Out:
#                                repo  \
# 147       ericauv/ericauv-portfolio
# 206              openmsupply/mobile
# 209              openmsupply/mobile
# 241         poissonconsulting/nlist
# 325                  BLUDRAG/SOFlow
# ...                             ...
# 5969195           lynnntropy/shinoa
# 5969263     Gilded-Games/The-Aether
# 5969275   bounswe/bounswe2022group4
# 5969327   bounswe/bounswe2022group4
# 5969543  StrangeLoopGames/EcoIssues
#
#                                                     labels   class  \
# 147                                        Medium Priority  medium
# 206      Docs: not needed Effort: small Feature Module:...  medium
# 209      Effort: medium Feature Module: indicators Prio...  medium
# 241      Difficulty: 2 Intermediate Effort: 2 Medium Pr...  medium
# 325                            enhancement medium priority  medium
# ...                                                    ...     ...
# 5969195                        enhancement priority:medium  medium
# 5969263  priority/medium status/pending-review type/ann...  medium
# 5969275                 Priority - Medium whom: individual  medium
# 5969327  Category - Documentation Priority - Medium who...  medium
# 5969543                                    Medium Priority  medium
#
#                                                       text
# 147      increase indent of listitem listitems should h...
# 206      add cash register page toggle is your feature ...
# 209      enforce indicator types is your feature reques...
# 241      add asmcmc and asmcmclist wrappers on asmcmc a...
# 325      create new option for dropdown scriptable obje...
# ...                                                    ...
# 5969195  optionally silence joinleave messages until th...
# 5969263  refactor remove skyroot bed explosiveness in t...
# 5969275  create a personal page for yourself create a p...
# 5969327  make meeting notes for the first meeting avail...
# 5969543  pay command does not work with point values tr...
#
# [195347 rows x 4 columns]

# %%
non_priority = df[df['class'] == 'non_priority']
non_priority
# Out:
#                                       repo  \
# 1              paris-saclay-cds/ramp-board
# 2                       mikemaddem/BearCAD
# 3                          gatsbyjs/gatsby
# 5        react-navigation/react-navigation
# 6                          rust-lang/cargo
# ...                                    ...
# 5969582              kubernetes/kubernetes
# 5969583                      SETI/pds-opus
# 5969584               turnkeylinux/tracker
# 5969585                  kubeflow/kubeflow
# 5969586             Azure/azure-powershell
#
#                                      labels         class  \
# 1                              bug frontend  non_priority
# 2                         no-issue-activity  non_priority
# 3              type: question or discussion  non_priority
# 5                                     Stale  non_priority
# 6                         C-feature-request  non_priority
# ...                                     ...           ...
# 5969582  area/kubeadm sig/cluster-lifecycle  non_priority
# 5969583  Bug Effort-Easy Priority 3 Z-Debby  non_priority
# 5969584               core feature security  non_priority
# 5969585                           inference  non_priority
# 5969586           Azure PS Team Investigate  non_priority
#
#                                                       text
# 1        log for failed submissions no longer accessibl...
# 2        new documentation will happen once the project...
# 3        build and develop inconsistent styling please ...
# 5        how to let the creatematerialtoptabnavigator c...
# 6        provide targetcpu and targetfeatures to builds...
# ...                                                    ...
# 5969582  this might take a minute or longer hi people s...
# 5969583  in lists on main search page switch meaning ex...
# 5969584  extend coverage to webmin webshell and other s...
# 5969585  tfserving component should add an ambassador r...
# 5969586  on machine with only azurerm after installing ...
#
# [4652524 rows x 4 columns]

# %%
high_priority = pd.concat([critical, high, p2_high], ignore_index=True)
high_priority
# Out:
#                                                      repo  \
# 0                                        appf-anu/tickets
# 1                                        appf-anu/tickets
# 2                                       AFTERWAKE/IRCBots
# 3       ConsumerDataStandardsAustralia/standards-maint...
# 4                                        appf-anu/tickets
# ...                                                   ...
# 552072                                       owncloud/ios
# 552073                AdguardTeam/AdguardBrowserExtension
# 552074                                          ONRR/nrrd
# 552075                                  etlegacy/etlegacy
# 552076                                  etlegacy/etlegacy
#
#                                               labels     class  \
# 0                                           CRITICAL  critical
# 1                                           CRITICAL  critical
# 2                         !!!critical!!! enhancement  critical
# 3                     change request security urgent  critical
# 4                                           CRITICAL  critical
# ...                                              ...       ...
# 552072  Enhancement blue-ticket iOS 11 image p2-high   p2_high
# 552073                                  Bug P2: High   p2_high
# 552074                     Explore Data P2: High bug   p2_high
# 552075               Feature P2: High cat: mod CGAME   p2_high
# 552076                      P2: High Task cat: other   p2_high
#
#                                                      text
# 0       temporal par difference temporal par differenc...
# 1       chamber deadman chamber deadman chamber deadma...
# 2                                new magic conch response
# 3       removal of requirement for cdr ca certificate ...
# 4       spc camera numfilescreated spc camera numfiles...
# ...                                                   ...
# 552072  can‘t display heic images heic shot with ios b...
# 552073  stealth mode settings shouldnt be applied in t...
# 552074  explore data nationwide summary onshore royalt...
# 552075  rework explosion and particles effects particl...
# 552076  provide snapshot builds for public testing at ...
#
# [552077 rows x 4 columns]

# %%
rest = pd.concat([non_priority, low, medium], ignore_index=True)
rest
# Out:
#                                       repo  \
# 0              paris-saclay-cds/ramp-board
# 1                       mikemaddem/BearCAD
# 2                          gatsbyjs/gatsby
# 3        react-navigation/react-navigation
# 4                          rust-lang/cargo
# ...                                    ...
# 5067007                  lynnntropy/shinoa
# 5067008            Gilded-Games/The-Aether
# 5067009          bounswe/bounswe2022group4
# 5067010          bounswe/bounswe2022group4
# 5067011         StrangeLoopGames/EcoIssues
#
#                                                     labels         class  \
# 0                                             bug frontend  non_priority
# 1                                        no-issue-activity  non_priority
# 2                             type: question or discussion  non_priority
# 3                                                    Stale  non_priority
# 4                                        C-feature-request  non_priority
# ...                                                    ...           ...
# 5067007                        enhancement priority:medium        medium
# 5067008  priority/medium status/pending-review type/ann...        medium
# 5067009                 Priority - Medium whom: individual        medium
# 5067010  Category - Documentation Priority - Medium who...        medium
# 5067011                                    Medium Priority        medium
#
#                                                       text
# 0        log for failed submissions no longer accessibl...
# 1        new documentation will happen once the project...
# 2        build and develop inconsistent styling please ...
# 3        how to let the creatematerialtoptabnavigator c...
# 4        provide targetcpu and targetfeatures to builds...
# ...                                                    ...
# 5067007  optionally silence joinleave messages until th...
# 5067008  refactor remove skyroot bed explosiveness in t...
# 5067009  create a personal page for yourself create a p...
# 5067010  make meeting notes for the first meeting avail...
# 5067011  pay command does not work with point values tr...
#
# [5067012 rows x 4 columns]
