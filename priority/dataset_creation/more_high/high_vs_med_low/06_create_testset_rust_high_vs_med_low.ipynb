# %%
path_to_files = "/fp/projects01/ec307/ec-krimhau/github_datasets"
file_name = "clean_github_repos_with_priority_issues.csv"
full_path = f'{path_to_files}/{file_name}'

# %%
import pandas as pd

# Save the combined DataFrame to a new CSV file
df = pd.read_csv(f'{path_to_files}/{file_name}')
df
# Out:
#                                         repo  \
# 0                  unitystation/unitystation
# 1                paris-saclay-cds/ramp-board
# 2                         mikemaddem/BearCAD
# 3                            gatsbyjs/gatsby
# 4        zowe/sample-spring-boot-api-service
# ...                                      ...
# 7704701                 turnkeylinux/tracker
# 7704702                            gocd/gocd
# 7704703                          istio/istio
# 7704704                    kubeflow/kubeflow
# 7704705               Azure/azure-powershell
#
#                                                     labels         class  \
# 0                         Bug High Priority In Progress UI          high
# 1                                             bug frontend  non_priority
# 2                                        no-issue-activity  non_priority
# 3                             type: question or discussion  non_priority
# 4        Feature: API Security Priority: High no-issue-...          high
# ...                                                    ...           ...
# 7704701                              core feature security  non_priority
# 7704702                                  dashboard wontfix  non_priority
# 7704703                        area/policies and telemetry  non_priority
# 7704704                                          inference  non_priority
# 7704705                          Azure PS Team Investigate  non_priority
#
#                                                       text
# 0        client breaking nre when using edit field on c...
# 1        log for failed submissions no longer accessibl...
# 2        new documentation will happen once the project...
# 3        build and develop inconsistent styling please ...
# 4        the sdk provides a separate java nospring libr...
# ...                                                    ...
# 7704701  extend coverage to webmin webshell and other s...
# 7704702  dashboard api build cause material revision is...
# 7704703  istio dashboard does not currently display con...
# 7704704  tfserving component should add an ambassador r...
# 7704705  on machine with only azurerm after installing ...
#
# [7704706 rows x 4 columns]

# %%
df['class'].value_counts()
# Out:
# class
# non_priority    5907837
# high             581664
# low              322452
# in_triage        322172
# medium           260807
# critical         173979
# p2               113309
# p2_high           22486
# Name: count, dtype: int64

# %%
# Dropping duplicate issues. 
df = df.drop_duplicates(subset='text')
df
# Out:
#                                         repo  \
# 0                  unitystation/unitystation
# 1                paris-saclay-cds/ramp-board
# 2                         mikemaddem/BearCAD
# 3                            gatsbyjs/gatsby
# 4        zowe/sample-spring-boot-api-service
# ...                                      ...
# 7704698                kubernetes/kubernetes
# 7704699                        SETI/pds-opus
# 7704701                 turnkeylinux/tracker
# 7704704                    kubeflow/kubeflow
# 7704705               Azure/azure-powershell
#
#                                                     labels         class  \
# 0                         Bug High Priority In Progress UI          high
# 1                                             bug frontend  non_priority
# 2                                        no-issue-activity  non_priority
# 3                             type: question or discussion  non_priority
# 4        Feature: API Security Priority: High no-issue-...          high
# ...                                                    ...           ...
# 7704698                 area/kubeadm sig/cluster-lifecycle  non_priority
# 7704699                 Bug Effort-Easy Priority 3 Z-Debby  non_priority
# 7704701                              core feature security  non_priority
# 7704704                                          inference  non_priority
# 7704705                          Azure PS Team Investigate  non_priority
#
#                                                       text
# 0        client breaking nre when using edit field on c...
# 1        log for failed submissions no longer accessibl...
# 2        new documentation will happen once the project...
# 3        build and develop inconsistent styling please ...
# 4        the sdk provides a separate java nospring libr...
# ...                                                    ...
# 7704698  this might take a minute or longer hi people s...
# 7704699  in lists on main search page switch meaning ex...
# 7704701  extend coverage to webmin webshell and other s...
# 7704704  tfserving component should add an ambassador r...
# 7704705  on machine with only azurerm after installing ...
#
# [6061597 rows x 4 columns]

# %%
df['class'].value_counts()
# Out:
# class
# non_priority    4690735
# high             441600
# in_triage        259038
# low              246138
# medium           195347
# critical         123601
# p2                91723
# p2_high           13415
# Name: count, dtype: int64

# %%
# Bad repos with many bot issues 
bad_repos = ['AdguardTeam/AdguardFilters', 'webcompat/web-bugs', 'Predatoria/BeastsOfBermuda', 'Thy-Vipe/BeastsOfBermuda-issues' 'tomhughes/trac-tickets', 'k8smeetup/website-tasks', 'steedos/steedos-platform', 'msupply-foundation/mobile', 'StrangeLoopGames/EcoIssues']
# Test sets 
test_sets = ['flutter/flutter', 'rust-lang/rust', 'python/mypy']
remove_repos = bad_repos + test_sets
df = df[~df['repo'].isin(remove_repos)]
# Drop missing values from df
df.dropna(inplace=True)

# Reset the index of df
df.reset_index(drop=True, inplace=True)
df
# Out:
# /localscratch/490809/ipykernel_1899641/2873826402.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
#                                         repo  \
# 0                  unitystation/unitystation
# 1                paris-saclay-cds/ramp-board
# 2                         mikemaddem/BearCAD
# 3                            gatsbyjs/gatsby
# 4        zowe/sample-spring-boot-api-service
# ...                                      ...
# 5839749                kubernetes/kubernetes
# 5839750                        SETI/pds-opus
# 5839751                 turnkeylinux/tracker
# 5839752                    kubeflow/kubeflow
# 5839753               Azure/azure-powershell
#
#                                                     labels         class  \
# 0                         Bug High Priority In Progress UI          high
# 1                                             bug frontend  non_priority
# 2                                        no-issue-activity  non_priority
# 3                             type: question or discussion  non_priority
# 4        Feature: API Security Priority: High no-issue-...          high
# ...                                                    ...           ...
# 5839749                 area/kubeadm sig/cluster-lifecycle  non_priority
# 5839750                 Bug Effort-Easy Priority 3 Z-Debby  non_priority
# 5839751                              core feature security  non_priority
# 5839752                                          inference  non_priority
# 5839753                          Azure PS Team Investigate  non_priority
#
#                                                       text
# 0        client breaking nre when using edit field on c...
# 1        log for failed submissions no longer accessibl...
# 2        new documentation will happen once the project...
# 3        build and develop inconsistent styling please ...
# 4        the sdk provides a separate java nospring libr...
# ...                                                    ...
# 5839749  this might take a minute or longer hi people s...
# 5839750  in lists on main search page switch meaning ex...
# 5839751  extend coverage to webmin webshell and other s...
# 5839752  tfserving component should add an ambassador r...
# 5839753  on machine with only azurerm after installing ...
#
# [5839754 rows x 4 columns]

# %%
# Check if any value in the 'repo' column is in the bad_repos list
contains_bad_repo = df['repo'].isin(bad_repos).any()
if contains_bad_repo == False:
    print(f"all repos removed. contains_bad_repo: {contains_bad_repo}")
else: 
    print("something went wrong when removing repos")
    contains_bad_repo
# Out:
# all repos removed. contains_bad_repo: False

# %%
# Count of issues per repo
repo_names = df['repo'].value_counts().to_frame()[:50].index.to_numpy()
print(repo_names)
df['repo'].value_counts().to_frame()[:50]
# Out:
# ['microsoft/vscode' 'cockroachdb/cockroach'
#  'department-of-veterans-affairs/va.gov-team' 'elastic/kibana'
#  'Microsoft/vscode' 'kubernetes/kubernetes' 'mozilla-mobile/fenix'
#  'brave/brave-browser' 'dotnet/runtime' 'Automattic/wp-calypso'
#  'godotengine/godot' 'dart-lang/sdk' 'elastic/elasticsearch'
#  'dotnet/roslyn' 'WordPress/gutenberg' 'ansible/ansible'
#  'facebook/react-native' 'magento/magento2' 'CleverRaven/Cataclysm-DDA'
#  'ballerina-platform/ballerina-lang' 'zephyrproject-rtos/zephyr'
#  'pytorch/pytorch' 'pingcap/tidb' 'eclipse/che' 'sourcegraph/sourcegraph'
#  'quarkusio/quarkus' 'appsmithorg/appsmith' 'grafana/grafana'
#  'spring-projects/spring-boot' 'dotnet/aspnetcore' 'ray-project/ray'
#  'pandas-dev/pandas' 'aws/aws-cdk' 'airbytehq/airbyte' 'istio/istio'
#  'saltstack/salt' 'mantidproject/mantid' 'yugabyte/yugabyte-db'
#  'dbeaver/dbeaver' 'qgis/QGIS' 'vercel/next.js' 'metabase/metabase'
#  'Thy-Vipe/BeastsOfBermuda-issues' 'ampproject/amphtml' 'gatsbyjs/gatsby'
#  'milvus-io/milvus' 'expo/expo' 'PrestaShop/PrestaShop'
#  'tgstation/tgstation' 'Azure/azure-cli']
#                                             count
# repo
# microsoft/vscode                            46284
# cockroachdb/cockroach                       38353
# department-of-veterans-affairs/va.gov-team  37630
# elastic/kibana                              35054
# Microsoft/vscode                            28250
# kubernetes/kubernetes                       27409
# mozilla-mobile/fenix                        19318
# brave/brave-browser                         18575
# dotnet/runtime                              18221
# Automattic/wp-calypso                       17728
# godotengine/godot                           17298
# dart-lang/sdk                               15396
# elastic/elasticsearch                       14910
# dotnet/roslyn                               13757
# WordPress/gutenberg                         13225
# ansible/ansible                             13090
# facebook/react-native                       12814
# magento/magento2                            12113
# CleverRaven/Cataclysm-DDA                   11974
# ballerina-platform/ballerina-lang           11885
# zephyrproject-rtos/zephyr                   11883
# pytorch/pytorch                             11877
# pingcap/tidb                                11871
# eclipse/che                                 11843
# sourcegraph/sourcegraph                     11446
# quarkusio/quarkus                           11152
# appsmithorg/appsmith                        11123
# grafana/grafana                             11075
# spring-projects/spring-boot                 10572
# dotnet/aspnetcore                           10075
# ray-project/ray                             10058
# pandas-dev/pandas                           10057
# aws/aws-cdk                                  9582
# airbytehq/airbyte                            9546
# istio/istio                                  9504
# saltstack/salt                               9474
# mantidproject/mantid                         9409
# yugabyte/yugabyte-db                         9147
# dbeaver/dbeaver                              9122
# qgis/QGIS                                    8849
# vercel/next.js                               8635
# metabase/metabase                            8336
# Thy-Vipe/BeastsOfBermuda-issues              8035
# ampproject/amphtml                           7815
# gatsbyjs/gatsby                              7541
# milvus-io/milvus                             7500
# expo/expo                                    7477
# PrestaShop/PrestaShop                        7476
# tgstation/tgstation                          7456
# Azure/azure-cli                              7443

# %%
# repos with most high priority labels.
high_priority_repos = df[df['class'] == 'high']['repo'].value_counts().to_frame()[:50]
high_priority_repos_only = df[df['class'] == 'high']['repo'].value_counts().nlargest(50).index.to_list()
print(high_priority_repos_only)
# Out:
# ['kubernetes/kubernetes', 'tomhughes/trac-tickets', 'ray-project/ray', 'eclipse/che', 'google/site-kit-wp', 'ballerina-platform/ballerina-lang', 'GoogleCloudPlatform/python-docs-samples', 'pytorch/pytorch', '4GeeksAcademy/About-4Geeks-Academy', 'ahmedkaludi/accelerated-mobile-pages', 'aws/aws-cdk', 'bazelbuild/bazel', 'wso2/product-is', 'Automattic/wp-calypso', 'dart-lang/sdk', 'musescore/MuseScore', 'googleapis/elixir-google-api', 'jenkins-x/jx', 'mozilla-mobile/fenix', 'craftercms/craftercms', 'o3de/o3de', 'geosolutions-it/MapStore2', 'openshift/origin', 'googleapis/google-cloud-ruby', 'zulip/zulip', 'yugabyte/yugabyte-db', 'learningequality/kolibri', 'GoogleCloudPlatform/fda-mystudies', 'kubernetes/minikube', 'vector-im/riot-web', 'ampproject/amphtml', 'mantidproject/mantid', 'javaee/glassfish', 'googleapis/google-cloud-go', 'Microsoft/vscode', 'ArctosDB/arctos', 'eclipse-ee4j/glassfish', 'dotnet/docs', 'open-metadata/OpenMetadata', 'minishift/minishift', 'tine20/Tine-2.0-Open-Source-Groupware-and-CRM', 'ahmedkaludi/schema-and-structured-data-for-wp', 'kubeflow/kubeflow', 'NOAA-PMEL/Ferret', 'googlefonts/fontbakery', 'openmsupply/mobile', 'matrixorigin/matrixone', 'dotnet/AspNetCore.Docs', 'ita-social-projects/GreenCity', 'wso2/product-apim']

# %%
# Extract all issues from the top 50 repositories, regardless of their class
df= df[df['repo'].isin(high_priority_repos_only)]
df
# Out:
#                           repo  \
# 9           openmsupply/mobile
# 82                 dotnet/docs
# 155         openmsupply/mobile
# 156         openmsupply/mobile
# 182      kubernetes/kubernetes
# ...                        ...
# 5839690  kubernetes/kubernetes
# 5839700       Microsoft/vscode
# 5839740       Microsoft/vscode
# 5839749  kubernetes/kubernetes
# 5839752      kubeflow/kubeflow
#
#                                                     labels         class  \
# 9        Docs: not needed Effort: small Feature Module:...          high
# 82                 :books: Area - F# Guide doc-enhancement  non_priority
# 155                                                Feature  non_priority
# 156      Docs: needed Epic Feature Module: dispensary P...          high
# 182                      kind/bug lifecycle/rotten sig/cli  non_priority
# ...                                                    ...           ...
# 5839690         area/api kind/feature sig/apps sig/windows  non_priority
# 5839700                                api needs more info  non_priority
# 5839740                                         javascript  non_priority
# 5839749                 area/kubeadm sig/cluster-lifecycle  non_priority
# 5839752                                          inference  non_priority
#
#                                                       text
# 9        autolog out after some time frame is your feat...
# 82       tidying up evaluation results versus the expre...
# 155      update cash register to use new payment option...
# 156      cash register is your feature request related ...
# 182      cannot expose long array of ports because of c...
# ...                                                    ...
# 5839690  environment variables containing colon not all...
# 5839700  extension api suggestion ability to control se...
# 5839740  code navigation broken when using modules in i...
# 5839749  this might take a minute or longer hi people s...
# 5839752  tfserving component should add an ambassador r...
#
# [295865 rows x 4 columns]

# %%
df['class'].value_counts()
# Out:
# class
# non_priority    176226
# high             47883
# in_triage        28638
# p2               16196
# low              12103
# medium            9212
# critical          5607
# Name: count, dtype: int64

# %%
# p2
df.loc[df["class"] == "p2", 'labels'].value_counts().to_frame().head(50)
# Out:
#                                                     count
# labels
# P2                                                    594
# kind/flake priority/P2                                420
# kind/flake priority/P2 team/test-infra                347
# kind/bug severity/P2                                  142
# P2 Type: Enhancement                                   96
# Bug P2 Study builder                                   93
# component/web kind/bug priority/P2                     65
# area-analyzer p2-medium type-bug                       61
# kind/bug severity/P2 team/ide                          61
# area-analyzer P2 medium Type: bug                      56
# P2 enhancement                                         56
# Bug P2 Process: Fixed Process: Tested QA Proces...     53
# Category: Presentation P2: Soon Type: Bug              53
# P2: Soon Type: Feature Request WG: stories             52
# kind/test-flake priority/P2                            51
# Category: AMP Story P2: Soon Type: Bug                 47
# component/cli kind/bug priority/P2                     47
# Bug P2 Participant manager                             47
# P2: Soon Type: Bug WG: stories                         45
# P2 medium Type: bug area-analyzer                      45
# P2 type: process team-OSS mirror request               44
# Category: Ads P2: Soon Type: Bug                       43
# P2 bug                                                 42
# bug P2                                                 41
# area/tests kind/test-flake priority/P2                 41
# enhancement P2                                         39
# Bug P2 Participant manager Process: Fixed Proce...     38
# priority/P2                                            37
# Blazor P2 Source - Docs.ms doc-enhancement             36
# component/build kind/bug priority/P2                   35
# component/cli priority/P2                              34
# P2 medium Type: bug area-dart2js                       34
# P2 medium Resolution: assumed stale Type: bug a...     30
# Bug P2 Study builder Process: Fixed Process: Te...     30
# P2 Source - Docs.ms doc-enhancement                    29
# priority: p2 remove-gcp-devrel-py-tools type: p...     29
# triage me priority: p2 type: bug                       28
# type: bug priority: p2                                 28
# type: bug P2 team-Remote-Exec                          28
# P2 eng:performance                                     27
# P2 bug rllib                                           27
# component/build kind/enhancement priority/P2           27
# Category: Dynamic/Personalized Content P2: Soon...     27
# type: bug P2 team-ExternalDeps stale                   27
# area/tests priority/P2                                 26
# kind/bug lifecycle/stale severity/P2 team/ide2         26
# P2 engraving                                           25
# component/build priority/P2                            25
# Category: Presentation P2: Soon Type: Feature R...     25
# P2 community                                           25

# %%
# Critical value count
# Maybe remove the blocker since it is not always about priority.
df.loc[df['class'] == 'critical', 'labels'].value_counts().to_frame().head(50)
# Out:
#                                                     count
# labels
# Priority-Critical (Arctos is broken) Arctos Down       58
# Severity/Critical                                      54
# bug blocker                                            54
# Priority/Blocker Team/CompilerFE Type/Bug              50
# blocker                                                43
# kind/bug severity/blocker                              42
# Priority-Critical                                      35
# Area/Language Priority/Blocker Type/Bug                35
# Priority: Blocker bug                                  35
# bug P: highest S: blocker                              33
# bug P: highest S: critical                             29
# Type/Bug Priority/Blocker Team/CompilerFE              26
# bug Priority: Blocker                                  25
# release-blocker                                        25
# kind/bug priority/critical                             24
# Priority/Highest Severity/Critical Type/Bug            24
# Component: potlatch (flash editor) Priority: cr...     22
# Component: merkaartor Priority: critical Resolu...     21
# Priority/Blocker Type/Bug                              21
# kind/bug sig/graphics-audio priority/critical          21
# bug release-blocker                                    21
# Priority/Highest Severity/Critical bug                 19
# Area/Language Component/Compiler Priority/Block...     19
# Type/Bug Priority/Blocker                              18
# Area/Language Component/Parser Priority/Blocker...     18
# Area/BuildTools Priority/Blocker Type/Bug              18
# Priority/Highest Severity/Blocker Type/Bug             16
# Release Blocker eng:qa:verified 🐞 bug                  16
# Bug Felamimail Mantis urgent                           16
# bug GFDL: urgent P: highest S: blocker                 15
# Priority-Critical (Arctos is broken) Bug               15
# bug GFDL: urgent P: highest S: critical                15
# Bug Mantis Tinebase urgent                             15
# stability-blocker                                      14
# ActiveSync Bug Mantis urgent                           14
# 2.2.0 Priority/Highest Severity/Critical Type/Bug      14
# Type/Bug Priority/Blocker Team/jBallerina              14
# Bug Calendar Mantis urgent                             14
# blocker bug                                            14
# Component/Parser Priority/Blocker Type/Bug             13
# Severity/Critical bug                                  13
# Accepted Priority: Blocker bug                         13
# kind/bug severity/blocker team/ide                     13
# Priority/Blocker Team/jBallerina Type/Bug              13
# Priority/Blocker SwanLakeDump Team/CompilerFE T...     13
# Area/Parser Priority/Blocker Team/CompilerFE Ty...     12
# Release Blocker b:crash eng:qa:verified 🐞 bug          12
# Area/Parser Priority/Blocker SwanLakeDump Team/...     12
# Priority/Highest Severity/Blocker bug                  12
# kind/failing-test priority/critical-urgent sig/...     12

# %%
# Top labels for each priority level
df.loc[df['class'] == 'high', 'labels'].value_counts().to_frame().head(50)
# Print all labels for high priority
#pd.set_option('display.max_rows', None)
#df.loc[df['class'] == 'High', 'labels'].value_counts().to_frame()
# Out:
#                                                     count
# labels
# type: bug priority: p1 nightly failure                768
# P1                                                    681
# buildcop: issue priority: p1 type: bug                605
# priority: p1 type: bug flakybot: issue                590
# autosynth failure priority: p1 type: bug              576
# NEXT UPDATE [Priority: HIGH] bug                      367
# [P: HIGH] bug                                         304
# bug priority: high                                    301
# bug P: high S: normal                                 296
# P0                                                    294
# flakybot: issue priority: p1 type: bug                211
# bug important                                         188
# type: bug priority: p1 flakybot: issue                170
# P1 Type: Enhancement                                  157
# [Priority: HIGH] bug                                  156
# Component: mapnik Priority: major Resolution: f...    154
# P1 Quick                                              154
# Component: merkaartor Priority: major Resolutio...    151
# bug Priority: High                                    147
# P0 Urgent                                             137
# bug P1                                                136
# P2 Important                                          135
# enhancement priority: high                            134
# kind/bug needs-triage sig/content priority/major      124
# Component: website Priority: major Resolution: ...    122
# P0 Type: Enhancement                                  121
# P0 - critical                                         121
# bug high priority                                     109
# [P: HIGH] enhancement                                 103
# P1 bug                                                100
# NEED FAST REVIEW [Priority: HIGH] bug                 100
# P0 UI                                                  94
# bug P: high                                            93
# Component: potlatch (flash editor) Priority: ma...     93
# Bug P1 Study builder                                   93
# kind/bug priority/major                                88
# Component: nominatim Priority: major Resolution...     86
# bug P0                                                 82
# P1 - important                                         82
# enhancement P1                                         81
# NEXT UPDATE [Priority: HIGH] enhancement               81
# Docs: not needed Effort: small Feature Module: ...     76
# P1 enhancement                                         73
# Priority: High bug                                     71
# Priority-High (Needed for work) Function-CodeTa...     69
# priority/p0 kind/feature source/on-demand              68
# new feature priority: high                             67
# P1 Type: Bug                                           67
# kind/task priority/major                               66
# P0 Type: Bug                                           63

# %%
# Medium
df.loc[df['class'] == 'medium', 'labels'].value_counts().to_frame().head(50)
# Out:
#                                                     count
# labels
# Priority/Normal Type/Bug                             1079
# kind/bug area/docdb priority/medium                   413
# Type/Bug Priority/Normal                              272
# kind/bug area/ysql priority/medium                    255
# Priority/Normal Type/Improvement                      224
# bug priority: medium                                  221
# bug P: normal S: normal                               181
# enhancement priority: medium                          158
# kind/enhancement area/docdb priority/medium           153
# kind/enhancement area/ysql priority/medium            136
# enhancement Priority: Medium                           96
# bug Priority: Medium                                   92
# Priority/Normal Type/New Feature                       77
# kind/bug kind/failing-test area/docdb priority/...     72
# new feature priority: medium                           68
# Type/Improvement Priority/Normal                       68
# kind/bug priority/medium area/cdcsdk                   66
# API-M 4.0.0 Priority/Normal Type/Bug                   57
# enhancement P: normal S: normal                        56
# Priority/Normal Type/Question                          54
# [Type] Bug [Pri] Normal User Report                    51
# documentation priority: medium                         48
# Docs/Has Impact Priority/Normal Type/Docs              42
# kind/bug priority/medium area/ecosystem                42
# Function-CodeTables Priority-Normal                    40
# API-M 4.0.0 Priority/Normal React-UI Type/Bug          38
# bug P: highest S: normal                               38
# Priority: Medium bug                                   36
# bug priority: medium validate                          33
# priority: medium task                                  33
# Priority-Normal (Not urgent) Function-CodeTables       33
# good first issue MatrixCamp built-in funtcion M...     32
# Medium Priority                                        32
# kind/bug priority/medium area/ycql                     32
# Priority: Medium enhancement                           27
# Editor [Pri] Normal [Type] Bug                         24
# Type/Bug Priority/Normal APIM - 4.1.0                  24
# Priority/Normal Type/Bug Type/React-UI                 24
# priority: medium quality                               23
# kind/bug area/ysql kind/failing-test priority/m...     23
# Type/New Feature Priority/Normal                       22
# kind/new-feature priority/medium area/ecosystem...     21
# [Pri] Normal LaunchPad                                 21
# kind/bug area/docdb priority/medium xCluster           21
# Area-Pkg Pkg-Polymer PolymerMilestone-Next Prio...     20
# medium priority                                        20
# kind/enhancement priority/medium jira-originated       20
# NEXT UPDATE [Priority: MEDIUM] enhancement             20
# [Pri] Normal [Type] Task [Size] XS Blogger Expe...     18
# [Goal] Gutenberg [Pri] Normal [Type] Bug               18

# %%
# Low
df.loc[df['class'] == 'low', 'labels'].value_counts().to_frame().head(50)
# Out:
#                                                     count
# labels
# P3                                                    188
# Component: website Priority: minor Resolution: ...    172
# Component: mapnik Priority: minor Resolution: f...    134
# Component: mapnik Priority: minor Resolution: f...    111
# Component: nominatim Priority: minor Resolution...     94
# Component: merkaartor Priority: minor Resolutio...     86
# Component: mapnik Priority: minor Resolution: d...     86
# bug priority: low                                      82
# Component: website Priority: minor Resolution: ...     80
# enhancement Priority: Low                              77
# Component: potlatch2 Priority: minor Resolution...     74
# Component: merkaartor Priority: minor Resolutio...     69
# enhancement priority: low                              66
# Component: mapnik Priority: minor Resolution: d...     66
# Component: nominatim Priority: minor Resolution...     62
# bug Priority: Low                                      55
# Component: potlatch2 Priority: minor Type: defect      53
# Component: osmarender Priority: minor Resolutio...     52
# Component: potlatch (flash editor) Priority: mi...     51
# type: feature request P3 team-ExternalDeps stale       50
# Framework Low Priority Stale                           49
# Component: potlatch2 Priority: minor Type: enha...     49
# kind/task priority/minor                               48
# Component: potlatch2 Priority: minor Resolution...     47
# Component: potlatch (flash editor) Priority: mi...     47
# Component: website Priority: minor Resolution: ...     47
# Component: mapnik Priority: minor Resolution: i...     45
# Component: website Priority: minor Resolution: ...     44
# Component: mapnik Priority: minor Resolution: w...     43
# P3 Soon                                                42
# Component: website Priority: minor Resolution: ...     41
# P3: When Possible Type: Feature Request WG: run...     40
# component/web kind/bug priority/P3                     37
# Component: osmarender Priority: minor Resolutio...     36
# Bug Pri: medium Sev: minor UI                          35
# kind/bug priority/minor                                35
# Component: potlatch (flash editor) Priority: mi...     35
# Component: mapnik Priority: minor Resolution: w...     31
# Component: opencyclemap Priority: minor Type: e...     31
# [Type] Bug [Pri] Low User Report                       31
# Bug Pri: low Sev: minor UI                             31
# Component: admin_gui ERR: Assignee Priority: Mi...     30
# Component: nominatim Priority: minor Resolution...     29
# Bug Pri: low Sev: trivial UI                           28
# Component: nominatim Priority: minor Type: defect      28
# Low Priority MantidPlot Stale                          28
# Component: website Priority: trivial Resolution...     26
# Component: website Priority: minor Resolution: ...     25
# Category: Presentation P3: When Possible Type: ...     25
# component/documentation kind/task priority/minor       25

# %%
# non_priority
df.loc[df['class'] == 'non_priority', 'labels'].value_counts().to_frame().head(50)
# Out:
#                                       count
# labels
# kind/bug                               5646
# bug                                    4842
# 🐞 bug                                  3713
# needs more info                        2098
# kind/feature                           1720
# enhancement                            1469
# Type: Bug                              1310
# Type/Bug                               1065
# kind/question                           953
# Stale                                   936
# question                                930
# area-vm                                 899
# kind/enhancement                        898
# [Type] Bug User Report                  838
# Bug                                     807
# testplan-item                           721
# kind/task                               609
# area-analyzer                           574
# integrated-terminal                     573
# bug debug                               558
# kind/failing-test                       549
# area-front-end                          545
# area/documentation                      523
# area/docdb                              511
# new release                             509
# docs                                    490
# [Type] Bug                              483
# area/platform                           482
# lifecycle/rotten                        481
# Type: Feature Request                   481
# [Type] Task                             472
# [Type] Feature Request                  443
# improvement                             438
# debug                                   427
# kind/flake                              407
# :watch: Not Triaged Source - Docs.ms    405
# UI                                      395
# *duplicate                              377
# extensions                              370
# area-vm gardening                       365
# feature-request                         364
# needs-sig                               364
# *caused-by-extension                    347
# priority/backlog kind/failing-test      343
# suggestion                              325
# 🌟 feature request                       322
# Component: Framework                    309
# area/ysql                               306
# Type/Improvement                        303
# Reader [Type] Bug                       300

# %%
# in_triage
df.loc[df['class'] == 'in_triage', 'labels'].value_counts().to_frame().head(50)
# Out:
#                                                     count
# labels
# bug triage                                           2647
# bug needs-triage                                     2389
# feature-request needs-triage                         1349
# needs:triage                                         1157
# 🐞 bug needs:triage                                   1020
# kind/bug needs-sig needs-triage                       996
# kind/bug needs-triage                                 978
# area/docdb status/awaiting-triage                     881
# area/ysql status/awaiting-triage                      752
# needs:triage 🐞 bug                                    736
# triage me                                             454
# needs-sig needs-triage                                359
# kind/bug needs-triage severity/s0                     353
# guidance needs-triage                                 348
# bug status/needs-triage                               296
# enhancement triage                                    271
# triage/support                                        271
# needs-triage                                          267
# [Type] Bug Needs triage                               245
# feature-request status/needs-triage                   201
# kind/bug needs-triage severity/s1                     200
# kind/bug needs-triage severity/s-1                    162
# kind/bug needs-triage sig/content priority/minor      160
# triage                                                121
# kind/support triage/needs-information                 120
# kind/bug area/ysql priority/medium status/await...    110
# kind/bug needs-triage severity/s1 bvt                 108
# bug triage stale                                      108
# status/needs-triage                                   102
# documentation feature-request needs-triage             99
# needs-triage documentation                             96
# kind/bug needs-triage sig/ui-ux priority/minor         94
# triage/needs-information triage/support                85
# [Type] Bug User Report Needs triage                    73
# kind/bug sig/network triage/unresolved                 73
# area/ycql status/awaiting-triage                       67
# kind/bug sig/api-machinery triage/accepted             65
# kind/support needs-sig needs-triage                    65
# new feature triage                                     64
# kind/bug needs-triage bvt                              62
# eng:performance needs:triage                           62
# 🐞 bug needs:triage wontfix                             62
# kind/bug triage/accepted bvt                           61
# needs:triage wontfix                                   60
# triage docs                                            58
# needs-sig triage/support                               54
# kind/bug needs-triage sig/content priority/crit...     50
# b:crash eng:intermittent-test needs:triage eng:...     48
# kind/enhancement area/ysql status/awaiting-triage      47
# kind/bug area/ysql status/awaiting-triage              46

# %%
# Unique repo
df['repo'].nunique()
# Out:
# 50

# %%
# Value count labels
df["labels"].value_counts().to_frame()[:50]
# Out:
#                                           count
# labels
# kind/bug                                   5646
# bug                                        4842
# 🐞 bug                                      3713
# bug triage                                 2647
# bug needs-triage                           2389
# needs more info                            2098
# kind/feature                               1720
# enhancement                                1469
# feature-request needs-triage               1349
# Type: Bug                                  1310
# needs:triage                               1157
# Priority/Normal Type/Bug                   1079
# Type/Bug                                   1065
# 🐞 bug needs:triage                         1020
# kind/bug needs-sig needs-triage             996
# kind/bug needs-triage                       978
# kind/question                               953
# Stale                                       936
# question                                    930
# area-vm                                     899
# kind/enhancement                            898
# area/docdb status/awaiting-triage           881
# [Type] Bug User Report                      838
# Bug                                         807
# type: bug priority: p1 nightly failure      768
# area/ysql status/awaiting-triage            752
# needs:triage 🐞 bug                          736
# testplan-item                               721
# P1                                          681
# kind/task                                   609
# buildcop: issue priority: p1 type: bug      605
# P2                                          594
# priority: p1 type: bug flakybot: issue      590
# autosynth failure priority: p1 type: bug    576
# area-analyzer                               574
# integrated-terminal                         573
# bug debug                                   558
# kind/failing-test                           549
# area-front-end                              545
# area/documentation                          523
# area/docdb                                  511
# new release                                 509
# docs                                        490
# [Type] Bug                                  483
# area/platform                               482
# lifecycle/rotten                            481
# Type: Feature Request                       481
# [Type] Task                                 472
# triage me                                   454
# [Type] Feature Request                      443

# %%
df.value_counts('class').to_frame()
# Out:
#                count
# class
# non_priority  176226
# high           47883
# in_triage      28638
# p2             16196
# low            12103
# medium          9212
# critical        5607

# %%
df
# Out:
#                           repo  \
# 9           openmsupply/mobile
# 82                 dotnet/docs
# 155         openmsupply/mobile
# 156         openmsupply/mobile
# 182      kubernetes/kubernetes
# ...                        ...
# 5839690  kubernetes/kubernetes
# 5839700       Microsoft/vscode
# 5839740       Microsoft/vscode
# 5839749  kubernetes/kubernetes
# 5839752      kubeflow/kubeflow
#
#                                                     labels         class  \
# 9        Docs: not needed Effort: small Feature Module:...          high
# 82                 :books: Area - F# Guide doc-enhancement  non_priority
# 155                                                Feature  non_priority
# 156      Docs: needed Epic Feature Module: dispensary P...          high
# 182                      kind/bug lifecycle/rotten sig/cli  non_priority
# ...                                                    ...           ...
# 5839690         area/api kind/feature sig/apps sig/windows  non_priority
# 5839700                                api needs more info  non_priority
# 5839740                                         javascript  non_priority
# 5839749                 area/kubeadm sig/cluster-lifecycle  non_priority
# 5839752                                          inference  non_priority
#
#                                                       text
# 9        autolog out after some time frame is your feat...
# 82       tidying up evaluation results versus the expre...
# 155      update cash register to use new payment option...
# 156      cash register is your feature request related ...
# 182      cannot expose long array of ports because of c...
# ...                                                    ...
# 5839690  environment variables containing colon not all...
# 5839700  extension api suggestion ability to control se...
# 5839740  code navigation broken when using modules in i...
# 5839749  this might take a minute or longer hi people s...
# 5839752  tfserving component should add an ambassador r...
#
# [295865 rows x 4 columns]

# %%
high = df[df['class'] == 'high']
high
# Out:
#                                       repo  \
# 9                       openmsupply/mobile
# 156                     openmsupply/mobile
# 304      ballerina-platform/ballerina-lang
# 322      ballerina-platform/ballerina-lang
# 339                            zulip/zulip
# ...                                    ...
# 5837345              Automattic/wp-calypso
# 5837495              Automattic/wp-calypso
# 5837980             googlefonts/fontbakery
# 5838350                  wso2/product-apim
# 5839595           learningequality/kolibri
#
#                                                     labels class  \
# 9        Docs: not needed Effort: small Feature Module:...  high
# 156      Docs: needed Epic Feature Module: dispensary P...  high
# 304      Area/Tooling Component/LanguageServer Points/1...  high
# 322      Area/Tooling Component/LanguageServer Points/2...  high
# 339      area: authentication enhancement good first is...  high
# ...                                                    ...   ...
# 5837345                 Editor Media [Pri] High [Type] Bug  high
# 5837495                           Color Schemes [Pri] High  high
# 5837980                                          P0 Urgent  high
# 5838350                Type/Bug Priority/High APIM - 4.1.0  high
# 5839595                        P0 - critical TASK: bug fix  high
#
#                                                       text
# 9        autolog out after some time frame is your feat...
# 156      cash register is your feature request related ...
# 304      create local variable code action breaks code ...
# 322      revamp the completion item sorting phase descr...
# 339      add rate limiting to the login and password ch...
# ...                                                    ...
# 5837345  media editor sorry there was a problem loading...
# 5837495  make calypso components themable in order to a...
# 5837980  error in comgooglefontscheckdottedcircle ancho...
# 5838350  schema validation failure other errors in reso...
# 5839595  on tablet not able to see an exercise of the c...
#
# [47883 rows x 4 columns]

# %%
critical = df[df['class'] == 'critical']
critical
# Out:
#                                       repo  \
# 565                        wso2/product-is
# 906                        wso2/product-is
# 1503                          jenkins-x/jx
# 2040                       wso2/product-is
# 10256                          eclipse/che
# ...                                    ...
# 5835312             eclipse-ee4j/glassfish
# 5835809  ballerina-platform/ballerina-lang
# 5835814  ballerina-platform/ballerina-lang
# 5835922  ballerina-platform/ballerina-lang
# 5838907                    ArctosDB/arctos
#
#                                                     labels     class  \
# 565             Priority/Highest Severity/Blocker Type/Bug  critical
# 906            Priority/Highest Severity/Critical Type/Bug  critical
# 1503     area/build estimate/S kind/bug priority/critic...  critical
# 2040            Priority/Highest Severity/Blocker Type/Bug  critical
# 10256                            kind/bug severity/blocker  critical
# ...                                                    ...       ...
# 5835312  Component: build_system Priority: Critical Sta...  critical
# 5835809         Component/Parser Priority/Blocker Type/Bug  critical
# 5835814         Component/Parser Priority/Blocker Type/Bug  critical
# 5835922  Area/Language Component/Compiler Priority/Blocker  critical
# 5838907   Priority-Critical (Arctos is broken) Arctos Down  critical
#
#                                                       text
# 565      error occurred when manually sourcing the orac...
# 906      exception handling issue in cachecleanuptask w...
# 1503     change in googleapisgnostic breaks make genera...
# 2040     there is no ui option to enable scim while add...
# 10256    che installation fails on minikube describe th...
# ...                                                    ...
# 5835312  support building glassfish with maven x maven ...
# 5835809  parser crashed for missing closebracket in mem...
# 5835814  issue in parsing array type descriptor with us...
# 5835922  issues with object equivalency rules with remo...
# 5838907  arctos down please complete to the best of you...
#
# [5607 rows x 4 columns]

# %%
p2_high = df[df['class'] == 'p2_high']
p2_high
# Out:
# Empty DataFrame
# Columns: [repo, labels, class, text]
# Index: []

# %%
low = df[df['class'] == 'low']
low
# Out:
#                                   repo  \
# 472                  wso2/product-apim
# 980      ita-social-projects/GreenCity
# 1192                   wso2/product-is
# 2543             craftercms/craftercms
# 3546     ita-social-projects/GreenCity
# ...                                ...
# 5834565          craftercms/craftercms
# 5834845          craftercms/craftercms
# 5835307         eclipse-ee4j/glassfish
# 5835309         eclipse-ee4j/glassfish
# 5835313         eclipse-ee4j/glassfish
#
#                                                     labels class  \
# 472                                           Priority/Low   low
# 980                          Bug pri: low severity:trivial   low
# 1192     Complexity/Low Component/Identity Mgt Severity...   low
# 2543                                     bug priority: low   low
# 3546                 Bug pri: low severity:manor type: bug   low
# ...                                                    ...   ...
# 5834565                          enhancement priority: low   low
# 5834845                              priority: low quality   low
# 5835307  Component: admin ERR: Assignee Priority: Minor...   low
# 5835309  Component: admin_gui ERR: Assignee Priority: M...   low
# 5835313  Component: admin Component: admin_gui ERR: Ass...   low
#
#                                                       text
# 472      incorrect connection url in analytics configur...
# 980      bug tooltip with the text here you can set you...
# 1192     inconsistency in the definition of idnclaimdia...
# 2543     html response and code when management token i...
# 3546     hideshow password function doesnt work steps t...
# ...                                                    ...
# 5834565  add icons to the remaining nav bar actions to ...
# 5834845  warning message when stopping the delivery env...
# 5835307  restartdomain failed return when invalid jvmop...
# 5835309  tree view of admin console is still active whe...
# 5835313  provide monitoring capabilities for timerservi...
#
# [12103 rows x 4 columns]

# %%
medium = df[df['class'] == 'medium']
medium
# Out:
#                                   repo  \
# 201                 openmsupply/mobile
# 204                 openmsupply/mobile
# 356                  wso2/product-apim
# 498                    wso2/product-is
# 1172     ita-social-projects/GreenCity
# ...                                ...
# 5834893          craftercms/craftercms
# 5836077          craftercms/craftercms
# 5837892          Automattic/wp-calypso
# 5838295              wso2/product-apim
# 5839080              wso2/product-apim
#
#                                                     labels   class  \
# 201      Docs: not needed Effort: small Feature Module:...  medium
# 204      Effort: medium Feature Module: indicators Prio...  medium
# 356                 3.1.0 Priority/Normal Type/New Feature  medium
# 498      Affected/5.10.0-Alpha2 Priority/Normal Severit...  medium
# 1172     Bug Registered user Unregistered user pri: med...  medium
# ...                                                    ...     ...
# 5834893                       enhancement priority: medium  medium
# 5836077                               bug priority: medium  medium
# 5837892                [Type] Bug [Pri] Normal User Report  medium
# 5838295  Type/Improvement Priority/Normal Feature/Opera...  medium
# 5839080                           Type/Bug Priority/Normal  medium
#
#                                                       text
# 201      add cash register page toggle is your feature ...
# 204      enforce indicator types is your feature reques...
# 356      add option to determine deploymenttoml replace...
# 498      incorrect resopnse code validation when trying...
# 1172     bug not localizations in map related to steps ...
# ...                                                    ...
# 5834893  create site dialog updates studio ui update th...
# 5836077  login mechanism improvements describe the bug ...
# 5837892  fse beta color picker looks broken quick summa...
# 5838295  improve the policy create uiux by preprocessin...
# 5839080  unauthenticated request alert popsup when a us...
#
# [9212 rows x 4 columns]

# %%
non_priority = df[df['class'] == 'non_priority']
non_priority
# Out:
#                           repo                                      labels  \
# 82                 dotnet/docs     :books: Area - F# Guide doc-enhancement
# 155         openmsupply/mobile                                     Feature
# 182      kubernetes/kubernetes           kind/bug lifecycle/rotten sig/cli
# 203         openmsupply/mobile    Effort: small Feature Module: indicators
# 224            ray-project/ray                                    question
# ...                        ...                                         ...
# 5839690  kubernetes/kubernetes  area/api kind/feature sig/apps sig/windows
# 5839700       Microsoft/vscode                         api needs more info
# 5839740       Microsoft/vscode                                  javascript
# 5839749  kubernetes/kubernetes          area/kubeadm sig/cluster-lifecycle
# 5839752      kubeflow/kubeflow                                   inference
#
#                 class                                               text
# 82       non_priority  tidying up evaluation results versus the expre...
# 155      non_priority  update cash register to use new payment option...
# 182      non_priority  cannot expose long array of ports because of c...
# 203      non_priority  add remaining indicator localisation is your f...
# 224      non_priority  easiest way to loadplay a checkpoint after tra...
# ...               ...                                                ...
# 5839690  non_priority  environment variables containing colon not all...
# 5839700  non_priority  extension api suggestion ability to control se...
# 5839740  non_priority  code navigation broken when using modules in i...
# 5839749  non_priority  this might take a minute or longer hi people s...
# 5839752  non_priority  tfserving component should add an ambassador r...
#
# [176226 rows x 4 columns]

# %%
high_priority = pd.concat([critical, high, p2_high], ignore_index=True)
high_priority["label"] = 1
high_priority
# Out:
#                            repo  \
# 0               wso2/product-is
# 1               wso2/product-is
# 2                  jenkins-x/jx
# 3               wso2/product-is
# 4                   eclipse/che
# ...                         ...
# 53485     Automattic/wp-calypso
# 53486     Automattic/wp-calypso
# 53487    googlefonts/fontbakery
# 53488         wso2/product-apim
# 53489  learningequality/kolibri
#
#                                                   labels     class  \
# 0             Priority/Highest Severity/Blocker Type/Bug  critical
# 1            Priority/Highest Severity/Critical Type/Bug  critical
# 2      area/build estimate/S kind/bug priority/critic...  critical
# 3             Priority/Highest Severity/Blocker Type/Bug  critical
# 4                              kind/bug severity/blocker  critical
# ...                                                  ...       ...
# 53485                 Editor Media [Pri] High [Type] Bug      high
# 53486                           Color Schemes [Pri] High      high
# 53487                                          P0 Urgent      high
# 53488                Type/Bug Priority/High APIM - 4.1.0      high
# 53489                        P0 - critical TASK: bug fix      high
#
#                                                     text  label
# 0      error occurred when manually sourcing the orac...      1
# 1      exception handling issue in cachecleanuptask w...      1
# 2      change in googleapisgnostic breaks make genera...      1
# 3      there is no ui option to enable scim while add...      1
# 4      che installation fails on minikube describe th...      1
# ...                                                  ...    ...
# 53485  media editor sorry there was a problem loading...      1
# 53486  make calypso components themable in order to a...      1
# 53487  error in comgooglefontscheckdottedcircle ancho...      1
# 53488  schema validation failure other errors in reso...      1
# 53489  on tablet not able to see an exercise of the c...      1
#
# [53490 rows x 5 columns]

# %%
rest = pd.concat([low, medium], ignore_index=True)
rest["label"] = 0
rest
# Out:
#                                 repo  \
# 0                  wso2/product-apim
# 1      ita-social-projects/GreenCity
# 2                    wso2/product-is
# 3              craftercms/craftercms
# 4      ita-social-projects/GreenCity
# ...                              ...
# 21310          craftercms/craftercms
# 21311          craftercms/craftercms
# 21312          Automattic/wp-calypso
# 21313              wso2/product-apim
# 21314              wso2/product-apim
#
#                                                   labels   class  \
# 0                                           Priority/Low     low
# 1                          Bug pri: low severity:trivial     low
# 2      Complexity/Low Component/Identity Mgt Severity...     low
# 3                                      bug priority: low     low
# 4                  Bug pri: low severity:manor type: bug     low
# ...                                                  ...     ...
# 21310                       enhancement priority: medium  medium
# 21311                               bug priority: medium  medium
# 21312                [Type] Bug [Pri] Normal User Report  medium
# 21313  Type/Improvement Priority/Normal Feature/Opera...  medium
# 21314                           Type/Bug Priority/Normal  medium
#
#                                                     text  label
# 0      incorrect connection url in analytics configur...      0
# 1      bug tooltip with the text here you can set you...      0
# 2      inconsistency in the definition of idnclaimdia...      0
# 3      html response and code when management token i...      0
# 4      hideshow password function doesnt work steps t...      0
# ...                                                  ...    ...
# 21310  create site dialog updates studio ui update th...      0
# 21311  login mechanism improvements describe the bug ...      0
# 21312  fse beta color picker looks broken quick summa...      0
# 21313  improve the policy create uiux by preprocessin...      0
# 21314  unauthenticated request alert popsup when a us...      0
#
# [21315 rows x 5 columns]

# %%
from sklearn.utils import shuffle
# Number of rows in the highest class
n_rest = rest.shape[0]

hp_sampled = high_priority.sample(n=n_rest, random_state=42)  


balanced_data = pd.concat([rest, hp_sampled])

# Shuffle the combined dataset
balanced_data = shuffle(balanced_data, random_state=42)
balanced_data
# Out:
#                                           repo  \
# 1557                      mantidproject/mantid
# 18010                     yugabyte/yugabyte-db
# 20019  GoogleCloudPlatform/python-docs-samples
# 18424                     yugabyte/yugabyte-db
# 2982                        ampproject/amphtml
# ...                                        ...
# 6265                    tomhughes/trac-tickets
# 11284                    Automattic/wp-calypso
# 32903                   tomhughes/trac-tickets
# 860                        minishift/minishift
# 15795                    Automattic/wp-calypso
#
#                                                   labels   class  \
# 1557                                   Low Priority Muon     low
# 18010                kind/bug area/docdb priority/medium  medium
# 20019  priority: p1 type: bug api: healthcare samples...    high
# 18424  kind/bug area/cdc priority/medium area/cdcsdk ...  medium
# 2982   Category: User Input P3: When Possible Type: D...     low
# ...                                                  ...     ...
# 6265   Component: website Priority: minor Resolution:...     low
# 11284  [Type] Bug [Pri] Low Plans: eCommerce Nav Unif...     low
# 32903  Component: potlatch (flash editor) Priority: m...    high
# 860                              kind/bug priority/minor     low
# 15795  FixTheFlows Jetpack Plans Plans [Pri] Normal [...  medium
#
#                                                     text  label
# 1557   speed up asymmetry calculation this issue was ...      0
# 18010  with pgleaderchangewaitqueuestestaddtwoservers...      0
# 20019  healthcareapiclientfhirfhirresourcestest testc...      1
# 18424  on there is a core seen within less than an ho...      0
# 2982   capture and send the submitter button when sub...      0
# ...                                                  ...    ...
# 6265   add preview button to the form for creating ne...      0
# 11284  ecommerce customers menu item visibility quick...      0
# 32903  could not add relations i could not add a new ...      1
# 860    deleting a profile does not remove the instanc...      0
# 15795  jetpack monthly plans show errors about expiri...      0
#
# [42630 rows x 5 columns]

# %%
balanced_data['class'].value_counts()
# Out:
# class
# high        19039
# low         12103
# medium       9212
# critical     2276
# Name: count, dtype: int64

# %%
balanced_data = balanced_data[["label", "text"]]
balanced_data
# Out:
#        label                                               text
# 1557       0  speed up asymmetry calculation this issue was ...
# 18010      0  with pgleaderchangewaitqueuestestaddtwoservers...
# 20019      1  healthcareapiclientfhirfhirresourcestest testc...
# 18424      0  on there is a core seen within less than an ho...
# 2982       0  capture and send the submitter button when sub...
# ...      ...                                                ...
# 6265       0  add preview button to the form for creating ne...
# 11284      0  ecommerce customers menu item visibility quick...
# 32903      1  could not add relations i could not add a new ...
# 860        0  deleting a profile does not remove the instanc...
# 15795      0  jetpack monthly plans show errors about expiri...
#
# [42630 rows x 2 columns]

# %%
balanced_data['label'].value_counts()
# Out:
# label
# 0    21315
# 1    21315
# Name: count, dtype: int64

# %%
df.isnull().any().any()
# Out:
# False

# %%
full_path = f'{path_to_files}/HP_vs_med_low/high_vs_med_low_top_50_hp_repos_balanced_github.csv'

# %%
balanced_data.to_csv(full_path, index=False)

# %%
testing = pd.read_csv(full_path)

# %%
testing
# Out:
#        label                                               text
# 0          0  speed up asymmetry calculation this issue was ...
# 1          0  with pgleaderchangewaitqueuestestaddtwoservers...
# 2          1  healthcareapiclientfhirfhirresourcestest testc...
# 3          0  on there is a core seen within less than an ho...
# 4          0  capture and send the submitter button when sub...
# ...      ...                                                ...
# 42625      0  add preview button to the form for creating ne...
# 42626      0  ecommerce customers menu item visibility quick...
# 42627      1  could not add relations i could not add a new ...
# 42628      0  deleting a profile does not remove the instanc...
# 42629      0  jetpack monthly plans show errors about expiri...
#
# [42630 rows x 2 columns]
