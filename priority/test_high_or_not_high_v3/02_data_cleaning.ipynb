# %% [markdown]
# # Data cleaning
# We want the class with labels as numerical value and the body with clean text.
#
# This will remove:
# * duplicates
# * NaN entires
# * non english
# * url, html
#
# * make it lowercase
# * combine title and body

# %%
import pandas as pd
import sys
sys.path.append("../../scripts_shared/")
from preprocess_text import preprocess_text

# %%
# Read CSV into a dataframe
high_priority = pd.read_csv("csv/high_priority_no_td.csv", index_col=0)
not_high_priority = pd.read_csv("csv/not_high_no_td1.csv", index_col=0)
# Out:
# /tmp/ipykernel_13472/1896111304.py:3: DtypeWarning: Columns (0,2,3,4,5,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   not_high_priority = pd.read_csv("csv/not_high_no_td1.csv", index_col=0)

# %%
contains_stale = not_high_priority['labels'].str.contains("stale", case=False, na=False)
not_high_priority= not_high_priority[~contains_stale].reset_index(drop=True)
not_high_priority.reset_index(drop=True, inplace=True)
not_high_priority
# Out:
#                    id         type           created_at  \
# 0        1.141754e+10  IssuesEvent  2020-02-03 00:00:07
# 1        1.141754e+10  IssuesEvent  2020-02-03 00:00:12
# 2        1.141754e+10  IssuesEvent  2020-02-03 00:00:13
# 3        1.141754e+10  IssuesEvent  2020-02-03 00:00:16
# 4        1.141754e+10  IssuesEvent  2020-02-03 00:00:18
# ...               ...          ...                  ...
# 9206801  8.109961e+09  IssuesEvent  2018-08-14 09:21:15
# 9206802  8.109961e+09  IssuesEvent  2018-08-14 09:21:16
# 9206803  8.109982e+09  IssuesEvent  2018-08-14 09:25:07
# 9206804  8.109983e+09  IssuesEvent  2018-08-14 09:25:24
# 9206805  8.109984e+09  IssuesEvent  2018-08-14 09:25:29
#
#                                   repo  \
# 0        automationbs/testbugreporting
# 1                PowerShell/PowerShell
# 2                  thadiun/hello-world
# 3                PowerShell/PowerShell
# 4                PowerShell/PowerShell
# ...                                ...
# 9206801                     urbit/arvo
# 9206802    highcharts/highcharts-react
# 9206803           Loriowar/comindivion
# 9206804     TiiQu-Network/TQ-test-page
# 9206805         prominic/Moonshine-IDE
#
#                                                   repo_url  action  \
# 0        https://api.github.com/repos/automationbs/test...  opened
# 1        https://api.github.com/repos/PowerShell/PowerS...  closed
# 2         https://api.github.com/repos/thadiun/hello-world  closed
# 3        https://api.github.com/repos/PowerShell/PowerS...  closed
# 4        https://api.github.com/repos/PowerShell/PowerS...  closed
# ...                                                    ...     ...
# 9206801            https://api.github.com/repos/urbit/arvo  opened
# 9206802  https://api.github.com/repos/highcharts/highch...  closed
# 9206803  https://api.github.com/repos/Loriowar/comindivion  opened
# 9206804  https://api.github.com/repos/TiiQu-Network/TQ-...  closed
# 9206805  https://api.github.com/repos/prominic/Moonshin...  closed
#
#                                                      title  \
# 0                                            Default title
# 1                                               Show alias
# 2                   [Test] testing needs-triage (no delay)
# 3                                     $ENV in using module
# 4                Measure-Command does not measure its self
# ...                                                    ...
# 9206801            %bad-text trips up hall JSON conversion
# 9206802                            HighMaps mapBubble type
# 9206803  Add a validation on a belonging of a predicate...
# 9206804                     Error on submit with no values
# 9206805           Handle unknown tags in Visual Editor XML
#
#                                                     labels  \
# 0                                                      bug
# 1                       Issue-Question Resolution-Answered
# 2                                                   triage
# 3         Area-Language Issue-Question Resolution-Answered
# 4        Area-Cmdlets-Utility Issue-Question Resolution...
# ...                                                    ...
# 9206801      :hall / :talk cause known marks web interface
# 9206802                                      pending reply
# 9206803                              bug data manipulation
# 9206804                                                bug
# 9206805               Investigation PrimeFaces enhancement
#
#                                                       body
# 0        default description\n\n|Property | Value|\n|--...
# 1        <!--\r\n\r\nFor Windows PowerShell 5.1 issues,...
# 2                                                      NaN
# 3        # Summary of the new feature/enhancement\r\n\r...
# 4        ## The Issue\r\nI'm pretty sure this was just ...
# ...                                                    ...
# 9206801  Haven't tested this in detail yet, but pretty ...
# 9206802  Hello,\r\nIt is possible to create also HighMa...
# 9206803  Now user can change html content of the intera...
# 9206804  TypeError: Too few arguments in function sum (...
# 9206805  If provided Visual Editor XML brings some unkn...
#
# [9206806 rows x 9 columns]

# %%
# Number or different labels
high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                   count
# labels
# bug high priority                 10435
# high priority                     10360
# High Priority                      7484
# enhancement high priority          5486
# Priority: High                     4751
# priority.High                      3694
# priority.High type.Task            3685
# priority.high type.task            3209
# priority.High type.Story           2979
# priority.high                      2749
# bug priority: high                 2306
# high-priority                      2262
# priority: high                     2178
# bug high-priority                  2159
# type.Story priority.High           2155
# priority.high type.story           2130
# type.Task priority.High            2022
# bug High Priority                  1888
# High priority                      1815
# Priority: High Type: Bug           1768
# priority:high                      1726
# bug priority:high                  1470
# High Priority bug                  1338
# Priority: High bug                 1200
# Bug High Priority                  1143
# feature high priority              1091
# enhancement priority: high         1090
# enhancement high-priority          1053
# enhancement priority:high           982
# priority-high                       955
# bug priority-high                   927
# enhancement High Priority           902
# bug Priority: High                  837
# Priority: High Type: Enhancement    835
# high priority task                  831
# bug High priority                   744
# priority high                       733
# priority.high type.bug              717
# priority: high type: bug            704
# Type: Bug Priority: High            639
# Bug Priority: High                  620
# High Priority enhancement           611
# documentation priority.High         600
# prio:high                           587
# Bug - High Priority                 562
# priority.High type.Enhancement      562
# bug prio-high                       541
# Priority: High Type: Feature        541
# priority.high type.enhancement      540
# priority/high                       537

# %%
high_priority[high_priority["repo"] == "python/mypy"]
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body]
# Index: []

# %%
# Remove mypy from the dataset
high_priority = high_priority[high_priority["repo"] != "python/mypy"]
high_priority
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3       1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4       1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...              ...          ...                  ...
# 373104  7.334924e+09  IssuesEvent  2018-03-06 01:09:12
# 373105  7.334984e+09  IssuesEvent  2018-03-06 01:28:23
# 373106  7.335034e+09  IssuesEvent  2018-03-06 01:44:11
# 373107  7.335035e+09  IssuesEvent  2018-03-06 01:44:26
# 373108  7.335039e+09  IssuesEvent  2018-03-06 01:45:34
#
#                                        repo  \
# 0                 unitystation/unitystation
# 1       zowe/sample-spring-boot-api-service
# 2                        openmsupply/mobile
# 3       UltimateCodeMonkeys/CodeMonkeysMVVM
# 4        wordpress-mobile/WordPress-Android
# ...                                     ...
# 373104           StrangeLoopGames/EcoIssues
# 373105                        asteca/ASteCA
# 373106               wh1ter0se/PowerUp-2018
# 373107               wh1ter0se/PowerUp-2018
# 373108                      xcat2/xcat-core
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/unitystation/unit...  closed
# 1       https://api.github.com/repos/zowe/sample-sprin...  closed
# 2         https://api.github.com/repos/openmsupply/mobile  closed
# 3       https://api.github.com/repos/UltimateCodeMonke...  opened
# 4       https://api.github.com/repos/wordpress-mobile/...  closed
# ...                                                   ...     ...
# 373104  https://api.github.com/repos/StrangeLoopGames/...  closed
# 373105         https://api.github.com/repos/asteca/ASteCA  closed
# 373106  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 373107  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 373108       https://api.github.com/repos/xcat2/xcat-core  closed
#
#                                                     title  \
# 0       Client breaking NRE when using edit field on C...
# 1       The SDK provides a separate Java (no-Spring) l...
# 2                      Auto-log out after some time frame
# 3       Migrate: CodeMonkeys ViewModelNavigationServic...
# 4       IA Reader filter bottom sheet: manage untitled...
# ...                                                   ...
# 373104       Meteor hit - Can no longer join server 6.4.1
# 373105  Improve performance of synth cluster generatio...
# 373106  Get and record refined PID loops for rotation ...
# 373107  Figure out why CyborgCommandSpit() runs early ...
# 373108  error message improvement when adding users in...
#
#                                                    labels  \
# 0                        Bug High Priority In Progress UI
# 1       Feature: API Security Priority: High no-issue-...
# 2       Docs: not needed Effort: small Feature Module:...
# 3       Priority: High Status: In Progress Type: Maint...
# 4                        IA Reader [Pri] High [Type] Task
# ...                                                   ...
# 373104                                      High Priority
# 373105           code_enhance p:high performance synth-cl
# 373106                 IRL development high priority java
# 373107                         R&D bug high priority java
# 373108      priority:high sprint1 status:pending type:bug
#
#                                                      body
# 0       ### Bug:\r\n\r\nIf you use the edit field of t...
# 1       - The commons-spring library is split into:\r\...
# 2       ## Is your feature request related to a proble...
# 3       Migrate the Xamarin.Forms navigation service i...
# 4       In the filter bottom sheet we introduced in th...
# ...                                                   ...
# 373104  Just had the meteor hit on our server and now ...
# 373105  Follow up on #227.\r\n\r\n#### 0. Initial `syn...
# 373106  Pretty simple, and pretty sure we already have...
# 373107  The problem is that when we run autonomous (so...
# 373108  Problem statement: error message when adding x...
#
# [373109 rows x 9 columns]

# %%
not_high_priority[not_high_priority["repo"] == "python/mypy"]
# Out:
#                    id         type           created_at         repo  \
# 20492    1.142706e+10  IssuesEvent  2020-02-03 23:33:27  python/mypy
# 20521    1.142707e+10  IssuesEvent  2020-02-03 23:35:24  python/mypy
# 35777    1.362788e+10  IssuesEvent  2020-09-24 13:13:03  python/mypy
# 44233    1.363241e+10  IssuesEvent  2020-09-24 19:36:27  python/mypy
# 61258    2.407484e+10  IssuesEvent  2022-09-18 17:03:35  python/mypy
# ...               ...          ...                  ...          ...
# 9188054  7.349652e+09  IssuesEvent  2018-03-08 11:27:27  python/mypy
# 9188055  7.349652e+09  IssuesEvent  2018-03-08 11:27:27  python/mypy
# 9188830  7.349972e+09  IssuesEvent  2018-03-08 12:44:13  python/mypy
# 9188843  7.349979e+09  IssuesEvent  2018-03-08 12:45:41  python/mypy
# 9205708  8.109448e+09  IssuesEvent  2018-08-14 07:36:08  python/mypy
#
#                                          repo_url  action  \
# 20492    https://api.github.com/repos/python/mypy  closed
# 20521    https://api.github.com/repos/python/mypy  closed
# 35777    https://api.github.com/repos/python/mypy  opened
# 44233    https://api.github.com/repos/python/mypy  opened
# 61258    https://api.github.com/repos/python/mypy  opened
# ...                                           ...     ...
# 9188054  https://api.github.com/repos/python/mypy  closed
# 9188055  https://api.github.com/repos/python/mypy  closed
# 9188830  https://api.github.com/repos/python/mypy  opened
# 9188843  https://api.github.com/repos/python/mypy  closed
# 9205708  https://api.github.com/repos/python/mypy  closed
#
#                                                      title  \
# 20492             Type of conditional expression is object
# 20521      Type inference of Tuples returns object instead
# 35777          Daemon support for --follow-imports=silent
# 44233    regression: assignment of 'builtins.type' now ...
# 61258    stubtest: more concise error for forgotten arg...
# ...                                                    ...
# 9188054  Legal Python circular imports result in loss o...
# 9188055  Crash when serializing property with forward r...
# 9188830  Suggest type annotations for partial types spa...
# 9188843  What to do about inferring types from multiple...
# 9205708         Multi-line -c flag doesn't work on Windows
#
#                                                     labels  \
# 20492    false-positive needs discussion priority-1-nor...
# 20521                   bug false-positive priority-0-high
# 35777                                              feature
# 44233                                                  bug
# 61258                                              feature
# ...                                                    ...
# 9188054          bug priority-1-normal topic-import-cycles
# 9188055            crash priority-0-high topic-incremental
# 9188830  feature priority-2-low topic-fine-grained-incr...
# 9188843  feature priority-0-high topic-fine-grained-inc...
# 9205708                                 bug priority-2-low
#
#                                                       body
# 20492    The type of the following conditional expressi...
# 20521    While interacting with `zip` I encountered a v...
# 35777    After #5870 is done, it would be nice to also ...
# 44233    \r\n**Bug Report**\r\n\r\n#7963 causes a serio...
# 61258    **Feature**\r\n\r\nWhen the implementation add...
# ...                                                    ...
# 9188054  Example:\r\n\r\n`test/__init__.py`:\r\n```pyth...
# 9188055  This serialization test case fails with a cras...
# 9188830  We don't support inferring partial types from ...
# 9188843  Typically mypy infers the type of the variable...
# 9205708  Simplest reproduction seems to be\n\n``` bash\...
#
# [306 rows x 9 columns]

# %%
# Remove mypy from the dataset
not_high_priority = not_high_priority[not_high_priority["repo"] != "python/mypy"]
not_high_priority
# Out:
#                    id         type           created_at  \
# 0        1.141754e+10  IssuesEvent  2020-02-03 00:00:07
# 1        1.141754e+10  IssuesEvent  2020-02-03 00:00:12
# 2        1.141754e+10  IssuesEvent  2020-02-03 00:00:13
# 3        1.141754e+10  IssuesEvent  2020-02-03 00:00:16
# 4        1.141754e+10  IssuesEvent  2020-02-03 00:00:18
# ...               ...          ...                  ...
# 9206801  8.109961e+09  IssuesEvent  2018-08-14 09:21:15
# 9206802  8.109961e+09  IssuesEvent  2018-08-14 09:21:16
# 9206803  8.109982e+09  IssuesEvent  2018-08-14 09:25:07
# 9206804  8.109983e+09  IssuesEvent  2018-08-14 09:25:24
# 9206805  8.109984e+09  IssuesEvent  2018-08-14 09:25:29
#
#                                   repo  \
# 0        automationbs/testbugreporting
# 1                PowerShell/PowerShell
# 2                  thadiun/hello-world
# 3                PowerShell/PowerShell
# 4                PowerShell/PowerShell
# ...                                ...
# 9206801                     urbit/arvo
# 9206802    highcharts/highcharts-react
# 9206803           Loriowar/comindivion
# 9206804     TiiQu-Network/TQ-test-page
# 9206805         prominic/Moonshine-IDE
#
#                                                   repo_url  action  \
# 0        https://api.github.com/repos/automationbs/test...  opened
# 1        https://api.github.com/repos/PowerShell/PowerS...  closed
# 2         https://api.github.com/repos/thadiun/hello-world  closed
# 3        https://api.github.com/repos/PowerShell/PowerS...  closed
# 4        https://api.github.com/repos/PowerShell/PowerS...  closed
# ...                                                    ...     ...
# 9206801            https://api.github.com/repos/urbit/arvo  opened
# 9206802  https://api.github.com/repos/highcharts/highch...  closed
# 9206803  https://api.github.com/repos/Loriowar/comindivion  opened
# 9206804  https://api.github.com/repos/TiiQu-Network/TQ-...  closed
# 9206805  https://api.github.com/repos/prominic/Moonshin...  closed
#
#                                                      title  \
# 0                                            Default title
# 1                                               Show alias
# 2                   [Test] testing needs-triage (no delay)
# 3                                     $ENV in using module
# 4                Measure-Command does not measure its self
# ...                                                    ...
# 9206801            %bad-text trips up hall JSON conversion
# 9206802                            HighMaps mapBubble type
# 9206803  Add a validation on a belonging of a predicate...
# 9206804                     Error on submit with no values
# 9206805           Handle unknown tags in Visual Editor XML
#
#                                                     labels  \
# 0                                                      bug
# 1                       Issue-Question Resolution-Answered
# 2                                                   triage
# 3         Area-Language Issue-Question Resolution-Answered
# 4        Area-Cmdlets-Utility Issue-Question Resolution...
# ...                                                    ...
# 9206801      :hall / :talk cause known marks web interface
# 9206802                                      pending reply
# 9206803                              bug data manipulation
# 9206804                                                bug
# 9206805               Investigation PrimeFaces enhancement
#
#                                                       body
# 0        default description\n\n|Property | Value|\n|--...
# 1        <!--\r\n\r\nFor Windows PowerShell 5.1 issues,...
# 2                                                      NaN
# 3        # Summary of the new feature/enhancement\r\n\r...
# 4        ## The Issue\r\nI'm pretty sure this was just ...
# ...                                                    ...
# 9206801  Haven't tested this in detail yet, but pretty ...
# 9206802  Hello,\r\nIt is possible to create also HighMa...
# 9206803  Now user can change html content of the intera...
# 9206804  TypeError: Too few arguments in function sum (...
# 9206805  If provided Visual Editor XML brings some unkn...
#
# [9206500 rows x 9 columns]

# %%
# Number or different labels
not_high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                           count
# labels
# enhancement                              240489
# bug                                      236887
# security vulnerability                    52497
# question                                  34353
# feature                                   20431
# documentation                             17630
# Bug                                       12098
# help wanted                               10727
# wontfix                                    7180
# greenkeeper                                6767
# stat:awaiting response                     6530
# Sub Task Failing Test Paddle Frontend      6318
# good first issue                           6302
# enhancement help wanted                    6220
# invalid                                    6002
# task                                       5598
# feature request                            5533
# in progress                                5320
# duplicate                                  5177
# bug enhancement                            4829
# enhancement good first issue               4430
# npm-install-script                         4392
# status monika                              4277
# kind/bug                                   4254
# design                                     4143
# JAX Frontend Sub Task Failing Test         4011
# Enhancement                                3352
# Feature                                    3218
# watchout                                   3142
# bug help wanted                            3057
# type: bug                                  2911
# triage                                     2668
# frontend                                   2510
# action-needsmoderation                     2492
# new feature                                2453
# new-review user-submission                 2392
# Task                                       2348
# Type: Bug                                  2255
# documentation enhancement                  2234
# improvement                                2197
# weekly-digest                              2173
# todo                                       2165
# enhancement question                       2092
# new-version user-submission                2061
# Mend: dependency security vulnerability    2049
# feature-request                            1865
# discussion                                 1863
# backend                                    1849
# docs                                       1846
# bug fixed                                  1845

# %%
#Give each priority a label by number.
# 'Label encoding'. Makes is easier for machine learning models to work with categorical data.
high_priority["label"] = 0
high_priority["class"] = "high_priority"
high_priority.head()
# Out:
#              id         type           created_at  \
# 0  1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1  1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2  1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3  1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4  1.141756e+10  IssuesEvent  2020-02-03 00:08:03
#
#                                   repo  \
# 0            unitystation/unitystation
# 1  zowe/sample-spring-boot-api-service
# 2                   openmsupply/mobile
# 3  UltimateCodeMonkeys/CodeMonkeysMVVM
# 4   wordpress-mobile/WordPress-Android
#
#                                             repo_url  action  \
# 0  https://api.github.com/repos/unitystation/unit...  closed
# 1  https://api.github.com/repos/zowe/sample-sprin...  closed
# 2    https://api.github.com/repos/openmsupply/mobile  closed
# 3  https://api.github.com/repos/UltimateCodeMonke...  opened
# 4  https://api.github.com/repos/wordpress-mobile/...  closed
#
#                                                title  \
# 0  Client breaking NRE when using edit field on C...
# 1  The SDK provides a separate Java (no-Spring) l...
# 2                 Auto-log out after some time frame
# 3  Migrate: CodeMonkeys ViewModelNavigationServic...
# 4  IA Reader filter bottom sheet: manage untitled...
#
#                                               labels  \
# 0                   Bug High Priority In Progress UI
# 1  Feature: API Security Priority: High no-issue-...
# 2  Docs: not needed Effort: small Feature Module:...
# 3  Priority: High Status: In Progress Type: Maint...
# 4                   IA Reader [Pri] High [Type] Task
#
#                                                 body  label          class
# 0  ### Bug:\r\n\r\nIf you use the edit field of t...      0  high_priority
# 1  - The commons-spring library is split into:\r\...      0  high_priority
# 2  ## Is your feature request related to a proble...      0  high_priority
# 3  Migrate the Xamarin.Forms navigation service i...      0  high_priority
# 4  In the filter bottom sheet we introduced in th...      0  high_priority

# %%
not_high_priority["label"] = 1
not_high_priority["class"] = "not_high_priority" 
not_high_priority.head()
# Out:
# /tmp/ipykernel_13472/2987185790.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority["label"] = 1
# /tmp/ipykernel_13472/2987185790.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority["class"] = "not_high_priority"
#              id         type           created_at  \
# 0  1.141754e+10  IssuesEvent  2020-02-03 00:00:07
# 1  1.141754e+10  IssuesEvent  2020-02-03 00:00:12
# 2  1.141754e+10  IssuesEvent  2020-02-03 00:00:13
# 3  1.141754e+10  IssuesEvent  2020-02-03 00:00:16
# 4  1.141754e+10  IssuesEvent  2020-02-03 00:00:18
#
#                             repo  \
# 0  automationbs/testbugreporting
# 1          PowerShell/PowerShell
# 2            thadiun/hello-world
# 3          PowerShell/PowerShell
# 4          PowerShell/PowerShell
#
#                                             repo_url  action  \
# 0  https://api.github.com/repos/automationbs/test...  opened
# 1  https://api.github.com/repos/PowerShell/PowerS...  closed
# 2   https://api.github.com/repos/thadiun/hello-world  closed
# 3  https://api.github.com/repos/PowerShell/PowerS...  closed
# 4  https://api.github.com/repos/PowerShell/PowerS...  closed
#
#                                        title  \
# 0                              Default title
# 1                                 Show alias
# 2     [Test] testing needs-triage (no delay)
# 3                       $ENV in using module
# 4  Measure-Command does not measure its self
#
#                                               labels  \
# 0                                                bug
# 1                 Issue-Question Resolution-Answered
# 2                                             triage
# 3   Area-Language Issue-Question Resolution-Answered
# 4  Area-Cmdlets-Utility Issue-Question Resolution...
#
#                                                 body  label              class
# 0  default description\n\n|Property | Value|\n|--...      1  not_high_priority
# 1  <!--\r\n\r\nFor Windows PowerShell 5.1 issues,...      1  not_high_priority
# 2                                                NaN      1  not_high_priority
# 3  # Summary of the new feature/enhancement\r\n\r...      1  not_high_priority
# 4  ## The Issue\r\nI'm pretty sure this was just ...      1  not_high_priority

# %%
# Drop duplicates by the content of the body
high_priority = high_priority.drop_duplicates(subset=['title'], keep='last')
high_priority.dropna(inplace=True)
high_priority.reset_index(inplace=True)
high_priority.drop(columns=["index"] , inplace= True)
high_priority["class"].value_counts()
# Out:
# /tmp/ipykernel_13472/124914565.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_priority.dropna(inplace=True)
# /tmp/ipykernel_13472/124914565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_priority.drop(columns=["index"] , inplace= True)
# class
# high_priority    242908
# Name: count, dtype: int64

# %%
# Drop duplicates by the content of the body
not_high_priority = not_high_priority.drop_duplicates(subset=['title'], keep='last')
not_high_priority.dropna(inplace=True)
not_high_priority.reset_index(inplace=True)
not_high_priority.drop(columns=["index"] , inplace= True)
not_high_priority["class"].value_counts()
# Out:
# /tmp/ipykernel_13472/4269543193.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority.dropna(inplace=True)
# /tmp/ipykernel_13472/4269543193.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority.drop(columns=["index"] , inplace= True)
# class
# not_high_priority    1330864
# Name: count, dtype: int64

# %%
high_priority.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242908 entries, 0 to 242907
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          242908 non-null  float64
#  1   type        242908 non-null  object
#  2   created_at  242908 non-null  object
#  3   repo        242908 non-null  object
#  4   repo_url    242908 non-null  object
#  5   action      242908 non-null  object
#  6   title       242908 non-null  object
#  7   labels      242908 non-null  object
#  8   body        242908 non-null  object
#  9   label       242908 non-null  int64
#  10  class       242908 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 20.4+ MB

# %%
label_counts = high_priority["class"].value_counts()
label_counts_nhp = not_high_priority["class"].value_counts()
print(label_counts)
not_high_priority_count = label_counts_nhp["not_high_priority"]
print(not_high_priority_count)
hp_count = label_counts["high_priority"]
hp_count
# Out:
# class
# high_priority    242908
# Name: count, dtype: int64
# 1330864
# 242908

# %%
not_high_priority = not_high_priority.sample(frac=hp_count/not_high_priority_count, random_state=42)
not_high_priority
# Out:
#                    id         type           created_at  \
# 506660   2.774846e+10  IssuesEvent  2023-03-15 18:45:33
# 1124567  2.608744e+10  IssuesEvent  2022-12-26 06:02:34
# 886278   1.588172e+10  IssuesEvent  2021-04-09 15:08:34
# 180152   1.088138e+10  IssuesEvent  2019-11-17 17:23:15
# 387370   2.792452e+09  IssuesEvent  2015-05-11 00:39:07
# ...               ...          ...                  ...
# 1076238  1.517031e+10  IssuesEvent  2021-02-12 22:57:42
# 97808    2.655338e+10  IssuesEvent  2023-01-20 09:53:29
# 899891   1.795316e+10  IssuesEvent  2021-09-13 02:04:21
# 320232   1.115131e+10  IssuesEvent  2019-12-24 03:30:50
# 609847   1.309132e+10  IssuesEvent  2020-08-03 06:17:28
#
#                                    repo  \
# 506660                MPMG-DCC-UFMG/F01
# 1124567     orna-memory-hunting/storage
# 886278                   Ultimaker/Cura
# 180152                   WarEmu/WarBugs
# 387370              callmecavs/layzr.js
# ...                                 ...
# 1076238     getsentry/sentry-javascript
# 97808           LAION-AI/Open-Assistant
# 899891   OPGG-HACKTHON/MusicWard-Server
# 320232    smeeth-virpariya/Trello-Quora
# 609847                Rapptz/discord.py
#
#                                                   repo_url  action  \
# 506660      https://api.github.com/repos/MPMG-DCC-UFMG/F01  closed
# 1124567  https://api.github.com/repos/orna-memory-hunti...  closed
# 886278         https://api.github.com/repos/Ultimaker/Cura  closed
# 180152         https://api.github.com/repos/WarEmu/WarBugs  closed
# 387370    https://api.github.com/repos/callmecavs/layzr.js  closed
# ...                                                    ...     ...
# 1076238  https://api.github.com/repos/getsentry/sentry-...  opened
# 97808    https://api.github.com/repos/LAION-AI/Open-Ass...  closed
# 899891   https://api.github.com/repos/OPGG-HACKTHON/Mus...  closed
# 320232   https://api.github.com/repos/smeeth-virpariya/...  opened
# 609847      https://api.github.com/repos/Rapptz/discord.py  closed
#
#                                                      title  \
# 506660   Teste de generalizacao para a tag Despesas - P...
# 1124567                Increases earthen resistance by 80%
# 886278                         Cura crashes during preview
# 180152   [Scenario] "Gates of Ekrund' - Stuck next to Flag
# 387370                            Hidden images are loaded
# ...                                                    ...
# 1076238                 NPM 7 problem react version gatsby
# 97808                              Augment DIVERSE dataset
# 899891                                     SecurityUtil 수정
# 320232   Implement the endpoint "/userprofile/{userId}"...
# 609847        Get github username from discord integration
#
#                                                     labels  \
# 506660                     generalization test development
# 1124567  time 00h MSK q.3-Б / в бою выберешь - тайные и...
# 886278                         Status: Duplicate Type: Bug
# 180152                                  Map/Area Scenarios
# 387370                                             roadmap
# ...                                                    ...
# 1076238                               Status: Needs Triage
# 97808                                                 data
# 899891                                                  버그
# 320232                                         enhancement
# 609847                                  discord limitation
#
#                                                       body  label  \
# 506660   DoD: Realizar o teste de Generalização do vali...      1
# 1124567  # Trees & Toxins \r\n### Плюсы\r\n- **Increase...      1
# 886278   ### Application Version\n\n4.8.0\n\n### Platfo...      1
# 180152   I don't know how he got stuck there but if kep...      1
# 387370   Hey @callmecavs,\r\n\r\nIt appears that images...      1
# ...                                                    ...    ...
# 1076238  ## Package + Version\r\n"@sentry/gatsby": "^6....      1
# 97808    Create script to augment DIVERSE dataset into ...      1
# 899891   ## 개요\r\n> securityUtil 클래스 누락된 부분을 수정한다.\r\n\...      1
# 320232   This endpoint is used to get the details of an...      1
# 609847   ### The Problem\r\n\r\nI'm trying to make a bo...      1
#
#                      class
# 506660   not_high_priority
# 1124567  not_high_priority
# 886278   not_high_priority
# 180152   not_high_priority
# 387370   not_high_priority
# ...                    ...
# 1076238  not_high_priority
# 97808    not_high_priority
# 899891   not_high_priority
# 320232   not_high_priority
# 609847   not_high_priority
#
# [242908 rows x 11 columns]

# %%
all_priority = pd.concat([high_priority,not_high_priority] , ignore_index = True)
all_priority.tail()
# Out:
#                   id         type           created_at  \
# 485811  1.517031e+10  IssuesEvent  2021-02-12 22:57:42
# 485812  2.655338e+10  IssuesEvent  2023-01-20 09:53:29
# 485813  1.795316e+10  IssuesEvent  2021-09-13 02:04:21
# 485814  1.115131e+10  IssuesEvent  2019-12-24 03:30:50
# 485815  1.309132e+10  IssuesEvent  2020-08-03 06:17:28
#
#                                   repo  \
# 485811     getsentry/sentry-javascript
# 485812         LAION-AI/Open-Assistant
# 485813  OPGG-HACKTHON/MusicWard-Server
# 485814   smeeth-virpariya/Trello-Quora
# 485815               Rapptz/discord.py
#
#                                                  repo_url  action  \
# 485811  https://api.github.com/repos/getsentry/sentry-...  opened
# 485812  https://api.github.com/repos/LAION-AI/Open-Ass...  closed
# 485813  https://api.github.com/repos/OPGG-HACKTHON/Mus...  closed
# 485814  https://api.github.com/repos/smeeth-virpariya/...  opened
# 485815     https://api.github.com/repos/Rapptz/discord.py  closed
#
#                                                     title  \
# 485811                 NPM 7 problem react version gatsby
# 485812                            Augment DIVERSE dataset
# 485813                                    SecurityUtil 수정
# 485814  Implement the endpoint "/userprofile/{userId}"...
# 485815       Get github username from discord integration
#
#                       labels  \
# 485811  Status: Needs Triage
# 485812                  data
# 485813                    버그
# 485814           enhancement
# 485815    discord limitation
#
#                                                      body  label  \
# 485811  ## Package + Version\r\n"@sentry/gatsby": "^6....      1
# 485812  Create script to augment DIVERSE dataset into ...      1
# 485813  ## 개요\r\n> securityUtil 클래스 누락된 부분을 수정한다.\r\n\...      1
# 485814  This endpoint is used to get the details of an...      1
# 485815  ### The Problem\r\n\r\nI'm trying to make a bo...      1
#
#                     class
# 485811  not_high_priority
# 485812  not_high_priority
# 485813  not_high_priority
# 485814  not_high_priority
# 485815  not_high_priority

# %%
# Does this need to be more balanced?
all_priority["label"].value_counts()
# Out:
# label
# 0    242908
# 1    242908
# Name: count, dtype: int64

# %%
print(all_priority["title"][0])
print(all_priority["body"][0])
# Out:
# Auto-log out after some time frame
# ## Is your feature request related to a problem? Please describe.
#
# From @craigdrown
#
# IC Requirement: Automatically log a user out after a time frame of X for security reasons. Data should not be lost which was being worked on.
#
# ## Describe the solution you'd like
#
# Log the user out after X time
#
# ## Implementation
#
# Could use store custom data `logoutTimeoutPeriodInSecondsOrMinutes` to set the period..
#
# - Use [AppState](https://facebook.github.io/react-native/docs/appstate#addeventlistener) to hook into the app going into the background - log the user out if so. Android would go to sleep after X amount of time, putting the app into the background (I THINK, UNTESTED)
# - Use a package like https://www.npmjs.com/package/redux-idle-monitor to track activity, have a schedule that is reset each time an event happens.
# - Use the above package but combine it with the current user authentication scheduler (tries to re-auth against the server every X minutes, or the local DB if no connection available) - I think not good
#
# ## Describe alternatives you've considered
#
# Not having this in the dispensary/IC branch 🤣
#
# ## Additional context
#
# @wlthomson @mark-prins @Chris-Petty thoughts?

# %%
# Copy content of body to a new col named text
all_priority["text"] = all_priority["title"] + all_priority["body"]
all_priority.tail()
# Out:
#                   id         type           created_at  \
# 485811  1.517031e+10  IssuesEvent  2021-02-12 22:57:42
# 485812  2.655338e+10  IssuesEvent  2023-01-20 09:53:29
# 485813  1.795316e+10  IssuesEvent  2021-09-13 02:04:21
# 485814  1.115131e+10  IssuesEvent  2019-12-24 03:30:50
# 485815  1.309132e+10  IssuesEvent  2020-08-03 06:17:28
#
#                                   repo  \
# 485811     getsentry/sentry-javascript
# 485812         LAION-AI/Open-Assistant
# 485813  OPGG-HACKTHON/MusicWard-Server
# 485814   smeeth-virpariya/Trello-Quora
# 485815               Rapptz/discord.py
#
#                                                  repo_url  action  \
# 485811  https://api.github.com/repos/getsentry/sentry-...  opened
# 485812  https://api.github.com/repos/LAION-AI/Open-Ass...  closed
# 485813  https://api.github.com/repos/OPGG-HACKTHON/Mus...  closed
# 485814  https://api.github.com/repos/smeeth-virpariya/...  opened
# 485815     https://api.github.com/repos/Rapptz/discord.py  closed
#
#                                                     title  \
# 485811                 NPM 7 problem react version gatsby
# 485812                            Augment DIVERSE dataset
# 485813                                    SecurityUtil 수정
# 485814  Implement the endpoint "/userprofile/{userId}"...
# 485815       Get github username from discord integration
#
#                       labels  \
# 485811  Status: Needs Triage
# 485812                  data
# 485813                    버그
# 485814           enhancement
# 485815    discord limitation
#
#                                                      body  label  \
# 485811  ## Package + Version\r\n"@sentry/gatsby": "^6....      1
# 485812  Create script to augment DIVERSE dataset into ...      1
# 485813  ## 개요\r\n> securityUtil 클래스 누락된 부분을 수정한다.\r\n\...      1
# 485814  This endpoint is used to get the details of an...      1
# 485815  ### The Problem\r\n\r\nI'm trying to make a bo...      1
#
#                     class                                               text
# 485811  not_high_priority  NPM 7 problem react version gatsby## Package +...
# 485812  not_high_priority  Augment DIVERSE datasetCreate script to augmen...
# 485813  not_high_priority  SecurityUtil 수정## 개요\r\n> securityUtil 클래스 누락된...
# 485814  not_high_priority  Implement the endpoint "/userprofile/{userId}"...
# 485815  not_high_priority  Get github username from discord integration##...

# %%
all_priority["text"][0]
# Out:
# "Auto-log out after some time frame## Is your feature request related to a problem? Please describe.\r\n\r\nFrom @craigdrown \r\n\r\nIC Requirement: Automatically log a user out after a time frame of X for security reasons. Data should not be lost which was being worked on.\r\n\r\n## Describe the solution you'd like\r\n\r\nLog the user out after X time\r\n\r\n## Implementation\r\n\r\nCould use store custom data `logoutTimeoutPeriodInSecondsOrMinutes` to set the period..\r\n\r\n- Use [AppState](https://facebook.github.io/react-native/docs/appstate#addeventlistener) to hook into the app going into the background - log the user out if so. Android would go to sleep after X amount of time, putting the app into the background (I THINK, UNTESTED)\r\n- Use a package like https://www.npmjs.com/package/redux-idle-monitor to track activity, have a schedule that is reset each time an event happens.\r\n- Use the above package but combine it with the current user authentication scheduler (tries to re-auth against the server every X minutes, or the local DB if no connection available) - I think not good\r\n\r\n## Describe alternatives you've considered\r\n\r\nNot having this in the dispensary/IC branch 🤣 \r\n\r\n## Additional context\r\n\r\n@wlthomson @mark-prins @Chris-Petty thoughts?\r\n"

# %%
# Make a new dataframe with only text, label and class cols.
all_priority_subset = all_priority[["text" , "label" , "class"]]
all_priority_subset
# Out:
#                                                      text  label  \
# 0       Auto-log out after some time frame## Is your f...      0
# 1       Image Picker for SourceImplement an Android Im...      0
# 2       Fix Video Page ListItem Hovering Behaviour- Wh...      0
# 3       Escape shuttle reaches ludicrous speed## Descr...      0
# 4              constructing  virtual router structure\r\n      0
# ...                                                   ...    ...
# 485811  NPM 7 problem react version gatsby## Package +...      1
# 485812  Augment DIVERSE datasetCreate script to augmen...      1
# 485813  SecurityUtil 수정## 개요\r\n> securityUtil 클래스 누락된...      1
# 485814  Implement the endpoint "/userprofile/{userId}"...      1
# 485815  Get github username from discord integration##...      1
#
#                     class
# 0           high_priority
# 1           high_priority
# 2           high_priority
# 3           high_priority
# 4           high_priority
# ...                   ...
# 485811  not_high_priority
# 485812  not_high_priority
# 485813  not_high_priority
# 485814  not_high_priority
# 485815  not_high_priority
#
# [485816 rows x 3 columns]

# %%
# Convert to string
all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)
# Out:
# /tmp/ipykernel_13472/3106036705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)

# %%
all_priority_subset
# Out:
#                                                      text  label  \
# 0       Auto-log out after some time frame## Is your f...      0
# 1       Image Picker for SourceImplement an Android Im...      0
# 2       Fix Video Page ListItem Hovering Behaviour- Wh...      0
# 3       Escape shuttle reaches ludicrous speed## Descr...      0
# 4              constructing  virtual router structure\r\n      0
# ...                                                   ...    ...
# 485811  NPM 7 problem react version gatsby## Package +...      1
# 485812  Augment DIVERSE datasetCreate script to augmen...      1
# 485813  SecurityUtil 수정## 개요\r\n> securityUtil 클래스 누락된...      1
# 485814  Implement the endpoint "/userprofile/{userId}"...      1
# 485815  Get github username from discord integration##...      1
#
#                     class                                           text_str
# 0           high_priority  Auto-log out after some time frame## Is your f...
# 1           high_priority  Image Picker for SourceImplement an Android Im...
# 2           high_priority  Fix Video Page ListItem Hovering Behaviour- Wh...
# 3           high_priority  Escape shuttle reaches ludicrous speed## Descr...
# 4           high_priority         constructing  virtual router structure\r\n
# ...                   ...                                                ...
# 485811  not_high_priority  NPM 7 problem react version gatsby## Package +...
# 485812  not_high_priority  Augment DIVERSE datasetCreate script to augmen...
# 485813  not_high_priority  SecurityUtil 수정## 개요\r\n> securityUtil 클래스 누락된...
# 485814  not_high_priority  Implement the endpoint "/userprofile/{userId}"...
# 485815  not_high_priority  Get github username from discord integration##...
#
# [485816 rows x 4 columns]

# %%
# Clean the data.
all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_13472/63294665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)

# %%
# Make a subset with text_clean and label
priority_label_text = all_priority_subset[["text_clean" , "label"]]
priority_label_text
# Out:
#                                                text_clean  label
# 0       autolog out after some time frame is your feat...      0
# 1       image picker for sourceimplement an android im...      0
# 2       fix video page listitem hovering behaviour whe...      0
# 3       escape shuttle reaches ludicrous speed descrip...      0
# 4                                                     NaN      0
# ...                                                   ...    ...
# 485811  npm 7 problem react version gatsby package ver...      1
# 485812  augment diverse datasetcreate script to augmen...      1
# 485813  securityutil 수정 개요 securityutil 클래스 누락된 부분을 수정...      1
# 485814  implement the endpoint userprofileuserid to ge...      1
# 485815  get github username from discord integration t...      1
#
# [485816 rows x 2 columns]

# %%
# Need to dropna here since cleaning function returns NaN for not english text.
priority_label_text.dropna(inplace=True)
priority_label_text.reset_index(inplace=True)
priority_label_text.drop(columns=["index"] , inplace= True)

priority_label_text
# Out:
# /tmp/ipykernel_13472/239147930.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.dropna(inplace=True)
# /tmp/ipykernel_13472/239147930.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.drop(columns=["index"] , inplace= True)
#                                                text_clean  label
# 0       autolog out after some time frame is your feat...      0
# 1       image picker for sourceimplement an android im...      0
# 2       fix video page listitem hovering behaviour whe...      0
# 3       escape shuttle reaches ludicrous speed descrip...      0
# 4       binder doesnt load notebooks outside of the un...      0
# ...                                                   ...    ...
# 442383  npm 7 problem react version gatsby package ver...      1
# 442384  augment diverse datasetcreate script to augmen...      1
# 442385  securityutil 수정 개요 securityutil 클래스 누락된 부분을 수정...      1
# 442386  implement the endpoint userprofileuserid to ge...      1
# 442387  get github username from discord integration t...      1
#
# [442388 rows x 2 columns]

# %%
# 10% of the data for testing
test_df = priority_label_text.sample(frac=0.1, random_state=42)
# Remove test data from priority_label_text
priority_label_text = priority_label_text.drop(test_df.index)
test_df
# Out:
#                                                text_clean  label
# 240390  cardano indonesia meeting 3 24 january 2022 un...      1
# 326602  expose active services rest api card the micro...      1
# 425306  querycachememoryleakteststressuserlistenerremo...      1
# 78226   fix linter errors for applicationnow that lint...      0
# 259260  order show updated dateadd date updated to sho...      1
# ...                                                   ...    ...
# 292789  comprehensive themingin the comprehensive them...      1
# 142511  post title is not appearing when a post is sha...      0
# 214166  checkeredflag  emoji is missing from reactions...      0
# 83336   mapbox crashes randomly normally in low gps ar...      0
# 125854  allow front page image and attribution to be s...      0
#
# [44239 rows x 2 columns]

# %%
test_df.label.value_counts().to_frame()[:50]
# Out:
#        count
# label
# 0      22749
# 1      21490

# %%
test_df = test_df.reset_index(drop=True)
priority_label_text = priority_label_text.reset_index(drop=True) 
priority_label_text
# Out:
#                                                text_clean  label
# 0       autolog out after some time frame is your feat...      0
# 1       image picker for sourceimplement an android im...      0
# 2       fix video page listitem hovering behaviour whe...      0
# 3       escape shuttle reaches ludicrous speed descrip...      0
# 4       binder doesnt load notebooks outside of the un...      0
# ...                                                   ...    ...
# 398144  running monomerbased executables on windowshi ...      1
# 398145  shamir 1ofx groups scheme where someeach group...      1
# 398146  setting fishhistory to empty in configfish cra...      1
# 398147  augment diverse datasetcreate script to augmen...      1
# 398148  securityutil 수정 개요 securityutil 클래스 누락된 부분을 수정...      1
#
# [398149 rows x 2 columns]

# %%
# Clean dataset with clean text and labels.
# 0 = high priority, 1 = not high priority
priority_label_text.to_csv("csv/clean_priority_high_or_not_high.csv")

# %%
test_df.to_csv("csv/testset_priority_high_or_not_high_clean.csv")

# %%
pri = pd.read_csv("csv/clean_priority_high_or_not_high.csv", index_col=0)
pri
# Out:
#                                                text_clean  label
# 0       autolog out after some time frame is your feat...      0
# 1       image picker for sourceimplement an android im...      0
# 2       fix video page listitem hovering behaviour whe...      0
# 3       escape shuttle reaches ludicrous speed descrip...      0
# 4       binder doesnt load notebooks outside of the un...      0
# ...                                                   ...    ...
# 398144  running monomerbased executables on windowshi ...      1
# 398145  shamir 1ofx groups scheme where someeach group...      1
# 398146  setting fishhistory to empty in configfish cra...      1
# 398147  augment diverse datasetcreate script to augmen...      1
# 398148  securityutil 수정 개요 securityutil 클래스 누락된 부분을 수정...      1
#
# [398149 rows x 2 columns]

# %%
test = pd.read_csv("csv/testset_priority_high_or_not_high_clean.csv", index_col=0)
