# %% [markdown]
# # Data cleaning
# We want the class with labels as numerical value and the body with clean text.
#
# This will remove:
# * duplicates
# * NaN entires
# * non english
# * url, html
#
# * make it lowercase
# * combine title and body

# %%
import pandas as pd
import sys
sys.path.append("../../../scripts_shared/")
from preprocess_text import preprocess_text

# %%
# Read CSV into a dataframe
high_priority = pd.read_csv("csv/high/high_priority_no_td.csv", index_col=0)
not_high_priority = pd.read_csv("csv/random/random_no_td.csv", index_col=0)

# %%
contains_stale = not_high_priority['labels'].str.contains("stale", case=False, na=False)
not_high_priority= not_high_priority[~contains_stale].reset_index(drop=True)
not_high_priority.reset_index(drop=True, inplace=True)
not_high_priority
# Out:
#                    id         type           created_at  \
# 0        1.141754e+10  IssuesEvent  2020-02-03 00:00:07
# 1        1.141754e+10  IssuesEvent  2020-02-03 00:00:12
# 2        1.141754e+10  IssuesEvent  2020-02-03 00:00:13
# 3        1.141754e+10  IssuesEvent  2020-02-03 00:00:16
# 4        1.141754e+10  IssuesEvent  2020-02-03 00:00:18
# ...               ...          ...                  ...
# 1962497  8.109961e+09  IssuesEvent  2018-08-14 09:21:15
# 1962498  8.109961e+09  IssuesEvent  2018-08-14 09:21:16
# 1962499  8.109982e+09  IssuesEvent  2018-08-14 09:25:07
# 1962500  8.109983e+09  IssuesEvent  2018-08-14 09:25:24
# 1962501  8.109984e+09  IssuesEvent  2018-08-14 09:25:29
#
#                                   repo  \
# 0        automationbs/testbugreporting
# 1                PowerShell/PowerShell
# 2                  thadiun/hello-world
# 3                PowerShell/PowerShell
# 4                PowerShell/PowerShell
# ...                                ...
# 1962497                     urbit/arvo
# 1962498    highcharts/highcharts-react
# 1962499           Loriowar/comindivion
# 1962500     TiiQu-Network/TQ-test-page
# 1962501         prominic/Moonshine-IDE
#
#                                                   repo_url  action  \
# 0        https://api.github.com/repos/automationbs/test...  opened
# 1        https://api.github.com/repos/PowerShell/PowerS...  closed
# 2         https://api.github.com/repos/thadiun/hello-world  closed
# 3        https://api.github.com/repos/PowerShell/PowerS...  closed
# 4        https://api.github.com/repos/PowerShell/PowerS...  closed
# ...                                                    ...     ...
# 1962497            https://api.github.com/repos/urbit/arvo  opened
# 1962498  https://api.github.com/repos/highcharts/highch...  closed
# 1962499  https://api.github.com/repos/Loriowar/comindivion  opened
# 1962500  https://api.github.com/repos/TiiQu-Network/TQ-...  closed
# 1962501  https://api.github.com/repos/prominic/Moonshin...  closed
#
#                                                      title  \
# 0                                            Default title
# 1                                               Show alias
# 2                   [Test] testing needs-triage (no delay)
# 3                                     $ENV in using module
# 4                Measure-Command does not measure its self
# ...                                                    ...
# 1962497            %bad-text trips up hall JSON conversion
# 1962498                            HighMaps mapBubble type
# 1962499  Add a validation on a belonging of a predicate...
# 1962500                     Error on submit with no values
# 1962501           Handle unknown tags in Visual Editor XML
#
#                                                     labels  \
# 0                                                      bug
# 1                       Issue-Question Resolution-Answered
# 2                                                   triage
# 3         Area-Language Issue-Question Resolution-Answered
# 4        Area-Cmdlets-Utility Issue-Question Resolution...
# ...                                                    ...
# 1962497      :hall / :talk cause known marks web interface
# 1962498                                      pending reply
# 1962499                              bug data manipulation
# 1962500                                                bug
# 1962501               Investigation PrimeFaces enhancement
#
#                                                       body
# 0        default description\n\n|Property | Value|\n|--...
# 1        <!--\r\n\r\nFor Windows PowerShell 5.1 issues,...
# 2                                                      NaN
# 3        # Summary of the new feature/enhancement\r\n\r...
# 4        ## The Issue\r\nI'm pretty sure this was just ...
# ...                                                    ...
# 1962497  Haven't tested this in detail yet, but pretty ...
# 1962498  Hello,\r\nIt is possible to create also HighMa...
# 1962499  Now user can change html content of the intera...
# 1962500  TypeError: Too few arguments in function sum (...
# 1962501  If provided Visual Editor XML brings some unkn...
#
# [1962502 rows x 9 columns]

# %%
# Number or different labels
high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                   count
# labels
# bug high priority                 10435
# high priority                     10360
# High Priority                      7484
# enhancement high priority          5486
# Priority: High                     4751
# priority.High                      3694
# priority.High type.Task            3685
# priority.high type.task            3209
# priority.High type.Story           2979
# priority.high                      2749
# bug priority: high                 2306
# high-priority                      2262
# priority: high                     2178
# bug high-priority                  2159
# type.Story priority.High           2155
# priority.high type.story           2130
# type.Task priority.High            2022
# bug High Priority                  1888
# High priority                      1815
# Priority: High Type: Bug           1768
# priority:high                      1726
# bug priority:high                  1470
# High Priority bug                  1338
# Priority: High bug                 1200
# Bug High Priority                  1143
# feature high priority              1091
# enhancement priority: high         1090
# enhancement high-priority          1053
# enhancement priority:high           982
# priority-high                       955
# bug priority-high                   927
# enhancement High Priority           902
# bug Priority: High                  837
# Priority: High Type: Enhancement    835
# high priority task                  831
# bug High priority                   744
# priority high                       733
# priority.high type.bug              717
# priority: high type: bug            704
# Type: Bug Priority: High            639
# Bug Priority: High                  620
# High Priority enhancement           611
# documentation priority.High         600
# prio:high                           587
# Bug - High Priority                 562
# priority.High type.Enhancement      562
# bug prio-high                       541
# Priority: High Type: Feature        541
# priority.high type.enhancement      540
# priority/high                       537

# %%
high_priority[high_priority["repo"] == "python/mypy"]
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body]
# Index: []

# %%
# Remove mypy from the dataset
high_priority = high_priority[high_priority["repo"] != "python/mypy"]
high_priority
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3       1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4       1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...              ...          ...                  ...
# 373104  7.334924e+09  IssuesEvent  2018-03-06 01:09:12
# 373105  7.334984e+09  IssuesEvent  2018-03-06 01:28:23
# 373106  7.335034e+09  IssuesEvent  2018-03-06 01:44:11
# 373107  7.335035e+09  IssuesEvent  2018-03-06 01:44:26
# 373108  7.335039e+09  IssuesEvent  2018-03-06 01:45:34
#
#                                        repo  \
# 0                 unitystation/unitystation
# 1       zowe/sample-spring-boot-api-service
# 2                        openmsupply/mobile
# 3       UltimateCodeMonkeys/CodeMonkeysMVVM
# 4        wordpress-mobile/WordPress-Android
# ...                                     ...
# 373104           StrangeLoopGames/EcoIssues
# 373105                        asteca/ASteCA
# 373106               wh1ter0se/PowerUp-2018
# 373107               wh1ter0se/PowerUp-2018
# 373108                      xcat2/xcat-core
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/unitystation/unit...  closed
# 1       https://api.github.com/repos/zowe/sample-sprin...  closed
# 2         https://api.github.com/repos/openmsupply/mobile  closed
# 3       https://api.github.com/repos/UltimateCodeMonke...  opened
# 4       https://api.github.com/repos/wordpress-mobile/...  closed
# ...                                                   ...     ...
# 373104  https://api.github.com/repos/StrangeLoopGames/...  closed
# 373105         https://api.github.com/repos/asteca/ASteCA  closed
# 373106  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 373107  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 373108       https://api.github.com/repos/xcat2/xcat-core  closed
#
#                                                     title  \
# 0       Client breaking NRE when using edit field on C...
# 1       The SDK provides a separate Java (no-Spring) l...
# 2                      Auto-log out after some time frame
# 3       Migrate: CodeMonkeys ViewModelNavigationServic...
# 4       IA Reader filter bottom sheet: manage untitled...
# ...                                                   ...
# 373104       Meteor hit - Can no longer join server 6.4.1
# 373105  Improve performance of synth cluster generatio...
# 373106  Get and record refined PID loops for rotation ...
# 373107  Figure out why CyborgCommandSpit() runs early ...
# 373108  error message improvement when adding users in...
#
#                                                    labels  \
# 0                        Bug High Priority In Progress UI
# 1       Feature: API Security Priority: High no-issue-...
# 2       Docs: not needed Effort: small Feature Module:...
# 3       Priority: High Status: In Progress Type: Maint...
# 4                        IA Reader [Pri] High [Type] Task
# ...                                                   ...
# 373104                                      High Priority
# 373105           code_enhance p:high performance synth-cl
# 373106                 IRL development high priority java
# 373107                         R&D bug high priority java
# 373108      priority:high sprint1 status:pending type:bug
#
#                                                      body
# 0       ### Bug:\r\n\r\nIf you use the edit field of t...
# 1       - The commons-spring library is split into:\r\...
# 2       ## Is your feature request related to a proble...
# 3       Migrate the Xamarin.Forms navigation service i...
# 4       In the filter bottom sheet we introduced in th...
# ...                                                   ...
# 373104  Just had the meteor hit on our server and now ...
# 373105  Follow up on #227.\r\n\r\n#### 0. Initial `syn...
# 373106  Pretty simple, and pretty sure we already have...
# 373107  The problem is that when we run autonomous (so...
# 373108  Problem statement: error message when adding x...
#
# [373109 rows x 9 columns]

# %%
not_high_priority[not_high_priority["repo"] == "python/mypy"]
# Out:
#                    id         type           created_at         repo  \
# 20709    1.142706e+10  IssuesEvent  2020-02-03 23:33:27  python/mypy
# 20738    1.142707e+10  IssuesEvent  2020-02-03 23:35:24  python/mypy
# 36207    1.362788e+10  IssuesEvent  2020-09-24 13:13:03  python/mypy
# 44724    1.363241e+10  IssuesEvent  2020-09-24 19:36:27  python/mypy
# 62256    2.407484e+10  IssuesEvent  2022-09-18 17:03:35  python/mypy
# ...               ...          ...                  ...          ...
# 1943428  7.349652e+09  IssuesEvent  2018-03-08 11:27:27  python/mypy
# 1944204  7.349972e+09  IssuesEvent  2018-03-08 12:44:13  python/mypy
# 1944217  7.349979e+09  IssuesEvent  2018-03-08 12:45:41  python/mypy
# 1948970  1.785710e+10  IssuesEvent  2021-09-05 08:41:21  python/mypy
# 1961398  8.109448e+09  IssuesEvent  2018-08-14 07:36:08  python/mypy
#
#                                          repo_url  action  \
# 20709    https://api.github.com/repos/python/mypy  closed
# 20738    https://api.github.com/repos/python/mypy  closed
# 36207    https://api.github.com/repos/python/mypy  opened
# 44724    https://api.github.com/repos/python/mypy  opened
# 62256    https://api.github.com/repos/python/mypy  opened
# ...                                           ...     ...
# 1943428  https://api.github.com/repos/python/mypy  closed
# 1944204  https://api.github.com/repos/python/mypy  opened
# 1944217  https://api.github.com/repos/python/mypy  closed
# 1948970  https://api.github.com/repos/python/mypy  opened
# 1961398  https://api.github.com/repos/python/mypy  closed
#
#                                                      title  \
# 20709             Type of conditional expression is object
# 20738      Type inference of Tuples returns object instead
# 36207          Daemon support for --follow-imports=silent
# 44724    regression: assignment of 'builtins.type' now ...
# 62256    stubtest: more concise error for forgotten arg...
# ...                                                    ...
# 1943428  Crash when serializing property with forward r...
# 1944204  Suggest type annotations for partial types spa...
# 1944217  What to do about inferring types from multiple...
# 1948970  Name already defined error with warlus operato...
# 1961398         Multi-line -c flag doesn't work on Windows
#
#                                                     labels  \
# 20709    false-positive needs discussion priority-1-nor...
# 20738                   bug false-positive priority-0-high
# 36207                                              feature
# 44724                                                  bug
# 62256                                              feature
# ...                                                    ...
# 1943428            crash priority-0-high topic-incremental
# 1944204  feature priority-2-low topic-fine-grained-incr...
# 1944217  feature priority-0-high topic-fine-grained-inc...
# 1948970                                                bug
# 1961398                                 bug priority-2-low
#
#                                                       body
# 20709    The type of the following conditional expressi...
# 20738    While interacting with `zip` I encountered a v...
# 36207    After #5870 is done, it would be nice to also ...
# 44724    \r\n**Bug Report**\r\n\r\n#7963 causes a serio...
# 62256    **Feature**\r\n\r\nWhen the implementation add...
# ...                                                    ...
# 1943428  This serialization test case fails with a cras...
# 1944204  We don't support inferring partial types from ...
# 1944217  Typically mypy infers the type of the variable...
# 1948970  Invalid error for mypy: Name "x" already defin...
# 1961398  Simplest reproduction seems to be\n\n``` bash\...
#
# [312 rows x 9 columns]

# %%
# Remove mypy from the dataset
not_high_priority = not_high_priority[not_high_priority["repo"] != "python/mypy"]
not_high_priority
# Out:
#                    id         type           created_at  \
# 0        1.141754e+10  IssuesEvent  2020-02-03 00:00:07
# 1        1.141754e+10  IssuesEvent  2020-02-03 00:00:12
# 2        1.141754e+10  IssuesEvent  2020-02-03 00:00:13
# 3        1.141754e+10  IssuesEvent  2020-02-03 00:00:16
# 4        1.141754e+10  IssuesEvent  2020-02-03 00:00:18
# ...               ...          ...                  ...
# 1962497  8.109961e+09  IssuesEvent  2018-08-14 09:21:15
# 1962498  8.109961e+09  IssuesEvent  2018-08-14 09:21:16
# 1962499  8.109982e+09  IssuesEvent  2018-08-14 09:25:07
# 1962500  8.109983e+09  IssuesEvent  2018-08-14 09:25:24
# 1962501  8.109984e+09  IssuesEvent  2018-08-14 09:25:29
#
#                                   repo  \
# 0        automationbs/testbugreporting
# 1                PowerShell/PowerShell
# 2                  thadiun/hello-world
# 3                PowerShell/PowerShell
# 4                PowerShell/PowerShell
# ...                                ...
# 1962497                     urbit/arvo
# 1962498    highcharts/highcharts-react
# 1962499           Loriowar/comindivion
# 1962500     TiiQu-Network/TQ-test-page
# 1962501         prominic/Moonshine-IDE
#
#                                                   repo_url  action  \
# 0        https://api.github.com/repos/automationbs/test...  opened
# 1        https://api.github.com/repos/PowerShell/PowerS...  closed
# 2         https://api.github.com/repos/thadiun/hello-world  closed
# 3        https://api.github.com/repos/PowerShell/PowerS...  closed
# 4        https://api.github.com/repos/PowerShell/PowerS...  closed
# ...                                                    ...     ...
# 1962497            https://api.github.com/repos/urbit/arvo  opened
# 1962498  https://api.github.com/repos/highcharts/highch...  closed
# 1962499  https://api.github.com/repos/Loriowar/comindivion  opened
# 1962500  https://api.github.com/repos/TiiQu-Network/TQ-...  closed
# 1962501  https://api.github.com/repos/prominic/Moonshin...  closed
#
#                                                      title  \
# 0                                            Default title
# 1                                               Show alias
# 2                   [Test] testing needs-triage (no delay)
# 3                                     $ENV in using module
# 4                Measure-Command does not measure its self
# ...                                                    ...
# 1962497            %bad-text trips up hall JSON conversion
# 1962498                            HighMaps mapBubble type
# 1962499  Add a validation on a belonging of a predicate...
# 1962500                     Error on submit with no values
# 1962501           Handle unknown tags in Visual Editor XML
#
#                                                     labels  \
# 0                                                      bug
# 1                       Issue-Question Resolution-Answered
# 2                                                   triage
# 3         Area-Language Issue-Question Resolution-Answered
# 4        Area-Cmdlets-Utility Issue-Question Resolution...
# ...                                                    ...
# 1962497      :hall / :talk cause known marks web interface
# 1962498                                      pending reply
# 1962499                              bug data manipulation
# 1962500                                                bug
# 1962501               Investigation PrimeFaces enhancement
#
#                                                       body
# 0        default description\n\n|Property | Value|\n|--...
# 1        <!--\r\n\r\nFor Windows PowerShell 5.1 issues,...
# 2                                                      NaN
# 3        # Summary of the new feature/enhancement\r\n\r...
# 4        ## The Issue\r\nI'm pretty sure this was just ...
# ...                                                    ...
# 1962497  Haven't tested this in detail yet, but pretty ...
# 1962498  Hello,\r\nIt is possible to create also HighMa...
# 1962499  Now user can change html content of the intera...
# 1962500  TypeError: Too few arguments in function sum (...
# 1962501  If provided Visual Editor XML brings some unkn...
#
# [1962190 rows x 9 columns]

# %%
# Number or different labels
not_high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                           count
# labels
# enhancement                              244118
# bug                                      240559
# security vulnerability                    53086
# question                                  34827
# feature                                   20725
# documentation                             17936
# Bug                                       12282
# help wanted                               10875
# wontfix                                    7279
# greenkeeper                                6842
# stat:awaiting response                     6602
# Sub Task Failing Test Paddle Frontend      6463
# good first issue                           6418
# enhancement help wanted                    6290
# invalid                                    6093
# task                                       5668
# feature request                            5605
# in progress                                5372
# duplicate                                  5235
# bug enhancement                            4899
# enhancement good first issue               4516
# npm-install-script                         4452
# status monika                              4372
# kind/bug                                   4335
# design                                     4178
# JAX Frontend Sub Task Failing Test         4099
# Enhancement                                3402
# Feature                                    3266
# watchout                                   3241
# bug help wanted                            3094
# type: bug                                  2958
# triage                                     2701
# action-needsmoderation                     2551
# frontend                                   2536
# new feature                                2493
# new-review user-submission                 2417
# Task                                       2378
# Type: Bug                                  2292
# documentation enhancement                  2277
# improvement                                2225
# weekly-digest                              2211
# todo                                       2190
# enhancement question                       2121
# new-version user-submission                2089
# Mend: dependency security vulnerability    2073
# feature-request                            1898
# discussion                                 1887
# docs                                       1878
# backend                                    1869
# bug fixed                                  1863

# %%
#Give each priority a label by number.
# 'Label encoding'. Makes is easier for machine learning models to work with categorical data.
high_priority["label"] = 0
high_priority["class"] = "high_priority"
high_priority.head()
# Out:
#              id         type           created_at  \
# 0  1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1  1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2  1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3  1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4  1.141756e+10  IssuesEvent  2020-02-03 00:08:03
#
#                                   repo  \
# 0            unitystation/unitystation
# 1  zowe/sample-spring-boot-api-service
# 2                   openmsupply/mobile
# 3  UltimateCodeMonkeys/CodeMonkeysMVVM
# 4   wordpress-mobile/WordPress-Android
#
#                                             repo_url  action  \
# 0  https://api.github.com/repos/unitystation/unit...  closed
# 1  https://api.github.com/repos/zowe/sample-sprin...  closed
# 2    https://api.github.com/repos/openmsupply/mobile  closed
# 3  https://api.github.com/repos/UltimateCodeMonke...  opened
# 4  https://api.github.com/repos/wordpress-mobile/...  closed
#
#                                                title  \
# 0  Client breaking NRE when using edit field on C...
# 1  The SDK provides a separate Java (no-Spring) l...
# 2                 Auto-log out after some time frame
# 3  Migrate: CodeMonkeys ViewModelNavigationServic...
# 4  IA Reader filter bottom sheet: manage untitled...
#
#                                               labels  \
# 0                   Bug High Priority In Progress UI
# 1  Feature: API Security Priority: High no-issue-...
# 2  Docs: not needed Effort: small Feature Module:...
# 3  Priority: High Status: In Progress Type: Maint...
# 4                   IA Reader [Pri] High [Type] Task
#
#                                                 body  label          class
# 0  ### Bug:\r\n\r\nIf you use the edit field of t...      0  high_priority
# 1  - The commons-spring library is split into:\r\...      0  high_priority
# 2  ## Is your feature request related to a proble...      0  high_priority
# 3  Migrate the Xamarin.Forms navigation service i...      0  high_priority
# 4  In the filter bottom sheet we introduced in th...      0  high_priority

# %%
not_high_priority["label"] = 1
not_high_priority["class"] = "not_high_priority" 
not_high_priority.head()
# Out:
# /tmp/ipykernel_293120/2987185790.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority["label"] = 1
# /tmp/ipykernel_293120/2987185790.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority["class"] = "not_high_priority"
#              id         type           created_at  \
# 0  1.141754e+10  IssuesEvent  2020-02-03 00:00:07
# 1  1.141754e+10  IssuesEvent  2020-02-03 00:00:12
# 2  1.141754e+10  IssuesEvent  2020-02-03 00:00:13
# 3  1.141754e+10  IssuesEvent  2020-02-03 00:00:16
# 4  1.141754e+10  IssuesEvent  2020-02-03 00:00:18
#
#                             repo  \
# 0  automationbs/testbugreporting
# 1          PowerShell/PowerShell
# 2            thadiun/hello-world
# 3          PowerShell/PowerShell
# 4          PowerShell/PowerShell
#
#                                             repo_url  action  \
# 0  https://api.github.com/repos/automationbs/test...  opened
# 1  https://api.github.com/repos/PowerShell/PowerS...  closed
# 2   https://api.github.com/repos/thadiun/hello-world  closed
# 3  https://api.github.com/repos/PowerShell/PowerS...  closed
# 4  https://api.github.com/repos/PowerShell/PowerS...  closed
#
#                                        title  \
# 0                              Default title
# 1                                 Show alias
# 2     [Test] testing needs-triage (no delay)
# 3                       $ENV in using module
# 4  Measure-Command does not measure its self
#
#                                               labels  \
# 0                                                bug
# 1                 Issue-Question Resolution-Answered
# 2                                             triage
# 3   Area-Language Issue-Question Resolution-Answered
# 4  Area-Cmdlets-Utility Issue-Question Resolution...
#
#                                                 body  label              class
# 0  default description\n\n|Property | Value|\n|--...      1  not_high_priority
# 1  <!--\r\n\r\nFor Windows PowerShell 5.1 issues,...      1  not_high_priority
# 2                                                NaN      1  not_high_priority
# 3  # Summary of the new feature/enhancement\r\n\r...      1  not_high_priority
# 4  ## The Issue\r\nI'm pretty sure this was just ...      1  not_high_priority

# %%
# Drop duplicates by the content of the body
high_priority = high_priority.drop_duplicates(subset=['title'], keep='last')
high_priority.dropna(inplace=True)
high_priority.reset_index(inplace=True)
high_priority.drop(columns=["index"] , inplace= True)
high_priority["class"].value_counts()
# Out:
# /tmp/ipykernel_293120/124914565.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_priority.dropna(inplace=True)
# /tmp/ipykernel_293120/124914565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_priority.drop(columns=["index"] , inplace= True)
# class
# high_priority    242908
# Name: count, dtype: int64

# %%
# Drop duplicates by the content of the title
not_high_priority = not_high_priority.drop_duplicates(subset=['title'], keep='last')
not_high_priority.dropna(inplace=True)
not_high_priority.reset_index(inplace=True)
not_high_priority.drop(columns=["index"] , inplace= True)
not_high_priority["class"].value_counts()
# Out:
# /tmp/ipykernel_293120/3768055171.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority.dropna(inplace=True)
# /tmp/ipykernel_293120/3768055171.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority.drop(columns=["index"] , inplace= True)
# class
# not_high_priority    1348848
# Name: count, dtype: int64

# %%
high_priority.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242908 entries, 0 to 242907
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          242908 non-null  float64
#  1   type        242908 non-null  object
#  2   created_at  242908 non-null  object
#  3   repo        242908 non-null  object
#  4   repo_url    242908 non-null  object
#  5   action      242908 non-null  object
#  6   title       242908 non-null  object
#  7   labels      242908 non-null  object
#  8   body        242908 non-null  object
#  9   label       242908 non-null  int64
#  10  class       242908 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 20.4+ MB

# %%
label_counts = high_priority["class"].value_counts()
label_counts_nhp = not_high_priority["class"].value_counts()
print(label_counts)
not_high_priority_count = label_counts_nhp["not_high_priority"]
print(not_high_priority_count)
hp_count = label_counts["high_priority"]
hp_count
# Out:
# class
# high_priority    242908
# Name: count, dtype: int64
# 1348848
# 242908

# %%
not_high_priority = not_high_priority.sample(frac=hp_count/not_high_priority_count, random_state=42)
not_high_priority
# Out:
#                    id         type           created_at  \
# 643668   2.700045e+10  IssuesEvent  2023-02-10 07:11:42
# 956986   9.417758e+09  IssuesEvent  2019-04-10 17:31:20
# 612335   4.150918e+09  IssuesEvent  2016-06-15 18:52:52
# 735687   1.251640e+10  IssuesEvent  2020-06-03 09:19:04
# 433267   8.816403e+09  IssuesEvent  2018-12-30 10:11:36
# ...               ...          ...                  ...
# 579151   9.484295e+09  IssuesEvent  2019-04-22 05:52:06
# 209513   5.696062e+09  IssuesEvent  2017-04-16 06:54:30
# 1076027  1.516023e+10  IssuesEvent  2021-02-12 06:31:44
# 1020243  7.274215e+09  IssuesEvent  2018-02-21 09:13:52
# 208157   2.330509e+10  IssuesEvent  2022-08-07 22:24:38
#
#                                   repo  \
# 643668           LCTT/TranslateProject
# 956986            femueller/python-n26
# 612335               e-government-ua/i
# 735687              MenosGrante/Rekado
# 433267   29988122/Fate-Grand-Order_Lua
# ...                                ...
# 579151                   mhulse/kludgy
# 209513          mevdschee/php-crud-api
# 1076027  pythonindia/inpycon2020-tasks
# 1020243                   sass/libsass
# 208157      medetasi/homurua.github.io
#
#                                                   repo_url  action  \
# 643668   https://api.github.com/repos/LCTT/TranslatePro...  opened
# 956986   https://api.github.com/repos/femueller/python-n26  closed
# 612335      https://api.github.com/repos/e-government-ua/i  closed
# 735687     https://api.github.com/repos/MenosGrante/Rekado  closed
# 433267   https://api.github.com/repos/29988122/Fate-Gra...  closed
# ...                                                    ...     ...
# 579151          https://api.github.com/repos/mhulse/kludgy  closed
# 209513   https://api.github.com/repos/mevdschee/php-cru...  closed
# 1076027  https://api.github.com/repos/pythonindia/inpyc...  closed
# 1020243          https://api.github.com/repos/sass/libsass  closed
# 208157   https://api.github.com/repos/medetasi/homurua....  opened
#
#                                                      title  \
# 643668                                  是否考虑过使用经过审定的标准术语库？
# 956986                        Run flake8 for Travis builds
# 612335   Реализовать Системтаску получения содержимого ...
# 735687   [Feature request] Add application to the F-Dro...
# 433267   (ways to capture screen) Is "Screenshot by... ...
# ...                                                    ...
# 579151                                   Document cron job
# 209513        Need to add String message in Response Body
# 1076027                           Managing Lightning Talks
# 1020243  @extend inside @at-root (without: media) doesn...
# 208157                                        Gin 框架源码阅读笔记
#
#                                                     labels  \
# 643668                                            question
# 956986                                         enhancement
# 612335                        active test testing _wf-base
# 735687                                     4.1 enhancement
# 433267                                         enhancement
# ...                                                    ...
# 579151                         code documentation question
# 209513                               duplicate enhancement
# 1076027                                             wg/cfp
# 1020243  Bug - @at-root with/without Bug - @extends Bug...
# 208157             Gitalk 0376c8e3557555a8ef7dbf7dcd3a0007
#
#                                                       body  label  \
# 643668   ### Your Questions\n\n[术语在线](https://www.termo...      1
# 956986   Flake8 should automatically run on builds with...      1
# 612335   - [x] 1) Класс и название системтаски GetDocum...      1
# 735687   It would be nice for a better dirstribution to...      1
# 433267   I just played a bit around with the Settings i...      1
# ...                                                    ...    ...
# 579151   Work in progress:\r\n\r\n```bash\r\n# Check fo...      1
# 209513   API response body has sometimes 'null' string ...      1
# 1076027  Initial discussion:\r\n- Take input during the...      1
# 1020243  ``` scss\r\n.a {\r\n  display: block;\r\n}\r\n...      1
# 208157   https://wmf.im/p/gin-%E6%A1%86%E6%9E%B6%E6%BA%...      1
#
#                      class
# 643668   not_high_priority
# 956986   not_high_priority
# 612335   not_high_priority
# 735687   not_high_priority
# 433267   not_high_priority
# ...                    ...
# 579151   not_high_priority
# 209513   not_high_priority
# 1076027  not_high_priority
# 1020243  not_high_priority
# 208157   not_high_priority
#
# [242908 rows x 11 columns]

# %%
all_priority = pd.concat([high_priority,not_high_priority] , ignore_index = True)
all_priority.tail()
# Out:
#                   id         type           created_at  \
# 485811  9.484295e+09  IssuesEvent  2019-04-22 05:52:06
# 485812  5.696062e+09  IssuesEvent  2017-04-16 06:54:30
# 485813  1.516023e+10  IssuesEvent  2021-02-12 06:31:44
# 485814  7.274215e+09  IssuesEvent  2018-02-21 09:13:52
# 485815  2.330509e+10  IssuesEvent  2022-08-07 22:24:38
#
#                                  repo  \
# 485811                  mhulse/kludgy
# 485812         mevdschee/php-crud-api
# 485813  pythonindia/inpycon2020-tasks
# 485814                   sass/libsass
# 485815     medetasi/homurua.github.io
#
#                                                  repo_url  action  \
# 485811         https://api.github.com/repos/mhulse/kludgy  closed
# 485812  https://api.github.com/repos/mevdschee/php-cru...  closed
# 485813  https://api.github.com/repos/pythonindia/inpyc...  closed
# 485814          https://api.github.com/repos/sass/libsass  closed
# 485815  https://api.github.com/repos/medetasi/homurua....  opened
#
#                                                     title  \
# 485811                                  Document cron job
# 485812       Need to add String message in Response Body
# 485813                           Managing Lightning Talks
# 485814  @extend inside @at-root (without: media) doesn...
# 485815                                       Gin 框架源码阅读笔记
#
#                                                    labels  \
# 485811                        code documentation question
# 485812                              duplicate enhancement
# 485813                                             wg/cfp
# 485814  Bug - @at-root with/without Bug - @extends Bug...
# 485815            Gitalk 0376c8e3557555a8ef7dbf7dcd3a0007
#
#                                                      body  label  \
# 485811  Work in progress:\r\n\r\n```bash\r\n# Check fo...      1
# 485812  API response body has sometimes 'null' string ...      1
# 485813  Initial discussion:\r\n- Take input during the...      1
# 485814  ``` scss\r\n.a {\r\n  display: block;\r\n}\r\n...      1
# 485815  https://wmf.im/p/gin-%E6%A1%86%E6%9E%B6%E6%BA%...      1
#
#                     class
# 485811  not_high_priority
# 485812  not_high_priority
# 485813  not_high_priority
# 485814  not_high_priority
# 485815  not_high_priority

# %%
# Does this need to be more balanced?
all_priority["label"].value_counts()
# Out:
# label
# 0    242908
# 1    242908
# Name: count, dtype: int64

# %%
print(all_priority["title"][0])
print(all_priority["body"][0])
# Out:
# Auto-log out after some time frame
# ## Is your feature request related to a problem? Please describe.
#
# From @craigdrown
#
# IC Requirement: Automatically log a user out after a time frame of X for security reasons. Data should not be lost which was being worked on.
#
# ## Describe the solution you'd like
#
# Log the user out after X time
#
# ## Implementation
#
# Could use store custom data `logoutTimeoutPeriodInSecondsOrMinutes` to set the period..
#
# - Use [AppState](https://facebook.github.io/react-native/docs/appstate#addeventlistener) to hook into the app going into the background - log the user out if so. Android would go to sleep after X amount of time, putting the app into the background (I THINK, UNTESTED)
# - Use a package like https://www.npmjs.com/package/redux-idle-monitor to track activity, have a schedule that is reset each time an event happens.
# - Use the above package but combine it with the current user authentication scheduler (tries to re-auth against the server every X minutes, or the local DB if no connection available) - I think not good
#
# ## Describe alternatives you've considered
#
# Not having this in the dispensary/IC branch 🤣
#
# ## Additional context
#
# @wlthomson @mark-prins @Chris-Petty thoughts?

# %%
# Copy content of body to a new col named text
all_priority["text"] = all_priority["title"] + all_priority["body"]
all_priority.tail()
# Out:
#                   id         type           created_at  \
# 485811  9.484295e+09  IssuesEvent  2019-04-22 05:52:06
# 485812  5.696062e+09  IssuesEvent  2017-04-16 06:54:30
# 485813  1.516023e+10  IssuesEvent  2021-02-12 06:31:44
# 485814  7.274215e+09  IssuesEvent  2018-02-21 09:13:52
# 485815  2.330509e+10  IssuesEvent  2022-08-07 22:24:38
#
#                                  repo  \
# 485811                  mhulse/kludgy
# 485812         mevdschee/php-crud-api
# 485813  pythonindia/inpycon2020-tasks
# 485814                   sass/libsass
# 485815     medetasi/homurua.github.io
#
#                                                  repo_url  action  \
# 485811         https://api.github.com/repos/mhulse/kludgy  closed
# 485812  https://api.github.com/repos/mevdschee/php-cru...  closed
# 485813  https://api.github.com/repos/pythonindia/inpyc...  closed
# 485814          https://api.github.com/repos/sass/libsass  closed
# 485815  https://api.github.com/repos/medetasi/homurua....  opened
#
#                                                     title  \
# 485811                                  Document cron job
# 485812       Need to add String message in Response Body
# 485813                           Managing Lightning Talks
# 485814  @extend inside @at-root (without: media) doesn...
# 485815                                       Gin 框架源码阅读笔记
#
#                                                    labels  \
# 485811                        code documentation question
# 485812                              duplicate enhancement
# 485813                                             wg/cfp
# 485814  Bug - @at-root with/without Bug - @extends Bug...
# 485815            Gitalk 0376c8e3557555a8ef7dbf7dcd3a0007
#
#                                                      body  label  \
# 485811  Work in progress:\r\n\r\n```bash\r\n# Check fo...      1
# 485812  API response body has sometimes 'null' string ...      1
# 485813  Initial discussion:\r\n- Take input during the...      1
# 485814  ``` scss\r\n.a {\r\n  display: block;\r\n}\r\n...      1
# 485815  https://wmf.im/p/gin-%E6%A1%86%E6%9E%B6%E6%BA%...      1
#
#                     class                                               text
# 485811  not_high_priority  Document cron jobWork in progress:\r\n\r\n```b...
# 485812  not_high_priority  Need to add String message in Response Body AP...
# 485813  not_high_priority  Managing Lightning TalksInitial discussion:\r\...
# 485814  not_high_priority  @extend inside @at-root (without: media) doesn...
# 485815  not_high_priority  Gin 框架源码阅读笔记https://wmf.im/p/gin-%E6%A1%86%E6%...

# %%
all_priority["text"][0]
# Out:
# "Auto-log out after some time frame## Is your feature request related to a problem? Please describe.\r\n\r\nFrom @craigdrown \r\n\r\nIC Requirement: Automatically log a user out after a time frame of X for security reasons. Data should not be lost which was being worked on.\r\n\r\n## Describe the solution you'd like\r\n\r\nLog the user out after X time\r\n\r\n## Implementation\r\n\r\nCould use store custom data `logoutTimeoutPeriodInSecondsOrMinutes` to set the period..\r\n\r\n- Use [AppState](https://facebook.github.io/react-native/docs/appstate#addeventlistener) to hook into the app going into the background - log the user out if so. Android would go to sleep after X amount of time, putting the app into the background (I THINK, UNTESTED)\r\n- Use a package like https://www.npmjs.com/package/redux-idle-monitor to track activity, have a schedule that is reset each time an event happens.\r\n- Use the above package but combine it with the current user authentication scheduler (tries to re-auth against the server every X minutes, or the local DB if no connection available) - I think not good\r\n\r\n## Describe alternatives you've considered\r\n\r\nNot having this in the dispensary/IC branch 🤣 \r\n\r\n## Additional context\r\n\r\n@wlthomson @mark-prins @Chris-Petty thoughts?\r\n"

# %%
# Make a new dataframe with only text, label and class cols.
all_priority_subset = all_priority[["text" , "label" , "class"]]
all_priority_subset
# Out:
#                                                      text  label  \
# 0       Auto-log out after some time frame## Is your f...      0
# 1       Image Picker for SourceImplement an Android Im...      0
# 2       Fix Video Page ListItem Hovering Behaviour- Wh...      0
# 3       Escape shuttle reaches ludicrous speed## Descr...      0
# 4              constructing  virtual router structure\r\n      0
# ...                                                   ...    ...
# 485811  Document cron jobWork in progress:\r\n\r\n```b...      1
# 485812  Need to add String message in Response Body AP...      1
# 485813  Managing Lightning TalksInitial discussion:\r\...      1
# 485814  @extend inside @at-root (without: media) doesn...      1
# 485815  Gin 框架源码阅读笔记https://wmf.im/p/gin-%E6%A1%86%E6%...      1
#
#                     class
# 0           high_priority
# 1           high_priority
# 2           high_priority
# 3           high_priority
# 4           high_priority
# ...                   ...
# 485811  not_high_priority
# 485812  not_high_priority
# 485813  not_high_priority
# 485814  not_high_priority
# 485815  not_high_priority
#
# [485816 rows x 3 columns]

# %%
# Convert to string
all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)
# Out:
# /tmp/ipykernel_293120/3106036705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)

# %%
all_priority_subset
# Out:
#                                                      text  label  \
# 0       Auto-log out after some time frame## Is your f...      0
# 1       Image Picker for SourceImplement an Android Im...      0
# 2       Fix Video Page ListItem Hovering Behaviour- Wh...      0
# 3       Escape shuttle reaches ludicrous speed## Descr...      0
# 4              constructing  virtual router structure\r\n      0
# ...                                                   ...    ...
# 485811  Document cron jobWork in progress:\r\n\r\n```b...      1
# 485812  Need to add String message in Response Body AP...      1
# 485813  Managing Lightning TalksInitial discussion:\r\...      1
# 485814  @extend inside @at-root (without: media) doesn...      1
# 485815  Gin 框架源码阅读笔记https://wmf.im/p/gin-%E6%A1%86%E6%...      1
#
#                     class                                           text_str
# 0           high_priority  Auto-log out after some time frame## Is your f...
# 1           high_priority  Image Picker for SourceImplement an Android Im...
# 2           high_priority  Fix Video Page ListItem Hovering Behaviour- Wh...
# 3           high_priority  Escape shuttle reaches ludicrous speed## Descr...
# 4           high_priority         constructing  virtual router structure\r\n
# ...                   ...                                                ...
# 485811  not_high_priority  Document cron jobWork in progress:\r\n\r\n```b...
# 485812  not_high_priority  Need to add String message in Response Body AP...
# 485813  not_high_priority  Managing Lightning TalksInitial discussion:\r\...
# 485814  not_high_priority  @extend inside @at-root (without: media) doesn...
# 485815  not_high_priority  Gin 框架源码阅读笔记https://wmf.im/p/gin-%E6%A1%86%E6%...
#
# [485816 rows x 4 columns]

# %%
# Clean the data.
all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_293120/63294665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)

# %%
# Make a subset with text_clean and label
priority_label_text = all_priority_subset[["text_clean" , "label"]]
priority_label_text
# Out:
#                                                text_clean  label
# 0       autolog out after some time frame is your feat...      0
# 1       image picker for sourceimplement an android im...      0
# 2       fix video page listitem hovering behaviour whe...      0
# 3       escape shuttle reaches ludicrous speed descrip...      0
# 4                                                     NaN      0
# ...                                                   ...    ...
# 485811  document cron jobwork in progress bash check f...      1
# 485812  need to add string message in response body ap...      1
# 485813  managing lightning talksinitial discussion tak...      1
# 485814  extend inside atroot without media doesnt work...      1
# 485815                                                NaN      1
#
# [485816 rows x 2 columns]

# %%
# Need to dropna here since cleaning function returns NaN for not english text.
priority_label_text.dropna(inplace=True)
priority_label_text.reset_index(inplace=True)
priority_label_text.drop(columns=["index"] , inplace= True)

priority_label_text
# Out:
# /tmp/ipykernel_293120/239147930.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.dropna(inplace=True)
# /tmp/ipykernel_293120/239147930.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.drop(columns=["index"] , inplace= True)
#                                                text_clean  label
# 0       autolog out after some time frame is your feat...      0
# 1       image picker for sourceimplement an android im...      0
# 2       fix video page listitem hovering behaviour whe...      0
# 3       escape shuttle reaches ludicrous speed descrip...      0
# 4       binder doesnt load notebooks outside of the un...      0
# ...                                                   ...    ...
# 442653  hardcoded provincees in statisticsfrom harriek...      1
# 442654  document cron jobwork in progress bash check f...      1
# 442655  need to add string message in response body ap...      1
# 442656  managing lightning talksinitial discussion tak...      1
# 442657  extend inside atroot without media doesnt work...      1
#
# [442658 rows x 2 columns]

# %%
# Splitting the DataFrame
test_df = priority_label_text.sample(frac=0.05, random_state=1)  # Select 5% of the data
test_file_name = f"csv/clean_test_high_vs_random.csv"
test_df.to_csv(test_file_name, index=False)
priority_df = priority_label_text.drop(test_df.index)
priority_df.reset_index(drop=True, inplace=True)
priority_df
# Out:
#                                                text_clean  label
# 0       autolog out after some time frame is your feat...      0
# 1       image picker for sourceimplement an android im...      0
# 2       fix video page listitem hovering behaviour whe...      0
# 3       escape shuttle reaches ludicrous speed descrip...      0
# 4       binder doesnt load notebooks outside of the un...      0
# ...                                                   ...    ...
# 420520  函数状态异常 未找到函数执行入口文件shell login successful for t...      1
# 420521  hardcoded provincees in statisticsfrom harriek...      1
# 420522  document cron jobwork in progress bash check f...      1
# 420523  need to add string message in response body ap...      1
# 420524  managing lightning talksinitial discussion tak...      1
#
# [420525 rows x 2 columns]

# %%
# Clean dataset with clean text and labels.
# 0 = high priority, 1 = not high priority
file_name = f"csv/clean_high_vs_random.csv"
priority_df.to_csv(file_name)

# %%
pri = pd.read_csv(file_name)
pri
# Out:
#         Unnamed: 0                                         text_clean  label
# 0                0  autolog out after some time frame is your feat...      0
# 1                1  image picker for sourceimplement an android im...      0
# 2                2  fix video page listitem hovering behaviour whe...      0
# 3                3  escape shuttle reaches ludicrous speed descrip...      0
# 4                4  binder doesnt load notebooks outside of the un...      0
# ...            ...                                                ...    ...
# 420520      420520  函数状态异常 未找到函数执行入口文件shell login successful for t...      1
# 420521      420521  hardcoded provincees in statisticsfrom harriek...      1
# 420522      420522  document cron jobwork in progress bash check f...      1
# 420523      420523  need to add string message in response body ap...      1
# 420524      420524  managing lightning talksinitial discussion tak...      1
#
# [420525 rows x 3 columns]
