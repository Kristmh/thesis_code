# %% [markdown]
# # Data cleaning
# We want the class with labels as numerical value and the body with clean text.
#
# This will remove:
# * duplicates
# * NaN entires
# * non english
# * url, html
#
# * make it lowercase
# * combine title and body

# %%
import pandas as pd
import sys
import numpy as np
sys.path.append("../../../scripts_shared/")
from preprocess_text import preprocess_text

# %%
# Read CSV into a dataframe
#high_priority = pd.read_csv("csv/high_priority_no_td.csv", index_col=0)
#medium_priority = pd.read_csv("csv/medium_priority_no_td.csv", index_col=0)
low_priority = pd.read_csv("csv/low/low_priority_no_td.csv", index_col=0)
not_priority = pd.read_csv("csv/random/random_no_td.csv", index_col=0)

# %%
# Number or different labels
low_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# enhancement low priority                             5496
# low priority                                         5485
# bug low priority                                     2798
# Low Priority                                         2732
# pri:low pri:lowest                                   2692
# Priority: Low                                        2504
# priority: low                                        1191
# Priority: Low Type: Enhancement                      1155
# bug priority: low                                    1154
# auto-migrated Priority-Low Type-Enhancement          1150
# low-priority                                         1140
# enhancement low-priority                             1116
# enhancement priority:low                             1021
# enhancement priority: low                             968
# auto-migrated Priority-Low Type-Defect                889
# priority:low                                          829
# Low priority                                          741
# pri:lowest pri:low                                    725
# Being Redone Low Priority                             705
# Priority: Low Type: Bug                               674
# enhancement Low Priority                              673
# Coverity bug priority: low                            637
# Low Priority enhancement                              602
# priority.low type.story                               591
# priority-low                                          585
# enhancement priority-low                              565
# feature low priority                                  565
# Priority-Low Type-Enhancement                         565
# bug priority:low                                      553
# bug Low Priority                                      509
# bug low-priority                                      500
# priority.Low type.Story                               490
# request:new-pkg priority:low                          490
# pri:high pri:low pri:lowest                           446
# priority.Low                                          444
# priority.low                                          440
# Priority: Low Status: Available Type: Enhancement     425
# Enhancement Low Priority                              406
# enhancement Priority: Low                             368
# 🟩 priority: low 🚦 status: awaiting triage ✨ goa...    345
# priority low                                          345
# Bug Low Priority                                      333
# Priority: Low enhancement                             315
# low-priority bug                                      308
# Low Priority bug                                      305
# bug Priority: Low                                     300
# low prio                                              284
# Low priority enhancement                              279
# priority::low                                         272
# Priority-Low                                          263

# %%
not_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                           count
# labels
# enhancement                              244118
# bug                                      240687
# security vulnerability                    53086
# question                                  34833
# feature                                   20745
# documentation                             17938
# Bug                                       12282
# help wanted                               10875
# wontfix                                    7279
# greenkeeper                                6842
# stat:awaiting response                     6602
# Sub Task Failing Test Paddle Frontend      6463
# good first issue                           6418
# enhancement help wanted                    6290
# invalid                                    6093
# task                                       5668
# feature request                            5605
# in progress                                5372
# duplicate                                  5236
# bug enhancement                            4899
# enhancement good first issue               4516
# npm-install-script                         4452
# status monika                              4372
# kind/bug                                   4335
# design                                     4178
# JAX Frontend Sub Task Failing Test         4099
# Enhancement                                3402
# Feature                                    3266
# watchout                                   3241
# bug help wanted                            3094
# type: bug                                  2958
# triage                                     2701
# action-needsmoderation                     2551
# frontend                                   2536
# new feature                                2493
# new-review user-submission                 2417
# Task                                       2378
# Type: Bug                                  2292
# documentation enhancement                  2277
# improvement                                2225
# weekly-digest                              2211
# todo                                       2190
# enhancement question                       2121
# new-version user-submission                2089
# Mend: dependency security vulnerability    2073
# feature-request                            1898
# discussion                                 1887
# docs                                       1878
# backend                                    1869
# bug fixed                                  1863

# %%
contains_stale = not_priority['labels'].str.contains("stale", case=False, na=False)
not_priority= not_priority[~contains_stale].reset_index(drop=True)
not_priority.reset_index(drop=True, inplace=True)
not_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                           count
# labels
# enhancement                              244118
# bug                                      240687
# security vulnerability                    53086
# question                                  34833
# feature                                   20745
# documentation                             17938
# Bug                                       12282
# help wanted                               10875
# wontfix                                    7279
# greenkeeper                                6842
# stat:awaiting response                     6602
# Sub Task Failing Test Paddle Frontend      6463
# good first issue                           6418
# enhancement help wanted                    6290
# invalid                                    6093
# task                                       5668
# feature request                            5605
# in progress                                5372
# duplicate                                  5236
# bug enhancement                            4899
# enhancement good first issue               4516
# npm-install-script                         4452
# status monika                              4372
# kind/bug                                   4335
# design                                     4178
# JAX Frontend Sub Task Failing Test         4099
# Enhancement                                3402
# Feature                                    3266
# watchout                                   3241
# bug help wanted                            3094
# type: bug                                  2958
# triage                                     2701
# action-needsmoderation                     2551
# frontend                                   2536
# new feature                                2493
# new-review user-submission                 2417
# Task                                       2378
# Type: Bug                                  2292
# documentation enhancement                  2277
# improvement                                2225
# weekly-digest                              2211
# todo                                       2190
# enhancement question                       2121
# new-version user-submission                2089
# Mend: dependency security vulnerability    2073
# feature-request                            1898
# discussion                                 1887
# docs                                       1878
# backend                                    1869
# bug fixed                                  1863

# %%
#Give each priority a label by number.
# 'Label encoding'. Makes is easier for machine learning models to work with categorical data.
low_priority["labels"] = 0
low_priority["class"] = "low_priority"
not_priority["labels"] = 1
not_priority["class"] = "not_priority"

# %%
priority = pd.concat([low_priority, not_priority] , ignore_index = True)

# %%
priority[priority["repo"] == "python/mypy"]
# Out:
#                    id         type           created_at         repo  \
# 220467   1.142706e+10  IssuesEvent  2020-02-03 23:33:27  python/mypy
# 220496   1.142707e+10  IssuesEvent  2020-02-03 23:35:24  python/mypy
# 235965   1.362788e+10  IssuesEvent  2020-09-24 13:13:03  python/mypy
# 244482   1.363241e+10  IssuesEvent  2020-09-24 19:36:27  python/mypy
# 262014   2.407484e+10  IssuesEvent  2022-09-18 17:03:35  python/mypy
# ...               ...          ...                  ...          ...
# 2143186  7.349652e+09  IssuesEvent  2018-03-08 11:27:27  python/mypy
# 2143962  7.349972e+09  IssuesEvent  2018-03-08 12:44:13  python/mypy
# 2143975  7.349979e+09  IssuesEvent  2018-03-08 12:45:41  python/mypy
# 2148728  1.785710e+10  IssuesEvent  2021-09-05 08:41:21  python/mypy
# 2161156  8.109448e+09  IssuesEvent  2018-08-14 07:36:08  python/mypy
#
#                                          repo_url  action  \
# 220467   https://api.github.com/repos/python/mypy  closed
# 220496   https://api.github.com/repos/python/mypy  closed
# 235965   https://api.github.com/repos/python/mypy  opened
# 244482   https://api.github.com/repos/python/mypy  opened
# 262014   https://api.github.com/repos/python/mypy  opened
# ...                                           ...     ...
# 2143186  https://api.github.com/repos/python/mypy  closed
# 2143962  https://api.github.com/repos/python/mypy  opened
# 2143975  https://api.github.com/repos/python/mypy  closed
# 2148728  https://api.github.com/repos/python/mypy  opened
# 2161156  https://api.github.com/repos/python/mypy  closed
#
#                                                      title  labels  \
# 220467            Type of conditional expression is object       1
# 220496     Type inference of Tuples returns object instead       1
# 235965         Daemon support for --follow-imports=silent        1
# 244482   regression: assignment of 'builtins.type' now ...       1
# 262014   stubtest: more concise error for forgotten arg...       1
# ...                                                    ...     ...
# 2143186  Crash when serializing property with forward r...       1
# 2143962  Suggest type annotations for partial types spa...       1
# 2143975  What to do about inferring types from multiple...       1
# 2148728  Name already defined error with warlus operato...       1
# 2161156         Multi-line -c flag doesn't work on Windows       1
#
#                                                       body         class
# 220467   The type of the following conditional expressi...  not_priority
# 220496   While interacting with `zip` I encountered a v...  not_priority
# 235965   After #5870 is done, it would be nice to also ...  not_priority
# 244482   \r\n**Bug Report**\r\n\r\n#7963 causes a serio...  not_priority
# 262014   **Feature**\r\n\r\nWhen the implementation add...  not_priority
# ...                                                    ...           ...
# 2143186  This serialization test case fails with a cras...  not_priority
# 2143962  We don't support inferring partial types from ...  not_priority
# 2143975  Typically mypy infers the type of the variable...  not_priority
# 2148728  Invalid error for mypy: Name "x" already defin...  not_priority
# 2161156  Simplest reproduction seems to be\n\n``` bash\...  not_priority
#
# [312 rows x 10 columns]

# %%
# Remove mypy from the dataset
priority = priority[priority["repo"] != "python/mypy"]
priority
# Out:
#                    id         type           created_at  \
# 0        1.141755e+10  IssuesEvent  2020-02-03 00:02:50
# 1        1.141766e+10  IssuesEvent  2020-02-03 00:46:42
# 2        1.141777e+10  IssuesEvent  2020-02-03 01:25:06
# 3        1.141780e+10  IssuesEvent  2020-02-03 01:34:56
# 4        1.141786e+10  IssuesEvent  2020-02-03 01:52:04
# ...               ...          ...                  ...
# 2162255  8.109961e+09  IssuesEvent  2018-08-14 09:21:15
# 2162256  8.109961e+09  IssuesEvent  2018-08-14 09:21:16
# 2162257  8.109982e+09  IssuesEvent  2018-08-14 09:25:07
# 2162258  8.109983e+09  IssuesEvent  2018-08-14 09:25:24
# 2162259  8.109984e+09  IssuesEvent  2018-08-14 09:25:29
#
#                                 repo  \
# 0             poissonconsulting/term
# 1                WordPress/gutenberg
# 2                  MarkBind/markbind
# 3                  MarkBind/markbind
# 4             poissonconsulting/term
# ...                              ...
# 2162255                   urbit/arvo
# 2162256  highcharts/highcharts-react
# 2162257         Loriowar/comindivion
# 2162258   TiiQu-Network/TQ-test-page
# 2162259       prominic/Moonshine-IDE
#
#                                                   repo_url    action  \
# 0        https://api.github.com/repos/poissonconsulting...    opened
# 1         https://api.github.com/repos/WordPress/gutenberg    closed
# 2           https://api.github.com/repos/MarkBind/markbind  reopened
# 3           https://api.github.com/repos/MarkBind/markbind    closed
# 4        https://api.github.com/repos/poissonconsulting...    closed
# ...                                                    ...       ...
# 2162255            https://api.github.com/repos/urbit/arvo    opened
# 2162256  https://api.github.com/repos/highcharts/highch...    closed
# 2162257  https://api.github.com/repos/Loriowar/comindivion    opened
# 2162258  https://api.github.com/repos/TiiQu-Network/TQ-...    closed
# 2162259  https://api.github.com/repos/prominic/Moonshin...    closed
#
#                                                      title  labels  \
# 0              Document levels of validation in vld_term()       0
# 1                        Z-index issue using Classic block       0
# 2                    Indicate the language of a code block       0
# 3           Use one attribute name for header, title, name       0
# 4              Document levels of validation in vld_term()       0
# ...                                                    ...     ...
# 2162255            %bad-text trips up hall JSON conversion       1
# 2162256                            HighMaps mapBubble type       1
# 2162257  Add a validation on a belonging of a predicate...       1
# 2162258                     Error on submit with no values       1
# 2162259           Handle unknown tags in Visual Editor XML       1
#
#                                                       body         class
# 0               As this is what other functions reference.  low_priority
# 1        Selecting a link in the classic block and havi...  low_priority
# 2        **Tell us about your environment**\r\n\r\n* **...  low_priority
# 3        May be better to choose one of the three and u...  low_priority
# 4               As this is what other functions reference.  low_priority
# ...                                                    ...           ...
# 2162255  Haven't tested this in detail yet, but pretty ...  not_priority
# 2162256  Hello,\r\nIt is possible to create also HighMa...  not_priority
# 2162257  Now user can change html content of the intera...  not_priority
# 2162258  TypeError: Too few arguments in function sum (...  not_priority
# 2162259  If provided Visual Editor XML brings some unkn...  not_priority
#
# [2161948 rows x 10 columns]

# %%
# Drop duplicates by the content of the title
priority = priority.drop_duplicates(subset=['title'], keep='last')
priority.dropna(inplace=True)
priority.reset_index(inplace=True)
priority.drop(columns=["index"] , inplace= True)
priority["class"].value_counts()
# Out:
# /tmp/ipykernel_246870/1842014761.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority.dropna(inplace=True)
# /tmp/ipykernel_246870/1842014761.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority.drop(columns=["index"] , inplace= True)
# class
# not_priority    1348848
# low_priority     140869
# Name: count, dtype: int64

# %%
# Split the dataframe 
low_priority = priority.loc[priority['class'] == 'low_priority'].copy()
not_priority = priority.loc[priority['class'] == 'not_priority'].copy()

# %%
low_label_counts = low_priority["class"].value_counts()
not_label_counts = not_priority["class"].value_counts()
lp_count = low_label_counts["low_priority"]
print(f"low count: {lp_count}")
not_count = not_label_counts["not_priority"]
print(f"not count: {not_count}")
# Out:
# low count: 140869
# not count: 1348848

# %%
not_priority = not_priority.sample(frac=lp_count/not_count, random_state=42)
low_vs_not = pd.concat([low_priority, not_priority] , ignore_index = True)
low_vs_not["class"].value_counts()
# Out:
# class
# low_priority    140869
# not_priority    140869
# Name: count, dtype: int64

# %%
print(low_vs_not["title"][0])
print(low_vs_not["body"][0])
# Out:
# Z-index issue using Classic block
# Selecting a link in the classic block and having it active then selecting another link in the left sidebar it looked like this:
#
# ![screen shot 2018-05-31 at 18 37 33](https://user-images.githubusercontent.com/5323259/40795551-b05f6796-6502-11e8-8510-65198a4cf7df.png)

# %%
# Copy content of body to a new col named text
low_vs_not["text"] = low_vs_not["title"] + low_vs_not["body"]
low_vs_not.tail()
# Out:
#                   id         type           created_at  \
# 281733  9.413568e+09  IssuesEvent  2019-04-10 08:08:18
# 281734  8.815382e+09  IssuesEvent  2018-12-29 17:51:35
# 281735  1.309706e+10  IssuesEvent  2020-08-03 16:45:20
# 281736  1.998156e+10  IssuesEvent  2022-01-30 00:55:08
# 281737  9.782555e+09  IssuesEvent  2019-06-08 00:29:21
#
#                                     repo  \
# 281733                       IPVS-AS/MBP
# 281734  BITPlan/docker-semanticmediawiki
# 281735              gbif/portal-feedback
# 281736       jordanlambrecht/pb-oct-2022
# 281737                   xiaospider/test
#
#                                                  repo_url  action  \
# 281733           https://api.github.com/repos/IPVS-AS/MBP  closed
# 281734  https://api.github.com/repos/BITPlan/docker-se...  closed
# 281735  https://api.github.com/repos/gbif/portal-feedback  opened
# 281736  https://api.github.com/repos/jordanlambrecht/p...  closed
# 281737       https://api.github.com/repos/xiaospider/test  closed
#
#                                                     title  labels  \
# 281733  Monitoring: Allow the user to define abnormal ...       1
# 281734  RUN /bin/bash /docker-entrypoint.sh -smw step ...       1
# 281735  Null links on GrSciColl pagination in other la...       1
# 281736         TODO: Migrate to Strapi (or wordpress idk)       1
# 281737                Found a bug2019-06-08T00:29:20.032Z       1
#
#                                                      body         class  \
# 281733  The user should be able to define situations i...  not_priority
# 281734  I get the following error at Step 12:\n\nStep ...  not_priority
# 281735  The first-page on GrSciColl institutions, coll...  not_priority
# 281736  I'm on the fence about whether we should use S...  not_priority
# 281737                    I'm having a problem with this.  not_priority
#
#                                                      text
# 281733  Monitoring: Allow the user to define abnormal ...
# 281734  RUN /bin/bash /docker-entrypoint.sh -smw step ...
# 281735  Null links on GrSciColl pagination in other la...
# 281736  TODO: Migrate to Strapi (or wordpress idk)I'm ...
# 281737  Found a bug2019-06-08T00:29:20.032ZI'm having ...

# %%
low_vs_not["text"][0]
# Out:
# 'Z-index issue using Classic blockSelecting a link in the classic block and having it active then selecting another link in the left sidebar it looked like this:\r\n\r\n![screen shot 2018-05-31 at 18 37 33](https://user-images.githubusercontent.com/5323259/40795551-b05f6796-6502-11e8-8510-65198a4cf7df.png)\r\n'

# %%
# Make a new dataframe with only text, label and class cols.
all_priority_subset = low_vs_not[["text" , "labels" , "class"]]
all_priority_subset
# Out:
#                                                      text  labels  \
# 0       Z-index issue using Classic blockSelecting a l...       0
# 1       Indicate the language of a code block**Tell us...       0
# 2       Use one attribute name for header, title, name...       0
# 3       Document levels of validation in vld_term()As ...       0
# 4       Support puml files in boilerplatessee [this co...       0
# ...                                                   ...     ...
# 281733  Monitoring: Allow the user to define abnormal ...       1
# 281734  RUN /bin/bash /docker-entrypoint.sh -smw step ...       1
# 281735  Null links on GrSciColl pagination in other la...       1
# 281736  TODO: Migrate to Strapi (or wordpress idk)I'm ...       1
# 281737  Found a bug2019-06-08T00:29:20.032ZI'm having ...       1
#
#                class
# 0       low_priority
# 1       low_priority
# 2       low_priority
# 3       low_priority
# 4       low_priority
# ...              ...
# 281733  not_priority
# 281734  not_priority
# 281735  not_priority
# 281736  not_priority
# 281737  not_priority
#
# [281738 rows x 3 columns]

# %%
# Convert to string
all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)
# Out:
# /tmp/ipykernel_246870/3106036705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)

# %%
all_priority_subset
# Out:
#                                                      text  labels  \
# 0       Z-index issue using Classic blockSelecting a l...       0
# 1       Indicate the language of a code block**Tell us...       0
# 2       Use one attribute name for header, title, name...       0
# 3       Document levels of validation in vld_term()As ...       0
# 4       Support puml files in boilerplatessee [this co...       0
# ...                                                   ...     ...
# 281733  Monitoring: Allow the user to define abnormal ...       1
# 281734  RUN /bin/bash /docker-entrypoint.sh -smw step ...       1
# 281735  Null links on GrSciColl pagination in other la...       1
# 281736  TODO: Migrate to Strapi (or wordpress idk)I'm ...       1
# 281737  Found a bug2019-06-08T00:29:20.032ZI'm having ...       1
#
#                class                                           text_str
# 0       low_priority  Z-index issue using Classic blockSelecting a l...
# 1       low_priority  Indicate the language of a code block**Tell us...
# 2       low_priority  Use one attribute name for header, title, name...
# 3       low_priority  Document levels of validation in vld_term()As ...
# 4       low_priority  Support puml files in boilerplatessee [this co...
# ...              ...                                                ...
# 281733  not_priority  Monitoring: Allow the user to define abnormal ...
# 281734  not_priority  RUN /bin/bash /docker-entrypoint.sh -smw step ...
# 281735  not_priority  Null links on GrSciColl pagination in other la...
# 281736  not_priority  TODO: Migrate to Strapi (or wordpress idk)I'm ...
# 281737  not_priority  Found a bug2019-06-08T00:29:20.032ZI'm having ...
#
# [281738 rows x 4 columns]

# %%
# Clean the data.
all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_246870/63294665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)

# %%
# Make a subset with text_clean and label
priority_label_text = all_priority_subset[["text_clean" , "labels", "class"]]
priority_label_text
# Out:
#                                                text_clean  labels  \
# 0       zindex issue using classic blockselecting a li...       0
# 1       indicate the language of a code blocktell us a...       0
# 2       use one attribute name for header title namema...       0
# 3       document levels of validation in vldtermas thi...       0
# 4       support puml files in boilerplatessee this com...       0
# ...                                                   ...     ...
# 281733  monitoring allow the user to define abnormal s...       1
# 281734  run binbash dockerentrypointsh smw step is fai...       1
# 281735  null links on grscicoll pagination in other la...       1
# 281736  todo migrate to strapi or wordpress idkim on t...       1
# 281737  found a bug20190608t002920032zim having a prob...       1
#
#                class
# 0       low_priority
# 1       low_priority
# 2       low_priority
# 3       low_priority
# 4       low_priority
# ...              ...
# 281733  not_priority
# 281734  not_priority
# 281735  not_priority
# 281736  not_priority
# 281737  not_priority
#
# [281738 rows x 3 columns]

# %%
# Need to dropna here since cleaning function returns NaN for not english text.
priority_label_text.dropna(inplace=True)
priority_label_text.reset_index(inplace=True)
priority_label_text.drop(columns=["index"] , inplace= True)

priority_label_text
# Out:
# /tmp/ipykernel_246870/239147930.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.dropna(inplace=True)
# /tmp/ipykernel_246870/239147930.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.drop(columns=["index"] , inplace= True)
#                                                text_clean  labels  \
# 0       zindex issue using classic blockselecting a li...       0
# 1       indicate the language of a code blocktell us a...       0
# 2       use one attribute name for header title namema...       0
# 3       document levels of validation in vldtermas thi...       0
# 4       support puml files in boilerplatessee this com...       0
# ...                                                   ...     ...
# 258009  monitoring allow the user to define abnormal s...       1
# 258010  run binbash dockerentrypointsh smw step is fai...       1
# 258011  null links on grscicoll pagination in other la...       1
# 258012  todo migrate to strapi or wordpress idkim on t...       1
# 258013  found a bug20190608t002920032zim having a prob...       1
#
#                class
# 0       low_priority
# 1       low_priority
# 2       low_priority
# 3       low_priority
# 4       low_priority
# ...              ...
# 258009  not_priority
# 258010  not_priority
# 258011  not_priority
# 258012  not_priority
# 258013  not_priority
#
# [258014 rows x 3 columns]

# %%
# Splitting the DataFrame
test_df = priority_label_text.sample(frac=0.05, random_state=1)  # Select 5% of the data
priority_df = priority_label_text.drop(test_df.index) 
priority_df.reset_index(drop=True, inplace=True)
priority_df
# Out:
#                                                text_clean  labels  \
# 0       zindex issue using classic blockselecting a li...       0
# 1       indicate the language of a code blocktell us a...       0
# 2       use one attribute name for header title namema...       0
# 3       document levels of validation in vldtermas thi...       0
# 4       support puml files in boilerplatessee this com...       0
# ...                                                   ...     ...
# 245108  monitoring allow the user to define abnormal s...       1
# 245109  run binbash dockerentrypointsh smw step is fai...       1
# 245110  null links on grscicoll pagination in other la...       1
# 245111  todo migrate to strapi or wordpress idkim on t...       1
# 245112  found a bug20190608t002920032zim having a prob...       1
#
#                class
# 0       low_priority
# 1       low_priority
# 2       low_priority
# 3       low_priority
# 4       low_priority
# ...              ...
# 245108  not_priority
# 245109  not_priority
# 245110  not_priority
# 245111  not_priority
# 245112  not_priority
#
# [245113 rows x 3 columns]

# %%
test_file_name = f"csv/clean_test_low_vs_random.csv"
test_df.to_csv(test_file_name, index=False)

# %%
# Clean dataset with clean text and labels.
# 0 = high priority, 1 = not high priority
file_name = f"csv/clean_low_vs_random.csv"
priority_df.to_csv(file_name, index=False)

# %%
pri = pd.read_csv(file_name)
pri
# Out:
#                                                text_clean  labels  \
# 0       zindex issue using classic blockselecting a li...       0
# 1       indicate the language of a code blocktell us a...       0
# 2       use one attribute name for header title namema...       0
# 3       document levels of validation in vldtermas thi...       0
# 4       support puml files in boilerplatessee this com...       0
# ...                                                   ...     ...
# 245108  monitoring allow the user to define abnormal s...       1
# 245109  run binbash dockerentrypointsh smw step is fai...       1
# 245110  null links on grscicoll pagination in other la...       1
# 245111  todo migrate to strapi or wordpress idkim on t...       1
# 245112  found a bug20190608t002920032zim having a prob...       1
#
#                class
# 0       low_priority
# 1       low_priority
# 2       low_priority
# 3       low_priority
# 4       low_priority
# ...              ...
# 245108  not_priority
# 245109  not_priority
# 245110  not_priority
# 245111  not_priority
# 245112  not_priority
#
# [245113 rows x 3 columns]

# %%
test_df = pd.read_csv(test_file_name)
test_df
# Out:
#                                               text_clean  labels         class
# 0      login with microsoft user story as an editor i...       1  not_priority
# 1       06iileeのblog is downin 7a68938httpsgithubcomi...       1  not_priority
# 2      opening supportfrom lobaishttpscodegooglecomul...       0  low_priority
# 3      create implementation plan for enhanced datagr...       0  low_priority
# 4      right click on list view able to right click o...       1  not_priority
# ...                                                  ...     ...           ...
# 12896  add browser methods to runtimeit would be grea...       1  not_priority
# 12897  login page form icons not shownthe code makes ...       0  low_priority
# 12898  regressing timestampsbug report a transactions...       1  not_priority
# 12899  fluvio cluster releases list should hide devel...       0  low_priority
# 12900  warnings when building text containing literal...       0  low_priority
#
# [12901 rows x 3 columns]
