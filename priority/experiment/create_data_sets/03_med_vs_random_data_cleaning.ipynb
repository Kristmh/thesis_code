# %% [markdown]
# # Data cleaning
# We want the class with labels as numerical value and the body with clean text.
#
# This will remove:
# * duplicates
# * NaN entires
# * non english
# * url, html
#
# * make it lowercase
# * combine title and body

# %%
import pandas as pd
import sys
import numpy as np
sys.path.append("../../../scripts_shared/")
from preprocess_text import preprocess_text

# %%
# Read CSV into a dataframe
#high_priority = pd.read_csv("csv/high_priority_no_td.csv", index_col=0)
medium_priority = pd.read_csv("csv/medium/medium_priority_no_td.csv", index_col=0)
#low_priority = pd.read_csv("csv/low_priority_no_td.csv", index_col=0)
not_priority = pd.read_csv("csv/random/random_no_td.csv", index_col=0)

# %%
# Number or different labels
medium_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# auto-migrated Priority-Medium Type-Defect           22849
# Medium Priority                                      3415
# Priority: Medium                                     3042
# bug imported Priority-Medium                         2846
# auto-migrated Priority-Medium Type-Enhancement       2167
# medium priority                                      2051
# bug priority: medium                                 2013
# enhancement medium priority                          1905
# priority.Medium                                      1653
# migrated Priority: Medium Type: Bug                  1650
# bug medium priority                                  1564
# auto-migrated Priority-Medium Type-Sample            1523
# priority.Medium type.Story                           1448
# priority: medium                                     1401
# priority.Medium type.Task                            1353
# Priority: Medium Type: Bug                           1313
# priority.medium                                      1271
# Priority-Medium Type-Defect auto-migrated            1193
# Priority: Medium Type: Enhancement                   1191
# bug imported invalid Priority-Medium                 1146
# priority.medium type.story                           1013
# Priority-Medium Type-Defect                          1012
# enhancement priority: medium                          991
# 1 star bug imported Priority-Medium                   958
# type.Story priority.Medium                            937
# bug prio-medium                                       832
# priority.medium type.task                             783
# type.Task priority.Medium                             722
# 2–5 stars bug imported Priority-Medium                714
# priority:medium                                       712
# Medium priority                                       709
# enhancement priority:medium                           694
# bug Fixed Priority-Medium                             593
# prio:medium type:feature                              556
# enhancement prio-medium                               548
# C: Functionality E: All Editions P: Medium T: E...    547
# bug priority:medium                                   540
# priority.medium type.enhancement                      535
# priority.Medium type.Enhancement                      512
# bug imported Priority-Medium wontfix                  497
# enhancement Medium Priority                           473
# kind/bug area/docdb priority/medium                   463
# feature medium priority                               454
# enhancement imported Priority-Medium                  452
# bug Medium Priority                                   438
# C: Functionality P: Medium T: Enhancement             414
# Priority: Medium Type: Feature                        412
# Priority - Medium Type -Task                          404
# prio:medium type:bug                                  391
# type.Enhancement priority.Medium                      389

# %%
#Give each priority a label by number.
# 'Label encoding'. Makes is easier for machine learning models to work with categorical data.
medium_priority["labels"] = 0
medium_priority["class"] = "medium_priority"
not_priority["labels"] = 1
not_priority["class"] = "not_priority"

# %%
priority = pd.concat([medium_priority, not_priority] , ignore_index = True)

# %%
priority[priority["repo"] == "python/mypy"]
# Out:
#                    id         type           created_at         repo  \
# 269799   1.142706e+10  IssuesEvent  2020-02-03 23:33:27  python/mypy
# 269828   1.142707e+10  IssuesEvent  2020-02-03 23:35:24  python/mypy
# 285297   1.362788e+10  IssuesEvent  2020-09-24 13:13:03  python/mypy
# 293814   1.363241e+10  IssuesEvent  2020-09-24 19:36:27  python/mypy
# 311346   2.407484e+10  IssuesEvent  2022-09-18 17:03:35  python/mypy
# ...               ...          ...                  ...          ...
# 2192518  7.349652e+09  IssuesEvent  2018-03-08 11:27:27  python/mypy
# 2193294  7.349972e+09  IssuesEvent  2018-03-08 12:44:13  python/mypy
# 2193307  7.349979e+09  IssuesEvent  2018-03-08 12:45:41  python/mypy
# 2198060  1.785710e+10  IssuesEvent  2021-09-05 08:41:21  python/mypy
# 2210488  8.109448e+09  IssuesEvent  2018-08-14 07:36:08  python/mypy
#
#                                          repo_url  action  \
# 269799   https://api.github.com/repos/python/mypy  closed
# 269828   https://api.github.com/repos/python/mypy  closed
# 285297   https://api.github.com/repos/python/mypy  opened
# 293814   https://api.github.com/repos/python/mypy  opened
# 311346   https://api.github.com/repos/python/mypy  opened
# ...                                           ...     ...
# 2192518  https://api.github.com/repos/python/mypy  closed
# 2193294  https://api.github.com/repos/python/mypy  opened
# 2193307  https://api.github.com/repos/python/mypy  closed
# 2198060  https://api.github.com/repos/python/mypy  opened
# 2210488  https://api.github.com/repos/python/mypy  closed
#
#                                                      title  labels  \
# 269799            Type of conditional expression is object       1
# 269828     Type inference of Tuples returns object instead       1
# 285297         Daemon support for --follow-imports=silent        1
# 293814   regression: assignment of 'builtins.type' now ...       1
# 311346   stubtest: more concise error for forgotten arg...       1
# ...                                                    ...     ...
# 2192518  Crash when serializing property with forward r...       1
# 2193294  Suggest type annotations for partial types spa...       1
# 2193307  What to do about inferring types from multiple...       1
# 2198060  Name already defined error with warlus operato...       1
# 2210488         Multi-line -c flag doesn't work on Windows       1
#
#                                                       body         class
# 269799   The type of the following conditional expressi...  not_priority
# 269828   While interacting with `zip` I encountered a v...  not_priority
# 285297   After #5870 is done, it would be nice to also ...  not_priority
# 293814   \r\n**Bug Report**\r\n\r\n#7963 causes a serio...  not_priority
# 311346   **Feature**\r\n\r\nWhen the implementation add...  not_priority
# ...                                                    ...           ...
# 2192518  This serialization test case fails with a cras...  not_priority
# 2193294  We don't support inferring partial types from ...  not_priority
# 2193307  Typically mypy infers the type of the variable...  not_priority
# 2198060  Invalid error for mypy: Name "x" already defin...  not_priority
# 2210488  Simplest reproduction seems to be\n\n``` bash\...  not_priority
#
# [312 rows x 10 columns]

# %%
# Remove mypy from the dataset
priority = priority[priority["repo"] != "python/mypy"]
priority
# Out:
#                    id         type           created_at  \
# 0        1.141757e+10  IssuesEvent  2020-02-03 00:11:29
# 1        1.141781e+10  IssuesEvent  2020-02-03 01:38:13
# 2        1.141805e+10  IssuesEvent  2020-02-03 02:48:17
# 3        1.141809e+10  IssuesEvent  2020-02-03 03:00:58
# 4        1.141821e+10  IssuesEvent  2020-02-03 03:33:19
# ...               ...          ...                  ...
# 2211587  8.109961e+09  IssuesEvent  2018-08-14 09:21:15
# 2211588  8.109961e+09  IssuesEvent  2018-08-14 09:21:16
# 2211589  8.109982e+09  IssuesEvent  2018-08-14 09:25:07
# 2211590  8.109983e+09  IssuesEvent  2018-08-14 09:25:24
# 2211591  8.109984e+09  IssuesEvent  2018-08-14 09:25:29
#
#                                 repo  \
# 0            poissonconsulting/nlist
# 1          ericauv/ericauv-portfolio
# 2            poissonconsulting/nlist
# 3            poissonconsulting/nlist
# 4            poissonconsulting/nlist
# ...                              ...
# 2211587                   urbit/arvo
# 2211588  highcharts/highcharts-react
# 2211589         Loriowar/comindivion
# 2211590   TiiQu-Network/TQ-test-page
# 2211591       prominic/Moonshine-IDE
#
#                                                   repo_url  action  \
# 0        https://api.github.com/repos/poissonconsulting...  closed
# 1        https://api.github.com/repos/ericauv/ericauv-p...  closed
# 2        https://api.github.com/repos/poissonconsulting...  closed
# 3        https://api.github.com/repos/poissonconsulting...  opened
# 4        https://api.github.com/repos/poissonconsulting...  opened
# ...                                                    ...     ...
# 2211587            https://api.github.com/repos/urbit/arvo  opened
# 2211588  https://api.github.com/repos/highcharts/highch...  closed
# 2211589  https://api.github.com/repos/Loriowar/comindivion  opened
# 2211590  https://api.github.com/repos/TiiQu-Network/TQ-...  closed
# 2211591  https://api.github.com/repos/prominic/Moonshin...  closed
#
#                                                      title  labels  \
# 0        tidy.nlists should return table with term, est...       0
# 1                              Increase Indent of ListItem       0
# 2        deprecate as.nlist and as.nlists for as_nlist ...       0
# 3        Add as_mcmc and as_mcmc_list wrappers on as.mc...       0
# 4                     Add as.nlist.mcmc and as.nlists.mcmc       0
# ...                                                    ...     ...
# 2211587            %bad-text trips up hall JSON conversion       1
# 2211588                            HighMaps mapBubble type       1
# 2211589  Add a validation on a belonging of a predicate...       1
# 2211590                     Error on submit with no values       1
# 2211591           Handle unknown tags in Visual Editor XML       1
#
#                                                       body            class
# 0                                                      NaN  medium_priority
# 1        ListItems should have greater indent to differ...  medium_priority
# 2                                                      NaN  medium_priority
# 3        but\r\n```\r\n> as_mcmc(nlist(x = matrix(1:6, ...  medium_priority
# 4                                                      NaN  medium_priority
# ...                                                    ...              ...
# 2211587  Haven't tested this in detail yet, but pretty ...     not_priority
# 2211588  Hello,\r\nIt is possible to create also HighMa...     not_priority
# 2211589  Now user can change html content of the intera...     not_priority
# 2211590  TypeError: Too few arguments in function sum (...     not_priority
# 2211591  If provided Visual Editor XML brings some unkn...     not_priority
#
# [2211280 rows x 10 columns]

# %%
# Drop duplicates by the content of the body
priority = priority.drop_duplicates(subset=['title'], keep='last')
priority.dropna(inplace=True)
priority.reset_index(inplace=True)
priority.drop(columns=["index"] , inplace= True)
priority["class"].value_counts()
# Out:
# /tmp/ipykernel_271074/2859834588.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority.dropna(inplace=True)
# /tmp/ipykernel_271074/2859834588.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority.drop(columns=["index"] , inplace= True)
# class
# not_priority       1348848
# medium_priority     160379
# Name: count, dtype: int64

# %%
# Split the dataframe 
medium_priority = priority.loc[priority['class'] == 'medium_priority'].copy()
not_priority = priority.loc[priority['class'] == 'not_priority'].copy()

# %%
medium_label_counts = medium_priority["class"].value_counts()
not_label_counts = not_priority["class"].value_counts()
mp_count = medium_label_counts["medium_priority"]
print(f"med count: {mp_count}")
not_count = not_label_counts["not_priority"]
print(f"not count: {not_count}")
# Out:
# med count: 160379
# not count: 1348848

# %%
not_priority = not_priority.sample(frac=mp_count/not_count, random_state=42)
med_vs_not = pd.concat([medium_priority, not_priority] , ignore_index = True)
med_vs_not["class"].value_counts()
# Out:
# class
# medium_priority    160379
# not_priority       160379
# Name: count, dtype: int64

# %%
print(med_vs_not["title"][0])
print(med_vs_not["body"][0])
# Out:
# Increase Indent of ListItem
# ListItems should have greater indent to differentiate them from ListTitle

# %%
# Copy content of body to a new col named text
med_vs_not["text"] = med_vs_not["title"] + med_vs_not["body"]
med_vs_not.tail()
# Out:
#                   id         type           created_at  \
# 320753  2.713061e+10  IssuesEvent  2023-02-16 09:31:00
# 320754  2.662113e+10  IssuesEvent  2023-01-24 11:18:15
# 320755  2.712448e+10  IssuesEvent  2023-02-16 03:16:25
# 320756  1.362765e+10  IssuesEvent  2020-09-24 12:54:26
# 320757  5.578005e+09  IssuesEvent  2017-03-28 11:11:57
#
#                               repo  \
# 320753         parlemonde/1village
# 320754    LivelyKernel/lively.next
# 320755  cityofaustin/atd-data-tech
# 320756       homebridge/HAP-NodeJS
# 320757            SemsProject/MOST
#
#                                                  repo_url  action  \
# 320753   https://api.github.com/repos/parlemonde/1village  closed
# 320754  https://api.github.com/repos/LivelyKernel/live...  closed
# 320755  https://api.github.com/repos/cityofaustin/atd-...  closed
# 320756  https://api.github.com/repos/homebridge/HAP-No...  closed
# 320757      https://api.github.com/repos/SemsProject/MOST  closed
#
#                                                     title  labels  \
# 320753                      FRONT - Page 2  : Identifiant       1
# 320754  New Connection on sidebar confusing and unintu...       1
# 320755  Update number of projects visible by default i...       1
# 320756        Homekit TELEVISION Accessory icon iPadOS 14       1
# 320757                          don't compute diffs twice       1
#
#                                                      body         class  \
# 320753  - [x] Créer page \n- [x] Ajouter élèves\n- [x]...  not_priority
# 320754  I find the New Connection using the sidebar co...  not_priority
# 320755  <!-- Email -->\n<!-- meredith.quick@austintexa...  not_priority
# 320756  Hi Devs!\r\n\r\nJust installed iPadOS 14 GM Se...  not_priority
# 320757  ## Trac Ticket #8\n**component:** website\n**o...  not_priority
#
#                                                      text
# 320753  FRONT - Page 2  : Identifiant- [x] Créer page ...
# 320754  New Connection on sidebar confusing and unintu...
# 320755  Update number of projects visible by default i...
# 320756  Homekit TELEVISION Accessory icon iPadOS 14Hi ...
# 320757  don't compute diffs twice## Trac Ticket #8\n**...

# %%
med_vs_not["text"][0]
# Out:
# 'Increase Indent of ListItemListItems should have greater indent to differentiate them from ListTitle'

# %%
# Make a new dataframe with only text, label and class cols.
all_priority_subset = med_vs_not[["text" , "labels" , "class"]]
all_priority_subset
# Out:
#                                                      text  labels  \
# 0       Increase Indent of ListItemListItems should ha...       0
# 1       Add as_mcmc and as_mcmc_list wrappers on as.mc...       0
# 2       Create New Option For Dropdown Scriptable Obje...       0
# 3       Header takes too much vertical space on wide s...       0
# 4       PageBody extends past html containerWhen navig...       0
# ...                                                   ...     ...
# 320753  FRONT - Page 2  : Identifiant- [x] Créer page ...       1
# 320754  New Connection on sidebar confusing and unintu...       1
# 320755  Update number of projects visible by default i...       1
# 320756  Homekit TELEVISION Accessory icon iPadOS 14Hi ...       1
# 320757  don't compute diffs twice## Trac Ticket #8\n**...       1
#
#                   class
# 0       medium_priority
# 1       medium_priority
# 2       medium_priority
# 3       medium_priority
# 4       medium_priority
# ...                 ...
# 320753     not_priority
# 320754     not_priority
# 320755     not_priority
# 320756     not_priority
# 320757     not_priority
#
# [320758 rows x 3 columns]

# %%
# Convert to string
all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)
# Out:
# /tmp/ipykernel_271074/3106036705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)

# %%
all_priority_subset
# Out:
#                                                      text  labels  \
# 0       Increase Indent of ListItemListItems should ha...       0
# 1       Add as_mcmc and as_mcmc_list wrappers on as.mc...       0
# 2       Create New Option For Dropdown Scriptable Obje...       0
# 3       Header takes too much vertical space on wide s...       0
# 4       PageBody extends past html containerWhen navig...       0
# ...                                                   ...     ...
# 320753  FRONT - Page 2  : Identifiant- [x] Créer page ...       1
# 320754  New Connection on sidebar confusing and unintu...       1
# 320755  Update number of projects visible by default i...       1
# 320756  Homekit TELEVISION Accessory icon iPadOS 14Hi ...       1
# 320757  don't compute diffs twice## Trac Ticket #8\n**...       1
#
#                   class                                           text_str
# 0       medium_priority  Increase Indent of ListItemListItems should ha...
# 1       medium_priority  Add as_mcmc and as_mcmc_list wrappers on as.mc...
# 2       medium_priority  Create New Option For Dropdown Scriptable Obje...
# 3       medium_priority  Header takes too much vertical space on wide s...
# 4       medium_priority  PageBody extends past html containerWhen navig...
# ...                 ...                                                ...
# 320753     not_priority  FRONT - Page 2  : Identifiant- [x] Créer page ...
# 320754     not_priority  New Connection on sidebar confusing and unintu...
# 320755     not_priority  Update number of projects visible by default i...
# 320756     not_priority  Homekit TELEVISION Accessory icon iPadOS 14Hi ...
# 320757     not_priority  don't compute diffs twice## Trac Ticket #8\n**...
#
# [320758 rows x 4 columns]

# %%
# Clean the data.
all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_271074/63294665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)

# %%
# Make a subset with text_clean and label
priority_label_text = all_priority_subset[["text_clean" , "labels", "class"]]
priority_label_text
# Out:
#                                                text_clean  labels  \
# 0       increase indent of listitemlistitems should ha...       0
# 1       add asmcmc and asmcmclist wrappers on asmcmc a...       0
# 2       create new option for dropdown scriptable obje...       0
# 3       header takes too much vertical space on wide s...       0
# 4       pagebody extends past html containerwhen navig...       0
# ...                                                   ...     ...
# 320753                                                NaN       1
# 320754  new connection on sidebar confusing and unintu...       1
# 320755  update number of projects visible by default i...       1
# 320756  homekit television accessory icon ipados 14hi ...       1
# 320757  dont compute diffs twice trac ticket 8 compone...       1
#
#                   class
# 0       medium_priority
# 1       medium_priority
# 2       medium_priority
# 3       medium_priority
# 4       medium_priority
# ...                 ...
# 320753     not_priority
# 320754     not_priority
# 320755     not_priority
# 320756     not_priority
# 320757     not_priority
#
# [320758 rows x 3 columns]

# %%
# Need to dropna here since cleaning function returns NaN for not english text.
priority_label_text.dropna(inplace=True)
priority_label_text.reset_index(inplace=True)
priority_label_text.drop(columns=["index"] , inplace= True)

priority_label_text
# Out:
# /tmp/ipykernel_271074/239147930.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.dropna(inplace=True)
# /tmp/ipykernel_271074/239147930.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.drop(columns=["index"] , inplace= True)
#                                                text_clean  labels  \
# 0       increase indent of listitemlistitems should ha...       0
# 1       add asmcmc and asmcmclist wrappers on asmcmc a...       0
# 2       create new option for dropdown scriptable obje...       0
# 3       header takes too much vertical space on wide s...       0
# 4       pagebody extends past html containerwhen navig...       0
# ...                                                   ...     ...
# 290388  kfrg republic airportnew yorkusathis one is re...       1
# 290389  new connection on sidebar confusing and unintu...       1
# 290390  update number of projects visible by default i...       1
# 290391  homekit television accessory icon ipados 14hi ...       1
# 290392  dont compute diffs twice trac ticket 8 compone...       1
#
#                   class
# 0       medium_priority
# 1       medium_priority
# 2       medium_priority
# 3       medium_priority
# 4       medium_priority
# ...                 ...
# 290388     not_priority
# 290389     not_priority
# 290390     not_priority
# 290391     not_priority
# 290392     not_priority
#
# [290393 rows x 3 columns]

# %%
# Splitting the DataFrame
test_df = priority_label_text.sample(frac=0.05, random_state=1)  # Select 5% of the data
test_file_name = f"csv/clean_test_med_vs_random.csv"
test_df.to_csv(test_file_name, index=False)
priority_df = priority_label_text.drop(test_df.index)
priority_df.reset_index(drop=True, inplace=True)
priority_df
# Out:
#                                                text_clean  labels  \
# 0       increase indent of listitemlistitems should ha...       0
# 1       add asmcmc and asmcmclist wrappers on asmcmc a...       0
# 2       create new option for dropdown scriptable obje...       0
# 3       header takes too much vertical space on wide s...       0
# 4       pagebody extends past html containerwhen navig...       0
# ...                                                   ...     ...
# 275868  kfrg republic airportnew yorkusathis one is re...       1
# 275869  new connection on sidebar confusing and unintu...       1
# 275870  update number of projects visible by default i...       1
# 275871  homekit television accessory icon ipados 14hi ...       1
# 275872  dont compute diffs twice trac ticket 8 compone...       1
#
#                   class
# 0       medium_priority
# 1       medium_priority
# 2       medium_priority
# 3       medium_priority
# 4       medium_priority
# ...                 ...
# 275868     not_priority
# 275869     not_priority
# 275870     not_priority
# 275871     not_priority
# 275872     not_priority
#
# [275873 rows x 3 columns]

# %%
# Clean dataset with clean text and labels.
# 0 = high priority, 1 = not high priority
file_name = f"csv/clean_med_vs_random.csv"
priority_df.to_csv(file_name, index=False)

# %%
pri = pd.read_csv(file_name)
pri
# Out:
#                                                text_clean  labels  \
# 0       increase indent of listitemlistitems should ha...       0
# 1       add asmcmc and asmcmclist wrappers on asmcmc a...       0
# 2       create new option for dropdown scriptable obje...       0
# 3       header takes too much vertical space on wide s...       0
# 4       pagebody extends past html containerwhen navig...       0
# ...                                                   ...     ...
# 275868  kfrg republic airportnew yorkusathis one is re...       1
# 275869  new connection on sidebar confusing and unintu...       1
# 275870  update number of projects visible by default i...       1
# 275871  homekit television accessory icon ipados 14hi ...       1
# 275872  dont compute diffs twice trac ticket 8 compone...       1
#
#                   class
# 0       medium_priority
# 1       medium_priority
# 2       medium_priority
# 3       medium_priority
# 4       medium_priority
# ...                 ...
# 275868     not_priority
# 275869     not_priority
# 275870     not_priority
# 275871     not_priority
# 275872     not_priority
#
# [275873 rows x 3 columns]

# %%
test_df = pd.read_csv(test_file_name)
test_df
# Out:
#                                               text_clean  labels  \
# 0      automatically add priority to the task as the ...       0
# 1      apiregister endpoint for iot devices to regist...       1
# 2      bug rename webhookbackground in knativebuild i...       1
# 3      pciebackend spurious crash during recoverydue ...       1
# 4      make outtargetdist directory match artifactszi...       1
# ...                                                  ...     ...
# 14515  buyer interactions post release emails additio...       1
# 14516  glfw3 build error  please use the generated is...       1
# 14517  fe implement a warning popup to prevent data l...       0
# 14518  add a comment field to the individual stations...       0
# 14519  emulate sql server mysql statement batches in ...       0
#
#                  class
# 0      medium_priority
# 1         not_priority
# 2         not_priority
# 3         not_priority
# 4         not_priority
# ...                ...
# 14515     not_priority
# 14516     not_priority
# 14517  medium_priority
# 14518  medium_priority
# 14519  medium_priority
#
# [14520 rows x 3 columns]
