# %% [markdown]
# # Data cleaning
# We want the class with labels as numerical value and the body with clean text.
#
# This will remove:
# * duplicates
# * NaN entires
# * non english
# * url, html
#
# * make it lowercase
# * combine title and body

# %%
import pandas as pd
import sys
import numpy as np
sys.path.append("../../../scripts_shared/")
from preprocess_text import preprocess_text

# %%
# Read CSV into a dataframe
high_priority = pd.read_csv("csv/high/high_priority_no_td.csv", index_col=0)
medium_priority = pd.read_csv("csv/medium/medium_priority_no_td.csv", index_col=0)
low_priority = pd.read_csv("csv/low/low_priority_no_td.csv", index_col=0)

# %%
# Number or different labels
high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                   count
# labels
# bug high priority                 10435
# high priority                     10360
# High Priority                      7484
# enhancement high priority          5486
# Priority: High                     4751
# priority.High                      3694
# priority.High type.Task            3685
# priority.high type.task            3209
# priority.High type.Story           2979
# priority.high                      2749
# bug priority: high                 2306
# high-priority                      2262
# priority: high                     2178
# bug high-priority                  2159
# type.Story priority.High           2155
# priority.high type.story           2130
# type.Task priority.High            2022
# bug High Priority                  1888
# High priority                      1815
# Priority: High Type: Bug           1768
# priority:high                      1726
# bug priority:high                  1470
# High Priority bug                  1338
# Priority: High bug                 1200
# Bug High Priority                  1143
# feature high priority              1091
# enhancement priority: high         1090
# enhancement high-priority          1053
# enhancement priority:high           982
# priority-high                       955
# bug priority-high                   927
# enhancement High Priority           902
# bug Priority: High                  837
# Priority: High Type: Enhancement    835
# high priority task                  831
# bug High priority                   744
# priority high                       733
# priority.high type.bug              717
# priority: high type: bug            704
# Type: Bug Priority: High            639
# Bug Priority: High                  620
# High Priority enhancement           611
# documentation priority.High         600
# prio:high                           587
# Bug - High Priority                 562
# priority.High type.Enhancement      562
# bug prio-high                       541
# Priority: High Type: Feature        541
# priority.high type.enhancement      540
# priority/high                       537

# %%
#Give each priority a label by number.
# 'Label encoding'. Makes is easier for machine learning models to work with categorical data.
high_priority["labels"] = 0
high_priority["class"] = "high_priority"
medium_priority["labels"] = 1
medium_priority["class"] = "medium_priority"
low_priority["labels"] = 2
low_priority["class"] = "low_priority"
high_priority.head()
# Out:
#              id         type           created_at  \
# 0  1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1  1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2  1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3  1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4  1.141756e+10  IssuesEvent  2020-02-03 00:08:03
#
#                                   repo  \
# 0            unitystation/unitystation
# 1  zowe/sample-spring-boot-api-service
# 2                   openmsupply/mobile
# 3  UltimateCodeMonkeys/CodeMonkeysMVVM
# 4   wordpress-mobile/WordPress-Android
#
#                                             repo_url  action  \
# 0  https://api.github.com/repos/unitystation/unit...  closed
# 1  https://api.github.com/repos/zowe/sample-sprin...  closed
# 2    https://api.github.com/repos/openmsupply/mobile  closed
# 3  https://api.github.com/repos/UltimateCodeMonke...  opened
# 4  https://api.github.com/repos/wordpress-mobile/...  closed
#
#                                                title  labels  \
# 0  Client breaking NRE when using edit field on C...       0
# 1  The SDK provides a separate Java (no-Spring) l...       0
# 2                 Auto-log out after some time frame       0
# 3  Migrate: CodeMonkeys ViewModelNavigationServic...       0
# 4  IA Reader filter bottom sheet: manage untitled...       0
#
#                                                 body          class
# 0  ### Bug:\r\n\r\nIf you use the edit field of t...  high_priority
# 1  - The commons-spring library is split into:\r\...  high_priority
# 2  ## Is your feature request related to a proble...  high_priority
# 3  Migrate the Xamarin.Forms navigation service i...  high_priority
# 4  In the filter bottom sheet we introduced in th...  high_priority

# %%
priority = pd.concat([high_priority, medium_priority, low_priority] , ignore_index = True)

# %%
priority[priority["repo"] == "python/mypy"]
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body, class]
# Index: []

# %%
# Remove mypy from the dataset
priority = priority[priority["repo"] != "python/mypy"]
priority
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3       1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4       1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...              ...          ...                  ...
# 821952  2.060586e+10  IssuesEvent  2022-03-06 23:45:23
# 821953  7.334740e+09  IssuesEvent  2018-03-06 00:10:40
# 821954  7.334876e+09  IssuesEvent  2018-03-06 00:53:49
# 821955  7.335047e+09  IssuesEvent  2018-03-06 01:48:07
# 821956  7.335050e+09  IssuesEvent  2018-03-06 01:49:10
#
#                                        repo  \
# 0                 unitystation/unitystation
# 1       zowe/sample-spring-boot-api-service
# 2                        openmsupply/mobile
# 3       UltimateCodeMonkeys/CodeMonkeysMVVM
# 4        wordpress-mobile/WordPress-Android
# ...                                     ...
# 821952            bounswe/bounswe2022group1
# 821953                      hoodedice/notes
# 821954            zephyrproject-rtos/zephyr
# 821955                   uwnrg/minotaur-cpp
# 821956                   uwnrg/minotaur-cpp
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/unitystation/unit...  closed
# 1       https://api.github.com/repos/zowe/sample-sprin...  closed
# 2         https://api.github.com/repos/openmsupply/mobile  closed
# 3       https://api.github.com/repos/UltimateCodeMonke...  opened
# 4       https://api.github.com/repos/wordpress-mobile/...  closed
# ...                                                   ...     ...
# 821952  https://api.github.com/repos/bounswe/bounswe20...  closed
# 821953       https://api.github.com/repos/hoodedice/notes  opened
# 821954  https://api.github.com/repos/zephyrproject-rto...  closed
# 821955    https://api.github.com/repos/uwnrg/minotaur-cpp  closed
# 821956    https://api.github.com/repos/uwnrg/minotaur-cpp  closed
#
#                                                     title  labels  \
# 0       Client breaking NRE when using edit field on C...       0
# 1       The SDK provides a separate Java (no-Spring) l...       0
# 2                      Auto-log out after some time frame       0
# 3       Migrate: CodeMonkeys ViewModelNavigationServic...       0
# 4       IA Reader filter bottom sheet: manage untitled...       0
# ...                                                   ...     ...
# 821952                        Editing Navigator of  Wiki        2
# 821953                           Check if passwords match       2
# 821954  Add doc to samples/bluetooth/mesh & samples/bl...       2
# 821955                   Fix the photo in about dialog xd       2
# 821956  Move Record Video/Screenshot and camera select...       2
#
#                                                      body          class
# 0       ### Bug:\r\n\r\nIf you use the edit field of t...  high_priority
# 1       - The commons-spring library is split into:\r\...  high_priority
# 2       ## Is your feature request related to a proble...  high_priority
# 3       Migrate the Xamarin.Forms navigation service i...  high_priority
# 4       In the filter bottom sheet we introduced in th...  high_priority
# ...                                                   ...            ...
# 821952  The navigator of the wiki should be edited and...   low_priority
# 821953  JavaScript code (or see if possible without) t...   low_priority
# 821954  We should document what exactly the sample is ...   low_priority
# 821955                                                NaN   low_priority
# 821956            that can be opened from a dropdown menu   low_priority
#
# [821957 rows x 10 columns]

# %%
# Drop duplicates by the content of the body
priority = priority.drop_duplicates(subset=['title'], keep='last')
priority.dropna(inplace=True)
priority.reset_index(inplace=True)
priority.drop(columns=["index"] , inplace= True)
priority["class"].value_counts()
# Out:
# /tmp/ipykernel_293020/2859834588.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority.dropna(inplace=True)
# /tmp/ipykernel_293020/2859834588.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority.drop(columns=["index"] , inplace= True)
# class
# high_priority      236610
# medium_priority    160163
# low_priority       143121
# Name: count, dtype: int64

# %%
# Split the dataframe 
high_priority = priority.loc[priority['class'] == 'high_priority'].copy()
medium_priority = priority.loc[priority['class'] == 'medium_priority'].copy()
low_priority = priority.loc[priority['class'] == 'low_priority'].copy()

# %%
high_label_counts = high_priority["class"].value_counts()
medium_label_counts = medium_priority["class"].value_counts()
low_label_counts = low_priority["class"].value_counts()
hp_count = high_label_counts["high_priority"]
print(hp_count)
mp_count = medium_label_counts["medium_priority"]
print(mp_count)
lp_count = low_label_counts["low_priority"]
lp_count
# Out:
# 236610
# 160163
# 143121

# %%
medium_priority = medium_priority.sample(frac=lp_count/mp_count, random_state=42)
med_and_low_priority = pd.concat([medium_priority, low_priority] , ignore_index = True)
med_and_low_priority["class"].value_counts()
# Out:
# class
# medium_priority    143121
# low_priority       143121
# Name: count, dtype: int64

# %%
med_and_low_priority["labels"] = 1
med_and_low_priority["class"] = "medium_and_low_priority"
med_and_low_priority["class"].value_counts()
# Out:
# class
# medium_and_low_priority    286242
# Name: count, dtype: int64

# %%
med_and_low_label_counts = med_and_low_priority["class"].value_counts()
ml_count = med_and_low_label_counts["medium_and_low_priority"]
ml_count
# Out:
# 286242

# %%
med_and_low_priority = med_and_low_priority.sample(frac=hp_count/ml_count, random_state=42)
all_priority = pd.concat([high_priority, med_and_low_priority] , ignore_index = True)
all_priority["class"].value_counts()
# Out:
# class
# high_priority              236610
# medium_and_low_priority    236610
# Name: count, dtype: int64

# %%
print(all_priority["title"][0])
print(all_priority["body"][0])
# Out:
# Auto-log out after some time frame
# ## Is your feature request related to a problem? Please describe.
#
# From @craigdrown
#
# IC Requirement: Automatically log a user out after a time frame of X for security reasons. Data should not be lost which was being worked on.
#
# ## Describe the solution you'd like
#
# Log the user out after X time
#
# ## Implementation
#
# Could use store custom data `logoutTimeoutPeriodInSecondsOrMinutes` to set the period..
#
# - Use [AppState](https://facebook.github.io/react-native/docs/appstate#addeventlistener) to hook into the app going into the background - log the user out if so. Android would go to sleep after X amount of time, putting the app into the background (I THINK, UNTESTED)
# - Use a package like https://www.npmjs.com/package/redux-idle-monitor to track activity, have a schedule that is reset each time an event happens.
# - Use the above package but combine it with the current user authentication scheduler (tries to re-auth against the server every X minutes, or the local DB if no connection available) - I think not good
#
# ## Describe alternatives you've considered
#
# Not having this in the dispensary/IC branch 🤣
#
# ## Additional context
#
# @wlthomson @mark-prins @Chris-Petty thoughts?

# %%
# Copy content of body to a new col named text
all_priority["text"] = all_priority["title"] + all_priority["body"]
all_priority.tail()
# Out:
#                   id         type           created_at  \
# 473215  5.903893e+09  IssuesEvent  2017-05-19 08:18:32
# 473216  8.817135e+09  IssuesEvent  2018-12-30 19:46:09
# 473217  1.295208e+10  IssuesEvent  2020-07-19 19:10:37
# 473218  2.096899e+10  IssuesEvent  2022-03-28 09:33:41
# 473219  4.725469e+09  IssuesEvent  2016-10-18 06:43:30
#
#                                 repo  \
# 473215           TEAMMATES/teammates
# 473216           toobigtoignore/issf
# 473217  banzaicloud/logging-operator
# 473218                 Igalia/wolvic
# 473219                   pmem/issues
#
#                                                  repo_url  action  \
# 473215   https://api.github.com/repos/TEAMMATES/teammates  opened
# 473216   https://api.github.com/repos/toobigtoignore/issf  closed
# 473217  https://api.github.com/repos/banzaicloud/loggi...  closed
# 473218         https://api.github.com/repos/Igalia/wolvic  closed
# 473219           https://api.github.com/repos/pmem/issues  closed
#
#                                                     title  labels  \
# 473215                   Include MOTD feature in CI tests       1
# 473216  Checkbox to disable tweeting displayed for non...       1
# 473217          Add additional labels to service monitors       1
# 473218        No mic button in the Keyboard for HVR build       1
# 473219  rpmem: errno is not set when passing invalid l...       1
#
#                                                      body  \
# 473215  Current:\r\n* Message of the Day feature is om...
# 473216  When contributing Case Study or Capacity Devel...
# 473217  **Is your feature request related to a problem...
# 473218  ## Configuration\r\n\r\n<!--- State the versio...
# 473219  1) create local pool of **X** size via malloc(...
#
#                           class  \
# 473215  medium_and_low_priority
# 473216  medium_and_low_priority
# 473217  medium_and_low_priority
# 473218  medium_and_low_priority
# 473219  medium_and_low_priority
#
#                                                      text
# 473215  Include MOTD feature in CI testsCurrent:\r\n* ...
# 473216  Checkbox to disable tweeting displayed for non...
# 473217  Add additional labels to service monitors**Is ...
# 473218  No mic button in the Keyboard for HVR build## ...
# 473219  rpmem: errno is not set when passing invalid l...

# %%
all_priority["text"][0]
# Out:
# "Auto-log out after some time frame## Is your feature request related to a problem? Please describe.\r\n\r\nFrom @craigdrown \r\n\r\nIC Requirement: Automatically log a user out after a time frame of X for security reasons. Data should not be lost which was being worked on.\r\n\r\n## Describe the solution you'd like\r\n\r\nLog the user out after X time\r\n\r\n## Implementation\r\n\r\nCould use store custom data `logoutTimeoutPeriodInSecondsOrMinutes` to set the period..\r\n\r\n- Use [AppState](https://facebook.github.io/react-native/docs/appstate#addeventlistener) to hook into the app going into the background - log the user out if so. Android would go to sleep after X amount of time, putting the app into the background (I THINK, UNTESTED)\r\n- Use a package like https://www.npmjs.com/package/redux-idle-monitor to track activity, have a schedule that is reset each time an event happens.\r\n- Use the above package but combine it with the current user authentication scheduler (tries to re-auth against the server every X minutes, or the local DB if no connection available) - I think not good\r\n\r\n## Describe alternatives you've considered\r\n\r\nNot having this in the dispensary/IC branch 🤣 \r\n\r\n## Additional context\r\n\r\n@wlthomson @mark-prins @Chris-Petty thoughts?\r\n"

# %%
# Make a new dataframe with only text, label and class cols.
all_priority_subset = all_priority[["text" , "labels" , "class"]]
all_priority_subset
# Out:
#                                                      text  labels  \
# 0       Auto-log out after some time frame## Is your f...       0
# 1       Image Picker for SourceImplement an Android Im...       0
# 2       Fix Video Page ListItem Hovering Behaviour- Wh...       0
# 3       Escape shuttle reaches ludicrous speed## Descr...       0
# 4              constructing  virtual router structure\r\n       0
# ...                                                   ...     ...
# 473215  Include MOTD feature in CI testsCurrent:\r\n* ...       1
# 473216  Checkbox to disable tweeting displayed for non...       1
# 473217  Add additional labels to service monitors**Is ...       1
# 473218  No mic button in the Keyboard for HVR build## ...       1
# 473219  rpmem: errno is not set when passing invalid l...       1
#
#                           class
# 0                 high_priority
# 1                 high_priority
# 2                 high_priority
# 3                 high_priority
# 4                 high_priority
# ...                         ...
# 473215  medium_and_low_priority
# 473216  medium_and_low_priority
# 473217  medium_and_low_priority
# 473218  medium_and_low_priority
# 473219  medium_and_low_priority
#
# [473220 rows x 3 columns]

# %%
# Convert to string
all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)
# Out:
# /tmp/ipykernel_293020/3106036705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_str"] = all_priority_subset['text'].astype(str)

# %%
all_priority_subset
# Out:
#                                                      text  labels  \
# 0       Auto-log out after some time frame## Is your f...       0
# 1       Image Picker for SourceImplement an Android Im...       0
# 2       Fix Video Page ListItem Hovering Behaviour- Wh...       0
# 3       Escape shuttle reaches ludicrous speed## Descr...       0
# 4              constructing  virtual router structure\r\n       0
# ...                                                   ...     ...
# 473215  Include MOTD feature in CI testsCurrent:\r\n* ...       1
# 473216  Checkbox to disable tweeting displayed for non...       1
# 473217  Add additional labels to service monitors**Is ...       1
# 473218  No mic button in the Keyboard for HVR build## ...       1
# 473219  rpmem: errno is not set when passing invalid l...       1
#
#                           class  \
# 0                 high_priority
# 1                 high_priority
# 2                 high_priority
# 3                 high_priority
# 4                 high_priority
# ...                         ...
# 473215  medium_and_low_priority
# 473216  medium_and_low_priority
# 473217  medium_and_low_priority
# 473218  medium_and_low_priority
# 473219  medium_and_low_priority
#
#                                                  text_str
# 0       Auto-log out after some time frame## Is your f...
# 1       Image Picker for SourceImplement an Android Im...
# 2       Fix Video Page ListItem Hovering Behaviour- Wh...
# 3       Escape shuttle reaches ludicrous speed## Descr...
# 4              constructing  virtual router structure\r\n
# ...                                                   ...
# 473215  Include MOTD feature in CI testsCurrent:\r\n* ...
# 473216  Checkbox to disable tweeting displayed for non...
# 473217  Add additional labels to service monitors**Is ...
# 473218  No mic button in the Keyboard for HVR build## ...
# 473219  rpmem: errno is not set when passing invalid l...
#
# [473220 rows x 4 columns]

# %%
# Clean the data.
all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_293020/63294665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)

# %%
# Make a subset with text_clean and label
priority_label_text = all_priority_subset[["text_clean" , "labels", "class"]]
priority_label_text
# Out:
#                                                text_clean  labels  \
# 0       autolog out after some time frame is your feat...       0
# 1       image picker for sourceimplement an android im...       0
# 2       fix video page listitem hovering behaviour whe...       0
# 3       escape shuttle reaches ludicrous speed descrip...       0
# 4                                                     NaN       0
# ...                                                   ...     ...
# 473215  include motd feature in ci testscurrent messag...       1
# 473216  checkbox to disable tweeting displayed for non...       1
# 473217  add additional labels to service monitorsis yo...       1
# 473218  no mic button in the keyboard for hvr build co...       1
# 473219  rpmem errno is not set when passing invalid le...       1
#
#                           class
# 0                 high_priority
# 1                 high_priority
# 2                 high_priority
# 3                 high_priority
# 4                 high_priority
# ...                         ...
# 473215  medium_and_low_priority
# 473216  medium_and_low_priority
# 473217  medium_and_low_priority
# 473218  medium_and_low_priority
# 473219  medium_and_low_priority
#
# [473220 rows x 3 columns]

# %%
# Need to dropna here since cleaning function returns NaN for not english text.
priority_label_text.dropna(inplace=True)
priority_label_text.reset_index(inplace=True)
priority_label_text.drop(columns=["index"] , inplace= True)

priority_label_text
# Out:
# /tmp/ipykernel_293020/239147930.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.dropna(inplace=True)
# /tmp/ipykernel_293020/239147930.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.drop(columns=["index"] , inplace= True)
#                                                text_clean  labels  \
# 0       autolog out after some time frame is your feat...       0
# 1       image picker for sourceimplement an android im...       0
# 2       fix video page listitem hovering behaviour whe...       0
# 3       escape shuttle reaches ludicrous speed descrip...       0
# 4       binder doesnt load notebooks outside of the un...       0
# ...                                                   ...     ...
# 441934  include motd feature in ci testscurrent messag...       1
# 441935  checkbox to disable tweeting displayed for non...       1
# 441936  add additional labels to service monitorsis yo...       1
# 441937  no mic button in the keyboard for hvr build co...       1
# 441938  rpmem errno is not set when passing invalid le...       1
#
#                           class
# 0                 high_priority
# 1                 high_priority
# 2                 high_priority
# 3                 high_priority
# 4                 high_priority
# ...                         ...
# 441934  medium_and_low_priority
# 441935  medium_and_low_priority
# 441936  medium_and_low_priority
# 441937  medium_and_low_priority
# 441938  medium_and_low_priority
#
# [441939 rows x 3 columns]

# %%
# Splitting the DataFrame
test_df = priority_label_text.sample(frac=0.05, random_state=1)  # Select 5% of the data
test_file_name = f"csv/clean_test_high_vs_med_low_priority.csv"
test_df.to_csv(test_file_name, index=False)
priority_df = priority_label_text.drop(test_df.index)
priority_df.reset_index(drop=True, inplace=True)
priority_df
# Out:
#                                                text_clean  labels  \
# 0       autolog out after some time frame is your feat...       0
# 1       image picker for sourceimplement an android im...       0
# 2       fix video page listitem hovering behaviour whe...       0
# 3       escape shuttle reaches ludicrous speed descrip...       0
# 4       binder doesnt load notebooks outside of the un...       0
# ...                                                   ...     ...
# 419837  include motd feature in ci testscurrent messag...       1
# 419838  checkbox to disable tweeting displayed for non...       1
# 419839  add additional labels to service monitorsis yo...       1
# 419840  no mic button in the keyboard for hvr build co...       1
# 419841  rpmem errno is not set when passing invalid le...       1
#
#                           class
# 0                 high_priority
# 1                 high_priority
# 2                 high_priority
# 3                 high_priority
# 4                 high_priority
# ...                         ...
# 419837  medium_and_low_priority
# 419838  medium_and_low_priority
# 419839  medium_and_low_priority
# 419840  medium_and_low_priority
# 419841  medium_and_low_priority
#
# [419842 rows x 3 columns]

# %%
# Clean dataset with clean text and labels.
# 0 = high priority, 1 = not high priority
file_name = f"csv/clean_high_vs_med_and_low_priority.csv"
priority_df.to_csv(file_name, index=False)

# %%
pri = pd.read_csv(file_name)
pri
# Out:
#                                                text_clean  labels  \
# 0       autolog out after some time frame is your feat...       0
# 1       image picker for sourceimplement an android im...       0
# 2       fix video page listitem hovering behaviour whe...       0
# 3       escape shuttle reaches ludicrous speed descrip...       0
# 4       binder doesnt load notebooks outside of the un...       0
# ...                                                   ...     ...
# 419837  include motd feature in ci testscurrent messag...       1
# 419838  checkbox to disable tweeting displayed for non...       1
# 419839  add additional labels to service monitorsis yo...       1
# 419840  no mic button in the keyboard for hvr build co...       1
# 419841  rpmem errno is not set when passing invalid le...       1
#
#                           class
# 0                 high_priority
# 1                 high_priority
# 2                 high_priority
# 3                 high_priority
# 4                 high_priority
# ...                         ...
# 419837  medium_and_low_priority
# 419838  medium_and_low_priority
# 419839  medium_and_low_priority
# 419840  medium_and_low_priority
# 419841  medium_and_low_priority
#
# [419842 rows x 3 columns]

# %%
test_df = pd.read_csv(test_file_name)
test_df
# Out:
#                                               text_clean  labels  \
# 0      block sizesadjust block sizes to fit the provi...       1
# 1      ui style and widgets broken in the test enviro...       0
# 2      this dropdown list should not work in this scr...       0
# 3      e2e docker use mariadb instead of mysqllike is...       1
# 4      crosscompile toolchain variant doesnt working ...       1
# ...                                                  ...     ...
# 22092  error handling sync error handling mechanismmw...       0
# 22093  limit maximum requests in a given timethis is ...       0
# 22094  looking for a volunteer officiel facebook page...       1
# 22095  add tests for add todo command its related tes...       0
# 22096  convert sql functions to views for orm compata...       0
#
#                          class
# 0      medium_and_low_priority
# 1                high_priority
# 2                high_priority
# 3      medium_and_low_priority
# 4      medium_and_low_priority
# ...                        ...
# 22092            high_priority
# 22093            high_priority
# 22094  medium_and_low_priority
# 22095            high_priority
# 22096            high_priority
#
# [22097 rows x 3 columns]
