# %%
import pandas as pd

# %%
# Read CSV into a dataframe
high_priority = pd.read_csv("csv/final_high_priority_dataset.csv", index_col=0)
not_high_priority = pd.read_csv("csv/final_not_high_priority_dataset.csv", index_col=0)

# %%
high_priority
# Out:
#                  id         type           created_at  \
# 0      2.125950e+10  IssuesEvent  2022-04-13 01:29:38
# 1      2.125952e+10  IssuesEvent  2022-04-13 01:31:43
# 2      2.125953e+10  IssuesEvent  2022-04-13 01:31:57
# 3      2.125953e+10  IssuesEvent  2022-04-13 01:31:58
# 4      2.125953e+10  IssuesEvent  2022-04-13 01:31:59
# ...             ...          ...                  ...
# 80836  2.060556e+10  IssuesEvent  2022-03-06 22:47:36
# 80837  2.060560e+10  IssuesEvent  2022-03-06 22:56:38
# 80838  2.060562e+10  IssuesEvent  2022-03-06 23:01:12
# 80839  2.060568e+10  IssuesEvent  2022-03-06 23:10:44
# 80840  2.060573e+10  IssuesEvent  2022-03-06 23:19:54
#
#                                           repo  \
# 0                       federicazoe/gradetools
# 1                      darrylsyms/fretwise-app
# 2                              ArctosDB/arctos
# 3                              ArctosDB/arctos
# 4                              ArctosDB/arctos
# ...                                        ...
# 80836  BlueCodeSystems/opensrp-client-ecap-chw
# 80837                   gurtejboparai/bookwyrm
# 80838               AdguardTeam/AdguardFilters
# 80839  BlueCodeSystems/opensrp-client-ecap-chw
# 80840                         NicholasG04/Prom
#
#                                                 repo_url  action  \
# 0      https://api.github.com/repos/federicazoe/grade...  opened
# 1      https://api.github.com/repos/darrylsyms/fretwi...  closed
# 2           https://api.github.com/repos/ArctosDB/arctos  closed
# 3           https://api.github.com/repos/ArctosDB/arctos  closed
# 4           https://api.github.com/repos/ArctosDB/arctos  closed
# ...                                                  ...     ...
# 80836  https://api.github.com/repos/BlueCodeSystems/o...  closed
# 80837  https://api.github.com/repos/gurtejboparai/boo...  closed
# 80838  https://api.github.com/repos/AdguardTeam/Adgua...  opened
# 80839  https://api.github.com/repos/BlueCodeSystems/o...  opened
# 80840      https://api.github.com/repos/NicholasG04/Prom  opened
#
#                                                    title  \
# 0                                 Comprehensive vignette
# 1                                              App crash
# 2           Need a graceful error message for logging in
# 3                                  rebuild startup stuff
# 4      Error pre-creating locality using geography sp...
# ...                                                  ...
# 80836  Currently when a family member is added  to a ...
# 80837                                  Setup CI pipeline
# 80838                                    www.masrawy.com
# 80839  Issues opened on Household screening and Enrol...
# 80840                Lack of discrete axolotl references
#
#                                                   labels  \
# 0                                          high priority
# 1                     bug requires testing high priority
# 2      Priority-Normal (Not urgent) Enhancement Displ...
# 3                   Priority-Critical (Arctos is broken)
# 4      Priority-Critical (Arctos is broken) Function-...
# ...                                                  ...
# 80836                                  bug High Priority
# 80837                                      High Priority
# 80838             T: Ads P1: Critical N: AdGuard for iOS
# 80839   High Priority Household screening and enrollment
# 80840  enhancement UI User Panel Admin Panel High Pri...
#
#                                                     body
# 0      - [ ] Create new vignette on project team grad...
# 1      App crashes when Darryl visits "MessagesScreen...
# 2      If you click on a link from your email without...
# 3      missing, onRequestStart, rolecheck don't alway...
# 4      **Describe the bug**\r\nI noticed I now have t...
# ...                                                  ...
# 80836                                                NaN
# 80837                                                NaN
# 80838  \r\n### Issue URL (Ads)\r\n [https://www.masra...
# 80839  - [ ] Ensure the field Home address is prefill...
# 80840  There is an atrocious lack of hidden, inconspi...
#
# [80841 rows x 9 columns]

# %%
# Number or different labels
high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# Severe Urgent                                        7587
# bug urgent                                           1856
# high priority                                        1853
# bug high priority                                    1737
# bug critical                                         1334
# bot human_intervention_required priority/critic...   1035
# enhancement high priority                            1033
# priority.High                                         947
# priority.High type.Task                               838
# type.Task priority.High                               815
# High Priority                                         806
# type.Story priority.High                              731
# high priority task                                    663
# critical                                              507
# priority.High type.Story                              471
# urgent                                                423
# T: Ads P1: Critical N: AdGuard Browser Extension      422
# Urgent Severe                                         421
# bug high-priority                                     417
# high-priority                                         397
# bot priority/critical-urgent                          383
# type:critical                                         370
# N: AdGuard Browser Extension P1: Critical T: Ads      330
# Critical                                              320
# T: Incorrect Blocking P1: Critical N: AdGuard B...    319
# High priority                                         283
# enhancement high-priority                             272
# priority-high                                         262
# N: AdGuard Browser Extension P1: Critical T: In...    242
# High Priority bug                                     238
# bug High Priority                                     220
# Bug High Priority                                     213
# browser-firefox priority-critical engine-gecko        212
# enhancement urgent                                    196
# priority-critical browser-fenix engine-gecko          192
# T: Ads P1: Critical N: AdGuard for iOS                192
# bot priority/critical-urgent kind/bug                 189
# T: Ads N: AdGuard for Android P1: Critical            186
# priority high                                         182
# Urgent                                                182
# CRITICAL                                              174
# Priority High                                         169
# bug Critical                                          167
# Priority: Critical                                    166
# impact/critical                                       165
# T: Ads N: AdGuard for Windows P1: Critical            155
# T: Incorrect Blocking N: AdGuard for Windows P1...    154
# bug Urgent                                            141
# enhancement critical                                  141
# enhancement High Priority                             140

# %%
# Number or different labels
not_high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                            count
# labels
# bug                                        98108
# enhancement                                94219
# security vulnerability                     16071
# question                                   13304
# documentation                              10017
# feature                                     6763
# Bug                                         5836
# monika status                               5652
# watchout                                    4382
# stale                                       3876
# wontfix                                     3608
# help wanted                                 3370
# action-needsmoderation                      3292
# good first issue                            3169
# signature                                   2999
# alert:boom: environment/moc/zero            2979
# Stale                                       2814
# alert:boom: environment/moc/zero resolved   2798
# invalid                                     2497
# feature request                             2373
# kind/bug                                    2263
# enhancement good first issue                2183
# fetched                                     1770
# enhancement help wanted                     1731
# license policy violation                    1713
# task                                        1692
# AssignTo1 House: Hufflepuff                 1687
# no-issue-activity                           1531
# bug enhancement                             1502
# type: bug                                   1486
# House: Gryffindor Needs: Attention :wave:   1480
# House: Slytherin Needs: Author Feedback     1480
# Type: Bug                                   1358
# fresh tiny                                  1342
# documentation enhancement                   1316
# Needs: Triage :mag:                         1297
# Enhancement                                 1260
# frontend                                    1216
# duplicate                                   1139
# type/bug                                    1064
# orkut status                                1024
# severity.Medium type.FunctionalityBug       1001
# action-needsmoderation browser-fixme         997
# bug help wanted                              992
# harmony-bot-website status                   986
# backend                                      966
# ryanjie-google status                        950
# new feature                                  935
# bug good first issue                         895
# Feature                                      863

# %%
# Add a new column
high_priority["class"] = "high_priority"
high_priority
# Out:
#                  id         type           created_at  \
# 0      2.125950e+10  IssuesEvent  2022-04-13 01:29:38
# 1      2.125952e+10  IssuesEvent  2022-04-13 01:31:43
# 2      2.125953e+10  IssuesEvent  2022-04-13 01:31:57
# 3      2.125953e+10  IssuesEvent  2022-04-13 01:31:58
# 4      2.125953e+10  IssuesEvent  2022-04-13 01:31:59
# ...             ...          ...                  ...
# 80836  2.060556e+10  IssuesEvent  2022-03-06 22:47:36
# 80837  2.060560e+10  IssuesEvent  2022-03-06 22:56:38
# 80838  2.060562e+10  IssuesEvent  2022-03-06 23:01:12
# 80839  2.060568e+10  IssuesEvent  2022-03-06 23:10:44
# 80840  2.060573e+10  IssuesEvent  2022-03-06 23:19:54
#
#                                           repo  \
# 0                       federicazoe/gradetools
# 1                      darrylsyms/fretwise-app
# 2                              ArctosDB/arctos
# 3                              ArctosDB/arctos
# 4                              ArctosDB/arctos
# ...                                        ...
# 80836  BlueCodeSystems/opensrp-client-ecap-chw
# 80837                   gurtejboparai/bookwyrm
# 80838               AdguardTeam/AdguardFilters
# 80839  BlueCodeSystems/opensrp-client-ecap-chw
# 80840                         NicholasG04/Prom
#
#                                                 repo_url  action  \
# 0      https://api.github.com/repos/federicazoe/grade...  opened
# 1      https://api.github.com/repos/darrylsyms/fretwi...  closed
# 2           https://api.github.com/repos/ArctosDB/arctos  closed
# 3           https://api.github.com/repos/ArctosDB/arctos  closed
# 4           https://api.github.com/repos/ArctosDB/arctos  closed
# ...                                                  ...     ...
# 80836  https://api.github.com/repos/BlueCodeSystems/o...  closed
# 80837  https://api.github.com/repos/gurtejboparai/boo...  closed
# 80838  https://api.github.com/repos/AdguardTeam/Adgua...  opened
# 80839  https://api.github.com/repos/BlueCodeSystems/o...  opened
# 80840      https://api.github.com/repos/NicholasG04/Prom  opened
#
#                                                    title  \
# 0                                 Comprehensive vignette
# 1                                              App crash
# 2           Need a graceful error message for logging in
# 3                                  rebuild startup stuff
# 4      Error pre-creating locality using geography sp...
# ...                                                  ...
# 80836  Currently when a family member is added  to a ...
# 80837                                  Setup CI pipeline
# 80838                                    www.masrawy.com
# 80839  Issues opened on Household screening and Enrol...
# 80840                Lack of discrete axolotl references
#
#                                                   labels  \
# 0                                          high priority
# 1                     bug requires testing high priority
# 2      Priority-Normal (Not urgent) Enhancement Displ...
# 3                   Priority-Critical (Arctos is broken)
# 4      Priority-Critical (Arctos is broken) Function-...
# ...                                                  ...
# 80836                                  bug High Priority
# 80837                                      High Priority
# 80838             T: Ads P1: Critical N: AdGuard for iOS
# 80839   High Priority Household screening and enrollment
# 80840  enhancement UI User Panel Admin Panel High Pri...
#
#                                                     body          class
# 0      - [ ] Create new vignette on project team grad...  high_priority
# 1      App crashes when Darryl visits "MessagesScreen...  high_priority
# 2      If you click on a link from your email without...  high_priority
# 3      missing, onRequestStart, rolecheck don't alway...  high_priority
# 4      **Describe the bug**\r\nI noticed I now have t...  high_priority
# ...                                                  ...            ...
# 80836                                                NaN  high_priority
# 80837                                                NaN  high_priority
# 80838  \r\n### Issue URL (Ads)\r\n [https://www.masra...  high_priority
# 80839  - [ ] Ensure the field Home address is prefill...  high_priority
# 80840  There is an atrocious lack of hidden, inconspi...  high_priority
#
# [80841 rows x 10 columns]

# %%
not_high_priority["class"] = "not_high_priority"
not_high_priority
# Out:
#                   id         type           created_at  \
# 0       1.675120e+10  IssuesEvent  2021-06-12 00:00:03
# 1       1.675120e+10  IssuesEvent  2021-06-12 00:00:15
# 2       1.675120e+10  IssuesEvent  2021-06-12 00:00:21
# 3       1.675120e+10  IssuesEvent  2021-06-12 00:00:26
# 4       1.675120e+10  IssuesEvent  2021-06-12 00:00:27
# ...              ...          ...                  ...
# 798224  1.475140e+10  IssuesEvent  2021-01-08 05:00:49
# 798225  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 798226  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 798227  1.475140e+10  IssuesEvent  2021-01-08 05:01:02
# 798228  1.475140e+10  IssuesEvent  2021-01-08 05:01:04
#
#                                            repo  \
# 0                        SFDO-Tooling/CumulusCI
# 1                          atatkin/milos-uptime
# 2                            longturn/freeciv21
# 3                              microsoft/vscode
# 4       hashicorp/terraform-provider-kubernetes
# ...                                         ...
# 798224          nvim-treesitter/nvim-treesitter
# 798225                              supabase/ui
# 798226                              supabase/ui
# 798227              tristanjohnson849/card-demo
# 798228                          nushell/nushell
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/SFDO-Tooling/Cumu...  closed
# 1       https://api.github.com/repos/atatkin/milos-uptime  closed
# 2         https://api.github.com/repos/longturn/freeciv21  closed
# 3           https://api.github.com/repos/microsoft/vscode  closed
# 4       https://api.github.com/repos/hashicorp/terrafo...  closed
# ...                                                   ...     ...
# 798224  https://api.github.com/repos/nvim-treesitter/n...  opened
# 798225           https://api.github.com/repos/supabase/ui  closed
# 798226           https://api.github.com/repos/supabase/ui  closed
# 798227  https://api.github.com/repos/tristanjohnson849...  closed
# 798228       https://api.github.com/repos/nushell/nushell  closed
#
#                                                     title  \
# 0          Add installation info section to release notes
# 1                                  🛑 Minted HTTPS is down
# 2       Client crashes when trying to load the aviatio...
# 3       Native Notebooks - Changing kernel causes mark...
# 4       Feature Request: Generate Resources from Kuber...
# ...                                                   ...
# 798224  highlighting works as unexpected after attach ...
# 798225          Input component has an extra grid space y
# 798226                   Button to support Ref forwarding
# 798227                 We need to merge type 1 and type 2
# 798228                            Release #4 - Nu Scripts
#
#                                 labels  \
# 0                          enhancement
# 1                  minted-https status
# 2                                  bug
# 3               bug candidate notebook
# 4       acknowledged enhancement stale
# ...                                ...
# 798224                             bug
# 798225                             bug
# 798226                     enhancement
# 798227                good first issue
# 798228               enhancement pri-1
#
#                                                      body              class
# 0       Currently we generate release notes and then m...  not_high_priority
# 1       In [`03a8446`](https://github.com/atatkin/milo...  not_high_priority
# 2       More specifically, [this version](https://raw....  not_high_priority
# 3       - VS Code Version: 1.57.0 & 1.57.0-insider\r\n...  not_high_priority
# 4       At this point in time, the terraform provider ...  not_high_priority
# ...                                                   ...                ...
# 798224  **Describe the bug**\r\nsee reproduce.\r\n\r\n...  not_high_priority
# 798225  # Bug report\r\n\r\nI noticed that the Input c...  not_high_priority
# 798226  # Feature request\r\n\r\n## Is your feature re...  not_high_priority
# 798227                This is purely for practice and fun  not_high_priority
# 798228  # Requirements for Nu scripts\r\n- [x] variabl...  not_high_priority
#
# [798229 rows x 10 columns]

# %%
all_data = pd.concat([high_priority, not_high_priority] , ignore_index= True)

# %%
all_data
# Out:
#                   id         type           created_at  \
# 0       2.125950e+10  IssuesEvent  2022-04-13 01:29:38
# 1       2.125952e+10  IssuesEvent  2022-04-13 01:31:43
# 2       2.125953e+10  IssuesEvent  2022-04-13 01:31:57
# 3       2.125953e+10  IssuesEvent  2022-04-13 01:31:58
# 4       2.125953e+10  IssuesEvent  2022-04-13 01:31:59
# ...              ...          ...                  ...
# 879065  1.475140e+10  IssuesEvent  2021-01-08 05:00:49
# 879066  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 879067  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 879068  1.475140e+10  IssuesEvent  2021-01-08 05:01:02
# 879069  1.475140e+10  IssuesEvent  2021-01-08 05:01:04
#
#                                    repo  \
# 0                federicazoe/gradetools
# 1               darrylsyms/fretwise-app
# 2                       ArctosDB/arctos
# 3                       ArctosDB/arctos
# 4                       ArctosDB/arctos
# ...                                 ...
# 879065  nvim-treesitter/nvim-treesitter
# 879066                      supabase/ui
# 879067                      supabase/ui
# 879068      tristanjohnson849/card-demo
# 879069                  nushell/nushell
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/federicazoe/grade...  opened
# 1       https://api.github.com/repos/darrylsyms/fretwi...  closed
# 2            https://api.github.com/repos/ArctosDB/arctos  closed
# 3            https://api.github.com/repos/ArctosDB/arctos  closed
# 4            https://api.github.com/repos/ArctosDB/arctos  closed
# ...                                                   ...     ...
# 879065  https://api.github.com/repos/nvim-treesitter/n...  opened
# 879066           https://api.github.com/repos/supabase/ui  closed
# 879067           https://api.github.com/repos/supabase/ui  closed
# 879068  https://api.github.com/repos/tristanjohnson849...  closed
# 879069       https://api.github.com/repos/nushell/nushell  closed
#
#                                                     title  \
# 0                                  Comprehensive vignette
# 1                                               App crash
# 2            Need a graceful error message for logging in
# 3                                   rebuild startup stuff
# 4       Error pre-creating locality using geography sp...
# ...                                                   ...
# 879065  highlighting works as unexpected after attach ...
# 879066          Input component has an extra grid space y
# 879067                   Button to support Ref forwarding
# 879068                 We need to merge type 1 and type 2
# 879069                            Release #4 - Nu Scripts
#
#                                                    labels  \
# 0                                           high priority
# 1                      bug requires testing high priority
# 2       Priority-Normal (Not urgent) Enhancement Displ...
# 3                    Priority-Critical (Arctos is broken)
# 4       Priority-Critical (Arctos is broken) Function-...
# ...                                                   ...
# 879065                                                bug
# 879066                                                bug
# 879067                                        enhancement
# 879068                                   good first issue
# 879069                                  enhancement pri-1
#
#                                                      body              class
# 0       - [ ] Create new vignette on project team grad...      high_priority
# 1       App crashes when Darryl visits "MessagesScreen...      high_priority
# 2       If you click on a link from your email without...      high_priority
# 3       missing, onRequestStart, rolecheck don't alway...      high_priority
# 4       **Describe the bug**\r\nI noticed I now have t...      high_priority
# ...                                                   ...                ...
# 879065  **Describe the bug**\r\nsee reproduce.\r\n\r\n...  not_high_priority
# 879066  # Bug report\r\n\r\nI noticed that the Input c...  not_high_priority
# 879067  # Feature request\r\n\r\n## Is your feature re...  not_high_priority
# 879068                This is purely for practice and fun  not_high_priority
# 879069  # Requirements for Nu scripts\r\n- [x] variabl...  not_high_priority
#
# [879070 rows x 10 columns]

# %%
all_data_no_dupes = all_data.drop_duplicates()
all_data_no_dupes
# Out:
#                   id         type           created_at  \
# 0       2.125950e+10  IssuesEvent  2022-04-13 01:29:38
# 1       2.125952e+10  IssuesEvent  2022-04-13 01:31:43
# 2       2.125953e+10  IssuesEvent  2022-04-13 01:31:57
# 3       2.125953e+10  IssuesEvent  2022-04-13 01:31:58
# 4       2.125953e+10  IssuesEvent  2022-04-13 01:31:59
# ...              ...          ...                  ...
# 879065  1.475140e+10  IssuesEvent  2021-01-08 05:00:49
# 879066  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 879067  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 879068  1.475140e+10  IssuesEvent  2021-01-08 05:01:02
# 879069  1.475140e+10  IssuesEvent  2021-01-08 05:01:04
#
#                                    repo  \
# 0                federicazoe/gradetools
# 1               darrylsyms/fretwise-app
# 2                       ArctosDB/arctos
# 3                       ArctosDB/arctos
# 4                       ArctosDB/arctos
# ...                                 ...
# 879065  nvim-treesitter/nvim-treesitter
# 879066                      supabase/ui
# 879067                      supabase/ui
# 879068      tristanjohnson849/card-demo
# 879069                  nushell/nushell
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/federicazoe/grade...  opened
# 1       https://api.github.com/repos/darrylsyms/fretwi...  closed
# 2            https://api.github.com/repos/ArctosDB/arctos  closed
# 3            https://api.github.com/repos/ArctosDB/arctos  closed
# 4            https://api.github.com/repos/ArctosDB/arctos  closed
# ...                                                   ...     ...
# 879065  https://api.github.com/repos/nvim-treesitter/n...  opened
# 879066           https://api.github.com/repos/supabase/ui  closed
# 879067           https://api.github.com/repos/supabase/ui  closed
# 879068  https://api.github.com/repos/tristanjohnson849...  closed
# 879069       https://api.github.com/repos/nushell/nushell  closed
#
#                                                     title  \
# 0                                  Comprehensive vignette
# 1                                               App crash
# 2            Need a graceful error message for logging in
# 3                                   rebuild startup stuff
# 4       Error pre-creating locality using geography sp...
# ...                                                   ...
# 879065  highlighting works as unexpected after attach ...
# 879066          Input component has an extra grid space y
# 879067                   Button to support Ref forwarding
# 879068                 We need to merge type 1 and type 2
# 879069                            Release #4 - Nu Scripts
#
#                                                    labels  \
# 0                                           high priority
# 1                      bug requires testing high priority
# 2       Priority-Normal (Not urgent) Enhancement Displ...
# 3                    Priority-Critical (Arctos is broken)
# 4       Priority-Critical (Arctos is broken) Function-...
# ...                                                   ...
# 879065                                                bug
# 879066                                                bug
# 879067                                        enhancement
# 879068                                   good first issue
# 879069                                  enhancement pri-1
#
#                                                      body              class
# 0       - [ ] Create new vignette on project team grad...      high_priority
# 1       App crashes when Darryl visits "MessagesScreen...      high_priority
# 2       If you click on a link from your email without...      high_priority
# 3       missing, onRequestStart, rolecheck don't alway...      high_priority
# 4       **Describe the bug**\r\nI noticed I now have t...      high_priority
# ...                                                   ...                ...
# 879065  **Describe the bug**\r\nsee reproduce.\r\n\r\n...  not_high_priority
# 879066  # Bug report\r\n\r\nI noticed that the Input c...  not_high_priority
# 879067  # Feature request\r\n\r\n## Is your feature re...  not_high_priority
# 879068                This is purely for practice and fun  not_high_priority
# 879069  # Requirements for Nu scripts\r\n- [x] variabl...  not_high_priority
#
# [878779 rows x 10 columns]

# %%
# Convert dataframe to a CSV file.
all_data_no_dupes.to_csv("csv/full_dataset_priority_high_or_not_high.csv")
