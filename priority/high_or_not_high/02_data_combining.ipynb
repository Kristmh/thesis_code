# %%
import pandas as pd

# %%
# Read CSV into a dataframe
high_priority = pd.read_csv("csv/final_high_priority_dataset.csv", index_col=0)
not_high_priority = pd.read_csv("csv/final_not_high_priority_dataset.csv", index_col=0)

# %%
high_priority
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141757e+10  IssuesEvent  2020-02-03 00:11:29
# 2       1.141766e+10  IssuesEvent  2020-02-03 00:47:48
# 3       1.141776e+10  IssuesEvent  2020-02-03 01:22:41
# 4       1.141777e+10  IssuesEvent  2020-02-03 01:24:06
# ...              ...          ...                  ...
# 415158  7.334914e+09  IssuesEvent  2018-03-06 01:05:53
# 415159  7.334924e+09  IssuesEvent  2018-03-06 01:08:55
# 415160  7.334924e+09  IssuesEvent  2018-03-06 01:09:12
# 415161  7.335034e+09  IssuesEvent  2018-03-06 01:44:11
# 415162  7.335035e+09  IssuesEvent  2018-03-06 01:44:26
#
#                                 repo  \
# 0          unitystation/unitystation
# 1            poissonconsulting/nlist
# 2          unitystation/unitystation
# 3                 SolerSoft/TaskeRGB
# 4                   appf-anu/tickets
# ...                              ...
# 415158  Synodic-Software/Soul-Engine
# 415159    StrangeLoopGames/EcoIssues
# 415160    StrangeLoopGames/EcoIssues
# 415161        wh1ter0se/PowerUp-2018
# 415162        wh1ter0se/PowerUp-2018
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/unitystation/unit...  closed
# 1       https://api.github.com/repos/poissonconsulting...  closed
# 2       https://api.github.com/repos/unitystation/unit...  opened
# 3         https://api.github.com/repos/SolerSoft/TaskeRGB  closed
# 4           https://api.github.com/repos/appf-anu/tickets  closed
# ...                                                   ...     ...
# 415158  https://api.github.com/repos/Synodic-Software/...  closed
# 415159  https://api.github.com/repos/StrangeLoopGames/...  closed
# 415160  https://api.github.com/repos/StrangeLoopGames/...  closed
# 415161  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 415162  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
#
#                                                     title  \
# 0       Client breaking NRE when using edit field on C...
# 1       tidy.nlists should return table with term, est...
# 2                  Escape shuttle reaches ludicrous speed
# 3                                 Image Picker for Source
# 4                 [CRITICAL] GC20 Temporal PAR difference
# ...                                                   ...
# 415158                Windows/Visual Studio CMake Support
# 415159             USER ISSUE: Unable to set up contracts
# 415160       Meteor hit - Can no longer join server 6.4.1
# 415161  Get and record refined PID loops for rotation ...
# 415162  Figure out why CyborgCommandSpit() runs early ...
#
#                                                    labels  \
# 0                        Bug High Priority In Progress UI
# 1       Difficulty: 2 Intermediate Effort: 2 Medium Pr...
# 2                                   Bug High Priority lol
# 3                config enhancement palette priority-high
# 4                                                CRITICAL
# ...                                                   ...
# 415158                          Enhancement High Priority
# 415159                                      High Priority
# 415160                                      High Priority
# 415161                 IRL development high priority java
# 415162                         R&D bug high priority java
#
#                                                      body
# 0       ### Bug:\r\n\r\nIf you use the edit field of t...
# 1                                                     NaN
# 2       ## Description\r\n\r\nEscape shuttle accelerat...
# 3       Implement an Android Image Picker to browse Im...
# 4       ### GC20 Temporal PAR difference \n### [CRIT] ...
# ...                                                   ...
# 415158  The stored Visual Studio build files need to b...
# 415159  **Version:** 0.6.4.2 alpha\r\n\r\n**Steps to R...
# 415160  Just had the meteor hit on our server and now ...
# 415161  Pretty simple, and pretty sure we already have...
# 415162  The problem is that when we run autonomous (so...
#
# [415163 rows x 9 columns]

# %%
# Number or different labels
high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# bug high priority                                   10435
# high priority                                       10360
# Severe Urgent                                       10055
# bug urgent                                           7950
# bug critical                                         7643
# High Priority                                        7484
# enhancement high priority                            5486
# critical                                             4549
# priority.High                                        3694
# priority.High type.Task                              3685
# priority.high type.task                              3209
# priority.High type.Story                             2979
# urgent                                               2757
# priority.high                                        2749
# high-priority                                        2262
# bug high-priority                                    2159
# type.Story priority.High                             2155
# priority.high type.story                             2130
# type.Task priority.High                              2022
# Critical                                             1984
# bug High Priority                                    1888
# High priority                                        1815
# N: AdGuard Browser Extension P1: Critical T: Ads     1562
# CRITICAL                                             1485
# T: Ads P1: Critical N: AdGuard Browser Extension     1413
# High Priority bug                                    1338
# Urgent                                               1238
# bug Critical                                         1161
# Bug High Priority                                    1143
# feature high priority                                1091
# impact/critical                                      1075
# enhancement high-priority                            1053
# bot human_intervention_required priority/critic...   1035
# critical enhancement                                 1030
# enhancement urgent                                    999
# Critical Fix Released                                 973
# priority-high                                         955
# security-hub us-east-1 gha-test CRITICAL              953
# bug critical release                                  934
# type:critical                                         933
# bug priority-high                                     927
# N: AdGuard Browser Extension P1: Critical T: In...    924
# browser-firefox engine-gecko priority-critical        914
# T: Incorrect Blocking P1: Critical N: AdGuard B...    912
# enhancement High Priority                             902
# Priority: Critical                                    883
# browser-firefox-mobile engine-gecko priority-cr...    876
# browser-fenix engine-gecko priority-critical          833
# high priority task                                    831
# browser-firefox priority-critical engine-gecko        828

# %%
# Number or different labels
not_high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                            count
# labels
# bug                                        98108
# enhancement                                94219
# security vulnerability                     16071
# question                                   13304
# documentation                              10017
# feature                                     6763
# Bug                                         5836
# monika status                               5652
# watchout                                    4382
# stale                                       3876
# wontfix                                     3608
# help wanted                                 3370
# action-needsmoderation                      3292
# good first issue                            3169
# signature                                   2999
# alert:boom: environment/moc/zero            2979
# Stale                                       2814
# alert:boom: environment/moc/zero resolved   2798
# invalid                                     2497
# feature request                             2373
# kind/bug                                    2263
# enhancement good first issue                2183
# fetched                                     1770
# enhancement help wanted                     1731
# license policy violation                    1713
# task                                        1692
# AssignTo1 House: Hufflepuff                 1687
# no-issue-activity                           1531
# bug enhancement                             1502
# type: bug                                   1486
# House: Gryffindor Needs: Attention :wave:   1480
# House: Slytherin Needs: Author Feedback     1480
# Type: Bug                                   1358
# fresh tiny                                  1342
# documentation enhancement                   1316
# Needs: Triage :mag:                         1297
# Enhancement                                 1260
# frontend                                    1216
# duplicate                                   1139
# type/bug                                    1064
# orkut status                                1024
# severity.Medium type.FunctionalityBug       1001
# action-needsmoderation browser-fixme         997
# bug help wanted                              992
# harmony-bot-website status                   986
# backend                                      966
# ryanjie-google status                        950
# new feature                                  935
# bug good first issue                         895
# Feature                                      863

# %%
# Add a new column
high_priority["class"] = "high_priority"
high_priority
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141757e+10  IssuesEvent  2020-02-03 00:11:29
# 2       1.141766e+10  IssuesEvent  2020-02-03 00:47:48
# 3       1.141776e+10  IssuesEvent  2020-02-03 01:22:41
# 4       1.141777e+10  IssuesEvent  2020-02-03 01:24:06
# ...              ...          ...                  ...
# 415158  7.334914e+09  IssuesEvent  2018-03-06 01:05:53
# 415159  7.334924e+09  IssuesEvent  2018-03-06 01:08:55
# 415160  7.334924e+09  IssuesEvent  2018-03-06 01:09:12
# 415161  7.335034e+09  IssuesEvent  2018-03-06 01:44:11
# 415162  7.335035e+09  IssuesEvent  2018-03-06 01:44:26
#
#                                 repo  \
# 0          unitystation/unitystation
# 1            poissonconsulting/nlist
# 2          unitystation/unitystation
# 3                 SolerSoft/TaskeRGB
# 4                   appf-anu/tickets
# ...                              ...
# 415158  Synodic-Software/Soul-Engine
# 415159    StrangeLoopGames/EcoIssues
# 415160    StrangeLoopGames/EcoIssues
# 415161        wh1ter0se/PowerUp-2018
# 415162        wh1ter0se/PowerUp-2018
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/unitystation/unit...  closed
# 1       https://api.github.com/repos/poissonconsulting...  closed
# 2       https://api.github.com/repos/unitystation/unit...  opened
# 3         https://api.github.com/repos/SolerSoft/TaskeRGB  closed
# 4           https://api.github.com/repos/appf-anu/tickets  closed
# ...                                                   ...     ...
# 415158  https://api.github.com/repos/Synodic-Software/...  closed
# 415159  https://api.github.com/repos/StrangeLoopGames/...  closed
# 415160  https://api.github.com/repos/StrangeLoopGames/...  closed
# 415161  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 415162  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
#
#                                                     title  \
# 0       Client breaking NRE when using edit field on C...
# 1       tidy.nlists should return table with term, est...
# 2                  Escape shuttle reaches ludicrous speed
# 3                                 Image Picker for Source
# 4                 [CRITICAL] GC20 Temporal PAR difference
# ...                                                   ...
# 415158                Windows/Visual Studio CMake Support
# 415159             USER ISSUE: Unable to set up contracts
# 415160       Meteor hit - Can no longer join server 6.4.1
# 415161  Get and record refined PID loops for rotation ...
# 415162  Figure out why CyborgCommandSpit() runs early ...
#
#                                                    labels  \
# 0                        Bug High Priority In Progress UI
# 1       Difficulty: 2 Intermediate Effort: 2 Medium Pr...
# 2                                   Bug High Priority lol
# 3                config enhancement palette priority-high
# 4                                                CRITICAL
# ...                                                   ...
# 415158                          Enhancement High Priority
# 415159                                      High Priority
# 415160                                      High Priority
# 415161                 IRL development high priority java
# 415162                         R&D bug high priority java
#
#                                                      body          class
# 0       ### Bug:\r\n\r\nIf you use the edit field of t...  high_priority
# 1                                                     NaN  high_priority
# 2       ## Description\r\n\r\nEscape shuttle accelerat...  high_priority
# 3       Implement an Android Image Picker to browse Im...  high_priority
# 4       ### GC20 Temporal PAR difference \n### [CRIT] ...  high_priority
# ...                                                   ...            ...
# 415158  The stored Visual Studio build files need to b...  high_priority
# 415159  **Version:** 0.6.4.2 alpha\r\n\r\n**Steps to R...  high_priority
# 415160  Just had the meteor hit on our server and now ...  high_priority
# 415161  Pretty simple, and pretty sure we already have...  high_priority
# 415162  The problem is that when we run autonomous (so...  high_priority
#
# [415163 rows x 10 columns]

# %%
not_high_priority["class"] = "not_high_priority"
not_high_priority
# Out:
#                   id         type           created_at  \
# 0       1.675120e+10  IssuesEvent  2021-06-12 00:00:03
# 1       1.675120e+10  IssuesEvent  2021-06-12 00:00:15
# 2       1.675120e+10  IssuesEvent  2021-06-12 00:00:21
# 3       1.675120e+10  IssuesEvent  2021-06-12 00:00:26
# 4       1.675120e+10  IssuesEvent  2021-06-12 00:00:27
# ...              ...          ...                  ...
# 798224  1.475140e+10  IssuesEvent  2021-01-08 05:00:49
# 798225  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 798226  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 798227  1.475140e+10  IssuesEvent  2021-01-08 05:01:02
# 798228  1.475140e+10  IssuesEvent  2021-01-08 05:01:04
#
#                                            repo  \
# 0                        SFDO-Tooling/CumulusCI
# 1                          atatkin/milos-uptime
# 2                            longturn/freeciv21
# 3                              microsoft/vscode
# 4       hashicorp/terraform-provider-kubernetes
# ...                                         ...
# 798224          nvim-treesitter/nvim-treesitter
# 798225                              supabase/ui
# 798226                              supabase/ui
# 798227              tristanjohnson849/card-demo
# 798228                          nushell/nushell
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/SFDO-Tooling/Cumu...  closed
# 1       https://api.github.com/repos/atatkin/milos-uptime  closed
# 2         https://api.github.com/repos/longturn/freeciv21  closed
# 3           https://api.github.com/repos/microsoft/vscode  closed
# 4       https://api.github.com/repos/hashicorp/terrafo...  closed
# ...                                                   ...     ...
# 798224  https://api.github.com/repos/nvim-treesitter/n...  opened
# 798225           https://api.github.com/repos/supabase/ui  closed
# 798226           https://api.github.com/repos/supabase/ui  closed
# 798227  https://api.github.com/repos/tristanjohnson849...  closed
# 798228       https://api.github.com/repos/nushell/nushell  closed
#
#                                                     title  \
# 0          Add installation info section to release notes
# 1                                  🛑 Minted HTTPS is down
# 2       Client crashes when trying to load the aviatio...
# 3       Native Notebooks - Changing kernel causes mark...
# 4       Feature Request: Generate Resources from Kuber...
# ...                                                   ...
# 798224  highlighting works as unexpected after attach ...
# 798225          Input component has an extra grid space y
# 798226                   Button to support Ref forwarding
# 798227                 We need to merge type 1 and type 2
# 798228                            Release #4 - Nu Scripts
#
#                                 labels  \
# 0                          enhancement
# 1                  minted-https status
# 2                                  bug
# 3               bug candidate notebook
# 4       acknowledged enhancement stale
# ...                                ...
# 798224                             bug
# 798225                             bug
# 798226                     enhancement
# 798227                good first issue
# 798228               enhancement pri-1
#
#                                                      body              class
# 0       Currently we generate release notes and then m...  not_high_priority
# 1       In [`03a8446`](https://github.com/atatkin/milo...  not_high_priority
# 2       More specifically, [this version](https://raw....  not_high_priority
# 3       - VS Code Version: 1.57.0 & 1.57.0-insider\r\n...  not_high_priority
# 4       At this point in time, the terraform provider ...  not_high_priority
# ...                                                   ...                ...
# 798224  **Describe the bug**\r\nsee reproduce.\r\n\r\n...  not_high_priority
# 798225  # Bug report\r\n\r\nI noticed that the Input c...  not_high_priority
# 798226  # Feature request\r\n\r\n## Is your feature re...  not_high_priority
# 798227                This is purely for practice and fun  not_high_priority
# 798228  # Requirements for Nu scripts\r\n- [x] variabl...  not_high_priority
#
# [798229 rows x 10 columns]

# %%
all_data = pd.concat([high_priority, not_high_priority] , ignore_index= True)

# %%
all_data
# Out:
#                    id         type           created_at  \
# 0        1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1        1.141757e+10  IssuesEvent  2020-02-03 00:11:29
# 2        1.141766e+10  IssuesEvent  2020-02-03 00:47:48
# 3        1.141776e+10  IssuesEvent  2020-02-03 01:22:41
# 4        1.141777e+10  IssuesEvent  2020-02-03 01:24:06
# ...               ...          ...                  ...
# 1213387  1.475140e+10  IssuesEvent  2021-01-08 05:00:49
# 1213388  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 1213389  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 1213390  1.475140e+10  IssuesEvent  2021-01-08 05:01:02
# 1213391  1.475140e+10  IssuesEvent  2021-01-08 05:01:04
#
#                                     repo  \
# 0              unitystation/unitystation
# 1                poissonconsulting/nlist
# 2              unitystation/unitystation
# 3                     SolerSoft/TaskeRGB
# 4                       appf-anu/tickets
# ...                                  ...
# 1213387  nvim-treesitter/nvim-treesitter
# 1213388                      supabase/ui
# 1213389                      supabase/ui
# 1213390      tristanjohnson849/card-demo
# 1213391                  nushell/nushell
#
#                                                   repo_url  action  \
# 0        https://api.github.com/repos/unitystation/unit...  closed
# 1        https://api.github.com/repos/poissonconsulting...  closed
# 2        https://api.github.com/repos/unitystation/unit...  opened
# 3          https://api.github.com/repos/SolerSoft/TaskeRGB  closed
# 4            https://api.github.com/repos/appf-anu/tickets  closed
# ...                                                    ...     ...
# 1213387  https://api.github.com/repos/nvim-treesitter/n...  opened
# 1213388           https://api.github.com/repos/supabase/ui  closed
# 1213389           https://api.github.com/repos/supabase/ui  closed
# 1213390  https://api.github.com/repos/tristanjohnson849...  closed
# 1213391       https://api.github.com/repos/nushell/nushell  closed
#
#                                                      title  \
# 0        Client breaking NRE when using edit field on C...
# 1        tidy.nlists should return table with term, est...
# 2                   Escape shuttle reaches ludicrous speed
# 3                                  Image Picker for Source
# 4                  [CRITICAL] GC20 Temporal PAR difference
# ...                                                    ...
# 1213387  highlighting works as unexpected after attach ...
# 1213388          Input component has an extra grid space y
# 1213389                   Button to support Ref forwarding
# 1213390                 We need to merge type 1 and type 2
# 1213391                            Release #4 - Nu Scripts
#
#                                                     labels  \
# 0                         Bug High Priority In Progress UI
# 1        Difficulty: 2 Intermediate Effort: 2 Medium Pr...
# 2                                    Bug High Priority lol
# 3                 config enhancement palette priority-high
# 4                                                 CRITICAL
# ...                                                    ...
# 1213387                                                bug
# 1213388                                                bug
# 1213389                                        enhancement
# 1213390                                   good first issue
# 1213391                                  enhancement pri-1
#
#                                                       body              class
# 0        ### Bug:\r\n\r\nIf you use the edit field of t...      high_priority
# 1                                                      NaN      high_priority
# 2        ## Description\r\n\r\nEscape shuttle accelerat...      high_priority
# 3        Implement an Android Image Picker to browse Im...      high_priority
# 4        ### GC20 Temporal PAR difference \n### [CRIT] ...      high_priority
# ...                                                    ...                ...
# 1213387  **Describe the bug**\r\nsee reproduce.\r\n\r\n...  not_high_priority
# 1213388  # Bug report\r\n\r\nI noticed that the Input c...  not_high_priority
# 1213389  # Feature request\r\n\r\n## Is your feature re...  not_high_priority
# 1213390                This is purely for practice and fun  not_high_priority
# 1213391  # Requirements for Nu scripts\r\n- [x] variabl...  not_high_priority
#
# [1213392 rows x 10 columns]

# %%
all_data_no_dupes = all_data.drop_duplicates()
all_data_no_dupes
# Out:
#                    id         type           created_at  \
# 0        1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1        1.141757e+10  IssuesEvent  2020-02-03 00:11:29
# 2        1.141766e+10  IssuesEvent  2020-02-03 00:47:48
# 3        1.141776e+10  IssuesEvent  2020-02-03 01:22:41
# 4        1.141777e+10  IssuesEvent  2020-02-03 01:24:06
# ...               ...          ...                  ...
# 1213387  1.475140e+10  IssuesEvent  2021-01-08 05:00:49
# 1213388  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 1213389  1.475140e+10  IssuesEvent  2021-01-08 05:00:51
# 1213390  1.475140e+10  IssuesEvent  2021-01-08 05:01:02
# 1213391  1.475140e+10  IssuesEvent  2021-01-08 05:01:04
#
#                                     repo  \
# 0              unitystation/unitystation
# 1                poissonconsulting/nlist
# 2              unitystation/unitystation
# 3                     SolerSoft/TaskeRGB
# 4                       appf-anu/tickets
# ...                                  ...
# 1213387  nvim-treesitter/nvim-treesitter
# 1213388                      supabase/ui
# 1213389                      supabase/ui
# 1213390      tristanjohnson849/card-demo
# 1213391                  nushell/nushell
#
#                                                   repo_url  action  \
# 0        https://api.github.com/repos/unitystation/unit...  closed
# 1        https://api.github.com/repos/poissonconsulting...  closed
# 2        https://api.github.com/repos/unitystation/unit...  opened
# 3          https://api.github.com/repos/SolerSoft/TaskeRGB  closed
# 4            https://api.github.com/repos/appf-anu/tickets  closed
# ...                                                    ...     ...
# 1213387  https://api.github.com/repos/nvim-treesitter/n...  opened
# 1213388           https://api.github.com/repos/supabase/ui  closed
# 1213389           https://api.github.com/repos/supabase/ui  closed
# 1213390  https://api.github.com/repos/tristanjohnson849...  closed
# 1213391       https://api.github.com/repos/nushell/nushell  closed
#
#                                                      title  \
# 0        Client breaking NRE when using edit field on C...
# 1        tidy.nlists should return table with term, est...
# 2                   Escape shuttle reaches ludicrous speed
# 3                                  Image Picker for Source
# 4                  [CRITICAL] GC20 Temporal PAR difference
# ...                                                    ...
# 1213387  highlighting works as unexpected after attach ...
# 1213388          Input component has an extra grid space y
# 1213389                   Button to support Ref forwarding
# 1213390                 We need to merge type 1 and type 2
# 1213391                            Release #4 - Nu Scripts
#
#                                                     labels  \
# 0                         Bug High Priority In Progress UI
# 1        Difficulty: 2 Intermediate Effort: 2 Medium Pr...
# 2                                    Bug High Priority lol
# 3                 config enhancement palette priority-high
# 4                                                 CRITICAL
# ...                                                    ...
# 1213387                                                bug
# 1213388                                                bug
# 1213389                                        enhancement
# 1213390                                   good first issue
# 1213391                                  enhancement pri-1
#
#                                                       body              class
# 0        ### Bug:\r\n\r\nIf you use the edit field of t...      high_priority
# 1                                                      NaN      high_priority
# 2        ## Description\r\n\r\nEscape shuttle accelerat...      high_priority
# 3        Implement an Android Image Picker to browse Im...      high_priority
# 4        ### GC20 Temporal PAR difference \n### [CRIT] ...      high_priority
# ...                                                    ...                ...
# 1213387  **Describe the bug**\r\nsee reproduce.\r\n\r\n...  not_high_priority
# 1213388  # Bug report\r\n\r\nI noticed that the Input c...  not_high_priority
# 1213389  # Feature request\r\n\r\n## Is your feature re...  not_high_priority
# 1213390                This is purely for practice and fun  not_high_priority
# 1213391  # Requirements for Nu scripts\r\n- [x] variabl...  not_high_priority
#
# [1213092 rows x 10 columns]

# %%
# Convert dataframe to a CSV file.
all_data_no_dupes.to_csv("csv/full_dataset_priority_high_or_not_high.csv")
