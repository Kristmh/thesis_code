# %% [markdown]
# # Dataset creation
# This notebook will:
# * Remove Technical debt labels
# * Extract 5% to make testing set.
# * It will produce 3 different dataset:
#   1. High/med/priority dataset with no debt
#   2. Test dataset
#   3. Debt dataset

# %%
import pandas as pd

# %%
# Read in the full dataset
file_name = "high_priority"
priority_file_name = f'csv/{file_name}_full_dataset.csv'
priority = pd.read_csv(priority_file_name, index_col=0)
priority
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3       1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4       1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...              ...          ...                  ...
# 373788  7.334924e+09  IssuesEvent  2018-03-06 01:09:12
# 373789  7.334984e+09  IssuesEvent  2018-03-06 01:28:23
# 373790  7.335034e+09  IssuesEvent  2018-03-06 01:44:11
# 373791  7.335035e+09  IssuesEvent  2018-03-06 01:44:26
# 373792  7.335039e+09  IssuesEvent  2018-03-06 01:45:34
#
#                                        repo  \
# 0                 unitystation/unitystation
# 1       zowe/sample-spring-boot-api-service
# 2                        openmsupply/mobile
# 3       UltimateCodeMonkeys/CodeMonkeysMVVM
# 4        wordpress-mobile/WordPress-Android
# ...                                     ...
# 373788           StrangeLoopGames/EcoIssues
# 373789                        asteca/ASteCA
# 373790               wh1ter0se/PowerUp-2018
# 373791               wh1ter0se/PowerUp-2018
# 373792                      xcat2/xcat-core
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/unitystation/unit...  closed
# 1       https://api.github.com/repos/zowe/sample-sprin...  closed
# 2         https://api.github.com/repos/openmsupply/mobile  closed
# 3       https://api.github.com/repos/UltimateCodeMonke...  opened
# 4       https://api.github.com/repos/wordpress-mobile/...  closed
# ...                                                   ...     ...
# 373788  https://api.github.com/repos/StrangeLoopGames/...  closed
# 373789         https://api.github.com/repos/asteca/ASteCA  closed
# 373790  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 373791  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 373792       https://api.github.com/repos/xcat2/xcat-core  closed
#
#                                                     title  \
# 0       Client breaking NRE when using edit field on C...
# 1       The SDK provides a separate Java (no-Spring) l...
# 2                      Auto-log out after some time frame
# 3       Migrate: CodeMonkeys ViewModelNavigationServic...
# 4       IA Reader filter bottom sheet: manage untitled...
# ...                                                   ...
# 373788       Meteor hit - Can no longer join server 6.4.1
# 373789  Improve performance of synth cluster generatio...
# 373790  Get and record refined PID loops for rotation ...
# 373791  Figure out why CyborgCommandSpit() runs early ...
# 373792  error message improvement when adding users in...
#
#                                                    labels  \
# 0                        Bug High Priority In Progress UI
# 1       Feature: API Security Priority: High no-issue-...
# 2       Docs: not needed Effort: small Feature Module:...
# 3       Priority: High Status: In Progress Type: Maint...
# 4                        IA Reader [Pri] High [Type] Task
# ...                                                   ...
# 373788                                      High Priority
# 373789           code_enhance p:high performance synth-cl
# 373790                 IRL development high priority java
# 373791                         R&D bug high priority java
# 373792      priority:high sprint1 status:pending type:bug
#
#                                                      body
# 0       ### Bug:\r\n\r\nIf you use the edit field of t...
# 1       - The commons-spring library is split into:\r\...
# 2       ## Is your feature request related to a proble...
# 3       Migrate the Xamarin.Forms navigation service i...
# 4       In the filter bottom sheet we introduced in th...
# ...                                                   ...
# 373788  Just had the meteor hit on our server and now ...
# 373789  Follow up on #227.\r\n\r\n#### 0. Initial `syn...
# 373790  Pretty simple, and pretty sure we already have...
# 373791  The problem is that when we run autonomous (so...
# 373792  Problem statement: error message when adding x...
#
# [373793 rows x 9 columns]

# %%
# Create debt dataframe
technical_debt_regex = r'debt|\bTD\b'
contains_debt_high_priority = priority['labels'].str.contains(technical_debt_regex, case=False, na=False)
debt = priority[contains_debt_high_priority].reset_index(drop=True)
debt
# Out:
#                id         type           created_at  \
# 0    2.656199e+10  IssuesEvent  2023-01-20 16:36:45
# 1    2.227510e+10  IssuesEvent  2022-06-10 15:50:10
# 2    8.882455e+09  IssuesEvent  2019-01-14 13:16:54
# 3    2.330166e+10  IssuesEvent  2022-08-07 12:16:49
# 4    2.330180e+10  IssuesEvent  2022-08-07 12:39:55
# ..            ...          ...                  ...
# 679  2.332739e+10  IssuesEvent  2022-08-08 23:04:52
# 680  1.414105e+10  IssuesEvent  2020-11-10 12:07:20
# 681  2.589332e+10  IssuesEvent  2022-12-14 19:57:19
# 682  1.052572e+10  IssuesEvent  2019-09-30 15:35:16
# 683  4.928457e+09  IssuesEvent  2016-11-27 10:10:39
#
#                                            repo  \
# 0                                 bcgov/cas-cif
# 1    department-of-veterans-affairs/va.gov-team
# 2      GoogleCloudPlatform/google-cloud-eclipse
# 3                            KinsonDigital/SWCM
# 4            KinsonDigital/GitHubReleaseChecker
# ..                                          ...
# 679                    KinsonDigital/GitHubData
# 680                              zeebe-io/zeebe
# 681                               bcgov/cas-cif
# 682                              huridocs/uwazi
# 683    GoogleCloudPlatform/google-cloud-eclipse
#
#                                               repo_url  action  \
# 0           https://api.github.com/repos/bcgov/cas-cif  closed
# 1    https://api.github.com/repos/department-of-vet...  closed
# 2    https://api.github.com/repos/GoogleCloudPlatfo...  opened
# 3      https://api.github.com/repos/KinsonDigital/SWCM  closed
# 4    https://api.github.com/repos/KinsonDigital/Git...  closed
# ..                                                 ...     ...
# 679  https://api.github.com/repos/KinsonDigital/Git...  opened
# 680        https://api.github.com/repos/zeebe-io/zeebe  closed
# 681         https://api.github.com/repos/bcgov/cas-cif  opened
# 682        https://api.github.com/repos/huridocs/uwazi  closed
# 683  https://api.github.com/repos/GoogleCloudPlatfo...  closed
#
#                                                  title  \
# 0    Tech Debt: some prod data must be a migration ...
# 1       Remove step from Platform Orientation template
# 2             Upgrade to latest appengine-plugins-core
# 3                       🚧Update issue and PR templates
# 4                       🚧Update issue and PR templates
# ..                                                 ...
# 679     🚧Fix project item and research issue templates
# 680                Use MAPPED storage level by default
# 681  Tech Debt: some prod data must be a migration ...
# 682  Create e2e of custom home-page and custom CSS ...
# 683                           Hamcrest jars in release
#
#                                                 labels  \
# 0                              Tech Debt High Priority
# 1    tech-debt Orientation governance-team Ready hi...
# 2                        Tech Debt high priority ready
# 3    good first issue high priority preview tech de...
# 4    good first issue high priority preview tech de...
# ..                                                 ...
# 679  good first issue high priority tech debt 📝docu...
# 680  Impact: Performance Impact: Tech Debt Priority...
# 681         Backlog Refinement Tech Debt High Priority
# 682            Priority: High Status: Sprint Tech Debt
# 683                      build high priority Tech Debt
#
#                                                   body
# 0    ### Description of the Tech Debt ###\r\n\r\nRi...
# 1    ## User Story\nAs a new VFS team member, I wan...
# 2    The latest release of appengine-plugins-core d...
# 3    ### I have done the items below . . .\n\n- [x]...
# 4    ### I have done the items below . . .\n\n- [x]...
# ..                                                 ...
# 679  ### Complete The Item Below\n\n- [X] I have up...
# 680  **Is your feature request related to a problem...
# 681  ###Description of the Tech Debt###\n\nRight no...
# 682  This is the first page every client sees. If t...
# 683  Our release build bundles in 3 hamcrest jars. ...
#
# [684 rows x 9 columns]

# %%
debt.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# priority: high type: technical debt                    31
# good first issue high priority preview tech deb...     19
# tech debt high priority preview                        16
# Priority: High Tech Debt                               15
# high priority preview tech debt                        12
# Sprint Priority: High Tech Debt                        12
# Priority: High Status: Sprint Tech Debt                12
# high priority tech debt                                10
# high priority technical debt                            8
# frontend vsa-debt mvp FSR FSR Enhancements high...      7
# Tech Debt High Priority                                 7
# Sprint Priority: High Tech Debt :hammer_and_wre...      6
# Priority: HIGH TECH DEBT                                6
# Bug Priority: High Tech Debt                            6
# technical debt priority: high                           6
# high priority ingest robot hookup needs review ...      5
# Chain Registry Contract Reg DocOps Epic Hashico...      5
# Tech Debt high priority                                 5
# Priority: High Tech Debt :hammer_and_wrench:            5
# frontend vsa-debt FSR FSR Enhancements high-pri...      5
# Tech Debt enhancement priority:high                     5
# C: Chain Registry C: Contract Registry C: Hashi...      5
# research vsa-debt mvp high-priority Streamlined...      5
# type:debt priority:high                                 5
# high priority in progress technical-debt                5
# Features High Priority Technical Debt                   4
# design research vsa-debt mvp high-priority Stre...      4
# [Pri] High [Type] Technical Debt                        4
# Tech Debt priority:high                                 4
# high priority tech-debt/cleanup                         4
# research tech-debt governance-team Ready high-p...      4
# priority / high area / devOps type / technical ...      4
# good first issue tech debt high priority previe...      4
# area / devOps priority / high type / technical ...      3
# Sprint Priority: High Tech Debt :hammer_and_wre...      3
# Sprint Priority: High Tech Debt :hammer_and_wre...      3
# Feature Request Priority: High Tech Debt                3
# Sprint Priority: High Tech Debt :hammer_and_wre...      3
# high priority techdebt                                  3
# High Priority technical debt                            3
# Bug Priority: High Sprint Tech Debt                     3
# on board priority high technical debt                   3
# Priority: High Type: Technical Debt                     3
# research tech-debt governance-team github Ready...      3
# High-Priority tech debt                                 3
# in:MicroProfile/OpenAPI priority/high tech debt         3
# High Priority Enhancement Upgrades Technical Debt       3
# HIGH PRIORITY TECH DEBT                                 3
# high priority Tech Debt                                 3
# Bug Priority: High Status: Sprint Tech Debt             3

# %%
# Dataset with debt and the given priority
debt_file_name = f"csv/{file_name}_with_td.csv"
debt.to_csv(debt_file_name)

# %%
# To labels
priority.labels.value_counts().to_frame()[:50]
# Out:
#                                   count
# labels
# bug high priority                 10435
# high priority                     10360
# High Priority                      7484
# enhancement high priority          5486
# Priority: High                     4751
# priority.High                      3694
# priority.High type.Task            3685
# priority.high type.task            3209
# priority.High type.Story           2979
# priority.high                      2749
# bug priority: high                 2306
# high-priority                      2262
# priority: high                     2178
# bug high-priority                  2159
# type.Story priority.High           2155
# priority.high type.story           2130
# type.Task priority.High            2022
# bug High Priority                  1888
# High priority                      1815
# Priority: High Type: Bug           1768
# priority:high                      1726
# bug priority:high                  1470
# High Priority bug                  1338
# Priority: High bug                 1200
# Bug High Priority                  1143
# feature high priority              1091
# enhancement priority: high         1090
# enhancement high-priority          1053
# enhancement priority:high           982
# priority-high                       955
# bug priority-high                   927
# enhancement High Priority           902
# bug Priority: High                  837
# Priority: High Type: Enhancement    835
# high priority task                  831
# bug High priority                   744
# priority high                       733
# priority.high type.bug              717
# priority: high type: bug            704
# Type: Bug Priority: High            639
# Bug Priority: High                  620
# High Priority enhancement           611
# documentation priority.High         600
# prio:high                           587
# priority.High type.Enhancement      562
# Bug - High Priority                 562
# Priority: High Type: Feature        541
# bug prio-high                       541
# priority.high type.enhancement      540
# priority/high                       537

# %%
# Remove debt from the dataset
priority_no_debt = priority[~contains_debt_high_priority].reset_index(drop=True)
priority_no_debt.reset_index(drop=True, inplace=True)
priority_no_debt
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3       1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4       1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...              ...          ...                  ...
# 373104  7.334924e+09  IssuesEvent  2018-03-06 01:09:12
# 373105  7.334984e+09  IssuesEvent  2018-03-06 01:28:23
# 373106  7.335034e+09  IssuesEvent  2018-03-06 01:44:11
# 373107  7.335035e+09  IssuesEvent  2018-03-06 01:44:26
# 373108  7.335039e+09  IssuesEvent  2018-03-06 01:45:34
#
#                                        repo  \
# 0                 unitystation/unitystation
# 1       zowe/sample-spring-boot-api-service
# 2                        openmsupply/mobile
# 3       UltimateCodeMonkeys/CodeMonkeysMVVM
# 4        wordpress-mobile/WordPress-Android
# ...                                     ...
# 373104           StrangeLoopGames/EcoIssues
# 373105                        asteca/ASteCA
# 373106               wh1ter0se/PowerUp-2018
# 373107               wh1ter0se/PowerUp-2018
# 373108                      xcat2/xcat-core
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/unitystation/unit...  closed
# 1       https://api.github.com/repos/zowe/sample-sprin...  closed
# 2         https://api.github.com/repos/openmsupply/mobile  closed
# 3       https://api.github.com/repos/UltimateCodeMonke...  opened
# 4       https://api.github.com/repos/wordpress-mobile/...  closed
# ...                                                   ...     ...
# 373104  https://api.github.com/repos/StrangeLoopGames/...  closed
# 373105         https://api.github.com/repos/asteca/ASteCA  closed
# 373106  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 373107  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 373108       https://api.github.com/repos/xcat2/xcat-core  closed
#
#                                                     title  \
# 0       Client breaking NRE when using edit field on C...
# 1       The SDK provides a separate Java (no-Spring) l...
# 2                      Auto-log out after some time frame
# 3       Migrate: CodeMonkeys ViewModelNavigationServic...
# 4       IA Reader filter bottom sheet: manage untitled...
# ...                                                   ...
# 373104       Meteor hit - Can no longer join server 6.4.1
# 373105  Improve performance of synth cluster generatio...
# 373106  Get and record refined PID loops for rotation ...
# 373107  Figure out why CyborgCommandSpit() runs early ...
# 373108  error message improvement when adding users in...
#
#                                                    labels  \
# 0                        Bug High Priority In Progress UI
# 1       Feature: API Security Priority: High no-issue-...
# 2       Docs: not needed Effort: small Feature Module:...
# 3       Priority: High Status: In Progress Type: Maint...
# 4                        IA Reader [Pri] High [Type] Task
# ...                                                   ...
# 373104                                      High Priority
# 373105           code_enhance p:high performance synth-cl
# 373106                 IRL development high priority java
# 373107                         R&D bug high priority java
# 373108      priority:high sprint1 status:pending type:bug
#
#                                                      body
# 0       ### Bug:\r\n\r\nIf you use the edit field of t...
# 1       - The commons-spring library is split into:\r\...
# 2       ## Is your feature request related to a proble...
# 3       Migrate the Xamarin.Forms navigation service i...
# 4       In the filter bottom sheet we introduced in th...
# ...                                                   ...
# 373104  Just had the meteor hit on our server and now ...
# 373105  Follow up on #227.\r\n\r\n#### 0. Initial `syn...
# 373106  Pretty simple, and pretty sure we already have...
# 373107  The problem is that when we run autonomous (so...
# 373108  Problem statement: error message when adding x...
#
# [373109 rows x 9 columns]

# %%
# Sanity check
should_be_empty=priority_no_debt[priority_no_debt['labels'].str.contains(technical_debt_regex, case=False, na=False)]
should_be_empty
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body]
# Index: []

# %%
# Splitting the DataFrame
test_df = priority_no_debt.sample(frac=0.05, random_state=1)  # Select 5% of the data
priority_df = priority_no_debt.drop(test_df.index) 
priority_df.reset_index(drop=True, inplace=True)
priority_df
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3       1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4       1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...              ...          ...                  ...
# 354449  7.334924e+09  IssuesEvent  2018-03-06 01:09:12
# 354450  7.334984e+09  IssuesEvent  2018-03-06 01:28:23
# 354451  7.335034e+09  IssuesEvent  2018-03-06 01:44:11
# 354452  7.335035e+09  IssuesEvent  2018-03-06 01:44:26
# 354453  7.335039e+09  IssuesEvent  2018-03-06 01:45:34
#
#                                        repo  \
# 0                 unitystation/unitystation
# 1       zowe/sample-spring-boot-api-service
# 2                        openmsupply/mobile
# 3       UltimateCodeMonkeys/CodeMonkeysMVVM
# 4        wordpress-mobile/WordPress-Android
# ...                                     ...
# 354449           StrangeLoopGames/EcoIssues
# 354450                        asteca/ASteCA
# 354451               wh1ter0se/PowerUp-2018
# 354452               wh1ter0se/PowerUp-2018
# 354453                      xcat2/xcat-core
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/unitystation/unit...  closed
# 1       https://api.github.com/repos/zowe/sample-sprin...  closed
# 2         https://api.github.com/repos/openmsupply/mobile  closed
# 3       https://api.github.com/repos/UltimateCodeMonke...  opened
# 4       https://api.github.com/repos/wordpress-mobile/...  closed
# ...                                                   ...     ...
# 354449  https://api.github.com/repos/StrangeLoopGames/...  closed
# 354450         https://api.github.com/repos/asteca/ASteCA  closed
# 354451  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 354452  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 354453       https://api.github.com/repos/xcat2/xcat-core  closed
#
#                                                     title  \
# 0       Client breaking NRE when using edit field on C...
# 1       The SDK provides a separate Java (no-Spring) l...
# 2                      Auto-log out after some time frame
# 3       Migrate: CodeMonkeys ViewModelNavigationServic...
# 4       IA Reader filter bottom sheet: manage untitled...
# ...                                                   ...
# 354449       Meteor hit - Can no longer join server 6.4.1
# 354450  Improve performance of synth cluster generatio...
# 354451  Get and record refined PID loops for rotation ...
# 354452  Figure out why CyborgCommandSpit() runs early ...
# 354453  error message improvement when adding users in...
#
#                                                    labels  \
# 0                        Bug High Priority In Progress UI
# 1       Feature: API Security Priority: High no-issue-...
# 2       Docs: not needed Effort: small Feature Module:...
# 3       Priority: High Status: In Progress Type: Maint...
# 4                        IA Reader [Pri] High [Type] Task
# ...                                                   ...
# 354449                                      High Priority
# 354450           code_enhance p:high performance synth-cl
# 354451                 IRL development high priority java
# 354452                         R&D bug high priority java
# 354453      priority:high sprint1 status:pending type:bug
#
#                                                      body
# 0       ### Bug:\r\n\r\nIf you use the edit field of t...
# 1       - The commons-spring library is split into:\r\...
# 2       ## Is your feature request related to a proble...
# 3       Migrate the Xamarin.Forms navigation service i...
# 4       In the filter bottom sheet we introduced in th...
# ...                                                   ...
# 354449  Just had the meteor hit on our server and now ...
# 354450  Follow up on #227.\r\n\r\n#### 0. Initial `syn...
# 354451  Pretty simple, and pretty sure we already have...
# 354452  The problem is that when we run autonomous (so...
# 354453  Problem statement: error message when adding x...
#
# [354454 rows x 9 columns]

# %%
test_df.reset_index(drop=True, inplace=True)
test_df
# Out:
#                  id         type           created_at  \
# 0      1.524382e+10  IssuesEvent  2021-02-19 11:50:11
# 1      2.518793e+09  IssuesEvent  2015-01-17 02:56:12
# 2      3.835368e+09  IssuesEvent  2016-04-01 14:06:15
# 3      1.806097e+10  IssuesEvent  2021-09-20 13:57:15
# 4      3.203484e+09  IssuesEvent  2015-10-02 19:15:11
# ...             ...          ...                  ...
# 18650  1.877249e+10  IssuesEvent  2021-11-07 03:57:06
# 18651  2.874167e+09  IssuesEvent  2015-06-08 20:58:37
# 18652  1.681615e+10  IssuesEvent  2021-06-17 07:37:53
# 18653  5.166520e+09  IssuesEvent  2017-01-17 16:25:14
# 18654  2.660307e+10  IssuesEvent  2023-01-23 17:07:31
#
#                                      repo  \
# 0                       TIC4002-F18-1/tp2
# 1             chessmasterhong/WaterEmblem
# 2               cs2103jan2016-f13-3j/main
# 3                AY2122S1-CS2103-W14-4/tp
# 4                             nrc/rustfmt
# ...                                   ...
# 18650           AY2122S1-CS2103T-T10-1/tp
# 18651                   canadainc/quran10
# 18652  CenterForTheBuiltEnvironment/clima
# 18653                       motion/pundle
# 18654       netlify/netlify-plugin-gatsby
#
#                                                 repo_url  action  \
# 0         https://api.github.com/repos/TIC4002-F18-1/tp2  opened
# 1      https://api.github.com/repos/chessmasterhong/W...  closed
# 2      https://api.github.com/repos/cs2103jan2016-f13...  closed
# 3      https://api.github.com/repos/AY2122S1-CS2103-W...  closed
# 4               https://api.github.com/repos/nrc/rustfmt  closed
# ...                                                  ...     ...
# 18650  https://api.github.com/repos/AY2122S1-CS2103T-...  opened
# 18651     https://api.github.com/repos/canadainc/quran10  opened
# 18652  https://api.github.com/repos/CenterForTheBuilt...  closed
# 18653         https://api.github.com/repos/motion/pundle  closed
# 18654  https://api.github.com/repos/netlify/netlify-p...  closed
#
#                                                    title  \
# 0                              Update UG with Add Remark
# 1                            Dead enemies still a target
# 2                                         Implement Redo
# 3                 Update AboutUs page of project website
# 4      When splitting strings without spaces, look fo...
# ...                                                  ...
# 18650                            Add User Profile Window
# 18651                            Implement search picker
# 18652                           General :: Starting Page
# 18653                                   Implement dedupe
# 18654            Test plugin with old versions of Gatsby
#
#                                                   labels  \
# 0                                          priority.high
# 1                                      bug high priority
# 2               priority.high type.enhancement type.task
# 3                                priority.High type.Task
# 4                            easy p-high poor-formatting
# ...                                                  ...
# 18650                                      priority.High
# 18651  Component-Logic Component-Scripts Component-UI...
# 18652                                      High Priority
# 18653                                      priority-high
# 18654        good first issue type: chore priority: high
#
#                                                     body
# 0                                                    NaN
# 1      After killing an enemy, if I hover over it I c...
# 2                                                    NaN
# 3                                                    NaN
# 4      ```\r\n-        format!("file_name,\"{}\",file...
# ...                                                  ...
# 18650  Add a User Profile Window, which displays the ...
# 18651                Allow ayat to be picked via search.
# 18652  The landing page for the website should be imp...
# 18653  Instead of using filepaths, dedupe resolver wi...
# 18654  Currently the latest version of the plugin [re...
#
# [18655 rows x 9 columns]

# %%
test_df.labels.value_counts().to_frame()[:50]
# Out:
#                                   count
# labels
# bug high priority                   542
# high priority                       525
# High Priority                       380
# Priority: High                      271
# enhancement high priority           260
# priority.High                       185
# priority.high type.task             183
# priority.High type.Task             172
# priority.High type.Story            141
# priority.high                       140
# bug priority: high                  121
# high-priority                       120
# priority.high type.story            118
# type.Story priority.High             99
# priority: high                       98
# priority:high                        93
# bug High Priority                    92
# bug high-priority                    87
# type.Task priority.High              84
# High priority                        83
# Priority: High Type: Bug             82
# High Priority bug                    75
# Priority: High bug                   62
# feature high priority                62
# bug priority:high                    58
# Bug High Priority                    55
# enhancement high-priority            53
# enhancement priority:high            51
# bug priority-high                    49
# priority.high type.bug               47
# enhancement priority: high           46
# Priority: High Type: Enhancement     42
# High Priority enhancement            38
# bug High priority                    37
# high priority task                   36
# priority: high type: bug             36
# priority-high                        36
# enhancement High Priority            33
# Priority: high                       32
# bug Priority: High                   32
# High priority bug                    32
# enhancement Priority: High           31
# documentation priority.High          31
# priority.High type.Enhancement       29
# bug prio:high                        29
# Bug - High Priority                  28
# prio:high                            28
# priority high                        27
# priority.High type.Bug               27
# bug prio-high                        27

# %%
# Convert to csv
priority_file_name = f"csv/{file_name}_no_td.csv"
priority_df.to_csv(priority_file_name)

# %%
test_set_file_name = f"csv/{file_name}_test_set.csv"
test_df.to_csv(test_set_file_name)

# %%
pri = pd.read_csv(priority_file_name, index_col=0)
pri
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141754e+10  IssuesEvent  2020-02-03 00:01:26
# 2       1.141755e+10  IssuesEvent  2020-02-03 00:02:58
# 3       1.141755e+10  IssuesEvent  2020-02-03 00:04:18
# 4       1.141756e+10  IssuesEvent  2020-02-03 00:08:03
# ...              ...          ...                  ...
# 354449  7.334924e+09  IssuesEvent  2018-03-06 01:09:12
# 354450  7.334984e+09  IssuesEvent  2018-03-06 01:28:23
# 354451  7.335034e+09  IssuesEvent  2018-03-06 01:44:11
# 354452  7.335035e+09  IssuesEvent  2018-03-06 01:44:26
# 354453  7.335039e+09  IssuesEvent  2018-03-06 01:45:34
#
#                                        repo  \
# 0                 unitystation/unitystation
# 1       zowe/sample-spring-boot-api-service
# 2                        openmsupply/mobile
# 3       UltimateCodeMonkeys/CodeMonkeysMVVM
# 4        wordpress-mobile/WordPress-Android
# ...                                     ...
# 354449           StrangeLoopGames/EcoIssues
# 354450                        asteca/ASteCA
# 354451               wh1ter0se/PowerUp-2018
# 354452               wh1ter0se/PowerUp-2018
# 354453                      xcat2/xcat-core
#
#                                                  repo_url  action  \
# 0       https://api.github.com/repos/unitystation/unit...  closed
# 1       https://api.github.com/repos/zowe/sample-sprin...  closed
# 2         https://api.github.com/repos/openmsupply/mobile  closed
# 3       https://api.github.com/repos/UltimateCodeMonke...  opened
# 4       https://api.github.com/repos/wordpress-mobile/...  closed
# ...                                                   ...     ...
# 354449  https://api.github.com/repos/StrangeLoopGames/...  closed
# 354450         https://api.github.com/repos/asteca/ASteCA  closed
# 354451  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 354452  https://api.github.com/repos/wh1ter0se/PowerUp...  closed
# 354453       https://api.github.com/repos/xcat2/xcat-core  closed
#
#                                                     title  \
# 0       Client breaking NRE when using edit field on C...
# 1       The SDK provides a separate Java (no-Spring) l...
# 2                      Auto-log out after some time frame
# 3       Migrate: CodeMonkeys ViewModelNavigationServic...
# 4       IA Reader filter bottom sheet: manage untitled...
# ...                                                   ...
# 354449       Meteor hit - Can no longer join server 6.4.1
# 354450  Improve performance of synth cluster generatio...
# 354451  Get and record refined PID loops for rotation ...
# 354452  Figure out why CyborgCommandSpit() runs early ...
# 354453  error message improvement when adding users in...
#
#                                                    labels  \
# 0                        Bug High Priority In Progress UI
# 1       Feature: API Security Priority: High no-issue-...
# 2       Docs: not needed Effort: small Feature Module:...
# 3       Priority: High Status: In Progress Type: Maint...
# 4                        IA Reader [Pri] High [Type] Task
# ...                                                   ...
# 354449                                      High Priority
# 354450           code_enhance p:high performance synth-cl
# 354451                 IRL development high priority java
# 354452                         R&D bug high priority java
# 354453      priority:high sprint1 status:pending type:bug
#
#                                                      body
# 0       ### Bug:\r\n\r\nIf you use the edit field of t...
# 1       - The commons-spring library is split into:\r\...
# 2       ## Is your feature request related to a proble...
# 3       Migrate the Xamarin.Forms navigation service i...
# 4       In the filter bottom sheet we introduced in th...
# ...                                                   ...
# 354449  Just had the meteor hit on our server and now ...
# 354450  Follow up on #227.\r\n\r\n#### 0. Initial `syn...
# 354451  Pretty simple, and pretty sure we already have...
# 354452  The problem is that when we run autonomous (so...
# 354453  Problem statement: error message when adding x...
#
# [354454 rows x 9 columns]

# %%
test_set = pd.read_csv(test_set_file_name, index_col=0)
test_set
# Out:
#                  id         type           created_at  \
# 0      1.524382e+10  IssuesEvent  2021-02-19 11:50:11
# 1      2.518793e+09  IssuesEvent  2015-01-17 02:56:12
# 2      3.835368e+09  IssuesEvent  2016-04-01 14:06:15
# 3      1.806097e+10  IssuesEvent  2021-09-20 13:57:15
# 4      3.203484e+09  IssuesEvent  2015-10-02 19:15:11
# ...             ...          ...                  ...
# 18650  1.877249e+10  IssuesEvent  2021-11-07 03:57:06
# 18651  2.874167e+09  IssuesEvent  2015-06-08 20:58:37
# 18652  1.681615e+10  IssuesEvent  2021-06-17 07:37:53
# 18653  5.166520e+09  IssuesEvent  2017-01-17 16:25:14
# 18654  2.660307e+10  IssuesEvent  2023-01-23 17:07:31
#
#                                      repo  \
# 0                       TIC4002-F18-1/tp2
# 1             chessmasterhong/WaterEmblem
# 2               cs2103jan2016-f13-3j/main
# 3                AY2122S1-CS2103-W14-4/tp
# 4                             nrc/rustfmt
# ...                                   ...
# 18650           AY2122S1-CS2103T-T10-1/tp
# 18651                   canadainc/quran10
# 18652  CenterForTheBuiltEnvironment/clima
# 18653                       motion/pundle
# 18654       netlify/netlify-plugin-gatsby
#
#                                                 repo_url  action  \
# 0         https://api.github.com/repos/TIC4002-F18-1/tp2  opened
# 1      https://api.github.com/repos/chessmasterhong/W...  closed
# 2      https://api.github.com/repos/cs2103jan2016-f13...  closed
# 3      https://api.github.com/repos/AY2122S1-CS2103-W...  closed
# 4               https://api.github.com/repos/nrc/rustfmt  closed
# ...                                                  ...     ...
# 18650  https://api.github.com/repos/AY2122S1-CS2103T-...  opened
# 18651     https://api.github.com/repos/canadainc/quran10  opened
# 18652  https://api.github.com/repos/CenterForTheBuilt...  closed
# 18653         https://api.github.com/repos/motion/pundle  closed
# 18654  https://api.github.com/repos/netlify/netlify-p...  closed
#
#                                                    title  \
# 0                              Update UG with Add Remark
# 1                            Dead enemies still a target
# 2                                         Implement Redo
# 3                 Update AboutUs page of project website
# 4      When splitting strings without spaces, look fo...
# ...                                                  ...
# 18650                            Add User Profile Window
# 18651                            Implement search picker
# 18652                           General :: Starting Page
# 18653                                   Implement dedupe
# 18654            Test plugin with old versions of Gatsby
#
#                                                   labels  \
# 0                                          priority.high
# 1                                      bug high priority
# 2               priority.high type.enhancement type.task
# 3                                priority.High type.Task
# 4                            easy p-high poor-formatting
# ...                                                  ...
# 18650                                      priority.High
# 18651  Component-Logic Component-Scripts Component-UI...
# 18652                                      High Priority
# 18653                                      priority-high
# 18654        good first issue type: chore priority: high
#
#                                                     body
# 0                                                    NaN
# 1      After killing an enemy, if I hover over it I c...
# 2                                                    NaN
# 3                                                    NaN
# 4      ```\r\n-        format!("file_name,\"{}\",file...
# ...                                                  ...
# 18650  Add a User Profile Window, which displays the ...
# 18651                Allow ayat to be picked via search.
# 18652  The landing page for the website should be imp...
# 18653  Instead of using filepaths, dedupe resolver wi...
# 18654  Currently the latest version of the plugin [re...
#
# [18655 rows x 9 columns]

# %%
debt = pd.read_csv(debt_file_name, index_col=0)
debt
# Out:
#                id         type           created_at  \
# 0    2.656199e+10  IssuesEvent  2023-01-20 16:36:45
# 1    2.227510e+10  IssuesEvent  2022-06-10 15:50:10
# 2    8.882455e+09  IssuesEvent  2019-01-14 13:16:54
# 3    2.330166e+10  IssuesEvent  2022-08-07 12:16:49
# 4    2.330180e+10  IssuesEvent  2022-08-07 12:39:55
# ..            ...          ...                  ...
# 679  2.332739e+10  IssuesEvent  2022-08-08 23:04:52
# 680  1.414105e+10  IssuesEvent  2020-11-10 12:07:20
# 681  2.589332e+10  IssuesEvent  2022-12-14 19:57:19
# 682  1.052572e+10  IssuesEvent  2019-09-30 15:35:16
# 683  4.928457e+09  IssuesEvent  2016-11-27 10:10:39
#
#                                            repo  \
# 0                                 bcgov/cas-cif
# 1    department-of-veterans-affairs/va.gov-team
# 2      GoogleCloudPlatform/google-cloud-eclipse
# 3                            KinsonDigital/SWCM
# 4            KinsonDigital/GitHubReleaseChecker
# ..                                          ...
# 679                    KinsonDigital/GitHubData
# 680                              zeebe-io/zeebe
# 681                               bcgov/cas-cif
# 682                              huridocs/uwazi
# 683    GoogleCloudPlatform/google-cloud-eclipse
#
#                                               repo_url  action  \
# 0           https://api.github.com/repos/bcgov/cas-cif  closed
# 1    https://api.github.com/repos/department-of-vet...  closed
# 2    https://api.github.com/repos/GoogleCloudPlatfo...  opened
# 3      https://api.github.com/repos/KinsonDigital/SWCM  closed
# 4    https://api.github.com/repos/KinsonDigital/Git...  closed
# ..                                                 ...     ...
# 679  https://api.github.com/repos/KinsonDigital/Git...  opened
# 680        https://api.github.com/repos/zeebe-io/zeebe  closed
# 681         https://api.github.com/repos/bcgov/cas-cif  opened
# 682        https://api.github.com/repos/huridocs/uwazi  closed
# 683  https://api.github.com/repos/GoogleCloudPlatfo...  closed
#
#                                                  title  \
# 0    Tech Debt: some prod data must be a migration ...
# 1       Remove step from Platform Orientation template
# 2             Upgrade to latest appengine-plugins-core
# 3                       🚧Update issue and PR templates
# 4                       🚧Update issue and PR templates
# ..                                                 ...
# 679     🚧Fix project item and research issue templates
# 680                Use MAPPED storage level by default
# 681  Tech Debt: some prod data must be a migration ...
# 682  Create e2e of custom home-page and custom CSS ...
# 683                           Hamcrest jars in release
#
#                                                 labels  \
# 0                              Tech Debt High Priority
# 1    tech-debt Orientation governance-team Ready hi...
# 2                        Tech Debt high priority ready
# 3    good first issue high priority preview tech de...
# 4    good first issue high priority preview tech de...
# ..                                                 ...
# 679  good first issue high priority tech debt 📝docu...
# 680  Impact: Performance Impact: Tech Debt Priority...
# 681         Backlog Refinement Tech Debt High Priority
# 682            Priority: High Status: Sprint Tech Debt
# 683                      build high priority Tech Debt
#
#                                                   body
# 0    ### Description of the Tech Debt ###\r\n\r\nRi...
# 1    ## User Story\nAs a new VFS team member, I wan...
# 2    The latest release of appengine-plugins-core d...
# 3    ### I have done the items below . . .\n\n- [x]...
# 4    ### I have done the items below . . .\n\n- [x]...
# ..                                                 ...
# 679  ### Complete The Item Below\n\n- [X] I have up...
# 680  **Is your feature request related to a problem...
# 681  ###Description of the Tech Debt###\n\nRight no...
# 682  This is the first page every client sees. If t...
# 683  Our release build bundles in 3 hamcrest jars. ...
#
# [684 rows x 9 columns]
