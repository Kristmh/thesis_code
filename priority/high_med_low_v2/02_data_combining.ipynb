# %%
import pandas as pd

# %%
# Read CSV into a dataframe
high_priority = pd.read_csv("csv/final_high_priority_dataset.csv", index_col=0)
medium_priority = pd.read_csv("csv/final_medium_priority_dataset.csv", index_col=0)
low_priority = pd.read_csv("csv/final_low_priority_dataset.csv", index_col=0)

# %%
high_priority
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141757e+10  IssuesEvent  2020-02-03 00:11:29
# 2       1.141766e+10  IssuesEvent  2020-02-03 00:47:48
# 3       1.141776e+10  IssuesEvent  2020-02-03 01:22:41
# 4       1.141777e+10  IssuesEvent  2020-02-03 01:24:06
# ...              ...          ...                  ...
# 415158  7.334914e+09  IssuesEvent  2018-03-06 01:05:53
# 415159  7.334924e+09  IssuesEvent  2018-03-06 01:08:55
# 415160  7.334924e+09  IssuesEvent  2018-03-06 01:09:12
# 415161  7.335034e+09  IssuesEvent  2018-03-06 01:44:11
# 415162  7.335035e+09  IssuesEvent  2018-03-06 01:44:26
#
#                                 repo  \
# 0          unitystation/unitystation
# 1            poissonconsulting/nlist
# 2          unitystation/unitystation
# 3                 SolerSoft/TaskeRGB
# 4                   appf-anu/tickets
# ...                              ...
# ...

# %%
# Number or different labels
high_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# bug high priority                                   10435
# high priority                                       10360
# Severe Urgent                                       10055
# bug urgent                                           7950
# bug critical                                         7643
# High Priority                                        7484
# enhancement high priority                            5486
# critical                                             4549
# priority.High                                        3694
# priority.High type.Task                              3685
# priority.high type.task                              3209
# priority.High type.Story                             2979
# urgent                                               2757
# priority.high                                        2749
# high-priority                                        2262
# ...

# %%
medium_priority
# Out:
#                   id         type           created_at  \
# 0       1.141757e+10  IssuesEvent  2020-02-03 00:11:29
# 1       1.141781e+10  IssuesEvent  2020-02-03 01:38:13
# 2       1.141805e+10  IssuesEvent  2020-02-03 02:48:17
# 3       1.141809e+10  IssuesEvent  2020-02-03 03:00:58
# 4       1.141821e+10  IssuesEvent  2020-02-03 03:33:19
# ...              ...          ...                  ...
# 131031  2.060567e+10  IssuesEvent  2022-03-06 23:09:05
# 131032  2.060573e+10  IssuesEvent  2022-03-06 23:19:57
# 131033  2.060577e+10  IssuesEvent  2022-03-06 23:26:50
# 131034  7.335014e+09  IssuesEvent  2018-03-06 01:37:19
# 131035  7.335036e+09  IssuesEvent  2018-03-06 01:44:45
#
#                               repo  \
# 0          poissonconsulting/nlist
# 1        ericauv/ericauv-portfolio
# 2          poissonconsulting/nlist
# 3          poissonconsulting/nlist
# 4          poissonconsulting/nlist
# ...                            ...
# 131031         nowthis/sankeymatic
# ...

# %%
# Number or different labels
medium_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# auto-migrated Priority-Medium Type-Defect           22849
# Medium Priority                                      3415
# bug imported Priority-Medium                         2846
# auto-migrated Priority-Medium Type-Enhancement       2167
# medium priority                                      2051
# enhancement medium priority                          1905
# priority.Medium                                      1653
# bug medium priority                                  1564
# auto-migrated Priority-Medium Type-Sample            1523
# priority.Medium type.Story                           1448
# priority.Medium type.Task                            1353
# priority.medium                                      1271
# Priority-Medium Type-Defect auto-migrated            1193
# bug imported invalid Priority-Medium                 1146
# priority.medium type.story                           1013
# ...

# %%
low_priority
# Out:
#                   id         type           created_at  \
# 0       1.141755e+10  IssuesEvent  2020-02-03 00:02:50
# 1       1.141786e+10  IssuesEvent  2020-02-03 01:52:04
# 2       1.141813e+10  IssuesEvent  2020-02-03 03:11:27
# 3       1.141822e+10  IssuesEvent  2020-02-03 03:35:44
# 4       1.141824e+10  IssuesEvent  2020-02-03 03:41:32
# ...              ...          ...                  ...
# 103621  2.060584e+10  IssuesEvent  2022-03-06 23:40:48
# 103622  2.060586e+10  IssuesEvent  2022-03-06 23:45:23
# 103623  7.334740e+09  IssuesEvent  2018-03-06 00:10:40
# 103624  7.335047e+09  IssuesEvent  2018-03-06 01:48:07
# 103625  7.335050e+09  IssuesEvent  2018-03-06 01:49:10
#
#                                                repo  \
# 0                            poissonconsulting/term
# 1                            poissonconsulting/term
# 2                           poissonconsulting/nlist
# 3                           poissonconsulting/nlist
# ...

# %%
# Number or different labels
low_priority.labels.value_counts().to_frame()[:50]
# Out:
#                                              count
# labels
# enhancement low priority                      5496
# low priority                                  5485
# bug low priority                              2798
# Low Priority                                  2732
# pri:low pri:lowest                            2692
# auto-migrated Priority-Low Type-Enhancement   1150
# low-priority                                  1140
# enhancement low-priority                      1116
# auto-migrated Priority-Low Type-Defect         889
# Low priority                                   741
# Being Redone Low Priority                      705
# enhancement Low Priority                       673
# Low Priority enhancement                       602
# priority.low type.story                        591
# priority-low                                   585
# enhancement priority-low                       565
# feature low priority                           565
# ...

# %%
# Add a new column
high_priority["class"] = "high_priority"
high_priority
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141757e+10  IssuesEvent  2020-02-03 00:11:29
# 2       1.141766e+10  IssuesEvent  2020-02-03 00:47:48
# 3       1.141776e+10  IssuesEvent  2020-02-03 01:22:41
# 4       1.141777e+10  IssuesEvent  2020-02-03 01:24:06
# ...              ...          ...                  ...
# 415158  7.334914e+09  IssuesEvent  2018-03-06 01:05:53
# 415159  7.334924e+09  IssuesEvent  2018-03-06 01:08:55
# 415160  7.334924e+09  IssuesEvent  2018-03-06 01:09:12
# 415161  7.335034e+09  IssuesEvent  2018-03-06 01:44:11
# 415162  7.335035e+09  IssuesEvent  2018-03-06 01:44:26
#
#                                 repo  \
# 0          unitystation/unitystation
# 1            poissonconsulting/nlist
# 2          unitystation/unitystation
# 3                 SolerSoft/TaskeRGB
# 4                   appf-anu/tickets
# ...                              ...
# ...

# %%
medium_priority["class"] = "medium_priority"
medium_priority
# Out:
#                   id         type           created_at  \
# 0       1.141757e+10  IssuesEvent  2020-02-03 00:11:29
# 1       1.141781e+10  IssuesEvent  2020-02-03 01:38:13
# 2       1.141805e+10  IssuesEvent  2020-02-03 02:48:17
# 3       1.141809e+10  IssuesEvent  2020-02-03 03:00:58
# 4       1.141821e+10  IssuesEvent  2020-02-03 03:33:19
# ...              ...          ...                  ...
# 131031  2.060567e+10  IssuesEvent  2022-03-06 23:09:05
# 131032  2.060573e+10  IssuesEvent  2022-03-06 23:19:57
# 131033  2.060577e+10  IssuesEvent  2022-03-06 23:26:50
# 131034  7.335014e+09  IssuesEvent  2018-03-06 01:37:19
# 131035  7.335036e+09  IssuesEvent  2018-03-06 01:44:45
#
#                               repo  \
# 0          poissonconsulting/nlist
# 1        ericauv/ericauv-portfolio
# 2          poissonconsulting/nlist
# 3          poissonconsulting/nlist
# 4          poissonconsulting/nlist
# ...                            ...
# 131031         nowthis/sankeymatic
# ...

# %%
low_priority["class"] = "low_priority"
low_priority
# Out:
#                   id         type           created_at  \
# 0       1.141755e+10  IssuesEvent  2020-02-03 00:02:50
# 1       1.141786e+10  IssuesEvent  2020-02-03 01:52:04
# 2       1.141813e+10  IssuesEvent  2020-02-03 03:11:27
# 3       1.141822e+10  IssuesEvent  2020-02-03 03:35:44
# 4       1.141824e+10  IssuesEvent  2020-02-03 03:41:32
# ...              ...          ...                  ...
# 103621  2.060584e+10  IssuesEvent  2022-03-06 23:40:48
# 103622  2.060586e+10  IssuesEvent  2022-03-06 23:45:23
# 103623  7.334740e+09  IssuesEvent  2018-03-06 00:10:40
# 103624  7.335047e+09  IssuesEvent  2018-03-06 01:48:07
# 103625  7.335050e+09  IssuesEvent  2018-03-06 01:49:10
#
#                                                repo  \
# 0                            poissonconsulting/term
# 1                            poissonconsulting/term
# 2                           poissonconsulting/nlist
# 3                           poissonconsulting/nlist
# ...

# %%
all_data = pd.concat([high_priority, medium_priority, low_priority] , ignore_index= True)

# %%
all_data
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141757e+10  IssuesEvent  2020-02-03 00:11:29
# 2       1.141766e+10  IssuesEvent  2020-02-03 00:47:48
# 3       1.141776e+10  IssuesEvent  2020-02-03 01:22:41
# 4       1.141777e+10  IssuesEvent  2020-02-03 01:24:06
# ...              ...          ...                  ...
# 649820  2.060584e+10  IssuesEvent  2022-03-06 23:40:48
# 649821  2.060586e+10  IssuesEvent  2022-03-06 23:45:23
# 649822  7.334740e+09  IssuesEvent  2018-03-06 00:10:40
# 649823  7.335047e+09  IssuesEvent  2018-03-06 01:48:07
# 649824  7.335050e+09  IssuesEvent  2018-03-06 01:49:10
#
#                                                repo  \
# 0                         unitystation/unitystation
# 1                           poissonconsulting/nlist
# 2                         unitystation/unitystation
# 3                                SolerSoft/TaskeRGB
# ...

# %%
all_data_no_dupes = all_data.drop_duplicates()
all_data_no_dupes
# Out:
#                   id         type           created_at  \
# 0       1.141754e+10  IssuesEvent  2020-02-03 00:00:44
# 1       1.141757e+10  IssuesEvent  2020-02-03 00:11:29
# 2       1.141766e+10  IssuesEvent  2020-02-03 00:47:48
# 3       1.141776e+10  IssuesEvent  2020-02-03 01:22:41
# 4       1.141777e+10  IssuesEvent  2020-02-03 01:24:06
# ...              ...          ...                  ...
# 649820  2.060584e+10  IssuesEvent  2022-03-06 23:40:48
# 649821  2.060586e+10  IssuesEvent  2022-03-06 23:45:23
# 649822  7.334740e+09  IssuesEvent  2018-03-06 00:10:40
# 649823  7.335047e+09  IssuesEvent  2018-03-06 01:48:07
# 649824  7.335050e+09  IssuesEvent  2018-03-06 01:49:10
#
#                                                repo  \
# 0                         unitystation/unitystation
# 1                           poissonconsulting/nlist
# 2                         unitystation/unitystation
# 3                                SolerSoft/TaskeRGB
# ...

# %%
# Convert dataframe to a CSV file.
all_data_no_dupes.to_csv("csv/full_dataset_priority_high_med_low.csv")
