# %% [markdown]
# # Create dataset: Highest vs rest (high, medium, low, lowest)
# * Under sampling the majority class.
# * 50/50 balance per class.

# %%
import pandas as pd
# Import csv file
file_name = "clean_MongoDB"
df = pd.read_csv(f'../csv/{file_name}.csv')
df
# Out:
#              priority                                        description  \
# 0          Major - P3  Currently there are a number of tests in the C...
# 1          Major - P3  The following compilation notes are getting ge...
# 2          Major - P3  \nh2. [verify-datafile-from-little-endian fail...
# 3          Major - P3  h2. [spinlock-gcc-test failed on ! Ubuntu 20.0...
# 4          Major - P3  \nh2. [cppsuite-hs-cleanup-stress failed on Cp...
# ...               ...                                                ...
# 103322     Major - P3  The following command generates a plan that do...
# 103323  Critical - P2  Hi Team,\r\n\r\nI have a very weird problem, w...
# 103324  Critical - P2  Mongod crashes while running YCSB.  Log and mo...
# 103325     Major - P3  Updated yaml files for the three projects to u...
# 103326     Major - P3  that is recognized by the sharded cluster. Thi...
#
#             project          labels      issuetype collection  \
# 0        WiredTiger              []    Improvement    MongoDB
# 1        WiredTiger              []            Bug    MongoDB
# 2        WiredTiger              []  Build Failure    MongoDB
# 3        WiredTiger  ['CI-blocker']  Build Failure    MongoDB
# 4        WiredTiger              []  Build Failure    MongoDB
# ...             ...             ...            ...        ...
# 103322  Core Server      ['neweng']            Bug    MongoDB
# 103323  Core Server              []            Bug    MongoDB
# 103324  Core Server              []            Bug    MongoDB
# 103325  Core Server   ['test-only']           Task    MongoDB
# 103326  Core Server              []           Task    MongoDB
#
#                                                  text_str  \
# 0       Currently there are a number of tests in the C...
# 1       The following compilation notes are getting ge...
# 2       \nh2. [verify-datafile-from-little-endian fail...
# 3       h2. [spinlock-gcc-test failed on ! Ubuntu 20.0...
# 4       \nh2. [cppsuite-hs-cleanup-stress failed on Cp...
# ...                                                   ...
# 103322  The following command generates a plan that do...
# 103323  Hi Team,\r\n\r\nI have a very weird problem, w...
# 103324  Mongod crashes while running YCSB.  Log and mo...
# 103325  Updated yaml files for the three projects to u...
# 103326  that is recognized by the sharded cluster. Thi...
#
#                                                text_clean
# 0       currently there are a number of tests in the c...
# 1       the following compilation notes are getting ge...
# 2       verifydatafilefromlittleendian failed on bigen...
# 3       spinlockgcctest failed on ubuntu host project ...
# 4       cppsuitehscleanupstress failed on cppsuite str...
# ...                                                   ...
# 103322  the following command generates a plan that do...
# 103323  hi team i have a very weird problem when i run...
# 103324  mongod crashes while running ycsb log and mong...
# 103325  updated yaml files for the three projects to u...
# 103326  that is recognized by the sharded cluster this...
#
# [103327 rows x 8 columns]

# %%
# Count class
df['priority'].value_counts().to_frame()
# Out:
#                count
# priority
# Major - P3     85556
# Minor - P4     11932
# Critical - P2   2992
# Trivial - P5    1937
# Blocker - P1     910

# %%
# NaN values
df.isnull().sum()
# Out:
# priority         0
# description      0
# project          0
# labels           0
# issuetype        0
# collection       0
# text_str         0
# text_clean     130
# dtype: int64

# %%
# Drop NaN values
df = df.dropna()
df.isnull().sum()
# Out:
# priority       0
# description    0
# project        0
# labels         0
# issuetype      0
# collection     0
# text_str       0
# text_clean     0
# dtype: int64

# %%
# Count class
df['priority'].value_counts().to_frame()
# Out:
#                count
# priority
# Major - P3     85442
# Minor - P4     11922
# Critical - P2   2988
# Trivial - P5    1937
# Blocker - P1     908

# %%
# Unique collections
df['collection'].unique()
# Out:
# array(['MongoDB'], dtype=object)

# %%
# Unique projects
df['project'].unique().tolist()
# Out:
# ['WiredTiger',
#  'Core Server',
#  'Rust Driver',
#  'Ruby Driver',
#  'Python Driver',
#  'PHP Driver: Library',
#  'PHP Driver: Extension',
#  'Node.js Driver',
#  'Motor',
#  'VS Code Extension',
#  'MongoDB Database Tools',
#  'MongoDB Shell',
#  'Mongoid',
#  'Libmongocrypt',
#  'Kafka Connector',
#  'Java Driver',
#  'Go Driver',
#  'Evergreen',
#  'Swift Driver',
#  'Drivers',
#  'Documentation',
#  'Spark Connector',
#  'Decision Automation Group',
#  'C++ Driver',
#  'C# Driver',
#  'Compass ',
#  'C Driver']

# %%
# Number of unique projects 
len(df['project'].unique())
# Out:
# 27

# %%
priority_mapping = {
    'Blocker - P1': 'Highest',
    'Critical - P2': 'High',
    'Major - P3': 'Medium',
    'Minor - P4': 'Low',
    'Trivial - P5': 'Lowest',

}
# Apply mapping
df['class'] = df['priority'].map(priority_mapping)
# Out:
# /tmp/ipykernel_318675/2311033747.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['class'] = df['priority'].map(priority_mapping)

# %%
# Find the priorities that are not mapped to 'Highest' by checking for nulls in 'class'
unmapped_priorities = df[df['class'].isnull()]['priority'].unique()

if len(unmapped_priorities)  == 0:
    print("All priorities are mapped to a new class")
else:
    print("Priorities not mapped to a new class:")
    for priority in unmapped_priorities:
        print(f"- {priority}")
# Out:
# All priorities are mapped to a new class

# %%
# Count class
df['class'].value_counts().to_frame()
# Out:
#          count
# class
# Medium   85442
# Low      11922
# High      2988
# Lowest    1937
# Highest    908

# %%
highest = df[df['class'] == 'Highest']
highest["label"] = 1
highest["class_original"] = "Highest"
highest["class"] = "highest"
high = df[df['class'] == 'High']
medium = df[df['class'] == 'Medium']
low = df[df['class'] == 'Low']
lowest = df[df['class'] == 'Lowest']
# Out:
# /tmp/ipykernel_318675/3737047461.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["label"] = 1
# /tmp/ipykernel_318675/3737047461.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["class_original"] = "Highest"
# /tmp/ipykernel_318675/3737047461.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["class"] = "highest"

# %%
# Concat all class except highest
rest = pd.concat([high, medium, low, lowest])
# Rename class to class_1
rest = rest.rename(columns={'class': 'class_original'})
rest["class"] = "rest" 
rest["label"] = 0
rest
# Out:
#              priority                                        description  \
# 361     Critical - P2  I'm hitting [the following assertion|https://g...
# 464     Critical - P2  In WT-3805, we made some changes intended to s...
# 733     Critical - P2  The smoke test of the {{timestamp_abort}} prog...
# 764     Critical - P2  In WT-3181, specifically: https://github.com/w...
# 812     Critical - P2  Write failures during a clean shutdown can lea...
# ...               ...                                                ...
# 102938   Trivial - P5  The MSVC 2015 compiler produces the following ...
# 102970   Trivial - P5  We set the location of the minidump using the ...
# 103096   Trivial - P5  I am using this check https://github.com/mzupa...
# 103111   Trivial - P5  {code:cpp}\r\nstd::unique_ptr<Lock::ResourceLo...
# 103156   Trivial - P5  Not restoring the stream format state of an os...
#
#             project             labels issuetype collection  \
# 361      WiredTiger                 []       Bug    MongoDB
# 464      WiredTiger            ['bkp']       Bug    MongoDB
# 733      WiredTiger                 []       Bug    MongoDB
# 764      WiredTiger                 []       Bug    MongoDB
# 812      WiredTiger                 []       Bug    MongoDB
# ...             ...                ...       ...        ...
# 102938  Core Server                 []       Bug    MongoDB
# 102970  Core Server  ['PM-372', 'stm']       Bug    MongoDB
# 103096  Core Server                 []  Question    MongoDB
# 103111  Core Server         ['neweng']      Task    MongoDB
# 103156  Core Server       ['coverity']       Bug    MongoDB
#
#                                                  text_str  \
# 361     I'm hitting [the following assertion|https://g...
# 464     In WT-3805, we made some changes intended to s...
# 733     The smoke test of the {{timestamp_abort}} prog...
# 764     In WT-3181, specifically: https://github.com/w...
# 812     Write failures during a clean shutdown can lea...
# ...                                                   ...
# 102938  The MSVC 2015 compiler produces the following ...
# 102970  We set the location of the minidump using the ...
# 103096  I am using this check https://github.com/mzupa...
# 103111  {code:cpp}\r\nstd::unique_ptr<Lock::ResourceLo...
# 103156  Not restoring the stream format state of an os...
#
#                                                text_clean class_original  \
# 361     im hitting the following assertion in a test s...           High
# 464     in we made some changes intended to skip most ...           High
# 733     the smoke test of the timestampabort program f...           High
# 764     in specifically the logic around updating btre...           High
# 812     write failures during a clean shutdown can lea...           High
# ...                                                   ...            ...
# 102938  the msvc compiler produces the following warni...         Lowest
# 102970  we set the location of the minidump using the ...         Lowest
# 103096  i am using this check to monitor replication l...         Lowest
# 103111  codecpp stduniqueptr rlk if isrsthreadsafe opc...         Lowest
# 103156  not restoring the stream format state of an os...         Lowest
#
#        class  label
# 361     rest      0
# 464     rest      0
# 733     rest      0
# 764     rest      0
# 812     rest      0
# ...      ...    ...
# 102938  rest      0
# 102970  rest      0
# 103096  rest      0
# 103111  rest      0
# 103156  rest      0
#
# [102289 rows x 11 columns]

# %%
# Value count rest class
rest['class'].value_counts().to_frame()
# Out:
#         count
# class
# rest   102289

# %%
from sklearn.utils import shuffle
# Number of rows in the highest class
n_highest = highest.shape[0]

rest_sampled = rest.sample(n=n_highest, random_state=42)  


balanced_data = pd.concat([highest, rest_sampled])

# Shuffle the combined dataset
balanced_data = shuffle(balanced_data, random_state=42)
balanced_data
# Out:
#             priority                                        description  \
# 31535  Critical - P2  2018-05-16 06:06:33,088 INFO c.c.dashboard.aut...
# 62050   Blocker - P1  First logged failure here: https://mci.10gen.c...
# 16753   Blocker - P1  I perform following tutorial for my knowledge\...
# 48909   Blocker - P1  h2. Description\r\nYes - it would be a new com...
# 57486   Blocker - P1  createUser docs are wrong, the name of the use...
# ...              ...                                                ...
# 88833     Major - P3  db.collection.count(\{$or: [{deleted: {$exists...
# 90893     Major - P3  We must make sure that there are no more users...
# 80099   Blocker - P1  {panel:title=Issue Status as of June 15, 2020|...
# 8609      Major - P3  The topology coordinator is the repository for...
# 61555     Major - P3  The legacy release of the C++ driver is being ...
#
#              project                                     labels    issuetype  \
# 31535        Mongoid             ['authentication,', 'mongodb']          Bug
# 62050     C++ Driver                             ['legacy-cxx']          Bug
# 16753    Core Server  ['replicaset', 'replication', 'sharding']          Bug
# 48909  Documentation                                         []         Task
# 57486  Documentation                     ['collector-298ba4e7']  Improvement
# ...              ...                                        ...          ...
# 88833    Core Server                                         []          Bug
# 90893    Core Server                                         []         Task
# 80099     WiredTiger            ['data-corruption-incr-backup']          Bug
# 8609     Core Server                                         []  Improvement
# 61555     C++ Driver                             ['legacy-cxx']  Improvement
#
#       collection                                           text_str  \
# 31535    MongoDB  2018-05-16 06:06:33,088 INFO c.c.dashboard.aut...
# 62050    MongoDB  First logged failure here: https://mci.10gen.c...
# 16753    MongoDB  I perform following tutorial for my knowledge\...
# 48909    MongoDB  h2. Description\r\nYes - it would be a new com...
# 57486    MongoDB  createUser docs are wrong, the name of the use...
# ...          ...                                                ...
# 88833    MongoDB  db.collection.count(\{$or: [{deleted: {$exists...
# 90893    MongoDB  We must make sure that there are no more users...
# 80099    MongoDB  {panel:title=Issue Status as of June 15, 2020|...
# 8609     MongoDB  The topology coordinator is the repository for...
# 61555    MongoDB  The legacy release of the C++ driver is being ...
#
#                                               text_clean    class  label  \
# 31535  info ccdashboardauthauthproperties no jwt secr...     rest      0
# 62050  first logged failure here note that this commi...  highest      1
# 16753  i perform following tutorial for my knowledgei...  highest      1
# 48909  description yes it would be a new component of...  highest      1
# 57486  createuser docs are wrong the name of the user...  highest      1
# ...                                                  ...      ...    ...
# 88833  dbcollectioncountor is extremmely slow i comma...     rest      0
# 90893  we must make sure that there are no more users...     rest      0
# 80099  paneltitleissue status as of june issue summar...  highest      1
# 8609   the topology coordinator is the repository for...     rest      0
# 61555  the legacy release of the c driver is being tr...     rest      0
#
#       class_original
# 31535           High
# 62050        Highest
# 16753        Highest
# 48909        Highest
# 57486        Highest
# ...              ...
# 88833         Medium
# 90893         Medium
# 80099        Highest
# 8609          Medium
# 61555         Medium
#
# [1816 rows x 11 columns]

# %%
balanced_data['class'].value_counts().to_frame()
# Out:
#          count
# class
# rest       908
# highest    908

# %%
balanced_data
# Out:
#             priority                                        description  \
# 31535  Critical - P2  2018-05-16 06:06:33,088 INFO c.c.dashboard.aut...
# 62050   Blocker - P1  First logged failure here: https://mci.10gen.c...
# 16753   Blocker - P1  I perform following tutorial for my knowledge\...
# 48909   Blocker - P1  h2. Description\r\nYes - it would be a new com...
# 57486   Blocker - P1  createUser docs are wrong, the name of the use...
# ...              ...                                                ...
# 88833     Major - P3  db.collection.count(\{$or: [{deleted: {$exists...
# 90893     Major - P3  We must make sure that there are no more users...
# 80099   Blocker - P1  {panel:title=Issue Status as of June 15, 2020|...
# 8609      Major - P3  The topology coordinator is the repository for...
# 61555     Major - P3  The legacy release of the C++ driver is being ...
#
#              project                                     labels    issuetype  \
# 31535        Mongoid             ['authentication,', 'mongodb']          Bug
# 62050     C++ Driver                             ['legacy-cxx']          Bug
# 16753    Core Server  ['replicaset', 'replication', 'sharding']          Bug
# 48909  Documentation                                         []         Task
# 57486  Documentation                     ['collector-298ba4e7']  Improvement
# ...              ...                                        ...          ...
# 88833    Core Server                                         []          Bug
# 90893    Core Server                                         []         Task
# 80099     WiredTiger            ['data-corruption-incr-backup']          Bug
# 8609     Core Server                                         []  Improvement
# 61555     C++ Driver                             ['legacy-cxx']  Improvement
#
#       collection                                           text_str  \
# 31535    MongoDB  2018-05-16 06:06:33,088 INFO c.c.dashboard.aut...
# 62050    MongoDB  First logged failure here: https://mci.10gen.c...
# 16753    MongoDB  I perform following tutorial for my knowledge\...
# 48909    MongoDB  h2. Description\r\nYes - it would be a new com...
# 57486    MongoDB  createUser docs are wrong, the name of the use...
# ...          ...                                                ...
# 88833    MongoDB  db.collection.count(\{$or: [{deleted: {$exists...
# 90893    MongoDB  We must make sure that there are no more users...
# 80099    MongoDB  {panel:title=Issue Status as of June 15, 2020|...
# 8609     MongoDB  The topology coordinator is the repository for...
# 61555    MongoDB  The legacy release of the C++ driver is being ...
#
#                                               text_clean    class  label  \
# 31535  info ccdashboardauthauthproperties no jwt secr...     rest      0
# 62050  first logged failure here note that this commi...  highest      1
# 16753  i perform following tutorial for my knowledgei...  highest      1
# 48909  description yes it would be a new component of...  highest      1
# 57486  createuser docs are wrong the name of the user...  highest      1
# ...                                                  ...      ...    ...
# 88833  dbcollectioncountor is extremmely slow i comma...     rest      0
# 90893  we must make sure that there are no more users...     rest      0
# 80099  paneltitleissue status as of june issue summar...  highest      1
# 8609   the topology coordinator is the repository for...     rest      0
# 61555  the legacy release of the c driver is being tr...     rest      0
#
#       class_original
# 31535           High
# 62050        Highest
# 16753        Highest
# 48909        Highest
# 57486        Highest
# ...              ...
# 88833         Medium
# 90893         Medium
# 80099        Highest
# 8609          Medium
# 61555         Medium
#
# [1816 rows x 11 columns]

# %%
# Count label
balanced_data['label'].value_counts().to_frame()
# Out:
#        count
# label
# 0        908
# 1        908

# %%
# Count original class
balanced_data['class_original'].value_counts().to_frame()
# Out:
#                 count
# class_original
# Highest           908
# Medium            739
# Low               119
# High               33
# Lowest             17

# %%
balanced_data = balanced_data[['text_clean', 'label']]
balanced_data
# Out:
#                                               text_clean  label
# 31535  info ccdashboardauthauthproperties no jwt secr...      0
# 62050  first logged failure here note that this commi...      1
# 16753  i perform following tutorial for my knowledgei...      1
# 48909  description yes it would be a new component of...      1
# 57486  createuser docs are wrong the name of the user...      1
# ...                                                  ...    ...
# 88833  dbcollectioncountor is extremmely slow i comma...      0
# 90893  we must make sure that there are no more users...      0
# 80099  paneltitleissue status as of june issue summar...      1
# 8609   the topology coordinator is the repository for...      0
# 61555  the legacy release of the c driver is being tr...      0
#
# [1816 rows x 2 columns]

# %%
# Save to csv
full_file_name = f'../csv/{file_name}_balanced.csv'
balanced_data.to_csv(full_file_name, index=False)

# %%
# Read csv
df = pd.read_csv(full_file_name)
df
# Out:
#                                              text_clean  label
# 0     info ccdashboardauthauthproperties no jwt secr...      0
# 1     first logged failure here note that this commi...      1
# 2     i perform following tutorial for my knowledgei...      1
# 3     description yes it would be a new component of...      1
# 4     createuser docs are wrong the name of the user...      1
# ...                                                 ...    ...
# 1811  dbcollectioncountor is extremmely slow i comma...      0
# 1812  we must make sure that there are no more users...      0
# 1813  paneltitleissue status as of june issue summar...      1
# 1814  the topology coordinator is the repository for...      0
# 1815  the legacy release of the c driver is being tr...      0
#
# [1816 rows x 2 columns]
