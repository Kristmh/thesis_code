# %%
import pandas as pd
import numpy as np
import os

# %%
def set_seed(seed=2022):
    '''Sets the seed of the entire notebook so results are the same every time we run.
    This is for REPRODUCIBILITY.'''
    np.random.seed(seed)

    os.environ['PYTHONHASHSEED'] = str(seed)


set_seed(2022)

# %%
def train_validate_test_split(df, train_percent=.85, validate_percent=.075, seed=2022):
    np.random.seed(seed)
    perm = np.random.permutation(df.index)
    m = len(df.index)
    train_end = int(train_percent * m)
    validate_end = int(validate_percent * m) + train_end
    train = df.iloc[perm[:train_end]]
    validate = df.iloc[perm[train_end:validate_end]]
    test = df.iloc[perm[validate_end:]]
    return train, validate, test

# %%
def train_test_split(df, train_percent=.8, seed=2022):
    np.random.seed(seed)
    perm = np.random.permutation(df.index)
    m = len(df.index)
    train_end = int(train_percent * m)
    train = df.iloc[perm[:train_end]]
    test = df.iloc[perm[train_end:]]
    return train, test

# %%
df_apache = pd.read_hdf('jira_all.h5', key="apache")
df_mongo = pd.read_hdf('jira_all.h5', key="mongodb")
df_sonatype = pd.read_hdf('jira_all.h5', key="sonatype")
df_jira = pd.read_hdf('jira_all.h5', key="jiraecosystem")

# %%
# List all keys in jira_all.h5
keys = pd.HDFStore('jira_all.h5').keys()
keys
# Out:
# ['/apache', '/jiraecosystem', '/mongodb', '/sonatype']

# %%
df_jiradata = pd.concat([df_apache, df_mongo , df_sonatype ,df_jira], ignore_index = True )

# %%
df_jiradata
# Out:
#               id fields.project.name                fields.created  \
# 0       12749100               HBase  2014-10-19T13:55:54.000+0000
# 1       13318144      Infrastructure  2020-07-20T00:15:10.000+0000
# 2       12679975         Apache Flex  2013-11-19T15:42:53.000+0000
# 3       13103349      Apache Gobblin  2017-09-19T20:23:44.000+0000
# 4       12816836              Groovy  2013-03-11T14:47:40.000+0000
# ...          ...                 ...                           ...
# 367985     76647   Atlassian Connect  2013-02-11T17:01:50.000-0600
# 367986     76606   Atlassian Connect  2013-02-28T10:22:22.000-0600
# 367987     76791   Atlassian Connect  2012-12-23T16:27:57.000-0600
# 367988     76832   Atlassian Connect  2012-12-04T19:44:03.000-0600
# 367989     76796   Atlassian Connect  2012-12-23T15:42:04.000-0600
#
#                              fields.labels  \
# 0                                       []
# 1                                       []
# 2                     ['easyfix', 'patch']
# 3                          ['Writer:HDFS']
# 4                                       []
# ...                                    ...
# 367985         ['p3_core', 'plugin_point']
# 367986  ['JIRA', 'Kentoo', 'defer_triage']
# 367987                        ['external']
# 367988                ['external', 'jira']
# 367989                        ['external']
#
#                                            fields.summary  \
# 0       Avoid onheap buffer copying at RPCServer#serRe...
# 1                  Create 'Heron' folder on ci-builds.a.o
# 2       SystemManager/mouseEventHandler replaces event...
# 3       Support writing Kafka messages to db/table fil...
# 4            making super-call safe causes a verify error
# ...                                                   ...
# 367985  As a Plugins 3 plugin developer, I have the ab...
# 367986      Get all users for a project or a project role
# 367987  I can use a JIRA project picker control in my ...
# 367988  I can add remote tab panels to the Project Adm...
# 367989  I can get the list of recently accessed projec...
#
#                                        fields.description fields.status.name  \
# 0       We would like to see DBB end-to-end in read pa...           Resolved
# 1       Please create a folder "Heron" and grant me ri...             Closed
# 2       When an application uses a class that extends ...               Open
# 3       - Add a new write file path type `DB_TABLE`, w...           Resolved
# 4       Summary says it all; simplest test case:\n\n73...             Closed
# ...                                                   ...                ...
# 367985  P3 plugins shall provide developers with the a...             Closed
# 367986  This is a follow up of ARA-117, expandUsers re...             Closed
# 367987                                                NaN             Closed
# 367988                Add a tab to the Project Admin page       Under Review
# 367989  REST API to retrieve the list of recently acce...             Closed
#
#                                 fields.status.description  \
# 0       A resolution has been taken, and it is awaitin...
# 1       The issue is considered finished, the resoluti...
# 2       The issue is open and ready for the assignee t...
# 3       A resolution has been taken, and it is awaitin...
# 4       The issue is considered finished, the resoluti...
# ...                                                   ...
# 367985  The issue is considered finished, the resoluti...
# 367986  The issue is considered finished, the resoluti...
# 367987  The issue is considered finished, the resoluti...
# 367988                                                NaN
# 367989  The issue is considered finished, the resoluti...
#
#        fields.issuetype.name  \
# 0                   Sub-task
# 1                       Task
# 2                        Bug
# 3                        Bug
# 4                        Bug
# ...                      ...
# 367985           New Feature
# 367986           New Feature
# 367987           New Feature
# 367988           New Feature
# 367989           New Feature
#
#                              fields.issuetype.description  \
# 0                               The sub-task of the issue
# 1                           A task that needs to be done.
# 2       A problem which impairs or prevents the functi...
# 3       A problem which impairs or prevents the functi...
# 4       A problem which impairs or prevents the functi...
# ...                                                   ...
# 367985  A new feature of the product, which has yet to...
# 367986  A new feature of the product, which has yet to...
# 367987  A new feature of the product, which has yet to...
# 367988  A new feature of the product, which has yet to...
# 367989  A new feature of the product, which has yet to...
#
#         fields.issuetype.subtask  \
# 0                           True
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 367985                     False
# 367986                     False
# 367987                     False
# 367988                     False
# 367989                     False
#
#                                           fields.comments
# 0       [{'self': 'https://issues.apache.org/jira/rest...
# 1       [{'self': 'https://issues.apache.org/jira/rest...
# 2                                                      []
# 3       [{'self': 'https://issues.apache.org/jira/rest...
# 4                                                      []
# ...                                                   ...
# 367985  [{'self': 'https://ecosystem.atlassian.net/res...
# 367986  [{'self': 'https://ecosystem.atlassian.net/res...
# 367987  [{'self': 'https://ecosystem.atlassian.net/res...
# 367988  [{'self': 'https://ecosystem.atlassian.net/res...
# 367989  [{'self': 'https://ecosystem.atlassian.net/res...
#
# [367990 rows x 12 columns]

# %%
df_jiradataset = df_jiradata[["fields.description", "fields.issuetype.name"]]

# %%
df_jiradataset
# Out:
#                                        fields.description  \
# 0       We would like to see DBB end-to-end in read pa...
# 1       Please create a folder "Heron" and grant me ri...
# 2       When an application uses a class that extends ...
# 3       - Add a new write file path type `DB_TABLE`, w...
# 4       Summary says it all; simplest test case:\n\n73...
# ...                                                   ...
# 367985  P3 plugins shall provide developers with the a...
# 367986  This is a follow up of ARA-117, expandUsers re...
# 367987                                                NaN
# 367988                Add a tab to the Project Admin page
# 367989  REST API to retrieve the list of recently acce...
#
#        fields.issuetype.name
# 0                   Sub-task
# 1                       Task
# 2                        Bug
# 3                        Bug
# 4                        Bug
# ...                      ...
# 367985           New Feature
# 367986           New Feature
# 367987           New Feature
# 367988           New Feature
# 367989           New Feature
#
# [367990 rows x 2 columns]

# %%
df_jiradataset.drop_duplicates(
    subset=["fields.description"], keep='last', inplace=True)
# Out:
# C:\Users\karth\AppData\Local\Temp\ipykernel_16632\1713541790.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jiradataset.drop_duplicates(

# %%
df_jiradataset.dropna(inplace=True)
df_jiradataset.reset_index(inplace=True)
df_jiradataset.drop(columns=["index"], inplace=True)
# Out:
# C:\Users\karth\AppData\Local\Temp\ipykernel_16632\2530609532.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jiradataset.dropna(inplace=True)
# C:\Users\karth\AppData\Local\Temp\ipykernel_16632\2530609532.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jiradataset.drop(columns=["index"], inplace=True)

# %%
df_jiradataset_TD = df_jiradataset[df_jiradataset["fields.issuetype.name"]=="Technical Debt"]

# %%
df_jiradataset_NTD = df_jiradataset[df_jiradataset["fields.issuetype.name"]
                                    != "Technical Debt"]

# %%
df_jiradataset_NTD.reset_index(inplace=True)

# %%
df_jiradataset_TD.reset_index(inplace=True)

# %%
df_jiradataset_TD
# Out:
#       index                                 fields.description  \
# 0     92612  Fixes the following issues found by spotbugs:\...
# 1     92613  These factories are part of the old type syste...
# 2     92614  The Flink codebases uses Kafka Client and Conf...
# 3     92615  We should update from Log4j 2.17.0 to 2.17.1 t...
# 4     92616  Flink uses net.sf.py4j:py4j version 0.10.8.1, ...
# ..      ...                                                ...
# 371  278331  This issue was raised following comments on th...
# 372  278378  Develop a functional test which asserts that n...
# 373  282229  Currently SourceClear scan for UPM is defined ...
# 374  282634  We are waiting for Jira to unlocked after Impo...
# 375  300189  Consider moving away from Promise and start us...
#
#     fields.issuetype.name
# 0          Technical Debt
# 1          Technical Debt
# 2          Technical Debt
# 3          Technical Debt
# 4          Technical Debt
# ..                    ...
# 371        Technical Debt
# 372        Technical Debt
# 373        Technical Debt
# 374        Technical Debt
# 375        Technical Debt
#
# [376 rows x 3 columns]

# %%
df_jiradataset_NTD
# Out:
#          index                                 fields.description  \
# 0            0  We would like to see DBB end-to-end in read pa...
# 1            1  Please create a folder "Heron" and grant me ri...
# 2            2  When an application uses a class that extends ...
# 3            3  - Add a new write file path type `DB_TABLE`, w...
# 4            4  Summary says it all; simplest test case:\n\n73...
# ...        ...                                                ...
# 304766  305142  We need a plugin point for remote apps, simila...
# 304767  305143  P3 plugins shall provide developers with the a...
# 304768  305144  This is a follow up of ARA-117, expandUsers re...
# 304769  305145                Add a tab to the Project Admin page
# 304770  305146  REST API to retrieve the list of recently acce...
#
#        fields.issuetype.name
# 0                   Sub-task
# 1                       Task
# 2                        Bug
# 3                        Bug
# 4                        Bug
# ...                      ...
# 304766           New Feature
# 304767           New Feature
# 304768           New Feature
# 304769           New Feature
# 304770           New Feature
#
# [304771 rows x 3 columns]

# %%
df_jiradataset_NTD = df_jiradataset_NTD.sample(frac=0.0015 , random_state= 2022)

# %%
df_jiradataset_NTD
# Out:
#          index                                 fields.description  \
# 16272    16272  The recent change to use the custom ObjectProp...
# 127659  127902  I'm having an issue I think is likely faced by...
# 5782      5782  When a service object cannot be created due to...
# 9277      9277  I've created a patch for jakarta-commons to ad...
# 148372  148672  The mongos forwards the {{createIndexes}} comm...
# ...        ...                                                ...
# 197741  198053  The synchro tests are failing due to internal ...
# 267882  268252  * coder-validator: help developer check Java m...
# 53452    53452  Fix the following issues spotted by OSS-Fuzz:\...
# 229082  229438  Hi,\r\n\r\nI need a group ID for my Java proje...
# 141309  141609  Specifically, {{unique: true/false}} and {{noB...
#
#        fields.issuetype.name
# 16272                    Bug
# 127659           Improvement
# 5782             Improvement
# 9277                     Bug
# 148372                   Bug
# ...                      ...
# 197741                   Bug
# 267882           New Project
# 53452                    Bug
# 229082           New Project
# 141309           Improvement
#
# [457 rows x 3 columns]

# %%
df_jiradataset_NTD.drop(columns=["index"], inplace = True)

# %%
df_jiradataset_TD.drop(columns=["index"], inplace=True)
# Out:
# C:\Users\karth\AppData\Local\Temp\ipykernel_16632\2234245929.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jiradataset_TD.drop(columns=["index"], inplace=True)

# %%
df_jiradataset_NTD["label"] = 0

# %%
df_jiradataset_TD["label"] = 1
# Out:
# C:\Users\karth\AppData\Local\Temp\ipykernel_16632\2810902983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jiradataset_TD["label"] = 1

# %%
df_jiradataset_data = pd.concat([df_jiradataset_NTD,df_jiradataset_TD],ignore_index=True )

# %%
df_jiradataset_data
# Out:
#                                     fields.description fields.issuetype.name  \
# 0    The recent change to use the custom ObjectProp...                   Bug
# 1    I'm having an issue I think is likely faced by...           Improvement
# 2    When a service object cannot be created due to...           Improvement
# 3    I've created a patch for jakarta-commons to ad...                   Bug
# 4    The mongos forwards the {{createIndexes}} comm...                   Bug
# ..                                                 ...                   ...
# 828  This issue was raised following comments on th...        Technical Debt
# 829  Develop a functional test which asserts that n...        Technical Debt
# 830  Currently SourceClear scan for UPM is defined ...        Technical Debt
# 831  We are waiting for Jira to unlocked after Impo...        Technical Debt
# 832  Consider moving away from Promise and start us...        Technical Debt
#
#      label
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 828      1
# 829      1
# 830      1
# 831      1
# 832      1
#
# [833 rows x 3 columns]

# %%
df_jiradataset_data.columns = ["text","class", "label"]

# %%
df_jira_data = df_jiradataset_data.sample(frac=1 , random_state=2022)

# %%
df_jira_data.reset_index(inplace=True)

# %%
df_jira_data.drop(columns=["index" , "class"] , inplace=True)

# %%
import re
from string import punctuation


def clean_text(text):
    '''Make text lowercase, remove text in square brackets,remove links,remove punctuation
    and remove words containing numbers.'''
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %%
df_jira_data["text"] = df_jira_data["text"].map(clean_text)

# %%
df_jira_data.to_csv("jira_TD_dataset.csv")

# %%
train , test = train_test_split(df_jira_data)

# %%
train
# Out:
#                                                   text  label
# 391   made arbiters not try to create session colle...      0
# 817  the flink codebases uses kafka client and conf...      1
# 713  i dont have a lot of information about this de...      1
# 485  we are waiting for jira to unlocked after impo...      1
# 515  theres some tech debt piling up in the request...      1
# ..                                                 ...    ...
# 5    add missing documentation commentsvxqueryvxque...      0
# 821   in btvrfydskc wtconndatacorruption is set in ...      1
# 445  we disabled the column store tests in the cove...      1
# 365  in  we added a few compiler warnings for the c...      1
# 611  when we update hadoop version from  to  use ak...      0
#
# [666 rows x 2 columns]

# %%
test
# Out:
#                                                   text  label
# 487  hi\r\rwe just brought our sqs utils project to...      0
# 756  the sinterstore command has been implemented b...      0
# 528            migration from jcenter to maven central      0
# 364  the author of  does not support his library an...      0
# 0    this is in kahaimplindexindexmanagerjavathe in...      0
# ..                                                 ...    ...
# 240  flink currently  provides support for two logg...      1
# 689  the streaming fieldaccessors keyedstreamkeyby ...      1
# 624   when page is first loaded and input is some c...      0
# 173  wtpagemodifylaststabletimestamp is no longer used      1
# 220  this package should deduplicate code from apij...      1
#
# [167 rows x 2 columns]
