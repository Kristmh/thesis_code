# %% [markdown]
# # Create dataset: Highest vs rest (high, medium, low, lowest)
# * Under sampling the majority class.
# * 50/50 balance per class.

# %%
file_path = '/fp/projects01/ec307/ec-krimhau/jira_datasets'
file_name = 'jira_clean_with_all_cols.csv'
full_path = f"{file_path}/{file_name}"

# %%
import pandas as pd
# Import csv file
df = pd.read_csv(full_path)
df
# Out:
#         priority                                        description  \
# 0        Blocker  We tried upgrading from Spring Boot 2.0.6 to S...
# 1          Major  The jobs that appear under Executions section ...
# 2        Trivial  Working with Spring-XD version 1.3.2.RELEASE\n...
# 3          Major  My project 7 node cluster and in that 2 node a...
# 4          Minor  See https://github.com/spring-projects/spring-...
# ...          ...                                                ...
# 1404240    Major                              it is very beautiful.
# 1404241    Major                                            library
# 1404242    Major  What is reactive-gremlin\r\n\r\nreactive-greml...
# 1404243    Major    Android view for a swipeable, weekly calendar.
# 1404244    Major  Beetlmvc is a web framework, which can support...
#
#                                                    project            labels  \
# 0                                                Spring XD                []
# 1                                                Spring XD                []
# 2                                                Spring XD                []
# 3                                                Spring XD  ['Spring', 'xd']
# 4                                                Spring XD                []
# ...                                                    ...               ...
# 1404240  Community Support - Open Source Project Reposi...                []
# 1404241  Community Support - Open Source Project Reposi...                []
# 1404242  Community Support - Open Source Project Reposi...                []
# 1404243  Community Support - Open Source Project Reposi...                []
# 1404244  Community Support - Open Source Project Reposi...                []
#
#            issuetype collection    class  \
# 0                Bug     Spring  Highest
# 1                Bug     Spring   Medium
# 2                Bug     Spring   Lowest
# 3                Bug     Spring   Medium
# 4              Story     Spring      Low
# ...              ...        ...      ...
# 1404240  New Project   Sonatype   Medium
# 1404241  New Project   Sonatype   Medium
# 1404242  New Project   Sonatype   Medium
# 1404243  New Project   Sonatype   Medium
# 1404244  New Project   Sonatype   Medium
#
#                                                   text_str  \
# 0        We tried upgrading from Spring Boot 2.0.6 to S...
# 1        The jobs that appear under Executions section ...
# 2        Working with Spring-XD version 1.3.2.RELEASE\n...
# 3        My project 7 node cluster and in that 2 node a...
# 4        See https://github.com/spring-projects/spring-...
# ...                                                    ...
# 1404240                              it is very beautiful.
# 1404241                                            library
# 1404242  What is reactive-gremlin\r\n\r\nreactive-greml...
# 1404243    Android view for a swipeable, weekly calendar.
# 1404244  Beetlmvc is a web framework, which can support...
#
#                                                 text_clean
# 0        we tried upgrading from spring boot to spring ...
# 1        the jobs that appear under executions section ...
# 2        working with springxd version the server with ...
# 3        my project node cluster and in that node are a...
# 4                                                      NaN
# ...                                                    ...
# 1404240                               it is very beautiful
# 1404241                                                NaN
# 1404242  what is reactivegremlin reactivegremlin is a s...
# 1404243       android view for a swipeable weekly calendar
# 1404244  beetlmvc is a web framework which can support ...
#
# [1404245 rows x 9 columns]

# %%
# Count class
df['class'].value_counts().to_frame()
# Out:
#           count
# class
# Medium   960459
# Low      271629
# High      82646
# Highest   56220
# Lowest    33291

# %%
# NaN values
df.isnull().sum()
# Out:
# priority           0
# description        0
# project            0
# labels             0
# issuetype          0
# collection         0
# class              0
# text_str           0
# text_clean     34264
# dtype: int64

# %%
# Drop NaN values
df = df.dropna()
df.isnull().sum()
# Out:
# priority       0
# description    0
# project        0
# labels         0
# issuetype      0
# collection     0
# class          0
# text_str       0
# text_clean     0
# dtype: int64

# %%
# Count class
df['class'].value_counts().to_frame()
# Out:
#           count
# class
# Medium   933029
# Low      267697
# High      81404
# Highest   55358
# Lowest    32493

# %%
# Unique collections
df['collection'].unique()
# Out:
# array(['Spring', 'RedHat', 'Sakai', 'JiraEcosystem', 'Hyperledger',
#        'Apache', 'SecondLife', 'IntelDAOS', 'Mindville', 'Sonatype'],
#       dtype=object)

# %%
# make df with class and text_clean
df = df[['class', 'text_clean']]

# %%
highest = df[df['class'] == 'Highest']
highest["label"] = 1
highest["class_original"] = "Highest"
highest["class"] = "highest"
high = df[df['class'] == 'High']
medium = df[df['class'] == 'Medium']
low = df[df['class'] == 'Low']
lowest = df[df['class'] == 'Lowest']
# Out:
# /localscratch/492580/ipykernel_2269417/3737047461.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["label"] = 1
# /localscratch/492580/ipykernel_2269417/3737047461.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["class_original"] = "Highest"
# /localscratch/492580/ipykernel_2269417/3737047461.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["class"] = "highest"

# %%
# Concat all class except highest and high
rest = lowest
# Rename class to class_1
rest = rest.rename(columns={'class': 'class_original'})
rest["class"] = "rest" 
rest["label"] = 0
rest
# Out:
#         class_original                                         text_clean  \
# 2               Lowest  working with springxd version the server with ...
# 17              Lowest  when i use the adminui web portal which runs o...
# 134             Lowest  copied from while testing a reactive processor...
# 289             Lowest  what is the functional justification for enfor...
# 444             Lowest  hdfsoutboundchanneladapterparser supports havi...
# ...                ...                                                ...
# 1398225         Lowest  please close this issue i apologize everything...
# 1401002         Lowest  following dependencies are not yet ready i alr...
# 1402620         Lowest  requesting access to orggrails to be able to s...
# 1403176         Lowest  im releasing my artifacts for the first time i...
# 1403679         Lowest  hi i currently face an unauthorized exception ...
#
#         class  label
# 2        rest      0
# 17       rest      0
# 134      rest      0
# 289      rest      0
# 444      rest      0
# ...       ...    ...
# 1398225  rest      0
# 1401002  rest      0
# 1402620  rest      0
# 1403176  rest      0
# 1403679  rest      0
#
# [32493 rows x 4 columns]

# %%
# Value count rest class
rest['class_original'].value_counts().to_frame()
# Out:
#                 count
# class_original
# Lowest          32493

# %%
from sklearn.utils import shuffle
# Number of rows in the highest class
n_highest = rest.shape[0]

rest_sampled = highest.sample(n=n_highest, random_state=42)  


balanced_data = pd.concat([rest, rest_sampled])

# Shuffle the combined dataset
balanced_data = shuffle(balanced_data, random_state=42)
balanced_data
# Out:
#         class_original                                         text_clean  \
# 1116117         Lowest  testing on version discovered test case does a...
# 84815          Highest  description this is an issue found when use co...
# 481244          Lowest  description since unixtimestamp udf was deprec...
# 995236          Lowest  in programmming guides most algos in ml have l...
# 564519         Highest  creation of system eventqueue was commented ou...
# ...                ...                                                ...
# 692093         Highest  seems to have introduced a bug because of whic...
# 1188023        Highest  copying s comment from mailing list on head wi...
# 33594           Lowest  add ability to merge multiple listsmapssets th...
# 851946          Lowest      rename asterixjavaclient to asterixtestclient
# 579590         Highest  if a running attempt is lost on a tracker a at...
#
#            class  label
# 1116117     rest      0
# 84815    highest      1
# 481244      rest      0
# 995236      rest      0
# 564519   highest      1
# ...          ...    ...
# 692093   highest      1
# 1188023  highest      1
# 33594       rest      0
# 851946      rest      0
# 579590   highest      1
#
# [64986 rows x 4 columns]

# %%
balanced_data['class'].value_counts().to_frame()
# Out:
#          count
# class
# rest     32493
# highest  32493

# %%
balanced_data
# Out:
#         class_original                                         text_clean  \
# 1116117         Lowest  testing on version discovered test case does a...
# 84815          Highest  description this is an issue found when use co...
# 481244          Lowest  description since unixtimestamp udf was deprec...
# 995236          Lowest  in programmming guides most algos in ml have l...
# 564519         Highest  creation of system eventqueue was commented ou...
# ...                ...                                                ...
# 692093         Highest  seems to have introduced a bug because of whic...
# 1188023        Highest  copying s comment from mailing list on head wi...
# 33594           Lowest  add ability to merge multiple listsmapssets th...
# 851946          Lowest      rename asterixjavaclient to asterixtestclient
# 579590         Highest  if a running attempt is lost on a tracker a at...
#
#            class  label
# 1116117     rest      0
# 84815    highest      1
# 481244      rest      0
# 995236      rest      0
# 564519   highest      1
# ...          ...    ...
# 692093   highest      1
# 1188023  highest      1
# 33594       rest      0
# 851946      rest      0
# 579590   highest      1
#
# [64986 rows x 4 columns]

# %%
# Count label
balanced_data['label'].value_counts().to_frame()
# Out:
#        count
# label
# 0      32493
# 1      32493

# %%
# Count original class
balanced_data['class_original'].value_counts().to_frame()
# Out:
#                 count
# class_original
# Lowest          32493
# Highest         32493

# %%
balanced_data = balanced_data[['label', 'text_clean']]
balanced_data = balanced_data.rename(columns={'text_clean': 'text'})
balanced_data
# Out:
#          label                                               text
# 1116117      0  testing on version discovered test case does a...
# 84815        1  description this is an issue found when use co...
# 481244       0  description since unixtimestamp udf was deprec...
# 995236       0  in programmming guides most algos in ml have l...
# 564519       1  creation of system eventqueue was commented ou...
# ...        ...                                                ...
# 692093       1  seems to have introduced a bug because of whic...
# 1188023      1  copying s comment from mailing list on head wi...
# 33594        0  add ability to merge multiple listsmapssets th...
# 851946       0      rename asterixjavaclient to asterixtestclient
# 579590       1  if a running attempt is lost on a tracker a at...
#
# [64986 rows x 2 columns]

# %%
out_path = '/fp/projects01/ec307/ec-krimhau/jira_datasets/high_highest_vs_rest/highest_vs_lowest_balanced_jira.csv'

# %%
# Save to csv
balanced_data.to_csv(out_path, index=False)

# %%
# Read csv
df = pd.read_csv(out_path)

# %%
df
# Out:
#        label                                               text
# 0          0  testing on version discovered test case does a...
# 1          1  description this is an issue found when use co...
# 2          0  description since unixtimestamp udf was deprec...
# 3          0  in programmming guides most algos in ml have l...
# 4          1  creation of system eventqueue was commented ou...
# ...      ...                                                ...
# 64981      1  seems to have introduced a bug because of whic...
# 64982      1  copying s comment from mailing list on head wi...
# 64983      0  add ability to merge multiple listsmapssets th...
# 64984      0      rename asterixjavaclient to asterixtestclient
# 64985      1  if a running attempt is lost on a tracker a at...
#
# [64986 rows x 2 columns]
