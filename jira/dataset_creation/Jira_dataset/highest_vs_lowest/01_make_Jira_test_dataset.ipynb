# %% [markdown]
# # Create dataset: Highest vs rest (high, medium, low, lowest)
# * Under sampling the majority class.
# * 50/50 balance per class.

# %%
file_name = "clean_Jira"


file_path = "/fp/projects01/ec307/ec-krimhau/jira_datasets/testsets_clean"


import pandas as pd
# Import csv file

df = pd.read_csv(f'{file_path}/{file_name}.csv')
df
# Out:
#        priority                                        description  \
# 0           Low  some errors show up as shown in the screenshot...
# 1           Low  I have been using Sourcetree 3.4.4.  We use cu...
# 2           Low  After installing SourceTree for Windows 10 64b...
# 3           Low  On windows, Sourcetree.exe will start "git.exe...
# 4           Low  Hello,\r\n\r\nSourceTree 3.4.7.\r\n\r\nOS: Win...
# ...         ...                                                ...
# 127602      Low  h3. Issue Summary\r\n\r\nIf a service desk pro...
# 127603      Low  h3. Issue Summary\r\n\r\nWe have '*Link Issue*...
# 127604      Low  h3. Issue Summary\r\n\r\nCreating child object...
# 127605      Low  h3. Issue Summary\r\nInsight IQL uses timezone...
# 127606   Medium  h3. Issue Summary\r\n\r\nThe intermittent issu...
#
#                               project labels issuetype collection  \
# 0              Sourcetree for Windows     []       Bug       Jira
# 1              Sourcetree for Windows     []       Bug       Jira
# 2              Sourcetree for Windows     []       Bug       Jira
# 3              Sourcetree for Windows     []       Bug       Jira
# 4              Sourcetree for Windows     []       Bug       Jira
# ...                               ...    ...       ...        ...
# 127602  Jira Service Management Cloud     []       Bug       Jira
# 127603  Jira Service Management Cloud     []       Bug       Jira
# 127604  Jira Service Management Cloud     []       Bug       Jira
# 127605  Jira Service Management Cloud     []       Bug       Jira
# 127606  Jira Service Management Cloud     []       Bug       Jira
#
#                                                  text_str  \
# 0       some errors show up as shown in the screenshot...
# 1       I have been using Sourcetree 3.4.4.  We use cu...
# 2       After installing SourceTree for Windows 10 64b...
# 3       On windows, Sourcetree.exe will start "git.exe...
# 4       Hello,\r\n\r\nSourceTree 3.4.7.\r\n\r\nOS: Win...
# ...                                                   ...
# 127602  h3. Issue Summary\r\n\r\nIf a service desk pro...
# 127603  h3. Issue Summary\r\n\r\nWe have '*Link Issue*...
# 127604  h3. Issue Summary\r\n\r\nCreating child object...
# 127605  h3. Issue Summary\r\nInsight IQL uses timezone...
# 127606  h3. Issue Summary\r\n\r\nThe intermittent issu...
#
#                                                text_clean
# 0       some errors show up as shown in the screenshot...
# 1       i have been using sourcetree we use custom act...
# 2       after installing sourcetree for windows machin...
# 3       on windows sourcetreeexe will start gitexe fsm...
# 4       hello sourcetree os windows pro problem create...
# ...                                                   ...
# 127602  issue summary if a service desk project has a ...
# 127603  issue summary we have link issue button in the...
# 127604  issue summary creating child objects with no s...
# 127605  issue summary insight iql uses timezones in a ...
# 127606  issue summary the intermittent issue portalonl...
#
# [127607 rows x 8 columns]

# %%
# Count class
df['priority'].value_counts().to_frame()
# Out:
#           count
# priority
# Low       72641
# Medium    40559
# High       9739
# Highest    4668

# %%
# NaN values
df.isnull().sum()
# Out:
# priority        0
# description     0
# project         0
# labels          0
# issuetype       0
# collection      0
# text_str        0
# text_clean     69
# dtype: int64

# %%
# Drop NaN values
df = df.dropna()
df.isnull().sum()
# Out:
# priority       0
# description    0
# project        0
# labels         0
# issuetype      0
# collection     0
# text_str       0
# text_clean     0
# dtype: int64

# %%
# Count class
df['priority'].value_counts().to_frame()
# Out:
#           count
# priority
# Low       72610
# Medium    40526
# High       9736
# Highest    4666

# %%
# Unique collections
df['collection'].unique()
# Out:
# array(['Jira'], dtype=object)

# %%
# Unique projects
df['project'].unique().tolist()
# Out:
# ['Sourcetree for Windows',
#  'Jira Service Management Cloud',
#  'Jira Server and Data Center',
#  'Sourcetree For Mac',
#  'Jira Cloud',
#  'Advanced Roadmaps',
#  'Automation for Jira',
#  'Identity',
#  'Atlassian Internationalization',
#  'atlassian-http',
#  'FishEye',
#  'Crowd',
#  'Crucible',
#  'atlassian-seraph',
#  'Confluence Server and Data Center',
#  'Server Deployments and Scale',
#  'Atlassian OAuth 2.0',
#  'Migration Platform',
#  'Jira Work Management Cloud',
#  'Jira Software Server and Data Center',
#  'Confluence Cloud',
#  'Clover',
#  'Atlassian Cloud',
#  'Bitbucket Server',
#  'Bitbucket Cloud',
#  'Bamboo',
#  'Atlassian Product Integrations',
#  'Atlassian Access',
#  'Jira Software Cloud',
#  'Jira Service Management Server and Data Center']

# %%
# Number of unique projects 
len(df['project'].unique())
# Out:
# 30

# %%
priority_mapping = {
    # Highest priority
    'Highest': 'Highest',
    'High': 'High',
    'Medium': 'Medium',
    'Low': 'Low',

}
# Apply mapping
df['class'] = df['priority'].map(priority_mapping)
# Out:
# /localscratch/585336/ipykernel_1299383/3135084215.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['class'] = df['priority'].map(priority_mapping)

# %%
# Find the priorities that are not mapped to 'Highest' by checking for nulls in 'class'
unmapped_priorities = df[df['class'].isnull()]['priority'].unique()

if len(unmapped_priorities)  == 0:
    print("All priorities are mapped to a new class")
else:
    print("Priorities not mapped to a new class:")
    for priority in unmapped_priorities:
        print(f"- {priority}")
# Out:
# All priorities are mapped to a new class

# %%
# Count class
df['class'].value_counts().to_frame()
# Out:
#          count
# class
# Low      72610
# Medium   40526
# High      9736
# Highest   4666

# %%
highest = df[df['class'] == 'Highest']
highest["label"] = 1
highest["class_original"] = "Highest"
highest["class"] = "highest"
high = df[df['class'] == 'High']
medium = df[df['class'] == 'Medium']
low = df[df['class'] == 'Low']
low["label"] = 0
# Out:
# /localscratch/585336/ipykernel_1299383/2928862923.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["label"] = 1
# /localscratch/585336/ipykernel_1299383/2928862923.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["class_original"] = "Highest"
# /localscratch/585336/ipykernel_1299383/2928862923.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["class"] = "highest"
# /localscratch/585336/ipykernel_1299383/2928862923.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low["label"] = 0

# %%
# Concat all class except highest
rest = pd.concat([high, medium, low])
# Rename class to class_1
rest = rest.rename(columns={'class': 'class_original'})
rest["class"] = "rest" 
rest["label"] = 0
rest

# %%
# Value count rest class
rest['class'].value_counts().to_frame()

# %%
from sklearn.utils import shuffle
# Number of rows in the highest class
n_highest = highest.shape[0]

sampled = low.sample(n=n_highest, random_state=42)  


balanced_data = pd.concat([highest, sampled])

# Shuffle the combined dataset
balanced_data = shuffle(balanced_data, random_state=42)
balanced_data
# Out:
#        priority                                        description  \
# 68107       Low  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
# 120831      Low  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
# 70033   Highest  We have identified and fixed a cross-site scri...
# 88016       Low  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
# 83546       Low  h3. Issue Summary\r\nWhen editing Meeting Note...
# ...         ...                                                ...
# 36595       Low  {panel:bgColor=#e7f4fa}\r\n  *NOTE:* This bug ...
# 90828       Low  When a JIRA Agile board is deleted, all sprint...
# 41381       Low  When attempting to create a pull request for a...
# 32170   Highest  h3.*Problem Definition*\r\n* All of a sudden, ...
# 91919       Low  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
#
#                                      project  \
# 68107      Confluence Server and Data Center
# 120831                   Jira Software Cloud
# 70033      Confluence Server and Data Center
# 88016                       Confluence Cloud
# 83546                       Confluence Cloud
# ...                                      ...
# 36595                             Jira Cloud
# 90828   Jira Software Server and Data Center
# 41381                     Sourcetree For Mac
# 32170                             Jira Cloud
# 91919                       Confluence Cloud
#
#                                                    labels issuetype  \
# 68107                                                  []       Bug
# 120831                                                 []       Bug
# 70033            ['affects-server', 'editor', 'security']       Bug
# 88016                 ['affects-cloud', 'affects-server']       Bug
# 83546                                                  []       Bug
# ...                                                   ...       ...
# 36595   ['affects-cloud', 'affects-server', 'timeout-b...       Bug
# 90828                                  ['affects-server']       Bug
# 41381                                                  []       Bug
# 32170                                 ['bento', 'new-ui']       Bug
# 91919   ['Macros-Popular-Labels', 'editor', 'editor-ma...       Bug
#
#        collection                                           text_str  \
# 68107        Jira  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
# 120831       Jira  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
# 70033        Jira  We have identified and fixed a cross-site scri...
# 88016        Jira  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
# 83546        Jira  h3. Issue Summary\r\nWhen editing Meeting Note...
# ...           ...                                                ...
# 36595        Jira  {panel:bgColor=#e7f4fa}\r\n  *NOTE:* This bug ...
# 90828        Jira  When a JIRA Agile board is deleted, all sprint...
# 41381        Jira  When attempting to create a pull request for a...
# 32170        Jira  h3.*Problem Definition*\r\n* All of a sudden, ...
# 91919        Jira  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
#
#                                                text_clean    class  label  \
# 68107   note this bug report is for confluence server ...      Low      0
# 120831  note this bug report is for jira portfolio clo...      Low      0
# 70033   we have identified and fixed a crosssite scrip...  highest      1
# 88016   note this bug report is for confluence cloud u...      Low      0
# 83546   issue summary when editing meeting notes in sp...      Low      0
# ...                                                   ...      ...    ...
# 36595   note this bug report is for jira cloud using j...      Low      0
# 90828   when a jira agile board is deleted all sprints...      Low      0
# 41381   when attempting to create a pull request for a...      Low      0
# 32170   definition all of a sudden some users are unab...  highest      1
# 91919   note this bug report is for confluence cloud u...      Low      0
#
#        class_original
# 68107             NaN
# 120831            NaN
# 70033         Highest
# 88016             NaN
# 83546             NaN
# ...               ...
# 36595             NaN
# 90828             NaN
# 41381             NaN
# 32170         Highest
# 91919             NaN
#
# [9332 rows x 11 columns]

# %%
balanced_data['class'].value_counts().to_frame()
# Out:
#          count
# class
# Low       4666
# highest   4666

# %%
balanced_data
# Out:
#        priority                                        description  \
# 68107       Low  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
# 120831      Low  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
# 70033   Highest  We have identified and fixed a cross-site scri...
# 88016       Low  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
# 83546       Low  h3. Issue Summary\r\nWhen editing Meeting Note...
# ...         ...                                                ...
# 36595       Low  {panel:bgColor=#e7f4fa}\r\n  *NOTE:* This bug ...
# 90828       Low  When a JIRA Agile board is deleted, all sprint...
# 41381       Low  When attempting to create a pull request for a...
# 32170   Highest  h3.*Problem Definition*\r\n* All of a sudden, ...
# 91919       Low  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
#
#                                      project  \
# 68107      Confluence Server and Data Center
# 120831                   Jira Software Cloud
# 70033      Confluence Server and Data Center
# 88016                       Confluence Cloud
# 83546                       Confluence Cloud
# ...                                      ...
# 36595                             Jira Cloud
# 90828   Jira Software Server and Data Center
# 41381                     Sourcetree For Mac
# 32170                             Jira Cloud
# 91919                       Confluence Cloud
#
#                                                    labels issuetype  \
# 68107                                                  []       Bug
# 120831                                                 []       Bug
# 70033            ['affects-server', 'editor', 'security']       Bug
# 88016                 ['affects-cloud', 'affects-server']       Bug
# 83546                                                  []       Bug
# ...                                                   ...       ...
# 36595   ['affects-cloud', 'affects-server', 'timeout-b...       Bug
# 90828                                  ['affects-server']       Bug
# 41381                                                  []       Bug
# 32170                                 ['bento', 'new-ui']       Bug
# 91919   ['Macros-Popular-Labels', 'editor', 'editor-ma...       Bug
#
#        collection                                           text_str  \
# 68107        Jira  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
# 120831       Jira  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
# 70033        Jira  We have identified and fixed a cross-site scri...
# 88016        Jira  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
# 83546        Jira  h3. Issue Summary\r\nWhen editing Meeting Note...
# ...           ...                                                ...
# 36595        Jira  {panel:bgColor=#e7f4fa}\r\n  *NOTE:* This bug ...
# 90828        Jira  When a JIRA Agile board is deleted, all sprint...
# 41381        Jira  When attempting to create a pull request for a...
# 32170        Jira  h3.*Problem Definition*\r\n* All of a sudden, ...
# 91919        Jira  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
#
#                                                text_clean    class  label  \
# 68107   note this bug report is for confluence server ...      Low      0
# 120831  note this bug report is for jira portfolio clo...      Low      0
# 70033   we have identified and fixed a crosssite scrip...  highest      1
# 88016   note this bug report is for confluence cloud u...      Low      0
# 83546   issue summary when editing meeting notes in sp...      Low      0
# ...                                                   ...      ...    ...
# 36595   note this bug report is for jira cloud using j...      Low      0
# 90828   when a jira agile board is deleted all sprints...      Low      0
# 41381   when attempting to create a pull request for a...      Low      0
# 32170   definition all of a sudden some users are unab...  highest      1
# 91919   note this bug report is for confluence cloud u...      Low      0
#
#        class_original
# 68107             NaN
# 120831            NaN
# 70033         Highest
# 88016             NaN
# 83546             NaN
# ...               ...
# 36595             NaN
# 90828             NaN
# 41381             NaN
# 32170         Highest
# 91919             NaN
#
# [9332 rows x 11 columns]

# %%
# Count label
balanced_data['label'].value_counts().to_frame()
# Out:
#        count
# label
# 0       4666
# 1       4666

# %%
# Count original class
balanced_data['class_original'].value_counts().to_frame()
# Out:
#                 count
# class_original
# Highest          4666

# %%
# New df with only text clean and label
balanced_data = balanced_data[['text_clean', 'label']]
balanced_data
# Out:
#                                                text_clean  label
# 68107   note this bug report is for confluence server ...      0
# 120831  note this bug report is for jira portfolio clo...      0
# 70033   we have identified and fixed a crosssite scrip...      1
# 88016   note this bug report is for confluence cloud u...      0
# 83546   issue summary when editing meeting notes in sp...      0
# ...                                                   ...    ...
# 36595   note this bug report is for jira cloud using j...      0
# 90828   when a jira agile board is deleted all sprints...      0
# 41381   when attempting to create a pull request for a...      0
# 32170   definition all of a sudden some users are unab...      1
# 91919   note this bug report is for confluence cloud u...      0
#
# [9332 rows x 2 columns]

# %%
balanced_data.rename(columns={'text_clean': 'text'}, inplace=True)
balanced_data
# Out:
# /localscratch/585336/ipykernel_1299383/984652038.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   balanced_data.rename(columns={'text_clean': 'text'}, inplace=True)
#                                                      text  label
# 68107   note this bug report is for confluence server ...      0
# 120831  note this bug report is for jira portfolio clo...      0
# 70033   we have identified and fixed a crosssite scrip...      1
# 88016   note this bug report is for confluence cloud u...      0
# 83546   issue summary when editing meeting notes in sp...      0
# ...                                                   ...    ...
# 36595   note this bug report is for jira cloud using j...      0
# 90828   when a jira agile board is deleted all sprints...      0
# 41381   when attempting to create a pull request for a...      0
# 32170   definition all of a sudden some users are unab...      1
# 91919   note this bug report is for confluence cloud u...      0
#
# [9332 rows x 2 columns]

# %%
# Save to csv
out_path = "/fp/projects01/ec307/ec-krimhau/jira_datasets/jira_highest_vs_lowest"
full_file_name = f'{out_path}/jira_{file_name}_highest_lowest_balanced.csv'
balanced_data.to_csv(full_file_name, index=False)

# %%
# Read csv
df = pd.read_csv(full_file_name)
df
# Out:
#                                                    text  label
# 0     note this bug report is for confluence server ...      0
# 1     note this bug report is for jira portfolio clo...      0
# 2     we have identified and fixed a crosssite scrip...      1
# 3     note this bug report is for confluence cloud u...      0
# 4     issue summary when editing meeting notes in sp...      0
# ...                                                 ...    ...
# 9327  note this bug report is for jira cloud using j...      0
# 9328  when a jira agile board is deleted all sprints...      0
# 9329  when attempting to create a pull request for a...      0
# 9330  definition all of a sudden some users are unab...      1
# 9331  note this bug report is for confluence cloud u...      0
#
# [9332 rows x 2 columns]
