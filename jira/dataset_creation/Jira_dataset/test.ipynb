# %%
import pandas as pd
# read redhat csv
df = pd.read_csv('jira_issues.csv')
df
# Out:
#               id            fields.project.name fields.priority.name  \
# 0       12776962  Red Hat 3scale API Management                Major
# 1       12776960  Red Hat 3scale API Management                Major
# 2       12776959  Red Hat 3scale API Management                Minor
# 3       12776957  Red Hat 3scale API Management                Major
# 4       12776947  Red Hat 3scale API Management                Minor
# ...          ...                            ...                  ...
# 265495  12817244      Red Hat Developer Website                  NaN
# 265496  12817243      Red Hat Developer Website                  NaN
# 265497  12817233      Red Hat Developer Website                  NaN
# 265498  12817029      Red Hat Developer Website                  NaN
# 265499  12817028      Red Hat Developer Website                  NaN
#
#                       fields.created   fields.labels  \
# 0       2018-10-30T10:35:11.000+0000              []
# ...

# %%
# Value counts fields.priority.name
df['fields.priority.name'].value_counts()
# Out:
# fields.priority.name
# Major            182968
# Minor             26163
# Critical          19475
# Blocker           15502
# Unprioritized      5697
# High               4581
# Optional           2664
# Medium             2582
# Trivial            1602
# Undefined          1302
# Urgent             1201
# Low                 840
# Normal              188
# Should Have           1
# Must Have             1
# Name: count, dtype: int64

# %%
df['fields.issuetype.name'].value_counts()
# Out:
# fields.issuetype.name
# Bug                          128778
# Task                          46013
# Feature Request               27884
# Enhancement                   21679
# Sub-task                      17924
# Story                         10335
# Epic                           3664
# Component Upgrade              3477
# Release                         796
# Quality Risk                    770
# QE Task                         765
# Feature                         721
# Documentation                   643
# Component Upgrade Subtask       559
# Patch                           490
# Requirement                     349
# Support Patch                   168
# Clarification                    83
# Tracker                          78
# Dev Sub-task                     65
# Improvement                      38
# Simple Task                      38
# Initiative                       24
# QE Sub-task                      23
# Support Request                  22
# ...
