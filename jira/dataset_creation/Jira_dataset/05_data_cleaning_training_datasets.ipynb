# %% [markdown]
# # Data cleaning
# We want the class with labels as numerical value and the body with clean text.
#
# This will remove:
# * duplicates
# * NaN entires
# * non english
# * url, html
#
# * make it lowercase
# * combine title and body

# %%
import pandas as pd
import sys
sys.path.append("../../../scripts_shared/")
from preprocess_text import preprocess_text

# %%
file_name = "all_priority_group_in_classes.csv"
df = pd.read_csv(file_name)
df
# Out:
#         priority                                        description  \
# 0        Blocker  We tried upgrading from Spring Boot 2.0.6 to S...
# 1          Major  The jobs that appear under Executions section ...
# 2        Trivial  Working with Spring-XD version 1.3.2.RELEASE\n...
# 3          Major  My project 7 node cluster and in that 2 node a...
# 4          Minor  See https://github.com/spring-projects/spring-...
# ...          ...                                                ...
# 1611180    Major                              it is very beautiful.
# 1611181    Major                                            library
# 1611182    Major  What is reactive-gremlin\r\n\r\nreactive-greml...
# 1611183    Major    Android view for a swipeable, weekly calendar.
# 1611184    Major  Beetlmvc is a web framework, which can support...
#
#                                                    project            labels  \
# 0                                                Spring XD                []
# 1                                                Spring XD                []
# 2                                                Spring XD                []
# 3                                                Spring XD  ['Spring', 'xd']
# 4                                                Spring XD                []
# ...                                                    ...               ...
# 1611180  Community Support - Open Source Project Reposi...                []
# 1611181  Community Support - Open Source Project Reposi...                []
# 1611182  Community Support - Open Source Project Reposi...                []
# 1611183  Community Support - Open Source Project Reposi...                []
# 1611184  Community Support - Open Source Project Reposi...                []
#
#            issuetype collection    class
# 0                Bug     Spring  Highest
# 1                Bug     Spring   Medium
# 2                Bug     Spring   Lowest
# 3                Bug     Spring   Medium
# 4              Story     Spring      Low
# ...              ...        ...      ...
# 1611180  New Project   Sonatype   Medium
# 1611181  New Project   Sonatype   Medium
# 1611182  New Project   Sonatype   Medium
# 1611183  New Project   Sonatype   Medium
# 1611184  New Project   Sonatype   Medium
#
# [1611185 rows x 7 columns]

# %%
# Count per priority
df['class'].value_counts()
# Out:
# class
# Medium     1118034
# Low         299697
# High         89619
# Highest      61754
# Lowest       36703
# Name: count, dtype: int64

# %%
df['issuetype'].value_counts().to_frame()[:50]
# Out:
#                                  count
# issuetype
# Bug                             759733
# Improvement                     268685
# Task                            157186
# Sub-task                        118987
# New Feature                      71440
# New Project                      65487
# Feature Request                  42457
# Story                            28386
# Enhancement                      28333
# Test                             10147
# Publishing Support                9413
# Epic                              8464
# Wish                              8131
# Component Upgrade                 6376
# Documentation                     3999
# Dependency upgrade                3647
# Question                          2202
# Problem                           1598
# QE Task                           1471
# Technical task                    1272
# Defect                            1198
# (Deprecated) Contributed Patch    1050
# Release                            902
# Quality Risk                       779
# Feature                            773
# Project                            692
# Refactoring                        670
# Dev Task                           652
# Umbrella                           614
# Component Upgrade Subtask          564
# Suggestion                         542
# Patch                              503
# Planned Work                       409
# Requirement                        400
# Test Task                          373
# Clarification                      361
# Github Integration                 328
# Sub-Task                           239
# Brainstorming                      239
# New Git Repo                       193
# Support Request                    177
# Support Patch                      170
# GitBox Request                     169
# New JIRA Project                   142
# Support                            119
# Request                            111
# Tracker                            102
# Roadmap item                        85
# Dependency                          82
# SVN->GIT Migration                  77

# %%
# Unique projects
df['project'].nunique()
# Out:
# 1157

# %%
# Unique collections
df['collection'].nunique()
# Out:
# 10

# %%
# Count per collection
df['collection'].value_counts().to_frame()
# Out:
#                 count
# collection
# Apache         984269
# RedHat         338623
# Sonatype        87255
# Spring          68556
# Sakai           49820
# JiraEcosystem   41484
# Hyperledger     28144
# IntelDAOS        9306
# Mindville        2115
# SecondLife       1613

# %%
# Drop duplicates by the content of the description
df = df.drop_duplicates(subset=['description'], keep='last')
df.dropna(inplace=True)
df.reset_index(inplace=True)
df.drop(columns=["index"] , inplace= True)
df["class"].value_counts()
# Out:
# /tmp/ipykernel_131328/3029890719.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
# /tmp/ipykernel_131328/3029890719.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["index"] , inplace= True)
# class
# Medium     960459
# Low        271629
# High        82646
# Highest     56220
# Lowest      33291
# Name: count, dtype: int64

# %%
print(df["description"][0])
# Out:
# We tried upgrading from Spring Boot 2.0.6 to Spring 2.1.0 and noticing a critical multi-threading bug in the WebClient.  We are using Spring WebFlux with Netty Embedded Server
#
# In SpringBoot 2.0.6 you can see data received and published on happens on two different threads but in SpringBoot 2.1.0 all execution is happening on the same thread even data is published to same thread.  Any reason why the multi-threading behavior has changed in SpringBoot 2.1.0?  Seems like a major defect.  This flaw is preventing us from upgrading to Spring Boot 2.1.0.
#
# It appears with Spring Boot 2.1.0 the default threading behavior of the WebClient has changed to where emissions on published on main thread as opposed to a different thread
#
# See results below
#
# I print the thread on the doOnRequest method of the WebClient
#
# I also print the thread on the doOnNext of the Mono
#
# For version 2.10 you can see emissions are published on the main thread but in earlier version
#
# 2.0.6 emissions published on a different thread.
#
# You can see even response time increased for 2.10 because emissions are published on main thread as opposed to different thread
#
# 2.0.6.RELEASE
#
# 2018-11-15 08:49:45.626 INFO 15228 — [ctor-http-nio-5] c.c.x.n.s.handler.rest.SearchHandler : Search request received for query :
#  2018-11-15 08:49:45.630 INFO 15228 — [ctor-http-nio-5] c.c.x.n.c.s.x.impl.HttpSearchService : Request for search using query param :
#  2018-11-15 08:49:45.633 INFO 15228 — [ctor-http-nio-5] c.c.x.n.m.h.filter.RequestLoggingFilter : Executing request: GET [https://www|https://www/]
#  2018-11-15 08:49:45.635 INFO 15228 — [ctor-http-nio-5] c.c.x.n.m.util.AbstractLookupService : Subscribed to request with uri [https://www|https://www/]
#  2018-11-15 08:49:45.635 INFO 15228 — [ctor-http-nio-5] c.c.x.n.m.util.AbstractLookupService : Request received for uri [https://www|https://www/] [Thread[reactor-http-nio-5,5,main]]
#  2018-11-15 08:49:47.069 INFO 15228 — [ctor-http-nio-4] c.c.x.n.s.f.RequestProcessingTimeFilter : Request processing time for GET 34291c26-8419-4cf9-8c50-eea84bf59d48 is 17 ms with http status null
#  2018-11-15 08:49:47.253 INFO 15228 — [ctor-http-nio-8] c.c.x.n.m.util.AbstractLookupService : Time taken for request [http://www|http://www/] is : [1624] ms Thread[reactor-http-nio-8,5,main]]
#
# 2.1.0.RELEASE
#
# 2018-11-15 09:07:15.886 INFO 5932 — [ctor-http-nio-6] c.c.x.n.s.handler.rest.SearchHandler : Search request received for query :
#  2018-11-15 09:07:15.906 INFO 5932 — [ctor-http-nio-6] c.c.x.n.c.s.x.impl.HttpSearchService : Request for search using query param :
#  2018-11-15 09:07:15.912 INFO 5932 — [ctor-http-nio-6] c.c.x.n.m.h.filter.RequestLoggingFilter : Executing request: GET [https://www|https://www/]
#  2018-11-15 09:07:15.914 INFO 5932 — [ctor-http-nio-6] c.c.x.n.m.util.AbstractLookupService : Subscribed to request with uri [https://www|https://www/]
#  2018-11-15 09:07:15.915 INFO 5932 — [ctor-http-nio-6] c.c.x.n.m.util.AbstractLookupService : Request received for uri [https://www|https://www/]  [Thread[reactor-http-nio-6,5,main]]
#  2018-11-15 09:07:18.356 INFO 5932 — [ctor-http-nio-6] c.c.x.n.m.util.AbstractLookupService : Time taken for request [https://www|https://www/] is : [2447] ms  [Thread[reactor-http-nio-6,5,main]]

# %%
# Convert to string
df["text_str"] = df['description'].astype(str)
# Out:
# /tmp/ipykernel_131328/2002586155.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["text_str"] = df['description'].astype(str)

# %%
# Clean the data.
df["text_clean"] = df["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_131328/874145615.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["text_clean"] = df["text_str"].map(preprocess_text)

# %%
# save df to csv
df.to_csv("jira_clean_with_all_cols.csv", index=False)

# %%
# Extract only cols need
df = df[["class", "text_clean"]]

# %%
# Row with NaN
df[df.isna().any(axis=1)]
# Out:
#            class text_clean
# 4            Low        NaN
# 22           Low        NaN
# 34           Low        NaN
# 43       Highest        NaN
# 52           Low        NaN
# ...          ...        ...
# 1404154   Medium        NaN
# 1404188   Medium        NaN
# 1404189   Medium        NaN
# 1404201   Medium        NaN
# 1404241   Medium        NaN
#
# [33656 rows x 2 columns]

# %%
# Need to dropna here since cleaning function returns NaN for not english text.
df.dropna(inplace=True)
df.reset_index(drop=True,inplace=True)

df
# Out:
#            class                                         text_clean
# 0        Highest  we tried upgrading from spring boot to spring ...
# 1         Medium  the jobs that appear under executions section ...
# 2         Lowest  working with springxd version the server with ...
# 3         Medium  my project node cluster and in that node are a...
# 4         Medium  im trying to run a job on springxd and the job...
# ...          ...                                                ...
# 1370584   Medium  simple android lib for pushing little messages...
# 1370585   Medium                               it is very beautiful
# 1370586   Medium  what is reactivegremlin reactivegremlin is a s...
# 1370587   Medium       android view for a swipeable weekly calendar
# 1370588   Medium  beetlmvc is a web framework which can support ...
#
# [1370589 rows x 2 columns]

# %%
# Rows with NaN
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [class, text_clean]
# Index: []

# %%
null_rows = df[df['text_clean'].isnull()]
null_rows
# Out:
# Empty DataFrame
# Columns: [class, text_clean]
# Index: []

# %%
# Clean dataset with clean text and class.
name = f"jira_clean.csv"
df.to_csv(name, index=False)

# %%
import os
priority_levels = ['Highest', 'High', 'Medium', 'Low', 'Lowest']

for level in priority_levels:
    try:
        # Make dir with level
        os.makedirs(f'{level}', exist_ok=True)
        # df with level class
        df_level = df[df['class'] == level]
        # Save to csv
        df_level.to_csv(f'{level}/clean_{level}.csv', index=False)
        print(f"Saved {level}.csv")
    except Exception as e:
        print(f"An error occurred for level {level}: {str(e)}")
# Out:
# Saved Highest.csv
# Saved High.csv
# Saved Medium.csv
# Saved Low.csv
# Saved Lowest.csv

# %%
# Read csv to check if file is saved correctly
for level in priority_levels:
    try:
        df = pd.read_csv(f'{level}/clean_{level}.csv')
        print(f"Read {level}.csv")
    except Exception as e:
        print(f"An error occurred while reading {level}.csv: {str(e)}")
# Out:
# Read Highest.csv
# Read High.csv
# Read Medium.csv
# Read Low.csv
# Read Lowest.csv

# %%
pri = pd.read_csv(name)
pri
# Out:
#            class                                         text_clean
# 0        Highest  we tried upgrading from spring boot to spring ...
# 1         Medium  the jobs that appear under executions section ...
# 2         Lowest  working with springxd version the server with ...
# 3         Medium  my project node cluster and in that node are a...
# 4         Medium  im trying to run a job on springxd and the job...
# ...          ...                                                ...
# 1370584   Medium  simple android lib for pushing little messages...
# 1370585   Medium                               it is very beautiful
# 1370586   Medium  what is reactivegremlin reactivegremlin is a s...
# 1370587   Medium       android view for a swipeable weekly calendar
# 1370588   Medium  beetlmvc is a web framework which can support ...
#
# [1370589 rows x 2 columns]

# %%
null_rows = pri[pri['text_clean'].isnull()]
null_rows
# Out:
#           class text_clean
# 887         Low        NaN
# 12981       Low        NaN
# 14443    Medium        NaN
# 14444    Medium        NaN
# 18752       Low        NaN
# ...         ...        ...
# 1361963  Medium        NaN
# 1363716  Medium        NaN
# 1364722  Medium        NaN
# 1366970  Medium        NaN
# 1366990  Medium        NaN
#
# [608 rows x 2 columns]

# %%
# Remove rows with NaN
pri = pri.dropna()
# Reset index
pri.reset_index(drop=True, inplace=True)
pri
# Out:
#            class                                         text_clean
# 0        Highest  we tried upgrading from spring boot to spring ...
# 1         Medium  the jobs that appear under executions section ...
# 2         Lowest  working with springxd version the server with ...
# 3         Medium  my project node cluster and in that node are a...
# 4         Medium  im trying to run a job on springxd and the job...
# ...          ...                                                ...
# 1369976   Medium  simple android lib for pushing little messages...
# 1369977   Medium                               it is very beautiful
# 1369978   Medium  what is reactivegremlin reactivegremlin is a s...
# 1369979   Medium       android view for a swipeable weekly calendar
# 1369980   Medium  beetlmvc is a web framework which can support ...
#
# [1369981 rows x 2 columns]
