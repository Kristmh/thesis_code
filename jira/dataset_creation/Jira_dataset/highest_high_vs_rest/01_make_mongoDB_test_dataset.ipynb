# %% [markdown]
# # Create dataset: Highest vs rest (high, medium, low, lowest)
# * Under sampling the majority class.
# * 50/50 balance per class.

# %%
file_name = "clean_MongoDB"


file_path = "/fp/projects01/ec307/ec-krimhau/jira_datasets/testsets_clean"


import pandas as pd
# Import csv file

df = pd.read_csv(f'{file_path}/{file_name}.csv')
df
# Out:
#              priority                                        description  \
# 0          Major - P3  Currently there are a number of tests in the C...
# 1          Major - P3  The following compilation notes are getting ge...
# 2          Major - P3  \nh2. [verify-datafile-from-little-endian fail...
# 3          Major - P3  h2. [spinlock-gcc-test failed on ! Ubuntu 20.0...
# 4          Major - P3  \nh2. [cppsuite-hs-cleanup-stress failed on Cp...
# ...               ...                                                ...
# 103322     Major - P3  The following command generates a plan that do...
# 103323  Critical - P2  Hi Team,\r\n\r\nI have a very weird problem, w...
# 103324  Critical - P2  Mongod crashes while running YCSB.  Log and mo...
# 103325     Major - P3  Updated yaml files for the three projects to u...
# 103326     Major - P3  that is recognized by the sharded cluster. Thi...
#
#             project          labels      issuetype collection  \
# 0        WiredTiger              []    Improvement    MongoDB
# 1        WiredTiger              []            Bug    MongoDB
# 2        WiredTiger              []  Build Failure    MongoDB
# 3        WiredTiger  ['CI-blocker']  Build Failure    MongoDB
# 4        WiredTiger              []  Build Failure    MongoDB
# ...             ...             ...            ...        ...
# 103322  Core Server      ['neweng']            Bug    MongoDB
# 103323  Core Server              []            Bug    MongoDB
# 103324  Core Server              []            Bug    MongoDB
# 103325  Core Server   ['test-only']           Task    MongoDB
# 103326  Core Server              []           Task    MongoDB
#
#                                                  text_str  \
# 0       Currently there are a number of tests in the C...
# 1       The following compilation notes are getting ge...
# 2       \nh2. [verify-datafile-from-little-endian fail...
# 3       h2. [spinlock-gcc-test failed on ! Ubuntu 20.0...
# 4       \nh2. [cppsuite-hs-cleanup-stress failed on Cp...
# ...                                                   ...
# 103322  The following command generates a plan that do...
# 103323  Hi Team,\r\n\r\nI have a very weird problem, w...
# 103324  Mongod crashes while running YCSB.  Log and mo...
# 103325  Updated yaml files for the three projects to u...
# 103326  that is recognized by the sharded cluster. Thi...
#
#                                                text_clean
# 0       currently there are a number of tests in the c...
# 1       the following compilation notes are getting ge...
# 2       verifydatafilefromlittleendian failed on bigen...
# 3       spinlockgcctest failed on ubuntu host project ...
# 4       cppsuitehscleanupstress failed on cppsuite str...
# ...                                                   ...
# 103322  the following command generates a plan that do...
# 103323  hi team i have a very weird problem when i run...
# 103324  mongod crashes while running ycsb log and mong...
# 103325  updated yaml files for the three projects to u...
# 103326  that is recognized by the sharded cluster this...
#
# [103327 rows x 8 columns]

# %%
# Count class
df['priority'].value_counts().to_frame()
# Out:
#                count
# priority
# Major - P3     85556
# Minor - P4     11932
# Critical - P2   2992
# Trivial - P5    1937
# Blocker - P1     910

# %%
# NaN values
df.isnull().sum()
# Out:
# priority         0
# description      0
# project          0
# labels           0
# issuetype        0
# collection       0
# text_str         0
# text_clean     130
# dtype: int64

# %%
# Drop NaN values
df = df.dropna()
df.isnull().sum()
# Out:
# priority       0
# description    0
# project        0
# labels         0
# issuetype      0
# collection     0
# text_str       0
# text_clean     0
# dtype: int64

# %%
# Count class
df['priority'].value_counts().to_frame()
# Out:
#                count
# priority
# Major - P3     85442
# Minor - P4     11922
# Critical - P2   2988
# Trivial - P5    1937
# Blocker - P1     908

# %%
# Unique collections
df['collection'].unique()
# Out:
# array(['MongoDB'], dtype=object)

# %%
# Unique projects
df['project'].unique().tolist()
# Out:
# ['WiredTiger',
#  'Core Server',
#  'Rust Driver',
#  'Ruby Driver',
#  'Python Driver',
#  'PHP Driver: Library',
#  'PHP Driver: Extension',
#  'Node.js Driver',
#  'Motor',
#  'VS Code Extension',
#  'MongoDB Database Tools',
#  'MongoDB Shell',
#  'Mongoid',
#  'Libmongocrypt',
#  'Kafka Connector',
#  'Java Driver',
#  'Go Driver',
#  'Evergreen',
#  'Swift Driver',
#  'Drivers',
#  'Documentation',
#  'Spark Connector',
#  'Decision Automation Group',
#  'C++ Driver',
#  'C# Driver',
#  'Compass ',
#  'C Driver']

# %%
# Number of unique projects 
len(df['project'].unique())
# Out:
# 27

# %%
priority_mapping = {
    'Blocker - P1': 'Highest',
    'Critical - P2': 'High',
    'Major - P3': 'Medium',
    'Minor - P4': 'Low',
    'Trivial - P5': 'Lowest',

}
# Apply mapping
df['class'] = df['priority'].map(priority_mapping)
# Out:
# /localscratch/585336/ipykernel_1302295/2311033747.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['class'] = df['priority'].map(priority_mapping)

# %%
# Find the priorities that are not mapped to 'Highest' by checking for nulls in 'class'
unmapped_priorities = df[df['class'].isnull()]['priority'].unique()

if len(unmapped_priorities)  == 0:
    print("All priorities are mapped to a new class")
else:
    print("Priorities not mapped to a new class:")
    for priority in unmapped_priorities:
        print(f"- {priority}")
# Out:
# All priorities are mapped to a new class

# %%
# Count class
df['class'].value_counts().to_frame()
# Out:
#          count
# class
# Medium   85442
# Low      11922
# High      2988
# Lowest    1937
# Highest    908

# %%
highest = df[df['class'] == 'Highest']
high = df[df['class'] == 'High']
medium = df[df['class'] == 'Medium']
low = df[df['class'] == 'Low']
lowest = df[df['class'] == 'Lowest']

# %%
highest_full = pd.concat([highest, high])
highest_full = highest_full.rename(columns={'class': 'class_original'})
highest_full["class"] = "highest" 
highest_full["label"] = 1
highest_full
# Out:
#              priority                                        description  \
# 202      Blocker - P1  Hello support team, \r\n\r\n \r\n\r\nAlright, ...
# 219      Blocker - P1  {panel:title=Issue Status as of Dec 30, 2021|b...
# 465      Blocker - P1  There are reports of databases where the numbe...
# 468      Blocker - P1  Follow-on from WT-3977. That ticket has test p...
# 653      Blocker - P1  There is a case when reconciliation is generat...
# ...               ...                                                ...
# 103234  Critical - P2  Building mongod/mongos on Windows with {{\-\-o...
# 103285  Critical - P2  A BSONElement of type String has a pointer+len...
# 103293  Critical - P2  {{mongod}}, {{mongoperf}} and {{mongosniff}} h...
# 103323  Critical - P2  Hi Team,\r\n\r\nI have a very weird problem, w...
# 103324  Critical - P2  Mongod crashes while running YCSB.  Log and mo...
#
#             project             labels issuetype collection  \
# 202      WiredTiger  ['confirmed_bug']       Bug    MongoDB
# 219      WiredTiger                 []       Bug    MongoDB
# 465      WiredTiger                 []       Bug    MongoDB
# 468      WiredTiger   ['SEKB', 'SWNA']       Bug    MongoDB
# 653      WiredTiger                 []       Bug    MongoDB
# ...             ...                ...       ...        ...
# 103234  Core Server                 []       Bug    MongoDB
# 103285  Core Server                 []       Bug    MongoDB
# 103293  Core Server      ['code-only']       Bug    MongoDB
# 103323  Core Server                 []       Bug    MongoDB
# 103324  Core Server                 []       Bug    MongoDB
#
#                                                  text_str  \
# 202     Hello support team, \r\n\r\n \r\n\r\nAlright, ...
# 219     {panel:title=Issue Status as of Dec 30, 2021|b...
# 465     There are reports of databases where the numbe...
# 468     Follow-on from WT-3977. That ticket has test p...
# 653     There is a case when reconciliation is generat...
# ...                                                   ...
# 103234  Building mongod/mongos on Windows with {{\-\-o...
# 103285  A BSONElement of type String has a pointer+len...
# 103293  {{mongod}}, {{mongoperf}} and {{mongosniff}} h...
# 103323  Hi Team,\r\n\r\nI have a very weird problem, w...
# 103324  Mongod crashes while running YCSB.  Log and mo...
#
#                                                text_clean class_original  \
# 202     hello support team alright so we are in a bit ...        Highest
# 219     paneltitleissue status as of dec issue descrip...        Highest
# 465     there are reports of databases where the numbe...        Highest
# 468     followon from that ticket has test program deb...        Highest
# 653     there is a case when reconciliation is generat...        Highest
# ...                                                   ...            ...
# 103234  building mongodmongos on windows with optoffdb...           High
# 103285  a bsonelement of type string has a pointerleng...           High
# 103293  mongod mongoperf and mongosniff has executable...           High
# 103323  hi team i have a very weird problem when i run...           High
# 103324  mongod crashes while running ycsb log and mong...           High
#
#           class  label
# 202     highest      1
# 219     highest      1
# 465     highest      1
# 468     highest      1
# 653     highest      1
# ...         ...    ...
# 103234  highest      1
# 103285  highest      1
# 103293  highest      1
# 103323  highest      1
# 103324  highest      1
#
# [3896 rows x 11 columns]

# %%
# Concat all class except highest
rest = pd.concat([medium, low, lowest])
# Rename class to class_1
rest = rest.rename(columns={'class': 'class_original'})
rest["class"] = "rest" 
rest["label"] = 0
rest
# Out:
#             priority                                        description  \
# 0         Major - P3  Currently there are a number of tests in the C...
# 1         Major - P3  The following compilation notes are getting ge...
# 2         Major - P3  \nh2. [verify-datafile-from-little-endian fail...
# 3         Major - P3  h2. [spinlock-gcc-test failed on ! Ubuntu 20.0...
# 4         Major - P3  \nh2. [cppsuite-hs-cleanup-stress failed on Cp...
# ...              ...                                                ...
# 102938  Trivial - P5  The MSVC 2015 compiler produces the following ...
# 102970  Trivial - P5  We set the location of the minidump using the ...
# 103096  Trivial - P5  I am using this check https://github.com/mzupa...
# 103111  Trivial - P5  {code:cpp}\r\nstd::unique_ptr<Lock::ResourceLo...
# 103156  Trivial - P5  Not restoring the stream format state of an os...
#
#             project             labels      issuetype collection  \
# 0        WiredTiger                 []    Improvement    MongoDB
# 1        WiredTiger                 []            Bug    MongoDB
# 2        WiredTiger                 []  Build Failure    MongoDB
# 3        WiredTiger     ['CI-blocker']  Build Failure    MongoDB
# 4        WiredTiger                 []  Build Failure    MongoDB
# ...             ...                ...            ...        ...
# 102938  Core Server                 []            Bug    MongoDB
# 102970  Core Server  ['PM-372', 'stm']            Bug    MongoDB
# 103096  Core Server                 []       Question    MongoDB
# 103111  Core Server         ['neweng']           Task    MongoDB
# 103156  Core Server       ['coverity']            Bug    MongoDB
#
#                                                  text_str  \
# 0       Currently there are a number of tests in the C...
# 1       The following compilation notes are getting ge...
# 2       \nh2. [verify-datafile-from-little-endian fail...
# 3       h2. [spinlock-gcc-test failed on ! Ubuntu 20.0...
# 4       \nh2. [cppsuite-hs-cleanup-stress failed on Cp...
# ...                                                   ...
# 102938  The MSVC 2015 compiler produces the following ...
# 102970  We set the location of the minidump using the ...
# 103096  I am using this check https://github.com/mzupa...
# 103111  {code:cpp}\r\nstd::unique_ptr<Lock::ResourceLo...
# 103156  Not restoring the stream format state of an os...
#
#                                                text_clean class_original  \
# 0       currently there are a number of tests in the c...         Medium
# 1       the following compilation notes are getting ge...         Medium
# 2       verifydatafilefromlittleendian failed on bigen...         Medium
# 3       spinlockgcctest failed on ubuntu host project ...         Medium
# 4       cppsuitehscleanupstress failed on cppsuite str...         Medium
# ...                                                   ...            ...
# 102938  the msvc compiler produces the following warni...         Lowest
# 102970  we set the location of the minidump using the ...         Lowest
# 103096  i am using this check to monitor replication l...         Lowest
# 103111  codecpp stduniqueptr rlk if isrsthreadsafe opc...         Lowest
# 103156  not restoring the stream format state of an os...         Lowest
#
#        class  label
# 0       rest      0
# 1       rest      0
# 2       rest      0
# 3       rest      0
# 4       rest      0
# ...      ...    ...
# 102938  rest      0
# 102970  rest      0
# 103096  rest      0
# 103111  rest      0
# 103156  rest      0
#
# [99301 rows x 11 columns]

# %%
# Value count rest class
rest['class'].value_counts().to_frame()
# Out:
#        count
# class
# rest   99301

# %%
from sklearn.utils import shuffle
# Number of rows in the highest class
n_highest = highest_full.shape[0]

sampled = rest.sample(n=n_highest, random_state=42)  


balanced_data = pd.concat([highest_full, sampled])

# Shuffle the combined dataset
balanced_data = shuffle(balanced_data, random_state=42)
balanced_data
# Out:
#             priority                                        description  \
# 10697  Critical - P2  Hi, I have deployed one mongodb sharded cluste...
# 59482     Major - P3  I can not issue the tar -zxvf mongo.tgz comman...
# 32964     Major - P3  When DRIVERS-1943 (https://github.com/mongodb/...
# 3306   Critical - P2  If a move-update results in an error and is ro...
# 14989   Blocker - P1  {code}\n *************************************...
# ...              ...                                                ...
# 59422     Major - P3  From http://www.mongodb.org/display/DOCS/Mongo...
# 32845     Major - P3  After initial sync complete, the connector ter...
# 80099   Blocker - P1  {panel:title=Issue Status as of June 15, 2020|...
# 75809     Major - P3  Proposed interface:\r\n\r\n{code:cpp|title=res...
# 36409     Minor - P4  The invocation of `client.StartSession( aConte...
#
#                project                           labels    issuetype  \
# 10697      Core Server                               []     Question
# 59482    Documentation           ['collector-298ba4e7']  Improvement
# 32964      Java Driver                               []  Improvement
# 3306       Core Server                               []          Bug
# 14989      Core Server                     ['buildbot']          Bug
# ...                ...                              ...          ...
# 59422    Documentation                               []         Task
# 32845  Kafka Connector                               []          Bug
# 80099       WiredTiger  ['data-corruption-incr-backup']          Bug
# 75809      Core Server                               []         Task
# 36409        Go Driver                     ['post-5.0']  Improvement
#
#       collection                                           text_str  \
# 10697    MongoDB  Hi, I have deployed one mongodb sharded cluste...
# 59482    MongoDB  I can not issue the tar -zxvf mongo.tgz comman...
# 32964    MongoDB  When DRIVERS-1943 (https://github.com/mongodb/...
# 3306     MongoDB  If a move-update results in an error and is ro...
# 14989    MongoDB  {code}\n *************************************...
# ...          ...                                                ...
# 59422    MongoDB  From http://www.mongodb.org/display/DOCS/Mongo...
# 32845    MongoDB  After initial sync complete, the connector ter...
# 80099    MongoDB  {panel:title=Issue Status as of June 15, 2020|...
# 75809    MongoDB  Proposed interface:\r\n\r\n{code:cpp|title=res...
# 36409    MongoDB  The invocation of `client.StartSession( aConte...
#
#                                               text_clean class_original  \
# 10697  hi i have deployed one mongodb sharded cluster...           High
# 59482  i can not issue the tar zxvf mongotgz command ...         Medium
# 32964  when is approved it will contain specification...         Medium
# 3306   if a moveupdate results in an error and is rol...           High
# 14989  code test jstestsreversecursorjs tue dec drop ...        Highest
# ...                                                  ...            ...
# 59422  from the manual should include the fact that m...         Medium
# 32845  after initial sync complete the connector term...         Medium
# 80099  paneltitleissue status as of june issue summar...        Highest
# 75809  proposed interface codecpptitlereshardingdatac...         Medium
# 36409  the invocation of clientstartsession acontext ...            Low
#
#          class  label
# 10697  highest      1
# 59482     rest      0
# 32964     rest      0
# 3306   highest      1
# 14989  highest      1
# ...        ...    ...
# 59422     rest      0
# 32845     rest      0
# 80099  highest      1
# 75809     rest      0
# 36409     rest      0
#
# [7792 rows x 11 columns]

# %%
balanced_data['class'].value_counts().to_frame()
# Out:
#          count
# class
# highest   3896
# rest      3896

# %%
balanced_data
# Out:
#             priority                                        description  \
# 10697  Critical - P2  Hi, I have deployed one mongodb sharded cluste...
# 59482     Major - P3  I can not issue the tar -zxvf mongo.tgz comman...
# 32964     Major - P3  When DRIVERS-1943 (https://github.com/mongodb/...
# 3306   Critical - P2  If a move-update results in an error and is ro...
# 14989   Blocker - P1  {code}\n *************************************...
# ...              ...                                                ...
# 59422     Major - P3  From http://www.mongodb.org/display/DOCS/Mongo...
# 32845     Major - P3  After initial sync complete, the connector ter...
# 80099   Blocker - P1  {panel:title=Issue Status as of June 15, 2020|...
# 75809     Major - P3  Proposed interface:\r\n\r\n{code:cpp|title=res...
# 36409     Minor - P4  The invocation of `client.StartSession( aConte...
#
#                project                           labels    issuetype  \
# 10697      Core Server                               []     Question
# 59482    Documentation           ['collector-298ba4e7']  Improvement
# 32964      Java Driver                               []  Improvement
# 3306       Core Server                               []          Bug
# 14989      Core Server                     ['buildbot']          Bug
# ...                ...                              ...          ...
# 59422    Documentation                               []         Task
# 32845  Kafka Connector                               []          Bug
# 80099       WiredTiger  ['data-corruption-incr-backup']          Bug
# 75809      Core Server                               []         Task
# 36409        Go Driver                     ['post-5.0']  Improvement
#
#       collection                                           text_str  \
# 10697    MongoDB  Hi, I have deployed one mongodb sharded cluste...
# 59482    MongoDB  I can not issue the tar -zxvf mongo.tgz comman...
# 32964    MongoDB  When DRIVERS-1943 (https://github.com/mongodb/...
# 3306     MongoDB  If a move-update results in an error and is ro...
# 14989    MongoDB  {code}\n *************************************...
# ...          ...                                                ...
# 59422    MongoDB  From http://www.mongodb.org/display/DOCS/Mongo...
# 32845    MongoDB  After initial sync complete, the connector ter...
# 80099    MongoDB  {panel:title=Issue Status as of June 15, 2020|...
# 75809    MongoDB  Proposed interface:\r\n\r\n{code:cpp|title=res...
# 36409    MongoDB  The invocation of `client.StartSession( aConte...
#
#                                               text_clean class_original  \
# 10697  hi i have deployed one mongodb sharded cluster...           High
# 59482  i can not issue the tar zxvf mongotgz command ...         Medium
# 32964  when is approved it will contain specification...         Medium
# 3306   if a moveupdate results in an error and is rol...           High
# 14989  code test jstestsreversecursorjs tue dec drop ...        Highest
# ...                                                  ...            ...
# 59422  from the manual should include the fact that m...         Medium
# 32845  after initial sync complete the connector term...         Medium
# 80099  paneltitleissue status as of june issue summar...        Highest
# 75809  proposed interface codecpptitlereshardingdatac...         Medium
# 36409  the invocation of clientstartsession acontext ...            Low
#
#          class  label
# 10697  highest      1
# 59482     rest      0
# 32964     rest      0
# 3306   highest      1
# 14989  highest      1
# ...        ...    ...
# 59422     rest      0
# 32845     rest      0
# 80099  highest      1
# 75809     rest      0
# 36409     rest      0
#
# [7792 rows x 11 columns]

# %%
# Count label
balanced_data['label'].value_counts().to_frame()
# Out:
#        count
# label
# 1       3896
# 0       3896

# %%
# Count original class
balanced_data['class_original'].value_counts().to_frame()
# Out:
#                 count
# class_original
# Medium           3357
# High             2988
# Highest           908
# Low               473
# Lowest             66

# %%
# New df with only text clean and label
balanced_data = balanced_data[['text_clean', 'label']]
balanced_data
# Out:
#                                               text_clean  label
# 10697  hi i have deployed one mongodb sharded cluster...      1
# 59482  i can not issue the tar zxvf mongotgz command ...      0
# 32964  when is approved it will contain specification...      0
# 3306   if a moveupdate results in an error and is rol...      1
# 14989  code test jstestsreversecursorjs tue dec drop ...      1
# ...                                                  ...    ...
# 59422  from the manual should include the fact that m...      0
# 32845  after initial sync complete the connector term...      0
# 80099  paneltitleissue status as of june issue summar...      1
# 75809  proposed interface codecpptitlereshardingdatac...      0
# 36409  the invocation of clientstartsession acontext ...      0
#
# [7792 rows x 2 columns]

# %%
balanced_data.rename(columns={'text_clean': 'text'}, inplace=True)
balanced_data
# Out:
# /localscratch/585336/ipykernel_1302295/984652038.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   balanced_data.rename(columns={'text_clean': 'text'}, inplace=True)
#                                                     text  label
# 10697  hi i have deployed one mongodb sharded cluster...      1
# 59482  i can not issue the tar zxvf mongotgz command ...      0
# 32964  when is approved it will contain specification...      0
# 3306   if a moveupdate results in an error and is rol...      1
# 14989  code test jstestsreversecursorjs tue dec drop ...      1
# ...                                                  ...    ...
# 59422  from the manual should include the fact that m...      0
# 32845  after initial sync complete the connector term...      0
# 80099  paneltitleissue status as of june issue summar...      1
# 75809  proposed interface codecpptitlereshardingdatac...      0
# 36409  the invocation of clientstartsession acontext ...      0
#
# [7792 rows x 2 columns]

# %%
# Save to csv
out_path = "/fp/projects01/ec307/ec-krimhau/jira_datasets/high_highest_vs_rest"
full_file_name = f'{out_path}/jira_{file_name}_highest_high_vs_rest_balanced.csv'
balanced_data.to_csv(full_file_name, index=False)

# %%
# Read csv
df = pd.read_csv(full_file_name)
df
# Out:
#                                                    text  label
# 0     hi i have deployed one mongodb sharded cluster...      1
# 1     i can not issue the tar zxvf mongotgz command ...      0
# 2     when is approved it will contain specification...      0
# 3     if a moveupdate results in an error and is rol...      1
# 4     code test jstestsreversecursorjs tue dec drop ...      1
# ...                                                 ...    ...
# 7787  from the manual should include the fact that m...      0
# 7788  after initial sync complete the connector term...      0
# 7789  paneltitleissue status as of june issue summar...      1
# 7790  proposed interface codecpptitlereshardingdatac...      0
# 7791  the invocation of clientstartsession acontext ...      0
#
# [7792 rows x 2 columns]
