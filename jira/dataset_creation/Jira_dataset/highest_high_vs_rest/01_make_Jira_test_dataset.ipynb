# %% [markdown]
# # Create dataset: Highest vs rest (high, medium, low, lowest)
# * Under sampling the majority class.
# * 50/50 balance per class.

# %%
file_name = "clean_Jira"


file_path = "/fp/projects01/ec307/ec-krimhau/jira_datasets/testsets_clean"


import pandas as pd
# Import csv file

df = pd.read_csv(f'{file_path}/{file_name}.csv')
df
# Out:
#        priority                                        description  \
# 0           Low  some errors show up as shown in the screenshot...
# 1           Low  I have been using Sourcetree 3.4.4.  We use cu...
# 2           Low  After installing SourceTree for Windows 10 64b...
# 3           Low  On windows, Sourcetree.exe will start "git.exe...
# 4           Low  Hello,\r\n\r\nSourceTree 3.4.7.\r\n\r\nOS: Win...
# ...         ...                                                ...
# 127602      Low  h3. Issue Summary\r\n\r\nIf a service desk pro...
# 127603      Low  h3. Issue Summary\r\n\r\nWe have '*Link Issue*...
# 127604      Low  h3. Issue Summary\r\n\r\nCreating child object...
# 127605      Low  h3. Issue Summary\r\nInsight IQL uses timezone...
# 127606   Medium  h3. Issue Summary\r\n\r\nThe intermittent issu...
#
#                               project labels issuetype collection  \
# 0              Sourcetree for Windows     []       Bug       Jira
# 1              Sourcetree for Windows     []       Bug       Jira
# 2              Sourcetree for Windows     []       Bug       Jira
# 3              Sourcetree for Windows     []       Bug       Jira
# 4              Sourcetree for Windows     []       Bug       Jira
# ...                               ...    ...       ...        ...
# 127602  Jira Service Management Cloud     []       Bug       Jira
# 127603  Jira Service Management Cloud     []       Bug       Jira
# 127604  Jira Service Management Cloud     []       Bug       Jira
# 127605  Jira Service Management Cloud     []       Bug       Jira
# 127606  Jira Service Management Cloud     []       Bug       Jira
#
#                                                  text_str  \
# 0       some errors show up as shown in the screenshot...
# 1       I have been using Sourcetree 3.4.4.  We use cu...
# 2       After installing SourceTree for Windows 10 64b...
# 3       On windows, Sourcetree.exe will start "git.exe...
# 4       Hello,\r\n\r\nSourceTree 3.4.7.\r\n\r\nOS: Win...
# ...                                                   ...
# 127602  h3. Issue Summary\r\n\r\nIf a service desk pro...
# 127603  h3. Issue Summary\r\n\r\nWe have '*Link Issue*...
# 127604  h3. Issue Summary\r\n\r\nCreating child object...
# 127605  h3. Issue Summary\r\nInsight IQL uses timezone...
# 127606  h3. Issue Summary\r\n\r\nThe intermittent issu...
#
#                                                text_clean
# 0       some errors show up as shown in the screenshot...
# 1       i have been using sourcetree we use custom act...
# 2       after installing sourcetree for windows machin...
# 3       on windows sourcetreeexe will start gitexe fsm...
# 4       hello sourcetree os windows pro problem create...
# ...                                                   ...
# 127602  issue summary if a service desk project has a ...
# 127603  issue summary we have link issue button in the...
# 127604  issue summary creating child objects with no s...
# 127605  issue summary insight iql uses timezones in a ...
# 127606  issue summary the intermittent issue portalonl...
#
# [127607 rows x 8 columns]

# %%
# Count class
df['priority'].value_counts().to_frame()
# Out:
#           count
# priority
# Low       72641
# Medium    40559
# High       9739
# Highest    4668

# %%
# NaN values
df.isnull().sum()
# Out:
# priority        0
# description     0
# project         0
# labels          0
# issuetype       0
# collection      0
# text_str        0
# text_clean     69
# dtype: int64

# %%
# Drop NaN values
df = df.dropna()
df.isnull().sum()
# Out:
# priority       0
# description    0
# project        0
# labels         0
# issuetype      0
# collection     0
# text_str       0
# text_clean     0
# dtype: int64

# %%
# Count class
df['priority'].value_counts().to_frame()
# Out:
#           count
# priority
# Low       72610
# Medium    40526
# High       9736
# Highest    4666

# %%
# Unique collections
df['collection'].unique()
# Out:
# array(['Jira'], dtype=object)

# %%
# Unique projects
df['project'].unique().tolist()
# Out:
# ['Sourcetree for Windows',
#  'Jira Service Management Cloud',
#  'Jira Server and Data Center',
#  'Sourcetree For Mac',
#  'Jira Cloud',
#  'Advanced Roadmaps',
#  'Automation for Jira',
#  'Identity',
#  'Atlassian Internationalization',
#  'atlassian-http',
#  'FishEye',
#  'Crowd',
#  'Crucible',
#  'atlassian-seraph',
#  'Confluence Server and Data Center',
#  'Server Deployments and Scale',
#  'Atlassian OAuth 2.0',
#  'Migration Platform',
#  'Jira Work Management Cloud',
#  'Jira Software Server and Data Center',
#  'Confluence Cloud',
#  'Clover',
#  'Atlassian Cloud',
#  'Bitbucket Server',
#  'Bitbucket Cloud',
#  'Bamboo',
#  'Atlassian Product Integrations',
#  'Atlassian Access',
#  'Jira Software Cloud',
#  'Jira Service Management Server and Data Center']

# %%
# Number of unique projects 
len(df['project'].unique())
# Out:
# 30

# %%
priority_mapping = {
    # Highest priority
    'Highest': 'Highest',
    'High': 'High',
    'Medium': 'Medium',
    'Low': 'Low',

}
# Apply mapping
df['class'] = df['priority'].map(priority_mapping)
# Out:
# /localscratch/585336/ipykernel_1302039/3135084215.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['class'] = df['priority'].map(priority_mapping)

# %%
# Find the priorities that are not mapped to 'Highest' by checking for nulls in 'class'
unmapped_priorities = df[df['class'].isnull()]['priority'].unique()

if len(unmapped_priorities)  == 0:
    print("All priorities are mapped to a new class")
else:
    print("Priorities not mapped to a new class:")
    for priority in unmapped_priorities:
        print(f"- {priority}")
# Out:
# All priorities are mapped to a new class

# %%
# Count class
df['class'].value_counts().to_frame()
# Out:
#          count
# class
# Low      72610
# Medium   40526
# High      9736
# Highest   4666

# %%
highest = df[df['class'] == 'Highest']
high = df[df['class'] == 'High']
medium = df[df['class'] == 'Medium']
low = df[df['class'] == 'Low']

# %%
highest_full = pd.concat([highest, high])
highest_full = highest_full.rename(columns={'class': 'class_original'})
highest_full["class"] = "highest" 
highest_full["label"] = 1
highest_full
# Out:
#        priority                                        description  \
# 452     Highest  Have been using sourcetree fine for some time ...
# 468     Highest  In my git project I have changes in the main p...
# 482     Highest  When performing any action that should result ...
# 485     Highest  Whatever I do or select on "Working Copy Chang...
# 489     Highest  Everything seems horribly slow including:\r\n*...
# ...         ...                                                ...
# 127432     High  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
# 127434     High  The root cause of this issue is: https://ecosy...
# 127478     High  h3. Issue Summary\r\n\r\nOn Service Management...
# 127563     High  h3. Issue Summary:\r\n\r\nWorkload Report in S...
# 127564     High  h3. Issue Summary\r\nWhen an issue is viewed o...
#
#                                                project  \
# 452                             Sourcetree for Windows
# 468                             Sourcetree for Windows
# 482                             Sourcetree for Windows
# 485                             Sourcetree for Windows
# 489                             Sourcetree for Windows
# ...                                                ...
# 127432  Jira Service Management Server and Data Center
# 127434  Jira Service Management Server and Data Center
# 127478                   Jira Service Management Cloud
# 127563                   Jira Service Management Cloud
# 127564                   Jira Service Management Cloud
#
#                                labels issuetype collection  \
# 452                                []       Bug       Jira
# 468            ['crash', 'submodule']       Bug       Jira
# 482                ['clone', 'crash']       Bug       Jira
# 485                                []       Bug       Jira
# 489     ['index.lock', 'performance']       Bug       Jira
# ...                               ...       ...        ...
# 127432                             []       Bug       Jira
# 127434             ['affects-server']       Bug       Jira
# 127478                             []       Bug       Jira
# 127563                             []       Bug       Jira
# 127564                             []       Bug       Jira
#
#                                                  text_str  \
# 452     Have been using sourcetree fine for some time ...
# 468     In my git project I have changes in the main p...
# 482     When performing any action that should result ...
# 485     Whatever I do or select on "Working Copy Chang...
# 489     Everything seems horribly slow including:\r\n*...
# ...                                                   ...
# 127432  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
# 127434  The root cause of this issue is: https://ecosy...
# 127478  h3. Issue Summary\r\n\r\nOn Service Management...
# 127563  h3. Issue Summary:\r\n\r\nWorkload Report in S...
# 127564  h3. Issue Summary\r\nWhen an issue is viewed o...
#
#                                                text_clean class_original  \
# 452     have been using sourcetree fine for some time ...        Highest
# 468     in my git project i have changes in the main p...        Highest
# 482     when performing any action that should result ...        Highest
# 485     whatever i do or select on working copy change...        Highest
# 489     everything seems horribly slow including many ...        Highest
# ...                                                   ...            ...
# 127432  note this bug report is for jira service desk ...           High
# 127434  the root cause of this issue is and is caused ...           High
# 127478  issue summary on service management reports wh...           High
# 127563  issue summary workload report in service desk ...           High
# 127564  issue summary when an issue is viewed on a mob...           High
#
#           class  label
# 452     highest      1
# 468     highest      1
# 482     highest      1
# 485     highest      1
# 489     highest      1
# ...         ...    ...
# 127432  highest      1
# 127434  highest      1
# 127478  highest      1
# 127563  highest      1
# 127564  highest      1
#
# [14402 rows x 11 columns]

# %%
# Concat all class except highest
rest = pd.concat([medium, low])
# Rename class to class_1
rest = rest.rename(columns={'class': 'class_original'})
rest["class"] = "rest" 
rest["label"] = 0
rest
# Out:
#        priority                                        description  \
# 245      Medium  I've organized my local repositories into fold...
# 412      Medium  I was on a repository from https://github.com/...
# 417      Medium  If I have staged and unstaged changes and I cl...
# 420      Medium  In the history browser, select a changeset wit...
# 423      Medium  Past two days doing remote pull causes Win 7 r...
# ...         ...                                                ...
# 127601      Low  h3. Issue Summary\r\n\r\nSorting objects using...
# 127602      Low  h3. Issue Summary\r\n\r\nIf a service desk pro...
# 127603      Low  h3. Issue Summary\r\n\r\nWe have '*Link Issue*...
# 127604      Low  h3. Issue Summary\r\n\r\nCreating child object...
# 127605      Low  h3. Issue Summary\r\nInsight IQL uses timezone...
#
#                               project  \
# 245            Sourcetree for Windows
# 412            Sourcetree for Windows
# 417            Sourcetree for Windows
# 420            Sourcetree for Windows
# 423            Sourcetree for Windows
# ...                               ...
# 127601  Jira Service Management Cloud
# 127602  Jira Service Management Cloud
# 127603  Jira Service Management Cloud
# 127604  Jira Service Management Cloud
# 127605  Jira Service Management Cloud
#
#                                           labels issuetype collection  \
# 245                                 ['verified']       Bug       Jira
# 412                    ['OpenTerminal', 'crash']       Bug       Jira
# 417                                           []       Bug       Jira
# 420     ['FileSystemWatcher', 'diff', 'refresh']       Bug       Jira
# 423                           ['freeze', 'pull']       Bug       Jira
# ...                                          ...       ...        ...
# 127601                                        []       Bug       Jira
# 127602                                        []       Bug       Jira
# 127603                                        []       Bug       Jira
# 127604                                        []       Bug       Jira
# 127605                                        []       Bug       Jira
#
#                                                  text_str  \
# 245     I've organized my local repositories into fold...
# 412     I was on a repository from https://github.com/...
# 417     If I have staged and unstaged changes and I cl...
# 420     In the history browser, select a changeset wit...
# 423     Past two days doing remote pull causes Win 7 r...
# ...                                                   ...
# 127601  h3. Issue Summary\r\n\r\nSorting objects using...
# 127602  h3. Issue Summary\r\n\r\nIf a service desk pro...
# 127603  h3. Issue Summary\r\n\r\nWe have '*Link Issue*...
# 127604  h3. Issue Summary\r\n\r\nCreating child object...
# 127605  h3. Issue Summary\r\nInsight IQL uses timezone...
#
#                                                text_clean class_original  \
# 245     ive organized my local repositories into folde...         Medium
# 412     i was on a repository from branch then i hit t...         Medium
# 417     if i have staged and unstaged changes and i cl...         Medium
# 420     in the history browser select a changeset with...         Medium
# 423     past two days doing remote pull causes win rot...         Medium
# ...                                                   ...            ...
# 127601  issue summary sorting objects using an iql que...            Low
# 127602  issue summary if a service desk project has a ...            Low
# 127603  issue summary we have link issue button in the...            Low
# 127604  issue summary creating child objects with no s...            Low
# 127605  issue summary insight iql uses timezones in a ...            Low
#
#        class  label
# 245     rest      0
# 412     rest      0
# 417     rest      0
# 420     rest      0
# 423     rest      0
# ...      ...    ...
# 127601  rest      0
# 127602  rest      0
# 127603  rest      0
# 127604  rest      0
# 127605  rest      0
#
# [113136 rows x 11 columns]

# %%
# Value count rest class
rest['class'].value_counts().to_frame()
# Out:
#         count
# class
# rest   113136

# %%
from sklearn.utils import shuffle
# Number of rows in the highest class
n_highest = highest_full.shape[0]

sampled = rest.sample(n=n_highest, random_state=42)  


balanced_data = pd.concat([highest_full, sampled])

# Shuffle the combined dataset
balanced_data = shuffle(balanced_data, random_state=42)
balanced_data
# Out:
#        priority                                        description  \
# 23484      High  I have reported this to support (Michelle De G...
# 102923   Medium  Hello,\n\nI am getting this error when I try t...
# 116207      Low  Every time I use the Build History screen, thi...
# 70783   Highest  The Add bookmark page is vulnerable to XSS att...
# 104774     High  I can not add(get/remove) ssh-keys to users wi...
# ...         ...                                                ...
# 91747       Low  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
# 14667      High  h3. Summary\r\n\r\nJIRA has no 'rate limiting'...
# 32170   Highest  h3.*Problem Definition*\r\n* All of a sudden, ...
# 90649       Low  {panel:bgColor=#e7f4fa}\r\n  *NOTE:* This bug ...
# 41155       Low  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
#
#                                   project  \
# 23484         Jira Server and Data Center
# 102923                    Bitbucket Cloud
# 116207                             Bamboo
# 70783   Confluence Server and Data Center
# 104774                    Bitbucket Cloud
# ...                                   ...
# 91747                    Confluence Cloud
# 14667         Jira Server and Data Center
# 32170                          Jira Cloud
# 90649                    Confluence Cloud
# 41155                          Jira Cloud
#
#                                                    labels issuetype  \
# 23484                                  ['affects-server']       Bug
# 102923                                       ['migrated']       Bug
# 116207                                      ['pm-review']       Bug
# 70783                      ['affects-server', 'security']       Bug
# 104774                                       ['migrated']       Bug
# ...                                                   ...       ...
# 91747                                                  []       Bug
# 14667   ['affects-server', 'architectural-flaw', 'ente...       Bug
# 32170                                 ['bento', 'new-ui']       Bug
# 90649   ['affects-cloud', 'affects-server', 'editor', ...       Bug
# 41155   ['affects-cloud', 'affects-server', 'hedge', '...       Bug
#
#        collection                                           text_str  \
# 23484        Jira  I have reported this to support (Michelle De G...
# 102923       Jira  Hello,\n\nI am getting this error when I try t...
# 116207       Jira  Every time I use the Build History screen, thi...
# 70783        Jira  The Add bookmark page is vulnerable to XSS att...
# 104774       Jira  I can not add(get/remove) ssh-keys to users wi...
# ...           ...                                                ...
# 91747        Jira  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
# 14667        Jira  h3. Summary\r\n\r\nJIRA has no 'rate limiting'...
# 32170        Jira  h3.*Problem Definition*\r\n* All of a sudden, ...
# 90649        Jira  {panel:bgColor=#e7f4fa}\r\n  *NOTE:* This bug ...
# 41155        Jira  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
#
#                                                text_clean class_original  \
# 23484   i have reported this to support michelle de gu...           High
# 102923  helloi am getting this error when i try to pus...         Medium
# 116207  every time i use the build history screen this...            Low
# 70783   the add bookmark page is vulnerable to xss att...        Highest
# 104774  i can not addgetremove sshkeys to users with u...           High
# ...                                                   ...            ...
# 91747   note this bug report is for confluence cloud u...            Low
# 14667   summary jira has no rate limiting or mail limi...           High
# 32170   definition all of a sudden some users are unab...        Highest
# 90649   note this bug report is for confluence cloud u...            Low
# 41155   note this bug report is for jira cloud using j...            Low
#
#           class  label
# 23484   highest      1
# 102923     rest      0
# 116207     rest      0
# 70783   highest      1
# 104774  highest      1
# ...         ...    ...
# 91747      rest      0
# 14667   highest      1
# 32170   highest      1
# 90649      rest      0
# 41155      rest      0
#
# [28804 rows x 11 columns]

# %%
balanced_data['class'].value_counts().to_frame()
# Out:
#          count
# class
# highest  14402
# rest     14402

# %%
balanced_data
# Out:
#        priority                                        description  \
# 23484      High  I have reported this to support (Michelle De G...
# 102923   Medium  Hello,\n\nI am getting this error when I try t...
# 116207      Low  Every time I use the Build History screen, thi...
# 70783   Highest  The Add bookmark page is vulnerable to XSS att...
# 104774     High  I can not add(get/remove) ssh-keys to users wi...
# ...         ...                                                ...
# 91747       Low  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
# 14667      High  h3. Summary\r\n\r\nJIRA has no 'rate limiting'...
# 32170   Highest  h3.*Problem Definition*\r\n* All of a sudden, ...
# 90649       Low  {panel:bgColor=#e7f4fa}\r\n  *NOTE:* This bug ...
# 41155       Low  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
#
#                                   project  \
# 23484         Jira Server and Data Center
# 102923                    Bitbucket Cloud
# 116207                             Bamboo
# 70783   Confluence Server and Data Center
# 104774                    Bitbucket Cloud
# ...                                   ...
# 91747                    Confluence Cloud
# 14667         Jira Server and Data Center
# 32170                          Jira Cloud
# 90649                    Confluence Cloud
# 41155                          Jira Cloud
#
#                                                    labels issuetype  \
# 23484                                  ['affects-server']       Bug
# 102923                                       ['migrated']       Bug
# 116207                                      ['pm-review']       Bug
# 70783                      ['affects-server', 'security']       Bug
# 104774                                       ['migrated']       Bug
# ...                                                   ...       ...
# 91747                                                  []       Bug
# 14667   ['affects-server', 'architectural-flaw', 'ente...       Bug
# 32170                                 ['bento', 'new-ui']       Bug
# 90649   ['affects-cloud', 'affects-server', 'editor', ...       Bug
# 41155   ['affects-cloud', 'affects-server', 'hedge', '...       Bug
#
#        collection                                           text_str  \
# 23484        Jira  I have reported this to support (Michelle De G...
# 102923       Jira  Hello,\n\nI am getting this error when I try t...
# 116207       Jira  Every time I use the Build History screen, thi...
# 70783        Jira  The Add bookmark page is vulnerable to XSS att...
# 104774       Jira  I can not add(get/remove) ssh-keys to users wi...
# ...           ...                                                ...
# 91747        Jira  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
# 14667        Jira  h3. Summary\r\n\r\nJIRA has no 'rate limiting'...
# 32170        Jira  h3.*Problem Definition*\r\n* All of a sudden, ...
# 90649        Jira  {panel:bgColor=#e7f4fa}\r\n  *NOTE:* This bug ...
# 41155        Jira  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
#
#                                                text_clean class_original  \
# 23484   i have reported this to support michelle de gu...           High
# 102923  helloi am getting this error when i try to pus...         Medium
# 116207  every time i use the build history screen this...            Low
# 70783   the add bookmark page is vulnerable to xss att...        Highest
# 104774  i can not addgetremove sshkeys to users with u...           High
# ...                                                   ...            ...
# 91747   note this bug report is for confluence cloud u...            Low
# 14667   summary jira has no rate limiting or mail limi...           High
# 32170   definition all of a sudden some users are unab...        Highest
# 90649   note this bug report is for confluence cloud u...            Low
# 41155   note this bug report is for jira cloud using j...            Low
#
#           class  label
# 23484   highest      1
# 102923     rest      0
# 116207     rest      0
# 70783   highest      1
# 104774  highest      1
# ...         ...    ...
# 91747      rest      0
# 14667   highest      1
# 32170   highest      1
# 90649      rest      0
# 41155      rest      0
#
# [28804 rows x 11 columns]

# %%
# Count label
balanced_data['label'].value_counts().to_frame()
# Out:
#        count
# label
# 1      14402
# 0      14402

# %%
# Count original class
balanced_data['class_original'].value_counts().to_frame()
# Out:
#                 count
# class_original
# High             9736
# Low              9189
# Medium           5213
# Highest          4666

# %%
# New df with only text clean and label
balanced_data = balanced_data[['text_clean', 'label']]
balanced_data
# Out:
#                                                text_clean  label
# 23484   i have reported this to support michelle de gu...      1
# 102923  helloi am getting this error when i try to pus...      0
# 116207  every time i use the build history screen this...      0
# 70783   the add bookmark page is vulnerable to xss att...      1
# 104774  i can not addgetremove sshkeys to users with u...      1
# ...                                                   ...    ...
# 91747   note this bug report is for confluence cloud u...      0
# 14667   summary jira has no rate limiting or mail limi...      1
# 32170   definition all of a sudden some users are unab...      1
# 90649   note this bug report is for confluence cloud u...      0
# 41155   note this bug report is for jira cloud using j...      0
#
# [28804 rows x 2 columns]

# %%
balanced_data.rename(columns={'text_clean': 'text'}, inplace=True)
balanced_data
# Out:
# /localscratch/585336/ipykernel_1302039/984652038.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   balanced_data.rename(columns={'text_clean': 'text'}, inplace=True)
#                                                      text  label
# 23484   i have reported this to support michelle de gu...      1
# 102923  helloi am getting this error when i try to pus...      0
# 116207  every time i use the build history screen this...      0
# 70783   the add bookmark page is vulnerable to xss att...      1
# 104774  i can not addgetremove sshkeys to users with u...      1
# ...                                                   ...    ...
# 91747   note this bug report is for confluence cloud u...      0
# 14667   summary jira has no rate limiting or mail limi...      1
# 32170   definition all of a sudden some users are unab...      1
# 90649   note this bug report is for confluence cloud u...      0
# 41155   note this bug report is for jira cloud using j...      0
#
# [28804 rows x 2 columns]

# %%
# Save to csv
out_path = "/fp/projects01/ec307/ec-krimhau/jira_datasets/high_highest_vs_rest"
full_file_name = f'{out_path}/jira_{file_name}_highest_high_vs_rest_balanced.csv'
balanced_data.to_csv(full_file_name, index=False)

# %%
# Read csv
df = pd.read_csv(full_file_name)
df
# Out:
#                                                     text  label
# 0      i have reported this to support michelle de gu...      1
# 1      helloi am getting this error when i try to pus...      0
# 2      every time i use the build history screen this...      0
# 3      the add bookmark page is vulnerable to xss att...      1
# 4      i can not addgetremove sshkeys to users with u...      1
# ...                                                  ...    ...
# 28799  note this bug report is for confluence cloud u...      0
# 28800  summary jira has no rate limiting or mail limi...      1
# 28801  definition all of a sudden some users are unab...      1
# 28802  note this bug report is for confluence cloud u...      0
# 28803  note this bug report is for jira cloud using j...      0
#
# [28804 rows x 2 columns]
