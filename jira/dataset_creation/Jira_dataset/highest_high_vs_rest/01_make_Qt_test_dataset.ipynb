# %% [markdown]
# # Create dataset: Highest vs rest (high, medium, low, lowest)
# * Under sampling the majority class.
# * 50/50 balance per class.

# %%
file_name = "clean_Qt"


file_path = "/fp/projects01/ec307/ec-krimhau/jira_datasets/testsets_clean"


import pandas as pd
# Import csv file

df = pd.read_csv(f'{file_path}/{file_name}.csv')
df
# Out:
#                      priority  \
# 0               P2: Important
# 1               P2: Important
# 2      P3: Somewhat important
# 3               P2: Important
# 4               P2: Important
# ...                       ...
# 99439           P2: Important
# 99440           P2: Important
# 99441           P2: Important
# 99442           P2: Important
# 99443            P1: Critical
#
#                                              description             project  \
# 0      While documentation projects can define custom...  Qt Project Website
# 1      Second cookie banner pop ups on top of the for...  Qt Project Website
# 2      Changing the 'Sort by criteria' in a doc.qt.io...  Qt Project Website
# 3      - open qt.io in Safari (Version 14.1.2 (16611....  Qt Project Website
# 4      I was reading  https://www.qt.io/blog/2019/01/...  Qt Project Website
# ...                                                  ...                 ...
# 99439  Running otool on the postgres and odbc plugins...                  Qt
# 99440  The application crashes when trying to record ...                  Qt
# 99441  When a Treeview is specified to fetch more row...                  Qt
# 99442  Hi,\r\n\r\nI'm attempting to build Qt 5.15 fro...                  Qt
# 99443  We can't keep up with fixing tests that fail o...                  Qt
#
#                                           labels issuetype collection  \
# 0                                             []       Bug         Qt
# 1                                             []      Task         Qt
# 2                                             []       Bug         Qt
# 3                                             []       Bug         Qt
# 4                                             []       Bug         Qt
# ...                                          ...       ...        ...
# 99439                                         []      Task         Qt
# 99440                                         []       Bug         Qt
# 99441           ['Reported_by_support_standard']       Bug         Qt
# 99442                                         []       Bug         Qt
# 99443  ['cmake_qt6', 'cmake_switch_requirement']      Task         Qt
#
#                                                 text_str  \
# 0      While documentation projects can define custom...
# 1      Second cookie banner pop ups on top of the for...
# 2      Changing the 'Sort by criteria' in a doc.qt.io...
# 3      - open qt.io in Safari (Version 14.1.2 (16611....
# 4      I was reading  https://www.qt.io/blog/2019/01/...
# ...                                                  ...
# 99439  Running otool on the postgres and odbc plugins...
# 99440  The application crashes when trying to record ...
# 99441  When a Treeview is specified to fetch more row...
# 99442  Hi,\r\n\r\nI'm attempting to build Qt 5.15 fro...
# 99443  We can't keep up with fixing tests that fail o...
#
#                                               text_clean
# 0      while documentation projects can define custom...
# 1      second cookie banner pop ups on top of the for...
# 2      changing the sort by criteria in a docqtio sea...
# 3      open qtio in safari version macos macbook pro ...
# 4      i was reading then i clicked on the search fie...
# ...                                                  ...
# 99439  running otool on the postgres and odbc plugins...
# 99440  the application crashes when trying to record ...
# 99441  when a treeview is specified to fetch more row...
# 99442  hi im attempting to build qt from sources for ...
# 99443  we cant keep up with fixing tests that fail on...
#
# [99444 rows x 8 columns]

# %%
# Count class
df['priority'].value_counts().to_frame()
# Out:
#                         count
# priority
# P2: Important           44089
# P3: Somewhat important  27348
# P1: Critical            17996
# P4: Low                  7165
# P0: Blocker              1943
# P5: Not important         903

# %%
# NaN values
df.isnull().sum()
# Out:
# priority        0
# description     0
# project         0
# labels          0
# issuetype       0
# collection      0
# text_str        0
# text_clean     33
# dtype: int64

# %%
# Drop NaN values
df = df.dropna()
df.isnull().sum()
# Out:
# priority       0
# description    0
# project        0
# labels         0
# issuetype      0
# collection     0
# text_str       0
# text_clean     0
# dtype: int64

# %%
# Count class
df['priority'].value_counts().to_frame()
# Out:
#                         count
# priority
# P2: Important           44078
# P3: Somewhat important  27342
# P1: Critical            17983
# P4: Low                  7164
# P0: Blocker              1941
# P5: Not important         903

# %%
# Unique collections
df['collection'].unique()
# Out:
# array(['Qt'], dtype=object)

# %%
# Unique projects
df['project'].unique().tolist()
# Out:
# ['Qt Project Website',
#  'Qt Quality Assurance Infrastructure',
#  'Qt',
#  'Qt Playground Projects',
#  'Qt Mobility',
#  'Qt for MCUs',
#  'Qt Bugtracking interface',
#  'Qt Installer Framework',
#  'Qt WebBrowser',
#  'Qt Visual Studio Tools',
#  'Qt Extensions',
#  'Qt Creator',
#  'Qt 3D Studio',
#  'Qt Safe Renderer',
#  'Qt Design Studio',
#  'Qbs ("Cubes")',
#  'Qt for Python',
#  'Coin',
#  'Qt Cloud',
#  'Qt Automotive Suite',
#  'Qt Solutions']

# %%
# Number of unique projects 
len(df['project'].unique())
# Out:
# 21

# %%
priority_mapping = {
    # Highest priority
    'P0: Blocker': 'Highest',
    'P1: Critical': 'High',
    'P2: Important': 'Medium',
    'P3: Somewhat important': 'Low',
    'P4: Low': 'Lowest',
    'P5: Not important': 'Lowest',

}
# Apply mapping
df['class'] = df['priority'].map(priority_mapping)
# Out:
# /localscratch/585336/ipykernel_1302954/3109083252.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['class'] = df['priority'].map(priority_mapping)

# %%
# Find the priorities that are not mapped to 'Highest' by checking for nulls in 'class'
unmapped_priorities = df[df['class'].isnull()]['priority'].unique()

if len(unmapped_priorities)  == 0:
    print("All priorities are mapped to a new class")
else:
    print("Priorities not mapped to a new class:")
    for priority in unmapped_priorities:
        print(f"- {priority}")
# Out:
# All priorities are mapped to a new class

# %%
# Count class
df['class'].value_counts().to_frame()
# Out:
#          count
# class
# Medium   44078
# Low      27342
# High     17983
# Lowest    8067
# Highest   1941

# %%
highest = df[df['class'] == 'Highest']
high = df[df['class'] == 'High']
medium = df[df['class'] == 'Medium']
low = df[df['class'] == 'Low']
lowest = df[df['class'] == 'Lowest']

# %%
highest_full = pd.concat([highest, high])
highest_full = highest_full.rename(columns={'class': 'class_original'})
highest_full["class"] = "highest" 
highest_full["label"] = 1
highest_full
# Out:
#            priority                                        description  \
# 37      P0: Blocker  Accessing http://download.qt.io from the Berli...
# 43      P0: Blocker  As per subject: patches are landing on git; th...
# 45      P0: Blocker  My QT update is too slow however speedtest sho...
# 55      P0: Blocker  I sent an email (from my [aacid@kde.org|mailto...
# 109     P0: Blocker  I've got a blank page after I log in with my u...
# ...             ...                                                ...
# 99428  P1: Critical  I had port my project from Desktop to Android ...
# 99430  P1: Critical  h3. Handling scaling factor changes during the...
# 99431  P1: Critical  Hello, my program will crash on some users' co...
# 99433  P1: Critical  When using the Material style on Android, if y...
# 99443  P1: Critical  We can't keep up with fixing tests that fail o...
#
#                   project                                             labels  \
# 37     Qt Project Website                                                 []
# 43     Qt Project Website                                                 []
# 45     Qt Project Website                                                 []
# 55     Qt Project Website                                                 []
# 109    Qt Project Website                                                 []
# ...                   ...                                                ...
# 99428                  Qt  ['Reported_by_support_standard', 'android_spec...
# 99430                  Qt                                                 []
# 99431                  Qt                                                 []
# 99433                  Qt         ['CandidateForScale', 'android_crash_bug']
# 99443                  Qt          ['cmake_qt6', 'cmake_switch_requirement']
#
#       issuetype collection                                           text_str  \
# 37          Bug         Qt  Accessing http://download.qt.io from the Berli...
# 43          Bug         Qt  As per subject: patches are landing on git; th...
# 45          Bug         Qt  My QT update is too slow however speedtest sho...
# 55          Bug         Qt  I sent an email (from my [aacid@kde.org|mailto...
# 109         Bug         Qt  I've got a blank page after I log in with my u...
# ...         ...        ...                                                ...
# 99428       Bug         Qt  I had port my project from Desktop to Android ...
# 99430       Bug         Qt  h3. Handling scaling factor changes during the...
# 99431       Bug         Qt  Hello, my program will crash on some users' co...
# 99433       Bug         Qt  When using the Material style on Android, if y...
# 99443      Task         Qt  We can't keep up with fixing tests that fail o...
#
#                                               text_clean class_original  \
# 37     accessing from the berlin office at least is v...        Highest
# 43     as per subject patches are landing on git the ...        Highest
# 45     my qt update is too slow however speedtest sho...        Highest
# 55     i sent an email from my address friday europea...        Highest
# 109    ive got a blank page after i log in with my us...        Highest
# ...                                                  ...            ...
# 99428  i had port my project from desktop to android ...           High
# 99430  handling scaling factor changes during the liv...           High
# 99431  hello my program will crash on some users comp...           High
# 99433  when using the material style on android if yo...           High
# 99443  we cant keep up with fixing tests that fail on...           High
#
#          class  label
# 37     highest      1
# 43     highest      1
# 45     highest      1
# 55     highest      1
# 109    highest      1
# ...        ...    ...
# 99428  highest      1
# 99430  highest      1
# 99431  highest      1
# 99433  highest      1
# 99443  highest      1
#
# [19924 rows x 11 columns]

# %%
# Concat all class except highest
rest = pd.concat([medium, low, lowest])
# Rename class to class_1
rest = rest.rename(columns={'class': 'class_original'})
rest["class"] = "rest" 
rest["label"] = 0
rest
# Out:
#                 priority                                        description  \
# 0          P2: Important  While documentation projects can define custom...
# 1          P2: Important  Second cookie banner pop ups on top of the for...
# 3          P2: Important  - open qt.io in Safari (Version 14.1.2 (16611....
# 4          P2: Important  I was reading  https://www.qt.io/blog/2019/01/...
# 6          P2: Important  From original issue:\r\n{quote}Mozilla publish...
# ...                  ...                                                ...
# 99208            P4: Low  In JS, "KeyboardEvent.code" is intended to ref...
# 99231  P5: Not important  In file _*qtbase/examples/widgets/itemviews/fr...
# 99243  P5: Not important  There is a problem with the code style\r\n\r\n...
# 99351            P4: Low  In  *_qtbase/src/3rdparty/libpng/png.c_*_,_  t...
# 99398            P4: Low  {code:c++}\r\n#include <QApplication>\r\n#incl...
#
#                   project labels    issuetype collection  \
# 0      Qt Project Website     []          Bug         Qt
# 1      Qt Project Website     []         Task         Qt
# 3      Qt Project Website     []          Bug         Qt
# 4      Qt Project Website     []          Bug         Qt
# 6      Qt Project Website     []  Improvement         Qt
# ...                   ...    ...          ...        ...
# 99208                  Qt     []          Bug         Qt
# 99231                  Qt     []          Bug         Qt
# 99243                  Qt     []          Bug         Qt
# 99351                  Qt     []          Bug         Qt
# 99398                  Qt     []          Bug         Qt
#
#                                                 text_str  \
# 0      While documentation projects can define custom...
# 1      Second cookie banner pop ups on top of the for...
# 3      - open qt.io in Safari (Version 14.1.2 (16611....
# 4      I was reading  https://www.qt.io/blog/2019/01/...
# 6      From original issue:\r\n{quote}Mozilla publish...
# ...                                                  ...
# 99208  In JS, "KeyboardEvent.code" is intended to ref...
# 99231  In file _*qtbase/examples/widgets/itemviews/fr...
# 99243  There is a problem with the code style\r\n\r\n...
# 99351  In  *_qtbase/src/3rdparty/libpng/png.c_*_,_  t...
# 99398  {code:c++}\r\n#include <QApplication>\r\n#incl...
#
#                                               text_clean class_original class  \
# 0      while documentation projects can define custom...         Medium  rest
# 1      second cookie banner pop ups on top of the for...         Medium  rest
# 3      open qtio in safari version macos macbook pro ...         Medium  rest
# 4      i was reading then i clicked on the search fie...         Medium  rest
# 6      from original issue quotemozilla published a t...         Medium  rest
# ...                                                  ...            ...   ...
# 99208  in js keyboardeventcode is intended to reflect...         Lowest  rest
# 99231  in file qtbaseexampleswidgetsitemviewsfrozenco...         Lowest  rest
# 99243             there is a problem with the code style         Lowest  rest
# 99351  in there is a line that reads written like thi...         Lowest  rest
# 99398  codec include include int mainint argc char ar...         Lowest  rest
#
#        label
# 0          0
# 1          0
# 3          0
# 4          0
# 6          0
# ...      ...
# 99208      0
# 99231      0
# 99243      0
# 99351      0
# 99398      0
#
# [79487 rows x 11 columns]

# %%
# Value count rest class
rest['class'].value_counts().to_frame()
# Out:
#        count
# class
# rest   79487

# %%
from sklearn.utils import shuffle
# Number of rows in the highest class
n_highest = highest_full.shape[0]

sampled = rest.sample(n=n_highest, random_state=42)  


balanced_data = pd.concat([highest_full, sampled])

# Shuffle the combined dataset
balanced_data = shuffle(balanced_data, random_state=42)
balanced_data
# Out:
#             priority                                        description  \
# 28211   P1: Critical  rename to QKeyboardDevice\r\nremove protected ...
# 62279  P2: Important  Right now the system language is used, which i...
# 36370   P1: Critical  The entries in the main menu are too wide. See...
# 12101  P2: Important  Hi Team,\r\n\r\nWe are moving to Qt framework ...
# 29956  P2: Important  Jira have wrong timezones. From example: Jira ...
# ...              ...                                                ...
# 19612   P1: Critical  The documentation of the macextras module say ...
# 47370   P1: Critical  Using qt-everywhere-opensource-src-4.8.3.tar.g...
# 9040   P2: Important  I have two components:\r\n * a QML app that co...
# 34382    P0: Blocker  It seems every example in the dev branch curre...
# 78947   P1: Critical  I create a new project via a wizard, open a qm...
#
#                         project  \
# 28211                        Qt
# 62279                        Qt
# 36370                        Qt
# 12101                        Qt
# 29956  Qt Bugtracking interface
# ...                         ...
# 19612                        Qt
# 47370                        Qt
# 9040                         Qt
# 34382                        Qt
# 78947                Qt Creator
#
#                                               labels issuetype collection  \
# 28211  ['Qt3D-2.0-Release', 'Qt3D_API_Review_Feb16']      Task         Qt
# 62279                                             []      Task         Qt
# 36370                                             []       Bug         Qt
# 12101                                             []      Task         Qt
# 29956                                             []       Bug         Qt
# ...                                              ...       ...        ...
# 19612                                             []       Bug         Qt
# 47370                                             []       Bug         Qt
# 9040                                              []       Bug         Qt
# 34382                                             []       Bug         Qt
# 78947                                             []       Bug         Qt
#
#                                                 text_str  \
# 28211  rename to QKeyboardDevice\r\nremove protected ...
# 62279  Right now the system language is used, which i...
# 36370  The entries in the main menu are too wide. See...
# 12101  Hi Team,\r\n\r\nWe are moving to Qt framework ...
# 29956  Jira have wrong timezones. From example: Jira ...
# ...                                                  ...
# 19612  The documentation of the macextras module say ...
# 47370  Using qt-everywhere-opensource-src-4.8.3.tar.g...
# 9040   I have two components:\r\n * a QML app that co...
# 34382  It seems every example in the dev branch curre...
# 78947  I create a new project via a wizard, open a qm...
#
#                                               text_clean class_original  \
# 28211  rename to qkeyboarddevice remove protected cto...           High
# 62279  right now the system language is used which is...         Medium
# 36370  the entries in the main menu are too wide see ...           High
# 12101  hi team we are moving to qt framework for our ...         Medium
# 29956  jira have wrong timezones from example jira th...         Medium
# ...                                                  ...            ...
# 19612  the documentation of the macextras module say ...           High
# 47370  using we are unable to build qt dlls qtcore qt...           High
# 9040   i have two components a qml app that contains ...         Medium
# 34382  it seems every example in the dev branch curre...        Highest
# 78947  i create a new project via a wizard open a qml...           High
#
#          class  label
# 28211  highest      1
# 62279     rest      0
# 36370  highest      1
# 12101     rest      0
# 29956     rest      0
# ...        ...    ...
# 19612  highest      1
# 47370  highest      1
# 9040      rest      0
# 34382  highest      1
# 78947  highest      1
#
# [39848 rows x 11 columns]

# %%
balanced_data['class'].value_counts().to_frame()
# Out:
#          count
# class
# highest  19924
# rest     19924

# %%
balanced_data
# Out:
#             priority                                        description  \
# 28211   P1: Critical  rename to QKeyboardDevice\r\nremove protected ...
# 62279  P2: Important  Right now the system language is used, which i...
# 36370   P1: Critical  The entries in the main menu are too wide. See...
# 12101  P2: Important  Hi Team,\r\n\r\nWe are moving to Qt framework ...
# 29956  P2: Important  Jira have wrong timezones. From example: Jira ...
# ...              ...                                                ...
# 19612   P1: Critical  The documentation of the macextras module say ...
# 47370   P1: Critical  Using qt-everywhere-opensource-src-4.8.3.tar.g...
# 9040   P2: Important  I have two components:\r\n * a QML app that co...
# 34382    P0: Blocker  It seems every example in the dev branch curre...
# 78947   P1: Critical  I create a new project via a wizard, open a qm...
#
#                         project  \
# 28211                        Qt
# 62279                        Qt
# 36370                        Qt
# 12101                        Qt
# 29956  Qt Bugtracking interface
# ...                         ...
# 19612                        Qt
# 47370                        Qt
# 9040                         Qt
# 34382                        Qt
# 78947                Qt Creator
#
#                                               labels issuetype collection  \
# 28211  ['Qt3D-2.0-Release', 'Qt3D_API_Review_Feb16']      Task         Qt
# 62279                                             []      Task         Qt
# 36370                                             []       Bug         Qt
# 12101                                             []      Task         Qt
# 29956                                             []       Bug         Qt
# ...                                              ...       ...        ...
# 19612                                             []       Bug         Qt
# 47370                                             []       Bug         Qt
# 9040                                              []       Bug         Qt
# 34382                                             []       Bug         Qt
# 78947                                             []       Bug         Qt
#
#                                                 text_str  \
# 28211  rename to QKeyboardDevice\r\nremove protected ...
# 62279  Right now the system language is used, which i...
# 36370  The entries in the main menu are too wide. See...
# 12101  Hi Team,\r\n\r\nWe are moving to Qt framework ...
# 29956  Jira have wrong timezones. From example: Jira ...
# ...                                                  ...
# 19612  The documentation of the macextras module say ...
# 47370  Using qt-everywhere-opensource-src-4.8.3.tar.g...
# 9040   I have two components:\r\n * a QML app that co...
# 34382  It seems every example in the dev branch curre...
# 78947  I create a new project via a wizard, open a qm...
#
#                                               text_clean class_original  \
# 28211  rename to qkeyboarddevice remove protected cto...           High
# 62279  right now the system language is used which is...         Medium
# 36370  the entries in the main menu are too wide see ...           High
# 12101  hi team we are moving to qt framework for our ...         Medium
# 29956  jira have wrong timezones from example jira th...         Medium
# ...                                                  ...            ...
# 19612  the documentation of the macextras module say ...           High
# 47370  using we are unable to build qt dlls qtcore qt...           High
# 9040   i have two components a qml app that contains ...         Medium
# 34382  it seems every example in the dev branch curre...        Highest
# 78947  i create a new project via a wizard open a qml...           High
#
#          class  label
# 28211  highest      1
# 62279     rest      0
# 36370  highest      1
# 12101     rest      0
# 29956     rest      0
# ...        ...    ...
# 19612  highest      1
# 47370  highest      1
# 9040      rest      0
# 34382  highest      1
# 78947  highest      1
#
# [39848 rows x 11 columns]

# %%
# Count label
balanced_data['label'].value_counts().to_frame()
# Out:
#        count
# label
# 1      19924
# 0      19924

# %%
# Count original class
balanced_data['class_original'].value_counts().to_frame()
# Out:
#                 count
# class_original
# High            17983
# Medium          11091
# Low              6786
# Lowest           2047
# Highest          1941

# %%
# New df with only text clean and label
balanced_data = balanced_data[['text_clean', 'label']]
balanced_data
# Out:
#                                               text_clean  label
# 28211  rename to qkeyboarddevice remove protected cto...      1
# 62279  right now the system language is used which is...      0
# 36370  the entries in the main menu are too wide see ...      1
# 12101  hi team we are moving to qt framework for our ...      0
# 29956  jira have wrong timezones from example jira th...      0
# ...                                                  ...    ...
# 19612  the documentation of the macextras module say ...      1
# 47370  using we are unable to build qt dlls qtcore qt...      1
# 9040   i have two components a qml app that contains ...      0
# 34382  it seems every example in the dev branch curre...      1
# 78947  i create a new project via a wizard open a qml...      1
#
# [39848 rows x 2 columns]

# %%
balanced_data.rename(columns={'text_clean': 'text'}, inplace=True)
balanced_data
# Out:
# /localscratch/585336/ipykernel_1302954/984652038.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   balanced_data.rename(columns={'text_clean': 'text'}, inplace=True)
#                                                     text  label
# 28211  rename to qkeyboarddevice remove protected cto...      1
# 62279  right now the system language is used which is...      0
# 36370  the entries in the main menu are too wide see ...      1
# 12101  hi team we are moving to qt framework for our ...      0
# 29956  jira have wrong timezones from example jira th...      0
# ...                                                  ...    ...
# 19612  the documentation of the macextras module say ...      1
# 47370  using we are unable to build qt dlls qtcore qt...      1
# 9040   i have two components a qml app that contains ...      0
# 34382  it seems every example in the dev branch curre...      1
# 78947  i create a new project via a wizard open a qml...      1
#
# [39848 rows x 2 columns]

# %%
# Save to csv
out_path = "/fp/projects01/ec307/ec-krimhau/jira_datasets/high_highest_vs_rest"
full_file_name = f'{out_path}/jira_{file_name}_highest_high_vs_rest_balanced.csv'
balanced_data.to_csv(full_file_name, index=False)

# %%
# Read csv
df = pd.read_csv(full_file_name)
df
# Out:
#                                                     text  label
# 0      rename to qkeyboarddevice remove protected cto...      1
# 1      right now the system language is used which is...      0
# 2      the entries in the main menu are too wide see ...      1
# 3      hi team we are moving to qt framework for our ...      0
# 4      jira have wrong timezones from example jira th...      0
# ...                                                  ...    ...
# 39843  the documentation of the macextras module say ...      1
# 39844  using we are unable to build qt dlls qtcore qt...      1
# 39845  i have two components a qml app that contains ...      0
# 39846  it seems every example in the dev branch curre...      1
# 39847  i create a new project via a wizard open a qml...      1
#
# [39848 rows x 2 columns]
