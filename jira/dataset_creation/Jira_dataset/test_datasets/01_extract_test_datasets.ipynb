# %% [markdown]
# # Extract Jira test datasets
# This notebook will extract test datasets from the Public Jira dataset.
# Following dataset can be used for testing:
# * MongoDB:
#
# Jira repos used to train the model:
# * Spring
# * RedHat
# * Sakai
# * JiraEcosystem
# * Jira
# * Hyperledger
# * Apache
# * SecondLife
# * Mojang
# * Qt
# * JFrog
# * IntelDAOS
# * Mindville
# * Sonatype

# %%
import pandas as pd
df = pd.read_csv("../all_priority_group_in_classes.csv")
df
# Out:
#         priority                                        description  \
# 0        Blocker  We tried upgrading from Spring Boot 2.0.6 to S...
# 1          Major  The jobs that appear under Executions section ...
# 2        Trivial  Working with Spring-XD version 1.3.2.RELEASE\n...
# 3          Major  My project 7 node cluster and in that 2 node a...
# 4          Minor  See https://github.com/spring-projects/spring-...
# ...          ...                                                ...
# 2000661    Major                              it is very beautiful.
# 2000662    Major                                            library
# 2000663    Major  What is reactive-gremlin\r\n\r\nreactive-greml...
# 2000664    Major    Android view for a swipeable, weekly calendar.
# 2000665    Major  Beetlmvc is a web framework, which can support...
#
#                                                    project            labels  \
# ...

# %%
# Unique projects used to train the model.
df['collection'].unique()
# Out:
# array(['Spring', 'RedHat', 'Sakai', 'JiraEcosystem', 'Jira',
#        'Hyperledger', 'Apache', 'SecondLife', 'MongoDB', 'Mojang', 'Qt',
#        'JFrog', 'IntelDAOS', 'Mindville', 'Sonatype'], dtype=object)
