# %% [markdown]
# # Create dataset: Highest vs rest (high, medium, low, lowest)
# * Under sampling the majority class.
# * 50/50 balance per class.

# %%
file_path = '/fp/projects01/ec307/ec-krimhau/jira_datasets'
file_name = 'jira_clean_with_all_cols.csv'
full_path = f"{file_path}/{file_name}"

# %%
import pandas as pd
# Import csv file
df = pd.read_csv(full_path)
df
# Out:
#         priority                                        description  \
# 0        Blocker  We tried upgrading from Spring Boot 2.0.6 to S...
# 1          Major  The jobs that appear under Executions section ...
# 2        Trivial  Working with Spring-XD version 1.3.2.RELEASE\n...
# 3          Major  My project 7 node cluster and in that 2 node a...
# 4          Minor  See https://github.com/spring-projects/spring-...
# ...          ...                                                ...
# 1404240    Major                              it is very beautiful.
# 1404241    Major                                            library
# 1404242    Major  What is reactive-gremlin\r\n\r\nreactive-greml...
# 1404243    Major    Android view for a swipeable, weekly calendar.
# 1404244    Major  Beetlmvc is a web framework, which can support...
#
#                                                    project            labels  \
# 0                                                Spring XD                []
# 1                                                Spring XD                []
# 2                                                Spring XD                []
# 3                                                Spring XD  ['Spring', 'xd']
# 4                                                Spring XD                []
# ...                                                    ...               ...
# 1404240  Community Support - Open Source Project Reposi...                []
# 1404241  Community Support - Open Source Project Reposi...                []
# 1404242  Community Support - Open Source Project Reposi...                []
# 1404243  Community Support - Open Source Project Reposi...                []
# 1404244  Community Support - Open Source Project Reposi...                []
#
#            issuetype collection    class  \
# 0                Bug     Spring  Highest
# 1                Bug     Spring   Medium
# 2                Bug     Spring   Lowest
# 3                Bug     Spring   Medium
# 4              Story     Spring      Low
# ...              ...        ...      ...
# 1404240  New Project   Sonatype   Medium
# 1404241  New Project   Sonatype   Medium
# 1404242  New Project   Sonatype   Medium
# 1404243  New Project   Sonatype   Medium
# 1404244  New Project   Sonatype   Medium
#
#                                                   text_str  \
# 0        We tried upgrading from Spring Boot 2.0.6 to S...
# 1        The jobs that appear under Executions section ...
# 2        Working with Spring-XD version 1.3.2.RELEASE\n...
# 3        My project 7 node cluster and in that 2 node a...
# 4        See https://github.com/spring-projects/spring-...
# ...                                                    ...
# 1404240                              it is very beautiful.
# 1404241                                            library
# 1404242  What is reactive-gremlin\r\n\r\nreactive-greml...
# 1404243    Android view for a swipeable, weekly calendar.
# 1404244  Beetlmvc is a web framework, which can support...
#
#                                                 text_clean
# 0        we tried upgrading from spring boot to spring ...
# 1        the jobs that appear under executions section ...
# 2        working with springxd version the server with ...
# 3        my project node cluster and in that node are a...
# 4                                                      NaN
# ...                                                    ...
# 1404240                               it is very beautiful
# 1404241                                                NaN
# 1404242  what is reactivegremlin reactivegremlin is a s...
# 1404243       android view for a swipeable weekly calendar
# 1404244  beetlmvc is a web framework which can support ...
#
# [1404245 rows x 9 columns]

# %%
# Count class
df['class'].value_counts().to_frame()
# Out:
#           count
# class
# Medium   960459
# Low      271629
# High      82646
# Highest   56220
# Lowest    33291

# %%
# NaN values
df.isnull().sum()
# Out:
# priority           0
# description        0
# project            0
# labels             0
# issuetype          0
# collection         0
# class              0
# text_str           0
# text_clean     34264
# dtype: int64

# %%
# Drop NaN values
df = df.dropna()
df.isnull().sum()
# Out:
# priority       0
# description    0
# project        0
# labels         0
# issuetype      0
# collection     0
# class          0
# text_str       0
# text_clean     0
# dtype: int64

# %%
# Count class
df['class'].value_counts().to_frame()
# Out:
#           count
# class
# Medium   933029
# Low      267697
# High      81404
# Highest   55358
# Lowest    32493

# %%
# Unique collections
df['collection'].unique()
# Out:
# array(['Spring', 'RedHat', 'Sakai', 'JiraEcosystem', 'Hyperledger',
#        'Apache', 'SecondLife', 'IntelDAOS', 'Mindville', 'Sonatype'],
#       dtype=object)

# %%
# make df with class and text_clean
df = df[['class', 'text_clean']]
df
# Out:
#            class                                         text_clean
# 0        Highest  we tried upgrading from spring boot to spring ...
# 1         Medium  the jobs that appear under executions section ...
# 2         Lowest  working with springxd version the server with ...
# 3         Medium  my project node cluster and in that node are a...
# 5         Medium  im trying to run a job on springxd and the job...
# ...          ...                                                ...
# 1404239   Medium  simple android lib for pushing little messages...
# 1404240   Medium                               it is very beautiful
# 1404242   Medium  what is reactivegremlin reactivegremlin is a s...
# 1404243   Medium       android view for a swipeable weekly calendar
# 1404244   Medium  beetlmvc is a web framework which can support ...
#
# [1369981 rows x 2 columns]

# %%
highest = df[df['class'] == 'Highest']
highest["class_original"] = "Highest"
high = df[df['class'] == 'High']
high["class_original"]= 'High'
medium = df[df['class'] == 'Medium']
low = df[df['class'] == 'Low']
lowest = df[df['class'] == 'Lowest']
# Out:
# /localscratch/583344/ipykernel_526153/1603564074.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["class_original"] = "Highest"
# /localscratch/583344/ipykernel_526153/1603564074.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high["class_original"]= 'High'

# %%
highest = pd.concat([highest,high])
highest["label"] = 1
highest["class"] = "Highest"
highest
# Out:
#            class                                         text_clean  \
# 0        Highest  we tried upgrading from spring boot to spring ...
# 13       Highest  i download the spring xd example projects and ...
# 197      Highest  several issues with staged version we now use ...
# 366      Highest  building and then running springclouddatarest ...
# 510      Highest  the abstractannotationmethodendpointmapping lo...
# ...          ...                                                ...
# 1402237  Highest  we have error on when we tried to close stagin...
# 1403170  Highest  hi ive released some artifacts via the usual s...
# 1403304  Highest  yesterday i released artifacts under group nam...
# 1403530  Highest  below is the error i got while running my proj...
# 1404022  Highest  i cant release this repository forbidden error...
#
#         class_original  label
# 0              Highest      1
# 13             Highest      1
# 197            Highest      1
# 366            Highest      1
# 510            Highest      1
# ...                ...    ...
# 1402237           High      1
# 1403170           High      1
# 1403304           High      1
# 1403530           High      1
# 1404022           High      1
#
# [136762 rows x 4 columns]

# %%
# Concat all class except highest and high
rest = pd.concat([low,lowest])
# Rename class to class_1
rest = rest.rename(columns={'class': 'class_original'})
rest["class"] = "rest" 
rest["label"] = 0
rest
# Out:
#         class_original                                         text_clean  \
# 9                  Low  hiim using ldap to a windows active directory ...
# 10                 Low  more details in the support ticket following e...
# 11                 Low  i unzip to replace the existing clear my brows...
# 14                 Low  codexdmodule compose foo definition time expre...
# 16                 Low  the mapreduce samples should have yarnresource...
# ...                ...                                                ...
# 1398225         Lowest  please close this issue i apologize everything...
# 1401002         Lowest  following dependencies are not yet ready i alr...
# 1402620         Lowest  requesting access to orggrails to be able to s...
# 1403176         Lowest  im releasing my artifacts for the first time i...
# 1403679         Lowest  hi i currently face an unauthorized exception ...
#
#         class  label
# 9        rest      0
# 10       rest      0
# 11       rest      0
# 14       rest      0
# 16       rest      0
# ...       ...    ...
# 1398225  rest      0
# 1401002  rest      0
# 1402620  rest      0
# 1403176  rest      0
# 1403679  rest      0
#
# [300190 rows x 4 columns]

# %%
# Value count rest class
rest['class_original'].value_counts().to_frame()
# Out:
#                  count
# class_original
# Low             267697
# Lowest           32493

# %%
from sklearn.utils import shuffle
# Number of rows in the highest class
n_highest =  highest.shape[0]

rest_sampled = rest.sample(n=n_highest, random_state=42)  


balanced_data = pd.concat([highest, rest_sampled])

# Shuffle the combined dataset
balanced_data = shuffle(balanced_data, random_state=42)
balanced_data
# Out:
#            class                                         text_clean  \
# 255633   Highest  we need to bump the version to example image e...
# 176892   Highest  right now it is almost impossible to create se...
# 169534      rest  this is a followup of which contained two issu...
# 282421   Highest  create a maven assembly to produce a zip file ...
# 60425       rest  suggestion slack bot that runs upstream should...
# ...          ...                                                ...
# 951370   Highest  noformatnopaneltrueexternalstestspy fileextern...
# 1249105     rest  when you browse the mbeans in jconsole both ac...
# 1271664  Highest  after creating new instance from bare karaf in...
# 1168234     rest  im writing a method which is not existing yet ...
# 1002076  Highest  pagerank input runs very slow and eventually f...
#
#         class_original  label
# 255633         Highest      1
# 176892            High      1
# 169534             Low      0
# 282421            High      1
# 60425              Low      0
# ...                ...    ...
# 951370            High      1
# 1249105         Lowest      0
# 1271664           High      1
# 1168234            Low      0
# 1002076           High      1
#
# [273524 rows x 4 columns]

# %%
balanced_data['class'].value_counts().to_frame()
# Out:
#           count
# class
# Highest  136762
# rest     136762

# %%
balanced_data
# Out:
#            class                                         text_clean  \
# 255633   Highest  we need to bump the version to example image e...
# 176892   Highest  right now it is almost impossible to create se...
# 169534      rest  this is a followup of which contained two issu...
# 282421   Highest  create a maven assembly to produce a zip file ...
# 60425       rest  suggestion slack bot that runs upstream should...
# ...          ...                                                ...
# 951370   Highest  noformatnopaneltrueexternalstestspy fileextern...
# 1249105     rest  when you browse the mbeans in jconsole both ac...
# 1271664  Highest  after creating new instance from bare karaf in...
# 1168234     rest  im writing a method which is not existing yet ...
# 1002076  Highest  pagerank input runs very slow and eventually f...
#
#         class_original  label
# 255633         Highest      1
# 176892            High      1
# 169534             Low      0
# 282421            High      1
# 60425              Low      0
# ...                ...    ...
# 951370            High      1
# 1249105         Lowest      0
# 1271664           High      1
# 1168234            Low      0
# 1002076           High      1
#
# [273524 rows x 4 columns]

# %%
# Count label
balanced_data['label'].value_counts().to_frame()
# Out:
#         count
# label
# 1      136762
# 0      136762

# %%
# Count original class
balanced_data['class_original'].value_counts().to_frame()
# Out:
#                  count
# class_original
# Low             122041
# High             81404
# Highest          55358
# Lowest           14721

# %%
balanced_data = balanced_data[['label', 'text_clean']]
balanced_data = balanced_data.rename(columns={'text_clean': 'text'})
balanced_data
# Out:
#          label                                               text
# 255633       1  we need to bump the version to example image e...
# 176892       1  right now it is almost impossible to create se...
# 169534       0  this is a followup of which contained two issu...
# 282421       1  create a maven assembly to produce a zip file ...
# 60425        0  suggestion slack bot that runs upstream should...
# ...        ...                                                ...
# 951370       1  noformatnopaneltrueexternalstestspy fileextern...
# 1249105      0  when you browse the mbeans in jconsole both ac...
# 1271664      1  after creating new instance from bare karaf in...
# 1168234      0  im writing a method which is not existing yet ...
# 1002076      1  pagerank input runs very slow and eventually f...
#
# [273524 rows x 2 columns]

# %%
out_path = '/fp/projects01/ec307/ec-krimhau/jira_datasets/highest_high_vs_low_lowest_balanced_jira.csv'

# %%
# Save to csv
balanced_data.to_csv(out_path, index=False)

# %%
# Read csv
df = pd.read_csv(out_path)

# %%
df
# Out:
#         label                                               text
# 0           1  we need to bump the version to example image e...
# 1           1  right now it is almost impossible to create se...
# 2           0  this is a followup of which contained two issu...
# 3           1  create a maven assembly to produce a zip file ...
# 4           0  suggestion slack bot that runs upstream should...
# ...       ...                                                ...
# 273519      1  noformatnopaneltrueexternalstestspy fileextern...
# 273520      0  when you browse the mbeans in jconsole both ac...
# 273521      1  after creating new instance from bare karaf in...
# 273522      0  im writing a method which is not existing yet ...
# 273523      1  pagerank input runs very slow and eventually f...
#
# [273524 rows x 2 columns]
