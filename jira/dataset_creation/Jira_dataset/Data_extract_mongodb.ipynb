# %% [markdown]
# # Extract data from public Jira data
# * This notebook will extract data from the public jira dataset
# * The dataset is stored in mongoDB.
# * mongoDB must be installed and running on your system.

# %% [markdown]
# For more details refer to
#  https://zenodo.org/record/5901956

# %% [markdown]
# Command used to export the data (this command takes about 15 minutes to complete).
#
# `mongodump --db=JiraRepos --gzip --archive=mongodump-JiraRepos.archive`
#
# Accompanying command to restore the data (this command takes about 15 minutes to complete). Expanded, this data is ~60GB inside MongoDB.
#
# `mongorestore --gzip --archive=mongodump-JiraRepos.archive --nsFrom "JiraRepos.*" --nsTo "JiraRepos.*"`
#
# Change the `--nsTo` command to contain the desired name for the JiraRepos database.
# mongorestore --gzip --archive=mongodump-JiraRepos.archive --nsFrom "JiraRepos.*" --nsTo "JiraRepos.Apache"
#
#
# For more information see: https://docs.mongodb.com/manual/tutorial/backup-and-restore-tools/

# %% [markdown]
# Jira Dataset for TD filtered was extracted from https://zenodo.org/record/5901956  (https://arxiv.org/pdf/2201.08368.pdf) and adapted
#
# Montgomery, Lloyd, Lüders, Clara, & Maalej, Prof. Dr. Walid. (2022). The Public Jira Dataset [Data set]. Zenodo. https://doi.org/10.5281/zenodo.5901956

# %%
import pymongo
# Default connection to localhost
myclient = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
mydb = myclient["JiraRepos"]
mydb
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'JiraRepos')

# %%
collist = mydb.list_collection_names()
collist
# Out:
# ['Spring',
#  'RedHat',
#  'Sakai',
#  'JiraEcosystem',
#  'Jira',
#  'Hyperledger',
#  'Apache',
#  'SecondLife',
#  'MariaDB',
#  'MongoDB',
#  'Mojang',
#  'Qt',
#  'JFrog',
#  'IntelDAOS',
#  'Mindville',
#  'Sonatype']

# %%
# Name of the collection to extract
collection_name = 'Qt'

# %%
import pymongo as pm
import pandas as pd
import os

CHUNK_SIZE = 500
client = pm.MongoClient()
coll = client.get_database('JiraRepos').get_collection(collection_name)
cursor = coll.find({}, batch_size=CHUNK_SIZE)

# Count total documents and calculate total chunks
total_docs = coll.count_documents({})
total_chunks = (total_docs + CHUNK_SIZE - 1) // CHUNK_SIZE  # Rounds up the division

def yield_rows(cursor, chunk_size):
    """
    Generator to yield chunks from cursor
    :param cursor:
    :param chunk_size:
    :return:
    """
    chunk = []
    for i, row in enumerate(cursor):
        if i % chunk_size == 0 and i > 0:
            yield chunk
            del chunk[:]
        chunk.append(row)
    yield chunk

# Define the columns you wish to extract
desired_columns = [
    "id", 
    "fields.project.name", 
    "fields.priority.name", 
    "fields.created", 
    "fields.labels", 
    "fields.summary", 
    "fields.description", 
    "fields.status.name",
    "fields.status.description", 
    "fields.issuetype.name", 
    "fields.issuetype.description", 
    "fields.issuetype.subtask", 
    "fields.comments"
]

# Ensure the directory exists
os.makedirs("dataset_dump/" + collection_name, exist_ok=True)

chunks = yield_rows(cursor, CHUNK_SIZE)

# Initialize chunk counter
chunk_counter = 0

for chunk in chunks:
    chunk_counter += 1  # Increment the chunk counter
    df = pd.json_normalize(chunk, errors='ignore')
    
    # Select only the columns that exist in the DataFrame
    available_columns = [col for col in desired_columns if col in df.columns]
lib/python3.11/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 13.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(
# <dask_expr.expr.DataFrame: expr=ReadCSV(1a95163)>

# %%
df = df.compute()

# %%
df
# Out:
#          id fields.project.name    fields.priority.name  \
# 0    348468  Qt Project Website           P2: Important
# 1    331989  Qt Project Website           P2: Important
# 2    331192  Qt Project Website  P3: Somewhat important
# 3    331155  Qt Project Website           Not Evaluated
# 4    330942  Qt Project Website           Not Evaluated
# ..      ...                 ...                     ...
# 495  301329                  Qt           P2: Important
# 496  301328                  Qt           Not Evaluated
# 497  301327                  Qt           P2: Important
# 498  301326                  Qt           P2: Important
# 499  301313                  Qt            P1: Critical
#
#                    fields.created                              fields.labels  \
# 0    2022-01-04T08:51:51.000+0000                                         []
# 1    2021-12-16T11:55:21.000+0000                                         []
# 2    2021-12-06T08:00:42.000+0000                                         []
# 3    2021-12-03T16:50:53.000+0000                                         []
# 4    2021-12-01T12:19:21.000+0000                                         []
# ..                            ...                                        ...
# 495  2020-07-01T12:03:13.000+0000                                         []
# 496  2020-07-01T11:51:59.000+0000           ['Reported_by_support_standard']
# 497  2020-07-01T11:11:14.000+0000           ['Reported_by_support_standard']
# 498  2020-07-01T11:00:14.000+0000                                         []
# 499  2020-07-01T08:43:56.000+0000  ['cmake_qt6', 'cmake_switch_requirement']
#
#                                         fields.summary  \
# 0    Custom css is not usable in published document...
# 1                                 Second Cookie banner
# 2    doc.qt.io search: Changing Sort by criterium a...
# 3              planet.qt.io did not fetch my last post
# 4    .sha256 virtual files are missing for qt 6.2.2...
# ..                                                 ...
# 495  Unable to record more than one video on Raspbe...
# 496  QQC2 AbstractButton.display: add option to sel...
# 497  QTreeView: FetchMore is not getting called for...
# 498  Select SDK and XCode for Build Qt from sources...
# 499  Skip or ignore remaining failing tests in CMak...
#
#                                     fields.description fields.status.name  \
# 0    While documentation projects can define custom...               Open
# 1    Second cookie banner pop ups on top of the for...               Open
# 2    Changing the 'Sort by criteria' in a doc.qt.io...               Open
# 3    Hi, I did a day ago a new post on cutelyst.org...               Open
# 4    missing\r\nhttps://download.qt.io/official_rel...             Closed
# ..                                                 ...                ...
# 495  The application crashes when trying to record ...             Closed
# 496  Currently seems like the only option to edit o...           Reported
# 497  When a Treeview is specified to fetch more row...             Closed
# 498  Hi,\r\n\r\nI'm attempting to build Qt 5.15 fro...             Closed
# 499  We can't keep up with fixing tests that fail o...             Closed
#
#                              fields.status.description fields.issuetype.name  \
# 0    The issue is open and ready for the assignee t...                   Bug
# 1    The issue is open and ready for the assignee t...                  Task
# 2    The issue is open and ready for the assignee t...                   Bug
# 3    The issue is open and ready for the assignee t...                   Bug
# 4    The issue is considered finished, the resoluti...                   Bug
# ..                                                 ...                   ...
# 495  The issue is considered finished, the resoluti...                   Bug
# 496  The issue has been reported, but no validation...            Suggestion
# 497  The issue is considered finished, the resoluti...                   Bug
# 498  The issue is considered finished, the resoluti...                   Bug
# 499  The issue is considered finished, the resoluti...                  Task
#
#                           fields.issuetype.description  \
# 0    A problem which impairs or prevents the functi...
# 1                        A task that needs to be done.
# 2    A problem which impairs or prevents the functi...
# 3    A problem which impairs or prevents the functi...
# 4    A problem which impairs or prevents the functi...
# ..                                                 ...
# 495  A problem which impairs or prevents the functi...
# 496                                 Public suggestions
# 497  A problem which impairs or prevents the functi...
# 498  A problem which impairs or prevents the functi...
# 499                      A task that needs to be done.
#
#      fields.issuetype.subtask  \
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ..                        ...
# 495                     False
# 496                     False
# 497                     False
# 498                     False
# 499                     False
#
#                                        fields.comments
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3    [{'self': 'https://bugreports.qt.io/rest/api/2...
# 4    [{'self': 'https://bugreports.qt.io/rest/api/2...
# ..                                                 ...
# 495  [{'self': 'https://bugreports.qt.io/rest/api/2...
# 496                                                 []
# 497  [{'self': 'https://bugreports.qt.io/rest/api/2...
# 498  [{'self': 'https://bugreports.qt.io/rest/api/2...
# 499  [{'self': 'https://bugreports.qt.io/rest/api/2...
#
# [148579 rows x 13 columns]

# %%
df["fields.priority.name"].value_counts().to_frame()[:50]
# Out:
#                         count
# fields.priority.name
# P2: Important           46926
# Not Evaluated           42453
# P3: Somewhat important  28075
# P1: Critical            20750
# P4: Low                  7375
# P0: Blocker              2050
# P5: Not important         935

# %%
df["fields.issuetype.name"].value_counts().to_frame()[:50]
# Out:
#                         count
# fields.issuetype.name
# Bug                    106804
# Suggestion              15723
# Task                    12015
# Technical task           4830
# Sub-task                 4792
# User Story               3401
# Epic                      793
# Change Request            209
# Improvement                11
# Research                    1

# %%
df["fields.project.name"].value_counts().to_frame()[:50]
# Out:
#                                      count
# fields.project.name
# Qt                                   97172
# Qt Creator                           25249
# Qt Design Studio                      4619
# Qt Quality Assurance Infrastructure   4169
# Qt 3D Studio                          4092
# Qt Installer Framework                2178
# Qt Mobility                           1926
# Qbs ("Cubes")                         1634
# Qt for Python                         1595
# Qt Automotive Suite                   1521
# Qt Safe Renderer                      1248
# Qt Visual Studio Tools                 967
# Qt Project Website                     787
# Coin                                   699
# Qt Bugtracking interface               315
# Qt Solutions                           196
# Qt Cloud                                82
# Qt for MCUs                             62
# Qt WebBrowser                           34
# Qt Playground Projects                  20
# Qt Extensions                           14

# %%
# Number of different projects
df["fields.project.name"].nunique()
# Out:
# 21

# %%
# To csv 
df.to_csv(f'final_dataset/{collection_name}.csv', index=False)

# %%
# read csv
df1 = pd.read_csv(f'final_dataset/{collection_name}.csv')     
df1
# Out:
#             id fields.project.name    fields.priority.name  \
# 0       348468  Qt Project Website           P2: Important
# 1       331989  Qt Project Website           P2: Important
# 2       331192  Qt Project Website  P3: Somewhat important
# 3       331155  Qt Project Website           Not Evaluated
# 4       330942  Qt Project Website           Not Evaluated
# ...        ...                 ...                     ...
# 148574  301329                  Qt           P2: Important
# 148575  301328                  Qt           Not Evaluated
# 148576  301327                  Qt           P2: Important
# 148577  301326                  Qt           P2: Important
# 148578  301313                  Qt            P1: Critical
#
#                       fields.created  \
# 0       2022-01-04T08:51:51.000+0000
# 1       2021-12-16T11:55:21.000+0000
# 2       2021-12-06T08:00:42.000+0000
# 3       2021-12-03T16:50:53.000+0000
# 4       2021-12-01T12:19:21.000+0000
# ...                              ...
# 148574  2020-07-01T12:03:13.000+0000
# 148575  2020-07-01T11:51:59.000+0000
# 148576  2020-07-01T11:11:14.000+0000
# 148577  2020-07-01T11:00:14.000+0000
# 148578  2020-07-01T08:43:56.000+0000
#
#                                     fields.labels  \
# 0                                              []
# 1                                              []
# 2                                              []
# 3                                              []
# 4                                              []
# ...                                           ...
# 148574                                         []
# 148575           ['Reported_by_support_standard']
# 148576           ['Reported_by_support_standard']
# 148577                                         []
# 148578  ['cmake_qt6', 'cmake_switch_requirement']
#
#                                            fields.summary  \
# 0       Custom css is not usable in published document...
# 1                                    Second Cookie banner
# 2       doc.qt.io search: Changing Sort by criterium a...
# 3                 planet.qt.io did not fetch my last post
# 4       .sha256 virtual files are missing for qt 6.2.2...
# ...                                                   ...
# 148574  Unable to record more than one video on Raspbe...
# 148575  QQC2 AbstractButton.display: add option to sel...
# 148576  QTreeView: FetchMore is not getting called for...
# 148577  Select SDK and XCode for Build Qt from sources...
# 148578  Skip or ignore remaining failing tests in CMak...
#
#                                        fields.description fields.status.name  \
# 0       While documentation projects can define custom...               Open
# 1       Second cookie banner pop ups on top of the for...               Open
# 2       Changing the 'Sort by criteria' in a doc.qt.io...               Open
# 3       Hi, I did a day ago a new post on cutelyst.org...               Open
# 4       missing\r\nhttps://download.qt.io/official_rel...             Closed
# ...                                                   ...                ...
# 148574  The application crashes when trying to record ...             Closed
# 148575  Currently seems like the only option to edit o...           Reported
# 148576  When a Treeview is specified to fetch more row...             Closed
# 148577  Hi,\r\n\r\nI'm attempting to build Qt 5.15 fro...             Closed
# 148578  We can't keep up with fixing tests that fail o...             Closed
#
#                                 fields.status.description  \
# 0       The issue is open and ready for the assignee t...
# 1       The issue is open and ready for the assignee t...
# 2       The issue is open and ready for the assignee t...
# 3       The issue is open and ready for the assignee t...
# 4       The issue is considered finished, the resoluti...
# ...                                                   ...
# 148574  The issue is considered finished, the resoluti...
# 148575  The issue has been reported, but no validation...
# 148576  The issue is considered finished, the resoluti...
# 148577  The issue is considered finished, the resoluti...
# 148578  The issue is considered finished, the resoluti...
#
#        fields.issuetype.name  \
# 0                        Bug
# 1                       Task
# 2                        Bug
# 3                        Bug
# 4                        Bug
# ...                      ...
# 148574                   Bug
# 148575            Suggestion
# 148576                   Bug
# 148577                   Bug
# 148578                  Task
#
#                              fields.issuetype.description  \
# 0       A problem which impairs or prevents the functi...
# 1                           A task that needs to be done.
# 2       A problem which impairs or prevents the functi...
# 3       A problem which impairs or prevents the functi...
# 4       A problem which impairs or prevents the functi...
# ...                                                   ...
# 148574  A problem which impairs or prevents the functi...
# 148575                                 Public suggestions
# 148576  A problem which impairs or prevents the functi...
# 148577  A problem which impairs or prevents the functi...
# 148578                      A task that needs to be done.
#
#         fields.issuetype.subtask  \
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 148574                     False
# 148575                     False
# 148576                     False
# 148577                     False
# 148578                     False
#
#                                           fields.comments
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3       [{'self': 'https://bugreports.qt.io/rest/api/2...
# 4       [{'self': 'https://bugreports.qt.io/rest/api/2...
# ...                                                   ...
# 148574  [{'self': 'https://bugreports.qt.io/rest/api/2...
# 148575                                                 []
# 148576  [{'self': 'https://bugreports.qt.io/rest/api/2...
# 148577  [{'self': 'https://bugreports.qt.io/rest/api/2...
# 148578  [{'self': 'https://bugreports.qt.io/rest/api/2...
#
# [148579 rows x 13 columns]
