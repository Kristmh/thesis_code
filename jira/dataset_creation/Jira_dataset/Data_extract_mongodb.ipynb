# %% [markdown]
# # Extract data from public Jira data
# * This notebook will extract data from the public jira dataset
# * The dataset is stored in mongoDB.
# * mongoDB must be installed and running on your system.

# %% [markdown]
# For more details refer to
#  https://zenodo.org/record/5901956

# %% [markdown]
# Command used to export the data (this command takes about 15 minutes to complete).
#
# `mongodump --db=JiraRepos --gzip --archive=mongodump-JiraRepos.archive`
#
# Accompanying command to restore the data (this command takes about 15 minutes to complete). Expanded, this data is ~60GB inside MongoDB.
#
# `mongorestore --gzip --archive=mongodump-JiraRepos.archive --nsFrom "JiraRepos.*" --nsTo "JiraRepos.*"`
#
# Change the `--nsTo` command to contain the desired name for the JiraRepos database.
# mongorestore --gzip --archive=mongodump-JiraRepos.archive --nsFrom "JiraRepos.*" --nsTo "JiraRepos.Apache"
#
#
# For more information see: https://docs.mongodb.com/manual/tutorial/backup-and-restore-tools/

# %% [markdown]
# Jira Dataset for TD filtered was extracted from https://zenodo.org/record/5901956  (https://arxiv.org/pdf/2201.08368.pdf) and adapted
#
# Montgomery, Lloyd, Lüders, Clara, & Maalej, Prof. Dr. Walid. (2022). The Public Jira Dataset [Data set]. Zenodo. https://doi.org/10.5281/zenodo.5901956

# %%
import pymongo
# Default connection to localhost
myclient = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
mydb = myclient["JiraRepos"]
mydb
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'JiraRepos')

# %%
collist = mydb.list_collection_names()
collist
# Out:
# ['Spring',
#  'RedHat',
#  'Sakai',
#  'JiraEcosystem',
#  'Jira',
#  'Hyperledger',
#  'Apache',
#  'SecondLife',
#  'MariaDB',
#  'MongoDB',
#  'Mojang',
#  'Qt',
#  'JFrog',
#  'IntelDAOS',
#  'Mindville',
#  'Sonatype']

# %%
# Name of the collection to extract
collection_name = 'JiraEcosystem'

# %%
import pymongo as pm
import pandas as pd
import os

CHUNK_SIZE = 500
client = pm.MongoClient()
coll = client.get_database('JiraRepos').get_collection(collection_name)
cursor = coll.find({}, batch_size=CHUNK_SIZE)

# Count total documents and calculate total chunks
total_docs = coll.count_documents({})
total_chunks = (total_docs + CHUNK_SIZE - 1) // CHUNK_SIZE  # Rounds up the division

def yield_rows(cursor, chunk_size):
    """
    Generator to yield chunks from cursor
    :param cursor:
    :param chunk_size:
    :return:
    """
    chunk = []
    for i, row in enumerate(cursor):
        if i % chunk_size == 0 and i > 0:
            yield chunk
            del chunk[:]
        chunk.append(row)
    yield chunk

# Define the columns you wish to extract
desired_columns = [
    "id", 
    "fields.project.name", 
    "fields.priority.name", 
    "fields.created", 
    "fields.labels", 
    "fields.summary", 
    "fields.description", 
    "fields.status.name",
    "fields.status.description", 
    "fields.issuetype.name", 
    "fields.issuetype.description", 
    "fields.issuetype.subtask", 
    "fields.comments"
]

# Ensure the directory exists
os.makedirs("dataset_dump/" + collection_name, exist_ok=True)

chunks = yield_rows(cursor, CHUNK_SIZE)

# Initialize chunk counter
chunk_counter = 0

for chunk in chunks:
    chunk_counter += 1  # Increment the chunk counter
    df = pd.json_normalize(chunk, errors='ignore')
    
    # Select only the columns that exist in the DataFrame
    available_columns = [col for col in desired_columns if col in df.columns]
    df = df[available_columns]

    # Save to CSV, considering 'id' is always present
    df.to_csv(f"dataset_dump/{collection_name}/{collection_name}-{chunk_counter}.csv", index=False)

    print(f"Processed chunk {chunk_counter} of {total_chunks}")

# Print completion message
print("All chunks processed.")
# Out:
# Processed chunk 1 of 84
# Processed chunk 2 of 84
# Processed chunk 3 of 84
# Processed chunk 4 of 84
# Processed chunk 5 of 84
# Processed chunk 6 of 84
# Processed chunk 7 of 84
# Processed chunk 8 of 84
# Processed chunk 9 of 84
# Processed chunk 10 of 84
# Processed chunk 11 of 84
# Processed chunk 12 of 84
# Processed chunk 13 of 84
# Processed chunk 14 of 84
# Processed chunk 15 of 84
# Processed chunk 16 of 84
# Processed chunk 17 of 84
# Processed chunk 18 of 84
# Processed chunk 19 of 84
# Processed chunk 20 of 84
# Processed chunk 21 of 84
# Processed chunk 22 of 84
# Processed chunk 23 of 84
# Processed chunk 24 of 84
# Processed chunk 25 of 84
# Processed chunk 26 of 84
# Processed chunk 27 of 84
# Processed chunk 28 of 84
# Processed chunk 29 of 84
# Processed chunk 30 of 84
# Processed chunk 31 of 84
# Processed chunk 32 of 84
# Processed chunk 33 of 84
# Processed chunk 34 of 84
# Processed chunk 35 of 84
# Processed chunk 36 of 84
# Processed chunk 37 of 84
# Processed chunk 38 of 84
# Processed chunk 39 of 84
# Processed chunk 40 of 84
# Processed chunk 41 of 84
# Processed chunk 42 of 84
# Processed chunk 43 of 84
# Processed chunk 44 of 84
# Processed chunk 45 of 84
# Processed chunk 46 of 84
# Processed chunk 47 of 84
# Processed chunk 48 of 84
# Processed chunk 49 of 84
# Processed chunk 50 of 84
# Processed chunk 51 of 84
# Processed chunk 52 of 84
# Processed chunk 53 of 84
# Processed chunk 54 of 84
# Processed chunk 55 of 84
# Processed chunk 56 of 84
# Processed chunk 57 of 84
# Processed chunk 58 of 84
# Processed chunk 59 of 84
# Processed chunk 60 of 84
# Processed chunk 61 of 84
# Processed chunk 62 of 84
# Processed chunk 63 of 84
# Processed chunk 64 of 84
# Processed chunk 65 of 84
# Processed chunk 66 of 84
# Processed chunk 67 of 84
# Processed chunk 68 of 84
# Processed chunk 69 of 84
# Processed chunk 70 of 84
# Processed chunk 71 of 84
# Processed chunk 72 of 84
# Processed chunk 73 of 84
# Processed chunk 74 of 84
# Processed chunk 75 of 84
# Processed chunk 76 of 84
# Processed chunk 77 of 84
# Processed chunk 78 of 84
# Processed chunk 79 of 84
# Processed chunk 80 of 84
# Processed chunk 81 of 84
# Processed chunk 82 of 84
# Processed chunk 83 of 84
# Processed chunk 84 of 84
# All chunks processed.

# %%
import dask
dask.config.set({'dataframe.query-planning': True})
import dask.dataframe as dd
df = dd.read_csv(f'dataset_dump/{collection_name}/{collection_name}-*.csv')
df
# Out:
# /home/krim/.conda/envs/thesis/lib/python3.11/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 13.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(
# <dask_expr.expr.DataFrame: expr=ReadCSV(746c9c8)>

# %%
df = df.compute()

# %%
df
# Out:
#          id         fields.project.name fields.priority.name  \
# 0    276837  Who's Looking for OnDemand                Minor
# 1    259197  Who's Looking for OnDemand                Major
# 2    253083  Who's Looking for OnDemand                Major
# 3    134767  Who's Looking for OnDemand             Critical
# 4    110186  Who's Looking for OnDemand                Major
# ..      ...                         ...                  ...
# 495   96951            Activity Streams                Major
# 496   96917            Activity Streams                Major
# 497   96817            Activity Streams                Major
# 498   96687            Activity Streams                Minor
# 499   94838            Activity Streams                Minor
#
#                    fields.created  \
# 0    2019-05-10T02:55:41.828-0500
# 1    2018-06-27T05:38:26.604-0500
# 2    2018-03-25T23:04:58.826-0500
# 3    2016-03-04T05:21:24.601-0600
# 4    2015-01-07T09:35:10.351-0600
# ..                            ...
# 495  2014-07-17T02:40:05.326-0500
# 496  2014-07-16T08:04:38.759-0500
# 497  2014-07-15T04:18:26.724-0500
# 498  2014-07-11T01:25:33.967-0500
# 499  2014-06-13T00:16:45.449-0500
#
#                                          fields.labels  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 495                                                 []
# 496                                      ['clarified']
# 497  ['activity-stream', 'crucible', 'fecru', 'fish...
# 498                                                 []
# 499                                                 []
#
#                                         fields.summary  \
# 0                 User profile picture doesn't display
# 1       CLONE - Users are occasionally displayed twice
# 2          CLONE - Username changes are not read by WL
# 3                      Add compatibility with JIRA 7.x
# 4                  Username changes are not read by WL
# ..                                                 ...
# 495        atlassian-streams 5.4.x Failing JDK8 Builds
# 496  Reproducible test failure assertThatOnlyEntrie...
# 497     Invalid space encoding in changeset-file links
# 498  Unable to comment on Confluence page via JIRA ...
# 499  Package imports incorrectly limit the plugins ...
#
#                                     fields.description fields.status.name  \
# 0    Some user profile picture doesn't display when...  Reviewing Request
# 1    Reported here: https://jira.atlassian.com/brow...              To Do
# 2    For those users for whom we have had to change...              To Do
# 3    Encountered this plugin within the ecosystem.a...        In Progress
# 4    For those users for whom we have had to change...  Reviewing Request
# ..                                                 ...                ...
# 495                                                NaN             Closed
# 496  {{AppLinksTests fail}} on {{activity-stream-5....             Closed
# 497  Links to changed files rendered by {{streams-f...             Closed
# 498  Steps to replicate:\r\n\r\n# In OnDemand, crea...             Closed
# 499                                                NaN             Closed
#
#                              fields.status.description fields.issuetype.name  \
# 0                                                  NaN                   Bug
# 1                                                  NaN                   Bug
# 2                                                  NaN                   Bug
# 3    This issue is being actively worked on at the ...           New Feature
# 4                                                  NaN                   Bug
# ..                                                 ...                   ...
# 495  The issue is considered finished, the resoluti...                   Bug
# 496  The issue is considered finished, the resoluti...                   Bug
# 497  The issue is considered finished, the resoluti...                   Bug
# 498  The issue is considered finished, the resoluti...                   Bug
# 499  The issue is considered finished, the resoluti...                   Bug
#
#                           fields.issuetype.description  \
# 0    A problem which impairs or prevents the functi...
# 1    A problem which impairs or prevents the functi...
# 2    A problem which impairs or prevents the functi...
# 3    A new feature of the product, which has yet to...
# 4    A problem which impairs or prevents the functi...
# ..                                                 ...
# 495  A problem which impairs or prevents the functi...
# 496  A problem which impairs or prevents the functi...
# 497  A problem which impairs or prevents the functi...
# 498  A problem which impairs or prevents the functi...
# 499  A problem which impairs or prevents the functi...
#
#      fields.issuetype.subtask  \
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ..                        ...
# 495                     False
# 496                     False
# 497                     False
# 498                     False
# 499                     False
#
#                                        fields.comments
# 0    [{'self': 'https://ecosystem.atlassian.net/res...
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4    [{'self': 'https://ecosystem.atlassian.net/res...
# ..                                                 ...
# 495  [{'self': 'https://ecosystem.atlassian.net/res...
# 496  [{'self': 'https://ecosystem.atlassian.net/res...
# 497                                                 []
# 498                                                 []
# 499                                                 []
#
# [41866 rows x 13 columns]

# %%
df["fields.priority.name"].value_counts().to_frame()[:50]
# Out:
#                       count
# fields.priority.name
# Major                 29060
# Minor                  6320
# Critical               2837
# Blocker                2439
# Trivial                 836

# %%
df["fields.issuetype.name"].value_counts().to_frame()[:50]
# Out:
#                         count
# fields.issuetype.name
# Bug                     20410
# Improvement              7098
# Task                     5028
# Story                    2993
# New Feature              2318
# Sub-task                 2294
# Suggestion                542
# Documentation             463
# Epic                      348
# Support Request           147
# DAC Feedback               96
# Forge Initiative           32
# Success Metric             13
# Plugin Release Request     13
# A/B Test                   12
# Feedback                    9
# App Incident                9
# Initiative                  8
# Technical Debt              8
# Ask a question              5
# Atlassian Incident          4
# Purchase                    3
# IT Help                     2
# Infrastructure              2
# Third-party issue           2
# Development Task            2
# Pricing Change              1
# Problem                     1
# Payment Support             1
# Support                     1
# Questions                   1

# %%
df["fields.project.name"].value_counts().to_frame()[:50]
# Out:
#                                                     count
# fields.project.name
# Atlassian Marketplace                                4563
# Atlassian User Interface                             4183
# Universal Plugin Manager                             3763
# Atlassian Connector for IntelliJ IDE (discontin...   2889
# Activity Streams                                     2293
# Atlassian Connect in Jira Cloud                      1999
# Atlassian Connect                                    1544
# Atlassian Connector for Eclipse (discontinued)       1499
# Atlassian Maven Plugin Suite                         1490
# Atlassian Gadgets                                    1485
# Application Links                                    1266
# Atlassian Plugins                                    1161
# Confluence Ecosystem (Moved: go.atlassian.com/c...    959
# Server Platform Frontend                              764
# Jira Performance Testing Tools                        721
# ActiveObjects                                         720
# Atlassian Connect JavaScript API                      654
# Atlassian Accessibility                               629
# Atlassian Plugins Webresources                        594
# Forge                                                 577
# Atlassian Troubleshooting & Support Tools Plugin      529
# Atlassian Reference Application                       497
# Atlassian Connector for Visual Studio (disconti...    454
# Atlassian REST                                        398
# Shared Access Layer                                   365
# Atlassian OAuth Plugin                                327
# Maven JGit Flow                                       307
# Atlassian Selenium                                    297
# Subversion JIRA plugin                                257
# JIRA Toolkit Plugin                                   253
# JIRA REST Java Client Library                         249
# Platform POM                                          194
# Atlassian Plugin SDK                                  185
# JIRA Service Desk Ecosystem                           183
# ADG Feedback                                          177
# Hackathon for Cloud                                   155
# Client-side Extensions                                149
# Atlassian Speakeasy                                   149
# Atlassian WebHooks Plugin                             142
# atlassian-cache                                       139
# Atlassian Soy Templates                               136
# JIRA Drag and Drop Attachments Plugin                 136
# Atlassian Connect Express (Node.js)                   121
# ASAP                                                  116
# Atlassian Connect Spring Boot                         114
# FastDev Plugin                                        111
# Ecosystem Initiatives                                 109
# Atlassian Plugin Scanner                              106
# Atlassian VCache                                      105
# Atlassian Template Renderer                           105

# %%
# Number of different projects
df["fields.project.name"].nunique()
# Out:
# 101

# %%
# To csv 
df.to_csv(f'final_dataset/{collection_name}.csv', index=False)

# %%
# read csv
df1 = pd.read_csv(f'final_dataset/{collection_name}.csv')     
df1
# Out:
#            id         fields.project.name fields.priority.name  \
# 0      276837  Who's Looking for OnDemand                Minor
# 1      259197  Who's Looking for OnDemand                Major
# 2      253083  Who's Looking for OnDemand                Major
# 3      134767  Who's Looking for OnDemand             Critical
# 4      110186  Who's Looking for OnDemand                Major
# ...       ...                         ...                  ...
# 41861   96951            Activity Streams                Major
# 41862   96917            Activity Streams                Major
# 41863   96817            Activity Streams                Major
# 41864   96687            Activity Streams                Minor
# 41865   94838            Activity Streams                Minor
#
#                      fields.created  \
# 0      2019-05-10T02:55:41.828-0500
# 1      2018-06-27T05:38:26.604-0500
# 2      2018-03-25T23:04:58.826-0500
# 3      2016-03-04T05:21:24.601-0600
# 4      2015-01-07T09:35:10.351-0600
# ...                             ...
# 41861  2014-07-17T02:40:05.326-0500
# 41862  2014-07-16T08:04:38.759-0500
# 41863  2014-07-15T04:18:26.724-0500
# 41864  2014-07-11T01:25:33.967-0500
# 41865  2014-06-13T00:16:45.449-0500
#
#                                            fields.labels  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 41861                                                 []
# 41862                                      ['clarified']
# 41863  ['activity-stream', 'crucible', 'fecru', 'fish...
# 41864                                                 []
# 41865                                                 []
#
#                                           fields.summary  \
# 0                   User profile picture doesn't display
# 1         CLONE - Users are occasionally displayed twice
# 2            CLONE - Username changes are not read by WL
# 3                        Add compatibility with JIRA 7.x
# 4                    Username changes are not read by WL
# ...                                                  ...
# 41861        atlassian-streams 5.4.x Failing JDK8 Builds
# 41862  Reproducible test failure assertThatOnlyEntrie...
# 41863     Invalid space encoding in changeset-file links
# 41864  Unable to comment on Confluence page via JIRA ...
# 41865  Package imports incorrectly limit the plugins ...
#
#                                       fields.description fields.status.name  \
# 0      Some user profile picture doesn't display when...  Reviewing Request
# 1      Reported here: https://jira.atlassian.com/brow...              To Do
# 2      For those users for whom we have had to change...              To Do
# 3      Encountered this plugin within the ecosystem.a...        In Progress
# 4      For those users for whom we have had to change...  Reviewing Request
# ...                                                  ...                ...
# 41861                                                NaN             Closed
# 41862  {{AppLinksTests fail}} on {{activity-stream-5....             Closed
# 41863  Links to changed files rendered by {{streams-f...             Closed
# 41864  Steps to replicate:\r\n\r\n# In OnDemand, crea...             Closed
# 41865                                                NaN             Closed
#
#                                fields.status.description  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      This issue is being actively worked on at the ...
# 4                                                    NaN
# ...                                                  ...
# 41861  The issue is considered finished, the resoluti...
# 41862  The issue is considered finished, the resoluti...
# 41863  The issue is considered finished, the resoluti...
# 41864  The issue is considered finished, the resoluti...
# 41865  The issue is considered finished, the resoluti...
#
#       fields.issuetype.name  \
# 0                       Bug
# 1                       Bug
# 2                       Bug
# 3               New Feature
# 4                       Bug
# ...                     ...
# 41861                   Bug
# 41862                   Bug
# 41863                   Bug
# 41864                   Bug
# 41865                   Bug
#
#                             fields.issuetype.description  \
# 0      A problem which impairs or prevents the functi...
# 1      A problem which impairs or prevents the functi...
# 2      A problem which impairs or prevents the functi...
# 3      A new feature of the product, which has yet to...
# 4      A problem which impairs or prevents the functi...
# ...                                                  ...
# 41861  A problem which impairs or prevents the functi...
# 41862  A problem which impairs or prevents the functi...
# 41863  A problem which impairs or prevents the functi...
# 41864  A problem which impairs or prevents the functi...
# 41865  A problem which impairs or prevents the functi...
#
#        fields.issuetype.subtask  \
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
# ...                         ...
# 41861                     False
# 41862                     False
# 41863                     False
# 41864                     False
# 41865                     False
#
#                                          fields.comments
# 0      [{'self': 'https://ecosystem.atlassian.net/res...
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4      [{'self': 'https://ecosystem.atlassian.net/res...
# ...                                                  ...
# 41861  [{'self': 'https://ecosystem.atlassian.net/res...
# 41862  [{'self': 'https://ecosystem.atlassian.net/res...
# 41863                                                 []
# 41864                                                 []
# 41865                                                 []
#
# [41866 rows x 13 columns]
