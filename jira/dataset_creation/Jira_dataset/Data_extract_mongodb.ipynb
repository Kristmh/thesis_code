# %% [markdown]
# # Extract data from public Jira data
# * This notebook will extract data from the public jira dataset
# * The dataset is stored in mongoDB.
# * mongoDB must be installed and running on your system.

# %% [markdown]
# For more details refer to
#  https://zenodo.org/record/5901956

# %% [markdown]
# Command used to export the data (this command takes about 15 minutes to complete).
#
# `mongodump --db=JiraRepos --gzip --archive=mongodump-JiraRepos.archive`
#
# Accompanying command to restore the data (this command takes about 15 minutes to complete). Expanded, this data is ~60GB inside MongoDB.
#
# `mongorestore --gzip --archive=mongodump-JiraRepos.archive --nsFrom "JiraRepos.*" --nsTo "JiraRepos.*"`
#
# Change the `--nsTo` command to contain the desired name for the JiraRepos database.
# mongorestore --gzip --archive=mongodump-JiraRepos.archive --nsFrom "JiraRepos.*" --nsTo "JiraRepos.Apache"
#
#
# For more information see: https://docs.mongodb.com/manual/tutorial/backup-and-restore-tools/

# %% [markdown]
# Jira Dataset for TD filtered was extracted from https://zenodo.org/record/5901956  (https://arxiv.org/pdf/2201.08368.pdf) and adapted
#
# Montgomery, Lloyd, Lüders, Clara, & Maalej, Prof. Dr. Walid. (2022). The Public Jira Dataset [Data set]. Zenodo. https://doi.org/10.5281/zenodo.5901956

# %%
import pymongo
# Default connection to localhost
myclient = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
mydb = myclient["JiraRepos"]
mydb
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'JiraRepos')

# %%
myapache = mydb["Apache"]
myjiraecosystem = mydb["JiraEcosystem"]
mySonatype = mydb["Sonatype"]
mymongo = mydb["MongoDB"]

# %%
collist = mydb.list_collection_names()
collist
# Out:
# ['Spring',
#  'RedHat',
#  'Sakai',
#  'JiraEcosystem',
#  'Jira',
#  'Hyperledger',
#  'Apache',
#  'SecondLife',
#  'MariaDB',
#  'MongoDB',
#  'Mojang',
#  'Qt',
#  'JFrog',
#  'IntelDAOS',
#  'Mindville',
#  'Sonatype']

# %%
# Name of the collection to extract
collection_name = 'Jira'

# %%
import pymongo as pm
import pandas as pd
import os

CHUNK_SIZE = 500
client = pm.MongoClient()
coll = client.get_database('JiraRepos').get_collection(collection_name)
cursor = coll.find({}, batch_size=CHUNK_SIZE)

# Count total documents and calculate total chunks
total_docs = coll.count_documents({})
total_chunks = (total_docs + CHUNK_SIZE - 1) // CHUNK_SIZE  # Rounds up the division

def yield_rows(cursor, chunk_size):
    """
    Generator to yield chunks from cursor
    :param cursor:
    :param chunk_size:
    :return:
    """
    chunk = []
    for i, row in enumerate(cursor):
        if i % chunk_size == 0 and i > 0:
            yield chunk
            del chunk[:]
        chunk.append(row)
    yield chunk

# Define the columns you wish to extract
desired_columns = [
    "id", 
    "fields.project.name", 
    "fields.priority.name", 
    "fields.created", 
    "fields.labels", 
    "fields.summary", 
    "fields.description", 
    "fields.status.name",
    "fields.status.description", 
    "fields.issuetype.name", 
    "fields.issuetype.description", 
    "fields.issuetype.subtask", 
    "fields.comments"
]

# Ensure the directory exists
os.makedirs("dataset_dump/" + collection_name, exist_ok=True)

chunks = yield_rows(cursor, CHUNK_SIZE)

# Initialize chunk counter
chunk_counter = 0

for chunk in chunks:
    chunk_counter += 1  # Increment the chunk counter
    df = pd.json_normalize(chunk, errors='ignore')
    
    # Select only the columns that exist in the DataFrame
    available_columns = [col for col in desired_columns if col in df.columns]
    df = df[available_columns]

    # Save to CSV, considering 'id' is always present
    df.to_csv(f"dataset_dump/{collection_name}/{collection_name}-{chunk_counter}.csv", index=False)

    print(f"Processed chunk {chunk_counter} of {total_chunks}")

# Print completion message
print("All chunks processed.")
# Out:
# Processed chunk 1 of 550
# Processed chunk 2 of 550
# Processed chunk 3 of 550
# Processed chunk 4 of 550
# Processed chunk 5 of 550
# Processed chunk 6 of 550
# Processed chunk 7 of 550
# Processed chunk 8 of 550
# Processed chunk 9 of 550
# Processed chunk 10 of 550
# Processed chunk 11 of 550
# Processed chunk 12 of 550
# Processed chunk 13 of 550
# Processed chunk 14 of 550
# Processed chunk 15 of 550
# Processed chunk 16 of 550
# Processed chunk 17 of 550
# Processed chunk 18 of 550
# Processed chunk 19 of 550
# Processed chunk 20 of 550
# Processed chunk 21 of 550
# Processed chunk 22 of 550
# Processed chunk 23 of 550
# Processed chunk 24 of 550
# Processed chunk 25 of 550
# Processed chunk 26 of 550
# Processed chunk 27 of 550
# Processed chunk 28 of 550
# Processed chunk 29 of 550
# Processed chunk 30 of 550
# Processed chunk 31 of 550
# Processed chunk 32 of 550
# Processed chunk 33 of 550
# Processed chunk 34 of 550
# Processed chunk 35 of 550
# Processed chunk 36 of 550
# Processed chunk 37 of 550
# Processed chunk 38 of 550
# Processed chunk 39 of 550
# Processed chunk 40 of 550
# Processed chunk 41 of 550
# Processed chunk 42 of 550
# Processed chunk 43 of 550
# Processed chunk 44 of 550
# Processed chunk 45 of 550
# Processed chunk 46 of 550
# Processed chunk 47 of 550
# Processed chunk 48 of 550
# Processed chunk 49 of 550
# Processed chunk 50 of 550
# Processed chunk 51 of 550
# Processed chunk 52 of 550
# Processed chunk 53 of 550
# Processed chunk 54 of 550
# Processed chunk 55 of 550
# Processed chunk 56 of 550
# Processed chunk 57 of 550
# Processed chunk 58 of 550
# Processed chunk 59 of 550
# Processed chunk 60 of 550
# Processed chunk 61 of 550
# Processed chunk 62 of 550
# Processed chunk 63 of 550
# Processed chunk 64 of 550
# Processed chunk 65 of 550
# Processed chunk 66 of 550
# Processed chunk 67 of 550
# Processed chunk 68 of 550
# Processed chunk 69 of 550
# Processed chunk 70 of 550
# Processed chunk 71 of 550
# Processed chunk 72 of 550
# Processed chunk 73 of 550
# Processed chunk 74 of 550
# Processed chunk 75 of 550
# Processed chunk 76 of 550
# Processed chunk 77 of 550
# Processed chunk 78 of 550
# Processed chunk 79 of 550
# Processed chunk 80 of 550
# Processed chunk 81 of 550
# Processed chunk 82 of 550
# Processed chunk 83 of 550
# Processed chunk 84 of 550
# Processed chunk 85 of 550
# Processed chunk 86 of 550
# Processed chunk 87 of 550
# Processed chunk 88 of 550
# Processed chunk 89 of 550
# Processed chunk 90 of 550
# Processed chunk 91 of 550
# Processed chunk 92 of 550
# Processed chunk 93 of 550
# Processed chunk 94 of 550
# Processed chunk 95 of 550
# Processed chunk 96 of 550
# Processed chunk 97 of 550
# Processed chunk 98 of 550
# Processed chunk 99 of 550
# Processed chunk 100 of 550
# Processed chunk 101 of 550
# Processed chunk 102 of 550
# Processed chunk 103 of 550
# Processed chunk 445 of 550
# Processed chunk 446 of 550
# Processed chunk 447 of 550
# Processed chunk 448 of 550
# Processed chunk 449 of 550
# Processed chunk 450 of 550
# Processed chunk 451 of 550
# Processed chunk 452 of 550
# Processed chunk 453 of 550
# Processed chunk 454 of 550
# Processed chunk 455 of 550
# Processed chunk 456 of 550
# Processed chunk 457 of 550
# Processed chunk 458 of 550
# Processed chunk 459 of 550
# Processed chunk 460 of 550
# Processed chunk 461 of 550
# Processed chunk 462 of 550
# Processed chunk 463 of 550
# Processed chunk 464 of 550
# Processed chunk 465 of 550
# Processed chunk 466 of 550
# Processed chunk 467 of 550
# Processed chunk 468 of 550
# Processed chunk 469 of 550
# Processed chunk 470 of 550
# Processed chunk 471 of 550
# Processed chunk 472 of 550
# Processed chunk 473 of 550
# Processed chunk 474 of 550
# Processed chunk 475 of 550
# Processed chunk 476 of 550
# Processed chunk 477 of 550
# Processed chunk 478 of 550
# Processed chunk 479 of 550
# Processed chunk 480 of 550
# Processed chunk 481 of 550
# Processed chunk 482 of 550
# Processed chunk 483 of 550
# Processed chunk 484 of 550
# Processed chunk 485 of 550
# Processed chunk 486 of 550
# Processed chunk 487 of 550
# Processed chunk 488 of 550
# Processed chunk 489 of 550
# Processed chunk 490 of 550
# Processed chunk 491 of 550
# Processed chunk 492 of 550
# Processed chunk 493 of 550
# Processed chunk 494 of 550
# Processed chunk 495 of 550
# Processed chunk 496 of 550
# Processed chunk 497 of 550
# Processed chunk 498 of 550
# Processed chunk 499 of 550
# Processed chunk 500 of 550
# Processed chunk 501 of 550
# Processed chunk 502 of 550
# Processed chunk 503 of 550
# Processed chunk 504 of 550
# Processed chunk 505 of 550
# Processed chunk 506 of 550
# Processed chunk 507 of 550
# Processed chunk 508 of 550
# Processed chunk 509 of 550
# Processed chunk 510 of 550
# Processed chunk 511 of 550
# Processed chunk 512 of 550
# Processed chunk 513 of 550
# Processed chunk 514 of 550
# Processed chunk 515 of 550
# Processed chunk 516 of 550
# Processed chunk 517 of 550
# Processed chunk 518 of 550
# Processed chunk 519 of 550
# Processed chunk 520 of 550
# Processed chunk 521 of 550
# Processed chunk 522 of 550
# Processed chunk 523 of 550
# Processed chunk 524 of 550
# Processed chunk 525 of 550
# Processed chunk 526 of 550
# Processed chunk 527 of 550
# Processed chunk 528 of 550
# Processed chunk 529 of 550
# Processed chunk 530 of 550
# Processed chunk 531 of 550
# Processed chunk 532 of 550
# Processed chunk 533 of 550
# Processed chunk 534 of 550
# Processed chunk 535 of 550
# Processed chunk 536 of 550
# Processed chunk 537 of 550
# Processed chunk 538 of 550
# Processed chunk 539 of 550
# Processed chunk 540 of 550
# Processed chunk 541 of 550
# Processed chunk 542 of 550
# Processed chunk 543 of 550
# Processed chunk 544 of 550
# Processed chunk 545 of 550
# Processed chunk 546 of 550
# Processed chunk 547 of 550
# Processed chunk 548 of 550
# Processed chunk 549 of 550
# Processed chunk 550 of 550
# All chunks processed.

# %%
import dask
dask.config.set({'dataframe.query-planning': True})
import dask.dataframe as dd
df = dd.read_csv(f'dataset_dump/{collection_name}/{collection_name}-*.csv')
df
# Out:
# /home/krim/.conda/envs/thesis/lib/python3.11/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 13.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(
# <dask_expr.expr.DataFrame: expr=ReadCSV(5e06ce2)>

# %%
df = df.compute()

# %%
df
# Out:
#           id            fields.project.name fields.priority.name  \
# 0    1843729         Sourcetree for Windows                  NaN
# 1    1843575         Sourcetree for Windows                  Low
# 2    1843552         Sourcetree for Windows                  Low
# 3    1843397         Sourcetree for Windows                  Low
# 4    1842733         Sourcetree for Windows                  NaN
# ..       ...                            ...                  ...
# 495  1777577  Jira Service Management Cloud                  NaN
# 496  1777505  Jira Service Management Cloud                  Low
# 497  1777387  Jira Service Management Cloud                  NaN
# 498  1777462  Jira Service Management Cloud                  Low
# 499  1777529  Jira Service Management Cloud               Medium
#
#                    fields.created fields.labels  \
# 0    2022-01-04T09:13:21.000+0000            []
# 1    2022-01-04T07:39:09.000+0000            []
# 2    2022-01-03T21:46:14.000+0000            []
# 3    2022-01-03T14:07:33.000+0000            []
# 4    2021-12-25T02:30:54.000+0000            []
# ..                            ...           ...
# 495  2021-07-28T08:49:54.000+0000            []
# 496  2021-07-28T07:18:51.000+0000            []
# 497  2021-07-28T06:50:23.000+0000            []
# 498  2021-07-27T18:57:59.000+0000            []
# 499  2021-07-27T13:18:03.000+0000            []
#
#                                         fields.summary  \
# 0    Please make warning LESS SCARY about a detache...
# 1                       Bug in listing bitbucket repos
# 2                 Spaces in File path of Custom Action
# 3     Failed to start (System.BadImageFormatException)
# 4                          commit view show in branchs
# ..                                                 ...
# 495                     Printing label tags for assets
# 496  Having child objects with no individual attrib...
# 497  Ability to display Insight custom field in Kan...
# 498  Insight IQL uses timezones in a way that can b...
# 499  Problem with the Attachment field : Extension ...
#
#                                     fields.description   fields.status.name  \
# 0    I wanted to follow a perfectly normal and feas...   Gathering Interest
# 1    some errors show up as shown in the screenshot...  Waiting for Release
# 2    I have been using Sourcetree 3.4.4.  We use cu...         Needs Triage
# 3    After installing SourceTree for Windows 10 64b...         Needs Triage
# 4    When the project contains many branches and I ...   Gathering Interest
# ..                                                 ...                  ...
# 495  Cant figure out a way to print labels on Insig...   Gathering Interest
# 496  h3. Issue Summary\r\n\r\nCreating child object...    Long Term Backlog
# 497  h3. Problem\r\n\r\nCurrently there is no capab...   Gathering Interest
# 498  h3. Issue Summary\r\nInsight IQL uses timezone...     Gathering Impact
# 499  h3. Issue Summary\r\n\r\nThe intermittent issu...               Closed
#
#                              fields.status.description fields.issuetype.name  \
# 0    This suggestion needs more unique domain votes...            Suggestion
# 1    A fix for this issue has been implemented and ...                   Bug
# 2    This issue is waiting to be reviewed by a memb...                   Bug
# 3    This issue is waiting to be reviewed by a memb...                   Bug
# 4    This suggestion needs more unique domain votes...            Suggestion
# ..                                                 ...                   ...
# 495  This suggestion needs more unique domain votes...            Suggestion
# 496  A fix for this issue is required, but planned ...                   Bug
# 497  This suggestion needs more unique domain votes...            Suggestion
# 498  This issue has been reviewed, but needs more s...                   Bug
# 499  Work on this issue is complete.\r\n\r\nIf it’s...                   Bug
#
#                           fields.issuetype.description  \
# 0                                                  NaN
# 1    A problem which impairs or prevents the functi...
# 2    A problem which impairs or prevents the functi...
# 3    A problem which impairs or prevents the functi...
# 4                                                  NaN
# ..                                                 ...
# 495                                                NaN
# 496  A problem which impairs or prevents the functi...
# 497                                                NaN
# 498  A problem which impairs or prevents the functi...
# 499  A problem which impairs or prevents the functi...
#
#      fields.issuetype.subtask  \
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ..                        ...
# 495                     False
# 496                     False
# 497                     False
# 498                     False
# 499                     False
#
#                                        fields.comments
# 0                                                   []
# 1    [{'self': 'https://jira.atlassian.com/rest/api...
# 2                                                   []
# 3    [{'self': 'https://jira.atlassian.com/rest/api...
# 4                                                   []
# ..                                                 ...
# 495  [{'self': 'https://jira.atlassian.com/rest/api...
# 496                                                 []
# 497                                                 []
# 498                                                 []
# 499  [{'self': 'https://jira.atlassian.com/rest/api...
#
# [274545 rows x 13 columns]

# %%
df["fields.priority.name"].value_counts().to_frame()[:50]
# Out:
#                       count
# fields.priority.name
# Low                   76547
# Medium                43672
# High                  10283
# Highest                5022

# %%
df["fields.issuetype.name"].value_counts().to_frame()[:50]
# Out:
#                                 count
# fields.issuetype.name
# Suggestion                     138378
# Bug                            131040
# Sub-task                         2501
# Support Request                  2438
# Public Security Vulnerability      98
# Improvement                        52
# New Feature                        23
# Task                               12
# Fug                                 2
# Feedback                            1

# %%
df["fields.project.name"].value_counts().to_frame()[:50]
# Out:
#                                                 count
# fields.project.name
# Jira Server and Data Center                     47225
# Confluence Server and Data Center               43910
# Jira Cloud                                      27916
# Confluence Cloud                                25115
# Bitbucket Cloud                                 20352
# Bamboo                                          14625
# Jira Software Server and Data Center            13273
# Jira Software Cloud                             12733
# Sourcetree for Windows                           9646
# Bitbucket Server                                 7885
# Atlassian Cloud                                  7755
# Jira Service Management Server and Data Center   6895
# Jira Service Management Cloud                    6892
# Crucible                                         6765
# FishEye                                          5561
# Sourcetree For Mac                               5292
# Crowd                                            4407
# Advanced Roadmaps                                2180
# Clover                                           1501
# Identity                                         1310
# Atlassian Internationalization                    837
# Migration Platform                                786
# Atlassian Access                                  527
# Atlassian Product Integrations                    438
# Automation for Jira                               342
# atlassian-seraph                                  177
# Jira Work Management Cloud                        136
# Server Deployments and Scale                       58
# Atlassian OAuth 2.0                                 4
# atlassian-http                                      2

# %%
# Number of different projects
df["fields.project.name"].nunique()
# Out:
# 30

# %%
# To csv 
df.to_csv(f'final_dataset/{collection_name}.csv', index=False)

# %%
# read csv
df1 = pd.read_csv(f'final_dataset/{collection_name}.csv')     
df1
# Out:
#              id            fields.project.name fields.priority.name  \
# 0       1843729         Sourcetree for Windows                  NaN
# 1       1843575         Sourcetree for Windows                  Low
# 2       1843552         Sourcetree for Windows                  Low
# 3       1843397         Sourcetree for Windows                  Low
# 4       1842733         Sourcetree for Windows                  NaN
# ...         ...                            ...                  ...
# 274540  1777577  Jira Service Management Cloud                  NaN
# 274541  1777505  Jira Service Management Cloud                  Low
# 274542  1777387  Jira Service Management Cloud                  NaN
# 274543  1777462  Jira Service Management Cloud                  Low
# 274544  1777529  Jira Service Management Cloud               Medium
#
#                       fields.created fields.labels  \
# 0       2022-01-04T09:13:21.000+0000            []
# 1       2022-01-04T07:39:09.000+0000            []
# 2       2022-01-03T21:46:14.000+0000            []
# 3       2022-01-03T14:07:33.000+0000            []
# 4       2021-12-25T02:30:54.000+0000            []
# ...                              ...           ...
# 274540  2021-07-28T08:49:54.000+0000            []
# 274541  2021-07-28T07:18:51.000+0000            []
# 274542  2021-07-28T06:50:23.000+0000            []
# 274543  2021-07-27T18:57:59.000+0000            []
# 274544  2021-07-27T13:18:03.000+0000            []
#
#                                            fields.summary  \
# 0       Please make warning LESS SCARY about a detache...
# 1                          Bug in listing bitbucket repos
# 2                    Spaces in File path of Custom Action
# 3        Failed to start (System.BadImageFormatException)
# 4                             commit view show in branchs
# ...                                                   ...
# 274540                     Printing label tags for assets
# 274541  Having child objects with no individual attrib...
# 274542  Ability to display Insight custom field in Kan...
# 274543  Insight IQL uses timezones in a way that can b...
# 274544  Problem with the Attachment field : Extension ...
#
#                                        fields.description  \
# 0       I wanted to follow a perfectly normal and feas...
# 1       some errors show up as shown in the screenshot...
# 2       I have been using Sourcetree 3.4.4.  We use cu...
# 3       After installing SourceTree for Windows 10 64b...
# 4       When the project contains many branches and I ...
# ...                                                   ...
# 274540  Cant figure out a way to print labels on Insig...
# 274541  h3. Issue Summary\r\n\r\nCreating child object...
# 274542  h3. Problem\r\n\r\nCurrently there is no capab...
# 274543  h3. Issue Summary\r\nInsight IQL uses timezone...
# 274544  h3. Issue Summary\r\n\r\nThe intermittent issu...
#
#          fields.status.name  \
# 0        Gathering Interest
# 1       Waiting for Release
# 2              Needs Triage
# 3              Needs Triage
# 4        Gathering Interest
# ...                     ...
# 274540   Gathering Interest
# 274541    Long Term Backlog
# 274542   Gathering Interest
# 274543     Gathering Impact
# 274544               Closed
#
#                                 fields.status.description  \
# 0       This suggestion needs more unique domain votes...
# 1       A fix for this issue has been implemented and ...
# 2       This issue is waiting to be reviewed by a memb...
# 3       This issue is waiting to be reviewed by a memb...
# 4       This suggestion needs more unique domain votes...
# ...                                                   ...
# 274540  This suggestion needs more unique domain votes...
# 274541  A fix for this issue is required, but planned ...
# 274542  This suggestion needs more unique domain votes...
# 274543  This issue has been reviewed, but needs more s...
# 274544  Work on this issue is complete.\r\n\r\nIf it’s...
#
#        fields.issuetype.name  \
# 0                 Suggestion
# 1                        Bug
# 2                        Bug
# 3                        Bug
# 4                 Suggestion
# ...                      ...
# 274540            Suggestion
# 274541                   Bug
# 274542            Suggestion
# 274543                   Bug
# 274544                   Bug
#
#                              fields.issuetype.description  \
# 0                                                     NaN
# 1       A problem which impairs or prevents the functi...
# 2       A problem which impairs or prevents the functi...
# 3       A problem which impairs or prevents the functi...
# 4                                                     NaN
# ...                                                   ...
# 274540                                                NaN
# 274541  A problem which impairs or prevents the functi...
# 274542                                                NaN
# 274543  A problem which impairs or prevents the functi...
# 274544  A problem which impairs or prevents the functi...
#
#         fields.issuetype.subtask  \
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 274540                     False
# 274541                     False
# 274542                     False
# 274543                     False
# 274544                     False
#
#                                           fields.comments
# 0                                                      []
# 1       [{'self': 'https://jira.atlassian.com/rest/api...
# 2                                                      []
# 3       [{'self': 'https://jira.atlassian.com/rest/api...
# 4                                                      []
# ...                                                   ...
# 274540  [{'self': 'https://jira.atlassian.com/rest/api...
# 274541                                                 []
# 274542                                                 []
# 274543                                                 []
# 274544  [{'self': 'https://jira.atlassian.com/rest/api...
#
# [274545 rows x 13 columns]
