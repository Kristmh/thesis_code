# %%
import pymongo
# Default connection to localhost
myclient = pymongo.MongoClient("mongodb://localhost:27017/")


mydb = myclient["JiraRepos"]
collist = mydb.list_collection_names()
collist
# Out:
# ['Spring',
#  'RedHat',
#  'Sakai',
#  'JiraEcosystem',
#  'Jira',
#  'Hyperledger',
#  'Apache',
#  'SecondLife',
#  'MariaDB',
#  'MongoDB',
#  'Mojang',
#  'Qt',
#  'JFrog',
#  'IntelDAOS',
#  'Mindville',
#  'Sonatype']

# %%
import pandas as pd
import os
# Create dir if not exists
os.makedirs('only_useful_cols', exist_ok=True)
all_dfs = []
for collection in collist:
    try:
        project = pd.read_csv(f'only_useful_cols/{collection}.csv')

        all_dfs.append(project)
        # Make a new column where the rows are the collection name
        project['collection'] = collection
        print(f'Processed {collection}')
   

    except Exception as e:
        print(f'Error  {e} in {collection}')
        continue


if all_dfs:
    df = pd.concat(all_dfs, ignore_index=True)
else:
    print('No CSV files were processed.')
df
# Out:
# Processed Spring
# Processed RedHat
# Processed Sakai
# Processed JiraEcosystem
# Processed Jira
# Processed Hyperledger
# Processed Apache
# Processed SecondLife
# Error  [Errno 2] No such file or directory: 'only_useful_cols/MariaDB.csv' in MariaDB
# Processed MongoDB
# /tmp/ipykernel_928387/3876485866.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   project = pd.read_csv(f'only_useful_cols/{collection}.csv')
# Processed Mojang
# Processed Qt
# Processed JFrog
# Processed IntelDAOS
# Processed Mindville
# Processed Sonatype
#         fields.priority.name  \
# 0                    Blocker
# 1                      Major
# 2                    Trivial
# 3                      Major
# 4                      Minor
# ...                      ...
# 2655048                Major
# 2655049                Major
# 2655050                Major
# 2655051                Major
# 2655052                Major
#
#                                         fields.description  \
# 0        We tried upgrading from Spring Boot 2.0.6 to S...
# 1        The jobs that appear under Executions section ...
# 2        Working with Spring-XD version 1.3.2.RELEASE\n...
# 3        My project 7 node cluster and in that 2 node a...
# 4        See https://github.com/spring-projects/spring-...
# ...                                                    ...
# 2655048                              it is very beautiful.
# 2655049                                            library
# 2655050  What is reactive-gremlin\r\n\r\nreactive-greml...
# 2655051    Android view for a swipeable, weekly calendar.
# 2655052  Beetlmvc is a web framework, which can support...
#
#                                        fields.project.name     fields.labels  \
# 0                                                Spring XD                []
# 1                                                Spring XD                []
# 2                                                Spring XD                []
# 3                                                Spring XD  ['Spring', 'xd']
# 4                                                Spring XD                []
# ...                                                    ...               ...
# 2655048  Community Support - Open Source Project Reposi...                []
# 2655049  Community Support - Open Source Project Reposi...                []
# 2655050  Community Support - Open Source Project Reposi...                []
# 2655051  Community Support - Open Source Project Reposi...                []
# 2655052  Community Support - Open Source Project Reposi...                []
#
#         fields.issuetype.name collection
# 0                         Bug     Spring
# 1                         Bug     Spring
# 2                         Bug     Spring
# 3                         Bug     Spring
# 4                       Story     Spring
# ...                       ...        ...
# 2655048           New Project   Sonatype
# 2655049           New Project   Sonatype
# 2655050           New Project   Sonatype
# 2655051           New Project   Sonatype
# 2655052           New Project   Sonatype
#
# [2655053 rows x 6 columns]

# %%
# To csv
df.to_csv('all_projects.csv', index=False)

# %%
# rename columns using rename function
df.rename(columns={'fields.priority.name': 'priority', 'fields.description': 'description', 'fields.project.name': 'project', 'fields.issuetype.name': 'issuetype', 'fields.labels': 'labels'}, inplace=True)
df
# Out:
#         priority                                        description  \
# 0        Blocker  We tried upgrading from Spring Boot 2.0.6 to S...
# 1          Major  The jobs that appear under Executions section ...
# 2        Trivial  Working with Spring-XD version 1.3.2.RELEASE\n...
# 3          Major  My project 7 node cluster and in that 2 node a...
# 4          Minor  See https://github.com/spring-projects/spring-...
# ...          ...                                                ...
# 2018905    Major                              it is very beautiful.
# 2018906    Major                                            library
# 2018907    Major  What is reactive-gremlin\r\n\r\nreactive-greml...
# 2018908    Major    Android view for a swipeable, weekly calendar.
# 2018909    Major  Beetlmvc is a web framework, which can support...
#
#                                                    project            labels  \
# 0                                                Spring XD                []
# 1                                                Spring XD                []
# 2                                                Spring XD                []
# 3                                                Spring XD  ['Spring', 'xd']
# 4                                                Spring XD                []
# ...                                                    ...               ...
# 2018905  Community Support - Open Source Project Reposi...                []
# 2018906  Community Support - Open Source Project Reposi...                []
# 2018907  Community Support - Open Source Project Reposi...                []
# 2018908  Community Support - Open Source Project Reposi...                []
# 2018909  Community Support - Open Source Project Reposi...                []
#
#            issuetype collection
# 0                Bug     Spring
# 1                Bug     Spring
# 2                Bug     Spring
# 3                Bug     Spring
# 4              Story     Spring
# ...              ...        ...
# 2018905  New Project   Sonatype
# 2018906  New Project   Sonatype
# 2018907  New Project   Sonatype
# 2018908  New Project   Sonatype
# 2018909  New Project   Sonatype
#
# [2018910 rows x 6 columns]

# %%
# drop priority rows with NaN
df = df.dropna(subset=['priority'])
# rest index
df = df.reset_index(drop=True)
df
# Out:
#         priority                                        description  \
# 0        Blocker  We tried upgrading from Spring Boot 2.0.6 to S...
# 1          Major  The jobs that appear under Executions section ...
# 2        Trivial  Working with Spring-XD version 1.3.2.RELEASE\n...
# 3          Major  My project 7 node cluster and in that 2 node a...
# 4          Minor  See https://github.com/spring-projects/spring-...
# ...          ...                                                ...
# 2071438    Major                              it is very beautiful.
# 2071439    Major                                            library
# 2071440    Major  What is reactive-gremlin\r\n\r\nreactive-greml...
# 2071441    Major    Android view for a swipeable, weekly calendar.
# 2071442    Major  Beetlmvc is a web framework, which can support...
#
#                                                    project     fields.labels  \
# 0                                                Spring XD                []
# 1                                                Spring XD                []
# 2                                                Spring XD                []
# 3                                                Spring XD  ['Spring', 'xd']
# 4                                                Spring XD                []
# ...                                                    ...               ...
# 2071438  Community Support - Open Source Project Reposi...                []
# 2071439  Community Support - Open Source Project Reposi...                []
# 2071440  Community Support - Open Source Project Reposi...                []
# 2071441  Community Support - Open Source Project Reposi...                []
# 2071442  Community Support - Open Source Project Reposi...                []
#
#            issuetype collection
# 0                Bug     Spring
# 1                Bug     Spring
# 2                Bug     Spring
# 3                Bug     Spring
# 4              Story     Spring
# ...              ...        ...
# 2071438  New Project   Sonatype
# 2071439  New Project   Sonatype
# 2071440  New Project   Sonatype
# 2071441  New Project   Sonatype
# 2071442  New Project   Sonatype
#
# [2071443 rows x 6 columns]

# %%
# count priority
df['priority'].value_counts().to_frame()[:50]
# Out:
#                           count
# priority
# Major                   1080149
# Minor                    287654
# Major - P3               109573
# Low                       86032
# Critical                  77997
# Medium                    72888
# Blocker                   57974
# P2: Important             46926
# Not Evaluated             42453
# Trivial                   34313
# P3: Somewhat important    28075
# P1: Critical              20750
# High                      19131
# Normal                    14534
# Minor - P4                12964
# 4 - Normal                11231
# P4: Low                    7375
# Unprioritized              6625
# P2                         6259
# P3                         6077
# Highest                    6014
# P4-Low                     3629
# Critical - P2              3437
# Optional                   3250
# P3-Medium                  2525
# 3 - High                   2509
# Trivial - P5               2124
# P2-High                    2102
# Urgent                     2077
# P0: Blocker                2050
# Unknown                    1708
# Not a Priority             1671
# Undefined                  1325
# 2 - Critical               1145
# P1-Urgent                  1046
# Blocker - P1               1044
# Lowest                      999
# P5: Not important           935
# P1                          701
# 1 - Blocker                 498
# Level 3                     444
# P4                          296
# P0                          270
# Unset                       254
# TBD                         168
# Severe                      101
# 5 - Minor                    37
# Showstopper                  34
# Important                    22
# Level 4                      14

# %%
# Remove issues with no priority level set.
df = df[df['priority'] != 'Unset']
df = df[df['priority'] != 'TBD']
df = df[df['priority'] != 'Undefined']
df = df[df['priority'] != 'Unprioritized']
df = df[df['priority'] != 'Not Evaluated']
df = df[df['priority'] != 'Unknown']


# rest index
df = df.reset_index(drop=True)
df
# Out:
#         priority                                        description  \
# 0        Blocker  We tried upgrading from Spring Boot 2.0.6 to S...
# 1          Major  The jobs that appear under Executions section ...
# 2        Trivial  Working with Spring-XD version 1.3.2.RELEASE\n...
# 3          Major  My project 7 node cluster and in that 2 node a...
# 4          Minor  See https://github.com/spring-projects/spring-...
# ...          ...                                                ...
# 2018905    Major                              it is very beautiful.
# 2018906    Major                                            library
# 2018907    Major  What is reactive-gremlin\r\n\r\nreactive-greml...
# 2018908    Major    Android view for a swipeable, weekly calendar.
# 2018909    Major  Beetlmvc is a web framework, which can support...
#
#                                                    project     fields.labels  \
# 0                                                Spring XD                []
# 1                                                Spring XD                []
# 2                                                Spring XD                []
# 3                                                Spring XD  ['Spring', 'xd']
# 4                                                Spring XD                []
# ...                                                    ...               ...
# 2018905  Community Support - Open Source Project Reposi...                []
# 2018906  Community Support - Open Source Project Reposi...                []
# 2018907  Community Support - Open Source Project Reposi...                []
# 2018908  Community Support - Open Source Project Reposi...                []
# 2018909  Community Support - Open Source Project Reposi...                []
#
#            issuetype collection
# 0                Bug     Spring
# 1                Bug     Spring
# 2                Bug     Spring
# 3                Bug     Spring
# 4              Story     Spring
# ...              ...        ...
# 2018905  New Project   Sonatype
# 2018906  New Project   Sonatype
# 2018907  New Project   Sonatype
# 2018908  New Project   Sonatype
# 2018909  New Project   Sonatype
#
# [2018910 rows x 6 columns]

# %%
df['priority'].value_counts().to_frame()[:50]
# Out:
#                           count
# priority
# Major                   1080149
# Minor                    287654
# Major - P3               109573
# Low                       86032
# Critical                  77997
# Medium                    72888
# Blocker                   57974
# P2: Important             46926
# Trivial                   34313
# P3: Somewhat important    28075
# P1: Critical              20750
# High                      19131
# Normal                    14534
# Minor - P4                12964
# 4 - Normal                11231
# P4: Low                    7375
# P2                         6259
# P3                         6077
# Highest                    6014
# P4-Low                     3629
# Critical - P2              3437
# Optional                   3250
# P3-Medium                  2525
# 3 - High                   2509
# Trivial - P5               2124
# P2-High                    2102
# Urgent                     2077
# P0: Blocker                2050
# Not a Priority             1671
# 2 - Critical               1145
# P1-Urgent                  1046
# Blocker - P1               1044
# Lowest                      999
# P5: Not important           935
# P1                          701
# 1 - Blocker                 498
# Level 3                     444
# P4                          296
# P0                          270
# Severe                      101
# 5 - Minor                    37
# Showstopper                  34
# Important                    22
# Level 4                      14
# Level 1                       9
# 6 - Trivial                   8
# Level 2                       6
# Complex Fast-Track            5
# Should Have                   3
# P5-Trivial                    2

# %% [markdown]
# ## Definition of each priority level according to the atlassian documentation.
# * Lowest - Trivial problem with little or no impact on progress. Color: Light grey.
# * Low - Minor problem or easily worked around. Color: Dark grey.
# * Medium - Has the potential to affect progress. Color: Yellow.
# * High - Serious problem that could block progress. Color: Orange.
# * Highest - The problem will block progress. Color: A dark red.
#
# #### Compared to github
# High == High and highest
# medium == medium
# low = low and lowest

# %% [markdown]
# # Ranking of priority levels.
# Most commonly used priority levels in this dataset.
# Using 4-6 levels of priority.
# 5 levels is most common.
# From low to high
# ## 5 priority levels
# ### Sonatype, MongoDB, Apache, RedHat, Spring, Sakai(not any trivial), JiraEcosytem, Sonatype
# * 4: Trivial
# * 3: Minor
# * 2: Major
# * 1: Critical
# * 0: Blocker
# ### Apache
# * P4
# * P3
# * P2
# * P1
# * P0
#
# ### Hyperledger, Mindville
# * Lowest
# * Low
# * Medium
# * High
# * Highest
#
# ### RadHat
# * Low
# * Normal
# * Medium
# * High
# * Urgent
#
# ### IntelDOAS:
# * Trivial
# * Low
# * Medium
# * High
# * Urgent
#
# ### SecondLife
# * Trivial
# * Minor
# * Major
# * Severe
# * Showstopper
#
# ### Mojang
# * Low
# * Normal
# * Important
# * Critical
# * Blocker
#
# ## 6 levels
# ### QT
# * P5: Not important
# * P4: Low
# * P3: Somewhat important
# * P2: Important
# * P1: Critical
# * P0: Blocker
#
# ### JFrog
# * Trivial
# * Minor
# * Normal
# * High
# * Critical
# * Blocker
#
#
# ## 4 levels
# ### Apache
# * Low
# * Normal
# * High
# * Urgent
#
# ### Jira (the org)
# * Low
# * Medium
# * High
# * Highest
# ### Mindville (few issues) can ignore.
# * Level 4
# * Level 3
# * Level 2
# * Level 1
