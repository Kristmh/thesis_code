# %% [markdown]
# # Data cleaning of test datasets
# We want the class with labels as numerical value and the body with clean text.
#
# This will remove:
# * duplicates
# * NaN entires
# * non english
# * url, html
#
# * make it lowercase
# * combine title and body

# %%
import pandas as pd
import sys
sys.path.append("../../../scripts_shared/")
from preprocess_text import preprocess_text

# %%
file_name = "test_sets_projects.csv"
df = pd.read_csv(file_name)
df
# Out:
#            priority                                        description  \
# 0               Low  some errors show up as shown in the screenshot...
# 1               Low  I have been using Sourcetree 3.4.4.  We use cu...
# 2               Low  After installing SourceTree for Windows 10 64b...
# 3               Low  On windows, Sourcetree.exe will start "git.exe...
# 4               Low  Hello,\r\n\r\nSourceTree 3.4.7.\r\n\r\nOS: Win...
# ...             ...                                                ...
# 386200  1 - Blocker  I am attempting to to follow the guide found h...
# 386201   4 - Normal  In binarystore.xml, maxCacheSize is in bytes b...
# 386202   4 - Normal  {color:#000000}We are using an artifact(folder...
# 386203   4 - Normal  Remote repositories created with the repo name...
# 386204   4 - Normal                                                NaN
#
#                               project labels    issuetype collection
# 0              Sourcetree for Windows     []          Bug       Jira
# 1              Sourcetree for Windows     []          Bug       Jira
# 2              Sourcetree for Windows     []          Bug       Jira
# 3              Sourcetree for Windows     []          Bug       Jira
# 4              Sourcetree for Windows     []          Bug       Jira
# ...                               ...    ...          ...        ...
# 386200  Artifactory Binary Repository     []          Bug      JFrog
# 386201  Artifactory Binary Repository     []          Bug      JFrog
# 386202  Artifactory Binary Repository     []  New Feature      JFrog
# 386203  Artifactory Binary Repository     []          Bug      JFrog
# 386204  Artifactory Binary Repository     []  Improvement      JFrog
#
# [386205 rows x 6 columns]

# %%
# Count per priority
df['priority'].value_counts()
# Out:
# priority
# Major - P3                109573
# Low                        76547
# P2: Important              46926
# Medium                     43672
# P3: Somewhat important     28075
# P1: Critical               20750
# Minor - P4                 12964
# 4 - Normal                 11231
# High                       10283
# P4: Low                     7375
# Highest                     5022
# Critical - P2               3437
# 3 - High                    2509
# Trivial - P5                2124
# P0: Blocker                 2050
# 2 - Critical                1145
# Blocker - P1                1044
# P5: Not important            935
# 1 - Blocker                  498
# 5 - Minor                     37
# 6 - Trivial                    8
# Name: count, dtype: int64

# %%
df['issuetype'].value_counts().to_frame()[:50]
# Out:
#                                 count
# issuetype
# Bug                            264247
# Task                            45736
# Improvement                     31603
# New Feature                     11622
# Suggestion                       9543
# Sub-task                         6846
# Technical task                   3256
# Build Failure                    2491
# Support Request                  2415
# User Story                       2318
# Epic                             1680
# Question                         1647
# RCA(sub)                          812
# Story                             288
# Spec Change                       234
# Investigation                     218
# Technical Debt                    162
# Problem Ticket                    159
# Change Request                    152
# Documentation                     139
# Performance                       129
# Public Security Vulnerability      98
# Release                            84
# Backport Sub-Task                  75
# Backport                           49
# Typo                               35
# Support Ticket                     34
# Feature Request                    34
# Incident                           33
# Tracking                           21
# Feedback                           10
# Cosmetic                            9
# Production Issue                    5
# Doc API                             4
# Workload                            3
# Design Request                      3
# Design                              2
# Fug                                 2
# Setup Ticket                        2
# Sub-bug                             1
# Defect                              1
# Doc UI                              1
# Research                            1
# Doc Removal                         1

# %%
# Unique projects
df['project'].nunique()
# Out:
# 88

# %%
# Unique collections
df['collection'].nunique()
# Out:
# 4

# %%
# Count per collection
df['collection'].value_counts().to_frame()
# Out:
#              count
# collection
# Jira        135524
# MongoDB     129142
# Qt          106111
# JFrog        15428

# %%
# Drop duplicates by the content of the description
df = df.drop_duplicates(subset=['description'], keep='last')
df.dropna(inplace=True)
df.reset_index(inplace=True)
df.drop(columns=["index"] , inplace= True)
df["priority"].value_counts()
# Out:
# /tmp/ipykernel_498302/1330035255.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
# /tmp/ipykernel_498302/1330035255.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["index"] , inplace= True)
# priority
# Major - P3                87427
# Low                       73555
# P2: Important             44433
# Medium                    41241
# P3: Somewhat important    27518
# P1: Critical              18183
# Minor - P4                12089
# High                       9841
# 4 - Normal                 9171
# P4: Low                    7203
# Highest                    4750
# Critical - P2              3051
# 3 - High                   2357
# Trivial - P5               1979
# P0: Blocker                1972
# 2 - Critical               1041
# Blocker - P1                928
# P5: Not important           910
# 1 - Blocker                 470
# 5 - Minor                    32
# 6 - Trivial                   8
# Name: count, dtype: int64

# %%
print(df["description"][0])
# Out:
# some errors show up as shown in the screenshot and when I try to clone the repo the sourcetree software crashes and closes.
#
# !image-2022-01-04-12-38-58-699.png!

# %%
# Convert to string
df["text_str"] = df['description'].astype(str)
# Out:
# /tmp/ipykernel_498302/2002586155.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["text_str"] = df['description'].astype(str)

# %%
# Clean the data.
df["text_clean"] = df["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_498302/874145615.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["text_clean"] = df["text_str"].map(preprocess_text)

# %%
# Row with NaN
df[df.isna().any(axis=1)]
# Out:
#           priority                                        description  \
# 17             Low  [https://pasteboard.co/cngS3Gi4a3LS.png]\r\n\r...
# 18             Low                !image-2021-11-22-10-34-33-096.png!
# 51             Low   \r\n\r\n!image-2021-08-12-21-48-12-368.png!\r...
# 52             Low  !image-2021-08-12-22-00-24-074.png!\r\n\r\n!im...
# 60             Low  Kinda annoying tbh:\r\n\r\n!https://i.postimg....
# ...            ...                                                ...
# 347866  4 - Normal  Add all permissions actions for:\r\nGET ‘ui/bu...
# 347919  4 - Normal  [https://docs.google.com/document/d/1H3D8GgXMW...
# 347923  4 - Normal  Ability to configure fine grain license polici...
# 348032  4 - Normal  RTFACT-18583 : not solved.\r\n\r\n[https://git...
# 348150  4 - Normal                                               xxxx
#
#                               project  \
# 17             Sourcetree for Windows
# 18             Sourcetree for Windows
# 51             Sourcetree for Windows
# 52             Sourcetree for Windows
# 60             Sourcetree for Windows
# ...                               ...
# 347866  Artifactory Binary Repository
# 347919  Artifactory Binary Repository
# 347923  Artifactory Binary Repository
# 348032  Artifactory Binary Repository
# 348150  Artifactory Binary Repository
#
#                                          labels    issuetype collection  \
# 17                                           []          Bug       Jira
# 18                                           []          Bug       Jira
# 51                                           []          Bug       Jira
# 52                                           []          Bug       Jira
# 60                                           []          Bug       Jira
# ...                                         ...          ...        ...
# 347866                                       []          Bug      JFrog
# 347919                                       []  New Feature      JFrog
# 347923                                       []         Task      JFrog
# 348032  ['artifactory', 'docker', 'repository']          Bug      JFrog
# 348150                                       []         Task      JFrog
#
#                                                  text_str text_clean
# 17      [https://pasteboard.co/cngS3Gi4a3LS.png]\r\n\r...        NaN
# 18                    !image-2021-11-22-10-34-33-096.png!        NaN
# 51       \r\n\r\n!image-2021-08-12-21-48-12-368.png!\r...        NaN
# 52      !image-2021-08-12-22-00-24-074.png!\r\n\r\n!im...        NaN
# 60      Kinda annoying tbh:\r\n\r\n!https://i.postimg....        NaN
# ...                                                   ...        ...
# 347866  Add all permissions actions for:\r\nGET ‘ui/bu...        NaN
# 347919  [https://docs.google.com/document/d/1H3D8GgXMW...        NaN
# 347923  Ability to configure fine grain license polici...        NaN
# 348032  RTFACT-18583 : not solved.\r\n\r\n[https://git...        NaN
# 348150                                               xxxx        NaN
#
# [4940 rows x 8 columns]

# %%
# Need to dropna here since cleaning function returns NaN for not english text.
df.dropna(inplace=True)
df.reset_index(drop=True,inplace=True)

df
# Out:
# /tmp/ipykernel_498302/2670129767.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
#            priority                                        description  \
# 0               Low  some errors show up as shown in the screenshot...
# 1               Low  I have been using Sourcetree 3.4.4.  We use cu...
# 2               Low  After installing SourceTree for Windows 10 64b...
# 3               Low  On windows, Sourcetree.exe will start "git.exe...
# 4               Low  Hello,\r\n\r\nSourceTree 3.4.7.\r\n\r\nOS: Win...
# ...             ...                                                ...
# 343214   4 - Normal  Hi,\r\n\r\nWhen using REST API to create repos...
# 343215  1 - Blocker  I am attempting to to follow the guide found h...
# 343216   4 - Normal  In binarystore.xml, maxCacheSize is in bytes b...
# 343217   4 - Normal  {color:#000000}We are using an artifact(folder...
# 343218   4 - Normal  Remote repositories created with the repo name...
#
#                               project                              labels  \
# 0              Sourcetree for Windows                                  []
# 1              Sourcetree for Windows                                  []
# 2              Sourcetree for Windows                                  []
# 3              Sourcetree for Windows                                  []
# 4              Sourcetree for Windows                                  []
# ...                               ...                                 ...
# 343214  Artifactory Binary Repository  ['PB_Done', 'QF', 'QF-P2', 'S-P1']
# 343215  Artifactory Binary Repository                                  []
# 343216  Artifactory Binary Repository                                  []
# 343217  Artifactory Binary Repository                                  []
# 343218  Artifactory Binary Repository                                  []
#
#           issuetype collection  \
# 0               Bug       Jira
# 1               Bug       Jira
# 2               Bug       Jira
# 3               Bug       Jira
# 4               Bug       Jira
# ...             ...        ...
# 343214          Bug      JFrog
# 343215          Bug      JFrog
# 343216          Bug      JFrog
# 343217  New Feature      JFrog
# 343218          Bug      JFrog
#
#                                                  text_str  \
# 0       some errors show up as shown in the screenshot...
# 1       I have been using Sourcetree 3.4.4.  We use cu...
# 2       After installing SourceTree for Windows 10 64b...
# 3       On windows, Sourcetree.exe will start "git.exe...
# 4       Hello,\r\n\r\nSourceTree 3.4.7.\r\n\r\nOS: Win...
# ...                                                   ...
# 343214  Hi,\r\n\r\nWhen using REST API to create repos...
# 343215  I am attempting to to follow the guide found h...
# 343216  In binarystore.xml, maxCacheSize is in bytes b...
# 343217  {color:#000000}We are using an artifact(folder...
# 343218  Remote repositories created with the repo name...
#
#                                                text_clean
# 0       some errors show up as shown in the screenshot...
# 1       i have been using sourcetree we use custom act...
# 2       after installing sourcetree for windows machin...
# 3       on windows sourcetreeexe will start gitexe fsm...
# 4       hello sourcetree os windows pro problem create...
# ...                                                   ...
# 343214  hi when using rest api to create repository if...
# 343215  i am attempting to to follow the guide found h...
# 343216  in binarystorexml maxcachesize is in bytes by ...
# 343217  are using an artifactfolder promotion process ...
# 343218  remote repositories created with the repo name...
#
# [343219 rows x 8 columns]

# %%
# Rows with NaN
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [priority, description, project, labels, issuetype, collection, text_str, text_clean]
# Index: []

# %%
null_rows = df[df['text_clean'].isnull()]
null_rows
# Out:
# Empty DataFrame
# Columns: [priority, description, project, labels, issuetype, collection, text_str, text_clean]
# Index: []

# %%
# save full df to csv
df.to_csv("jira_clean_testset_with_all_cols.csv", index=False)

# %%
import os
# Saves each collection to a separate csv
priority_levels = ['Jira', 'MongoDB', 'JFrog', 'Qt']

for dataset in priority_levels:
    try:
        # Make dir with level
        os.makedirs(f'test_datasets', exist_ok=True)
        # df with level class
        df_level = df[df['collection'] == dataset]
        # Save to csv
        df_level.to_csv(f'test_datasets/clean_{dataset}.csv', index=False)
        print(f"Saved {dataset}.csv")
    except Exception as e:
        print(f"An error occurred for level {dataset}: {str(e)}")
# Out:
# Saved Jira.csv
# Saved MongoDB.csv
# Saved JFrog.csv
# Saved Qt.csv

# %%
# Read csv to check if file is saved correctly
for dataset in priority_levels:
    try:
        df = pd.read_csv(f'test_datasets/clean_{dataset}.csv')
        print(f"Read {dataset}.csv")
    except Exception as e:
        print(f"An error occurred while reading {dataset}.csv: {str(e)}")
# Out:
# Read Jira.csv
# Read MongoDB.csv
# Read JFrog.csv
# Read Qt.csv
