# %%
import pandas as pd
# Import csv file
df = pd.read_csv('all_priority_group_in_classes_clean.csv')
df
# Out:
#         priority                                        description  \
# 0        Blocker  We tried upgrading from Spring Boot 2.0.6 to S...
# 1          Major  The jobs that appear under Executions section ...
# 2        Trivial  Working with Spring-XD version 1.3.2.RELEASE\n...
# 3          Major  My project 7 node cluster and in that 2 node a...
# 4          Minor  See https://github.com/spring-projects/spring-...
# ...          ...                                                ...
# 1741188    Major                              it is very beautiful.
# 1741189    Major                                            library
# 1741190    Major  What is reactive-gremlin\r\n\r\nreactive-greml...
# 1741191    Major    Android view for a swipeable, weekly calendar.
# 1741192    Major  Beetlmvc is a web framework, which can support...
#
#                                                    project            labels  \
# 0                                                Spring XD                []
# 1                                                Spring XD                []
# 2                                                Spring XD                []
# 3                                                Spring XD  ['Spring', 'xd']
# 4                                                Spring XD                []
# ...                                                    ...               ...
# 1741188  Community Support - Open Source Project Reposi...                []
# 1741189  Community Support - Open Source Project Reposi...                []
# 1741190  Community Support - Open Source Project Reposi...                []
# 1741191  Community Support - Open Source Project Reposi...                []
# 1741192  Community Support - Open Source Project Reposi...                []
#
#            issuetype collection    class  \
# 0                Bug     Spring  Highest
# 1                Bug     Spring   Medium
# 2                Bug     Spring   Lowest
# 3                Bug     Spring   Medium
# 4              Story     Spring      Low
# ...              ...        ...      ...
# 1741188  New Project   Sonatype   Medium
# 1741189  New Project   Sonatype   Medium
# 1741190  New Project   Sonatype   Medium
# 1741191  New Project   Sonatype   Medium
# 1741192  New Project   Sonatype   Medium
#
#                                                   text_str  \
# 0        We tried upgrading from Spring Boot 2.0.6 to S...
# 1        The jobs that appear under Executions section ...
# 2        Working with Spring-XD version 1.3.2.RELEASE\n...
# 3        My project 7 node cluster and in that 2 node a...
# 4        See https://github.com/spring-projects/spring-...
# ...                                                    ...
# 1741188                              it is very beautiful.
# 1741189                                            library
# 1741190  What is reactive-gremlin\r\n\r\nreactive-greml...
# 1741191    Android view for a swipeable, weekly calendar.
# 1741192  Beetlmvc is a web framework, which can support...
#
#                                                 text_clean
# 0        we tried upgrading from spring boot to spring ...
# 1        the jobs that appear under executions section ...
# 2        working with springxd version the server with ...
# 3        my project node cluster and in that node are a...
# 4                                                      NaN
# ...                                                    ...
# 1741188                               it is very beautiful
# 1741189                                                NaN
# 1741190  what is reactivegremlin reactivegremlin is a s...
# 1741191       android view for a swipeable weekly calendar
# 1741192  beetlmvc is a web framework which can support ...
#
# [1741193 rows x 9 columns]

# %%
# Count class
df['class'].value_counts().to_frame()
# Out:
#            count
# class
# Medium   1133338
# Low       387776
# High      113710
# Highest    63866
# Lowest     42503

# %%
# Make df with column collection is MongoDB
df_mongo = df[df['collection'] == 'MongoDB']
# To csv
df_mongo.to_csv('mongoDB_testset.csv', index=False)
# Count class
df_mongo['class'].value_counts().to_frame()
# Out:
#          count
# class
# Medium   87338
# Low      12032
# High      3051
# Lowest    1965
# Highest    928

# %%
# Remove mongodb from df
df = df[df['collection'] != 'MongoDB']
df
# Out:
#         priority                                        description  \
# 0        Blocker  We tried upgrading from Spring Boot 2.0.6 to S...
# 1          Major  The jobs that appear under Executions section ...
# 2        Trivial  Working with Spring-XD version 1.3.2.RELEASE\n...
# 3          Major  My project 7 node cluster and in that 2 node a...
# 4          Minor  See https://github.com/spring-projects/spring-...
# ...          ...                                                ...
# 1741188    Major                              it is very beautiful.
# 1741189    Major                                            library
# 1741190    Major  What is reactive-gremlin\r\n\r\nreactive-greml...
# 1741191    Major    Android view for a swipeable, weekly calendar.
# 1741192    Major  Beetlmvc is a web framework, which can support...
#
#                                                    project            labels  \
# 0                                                Spring XD                []
# 1                                                Spring XD                []
# 2                                                Spring XD                []
# 3                                                Spring XD  ['Spring', 'xd']
# 4                                                Spring XD                []
# ...                                                    ...               ...
# 1741188  Community Support - Open Source Project Reposi...                []
# 1741189  Community Support - Open Source Project Reposi...                []
# 1741190  Community Support - Open Source Project Reposi...                []
# 1741191  Community Support - Open Source Project Reposi...                []
# 1741192  Community Support - Open Source Project Reposi...                []
#
#            issuetype collection    class  \
# 0                Bug     Spring  Highest
# 1                Bug     Spring   Medium
# 2                Bug     Spring   Lowest
# 3                Bug     Spring   Medium
# 4              Story     Spring      Low
# ...              ...        ...      ...
# 1741188  New Project   Sonatype   Medium
# 1741189  New Project   Sonatype   Medium
# 1741190  New Project   Sonatype   Medium
# 1741191  New Project   Sonatype   Medium
# 1741192  New Project   Sonatype   Medium
#
#                                                   text_str  \
# 0        We tried upgrading from Spring Boot 2.0.6 to S...
# 1        The jobs that appear under Executions section ...
# 2        Working with Spring-XD version 1.3.2.RELEASE\n...
# 3        My project 7 node cluster and in that 2 node a...
# 4        See https://github.com/spring-projects/spring-...
# ...                                                    ...
# 1741188                              it is very beautiful.
# 1741189                                            library
# 1741190  What is reactive-gremlin\r\n\r\nreactive-greml...
# 1741191    Android view for a swipeable, weekly calendar.
# 1741192  Beetlmvc is a web framework, which can support...
#
#                                                 text_clean
# 0        we tried upgrading from spring boot to spring ...
# 1        the jobs that appear under executions section ...
# 2        working with springxd version the server with ...
# 3        my project node cluster and in that node are a...
# 4                                                      NaN
# ...                                                    ...
# 1741188                               it is very beautiful
# 1741189                                                NaN
# 1741190  what is reactivegremlin reactivegremlin is a s...
# 1741191       android view for a swipeable weekly calendar
# 1741192  beetlmvc is a web framework which can support ...
#
# [1635879 rows x 9 columns]

# %%
df_mongoo = df[df['collection'] == 'MongoDB']
df_mongoo
# Out:
# Empty DataFrame
# Columns: [priority, description, project, labels, issuetype, collection, class, text_str, text_clean]
# Index: []

# %%
highest = df[df['class'] == 'Highest']
highest["label"] = 1
high = df[df['class'] == 'High']
medium = df[df['class'] == 'Medium']
low = df[df['class'] == 'Low']
lowest = df[df['class'] == 'Lowest']
# Out:
# /tmp/ipykernel_345129/604172987.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["label"] = 1

# %%
# Concat all class except highest
rest = pd.concat([high, medium, low, lowest])
rest["label"] = 0
rest
# Out:
#          priority                                        description  \
# 7        Critical  According to the documentation we can load jar...
# 38       Critical  as stated in https://jira.spring.io/browse/INT...
# 57       Critical  XD container loose connection with Zookeeper.\...
# 152      Critical  If I deploy more than one instance of a module...
# 484      Critical  I am using the POX method to implement a simpl...
# ...           ...                                                ...
# 1735173   Trivial  Please close this issue - I apologize. Everyth...
# 1737950   Trivial  Following dependencies are not yet ready. I al...
# 1739568   Trivial  Requesting access to "org.grails" to be able t...
# 1740124   Trivial  I'm releasing my artifacts for the first time....
# 1740627   Trivial  Hi,\r\n\r\nI currently face an unauthorized ex...
#
#                                                    project  \
# 7                                                Spring XD
# 38                                               Spring XD
# 57                                               Spring XD
# 152                                              Spring XD
# 484                                    Spring Web Services
# ...                                                    ...
# 1735173  Community Support - Open Source Project Reposi...
# 1737950  Community Support - Open Source Project Reposi...
# 1739568  Community Support - Open Source Project Reposi...
# 1740124  Community Support - Open Source Project Reposi...
# 1740627  Community Support - Open Source Project Reposi...
#
#                                         labels           issuetype collection  \
# 7                                           []                 Bug     Spring
# 38                                          []                 Bug     Spring
# 57       ['container', 'curator', 'zookeeper']                 Bug     Spring
# 152                                         []                 Bug     Spring
# 484                                         []                 Bug     Spring
# ...                                        ...                 ...        ...
# 1735173                              ['nexus']  Publishing Support   Sonatype
# 1737950                                     []  Publishing Support   Sonatype
# 1739568          ['permissions', 'repository']  Publishing Support   Sonatype
# 1740124                                     []  Publishing Support   Sonatype
# 1740627                                     []  Publishing Support   Sonatype
#
#           class                                           text_str  \
# 7          High  According to the documentation we can load jar...
# 38         High  as stated in https://jira.spring.io/browse/INT...
# 57         High  XD container loose connection with Zookeeper.\...
# 152        High  If I deploy more than one instance of a module...
# 484        High  I am using the POX method to implement a simpl...
# ...         ...                                                ...
# 1735173  Lowest  Please close this issue - I apologize. Everyth...
# 1737950  Lowest  Following dependencies are not yet ready. I al...
# 1739568  Lowest  Requesting access to "org.grails" to be able t...
# 1740124  Lowest  I'm releasing my artifacts for the first time....
# 1740627  Lowest  Hi,\r\n\r\nI currently face an unauthorized ex...
#
#                                                 text_clean  label
# 7        according to the documentation we can load jar...      0
# 38       as stated in sprintintegration in springxd can...      0
# 57       xd container loose connection with zookeeperim...      0
# 152      if i deploy more than one instance of a module...      0
# 484      i am using the pox method to implement a simpl...      0
# ...                                                    ...    ...
# 1735173  please close this issue i apologize everything...      0
# 1737950  following dependencies are not yet ready i alr...      0
# 1739568  requesting access to orggrails to be able to s...      0
# 1740124  im releasing my artifacts for the first time i...      0
# 1740627  hi i currently face an unauthorized exception ...      0
#
# [1572941 rows x 10 columns]

# %%
# Value count rest class
rest['class'].value_counts().to_frame()
# Out:
#           count
# class
# Medium  1046000
# Low      375744
# High     110659
# Lowest    40538

# %%
from sklearn.utils import shuffle
# Number of rows in the highest class
n_highest = highest.shape[0]

rest_sampled = rest.sample(n=n_highest, random_state=42)  


balanced_data = pd.concat([highest, rest_sampled])

# Shuffle the combined dataset
balanced_data = shuffle(balanced_data, random_state=42)

# %%
# class count
balanced_data['class'].value_counts().to_frame()
# Out:
#          count
# class
# Highest  62938
# Medium   41785
# Low      15128
# High      4377
# Lowest    1648

# %%
balanced_data
# Out:
#         priority                                        description  \
# 9253     Blocker  The current implementation of cross store brok...
# 1073090    Major  *Introduction*\nThe StorageManager abstract cl...
# 122642     Major  If hostname:80 or hostname:443 is redirected t...
# 709927   Blocker  This JIRA is to fix the files created vs files...
# 1162400  Blocker  We recently updated from servicemix 3.3.1 to v...
# ...          ...                                                ...
# 1003128    Major  There are myriad styles of operators and givin...
# 391374     Major  On the top toolbar of Intellij the new toolbar...
# 58227    Blocker  Adapt WTO to depends on DWO as olm dependency....
# 281597   Blocker  On Amazon RDS PostgreSQL, the replication slot...
# 1706548    Major  I am trying to publish a project of mine to Ma...
#
#                                                    project  \
# 9253                                     Spring Data Neo4j
# 1073090                                     Tajo (Retired)
# 122642                                            Keycloak
# 709927                                       Hadoop Common
# 1162400                                         ServiceMix
# ...                                                    ...
# 1003128                                 Apache Apex Malhar
# 391374   Atlassian Connector for IntelliJ IDE (disconti...
# 58227                           Web Terminal for OpenShift
# 281597                                            Debezium
# 1706548                  Community Support - Maven Central
#
#                              labels        issuetype     collection    class  \
# 9253                             []              Bug         Spring  Highest
# 1073090                          []      Improvement         Apache   Medium
# 122642                           []      Enhancement         RedHat   Medium
# 709927                           []              Bug         Apache  Highest
# 1162400                          []              Bug         Apache  Highest
# ...                             ...              ...            ...      ...
# 1003128                          []      New Feature         Apache   Medium
# 391374                           []              Bug  JiraEcosystem   Medium
# 58227            ['sprint/current']  Feature Request         RedHat  Highest
# 281597                           []              Bug         RedHat  Highest
# 1706548  ['maven', 'maven-central']          Problem       Sonatype   Medium
#
#                                                   text_str  \
# 9253     The current implementation of cross store brok...
# 1073090  *Introduction*\nThe StorageManager abstract cl...
# 122642   If hostname:80 or hostname:443 is redirected t...
# 709927   This JIRA is to fix the files created vs files...
# 1162400  We recently updated from servicemix 3.3.1 to v...
# ...                                                    ...
# 1003128  There are myriad styles of operators and givin...
# 391374   On the top toolbar of Intellij the new toolbar...
# 58227    Adapt WTO to depends on DWO as olm dependency....
# 281597   On Amazon RDS PostgreSQL, the replication slot...
# 1706548  I am trying to publish a project of mine to Ma...
#
#                                                 text_clean  label
# 9253     the current implementation of cross store brok...      1
# 1073090  introductionthe storagemanager abstract class ...      0
# 122642   if or is redirected to kc and the client redir...      0
# 709927   this jira is to fix the files created vs files...      1
# 1162400  we recently updated from servicemix to version...      1
# ...                                                    ...    ...
# 1003128  there are myriad styles of operators and givin...      0
# 391374   on the top toolbar of intellij the new toolbar...      0
# 58227    adapt wto to depends on dwo as olm dependency ...      1
# 281597   on amazon rds postgresql the replication slots...      1
# 1706548  i am trying to publish a project of mine to ma...      0
#
# [125876 rows x 10 columns]

# %%
# Count label
balanced_data['label'].value_counts().to_frame()
# Out:
#        count
# label
# 1      62938
# 0      62938

# %%
# Unique project
balanced_data['project'].nunique()
# Out:
# 1072

# %%
# Unique collection
balanced_data['collection'].nunique()
# Out:
# 13

# %%
# make a df with only text_clean and label
balanced_data = balanced_data[['text_clean', 'label']]
balanced_data
# Out:
#                                                 text_clean  label
# 9253     the current implementation of cross store brok...      1
# 1073090  introductionthe storagemanager abstract class ...      0
# 122642   if or is redirected to kc and the client redir...      0
# 709927   this jira is to fix the files created vs files...      1
# 1162400  we recently updated from servicemix to version...      1
# ...                                                    ...    ...
# 1003128  there are myriad styles of operators and givin...      0
# 391374   on the top toolbar of intellij the new toolbar...      0
# 58227    adapt wto to depends on dwo as olm dependency ...      1
# 281597   on amazon rds postgresql the replication slots...      1
# 1706548  i am trying to publish a project of mine to ma...      0
#
# [125876 rows x 2 columns]

# %%
# To csv
balanced_data.to_csv('clean_high_vs_rest_5_levels.csv', index=False)

# %%
# Read csv to check the file
df = pd.read_csv('clean_high_vs_rest_5_levels.csv')
df
# Out:
#                                                text_clean  label
# 0       the current implementation of cross store brok...      1
# 1       introductionthe storagemanager abstract class ...      0
# 2       if or is redirected to kc and the client redir...      0
# 3       this jira is to fix the files created vs files...      1
# 4       we recently updated from servicemix to version...      1
# ...                                                   ...    ...
# 125871  there are myriad styles of operators and givin...      0
# 125872  on the top toolbar of intellij the new toolbar...      0
# 125873  adapt wto to depends on dwo as olm dependency ...      1
# 125874  on amazon rds postgresql the replication slots...      1
# 125875  i am trying to publish a project of mine to ma...      0
#
# [125876 rows x 2 columns]
