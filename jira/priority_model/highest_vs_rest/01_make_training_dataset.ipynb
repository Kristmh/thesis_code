# %% [markdown]
# # Create dataset: Highest vs rest (high, medium, low, lowest)
# * Under sampling the majority class.
# * 50/50 balance per class.

# %%
import pandas as pd
# Import csv file
df = pd.read_csv('../jira_clean_with_all_cols.csv')
df
# Out:
#         priority                                        description  \
# 0        Blocker  We tried upgrading from Spring Boot 2.0.6 to S...
# 1          Major  The jobs that appear under Executions section ...
# 2        Trivial  Working with Spring-XD version 1.3.2.RELEASE\n...
# 3          Major  My project 7 node cluster and in that 2 node a...
# 4          Minor  See https://github.com/spring-projects/spring-...
# ...          ...                                                ...
# 1404240    Major                              it is very beautiful.
# 1404241    Major                                            library
# 1404242    Major  What is reactive-gremlin\r\n\r\nreactive-greml...
# 1404243    Major    Android view for a swipeable, weekly calendar.
# 1404244    Major  Beetlmvc is a web framework, which can support...
#
#                                                    project            labels  \
# 0                                                Spring XD                []
# 1                                                Spring XD                []
# 2                                                Spring XD                []
# 3                                                Spring XD  ['Spring', 'xd']
# 4                                                Spring XD                []
# ...                                                    ...               ...
# 1404240  Community Support - Open Source Project Reposi...                []
# 1404241  Community Support - Open Source Project Reposi...                []
# 1404242  Community Support - Open Source Project Reposi...                []
# 1404243  Community Support - Open Source Project Reposi...                []
# 1404244  Community Support - Open Source Project Reposi...                []
#
#            issuetype collection    class  \
# 0                Bug     Spring  Highest
# 1                Bug     Spring   Medium
# 2                Bug     Spring   Lowest
# 3                Bug     Spring   Medium
# 4              Story     Spring      Low
# ...              ...        ...      ...
# 1404240  New Project   Sonatype   Medium
# 1404241  New Project   Sonatype   Medium
# 1404242  New Project   Sonatype   Medium
# 1404243  New Project   Sonatype   Medium
# 1404244  New Project   Sonatype   Medium
#
#                                                   text_str  \
# 0        We tried upgrading from Spring Boot 2.0.6 to S...
# 1        The jobs that appear under Executions section ...
# 2        Working with Spring-XD version 1.3.2.RELEASE\n...
# 3        My project 7 node cluster and in that 2 node a...
# 4        See https://github.com/spring-projects/spring-...
# ...                                                    ...
# 1404240                              it is very beautiful.
# 1404241                                            library
# 1404242  What is reactive-gremlin\r\n\r\nreactive-greml...
# 1404243    Android view for a swipeable, weekly calendar.
# 1404244  Beetlmvc is a web framework, which can support...
#
#                                                 text_clean
# 0        we tried upgrading from spring boot to spring ...
# 1        the jobs that appear under executions section ...
# 2        working with springxd version the server with ...
# 3        my project node cluster and in that node are a...
# 4                                                      NaN
# ...                                                    ...
# 1404240                               it is very beautiful
# 1404241                                                NaN
# 1404242  what is reactivegremlin reactivegremlin is a s...
# 1404243       android view for a swipeable weekly calendar
# 1404244  beetlmvc is a web framework which can support ...
#
# [1404245 rows x 9 columns]

# %%
# Count class
df['class'].value_counts().to_frame()
# Out:
#           count
# class
# Medium   960459
# Low      271629
# High      82646
# Highest   56220
# Lowest    33291

# %%
# NaN values
df.isnull().sum()
# Out:
# priority           0
# description        0
# project            0
# labels             0
# issuetype          0
# collection         0
# class              0
# text_str           0
# text_clean     34264
# dtype: int64

# %%
# Drop NaN values
df = df.dropna()
df.isnull().sum()
# Out:
# priority       0
# description    0
# project        0
# labels         0
# issuetype      0
# collection     0
# class          0
# text_str       0
# text_clean     0
# dtype: int64

# %%
# Count class
df['class'].value_counts().to_frame()
# Out:
#           count
# class
# Medium   933029
# Low      267697
# High      81404
# Highest   55358
# Lowest    32493

# %%
# Unique collections
df['collection'].unique()
# Out:
# array(['Spring', 'RedHat', 'Sakai', 'JiraEcosystem', 'Hyperledger',
#        'Apache', 'SecondLife', 'IntelDAOS', 'Mindville', 'Sonatype'],
#       dtype=object)

# %%
# make df with class and text_clean
df = df[['class', 'text_clean']]

# %%
highest = df[df['class'] == 'Highest']
highest["label"] = 1
highest["class_original"] = "Highest"
highest["class"] = "highest"
high = df[df['class'] == 'High']
medium = df[df['class'] == 'Medium']
low = df[df['class'] == 'Low']
lowest = df[df['class'] == 'Lowest']
# Out:
# /tmp/ipykernel_488373/3737047461.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["label"] = 1
# /tmp/ipykernel_488373/3737047461.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["class_original"] = "Highest"
# /tmp/ipykernel_488373/3737047461.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["class"] = "highest"

# %%
# Concat all class except highest
rest = pd.concat([high, medium, low, lowest])
# Rename class to class_1
rest = rest.rename(columns={'class': 'class_original'})
rest["class"] = "rest" 
rest["label"] = 0
rest
# Out:
#         class_original                                         text_clean  \
# 7                 High  according to the documentation we can load jar...
# 38                High  as stated in sprintintegration in springxd can...
# 57                High  xd container loose connection with zookeeperim...
# 152               High  if i deploy more than one instance of a module...
# 484               High  i am using the pox method to implement a simpl...
# ...                ...                                                ...
# 1398225         Lowest  please close this issue i apologize everything...
# 1401002         Lowest  following dependencies are not yet ready i alr...
# 1402620         Lowest  requesting access to orggrails to be able to s...
# 1403176         Lowest  im releasing my artifacts for the first time i...
# 1403679         Lowest  hi i currently face an unauthorized exception ...
#
#         class  label
# 7        rest      0
# 38       rest      0
# 57       rest      0
# 152      rest      0
# 484      rest      0
# ...       ...    ...
# 1398225  rest      0
# 1401002  rest      0
# 1402620  rest      0
# 1403176  rest      0
# 1403679  rest      0
#
# [1314623 rows x 4 columns]

# %%
# Value count rest class
rest['class'].value_counts().to_frame()
# Out:
#          count
# class
# rest   1314623

# %%
from sklearn.utils import shuffle
# Number of rows in the highest class
n_highest = highest.shape[0]

rest_sampled = rest.sample(n=n_highest, random_state=42)  


balanced_data = pd.concat([highest, rest_sampled])

# Shuffle the combined dataset
balanced_data = shuffle(balanced_data, random_state=42)
balanced_data
# Out:
#            class                                         text_clean  label  \
# 433910   highest  when we do range query on simple keys it does ...      1
# 118569   highest  unhandledpromiserejectionwarning unhandled pro...      1
# 426790      rest  the fabricunittestdaily branch failing intermi...      0
# 247541      rest  as a system operator i want to receive alerts ...      0
# 34437       rest  there is no support in datasourcetransactionma...      0
# ...          ...                                                ...    ...
# 1067449     rest  once i have imported a widget into the store i...      0
# 273693      rest  the spec defines an axiom of a ie singleton li...      0
# 108844      rest  to have an history on master of all csvs setup...      0
# 58315    highest  there are still some changes expected to be me...      1
# 284658   highest  crw failed to install from operatorhub because...      1
#
#         class_original
# 433910         Highest
# 118569         Highest
# 426790          Medium
# 247541          Medium
# 34437           Medium
# ...                ...
# 1067449            Low
# 273693          Medium
# 108844          Medium
# 58315          Highest
# 284658         Highest
#
# [110716 rows x 4 columns]

# %%
balanced_data['class'].value_counts().to_frame()
# Out:
#          count
# class
# highest  55358
# rest     55358

# %%
balanced_data
# Out:
#            class                                         text_clean  label  \
# 433910   highest  when we do range query on simple keys it does ...      1
# 118569   highest  unhandledpromiserejectionwarning unhandled pro...      1
# 426790      rest  the fabricunittestdaily branch failing intermi...      0
# 247541      rest  as a system operator i want to receive alerts ...      0
# 34437       rest  there is no support in datasourcetransactionma...      0
# ...          ...                                                ...    ...
# 1067449     rest  once i have imported a widget into the store i...      0
# 273693      rest  the spec defines an axiom of a ie singleton li...      0
# 108844      rest  to have an history on master of all csvs setup...      0
# 58315    highest  there are still some changes expected to be me...      1
# 284658   highest  crw failed to install from operatorhub because...      1
#
#         class_original
# 433910         Highest
# 118569         Highest
# 426790          Medium
# 247541          Medium
# 34437           Medium
# ...                ...
# 1067449            Low
# 273693          Medium
# 108844          Medium
# 58315          Highest
# 284658         Highest
#
# [110716 rows x 4 columns]

# %%
# Count label
balanced_data['label'].value_counts().to_frame()
# Out:
#        count
# label
# 1      55358
# 0      55358

# %%
# Count original class
balanced_data['class_original'].value_counts().to_frame()
# Out:
#                 count
# class_original
# Highest         55358
# Medium          39259
# Low             11262
# High             3411
# Lowest           1426

# %%
# Save to csv
balanced_data.to_csv('highest_vs_rest_balanced_jira.csv', index=False)

# %%
# Read csv
df = pd.read_csv('highest_vs_rest_balanced_jira.csv')
df
# Out:
#           class                                         text_clean  label  \
# 0       highest  when we do range query on simple keys it does ...      1
# 1       highest  unhandledpromiserejectionwarning unhandled pro...      1
# 2          rest  the fabricunittestdaily branch failing intermi...      0
# 3          rest  as a system operator i want to receive alerts ...      0
# 4          rest  there is no support in datasourcetransactionma...      0
# ...         ...                                                ...    ...
# 110711     rest  once i have imported a widget into the store i...      0
# 110712     rest  the spec defines an axiom of a ie singleton li...      0
# 110713     rest  to have an history on master of all csvs setup...      0
# 110714  highest  there are still some changes expected to be me...      1
# 110715  highest  crw failed to install from operatorhub because...      1
#
#        class_original
# 0             Highest
# 1             Highest
# 2              Medium
# 3              Medium
# 4              Medium
# ...               ...
# 110711            Low
# 110712         Medium
# 110713         Medium
# 110714        Highest
# 110715        Highest
#
# [110716 rows x 4 columns]
