# %% [markdown]
# # Create dataset: Highest vs rest (high, medium, low, lowest)
# * Under sampling the majority class.
# * 50/50 balance per class.

# %%
import pandas as pd
# Import csv file
file_name = "clean_Jira"
df = pd.read_csv(f'../csv/{file_name}.csv')
df
# Out:
#        priority                                        description  \
# 0           Low  some errors show up as shown in the screenshot...
# 1           Low  I have been using Sourcetree 3.4.4.  We use cu...
# 2           Low  After installing SourceTree for Windows 10 64b...
# 3           Low  On windows, Sourcetree.exe will start "git.exe...
# 4           Low  Hello,\r\n\r\nSourceTree 3.4.7.\r\n\r\nOS: Win...
# ...         ...                                                ...
# 127602      Low  h3. Issue Summary\r\n\r\nIf a service desk pro...
# 127603      Low  h3. Issue Summary\r\n\r\nWe have '*Link Issue*...
# 127604      Low  h3. Issue Summary\r\n\r\nCreating child object...
# 127605      Low  h3. Issue Summary\r\nInsight IQL uses timezone...
# 127606   Medium  h3. Issue Summary\r\n\r\nThe intermittent issu...
#
#                               project labels issuetype collection  \
# 0              Sourcetree for Windows     []       Bug       Jira
# 1              Sourcetree for Windows     []       Bug       Jira
# 2              Sourcetree for Windows     []       Bug       Jira
# 3              Sourcetree for Windows     []       Bug       Jira
# 4              Sourcetree for Windows     []       Bug       Jira
# ...                               ...    ...       ...        ...
# 127602  Jira Service Management Cloud     []       Bug       Jira
# 127603  Jira Service Management Cloud     []       Bug       Jira
# 127604  Jira Service Management Cloud     []       Bug       Jira
# 127605  Jira Service Management Cloud     []       Bug       Jira
# 127606  Jira Service Management Cloud     []       Bug       Jira
#
#                                                  text_str  \
# 0       some errors show up as shown in the screenshot...
# 1       I have been using Sourcetree 3.4.4.  We use cu...
# 2       After installing SourceTree for Windows 10 64b...
# 3       On windows, Sourcetree.exe will start "git.exe...
# 4       Hello,\r\n\r\nSourceTree 3.4.7.\r\n\r\nOS: Win...
# ...                                                   ...
# 127602  h3. Issue Summary\r\n\r\nIf a service desk pro...
# 127603  h3. Issue Summary\r\n\r\nWe have '*Link Issue*...
# 127604  h3. Issue Summary\r\n\r\nCreating child object...
# 127605  h3. Issue Summary\r\nInsight IQL uses timezone...
# 127606  h3. Issue Summary\r\n\r\nThe intermittent issu...
#
#                                                text_clean
# 0       some errors show up as shown in the screenshot...
# 1       i have been using sourcetree we use custom act...
# 2       after installing sourcetree for windows machin...
# 3       on windows sourcetreeexe will start gitexe fsm...
# 4       hello sourcetree os windows pro problem create...
# ...                                                   ...
# 127602  issue summary if a service desk project has a ...
# 127603  issue summary we have link issue button in the...
# 127604  issue summary creating child objects with no s...
# 127605  issue summary insight iql uses timezones in a ...
# 127606  issue summary the intermittent issue portalonl...
#
# [127607 rows x 8 columns]

# %%
# Count class
df['priority'].value_counts().to_frame()
# Out:
#           count
# priority
# Low       72641
# Medium    40559
# High       9739
# Highest    4668

# %%
# NaN values
df.isnull().sum()
# Out:
# priority        0
# description     0
# project         0
# labels          0
# issuetype       0
# collection      0
# text_str        0
# text_clean     69
# dtype: int64

# %%
# Drop NaN values
df = df.dropna()
df.isnull().sum()
# Out:
# priority       0
# description    0
# project        0
# labels         0
# issuetype      0
# collection     0
# text_str       0
# text_clean     0
# dtype: int64

# %%
# Count class
df['priority'].value_counts().to_frame()
# Out:
#           count
# priority
# Low       72610
# Medium    40526
# High       9736
# Highest    4666

# %%
# Unique collections
df['collection'].unique()
# Out:
# array(['Jira'], dtype=object)

# %%
# Unique projects
df['project'].unique().tolist()
# Out:
# ['Sourcetree for Windows',
#  'Jira Service Management Cloud',
#  'Jira Server and Data Center',
#  'Sourcetree For Mac',
#  'Jira Cloud',
#  'Advanced Roadmaps',
#  'Automation for Jira',
#  'Identity',
#  'Atlassian Internationalization',
#  'atlassian-http',
#  'FishEye',
#  'Crowd',
#  'Crucible',
#  'atlassian-seraph',
#  'Confluence Server and Data Center',
#  'Server Deployments and Scale',
#  'Atlassian OAuth 2.0',
#  'Migration Platform',
#  'Jira Work Management Cloud',
#  'Jira Software Server and Data Center',
#  'Confluence Cloud',
#  'Clover',
#  'Atlassian Cloud',
#  'Bitbucket Server',
#  'Bitbucket Cloud',
#  'Bamboo',
#  'Atlassian Product Integrations',
#  'Atlassian Access',
#  'Jira Software Cloud',
#  'Jira Service Management Server and Data Center']

# %%
# Number of unique projects 
len(df['project'].unique())
# Out:
# 30

# %%
priority_mapping = {
    # Highest priority
    'Highest': 'Highest',
    'High': 'High',
    'Medium': 'Medium',
    'Low': 'Low',

}
# Apply mapping
df['class'] = df['priority'].map(priority_mapping)
# Out:
# /tmp/ipykernel_583833/3135084215.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['class'] = df['priority'].map(priority_mapping)

# %%
# Find the priorities that are not mapped to 'Highest' by checking for nulls in 'class'
unmapped_priorities = df[df['class'].isnull()]['priority'].unique()

if len(unmapped_priorities)  == 0:
    print("All priorities are mapped to a new class")
else:
    print("Priorities not mapped to a new class:")
    for priority in unmapped_priorities:
        print(f"- {priority}")
# Out:
# All priorities are mapped to a new class

# %%
# Count class
df['class'].value_counts().to_frame()
# Out:
#          count
# class
# Low      72610
# Medium   40526
# High      9736
# Highest   4666

# %%
highest = df[df['class'] == 'Highest']
highest["label"] = 1
highest["class_original"] = "Highest"
highest["class"] = "highest"
high = df[df['class'] == 'High']
medium = df[df['class'] == 'Medium']
low = df[df['class'] == 'Low']
# Out:
# /tmp/ipykernel_583833/2699649058.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["label"] = 1
# /tmp/ipykernel_583833/2699649058.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["class_original"] = "Highest"
# /tmp/ipykernel_583833/2699649058.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["class"] = "highest"

# %%
# Concat all class except highest
rest = pd.concat([high, medium, low])
# Rename class to class_1
rest = rest.rename(columns={'class': 'class_original'})
rest["class"] = "rest" 
rest["label"] = 0
rest
# Out:
#        priority                                        description  \
# 172        High  On every startup, all git LFS repositories cur...
# 176        High  When changing te remote repository path throug...
# 422        High  *To Reproduce*\r\n{code}\r\ntry having multipl...
# 450        High  h3. Summary\r\n\r\n"File Status" string is som...
# 497        High  Whenever I want to push/pull my changes, this ...
# ...         ...                                                ...
# 127601      Low  h3. Issue Summary\r\n\r\nSorting objects using...
# 127602      Low  h3. Issue Summary\r\n\r\nIf a service desk pro...
# 127603      Low  h3. Issue Summary\r\n\r\nWe have '*Link Issue*...
# 127604      Low  h3. Issue Summary\r\n\r\nCreating child object...
# 127605      Low  h3. Issue Summary\r\nInsight IQL uses timezone...
#
#                               project                      labels issuetype  \
# 172            Sourcetree for Windows                          []       Bug
# 176            Sourcetree for Windows              ['DevTriaged']       Bug
# 422            Sourcetree for Windows          ['authentication']       Bug
# 450            Sourcetree for Windows  ['ContextMenu', 'SideBar']       Bug
# 497            Sourcetree for Windows                 ['askpass']       Bug
# ...                               ...                         ...       ...
# 127601  Jira Service Management Cloud                          []       Bug
# 127602  Jira Service Management Cloud                          []       Bug
# 127603  Jira Service Management Cloud                          []       Bug
# 127604  Jira Service Management Cloud                          []       Bug
# 127605  Jira Service Management Cloud                          []       Bug
#
#        collection                                           text_str  \
# 172          Jira  On every startup, all git LFS repositories cur...
# 176          Jira  When changing te remote repository path throug...
# 422          Jira  *To Reproduce*\r\n{code}\r\ntry having multipl...
# 450          Jira  h3. Summary\r\n\r\n"File Status" string is som...
# 497          Jira  Whenever I want to push/pull my changes, this ...
# ...           ...                                                ...
# 127601       Jira  h3. Issue Summary\r\n\r\nSorting objects using...
# 127602       Jira  h3. Issue Summary\r\n\r\nIf a service desk pro...
# 127603       Jira  h3. Issue Summary\r\n\r\nWe have '*Link Issue*...
# 127604       Jira  h3. Issue Summary\r\n\r\nCreating child object...
# 127605       Jira  h3. Issue Summary\r\nInsight IQL uses timezone...
#
#                                                text_clean class_original  \
# 172     on every startup all git lfs repositories curr...           High
# 176     when changing te remote repository path throug...           High
# 422     to reproduce code try having multiple reposito...           High
# 450     summary file status string is sometimes displa...           High
# 497     whenever i want to pushpull my changes this di...           High
# ...                                                   ...            ...
# 127601  issue summary sorting objects using an iql que...            Low
# 127602  issue summary if a service desk project has a ...            Low
# 127603  issue summary we have link issue button in the...            Low
# 127604  issue summary creating child objects with no s...            Low
# 127605  issue summary insight iql uses timezones in a ...            Low
#
#        class  label
# 172     rest      0
# 176     rest      0
# 422     rest      0
# 450     rest      0
# 497     rest      0
# ...      ...    ...
# 127601  rest      0
# 127602  rest      0
# 127603  rest      0
# 127604  rest      0
# 127605  rest      0
#
# [122872 rows x 11 columns]

# %%
# Value count rest class
rest['class'].value_counts().to_frame()
# Out:
#         count
# class
# rest   122872

# %%
from sklearn.utils import shuffle
# Number of rows in the highest class
n_highest = highest.shape[0]

rest_sampled = rest.sample(n=n_highest, random_state=42)  


balanced_data = pd.concat([highest, rest_sampled])

# Shuffle the combined dataset
balanced_data = shuffle(balanced_data, random_state=42)
balanced_data
# Out:
#        priority                                        description  \
# 105031   Medium  I&#x27;m using Firefox 37.0.1 on Ubuntu 14.04,...
# 113562      Low  h3. Summary\r\nWhen using Bitbucket Cloud as a...
# 70033   Highest  We have identified and fixed a cross-site scri...
# 75945    Medium  {panel:bgColor=#e7f4fa}\r\n  *NOTE:* This bug ...
# 30422       Low  h3. Problem Definition\r\n\r\nOn the old issue...
# ...         ...                                                ...
# 118917      Low  h3. Issue Summary\r\n\r\nWhen Jira and Conflue...
# 92795    Medium  Clover database contains FileInfo objects for ...
# 101950   Medium  LWJdeMacBook-Pro:~ lwj$ ping -c10 bitbucket.or...
# 32170   Highest  h3.*Problem Definition*\r\n* All of a sudden, ...
# 47683       Low  h1. Symptoms\r\n\r\nAfter upgrading to Crowd 2...
#
#                                      project  \
# 105031                       Bitbucket Cloud
# 113562                                Bamboo
# 70033      Confluence Server and Data Center
# 75945   Jira Software Server and Data Center
# 30422                             Jira Cloud
# ...                                      ...
# 118917                      Atlassian Access
# 92795                                 Clover
# 101950                       Bitbucket Cloud
# 32170                             Jira Cloud
# 47683                                  Crowd
#
#                                           labels issuetype collection  \
# 105031                              ['migrated']       Bug       Jira
# 113562                  ['bamboo-bugfix-kanban']       Bug       Jira
# 70033   ['affects-server', 'editor', 'security']       Bug       Jira
# 75945        ['affects-cloud', 'affects-server']       Bug       Jira
# 30422                                         []  Sub-task       Jira
# ...                                          ...       ...        ...
# 118917                                        []       Bug       Jira
# 92795                                         []       Bug       Jira
# 101950                              ['migrated']       Bug       Jira
# 32170                        ['bento', 'new-ui']       Bug       Jira
# 47683                                         []       Bug       Jira
#
#                                                  text_str  \
# 105031  I&#x27;m using Firefox 37.0.1 on Ubuntu 14.04,...
# 113562  h3. Summary\r\nWhen using Bitbucket Cloud as a...
# 70033   We have identified and fixed a cross-site scri...
# 75945   {panel:bgColor=#e7f4fa}\r\n  *NOTE:* This bug ...
# 30422   h3. Problem Definition\r\n\r\nOn the old issue...
# ...                                                   ...
# 118917  h3. Issue Summary\r\n\r\nWhen Jira and Conflue...
# 92795   Clover database contains FileInfo objects for ...
# 101950  LWJdeMacBook-Pro:~ lwj$ ping -c10 bitbucket.or...
# 32170   h3.*Problem Definition*\r\n* All of a sudden, ...
# 47683   h1. Symptoms\r\n\r\nAfter upgrading to Crowd 2...
#
#                                                text_clean    class  label  \
# 105031  using firefox on ubuntu and seeing the same th...     rest      0
# 113562  summary when using bitbucket cloud as a reposi...     rest      0
# 70033   we have identified and fixed a crosssite scrip...  highest      1
# 75945   note this bug is for jira server using jira cl...     rest      0
# 30422   problem definition on the old issue view hover...     rest      0
# ...                                                   ...      ...    ...
# 118917  issue summary when jira and confluence are con...     rest      0
# 92795   clover database contains fileinfo objects for ...     rest      0
# 101950  lwjdemacbookpro lwj ping bitbucketorgping bitb...     rest      0
# 32170   definition all of a sudden some users are unab...  highest      1
# 47683   symptoms after upgrading to crowd from a previ...     rest      0
#
#        class_original
# 105031         Medium
# 113562            Low
# 70033         Highest
# 75945          Medium
# 30422             Low
# ...               ...
# 118917            Low
# 92795          Medium
# 101950         Medium
# 32170         Highest
# 47683             Low
#
# [9332 rows x 11 columns]

# %%
balanced_data['class'].value_counts().to_frame()
# Out:
#          count
# class
# rest      4666
# highest   4666

# %%
balanced_data
# Out:
#        priority                                        description  \
# 105031   Medium  I&#x27;m using Firefox 37.0.1 on Ubuntu 14.04,...
# 113562      Low  h3. Summary\r\nWhen using Bitbucket Cloud as a...
# 70033   Highest  We have identified and fixed a cross-site scri...
# 75945    Medium  {panel:bgColor=#e7f4fa}\r\n  *NOTE:* This bug ...
# 30422       Low  h3. Problem Definition\r\n\r\nOn the old issue...
# ...         ...                                                ...
# 118917      Low  h3. Issue Summary\r\n\r\nWhen Jira and Conflue...
# 92795    Medium  Clover database contains FileInfo objects for ...
# 101950   Medium  LWJdeMacBook-Pro:~ lwj$ ping -c10 bitbucket.or...
# 32170   Highest  h3.*Problem Definition*\r\n* All of a sudden, ...
# 47683       Low  h1. Symptoms\r\n\r\nAfter upgrading to Crowd 2...
#
#                                      project  \
# 105031                       Bitbucket Cloud
# 113562                                Bamboo
# 70033      Confluence Server and Data Center
# 75945   Jira Software Server and Data Center
# 30422                             Jira Cloud
# ...                                      ...
# 118917                      Atlassian Access
# 92795                                 Clover
# 101950                       Bitbucket Cloud
# 32170                             Jira Cloud
# 47683                                  Crowd
#
#                                           labels issuetype collection  \
# 105031                              ['migrated']       Bug       Jira
# 113562                  ['bamboo-bugfix-kanban']       Bug       Jira
# 70033   ['affects-server', 'editor', 'security']       Bug       Jira
# 75945        ['affects-cloud', 'affects-server']       Bug       Jira
# 30422                                         []  Sub-task       Jira
# ...                                          ...       ...        ...
# 118917                                        []       Bug       Jira
# 92795                                         []       Bug       Jira
# 101950                              ['migrated']       Bug       Jira
# 32170                        ['bento', 'new-ui']       Bug       Jira
# 47683                                         []       Bug       Jira
#
#                                                  text_str  \
# 105031  I&#x27;m using Firefox 37.0.1 on Ubuntu 14.04,...
# 113562  h3. Summary\r\nWhen using Bitbucket Cloud as a...
# 70033   We have identified and fixed a cross-site scri...
# 75945   {panel:bgColor=#e7f4fa}\r\n  *NOTE:* This bug ...
# 30422   h3. Problem Definition\r\n\r\nOn the old issue...
# ...                                                   ...
# 118917  h3. Issue Summary\r\n\r\nWhen Jira and Conflue...
# 92795   Clover database contains FileInfo objects for ...
# 101950  LWJdeMacBook-Pro:~ lwj$ ping -c10 bitbucket.or...
# 32170   h3.*Problem Definition*\r\n* All of a sudden, ...
# 47683   h1. Symptoms\r\n\r\nAfter upgrading to Crowd 2...
#
#                                                text_clean    class  label  \
# 105031  using firefox on ubuntu and seeing the same th...     rest      0
# 113562  summary when using bitbucket cloud as a reposi...     rest      0
# 70033   we have identified and fixed a crosssite scrip...  highest      1
# 75945   note this bug is for jira server using jira cl...     rest      0
# 30422   problem definition on the old issue view hover...     rest      0
# ...                                                   ...      ...    ...
# 118917  issue summary when jira and confluence are con...     rest      0
# 92795   clover database contains fileinfo objects for ...     rest      0
# 101950  lwjdemacbookpro lwj ping bitbucketorgping bitb...     rest      0
# 32170   definition all of a sudden some users are unab...  highest      1
# 47683   symptoms after upgrading to crowd from a previ...     rest      0
#
#        class_original
# 105031         Medium
# 113562            Low
# 70033         Highest
# 75945          Medium
# 30422             Low
# ...               ...
# 118917            Low
# 92795          Medium
# 101950         Medium
# 32170         Highest
# 47683             Low
#
# [9332 rows x 11 columns]

# %%
# Count label
balanced_data['label'].value_counts().to_frame()
# Out:
#        count
# label
# 0       4666
# 1       4666

# %%
# Count original class
balanced_data['class_original'].value_counts().to_frame()
# Out:
#                 count
# class_original
# Highest          4666
# Low              2697
# Medium           1575
# High              394

# %%
# New df with only text clean and label
balanced_data = balanced_data[['text_clean', 'label']]
balanced_data
# Out:
#                                                text_clean  label
# 105031  using firefox on ubuntu and seeing the same th...      0
# 113562  summary when using bitbucket cloud as a reposi...      0
# 70033   we have identified and fixed a crosssite scrip...      1
# 75945   note this bug is for jira server using jira cl...      0
# 30422   problem definition on the old issue view hover...      0
# ...                                                   ...    ...
# 118917  issue summary when jira and confluence are con...      0
# 92795   clover database contains fileinfo objects for ...      0
# 101950  lwjdemacbookpro lwj ping bitbucketorgping bitb...      0
# 32170   definition all of a sudden some users are unab...      1
# 47683   symptoms after upgrading to crowd from a previ...      0
#
# [9332 rows x 2 columns]

# %%
# Save to csv
full_file_name = f'../csv/{file_name}_balanced.csv'
balanced_data.to_csv(full_file_name, index=False)

# %%
# Read csv
df = pd.read_csv(full_file_name)
df
# Out:
#                                              text_clean  label
# 0     using firefox on ubuntu and seeing the same th...      0
# 1     summary when using bitbucket cloud as a reposi...      0
# 2     we have identified and fixed a crosssite scrip...      1
# 3     note this bug is for jira server using jira cl...      0
# 4     problem definition on the old issue view hover...      0
# ...                                                 ...    ...
# 9327  issue summary when jira and confluence are con...      0
# 9328  clover database contains fileinfo objects for ...      0
# 9329  lwjdemacbookpro lwj ping bitbucketorgping bitb...      0
# 9330  definition all of a sudden some users are unab...      1
# 9331  symptoms after upgrading to crowd from a previ...      0
#
# [9332 rows x 2 columns]
