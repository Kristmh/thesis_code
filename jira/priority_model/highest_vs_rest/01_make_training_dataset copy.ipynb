# %%
import pandas as pd
# Import csv file
df = pd.read_csv('mongoDB_testset.csv')
df
# Out:
#              priority                                        description  \
# 0          Major - P3  Currently there are a number of tests in the C...
# 1          Major - P3  The following compilation notes are getting ge...
# 2          Major - P3  \nh2. [verify-datafile-from-little-endian fail...
# 3          Major - P3  h2. [spinlock-gcc-test failed on ! Ubuntu 20.0...
# 4          Major - P3  \nh2. [cppsuite-hs-cleanup-stress failed on Cp...
# ...               ...                                                ...
# 105309     Major - P3  The following command generates a plan that do...
# 105310  Critical - P2  Hi Team,\r\n\r\nI have a very weird problem, w...
# 105311  Critical - P2  Mongod crashes while running YCSB.  Log and mo...
# 105312     Major - P3  Updated yaml files for the three projects to u...
# 105313     Major - P3  that is recognized by the sharded cluster. Thi...
#
#             project          labels      issuetype collection   class  \
# 0        WiredTiger              []    Improvement    MongoDB  Medium
# 1        WiredTiger              []            Bug    MongoDB  Medium
# 2        WiredTiger              []  Build Failure    MongoDB  Medium
# 3        WiredTiger  ['CI-blocker']  Build Failure    MongoDB  Medium
# 4        WiredTiger              []  Build Failure    MongoDB  Medium
# ...             ...             ...            ...        ...     ...
# 105309  Core Server      ['neweng']            Bug    MongoDB  Medium
# 105310  Core Server              []            Bug    MongoDB    High
# 105311  Core Server              []            Bug    MongoDB    High
# 105312  Core Server   ['test-only']           Task    MongoDB  Medium
# 105313  Core Server              []           Task    MongoDB  Medium
#
#                                                  text_str  \
# 0       Currently there are a number of tests in the C...
# 1       The following compilation notes are getting ge...
# 2       \nh2. [verify-datafile-from-little-endian fail...
# 3       h2. [spinlock-gcc-test failed on ! Ubuntu 20.0...
# 4       \nh2. [cppsuite-hs-cleanup-stress failed on Cp...
# ...                                                   ...
# 105309  The following command generates a plan that do...
# 105310  Hi Team,\r\n\r\nI have a very weird problem, w...
# 105311  Mongod crashes while running YCSB.  Log and mo...
# 105312  Updated yaml files for the three projects to u...
# 105313  that is recognized by the sharded cluster. Thi...
#
#                                                text_clean
# 0       currently there are a number of tests in the c...
# 1       the following compilation notes are getting ge...
# 2       verifydatafilefromlittleendian failed on bigen...
# 3       spinlockgcctest failed on ubuntu host project ...
# 4       cppsuitehscleanupstress failed on cppsuite str...
# ...                                                   ...
# 105309  the following command generates a plan that do...
# 105310  hi team i have a very weird problem when i run...
# 105311  mongod crashes while running ycsb log and mong...
# 105312  updated yaml files for the three projects to u...
# 105313  that is recognized by the sharded cluster this...
#
# [105314 rows x 9 columns]

# %%
# Count class
df['class'].value_counts().to_frame()
# Out:
#          count
# class
# Medium   87338
# Low      12032
# High      3051
# Lowest    1965
# Highest    928

# %%
highest = df[df['class'] == 'Highest']
highest["label"] = 1
high = df[df['class'] == 'High']
medium = df[df['class'] == 'Medium']
low = df[df['class'] == 'Low']
lowest = df[df['class'] == 'Lowest']
# Out:
# /tmp/ipykernel_381656/604172987.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["label"] = 1

# %%
# Concat all class except highest
rest = pd.concat([high, medium, low, lowest])
rest["label"] = 0
rest
# Out:
#              priority                                        description  \
# 336     Critical - P2  I'm hitting [the following assertion|https://g...
# 438     Critical - P2  In WT-3805, we made some changes intended to s...
# 709     Critical - P2  The smoke test of the {{timestamp_abort}} prog...
# 740     Critical - P2  In WT-3181, specifically: https://github.com/w...
# 788     Critical - P2  Write failures during a clean shutdown can lea...
# ...               ...                                                ...
# 104920   Trivial - P5  The MSVC 2015 compiler produces the following ...
# 104952   Trivial - P5  We set the location of the minidump using the ...
# 105079   Trivial - P5  I am using this check https://github.com/mzupa...
# 105094   Trivial - P5  {code:cpp}\r\nstd::unique_ptr<Lock::ResourceLo...
# 105141   Trivial - P5  Not restoring the stream format state of an os...
#
#             project             labels issuetype collection   class  \
# 336      WiredTiger                 []       Bug    MongoDB    High
# 438      WiredTiger            ['bkp']       Bug    MongoDB    High
# 709      WiredTiger                 []       Bug    MongoDB    High
# 740      WiredTiger                 []       Bug    MongoDB    High
# 788      WiredTiger                 []       Bug    MongoDB    High
# ...             ...                ...       ...        ...     ...
# 104920  Core Server                 []       Bug    MongoDB  Lowest
# 104952  Core Server  ['PM-372', 'stm']       Bug    MongoDB  Lowest
# 105079  Core Server                 []  Question    MongoDB  Lowest
# 105094  Core Server         ['neweng']      Task    MongoDB  Lowest
# 105141  Core Server       ['coverity']       Bug    MongoDB  Lowest
#
#                                                  text_str  \
# 336     I'm hitting [the following assertion|https://g...
# 438     In WT-3805, we made some changes intended to s...
# 709     The smoke test of the {{timestamp_abort}} prog...
# 740     In WT-3181, specifically: https://github.com/w...
# 788     Write failures during a clean shutdown can lea...
# ...                                                   ...
# 104920  The MSVC 2015 compiler produces the following ...
# 104952  We set the location of the minidump using the ...
# 105079  I am using this check https://github.com/mzupa...
# 105094  {code:cpp}\r\nstd::unique_ptr<Lock::ResourceLo...
# 105141  Not restoring the stream format state of an os...
#
#                                                text_clean  label
# 336     im hitting the following assertion in a test s...      0
# 438     in we made some changes intended to skip most ...      0
# 709     the smoke test of the timestampabort program f...      0
# 740     in specifically the logic around updating btre...      0
# 788     write failures during a clean shutdown can lea...      0
# ...                                                   ...    ...
# 104920  the msvc compiler produces the following warni...      0
# 104952  we set the location of the minidump using the ...      0
# 105079  i am using this check to monitor replication l...      0
# 105094  codecpp stduniqueptr rlk if isrsthreadsafe opc...      0
# 105141  not restoring the stream format state of an os...      0
#
# [104386 rows x 10 columns]

# %%
# Value count rest class
rest['class'].value_counts().to_frame()
# Out:
#         count
# class
# Medium  87338
# Low     12032
# High     3051
# Lowest   1965

# %%
from sklearn.utils import shuffle
# Number of rows in the highest class
n_highest = highest.shape[0]

rest_sampled = rest.sample(n=n_highest, random_state=42)  


balanced_data = pd.concat([highest, rest_sampled])

# Shuffle the combined dataset
balanced_data = shuffle(balanced_data, random_state=42)

# %%
# class count
balanced_data['class'].value_counts().to_frame()
# Out:
#          count
# class
# Highest    928
# Medium     780
# Low        104
# High        30
# Lowest      14

# %%
balanced_data
# Out:
#             priority                                        description  \
# 26568   Blocker - P1  Hi,\r\nThis is my first JIRA ticket, so please...
# 54237   Blocker - P1  There must by a warning or an additional step ...
# 56126     Major - P3  Terrible example output: you format the output...
# 100709    Major - P3  My fix to WT-4289 was incorrect but the normal...
# 47812   Blocker - P1  Starting in 2.8, all database metadata (indexe...
# ...              ...                                                ...
# 22650     Major - P3  Seeing the document to run the unit tests [1],...
# 70269     Major - P3  {color:#1d1c1d}With the changes committed unde...
# 76914   Blocker - P1  * Branch system_perf.yml for 5.0\\  ** Change ...
# 52242     Major - P3  Add support for parsing hosts specified as Uni...
# 46664     Major - P3  Even though max open files limit is high, I se...
#
#                        project                           labels    issuetype  \
# 26568      PHP Driver: Library                               []          Bug
# 54237            Documentation                               []  Improvement
# 56126            Documentation    ['bite-sized', 'docs-triage']          Bug
# 100709              WiredTiger                               []          Bug
# 47812   MongoDB Database Tools                 ['pull-request']         Task
# ...                        ...                              ...          ...
# 22650              Ruby Driver                               []          Bug
# 70269              Core Server                ['range-deleter']         Task
# 76914              Core Server  ['branch-5.0', 'during-branch']         Task
# 52242             Swift Driver                               []  New Feature
# 46664                Evergreen                        ['agent']          Bug
#
#        collection    class                                           text_str  \
# 26568     MongoDB  Highest  Hi,\r\nThis is my first JIRA ticket, so please...
# 54237     MongoDB  Highest  There must by a warning or an additional step ...
# 56126     MongoDB   Medium  Terrible example output: you format the output...
# 100709    MongoDB   Medium  My fix to WT-4289 was incorrect but the normal...
# 47812     MongoDB  Highest  Starting in 2.8, all database metadata (indexe...
# ...           ...      ...                                                ...
# 22650     MongoDB   Medium  Seeing the document to run the unit tests [1],...
# 70269     MongoDB   Medium  {color:#1d1c1d}With the changes committed unde...
# 76914     MongoDB  Highest  * Branch system_perf.yml for 5.0\\  ** Change ...
# 52242     MongoDB   Medium  Add support for parsing hosts specified as Uni...
# 46664     MongoDB   Medium  Even though max open files limit is high, I se...
#
#                                                text_clean  label
# 26568   hi this is my first jira ticket so please forg...      1
# 54237   there must by a warning or an additional step ...      1
# 56126   terrible example output you format the output ...      0
# 100709  my fix to was incorrect but the normal test di...      0
# 47812   starting in all database metadata indexes coll...      1
# ...                                                   ...    ...
# 22650   seeing the document to run the unit tests i fi...      0
# 70269   the changes committed under autoyielding it sh...      0
# 76914   branch systemperfyml for change most reference...      1
# 52242   add support for parsing hosts specified as uni...      0
# 46664   even though max open files limit is high i see...      0
#
# [1856 rows x 10 columns]

# %%
# Count label
balanced_data['label'].value_counts().to_frame()
# Out:
#        count
# label
# 1        928
# 0        928

# %%
# Unique project
balanced_data['project'].nunique()
# Out:
# 26

# %%
# Unique collection
balanced_data['collection'].nunique()
# Out:
# 1

# %%
# make a df with only text_clean and label
balanced_data = balanced_data[['text_clean', 'label']]
balanced_data
# Out:
#                                                text_clean  label
# 26568   hi this is my first jira ticket so please forg...      1
# 54237   there must by a warning or an additional step ...      1
# 56126   terrible example output you format the output ...      0
# 100709  my fix to was incorrect but the normal test di...      0
# 47812   starting in all database metadata indexes coll...      1
# ...                                                   ...    ...
# 22650   seeing the document to run the unit tests i fi...      0
# 70269   the changes committed under autoyielding it sh...      0
# 76914   branch systemperfyml for change most reference...      1
# 52242   add support for parsing hosts specified as uni...      0
# 46664   even though max open files limit is high i see...      0
#
# [1856 rows x 2 columns]

# %%
# To csv
balanced_data.to_csv('clean_mongoDB_testset.csv', index=False)

# %%
# Read csv to check the file
df = pd.read_csv('clean_mongoDB_testset.csv')
df
# Out:
#                                              text_clean  label
# 0     hi this is my first jira ticket so please forg...      1
# 1     there must by a warning or an additional step ...      1
# 2     terrible example output you format the output ...      0
# 3     my fix to was incorrect but the normal test di...      0
# 4     starting in all database metadata indexes coll...      1
# ...                                                 ...    ...
# 1851  seeing the document to run the unit tests i fi...      0
# 1852  the changes committed under autoyielding it sh...      0
# 1853  branch systemperfyml for change most reference...      1
# 1854  add support for parsing hosts specified as uni...      0
# 1855  even though max open files limit is high i see...      0
#
# [1856 rows x 2 columns]
