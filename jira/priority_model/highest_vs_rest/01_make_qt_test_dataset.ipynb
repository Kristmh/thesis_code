# %% [markdown]
# # Create dataset: Highest vs rest (high, medium, low, lowest)
# * Under sampling the majority class.
# * 50/50 balance per class.

# %%
import pandas as pd
# Import csv file
file_name = "clean_Qt"
df = pd.read_csv(f'../csv/{file_name}.csv')
df
# Out:
#                      priority  \
# 0               P2: Important
# 1               P2: Important
# 2      P3: Somewhat important
# 3               P2: Important
# 4               P2: Important
# ...                       ...
# 99439           P2: Important
# 99440           P2: Important
# 99441           P2: Important
# 99442           P2: Important
# 99443            P1: Critical
#
#                                              description             project  \
# 0      While documentation projects can define custom...  Qt Project Website
# 1      Second cookie banner pop ups on top of the for...  Qt Project Website
# 2      Changing the 'Sort by criteria' in a doc.qt.io...  Qt Project Website
# 3      - open qt.io in Safari (Version 14.1.2 (16611....  Qt Project Website
# 4      I was reading  https://www.qt.io/blog/2019/01/...  Qt Project Website
# ...                                                  ...                 ...
# 99439  Running otool on the postgres and odbc plugins...                  Qt
# 99440  The application crashes when trying to record ...                  Qt
# 99441  When a Treeview is specified to fetch more row...                  Qt
# 99442  Hi,\r\n\r\nI'm attempting to build Qt 5.15 fro...                  Qt
# 99443  We can't keep up with fixing tests that fail o...                  Qt
#
#                                           labels issuetype collection  \
# 0                                             []       Bug         Qt
# 1                                             []      Task         Qt
# 2                                             []       Bug         Qt
# 3                                             []       Bug         Qt
# 4                                             []       Bug         Qt
# ...                                          ...       ...        ...
# 99439                                         []      Task         Qt
# 99440                                         []       Bug         Qt
# 99441           ['Reported_by_support_standard']       Bug         Qt
# 99442                                         []       Bug         Qt
# 99443  ['cmake_qt6', 'cmake_switch_requirement']      Task         Qt
#
#                                                 text_str  \
# 0      While documentation projects can define custom...
# 1      Second cookie banner pop ups on top of the for...
# 2      Changing the 'Sort by criteria' in a doc.qt.io...
# 3      - open qt.io in Safari (Version 14.1.2 (16611....
# 4      I was reading  https://www.qt.io/blog/2019/01/...
# ...                                                  ...
# 99439  Running otool on the postgres and odbc plugins...
# 99440  The application crashes when trying to record ...
# 99441  When a Treeview is specified to fetch more row...
# 99442  Hi,\r\n\r\nI'm attempting to build Qt 5.15 fro...
# 99443  We can't keep up with fixing tests that fail o...
#
#                                               text_clean
# 0      while documentation projects can define custom...
# 1      second cookie banner pop ups on top of the for...
# 2      changing the sort by criteria in a docqtio sea...
# 3      open qtio in safari version macos macbook pro ...
# 4      i was reading then i clicked on the search fie...
# ...                                                  ...
# 99439  running otool on the postgres and odbc plugins...
# 99440  the application crashes when trying to record ...
# 99441  when a treeview is specified to fetch more row...
# 99442  hi im attempting to build qt from sources for ...
# 99443  we cant keep up with fixing tests that fail on...
#
# [99444 rows x 8 columns]

# %%
# Count class
df['priority'].value_counts().to_frame()
# Out:
#                         count
# priority
# P2: Important           44089
# P3: Somewhat important  27348
# P1: Critical            17996
# P4: Low                  7165
# P0: Blocker              1943
# P5: Not important         903

# %%
# NaN values
df.isnull().sum()
# Out:
# priority        0
# description     0
# project         0
# labels          0
# issuetype       0
# collection      0
# text_str        0
# text_clean     33
# dtype: int64

# %%
# Drop NaN values
df = df.dropna()
df.isnull().sum()
# Out:
# priority       0
# description    0
# project        0
# labels         0
# issuetype      0
# collection     0
# text_str       0
# text_clean     0
# dtype: int64

# %%
# Count class
df['priority'].value_counts().to_frame()
# Out:
#                         count
# priority
# P2: Important           44078
# P3: Somewhat important  27342
# P1: Critical            17983
# P4: Low                  7164
# P0: Blocker              1941
# P5: Not important         903

# %%
# Unique collections
df['collection'].unique()
# Out:
# array(['Qt'], dtype=object)

# %%
# Unique projects
df['project'].unique().tolist()
# Out:
# ['Qt Project Website',
#  'Qt Quality Assurance Infrastructure',
#  'Qt',
#  'Qt Playground Projects',
#  'Qt Mobility',
#  'Qt for MCUs',
#  'Qt Bugtracking interface',
#  'Qt Installer Framework',
#  'Qt WebBrowser',
#  'Qt Visual Studio Tools',
#  'Qt Extensions',
#  'Qt Creator',
#  'Qt 3D Studio',
#  'Qt Safe Renderer',
#  'Qt Design Studio',
#  'Qbs ("Cubes")',
#  'Qt for Python',
#  'Coin',
#  'Qt Cloud',
#  'Qt Automotive Suite',
#  'Qt Solutions']

# %%
# Number of unique projects 
len(df['project'].unique())
# Out:
# 21

# %%
priority_mapping = {
    # Highest priority
    'P0: Blocker': 'Highest',
    'P1: Critical': 'High',
    'P2: Important': 'Medium',
    'P3: Somewhat important': 'Low',
    'P4: Low': 'Lowest',
    'P5: Not important': 'Lowest',

}
# Apply mapping
df['class'] = df['priority'].map(priority_mapping)
# Out:
# /tmp/ipykernel_626729/3109083252.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['class'] = df['priority'].map(priority_mapping)

# %%
# Find the priorities that are not mapped to 'Highest' by checking for nulls in 'class'
unmapped_priorities = df[df['class'].isnull()]['priority'].unique()

if len(unmapped_priorities)  == 0:
    print("All priorities are mapped to a new class")
else:
    print("Priorities not mapped to a new class:")
    for priority in unmapped_priorities:
        print(f"- {priority}")
# Out:
# All priorities are mapped to a new class

# %%
# Count class
df['class'].value_counts().to_frame()
# Out:
#          count
# class
# Medium   44078
# Low      27342
# High     17983
# Lowest    8067
# Highest   1941

# %%
highest = df[df['class'] == 'Highest']
highest["label"] = 1
highest["class_original"] = "Highest"
highest["class"] = "highest"
high = df[df['class'] == 'High']
medium = df[df['class'] == 'Medium']
low = df[df['class'] == 'Low']
lowest = df[df['class'] == 'Lowest']
# Out:
# /tmp/ipykernel_626729/3737047461.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["label"] = 1
# /tmp/ipykernel_626729/3737047461.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["class_original"] = "Highest"
# /tmp/ipykernel_626729/3737047461.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["class"] = "highest"

# %%
# Concat all class except highest
rest = pd.concat([high, medium, low, lowest])
# Rename class to class_1
rest = rest.rename(columns={'class': 'class_original'})
rest["class"] = "rest" 
rest["label"] = 0
rest
# Out:
#                 priority                                        description  \
# 16          P1: Critical  The Qt Designer manual does not appear to link...
# 27          P1: Critical  Across all Qt and Qt Automotive Suite document...
# 30          P1: Critical  For some reason videos don't play on the blog ...
# 32          P1: Critical  WASM is a new supported platform, but Qt Accou...
# 35          P1: Critical  Dear, \r\n\r\nThis is new partner registration...
# ...                  ...                                                ...
# 99208            P4: Low  In JS, "KeyboardEvent.code" is intended to ref...
# 99231  P5: Not important  In file _*qtbase/examples/widgets/itemviews/fr...
# 99243  P5: Not important  There is a problem with the code style\r\n\r\n...
# 99351            P4: Low  In  *_qtbase/src/3rdparty/libpng/png.c_*_,_  t...
# 99398            P4: Low  {code:c++}\r\n#include <QApplication>\r\n#incl...
#
#                   project                            labels issuetype  \
# 16     Qt Project Website                                []       Bug
# 27     Qt Project Website                                []       Bug
# 30     Qt Project Website                                []      Task
# 32     Qt Project Website  ['Reported_by_support_standard']       Bug
# 35     Qt Project Website                                []      Task
# ...                   ...                               ...       ...
# 99208                  Qt                                []       Bug
# 99231                  Qt                                []       Bug
# 99243                  Qt                                []       Bug
# 99351                  Qt                                []       Bug
# 99398                  Qt                                []       Bug
#
#       collection                                           text_str  \
# 16            Qt  The Qt Designer manual does not appear to link...
# 27            Qt  Across all Qt and Qt Automotive Suite document...
# 30            Qt  For some reason videos don't play on the blog ...
# 32            Qt  WASM is a new supported platform, but Qt Accou...
# 35            Qt  Dear, \r\n\r\nThis is new partner registration...
# ...          ...                                                ...
# 99208         Qt  In JS, "KeyboardEvent.code" is intended to ref...
# 99231         Qt  In file _*qtbase/examples/widgets/itemviews/fr...
# 99243         Qt  There is a problem with the code style\r\n\r\n...
# 99351         Qt  In  *_qtbase/src/3rdparty/libpng/png.c_*_,_  t...
# 99398         Qt  {code:c++}\r\n#include <QApplication>\r\n#incl...
#
#                                               text_clean class_original class  \
# 16     the qt designer manual does not appear to link...           High  rest
# 27     across all qt and qt automotive suite document...           High  rest
# 30     for some reason videos dont play on the blog p...           High  rest
# 32     wasm is a new supported platform but qt accoun...           High  rest
# 35     dear this is new partner registration request ...           High  rest
# ...                                                  ...            ...   ...
# 99208  in js keyboardeventcode is intended to reflect...         Lowest  rest
# 99231  in file qtbaseexampleswidgetsitemviewsfrozenco...         Lowest  rest
# 99243             there is a problem with the code style         Lowest  rest
# 99351  in there is a line that reads written like thi...         Lowest  rest
# 99398  codec include include int mainint argc char ar...         Lowest  rest
#
#        label
# 16         0
# 27         0
# 30         0
# 32         0
# 35         0
# ...      ...
# 99208      0
# 99231      0
# 99243      0
# 99351      0
# 99398      0
#
# [97470 rows x 11 columns]

# %%
# Value count rest class
rest['class'].value_counts().to_frame()
# Out:
#        count
# class
# rest   97470

# %%
from sklearn.utils import shuffle
# Number of rows in the highest class
n_highest = highest.shape[0]

rest_sampled = rest.sample(n=n_highest, random_state=42)  


balanced_data = pd.concat([highest, rest_sampled])

# Shuffle the combined dataset
balanced_data = shuffle(balanced_data, random_state=42)
balanced_data
# Out:
#                      priority  \
# 31125           P2: Important
# 47697             P0: Blocker
# 10965           P2: Important
# 95962           P2: Important
# 62146             P0: Blocker
# ...                       ...
# 57178             P0: Blocker
# 69816             P0: Blocker
# 34382             P0: Blocker
# 46892  P3: Somewhat important
# 67398            P1: Critical
#
#                                              description       project  \
# 31125  Using this example (run via qmlscene):\r\n{cod...            Qt
# 47697  If I happen to get two modal dialogs open at t...            Qt
# 10965  The attached screenshot shows that the Zapfino...            Qt
# 95962  Hello!\r\n\r\nI have some issues with MySQL/Op...            Qt
# 62146  We have a few updates to WebKit that the WebKi...            Qt
# ...                                                  ...           ...
# 57178  This was actually with the 4.7.0-RC1 package.\...            Qt
# 69816  A fairly sure way to cause this crash is to in...  Qt 3D Studio
# 34382  It seems every example in the dev branch curre...            Qt
# 46892  The style seems to have a few rough edges:\n\n...            Qt
# 67398  Steps to repro:\r\n * create new presentation\...  Qt 3D Studio
#
#                     labels issuetype collection  \
# 31125                   []       Bug         Qt
# 47697      ['Creator_Qt5']       Bug         Qt
# 10965                   []       Bug         Qt
# 95962                   []       Bug         Qt
# 62146                   []      Task         Qt
# ...                    ...       ...        ...
# 57178                   []       Bug         Qt
# 69816                   []       Bug         Qt
# 34382                   []       Bug         Qt
# 46892  ['Jira_Expiry_Tag']       Bug         Qt
# 67398                   []       Bug         Qt
#
#                                                 text_str  \
# 31125  Using this example (run via qmlscene):\r\n{cod...
# 47697  If I happen to get two modal dialogs open at t...
# 10965  The attached screenshot shows that the Zapfino...
# 95962  Hello!\r\n\r\nI have some issues with MySQL/Op...
# 62146  We have a few updates to WebKit that the WebKi...
# ...                                                  ...
# 57178  This was actually with the 4.7.0-RC1 package.\...
# 69816  A fairly sure way to cause this crash is to in...
# 34382  It seems every example in the dev branch curre...
# 46892  The style seems to have a few rough edges:\n\n...
# 67398  Steps to repro:\r\n * create new presentation\...
#
#                                               text_clean    class  label  \
# 31125  using this example run via qmlscene code impor...     rest      0
# 47697  if i happen to get two modal dialogs open at t...  highest      1
# 10965  the attached screenshot shows that the zapfino...     rest      0
# 95962  hello i have some issues with mysqlopenssl lib...     rest      0
# 62146  we have a few updates to webkit that the webki...  highest      1
# ...                                                  ...      ...    ...
# 57178  this was actually with the packageto reproduce...  highest      1
# 69816  a fairly sure way to cause this crash is to in...  highest      1
# 34382  it seems every example in the dev branch curre...  highest      1
# 46892  the style seems to have a few rough edgesthere...     rest      0
# 67398  steps to repro create new presentation add a l...     rest      0
#
#       class_original
# 31125         Medium
# 47697        Highest
# 10965         Medium
# 95962         Medium
# 62146        Highest
# ...              ...
# 57178        Highest
# 69816        Highest
# 34382        Highest
# 46892            Low
# 67398           High
#
# [3882 rows x 11 columns]

# %%
balanced_data['class'].value_counts().to_frame()
# Out:
#          count
# class
# rest      1941
# highest   1941

# %%
balanced_data
# Out:
#                      priority  \
# 31125           P2: Important
# 47697             P0: Blocker
# 10965           P2: Important
# 95962           P2: Important
# 62146             P0: Blocker
# ...                       ...
# 57178             P0: Blocker
# 69816             P0: Blocker
# 34382             P0: Blocker
# 46892  P3: Somewhat important
# 67398            P1: Critical
#
#                                              description       project  \
# 31125  Using this example (run via qmlscene):\r\n{cod...            Qt
# 47697  If I happen to get two modal dialogs open at t...            Qt
# 10965  The attached screenshot shows that the Zapfino...            Qt
# 95962  Hello!\r\n\r\nI have some issues with MySQL/Op...            Qt
# 62146  We have a few updates to WebKit that the WebKi...            Qt
# ...                                                  ...           ...
# 57178  This was actually with the 4.7.0-RC1 package.\...            Qt
# 69816  A fairly sure way to cause this crash is to in...  Qt 3D Studio
# 34382  It seems every example in the dev branch curre...            Qt
# 46892  The style seems to have a few rough edges:\n\n...            Qt
# 67398  Steps to repro:\r\n * create new presentation\...  Qt 3D Studio
#
#                     labels issuetype collection  \
# 31125                   []       Bug         Qt
# 47697      ['Creator_Qt5']       Bug         Qt
# 10965                   []       Bug         Qt
# 95962                   []       Bug         Qt
# 62146                   []      Task         Qt
# ...                    ...       ...        ...
# 57178                   []       Bug         Qt
# 69816                   []       Bug         Qt
# 34382                   []       Bug         Qt
# 46892  ['Jira_Expiry_Tag']       Bug         Qt
# 67398                   []       Bug         Qt
#
#                                                 text_str  \
# 31125  Using this example (run via qmlscene):\r\n{cod...
# 47697  If I happen to get two modal dialogs open at t...
# 10965  The attached screenshot shows that the Zapfino...
# 95962  Hello!\r\n\r\nI have some issues with MySQL/Op...
# 62146  We have a few updates to WebKit that the WebKi...
# ...                                                  ...
# 57178  This was actually with the 4.7.0-RC1 package.\...
# 69816  A fairly sure way to cause this crash is to in...
# 34382  It seems every example in the dev branch curre...
# 46892  The style seems to have a few rough edges:\n\n...
# 67398  Steps to repro:\r\n * create new presentation\...
#
#                                               text_clean    class  label  \
# 31125  using this example run via qmlscene code impor...     rest      0
# 47697  if i happen to get two modal dialogs open at t...  highest      1
# 10965  the attached screenshot shows that the zapfino...     rest      0
# 95962  hello i have some issues with mysqlopenssl lib...     rest      0
# 62146  we have a few updates to webkit that the webki...  highest      1
# ...                                                  ...      ...    ...
# 57178  this was actually with the packageto reproduce...  highest      1
# 69816  a fairly sure way to cause this crash is to in...  highest      1
# 34382  it seems every example in the dev branch curre...  highest      1
# 46892  the style seems to have a few rough edgesthere...     rest      0
# 67398  steps to repro create new presentation add a l...     rest      0
#
#       class_original
# 31125         Medium
# 47697        Highest
# 10965         Medium
# 95962         Medium
# 62146        Highest
# ...              ...
# 57178        Highest
# 69816        Highest
# 34382        Highest
# 46892            Low
# 67398           High
#
# [3882 rows x 11 columns]

# %%
# Count label
balanced_data['label'].value_counts().to_frame()
# Out:
#        count
# label
# 0       1941
# 1       1941

# %%
# Count original class
balanced_data['class_original'].value_counts().to_frame()
# Out:
#                 count
# class_original
# Highest          1941
# Medium            892
# Low               543
# High              362
# Lowest            144

# %%
balanced_data = balanced_data[['text_clean', 'label']]
balanced_data
# Out:
#                                               text_clean  label
# 31125  using this example run via qmlscene code impor...      0
# 47697  if i happen to get two modal dialogs open at t...      1
# 10965  the attached screenshot shows that the zapfino...      0
# 95962  hello i have some issues with mysqlopenssl lib...      0
# 62146  we have a few updates to webkit that the webki...      1
# ...                                                  ...    ...
# 57178  this was actually with the packageto reproduce...      1
# 69816  a fairly sure way to cause this crash is to in...      1
# 34382  it seems every example in the dev branch curre...      1
# 46892  the style seems to have a few rough edgesthere...      0
# 67398  steps to repro create new presentation add a l...      0
#
# [3882 rows x 2 columns]

# %%
# Save to csv
full_file_name = f'../csv/{file_name}_balanced.csv'
balanced_data.to_csv(full_file_name, index=False)

# %%
# Read csv
df = pd.read_csv(full_file_name)
df
# Out:
#                                              text_clean  label
# 0     using this example run via qmlscene code impor...      0
# 1     if i happen to get two modal dialogs open at t...      1
# 2     the attached screenshot shows that the zapfino...      0
# 3     hello i have some issues with mysqlopenssl lib...      0
# 4     we have a few updates to webkit that the webki...      1
# ...                                                 ...    ...
# 3877  this was actually with the packageto reproduce...      1
# 3878  a fairly sure way to cause this crash is to in...      1
# 3879  it seems every example in the dev branch curre...      1
# 3880  the style seems to have a few rough edgesthere...      0
# 3881  steps to repro create new presentation add a l...      0
#
# [3882 rows x 2 columns]
