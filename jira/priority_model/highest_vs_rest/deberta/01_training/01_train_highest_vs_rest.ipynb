# %% [markdown]
# # Training
# This notebook trains the model with 3 fold cross validation.

# %% [markdown]
# # Imports and setup

# %%
import sys
# Need this to load the packages correc in Fox ml nodes.
sys.path.append("/fp/homes01/u01/ec-krimhau/.local/lib/python3.11/site-packages")

# %%
import os
import gc
import copy
import time
import random
import string
import joblib

# For data manipulation
import numpy as np
import pandas as pd

# Pytorch Imports
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import Dataset, DataLoader

# Utils
from tqdm import tqdm
from collections import defaultdict

# Sklearn Imports
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GroupKFold, KFold

# For Transformer Models
from transformers import AutoTokenizer, AutoModel, AutoConfig, AdamW
from transformers import DataCollatorWithPadding
import datasets
# For colored terminal text
from colorama import Fore, Back, Style
b_ = Fore.BLUE
y_ = Fore.YELLOW
sr_ = Style.RESET_ALL

# Suppress warnings
import warnings
warnings.filterwarnings("ignore")

# For descriptive error messages
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

import wandb

# %%
# Load .env file
# %load_ext dotenv
# %dotenv /fp/homes01/u01/ec-krimhau/thesis_code/.env

# %%
os.environ['WANDB_NOTEBOOK_NAME'] = '/fp/homes01/u01/ec-krimhau/thesis_code/jira/priority_model/highest_vs_rest/deberta/01_training/01_train_highest_vs_rest.ipynb'
# Get wandb api key from .env file
wandb_api_key = os.getenv('WANDB_API_KEY')
# Login to wandb to track results
wandb.login(key = wandb_api_key) # API key
# Out:
# wandb: Currently logged in as: haugerud-kristian (krimhau). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /fp/homes01/u01/ec-krimhau/.netrc
# True

# %%
# Function to generate a unique random identifier for experiment tracking.
def id_generator(size=12, chars=string.ascii_lowercase + string.digits):
    return ''.join(random.SystemRandom().choice(chars) for _ in range(size))


HASH_NAME = id_generator(size=12)
print(HASH_NAME)
# Out:
# kmyc4k23vc47

# %%
# Config for the model
CONFIG = {"seed": 42,
          "epochs": 3,
          "model_name": "microsoft/deberta-v3-base",
          "train_batch_size": 8,
          "valid_batch_size": 16,
          "max_length": 512,
          "learning_rate": 1e-5,
          "scheduler": 'CosineAnnealingLR',
          "min_lr": 1e-6,
          "T_max": 500,
          "weight_decay": 1e-6,
          "n_fold": 3,
          "n_accumulate": 1,
          "num_classes": 2,
          "device": torch.device("cuda:0" if torch.cuda.is_available() else "cpu"),
          "hash_name": HASH_NAME,
          "_wandb_kernel": "deb",
          }

CONFIG["tokenizer"] = AutoTokenizer.from_pretrained(CONFIG['model_name'])
CONFIG['group'] = f'{HASH_NAME}-Baseline'

# %%
def set_seed(seed=42):
    '''Sets the seed of the entire notebook so results are the same every time we run.
    This is for REPRODUCIBILITY.'''
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    # When running on the CuDNN backend, two further options must be set
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    # Set a fixed value for the hash seed
    os.environ['PYTHONHASHSEED'] = str(seed)
    
set_seed(CONFIG['seed'])

# %%
# Splits the data into train and test. Validation is done using KFold.
def train_test_split(df, train_percent=.85, seed=42):
    np.random.seed(seed)
    perm = np.random.permutation(df.index)
    m = len(df.index)
    train_end = int(train_percent * m)
    train = df.iloc[perm[:train_end]]
    test = df.iloc[perm[train_end:]]
    return train, test

# %%
priority_df = pd.read_csv("../csv/highest_vs_rest_balanced_jira.csv" , index_col = 0)
priority_df
# Out:
#                                                 text_clean  label  \
# class
# highest  when we do range query on simple keys it does ...      1
# highest  unhandledpromiserejectionwarning unhandled pro...      1
# rest     the fabricunittestdaily branch failing intermi...      0
# rest     as a system operator i want to receive alerts ...      0
# rest     there is no support in datasourcetransactionma...      0
# ...                                                    ...    ...
# rest     once i have imported a widget into the store i...      0
# rest     the spec defines an axiom of a ie singleton li...      0
# rest     to have an history on master of all csvs setup...      0
# highest  there are still some changes expected to be me...      1
# highest  crw failed to install from operatorhub because...      1
#
#         class_original
# class
# highest        Highest
# highest        Highest
# rest            Medium
# rest            Medium
# rest            Medium
# ...                ...
# rest               Low
# rest            Medium
# rest            Medium
# highest        Highest
# highest        Highest
#
# [110716 rows x 3 columns]

# %%
# Drop NaN values and reset index of dataframe
priority_df = priority_df[priority_df['text_clean'].notna()]
priority_df = priority_df.rename(columns={'text_clean': 'text'})
priority_df = priority_df.reset_index()
priority_df.drop(columns=["class", "class_original"], inplace=True)

# %%
priority_df
# Out:
#                                                      text  label
# 0       when we do range query on simple keys it does ...      1
# 1       unhandledpromiserejectionwarning unhandled pro...      1
# 2       the fabricunittestdaily branch failing intermi...      0
# 3       as a system operator i want to receive alerts ...      0
# 4       there is no support in datasourcetransactionma...      0
# ...                                                   ...    ...
# 110711  once i have imported a widget into the store i...      0
# 110712  the spec defines an axiom of a ie singleton li...      0
# 110713  to have an history on master of all csvs setup...      0
# 110714  there are still some changes expected to be me...      1
# 110715  crw failed to install from operatorhub because...      1
#
# [110716 rows x 2 columns]

# %%
train_hp_df , test_hp_df = train_test_split(priority_df)

# %%
df = train_hp_df

# %%
df.reset_index(inplace = True)

# %%
df.drop(columns=["index"], inplace=True)

# %%
df
# Out:
#                                                     text  label
# 0      currently we are using usrshareelasticsearch a...      0
# 1      its been over hrs since the mirror has been up...      0
# 2      there has been discussion on the mailing lists...      0
# 3      when elytron client tries to obtain clientconf...      1
# 4      need to be able to release all items at once v...      1
# ...                                                  ...    ...
# 94103  this was discussed in the pr args will be kept...      0
# 94104  the take and filter kernels do not currently s...      0
# 94105  currently pointing to out of date links names ...      1
# 94106  the chaincode build image relies on accessing ...      1
# 94107  if i create a converter plugin with converterk...      1
#
# [94108 rows x 2 columns]

# %%
gkf = GroupKFold(n_splits=CONFIG['n_fold'])

for fold, ( _, val_) in enumerate(gkf.split(X=df, groups=df.text)):
    df.loc[val_ , "kfold"] = int(fold)
    
df["kfold"] = df["kfold"].astype(int)

# %%
df.groupby('kfold')['label'].value_counts()
# Out:
# kfold  label
# 0      1        15814
#        0        15556
# 1      0        15783
#        1        15586
# 2      0        15685
#        1        15684
# Name: count, dtype: int64

# %%
df
# Out:
#                                                     text  label  kfold
# 0      currently we are using usrshareelasticsearch a...      0      2
# 1      its been over hrs since the mirror has been up...      0      0
# 2      there has been discussion on the mailing lists...      0      0
# 3      when elytron client tries to obtain clientconf...      1      1
# 4      need to be able to release all items at once v...      1      2
# ...                                                  ...    ...    ...
# 94103  this was discussed in the pr args will be kept...      0      0
# 94104  the take and filter kernels do not currently s...      0      2
# 94105  currently pointing to out of date links names ...      1      2
# 94106  the chaincode build image relies on accessing ...      1      2
# 94107  if i create a converter plugin with converterk...      1      0
#
# [94108 rows x 3 columns]

# %%
class HP_Dataset(Dataset):
    def __init__(self, df, tokenizer, max_length):
        self.df = df
        self.max_len = max_length
        self.tokenizer = tokenizer
        self.text = df['text'].values
        self.targets = df['label'].values
        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, index):
        text = self.text[index]
        inputs = self.tokenizer.encode_plus(
                        text,
                        truncation=True,
                        add_special_tokens=True,
                        max_length=self.max_len
                    )
        
        return {
            'input_ids': inputs['input_ids'],
            'attention_mask': inputs['attention_mask'],
            'target': self.targets[index]
        }

# %%
collate_fn = DataCollatorWithPadding(tokenizer=CONFIG['tokenizer'])

# %%
class MeanPooling(nn.Module):
    def __init__(self):
        super(MeanPooling, self).__init__()
        
    def forward(self, last_hidden_state, attention_mask):
        input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        sum_mask = input_mask_expanded.sum(1)
        sum_mask = torch.clamp(sum_mask, min=1e-9)
        mean_embeddings = sum_embeddings / sum_mask
        return mean_embeddings

# %%
class HP_Model(nn.Module):
    def __init__(self, model_name):
        super(HP_Model, self).__init__()
        self.model = AutoModel.from_pretrained(model_name)
        self.config = AutoConfig.from_pretrained(model_name)
        self.drop = nn.Dropout(p=0.2)
        self.pooler = MeanPooling()
        self.fc = nn.Linear(self.config.hidden_size, CONFIG['num_classes'])
        
    def forward(self, ids, mask):        
        out = self.model(input_ids=ids,attention_mask=mask,
                         output_hidden_states=False)
        out = self.pooler(out.last_hidden_state, mask)
        out = self.drop(out)
        outputs = self.fc(out)
        return outputs

# %%
def criterion(outputs, labels):
    return nn.CrossEntropyLoss()(outputs, labels)

# %%
def train_one_epoch(model, optimizer, scheduler, dataloader, device, epoch):
    model.train()
    
    dataset_size = 0
    running_loss = 0.0
    
    bar = tqdm(enumerate(dataloader), total=len(dataloader))
    for step, data in bar:
        ids = data['input_ids'].to(device, dtype = torch.long)
        mask = data['attention_mask'].to(device, dtype = torch.long)
        targets = data['target'].to(device, dtype=torch.long)
        
        batch_size = ids.size(0)

        outputs = model(ids, mask)
        
        loss = criterion(outputs, targets)
        loss = loss / CONFIG['n_accumulate']
        loss.backward()
    
        if (step + 1) % CONFIG['n_accumulate'] == 0:
            optimizer.step()

            # zero the parameter gradients
            optimizer.zero_grad()

            if scheduler is not None:
                scheduler.step()
                
        running_loss += (loss.item() * batch_size)
        dataset_size += batch_size
        
        epoch_loss = running_loss / dataset_size
        
        bar.set_postfix(Epoch=epoch, Train_Loss=epoch_loss,
                        LR=optimizer.param_groups[0]['lr'])
    gc.collect()
    
    return epoch_loss

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

# %%
def all_classification_report(y_true, y_pred, target_names = ['Non_HP', 'HP'], digits=4):
    
    print('Classification Report:')
    print(classification_report(y_true, y_pred, target_names = target_names, digits=4))
    
    accuracy =round(accuracy_score(y_true, y_pred),4)
    print("Accuracy =",  accuracy)
    f1score = round(f1_score(y_true, y_pred),4)
    print("F1_score =", f1score)

    cm = confusion_matrix(y_true, y_pred, labels=[1,0])
    ax= plt.subplot()
    sns.heatmap(cm, annot=True, ax = ax, cmap='Blues', fmt="d")

    ax.set_title('Confusion Matrix')

    ax.set_xlabel('Predicted Labels')
    ax.set_ylabel('True Labels')

    ax.xaxis.set_ticklabels(['Non_HP', 'HP'])
    ax.yaxis.set_ticklabels(['Non_HP', 'HP'])
    
    return  accuracy , f1score

# %%
@torch.no_grad()
def valid_one_epoch(model, dataloader, device, epoch):
    model.eval()
    dataset_size = 0
    running_loss = 0.0
    
    y_pred = []
    y_true = []
    
    bar = tqdm(enumerate(dataloader), total=len(dataloader))
    for step, data in bar:        
        ids = data['input_ids'].to(device, dtype = torch.long)
        mask = data['attention_mask'].to(device, dtype = torch.long)
        targets = data['target'].to(device, dtype=torch.long)
        
        batch_size = ids.size(0)

        outputs = model(ids, mask)
        
        loss = criterion(outputs, targets)
        

        predictions = torch.argmax(outputs, dim=-1).flatten().tolist()
        
        target = targets.tolist()

        y_pred.extend(predictions)
        y_true.extend(target)
        running_loss += (loss.item() * batch_size)
        dataset_size += batch_size
        
        epoch_loss = running_loss / dataset_size
        
        bar.set_postfix(Epoch=epoch, Valid_Loss=epoch_loss,LR=optimizer.param_groups[0]['lr'])   
    
    
    accuracy, f1score = all_classification_report(y_true,y_pred)
    gc.collect()
    
    return epoch_loss , accuracy , f1score

# %%
from codecarbon import track_emissions
@track_emissions()
def run_training(model, optimizer, scheduler, device, num_epochs, fold):
    # To automatically log gradients
    wandb.watch(model, log_freq=100)
    
    if torch.cuda.is_available():
        print("[INFO] Using GPU: {}\n".format(torch.cuda.get_device_name()))
    
    start = time.time()
    best_model_wts = copy.deepcopy(model.state_dict())
    best_epoch_loss = np.inf
    history = defaultdict(list)
    
    for epoch in range(1, num_epochs + 1): 
        gc.collect()
        train_epoch_loss = train_one_epoch(model, optimizer, scheduler, 
                                           dataloader=train_loader, 
                                           device=CONFIG['device'], epoch=epoch)
        
        val_epoch_loss, accuracy , f1score = valid_one_epoch(model, valid_loader, device=CONFIG['device'], 
                                         epoch=epoch)
    
        history['Train Loss'].append(train_epoch_loss)
        history['Valid Loss'].append(val_epoch_loss)
      
        history['Valid accuracy'].append(accuracy)
        history['Valid f1score'].append(f1score)



        
        # Log the metrics
        wandb.log({"Train Loss": train_epoch_loss})
        wandb.log({"Valid Loss": val_epoch_loss})
        wandb.log({"Valid Accuracy": accuracy})
        wandb.log({"Valid F1_score": f1score})


        
        # deep copy the model
        if val_epoch_loss <= best_epoch_loss:
            print(f"{b_}Validation Loss Improved ({best_epoch_loss} ---> {val_epoch_loss})")
            best_epoch_loss = val_epoch_loss
            run.summary["Best Loss"] = best_epoch_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            PATH = f"{HASH_NAME}-Loss-Fold-{fold}.bin"
            torch.save(model.state_dict(), PATH)
            # Save a model file from the current directory
            print(f"Model Saved{sr_}")
            
        print()
    
    end = time.time()
    time_elapsed = end - start
    print('Training complete in {:.0f}h {:.0f}m {:.0f}s'.format(
        time_elapsed // 3600, (time_elapsed % 3600) // 60, (time_elapsed % 3600) % 60))
    print("Best Loss: {:.4f}".format(best_epoch_loss))
    
    # load best model weights
    model.load_state_dict(best_model_wts)
    
    return model, history

# %%
def prepare_loaders(fold):
    df_train = df[df.kfold != fold].reset_index(drop=True)
    df_valid = df[df.kfold == fold].reset_index(drop=True)
    
    train_dataset = HP_Dataset(df_train, tokenizer=CONFIG['tokenizer'], max_length=CONFIG['max_length'])
    valid_dataset = HP_Dataset(df_valid, tokenizer=CONFIG['tokenizer'], max_length=CONFIG['max_length'])

    train_loader = DataLoader(train_dataset, batch_size=CONFIG['train_batch_size'], collate_fn=collate_fn, 
                              num_workers=2, shuffle=True, pin_memory=True, drop_last=True)
    valid_loader = DataLoader(valid_dataset, batch_size=CONFIG['valid_batch_size'], collate_fn=collate_fn,
                              num_workers=2, shuffle=False, pin_memory=True)
    
    return train_loader, valid_loader

# %%
def fetch_scheduler(optimizer):
    if CONFIG['scheduler'] == 'CosineAnnealingLR':
        scheduler = lr_scheduler.CosineAnnealingLR(optimizer,T_max=CONFIG['T_max'], 
                                                   eta_min=CONFIG['min_lr'])
    elif CONFIG['scheduler'] == 'CosineAnnealingWarmRestarts':
        scheduler = lr_scheduler.CosineAnnealingWarmRestarts(optimizer,T_0=CONFIG['T_0'], 
                                                             eta_min=CONFIG['min_lr'])
    elif CONFIG['scheduler'] == None:
        return None
        
    return scheduler

# %%
for fold in range(0, CONFIG['n_fold']):
    print(f"{y_}====== Fold: {fold} ======{sr_}")
    run = wandb.init(project='HP_results_Jira_High_vs_rest_results', 
                     config=CONFIG,
                     job_type='Train',
                     group=CONFIG['group'],
                     tags=[CONFIG['model_name'], f'{HASH_NAME}'],
                     name=f'{HASH_NAME}-fold-{fold}',
                     anonymous='must')
    
    # Create Dataloaders
    train_loader, valid_loader = prepare_loaders(fold=fold)
    
    model = HP_Model(CONFIG['model_name'])
    model.to(CONFIG['device'])
    
    # Define Optimizer and Scheduler
    optimizer = AdamW(model.parameters(), lr=CONFIG['learning_rate'], weight_decay=CONFIG['weight_decay'])
    scheduler = fetch_scheduler(optimizer)
    
    model, history = run_training(model, optimizer, scheduler,
                                  device=CONFIG['device'],
                                  num_epochs=CONFIG['epochs'],
                                  fold=fold)
    
    run.finish()
    
    del model, history, train_loader, valid_loader
    _ = gc.collect()
    print()
# Out:
# ====== Fold: 0 ======
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/fp/homes01/u01/ec-krimhau/thesis_code/jira/priority_model/highest_vs_rest/deberta/01_training/wandb/run-20240319_114618-kmim3cnx</code>
# Syncing run <strong><a href='https://wandb.ai/krimhau/HP_results_Jira_High_vs_rest_results/runs/kmim3cnx' target="_blank">kmyc4k23vc47-fold-0</a></strong> to <a href='https://wandb.ai/krimhau/HP_results_Jira_High_vs_rest_results' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/krimhau/HP_results_Jira_High_vs_rest_results' target="_blank">https://wandb.ai/krimhau/HP_results_Jira_High_vs_rest_results</a>
#  View run at <a href='https://wandb.ai/krimhau/HP_results_Jira_High_vs_rest_results/runs/kmim3cnx' target="_blank">https://wandb.ai/krimhau/HP_results_Jira_High_vs_rest_results/runs/kmim3cnx</a>
# [codecarbon INFO @ 11:46:24] [setup] RAM Tracking...
# [codecarbon INFO @ 11:46:24] [setup] GPU Tracking...
# [codecarbon INFO @ 11:46:24] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 11:46:24] [setup] CPU Tracking...
# [codecarbon WARNING @ 11:46:24] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon WARNING @ 11:46:27] We saw that you have a AMD EPYC 7642 48-Core Processor but we don't know it. Please contact us.
# [codecarbon INFO @ 11:46:27] CPU Model on constant consumption mode: AMD EPYC 7642 48-Core Processor
# [codecarbon INFO @ 11:46:27] >>> Tracker's metadata:
# [codecarbon INFO @ 11:46:27]   Platform system: Linux-5.14.0-362.8.1.el9_3.x86_64-x86_64-with-glibc2.34
# [codecarbon INFO @ 11:46:27]   Python version: 3.11.3
# [codecarbon INFO @ 11:46:27]   CodeCarbon version: 2.3.4
# [codecarbon INFO @ 11:46:27]   Available RAM : 256.000 GB
# [codecarbon INFO @ 11:46:27]   CPU count: 24
# [codecarbon INFO @ 11:46:27]   CPU model: AMD EPYC 7642 48-Core Processor
# [codecarbon INFO @ 11:46:27]   GPU count: 1
# [codecarbon INFO @ 11:46:27]   GPU model: 1 x NVIDIA A100-PCIE-40GB
# [INFO] Using GPU: NVIDIA A100-PCIE-40GB
#   1%|          | 65/7842 [00:14<22:00,  5.89it/s, Epoch=1, LR=9.63e-6, Train_Loss=0.719][codecarbon INFO @ 11:46:45] Energy consumed for RAM : 0.000400 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:46:45] Energy consumed for all GPUs : 0.000734 kWh. Total GPU Power : 176.13753032088954 W
# [codecarbon INFO @ 11:46:45] Energy consumed for all CPUs : 0.000177 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:46:45] 0.001312 kWh of electricity used since the beginning.
#   2%|▏         | 132/7842 [00:29<28:38,  4.49it/s, Epoch=1, LR=8.54e-6, Train_Loss=0.692][codecarbon INFO @ 11:47:00] Energy consumed for RAM : 0.000800 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:47:00] Energy consumed for all GPUs : 0.001482 kWh. Total GPU Power : 179.41096693129035 W
# [codecarbon INFO @ 11:47:00] Energy consumed for all CPUs : 0.000354 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:47:00] 0.002636 kWh of electricity used since the beginning.
#   3%|▎         | 199/7842 [00:44<31:16,  4.07it/s, Epoch=1, LR=6.92e-6, Train_Loss=0.68] [codecarbon INFO @ 11:47:15] Energy consumed for RAM : 0.001200 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:47:15] Energy consumed for all GPUs : 0.002247 kWh. Total GPU Power : 183.64359365648224 W
# [codecarbon INFO @ 11:47:15] Energy consumed for all CPUs : 0.000531 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:47:15] 0.003978 kWh of electricity used since the beginning.
#   3%|▎         | 263/7842 [00:59<31:25,  4.02it/s, Epoch=1, LR=5.13e-6, Train_Loss=0.669][codecarbon INFO @ 11:47:30] Energy consumed for RAM : 0.001600 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:47:30] Energy consumed for all GPUs : 0.003035 kWh. Total GPU Power : 189.22058544284275 W
# [codecarbon INFO @ 11:47:30] Energy consumed for all CPUs : 0.000708 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:47:30] 0.005343 kWh of electricity used since the beginning.
#   4%|▍         | 330/7842 [01:14<30:16,  4.13it/s, Epoch=1, LR=3.33e-6, Train_Loss=0.668][codecarbon INFO @ 11:47:45] Energy consumed for RAM : 0.001999 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:47:45] Energy consumed for all GPUs : 0.003811 kWh. Total GPU Power : 186.3846356122254 W
# [codecarbon INFO @ 11:47:45] Energy consumed for all CPUs : 0.000886 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:47:45] 0.006696 kWh of electricity used since the beginning.
#   5%|▌         | 397/7842 [01:29<31:35,  3.93it/s, Epoch=1, LR=1.91e-6, Train_Loss=0.663][codecarbon INFO @ 11:48:00] Energy consumed for RAM : 0.002399 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:48:00] Energy consumed for all GPUs : 0.004601 kWh. Total GPU Power : 189.81317338703286 W
# [codecarbon INFO @ 11:48:00] Energy consumed for all CPUs : 0.001063 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:48:00] 0.008063 kWh of electricity used since the beginning.
#   6%|▌         | 462/7842 [01:44<22:51,  5.38it/s, Epoch=1, LR=1.13e-6, Train_Loss=0.66] [codecarbon INFO @ 11:48:15] Energy consumed for RAM : 0.002799 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:48:15] Energy consumed for all GPUs : 0.005397 kWh. Total GPU Power : 190.9897281747921 W
# [codecarbon INFO @ 11:48:15] Energy consumed for all CPUs : 0.001240 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:48:15] 0.009436 kWh of electricity used since the beginning.
#   7%|▋         | 527/7842 [01:59<24:21,  5.01it/s, Epoch=1, LR=1.06e-6, Train_Loss=0.659][codecarbon INFO @ 11:48:30] Energy consumed for RAM : 0.003199 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:48:30] Energy consumed for all GPUs : 0.006206 kWh. Total GPU Power : 194.23841163583205 W
# [codecarbon INFO @ 11:48:30] Energy consumed for all CPUs : 0.001417 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:48:30] 0.010822 kWh of electricity used since the beginning.
#   8%|▊         | 597/7842 [02:14<25:43,  4.69it/s, Epoch=1, LR=1.81e-6, Train_Loss=0.656][codecarbon INFO @ 11:48:45] Energy consumed for RAM : 0.003599 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:48:45] Energy consumed for all GPUs : 0.007001 kWh. Total GPU Power : 190.77625358829593 W
# [codecarbon INFO @ 11:48:45] Energy consumed for all CPUs : 0.001594 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:48:45] 0.012193 kWh of electricity used since the beginning.
#   8%|▊         | 659/7842 [02:29<30:04,  3.98it/s, Epoch=1, LR=3.06e-6, Train_Loss=0.657][codecarbon INFO @ 11:49:00] Energy consumed for RAM : 0.003999 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:49:00] Energy consumed for all GPUs : 0.007820 kWh. Total GPU Power : 196.69601543625566 W
# [codecarbon INFO @ 11:49:00] Energy consumed for all CPUs : 0.001771 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:49:00] 0.013589 kWh of electricity used since the beginning.
#   9%|▉         | 727/7842 [02:44<26:46,  4.43it/s, Epoch=1, LR=4.85e-6, Train_Loss=0.656][codecarbon INFO @ 11:49:15] Energy consumed for RAM : 0.004398 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:49:15] Energy consumed for all GPUs : 0.008629 kWh. Total GPU Power : 194.1917456563876 W
# [codecarbon INFO @ 11:49:15] Energy consumed for all CPUs : 0.001948 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:49:15] 0.014975 kWh of electricity used since the beginning.
#  10%|█         | 792/7842 [02:59<28:48,  4.08it/s, Epoch=1, LR=6.67e-6, Train_Loss=0.654][codecarbon INFO @ 11:49:30] Energy consumed for RAM : 0.004798 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:49:30] Energy consumed for all GPUs : 0.009460 kWh. Total GPU Power : 199.60407284317756 W
# [codecarbon INFO @ 11:49:30] Energy consumed for all CPUs : 0.002125 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:49:30] 0.016384 kWh of electricity used since the beginning.
#  11%|█         | 862/7842 [03:14<19:49,  5.87it/s, Epoch=1, LR=8.41e-6, Train_Loss=0.653][codecarbon INFO @ 11:49:45] Energy consumed for RAM : 0.005198 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:49:45] Energy consumed for all GPUs : 0.010261 kWh. Total GPU Power : 192.36160280945964 W
# [codecarbon INFO @ 11:49:45] Energy consumed for all CPUs : 0.002302 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:49:45] 0.017761 kWh of electricity used since the beginning.
#  12%|█▏        | 932/7842 [03:29<26:14,  4.39it/s, Epoch=1, LR=9.6e-6, Train_Loss=0.653] [codecarbon INFO @ 11:50:00] Energy consumed for RAM : 0.005598 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:50:00] Energy consumed for all GPUs : 0.011063 kWh. Total GPU Power : 192.49537630470655 W
# [codecarbon INFO @ 11:50:00] Energy consumed for all CPUs : 0.002479 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:50:00] 0.019140 kWh of electricity used since the beginning.
#  13%|█▎        | 997/7842 [03:44<28:38,  3.98it/s, Epoch=1, LR=1e-5, Train_Loss=0.651]   [codecarbon INFO @ 11:50:15] Energy consumed for RAM : 0.005998 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:50:15] Energy consumed for all GPUs : 0.011898 kWh. Total GPU Power : 200.34139769553036 W
# [codecarbon INFO @ 11:50:15] Energy consumed for all CPUs : 0.002656 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:50:15] 0.020552 kWh of electricity used since the beginning.
#  14%|█▎        | 1061/7842 [03:59<26:11,  4.32it/s, Epoch=1, LR=9.67e-6, Train_Loss=0.65] [codecarbon INFO @ 11:50:30] Energy consumed for RAM : 0.006397 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:50:30] Energy consumed for all GPUs : 0.012731 kWh. Total GPU Power : 200.07284619453344 W
# [codecarbon INFO @ 11:50:30] Energy consumed for all CPUs : 0.002833 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:50:30] 0.021961 kWh of electricity used since the beginning.
#  14%|█▍        | 1126/7842 [04:14<25:58,  4.31it/s, Epoch=1, LR=8.66e-6, Train_Loss=0.649][codecarbon INFO @ 11:50:45] Energy consumed for RAM : 0.006797 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:50:45] Energy consumed for all GPUs : 0.013561 kWh. Total GPU Power : 199.28177770502901 W
# [codecarbon INFO @ 11:50:45] Energy consumed for all CPUs : 0.003010 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:50:45] 0.023368 kWh of electricity used since the beginning.
#  15%|█▌        | 1192/7842 [04:29<29:49,  3.72it/s, Epoch=1, LR=7.1e-6, Train_Loss=0.649] [codecarbon INFO @ 11:51:00] Energy consumed for RAM : 0.007197 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:51:00] Energy consumed for all GPUs : 0.014393 kWh. Total GPU Power : 199.8414247952024 W
# [codecarbon INFO @ 11:51:00] Energy consumed for all CPUs : 0.003187 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:51:00] 0.024778 kWh of electricity used since the beginning.
#  16%|█▌        | 1257/7842 [04:44<22:09,  4.95it/s, Epoch=1, LR=5.3e-6, Train_Loss=0.647] [codecarbon INFO @ 11:51:15] Energy consumed for RAM : 0.007597 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:51:15] Energy consumed for all GPUs : 0.015221 kWh. Total GPU Power : 198.8601427860244 W
# [codecarbon INFO @ 11:51:15] Energy consumed for all CPUs : 0.003365 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:51:15] 0.026183 kWh of electricity used since the beginning.
#  17%|█▋        | 1322/7842 [04:59<24:14,  4.48it/s, Epoch=1, LR=3.53e-6, Train_Loss=0.646][codecarbon INFO @ 11:51:30] Energy consumed for RAM : 0.007997 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:51:30] Energy consumed for all GPUs : 0.016055 kWh. Total GPU Power : 200.21778716183488 W
# [codecarbon INFO @ 11:51:30] Energy consumed for all CPUs : 0.003542 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:51:30] 0.027594 kWh of electricity used since the beginning.
#  18%|█▊        | 1388/7842 [05:14<21:53,  4.91it/s, Epoch=1, LR=2.07e-6, Train_Loss=0.645][codecarbon INFO @ 11:51:45] Energy consumed for RAM : 0.008397 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:51:45] Energy consumed for all GPUs : 0.016886 kWh. Total GPU Power : 199.47551313062735 W
# [codecarbon INFO @ 11:51:45] Energy consumed for all CPUs : 0.003719 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:51:45] 0.029002 kWh of electricity used since the beginning.
#  19%|█▊        | 1458/7842 [05:29<19:47,  5.38it/s, Epoch=1, LR=1.16e-6, Train_Loss=0.644][codecarbon INFO @ 11:52:00] Energy consumed for RAM : 0.008796 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:52:00] Energy consumed for all GPUs : 0.017690 kWh. Total GPU Power : 192.96193748956085 W
# [codecarbon INFO @ 11:52:00] Energy consumed for all CPUs : 0.003896 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:52:00] 0.030382 kWh of electricity used since the beginning.
#  19%|█▉        | 1525/7842 [05:44<19:26,  5.42it/s, Epoch=1, LR=1.06e-6, Train_Loss=0.643][codecarbon INFO @ 11:52:15] Energy consumed for RAM : 0.009196 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:52:15] Energy consumed for all GPUs : 0.018504 kWh. Total GPU Power : 195.53291581625388 W
# [codecarbon INFO @ 11:52:15] Energy consumed for all CPUs : 0.004073 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:52:15] 0.031774 kWh of electricity used since the beginning.
#  20%|██        | 1592/7842 [05:59<21:34,  4.83it/s, Epoch=1, LR=1.73e-6, Train_Loss=0.641][codecarbon INFO @ 11:52:30] Energy consumed for RAM : 0.009596 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:52:30] Energy consumed for all GPUs : 0.019332 kWh. Total GPU Power : 198.78007123581358 W
# [codecarbon INFO @ 11:52:30] Energy consumed for all CPUs : 0.004250 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:52:30] 0.033178 kWh of electricity used since the beginning.
#  21%|██        | 1661/7842 [06:14<20:09,  5.11it/s, Epoch=1, LR=3.11e-6, Train_Loss=0.641][codecarbon INFO @ 11:52:45] Energy consumed for RAM : 0.009996 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:52:45] Energy consumed for all GPUs : 0.020152 kWh. Total GPU Power : 196.69144910273295 W
# [codecarbon INFO @ 11:52:45] Energy consumed for all CPUs : 0.004427 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:52:45] 0.034575 kWh of electricity used since the beginning.
#  22%|██▏       | 1730/7842 [06:29<19:35,  5.20it/s, Epoch=1, LR=4.96e-6, Train_Loss=0.64] [codecarbon INFO @ 11:53:00] Energy consumed for RAM : 0.010396 kWh. RAM Power : 96.0 W
#  22%|██▏       | 1731/7842 [06:29<23:08,  4.40it/s, Epoch=1, LR=4.96e-6, Train_Loss=0.64][codecarbon INFO @ 11:53:00] Energy consumed for all GPUs : 0.020957 kWh. Total GPU Power : 193.43409570482208 W
# [codecarbon INFO @ 11:53:00] Energy consumed for all CPUs : 0.004604 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:53:00] 0.035957 kWh of electricity used since the beginning.
#  23%|██▎       | 1795/7842 [06:44<25:18,  3.98it/s, Epoch=1, LR=6.76e-6, Train_Loss=0.64] [codecarbon INFO @ 11:53:15] Energy consumed for RAM : 0.010796 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:53:15] Energy consumed for all GPUs : 0.021800 kWh. Total GPU Power : 202.20307463859876 W
# [codecarbon INFO @ 11:53:15] Energy consumed for all CPUs : 0.004781 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:53:15] 0.037376 kWh of electricity used since the beginning.
#  24%|██▎       | 1861/7842 [06:59<16:46,  5.94it/s, Epoch=1, LR=8.39e-6, Train_Loss=0.64] [codecarbon INFO @ 11:53:30] Energy consumed for RAM : 0.011195 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:53:30] Energy consumed for all GPUs : 0.022630 kWh. Total GPU Power : 199.37511911702967 W
# [codecarbon INFO @ 11:53:30] Energy consumed for all CPUs : 0.004958 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:53:30] 0.038784 kWh of electricity used since the beginning.
#  25%|██▍       | 1926/7842 [07:14<24:10,  4.08it/s, Epoch=1, LR=9.52e-6, Train_Loss=0.639][codecarbon INFO @ 11:53:45] Energy consumed for RAM : 0.011595 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:53:45] Energy consumed for all GPUs : 0.023463 kWh. Total GPU Power : 200.11782141285255 W
# [codecarbon INFO @ 11:53:45] Energy consumed for all CPUs : 0.005135 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:53:45] 0.040194 kWh of electricity used since the beginning.
#  25%|██▌       | 1991/7842 [07:29<20:38,  4.72it/s, Epoch=1, LR=9.99e-6, Train_Loss=0.639][codecarbon INFO @ 11:54:00] Energy consumed for RAM : 0.011995 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:54:00] Energy consumed for all GPUs : 0.024303 kWh. Total GPU Power : 201.5965544692769 W
# [codecarbon INFO @ 11:54:00] Energy consumed for all CPUs : 0.005312 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:54:00] 0.041611 kWh of electricity used since the beginning.
#  26%|██▌       | 2058/7842 [07:44<18:35,  5.18it/s, Epoch=1, LR=9.7e-6, Train_Loss=0.639] [codecarbon INFO @ 11:54:15] Energy consumed for RAM : 0.012395 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:54:15] Energy consumed for all GPUs : 0.025134 kWh. Total GPU Power : 199.51571522618917 W
# [codecarbon INFO @ 11:54:15] Energy consumed for all CPUs : 0.005489 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:54:15] 0.043018 kWh of electricity used since the beginning.
#  27%|██▋       | 2124/7842 [07:59<20:48,  4.58it/s, Epoch=1, LR=8.7e-6, Train_Loss=0.639] [codecarbon INFO @ 11:54:30] Energy consumed for RAM : 0.012795 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:54:30] Energy consumed for all GPUs : 0.025964 kWh. Total GPU Power : 199.3460316307263 W
# [codecarbon INFO @ 11:54:30] Energy consumed for all CPUs : 0.005667 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:54:30] 0.044426 kWh of electricity used since the beginning.
#  28%|██▊       | 2190/7842 [08:14<22:26,  4.20it/s, Epoch=1, LR=7.16e-6, Train_Loss=0.639][codecarbon INFO @ 11:54:45] Energy consumed for RAM : 0.013195 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:54:45] Energy consumed for all GPUs : 0.026796 kWh. Total GPU Power : 199.70463092204363 W
# [codecarbon INFO @ 11:54:45] Energy consumed for all CPUs : 0.005844 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:54:45] 0.045834 kWh of electricity used since the beginning.
#  29%|██▉       | 2256/7842 [08:29<20:15,  4.60it/s, Epoch=1, LR=5.33e-6, Train_Loss=0.638][codecarbon INFO @ 11:55:00] Energy consumed for RAM : 0.013594 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:55:00] Energy consumed for all GPUs : 0.027623 kWh. Total GPU Power : 198.5588715295768 W
# [codecarbon INFO @ 11:55:00] Energy consumed for all CPUs : 0.006021 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:55:00] 0.047238 kWh of electricity used since the beginning.
#  30%|██▉       | 2323/7842 [08:44<21:52,  4.21it/s, Epoch=1, LR=3.51e-6, Train_Loss=0.638][codecarbon INFO @ 11:55:15] Energy consumed for RAM : 0.013994 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:55:15] Energy consumed for all GPUs : 0.028450 kWh. Total GPU Power : 198.58033758057957 W
# [codecarbon INFO @ 11:55:15] Energy consumed for all CPUs : 0.006198 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:55:15] 0.048642 kWh of electricity used since the beginning.
#  31%|███       | 2393/7842 [08:59<21:17,  4.26it/s, Epoch=1, LR=1.98e-6, Train_Loss=0.637][codecarbon INFO @ 11:55:30] Energy consumed for RAM : 0.014394 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:55:30] Energy consumed for all GPUs : 0.029276 kWh. Total GPU Power : 198.14742061209614 W
# [codecarbon INFO @ 11:55:30] Energy consumed for all CPUs : 0.006375 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:55:30] 0.050045 kWh of electricity used since the beginning.
#  31%|███▏      | 2458/7842 [09:14<21:38,  4.14it/s, Epoch=1, LR=1.16e-6, Train_Loss=0.636][codecarbon INFO @ 11:55:45] Energy consumed for RAM : 0.014794 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:55:45] Energy consumed for all GPUs : 0.030107 kWh. Total GPU Power : 199.6921432002975 W
# [codecarbon INFO @ 11:55:45] Energy consumed for all CPUs : 0.006552 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:55:45] 0.051453 kWh of electricity used since the beginning.
#  32%|███▏      | 2521/7842 [09:29<17:24,  5.09it/s, Epoch=1, LR=1.04e-6, Train_Loss=0.635][codecarbon INFO @ 11:56:00] Energy consumed for RAM : 0.015194 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:56:00] Energy consumed for all GPUs : 0.030949 kWh. Total GPU Power : 202.00647528485953 W
# [codecarbon INFO @ 11:56:00] Energy consumed for all CPUs : 0.006729 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:56:00] 0.052871 kWh of electricity used since the beginning.
#  33%|███▎      | 2585/7842 [09:44<25:23,  3.45it/s, Epoch=1, LR=1.63e-6, Train_Loss=0.634][codecarbon INFO @ 11:56:15] Energy consumed for RAM : 0.015593 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:56:15] Energy consumed for all GPUs : 0.031793 kWh. Total GPU Power : 202.7286120052193 W
# [codecarbon INFO @ 11:56:15] Energy consumed for all CPUs : 0.006906 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:56:15] 0.054293 kWh of electricity used since the beginning.
#  34%|███▍      | 2651/7842 [09:59<16:10,  5.35it/s, Epoch=1, LR=2.88e-6, Train_Loss=0.633][codecarbon INFO @ 11:56:30] Energy consumed for RAM : 0.015993 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:56:30] Energy consumed for all GPUs : 0.032623 kWh. Total GPU Power : 199.35792775786584 W
# [codecarbon INFO @ 11:56:30] Energy consumed for all CPUs : 0.007083 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:56:30] 0.055700 kWh of electricity used since the beginning.
#  35%|███▍      | 2714/7842 [10:14<21:34,  3.96it/s, Epoch=1, LR=4.49e-6, Train_Loss=0.632][codecarbon INFO @ 11:56:45] Energy consumed for RAM : 0.016393 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:56:45] Energy consumed for all GPUs : 0.033466 kWh. Total GPU Power : 202.25491189602604 W
# [codecarbon INFO @ 11:56:45] Energy consumed for all CPUs : 0.007260 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:56:45] 0.057119 kWh of electricity used since the beginning.
#  36%|███▌      | 2785/7842 [10:29<16:27,  5.12it/s, Epoch=1, LR=6.48e-6, Train_Loss=0.632][codecarbon INFO @ 11:57:00] Energy consumed for RAM : 0.016793 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:57:00] Energy consumed for all GPUs : 0.034289 kWh. Total GPU Power : 197.71501359445622 W
# [codecarbon INFO @ 11:57:00] Energy consumed for all CPUs : 0.007437 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:57:00] 0.058520 kWh of electricity used since the beginning.
#  36%|███▋      | 2849/7842 [10:44<19:35,  4.25it/s, Epoch=1, LR=8.12e-6, Train_Loss=0.63] [codecarbon INFO @ 11:57:15] Energy consumed for RAM : 0.017193 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:57:15] Energy consumed for all GPUs : 0.035125 kWh. Total GPU Power : 200.70402079757508 W
# [codecarbon INFO @ 11:57:15] Energy consumed for all CPUs : 0.007614 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:57:15] 0.059932 kWh of electricity used since the beginning.
#  37%|███▋      | 2915/7842 [10:59<18:14,  4.50it/s, Epoch=1, LR=9.37e-6, Train_Loss=0.63] [codecarbon INFO @ 11:57:30] Energy consumed for RAM : 0.017592 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:57:30] Energy consumed for all GPUs : 0.035950 kWh. Total GPU Power : 197.99896540652202 W
# [codecarbon INFO @ 11:57:30] Energy consumed for all CPUs : 0.007791 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:57:30] 0.061334 kWh of electricity used since the beginning.
#  38%|███▊      | 2980/7842 [11:14<20:15,  4.00it/s, Epoch=1, LR=9.96e-6, Train_Loss=0.63] [codecarbon INFO @ 11:57:45] Energy consumed for RAM : 0.017992 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:57:45] Energy consumed for all GPUs : 0.036795 kWh. Total GPU Power : 202.781939424831 W
# [codecarbon INFO @ 11:57:45] Energy consumed for all CPUs : 0.007969 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:57:45] 0.062755 kWh of electricity used since the beginning.
#  39%|███▉      | 3043/7842 [11:29<24:06,  3.32it/s, Epoch=1, LR=9.84e-6, Train_Loss=0.629][codecarbon INFO @ 11:58:00] Energy consumed for RAM : 0.018392 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:58:00] Energy consumed for all GPUs : 0.037634 kWh. Total GPU Power : 201.63048886644205 W
# [codecarbon INFO @ 11:58:00] Energy consumed for all CPUs : 0.008146 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:58:00] 0.064172 kWh of electricity used since the beginning.
#  40%|███▉      | 3109/7842 [11:44<20:49,  3.79it/s, Epoch=1, LR=8.99e-6, Train_Loss=0.629][codecarbon INFO @ 11:58:15] Energy consumed for RAM : 0.018792 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:58:15] Energy consumed for all GPUs : 0.038471 kWh. Total GPU Power : 200.94320344856106 W
# [codecarbon INFO @ 11:58:15] Energy consumed for all CPUs : 0.008323 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:58:15] 0.065586 kWh of electricity used since the beginning.
#  41%|████      | 3179/7842 [11:59<13:46,  5.64it/s, Epoch=1, LR=7.44e-6, Train_Loss=0.629][codecarbon INFO @ 11:58:30] Energy consumed for RAM : 0.019192 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:58:30] Energy consumed for all GPUs : 0.039285 kWh. Total GPU Power : 195.457717211151 W
# [codecarbon INFO @ 11:58:30] Energy consumed for all CPUs : 0.008500 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:58:30] 0.066977 kWh of electricity used since the beginning.
#  41%|████▏     | 3244/7842 [12:14<14:26,  5.30it/s, Epoch=1, LR=5.67e-6, Train_Loss=0.629][codecarbon INFO @ 11:58:45] Energy consumed for RAM : 0.019592 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:58:45] Energy consumed for all GPUs : 0.040117 kWh. Total GPU Power : 199.7021318278601 W
# [codecarbon INFO @ 11:58:45] Energy consumed for all CPUs : 0.008677 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:58:45] 0.068386 kWh of electricity used since the beginning.
#  42%|████▏     | 3309/7842 [12:29<21:43,  3.48it/s, Epoch=1, LR=3.87e-6, Train_Loss=0.628][codecarbon INFO @ 11:59:00] Energy consumed for RAM : 0.019991 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:59:00] Energy consumed for all GPUs : 0.040948 kWh. Total GPU Power : 199.50676686703582 W
# [codecarbon INFO @ 11:59:00] Energy consumed for all CPUs : 0.008854 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:59:00] 0.069794 kWh of electricity used since the beginning.
#  43%|████▎     | 3375/7842 [12:44<15:07,  4.92it/s, Epoch=1, LR=2.32e-6, Train_Loss=0.628][codecarbon INFO @ 11:59:15] Energy consumed for RAM : 0.020391 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:59:15] Energy consumed for all GPUs : 0.041790 kWh. Total GPU Power : 202.2447704275272 W
# [codecarbon INFO @ 11:59:15] Energy consumed for all CPUs : 0.009031 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:59:15] 0.071213 kWh of electricity used since the beginning.
#  44%|████▍     | 3435/7842 [12:59<15:03,  4.88it/s, Epoch=1, LR=1.37e-6, Train_Loss=0.627][codecarbon INFO @ 11:59:30] Energy consumed for RAM : 0.020791 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:59:30] Energy consumed for all GPUs : 0.042647 kWh. Total GPU Power : 205.6077353491224 W
# [codecarbon INFO @ 11:59:30] Energy consumed for all CPUs : 0.009208 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:59:30] 0.072646 kWh of electricity used since the beginning.
#  45%|████▍     | 3501/7842 [13:14<18:58,  3.81it/s, Epoch=1, LR=1e-6, Train_Loss=0.626]   [codecarbon INFO @ 11:59:45] Energy consumed for RAM : 0.021191 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 11:59:45] Energy consumed for all GPUs : 0.043486 kWh. Total GPU Power : 201.5131285099063 W
# [codecarbon INFO @ 11:59:45] Energy consumed for all CPUs : 0.009385 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 11:59:45] 0.074062 kWh of electricity used since the beginning.
#  46%|████▌     | 3571/7842 [13:29<12:25,  5.73it/s, Epoch=1, LR=1.44e-6, Train_Loss=0.625][codecarbon INFO @ 12:00:00] Energy consumed for RAM : 0.021591 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:00:00] Energy consumed for all GPUs : 0.044309 kWh. Total GPU Power : 197.55152979896008 W
# [codecarbon INFO @ 12:00:00] Energy consumed for all CPUs : 0.009562 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:00:00] 0.075462 kWh of electricity used since the beginning.
#  46%|████▋     | 3635/7842 [13:44<15:51,  4.42it/s, Epoch=1, LR=2.52e-6, Train_Loss=0.624][codecarbon INFO @ 12:00:15] Energy consumed for RAM : 0.021990 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:00:15] Energy consumed for all GPUs : 0.045145 kWh. Total GPU Power : 200.74742612241238 W
# [codecarbon INFO @ 12:00:15] Energy consumed for all CPUs : 0.009739 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:00:15] 0.076875 kWh of electricity used since the beginning.
#  47%|████▋     | 3699/7842 [13:59<19:00,  3.63it/s, Epoch=1, LR=4.08e-6, Train_Loss=0.624][codecarbon INFO @ 12:00:30] Energy consumed for RAM : 0.022390 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:00:30] Energy consumed for all GPUs : 0.045992 kWh. Total GPU Power : 203.44154076180428 W
# [codecarbon INFO @ 12:00:30] Energy consumed for all CPUs : 0.009916 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:00:30] 0.078299 kWh of electricity used since the beginning.
#  48%|████▊     | 3768/7842 [14:14<13:49,  4.91it/s, Epoch=1, LR=6.01e-6, Train_Loss=0.623][codecarbon INFO @ 12:00:45] Energy consumed for RAM : 0.022790 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:00:45] Energy consumed for all GPUs : 0.046807 kWh. Total GPU Power : 195.6209586846601 W
# [codecarbon INFO @ 12:00:45] Energy consumed for all CPUs : 0.010093 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:00:45] 0.079691 kWh of electricity used since the beginning.
#  49%|████▉     | 3832/7842 [14:29<12:51,  5.20it/s, Epoch=1, LR=7.72e-6, Train_Loss=0.623][codecarbon INFO @ 12:01:00] Energy consumed for RAM : 0.023190 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:01:00] Energy consumed for all GPUs : 0.047645 kWh. Total GPU Power : 201.16637756647475 W
# [codecarbon INFO @ 12:01:00] Energy consumed for all CPUs : 0.010271 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:01:00] 0.081106 kWh of electricity used since the beginning.
#  50%|████▉     | 3899/7842 [14:44<14:13,  4.62it/s, Epoch=1, LR=9.12e-6, Train_Loss=0.622][codecarbon INFO @ 12:01:15] Energy consumed for RAM : 0.023590 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:01:15] Energy consumed for all GPUs : 0.048481 kWh. Total GPU Power : 200.68777039586988 W
# [codecarbon INFO @ 12:01:15] Energy consumed for all CPUs : 0.010448 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:01:15] 0.082518 kWh of electricity used since the beginning.
#  51%|█████     | 3965/7842 [14:59<12:53,  5.01it/s, Epoch=1, LR=9.89e-6, Train_Loss=0.622][codecarbon INFO @ 12:01:30] Energy consumed for RAM : 0.023990 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:01:30] Energy consumed for all GPUs : 0.049307 kWh. Total GPU Power : 198.2151614880051 W
# [codecarbon INFO @ 12:01:30] Energy consumed for all CPUs : 0.010625 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:01:30] 0.083921 kWh of electricity used since the beginning.
#  51%|█████▏    | 4030/7842 [15:14<16:43,  3.80it/s, Epoch=1, LR=9.92e-6, Train_Loss=0.622][codecarbon INFO @ 12:01:45] Energy consumed for RAM : 0.024389 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:01:45] Energy consumed for all GPUs : 0.050140 kWh. Total GPU Power : 199.97114792587908 W
# [codecarbon INFO @ 12:01:45] Energy consumed for all CPUs : 0.010802 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:01:45] 0.085331 kWh of electricity used since the beginning.
#  52%|█████▏    | 4096/7842 [15:29<13:54,  4.49it/s, Epoch=1, LR=9.21e-6, Train_Loss=0.622][codecarbon INFO @ 12:02:00] Energy consumed for RAM : 0.024789 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:02:00] Energy consumed for all GPUs : 0.050979 kWh. Total GPU Power : 201.64160211141368 W
# [codecarbon INFO @ 12:02:00] Energy consumed for all CPUs : 0.010979 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:02:00] 0.086748 kWh of electricity used since the beginning.
#  53%|█████▎    | 4161/7842 [15:44<13:56,  4.40it/s, Epoch=1, LR=7.89e-6, Train_Loss=0.622][codecarbon INFO @ 12:02:15] Energy consumed for RAM : 0.025189 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:02:15] Energy consumed for all GPUs : 0.051811 kWh. Total GPU Power : 199.62988219064496 W
# [codecarbon INFO @ 12:02:15] Energy consumed for all CPUs : 0.011156 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:02:15] 0.088156 kWh of electricity used since the beginning.
#  54%|█████▍    | 4225/7842 [15:59<12:12,  4.94it/s, Epoch=1, LR=6.2e-6, Train_Loss=0.622] [codecarbon INFO @ 12:02:30] Energy consumed for RAM : 0.025589 kWh. RAM Power : 96.0 W
#  54%|█████▍    | 4226/7842 [15:59<12:45,  4.72it/s, Epoch=1, LR=6.18e-6, Train_Loss=0.622][codecarbon INFO @ 12:02:30] Energy consumed for all GPUs : 0.052653 kWh. Total GPU Power : 202.2509830858751 W
# [codecarbon INFO @ 12:02:30] Energy consumed for all CPUs : 0.011333 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:02:30] 0.089575 kWh of electricity used since the beginning.
#  55%|█████▍    | 4294/7842 [16:14<12:48,  4.62it/s, Epoch=1, LR=4.27e-6, Train_Loss=0.621][codecarbon INFO @ 12:02:45] Energy consumed for RAM : 0.025989 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:02:45] Energy consumed for all GPUs : 0.053479 kWh. Total GPU Power : 198.11964115242017 W
# [codecarbon INFO @ 12:02:45] Energy consumed for all CPUs : 0.011510 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:02:45] 0.090977 kWh of electricity used since the beginning.
#  56%|█████▌    | 4357/7842 [16:29<15:45,  3.69it/s, Epoch=1, LR=2.7e-6, Train_Loss=0.621] [codecarbon INFO @ 12:03:00] Energy consumed for RAM : 0.026389 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:03:00] Energy consumed for all GPUs : 0.054317 kWh. Total GPU Power : 201.40907102071307 W
# [codecarbon INFO @ 12:03:00] Energy consumed for all CPUs : 0.011687 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:03:00] 0.092393 kWh of electricity used since the beginning.
#  56%|█████▋    | 4420/7842 [16:44<15:15,  3.74it/s, Epoch=1, LR=1.56e-6, Train_Loss=0.621][codecarbon INFO @ 12:03:15] Energy consumed for RAM : 0.026788 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:03:15] Energy consumed for all GPUs : 0.055160 kWh. Total GPU Power : 202.3694864563767 W
# [codecarbon INFO @ 12:03:15] Energy consumed for all CPUs : 0.011864 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:03:15] 0.093813 kWh of electricity used since the beginning.
#  57%|█████▋    | 4485/7842 [16:59<12:51,  4.35it/s, Epoch=1, LR=1.02e-6, Train_Loss=0.621][codecarbon INFO @ 12:03:30] Energy consumed for RAM : 0.027188 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:03:30] Energy consumed for all GPUs : 0.056003 kWh. Total GPU Power : 202.28203001915477 W
# [codecarbon INFO @ 12:03:30] Energy consumed for all CPUs : 0.012041 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:03:30] 0.095232 kWh of electricity used since the beginning.
#  58%|█████▊    | 4549/7842 [17:14<13:54,  3.95it/s, Epoch=1, LR=1.21e-6, Train_Loss=0.62] [codecarbon INFO @ 12:03:45] Energy consumed for RAM : 0.027588 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:03:45] Energy consumed for all GPUs : 0.056844 kWh. Total GPU Power : 201.91902701873138 W
# [codecarbon INFO @ 12:03:45] Energy consumed for all CPUs : 0.012218 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:03:45] 0.096651 kWh of electricity used since the beginning.
#  59%|█████▉    | 4616/7842 [17:29<10:49,  4.97it/s, Epoch=1, LR=2.14e-6, Train_Loss=0.619][codecarbon INFO @ 12:04:00] Energy consumed for RAM : 0.027988 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:04:00] Energy consumed for all GPUs : 0.057683 kWh. Total GPU Power : 201.51224214203964 W
# [codecarbon INFO @ 12:04:00] Energy consumed for all CPUs : 0.012395 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:04:00] 0.098067 kWh of electricity used since the beginning.
#  60%|█████▉    | 4682/7842 [17:44<11:17,  4.66it/s, Epoch=1, LR=3.64e-6, Train_Loss=0.619][codecarbon INFO @ 12:04:15] Energy consumed for RAM : 0.028388 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:04:15] Energy consumed for all GPUs : 0.058524 kWh. Total GPU Power : 201.85277683319657 W
# [codecarbon INFO @ 12:04:15] Energy consumed for all CPUs : 0.012573 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:04:15] 0.099484 kWh of electricity used since the beginning.
#  61%|██████    | 4747/7842 [17:59<10:45,  4.79it/s, Epoch=1, LR=5.42e-6, Train_Loss=0.619][codecarbon INFO @ 12:04:30] Energy consumed for RAM : 0.028788 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:04:30] Energy consumed for all GPUs : 0.059363 kWh. Total GPU Power : 201.33852739238114 W
# [codecarbon INFO @ 12:04:30] Energy consumed for all CPUs : 0.012750 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:04:30] 0.100900 kWh of electricity used since the beginning.
#  61%|██████▏   | 4811/7842 [18:14<10:57,  4.61it/s, Epoch=1, LR=7.18e-6, Train_Loss=0.619][codecarbon INFO @ 12:04:45] Energy consumed for RAM : 0.029187 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:04:45] Energy consumed for all GPUs : 0.060208 kWh. Total GPU Power : 202.85181975875602 W
# [codecarbon INFO @ 12:04:45] Energy consumed for all CPUs : 0.012927 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:04:45] 0.102322 kWh of electricity used since the beginning.
#  62%|██████▏   | 4879/7842 [18:29<09:35,  5.15it/s, Epoch=1, LR=8.76e-6, Train_Loss=0.618][codecarbon INFO @ 12:05:00] Energy consumed for RAM : 0.029587 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:05:00] Energy consumed for all GPUs : 0.061036 kWh. Total GPU Power : 198.816251362431 W
# [codecarbon INFO @ 12:05:00] Energy consumed for all CPUs : 0.013104 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:05:00] 0.103727 kWh of electricity used since the beginning.
#  63%|██████▎   | 4945/7842 [18:44<11:10,  4.32it/s, Epoch=1, LR=9.73e-6, Train_Loss=0.617][codecarbon INFO @ 12:05:15] Energy consumed for RAM : 0.029987 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:05:15] Energy consumed for all GPUs : 0.061864 kWh. Total GPU Power : 198.74208536605246 W
# [codecarbon INFO @ 12:05:15] Energy consumed for all CPUs : 0.013281 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:05:15] 0.105131 kWh of electricity used since the beginning.
#  64%|██████▍   | 5012/7842 [18:59<11:01,  4.28it/s, Epoch=1, LR=9.99e-6, Train_Loss=0.617][codecarbon INFO @ 12:05:30] Energy consumed for RAM : 0.030387 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:05:30] Energy consumed for all GPUs : 0.062698 kWh. Total GPU Power : 200.40148897137985 W
# [codecarbon INFO @ 12:05:30] Energy consumed for all CPUs : 0.013458 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:05:30] 0.106543 kWh of electricity used since the beginning.
#  65%|██████▍   | 5080/7842 [19:14<10:49,  4.25it/s, Epoch=1, LR=9.44e-6, Train_Loss=0.617][codecarbon INFO @ 12:05:45] Energy consumed for RAM : 0.030787 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:05:45] Energy consumed for all GPUs : 0.063532 kWh. Total GPU Power : 200.0733595484174 W
# [codecarbon INFO @ 12:05:45] Energy consumed for all CPUs : 0.013635 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:05:45] 0.107953 kWh of electricity used since the beginning.
#  66%|██████▌   | 5145/7842 [19:29<09:06,  4.93it/s, Epoch=1, LR=8.26e-6, Train_Loss=0.617][codecarbon INFO @ 12:06:00] Energy consumed for RAM : 0.031187 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:06:00] Energy consumed for all GPUs : 0.064373 kWh. Total GPU Power : 201.95849784758775 W
# [codecarbon INFO @ 12:06:00] Energy consumed for all CPUs : 0.013812 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:06:00] 0.109371 kWh of electricity used since the beginning.
#  67%|██████▋   | 5215/7842 [19:44<08:15,  5.31it/s, Epoch=1, LR=6.48e-6, Train_Loss=0.617][codecarbon INFO @ 12:06:15] Energy consumed for RAM : 0.031586 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:06:15] Energy consumed for all GPUs : 0.065188 kWh. Total GPU Power : 195.60056057918496 W
# [codecarbon INFO @ 12:06:15] Energy consumed for all CPUs : 0.013989 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:06:15] 0.110763 kWh of electricity used since the beginning.
#  67%|██████▋   | 5280/7842 [19:59<10:23,  4.11it/s, Epoch=1, LR=4.66e-6, Train_Loss=0.617][codecarbon INFO @ 12:06:30] Energy consumed for RAM : 0.031986 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:06:30] Energy consumed for all GPUs : 0.066031 kWh. Total GPU Power : 202.40120364916433 W
# [codecarbon INFO @ 12:06:30] Energy consumed for all CPUs : 0.014166 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:06:30] 0.112183 kWh of electricity used since the beginning.
#  68%|██████▊   | 5343/7842 [20:14<09:40,  4.30it/s, Epoch=1, LR=3.02e-6, Train_Loss=0.616][codecarbon INFO @ 12:06:45] Energy consumed for RAM : 0.032386 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:06:45] Energy consumed for all GPUs : 0.066874 kWh. Total GPU Power : 202.5421738876968 W
# [codecarbon INFO @ 12:06:45] Energy consumed for all CPUs : 0.014343 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:06:45] 0.113604 kWh of electricity used since the beginning.
#  69%|██████▉   | 5408/7842 [20:29<09:58,  4.07it/s, Epoch=1, LR=1.73e-6, Train_Loss=0.616][codecarbon INFO @ 12:07:00] Energy consumed for RAM : 0.032786 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:07:00] Energy consumed for all GPUs : 0.067706 kWh. Total GPU Power : 199.76260122403667 W
# [codecarbon INFO @ 12:07:00] Energy consumed for all CPUs : 0.014520 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:07:00] 0.115013 kWh of electricity used since the beginning.
#  70%|██████▉   | 5472/7842 [20:44<08:58,  4.40it/s, Epoch=1, LR=1.07e-6, Train_Loss=0.616][codecarbon INFO @ 12:07:15] Energy consumed for RAM : 0.033186 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:07:15] Energy consumed for all GPUs : 0.068551 kWh. Total GPU Power : 202.67690422020686 W
# [codecarbon INFO @ 12:07:15] Energy consumed for all CPUs : 0.014697 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:07:15] 0.116434 kWh of electricity used since the beginning.
#  71%|███████   | 5534/7842 [20:59<07:27,  5.15it/s, Epoch=1, LR=1.1e-6, Train_Loss=0.616] [codecarbon INFO @ 12:07:30] Energy consumed for RAM : 0.033585 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:07:30] Energy consumed for all GPUs : 0.069399 kWh. Total GPU Power : 203.7938225082576 W
# [codecarbon INFO @ 12:07:30] Energy consumed for all CPUs : 0.014875 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:07:30] 0.117859 kWh of electricity used since the beginning.
#  71%|███████▏  | 5598/7842 [21:14<07:42,  4.85it/s, Epoch=1, LR=1.83e-6, Train_Loss=0.615][codecarbon INFO @ 12:07:45] Energy consumed for RAM : 0.033985 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:07:45] Energy consumed for all GPUs : 0.070246 kWh. Total GPU Power : 203.3984075852375 W
# [codecarbon INFO @ 12:07:45] Energy consumed for all CPUs : 0.015052 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:07:45] 0.119283 kWh of electricity used since the beginning.
#  72%|███████▏  | 5662/7842 [21:29<08:41,  4.18it/s, Epoch=1, LR=3.14e-6, Train_Loss=0.615][codecarbon INFO @ 12:08:00] Energy consumed for RAM : 0.034385 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:08:00] Energy consumed for all GPUs : 0.071088 kWh. Total GPU Power : 202.20262977411224 W
# [codecarbon INFO @ 12:08:00] Energy consumed for all CPUs : 0.015229 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:08:00] 0.120702 kWh of electricity used since the beginning.
#  73%|███████▎  | 5729/7842 [21:44<06:51,  5.14it/s, Epoch=1, LR=4.91e-6, Train_Loss=0.614][codecarbon INFO @ 12:08:15] Energy consumed for RAM : 0.034785 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:08:15] Energy consumed for all GPUs : 0.071917 kWh. Total GPU Power : 198.8279367216866 W
# [codecarbon INFO @ 12:08:15] Energy consumed for all CPUs : 0.015406 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:08:15] 0.122107 kWh of electricity used since the beginning.
#  74%|███████▍  | 5793/7842 [21:59<08:15,  4.14it/s, Epoch=1, LR=6.7e-6, Train_Loss=0.614] [codecarbon INFO @ 12:08:30] Energy consumed for RAM : 0.035185 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:08:30] Energy consumed for all GPUs : 0.072767 kWh. Total GPU Power : 204.2392366360968 W
# [codecarbon INFO @ 12:08:30] Energy consumed for all CPUs : 0.015583 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:08:30] 0.123535 kWh of electricity used since the beginning.
#  75%|███████▍  | 5856/7842 [22:14<09:58,  3.32it/s, Epoch=1, LR=8.28e-6, Train_Loss=0.614][codecarbon INFO @ 12:08:45] Energy consumed for RAM : 0.035585 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:08:45] Energy consumed for all GPUs : 0.073618 kWh. Total GPU Power : 204.2578427926177 W
# [codecarbon INFO @ 12:08:45] Energy consumed for all CPUs : 0.015760 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:08:45] 0.124963 kWh of electricity used since the beginning.
#  75%|███████▌  | 5915/7842 [22:29<08:02,  4.00it/s, Epoch=1, LR=9.37e-6, Train_Loss=0.613][codecarbon INFO @ 12:09:00] Energy consumed for RAM : 0.035984 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:09:00] Energy consumed for all GPUs : 0.074488 kWh. Total GPU Power : 208.8674375309432 W
# [codecarbon INFO @ 12:09:00] Energy consumed for all CPUs : 0.015937 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:09:00] 0.126410 kWh of electricity used since the beginning.
#  76%|███████▋  | 5982/7842 [22:44<05:47,  5.35it/s, Epoch=1, LR=9.97e-6, Train_Loss=0.613][codecarbon INFO @ 12:09:15] Energy consumed for RAM : 0.036384 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:09:15] Energy consumed for all GPUs : 0.075333 kWh. Total GPU Power : 202.85699579466063 W
# [codecarbon INFO @ 12:09:15] Energy consumed for all CPUs : 0.016114 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:09:15] 0.127831 kWh of electricity used since the beginning.
#  77%|███████▋  | 6043/7842 [22:59<07:26,  4.03it/s, Epoch=1, LR=9.84e-6, Train_Loss=0.613][codecarbon INFO @ 12:09:30] Energy consumed for RAM : 0.036784 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:09:30] Energy consumed for all GPUs : 0.076197 kWh. Total GPU Power : 207.39223441264946 W
# [codecarbon INFO @ 12:09:30] Energy consumed for all CPUs : 0.016291 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:09:30] 0.129272 kWh of electricity used since the beginning.
#  78%|███████▊  | 6108/7842 [23:14<05:41,  5.07it/s, Epoch=1, LR=9e-6, Train_Loss=0.613]   [codecarbon INFO @ 12:09:45] Energy consumed for RAM : 0.037184 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:09:45] Energy consumed for all GPUs : 0.077040 kWh. Total GPU Power : 202.4313218149535 W
# [codecarbon INFO @ 12:09:45] Energy consumed for all CPUs : 0.016468 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:09:45] 0.130692 kWh of electricity used since the beginning.
#  79%|███████▊  | 6172/7842 [23:29<05:36,  4.97it/s, Epoch=1, LR=7.62e-6, Train_Loss=0.612][codecarbon INFO @ 12:10:00] Energy consumed for RAM : 0.037584 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:10:00] Energy consumed for all GPUs : 0.077890 kWh. Total GPU Power : 204.1360935353713 W
# [codecarbon INFO @ 12:10:00] Energy consumed for all CPUs : 0.016645 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:10:00] 0.132119 kWh of electricity used since the beginning.
#  80%|███████▉  | 6236/7842 [23:44<05:53,  4.54it/s, Epoch=1, LR=5.9e-6, Train_Loss=0.612] [codecarbon INFO @ 12:10:15] Energy consumed for RAM : 0.037984 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:10:15] Energy consumed for all GPUs : 0.078729 kWh. Total GPU Power : 201.39237067519687 W
# [codecarbon INFO @ 12:10:15] Energy consumed for all CPUs : 0.016822 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:10:15] 0.133535 kWh of electricity used since the beginning.
#  80%|████████  | 6300/7842 [23:59<07:35,  3.38it/s, Epoch=1, LR=4.11e-6, Train_Loss=0.612][codecarbon INFO @ 12:10:30] Energy consumed for RAM : 0.038383 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:10:30] Energy consumed for all GPUs : 0.079573 kWh. Total GPU Power : 202.48326661816623 W
# [codecarbon INFO @ 12:10:30] Energy consumed for all CPUs : 0.016999 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:10:30] 0.134955 kWh of electricity used since the beginning.
#  81%|████████  | 6362/7842 [24:14<05:50,  4.22it/s, Epoch=1, LR=2.59e-6, Train_Loss=0.612][codecarbon INFO @ 12:10:45] Energy consumed for RAM : 0.038783 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 12:10:45] Energy consumed for all GPUs : 0.080437 kWh. Total GPU Power : 207.55648229465407 W
# [codecarbon INFO @ 12:10:45] Energy consumed for all CPUs : 0.017176 kWh. Total CPU Power : 42.5 W
# ...
# [codecarbon INFO @ 16:48:01] 0.544383 kWh of electricity used since the beginning.
#  92%|█████████▏| 7213/7842 [27:24<02:23,  4.39it/s, Epoch=3, LR=9.09e-6, Train_Loss=0.514][codecarbon INFO @ 16:48:16] Energy consumed for RAM : 0.153531 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:48:16] Energy consumed for all GPUs : 0.324282 kWh. Total GPU Power : 204.17633238071585 W
# [codecarbon INFO @ 16:48:16] Energy consumed for all CPUs : 0.067997 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:48:16] 0.545811 kWh of electricity used since the beginning.
#  93%|█████████▎| 7280/7842 [27:39<02:04,  4.53it/s, Epoch=3, LR=9.89e-6, Train_Loss=0.513][codecarbon INFO @ 16:48:31] Energy consumed for RAM : 0.153931 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:48:31] Energy consumed for all GPUs : 0.325112 kWh. Total GPU Power : 199.33466088804943 W
# [codecarbon INFO @ 16:48:31] Energy consumed for all CPUs : 0.068174 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:48:31] 0.547218 kWh of electricity used since the beginning.
#  94%|█████████▎| 7351/7842 [27:54<01:26,  5.67it/s, Epoch=3, LR=9.89e-6, Train_Loss=0.513][codecarbon INFO @ 16:48:46] Energy consumed for RAM : 0.154331 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:48:46] Energy consumed for all GPUs : 0.325922 kWh. Total GPU Power : 194.46136148427246 W
# [codecarbon INFO @ 16:48:46] Energy consumed for all CPUs : 0.068351 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:48:46] 0.548605 kWh of electricity used since the beginning.
#  95%|█████████▍| 7423/7842 [28:09<01:36,  4.34it/s, Epoch=3, LR=9.02e-6, Train_Loss=0.514][codecarbon INFO @ 16:49:01] Energy consumed for RAM : 0.154731 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:49:01] Energy consumed for all GPUs : 0.326730 kWh. Total GPU Power : 193.95659687782725 W
# [codecarbon INFO @ 16:49:01] Energy consumed for all CPUs : 0.068529 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:49:01] 0.549989 kWh of electricity used since the beginning.
#  96%|█████████▌| 7493/7842 [28:24<01:05,  5.35it/s, Epoch=3, LR=7.49e-6, Train_Loss=0.514][codecarbon INFO @ 16:49:16] Energy consumed for RAM : 0.155131 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:49:16] Energy consumed for all GPUs : 0.327541 kWh. Total GPU Power : 194.68717955577415 W
# [codecarbon INFO @ 16:49:16] Energy consumed for all CPUs : 0.068706 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:49:16] 0.551377 kWh of electricity used since the beginning.
#  96%|█████████▋| 7560/7842 [28:39<01:17,  3.64it/s, Epoch=3, LR=5.67e-6, Train_Loss=0.514][codecarbon INFO @ 16:49:31] Energy consumed for RAM : 0.155531 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:49:31] Energy consumed for all GPUs : 0.328364 kWh. Total GPU Power : 197.54118641150217 W
# [codecarbon INFO @ 16:49:31] Energy consumed for all CPUs : 0.068883 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:49:31] 0.552777 kWh of electricity used since the beginning.
#  97%|█████████▋| 7624/7842 [28:54<00:47,  4.57it/s, Epoch=3, LR=3.9e-6, Train_Loss=0.514] [codecarbon INFO @ 16:49:46] Energy consumed for RAM : 0.155930 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:49:46] Energy consumed for all GPUs : 0.329190 kWh. Total GPU Power : 198.2801464939425 W
# [codecarbon INFO @ 16:49:46] Energy consumed for all CPUs : 0.069060 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:49:46] 0.554180 kWh of electricity used since the beginning.
#  98%|█████████▊| 7687/7842 [29:09<00:41,  3.77it/s, Epoch=3, LR=2.4e-6, Train_Loss=0.514] [codecarbon INFO @ 16:50:01] Energy consumed for RAM : 0.156330 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:50:01] Energy consumed for all GPUs : 0.330027 kWh. Total GPU Power : 201.15947664941453 W
# [codecarbon INFO @ 16:50:01] Energy consumed for all CPUs : 0.069237 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:50:01] 0.555595 kWh of electricity used since the beginning.
#  99%|█████████▉| 7753/7842 [29:24<00:23,  3.72it/s, Epoch=3, LR=1.35e-6, Train_Loss=0.514][codecarbon INFO @ 16:50:16] Energy consumed for RAM : 0.156730 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:50:16] Energy consumed for all GPUs : 0.330842 kWh. Total GPU Power : 195.5019494916243 W
# [codecarbon INFO @ 16:50:16] Energy consumed for all CPUs : 0.069414 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:50:16] 0.556986 kWh of electricity used since the beginning.
# 100%|█████████▉| 7822/7842 [29:39<00:05,  3.99it/s, Epoch=3, LR=1e-6, Train_Loss=0.514]   [codecarbon INFO @ 16:50:31] Energy consumed for RAM : 0.157130 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:50:31] Energy consumed for all GPUs : 0.331643 kWh. Total GPU Power : 192.3472032359808 W
# [codecarbon INFO @ 16:50:31] Energy consumed for all CPUs : 0.069591 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:50:31] 0.558364 kWh of electricity used since the beginning.
# 100%|██████████| 7842/7842 [29:43<00:00,  4.40it/s, Epoch=3, LR=1.06e-6, Train_Loss=0.514]
#   4%|▍         | 83/1961 [00:10<03:44,  8.36it/s, Epoch=3, LR=1.06e-6, Valid_Loss=0.537][codecarbon INFO @ 16:50:46] Energy consumed for RAM : 0.157530 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:50:46] Energy consumed for all GPUs : 0.332595 kWh. Total GPU Power : 228.7248607802355 W
# [codecarbon INFO @ 16:50:46] Energy consumed for all CPUs : 0.069768 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:50:46] 0.559893 kWh of electricity used since the beginning.
#  10%|▉         | 191/1961 [00:25<04:55,  5.98it/s, Epoch=3, LR=1.06e-6, Valid_Loss=0.557][codecarbon INFO @ 16:51:01] Energy consumed for RAM : 0.157929 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:51:01] Energy consumed for all GPUs : 0.333627 kWh. Total GPU Power : 247.6368841288413 W
# [codecarbon INFO @ 16:51:01] Energy consumed for all CPUs : 0.069945 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:51:01] 0.561502 kWh of electricity used since the beginning.
#  16%|█▌        | 308/1961 [00:40<04:02,  6.81it/s, Epoch=3, LR=1.06e-6, Valid_Loss=0.557][codecarbon INFO @ 16:51:16] Energy consumed for RAM : 0.158329 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:51:16] Energy consumed for all GPUs : 0.334651 kWh. Total GPU Power : 246.0344746227981 W
# [codecarbon INFO @ 16:51:16] Energy consumed for all CPUs : 0.070122 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:51:16] 0.563103 kWh of electricity used since the beginning.
#  21%|██▏       | 418/1961 [00:55<03:08,  8.18it/s, Epoch=3, LR=1.06e-6, Valid_Loss=0.561][codecarbon INFO @ 16:51:31] Energy consumed for RAM : 0.158729 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:51:31] Energy consumed for all GPUs : 0.335683 kWh. Total GPU Power : 247.58900691303734 W
# [codecarbon INFO @ 16:51:31] Energy consumed for all CPUs : 0.070299 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:51:31] 0.564711 kWh of electricity used since the beginning.
#  27%|██▋       | 529/1961 [01:10<03:09,  7.55it/s, Epoch=3, LR=1.06e-6, Valid_Loss=0.558][codecarbon INFO @ 16:51:46] Energy consumed for RAM : 0.159129 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:51:46] Energy consumed for all GPUs : 0.336708 kWh. Total GPU Power : 246.2613547567634 W
# [codecarbon INFO @ 16:51:46] Energy consumed for all CPUs : 0.070476 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:51:46] 0.566314 kWh of electricity used since the beginning.
#  32%|███▏      | 637/1961 [01:25<02:41,  8.19it/s, Epoch=3, LR=1.06e-6, Valid_Loss=0.558][codecarbon INFO @ 16:52:01] Energy consumed for RAM : 0.159529 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:52:01] Energy consumed for all GPUs : 0.337741 kWh. Total GPU Power : 247.97535486610641 W
# [codecarbon INFO @ 16:52:01] Energy consumed for all CPUs : 0.070654 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:52:01] 0.567923 kWh of electricity used since the beginning.
#  38%|███▊      | 744/1961 [01:40<02:10,  9.31it/s, Epoch=3, LR=1.06e-6, Valid_Loss=0.557][codecarbon INFO @ 16:52:16] Energy consumed for RAM : 0.159928 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:52:16] Energy consumed for all GPUs : 0.338774 kWh. Total GPU Power : 247.9933974009787 W
# [codecarbon INFO @ 16:52:16] Energy consumed for all CPUs : 0.070831 kWh. Total CPU Power : 42.5 W
#  38%|███▊      | 745/1961 [01:40<02:29,  8.14it/s, Epoch=3, LR=1.06e-6, Valid_Loss=0.557][codecarbon INFO @ 16:52:16] 0.569533 kWh of electricity used since the beginning.
#  44%|████▍     | 862/1961 [01:55<02:05,  8.75it/s, Epoch=3, LR=1.06e-6, Valid_Loss=0.556][codecarbon INFO @ 16:52:31] Energy consumed for RAM : 0.160328 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:52:31] Energy consumed for all GPUs : 0.339800 kWh. Total GPU Power : 246.43173581322316 W
# [codecarbon INFO @ 16:52:31] Energy consumed for all CPUs : 0.071008 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:52:31] 0.571136 kWh of electricity used since the beginning.
#  50%|████▉     | 974/1961 [02:10<02:13,  7.37it/s, Epoch=3, LR=1.06e-6, Valid_Loss=0.555][codecarbon INFO @ 16:52:46] Energy consumed for RAM : 0.160728 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:52:46] Energy consumed for all GPUs : 0.340833 kWh. Total GPU Power : 248.08054289233934 W
# [codecarbon INFO @ 16:52:46] Energy consumed for all CPUs : 0.071185 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:52:46] 0.572746 kWh of electricity used since the beginning.
#  55%|█████▌    | 1084/1961 [02:25<02:02,  7.15it/s, Epoch=3, LR=1.06e-6, Valid_Loss=0.557][codecarbon INFO @ 16:53:01] Energy consumed for RAM : 0.161128 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:53:01] Energy consumed for all GPUs : 0.341868 kWh. Total GPU Power : 248.2907851323211 W
# [codecarbon INFO @ 16:53:01] Energy consumed for all CPUs : 0.071362 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:53:01] 0.574357 kWh of electricity used since the beginning.
#  61%|██████    | 1198/1961 [02:40<02:05,  6.08it/s, Epoch=3, LR=1.06e-6, Valid_Loss=0.558][codecarbon INFO @ 16:53:16] Energy consumed for RAM : 0.161528 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:53:16] Energy consumed for all GPUs : 0.342892 kWh. Total GPU Power : 246.04195169107118 W
# [codecarbon INFO @ 16:53:16] Energy consumed for all CPUs : 0.071539 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:53:16] 0.575959 kWh of electricity used since the beginning.
#  67%|██████▋   | 1307/1961 [02:55<01:30,  7.22it/s, Epoch=3, LR=1.06e-6, Valid_Loss=0.556][codecarbon INFO @ 16:53:31] Energy consumed for RAM : 0.161927 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:53:31] Energy consumed for all GPUs : 0.343928 kWh. Total GPU Power : 248.55149413396558 W
# [codecarbon INFO @ 16:53:31] Energy consumed for all CPUs : 0.071716 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:53:31] 0.577571 kWh of electricity used since the beginning.
#  73%|███████▎  | 1428/1961 [03:10<01:20,  6.63it/s, Epoch=3, LR=1.06e-6, Valid_Loss=0.559][codecarbon INFO @ 16:53:46] Energy consumed for RAM : 0.162327 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:53:46] Energy consumed for all GPUs : 0.344953 kWh. Total GPU Power : 246.30237697245138 W
# [codecarbon INFO @ 16:53:46] Energy consumed for all CPUs : 0.071893 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:53:46] 0.579174 kWh of electricity used since the beginning.
#  78%|███████▊  | 1539/1961 [03:25<00:53,  7.82it/s, Epoch=3, LR=1.06e-6, Valid_Loss=0.559][codecarbon INFO @ 16:54:01] Energy consumed for RAM : 0.162727 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:54:01] Energy consumed for all GPUs : 0.345987 kWh. Total GPU Power : 248.17802717909555 W
# [codecarbon INFO @ 16:54:01] Energy consumed for all CPUs : 0.072070 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:54:01] 0.580784 kWh of electricity used since the beginning.
#  84%|████████▍ | 1652/1961 [03:40<00:35,  8.77it/s, Epoch=3, LR=1.06e-6, Valid_Loss=0.56] [codecarbon INFO @ 16:54:16] Energy consumed for RAM : 0.163127 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:54:16] Energy consumed for all GPUs : 0.347021 kWh. Total GPU Power : 248.08006550948252 W
# [codecarbon INFO @ 16:54:16] Energy consumed for all CPUs : 0.072247 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:54:16] 0.582395 kWh of electricity used since the beginning.
#  90%|█████████ | 1768/1961 [03:55<00:23,  8.29it/s, Epoch=3, LR=1.06e-6, Valid_Loss=0.56] [codecarbon INFO @ 16:54:31] Energy consumed for RAM : 0.163527 kWh. RAM Power : 96.0 W
#  90%|█████████ | 1769/1961 [03:55<00:26,  7.30it/s, Epoch=3, LR=1.06e-6, Valid_Loss=0.56][codecarbon INFO @ 16:54:31] Energy consumed for all GPUs : 0.348045 kWh. Total GPU Power : 245.97172238534318 W
# [codecarbon INFO @ 16:54:31] Energy consumed for all CPUs : 0.072424 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:54:31] 0.583996 kWh of electricity used since the beginning.
#  95%|█████████▌| 1872/1961 [04:10<00:16,  5.49it/s, Epoch=3, LR=1.06e-6, Valid_Loss=0.56] [codecarbon INFO @ 16:54:46] Energy consumed for RAM : 0.163926 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:54:46] Energy consumed for all GPUs : 0.349080 kWh. Total GPU Power : 248.60740143983986 W
# [codecarbon INFO @ 16:54:46] Energy consumed for all CPUs : 0.072601 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:54:46] 0.585608 kWh of electricity used since the beginning.
# 100%|██████████| 1961/1961 [04:22<00:00,  7.47it/s, Epoch=3, LR=1.06e-6, Valid_Loss=0.56]
# Classification Report:
#               precision    recall  f1-score   support
#
#       Non_HP     0.7034    0.7310    0.7169     15685
#           HP     0.7200    0.6917    0.7056     15684
#
#     accuracy                         0.7113     31369
#    macro avg     0.7117    0.7113    0.7112     31369
# weighted avg     0.7117    0.7113    0.7112     31369
#
# Accuracy = 0.7113
# F1_score = 0.7056
# [codecarbon INFO @ 16:54:58]
# Graceful stopping: collecting and writing information.
# Please wait a few seconds...
# [codecarbon INFO @ 16:54:58] Energy consumed for RAM : 0.164263 kWh. RAM Power : 96.0 W
# [codecarbon INFO @ 16:54:58] Energy consumed for all GPUs : 0.349916 kWh. Total GPU Power : 238.43109348707623 W
# [codecarbon INFO @ 16:54:58] Energy consumed for all CPUs : 0.072750 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:54:58] 0.586930 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:54:58] Done!
# Training complete in 1h 42m 43s
# Best Loss: 0.5581
# VBox(children=(Label(value='0.021 MB of 0.021 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train Loss</td><td>█▄▁</td></tr><tr><td>Valid Accuracy</td><td>▁▇█</td></tr><tr><td>Valid F1_score</td><td>▁▇█</td></tr><tr><td>Valid Loss</td><td>█▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Best Loss</td><td>0.55807</td></tr><tr><td>Train Loss</td><td>0.51379</td></tr><tr><td>Valid Accuracy</td><td>0.7113</td></tr><tr><td>Valid F1_score</td><td>0.7056</td></tr><tr><td>Valid Loss</td><td>0.5603</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">kmyc4k23vc47-fold-2</strong> at: <a href='https://wandb.ai/krimhau/HP_results_Jira_High_vs_rest_results/runs/fhg9z642' target="_blank">https://wandb.ai/krimhau/HP_results_Jira_High_vs_rest_results/runs/fhg9z642</a><br/> View job at <a href='https://wandb.ai/krimhau/HP_results_Jira_High_vs_rest_results/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjE1MDM1ODY0Mg==/version_details/v2' target="_blank">https://wandb.ai/krimhau/HP_results_Jira_High_vs_rest_results/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjE1MDM1ODY0Mg==/version_details/v2</a><br/>Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240319_151205-fhg9z642/logs</code>

# %% [markdown]
# <h2> Testing Inference </h2>

# %%
import warnings,transformers,logging,torch

warnings.simplefilter('ignore')
logging.disable(logging.WARNING)

# %%
test_df = test_hp_df

# %%
test_df
# Out:
#                                                      text  label
# 16484   iiopsecurityinvocationtestcase fails with secu...      0
# 27086   it seems that we have some jars as part of pdf...      1
# 51630                              release olingo version      0
# 54583   log cleaner grows buffers when resultmessagesr...      1
# 59967   hiwith cvs cocoon ive been getting warnings li...      0
# ...                                                   ...    ...
# 76820   error log shows the followingmessage found com...      1
# 110268  when following the instructions for helloworld...      1
# 103694  rse server stop over ssh does not work for as ...      1
# 860     currently there is no way to browse and discov...      0
# 15795   i have a custom maven plugin that i wrote and ...      1
#
# [16608 rows x 2 columns]

# %%
class HP_TestDataset(Dataset):
    def __init__(self, df, tokenizer, max_length):
        self.df = df
        self.max_len = max_length
        self.tokenizer = tokenizer
        self.text = df['text'].values
        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, index):
        text = self.text[index]
        inputs = self.tokenizer.encode_plus(
                        text,
                        truncation=True,
                        add_special_tokens=True,
                        max_length=self.max_len
                    )
        
        samples = {
            'input_ids': inputs['input_ids'],
            'attention_mask': inputs['attention_mask'],
            
        }

        if 'token_type_ids' in inputs:
            samples['token_type_ids'] = inputs['token_type_ids']
        
        return samples

# %%
collate_fn = DataCollatorWithPadding(tokenizer=CONFIG['tokenizer'])

softmax = nn.Softmax(dim=1)
model = HP_Model(CONFIG['model_name'])

# %%
def prepare_test_loader(test_df):    
    test_dataset = HP_TestDataset(test_df, 
                                   tokenizer=CONFIG['tokenizer'], 
                                   max_length=CONFIG['max_length'])
    
    test_loader = DataLoader(test_dataset, 
                             batch_size=CONFIG['valid_batch_size'], 
                             collate_fn=collate_fn, 
                             num_workers=2, 
                             shuffle=False, 
                             pin_memory=True, 
                             drop_last=False)
    return test_loader

test_loader = prepare_test_loader(test_df)

# %%
@torch.no_grad()
def inference(test_loader, model, device):
    preds = []
    preds_target = []
    model.eval()
    model.to(device)
    
    bar = tqdm(enumerate(test_loader), total=len(test_loader))
    
    for step, data in bar: 
        ids = data['input_ids'].to(device, dtype = torch.long)
        mask = data['attention_mask'].to(device, dtype = torch.long)
        
        output = model(ids, mask)
        y_preds = softmax(torch.tensor(output.to('cpu'))).numpy()
        pred_target = torch.argmax(output, dim=-1).flatten().tolist()
        
        preds.append(y_preds)
        preds_target.append(pred_target) 
    predictions = np.concatenate(preds)
    predictions_label = np.concatenate(preds_target)
    return predictions , predictions_label

# %%
deberta_predictions = []
deberta_predictions_labels = []



for fold in range(0, CONFIG['n_fold']):
    print("Fold {}".format(fold))
    
    state = torch.load(f'{HASH_NAME}-Loss-Fold-{fold}.bin')
    model.load_state_dict(state)
    
    prediction, predictions_label = inference(test_loader, model, CONFIG['device'])
    deberta_predictions.append(prediction)
    deberta_predictions_labels.append(predictions_label)
    del state, prediction; gc.collect()
    torch.cuda.empty_cache()
del model
# Out:
# Fold 0
# 100%|██████████| 1038/1038 [02:15<00:00,  7.68it/s]
# Fold 1
# 100%|██████████| 1038/1038 [02:15<00:00,  7.67it/s]
# Fold 2
# 100%|██████████| 1038/1038 [02:15<00:00,  7.67it/s]

# %%
deberta_predictions
# Out:
# [array([[0.27178073, 0.7282193 ],
#         [0.11238998, 0.88761   ],
#         [0.38828748, 0.6117125 ],
#         ...,
#         [0.3559289 , 0.64407116],
#         [0.93314004, 0.06685997],
#         [0.3926115 , 0.60738844]], dtype=float32),
#  array([[0.3151631 , 0.68483686],
#         [0.05584864, 0.94415134],
#         [0.22189075, 0.7781092 ],
#         ...,
#         [0.3907594 , 0.6092406 ],
#         [0.96630424, 0.03369572],
#         [0.4112003 , 0.5887997 ]], dtype=float32),
#  array([[0.33432955, 0.66567045],
#         [0.17477728, 0.8252227 ],
#         [0.422705  , 0.57729495],
#         ...,
#         [0.36321118, 0.6367888 ],
#         [0.9270546 , 0.0729454 ],
#         [0.37330398, 0.626696  ]], dtype=float32)]

# %%
predictions = np.mean(deberta_predictions, axis=0)
predictions
# Out:
# array([[0.30709115, 0.6929088 ],
#        [0.11433864, 0.88566136],
#        [0.3442944 , 0.6557056 ],
#        ...,
#        [0.3699665 , 0.6300335 ],
#        [0.9421663 , 0.0578337 ],
#        [0.39237192, 0.60762805]], dtype=float32)

# %%
len(predictions)
# Out:
# 16608

# %%
predictions
# Out:
# array([[0.30709115, 0.6929088 ],
#        [0.11433864, 0.88566136],
#        [0.3442944 , 0.6557056 ],
#        ...,
#        [0.3699665 , 0.6300335 ],
#        [0.9421663 , 0.0578337 ],
#        [0.39237192, 0.60762805]], dtype=float32)

# %%
test_df["prediction_0"] = predictions[:, 0]

# %%
test_df["prediction_1"] = predictions[:, 1]

# %%
for i in range(0, CONFIG['n_fold']):

    test_df[f"prediction_label_fold_{i}"] = deberta_predictions_labels[i]

# %%
test_df
# Out:
#                                                      text  label  \
# 16484   iiopsecurityinvocationtestcase fails with secu...      0
# 27086   it seems that we have some jars as part of pdf...      1
# 51630                              release olingo version      0
# 54583   log cleaner grows buffers when resultmessagesr...      1
# 59967   hiwith cvs cocoon ive been getting warnings li...      0
# ...                                                   ...    ...
# 76820   error log shows the followingmessage found com...      1
# 110268  when following the instructions for helloworld...      1
# 103694  rse server stop over ssh does not work for as ...      1
# 860     currently there is no way to browse and discov...      0
# 15795   i have a custom maven plugin that i wrote and ...      1
#
#         prediction_0  prediction_1  prediction_label_fold_0  \
# 16484       0.307091      0.692909                        1
# 27086       0.114339      0.885661                        1
# 51630       0.344294      0.655706                        1
# 54583       0.420403      0.579597                        1
# 59967       0.598095      0.401905                        0
# ...              ...           ...                      ...
# 76820       0.556701      0.443299                        1
# 110268      0.027527      0.972473                        1
# 103694      0.369967      0.630033                        1
# 860         0.942166      0.057834                        0
# 15795       0.392372      0.607628                        1
#
#         prediction_label_fold_1  prediction_label_fold_2
# 16484                         1                        1
# 27086                         1                        1
# 51630                         1                        1
# 54583                         1                        1
# 59967                         0                        0
# ...                         ...                      ...
# 76820                         0                        1
# 110268                        1                        1
# 103694                        1                        1
# 860                           0                        0
# 15795                         1                        1
#
# [16608 rows x 7 columns]

# %%
len(test_df)
# Out:
# 16608

# %%
test_df['Max'] = test_df[['prediction_0','prediction_1']].idxmax(axis=1)

# %%
test_df["pred"] = test_df['Max'].apply(lambda x: x.replace("prediction_0", "0"))

# %%
test_df["pred"] = test_df['pred'].apply(lambda x: x.replace("prediction_1", "1"))

# %%
test_df["pred"] = test_df["pred"].astype(int)

# %%
test_df
# Out:
#                                                      text  label  \
# 16484   iiopsecurityinvocationtestcase fails with secu...      0
# 27086   it seems that we have some jars as part of pdf...      1
# 51630                              release olingo version      0
# 54583   log cleaner grows buffers when resultmessagesr...      1
# 59967   hiwith cvs cocoon ive been getting warnings li...      0
# ...                                                   ...    ...
# 76820   error log shows the followingmessage found com...      1
# 110268  when following the instructions for helloworld...      1
# 103694  rse server stop over ssh does not work for as ...      1
# 860     currently there is no way to browse and discov...      0
# 15795   i have a custom maven plugin that i wrote and ...      1
#
#         prediction_0  prediction_1  prediction_label_fold_0  \
# 16484       0.307091      0.692909                        1
# 27086       0.114339      0.885661                        1
# 51630       0.344294      0.655706                        1
# 54583       0.420403      0.579597                        1
# 59967       0.598095      0.401905                        0
# ...              ...           ...                      ...
# 76820       0.556701      0.443299                        1
# 110268      0.027527      0.972473                        1
# 103694      0.369967      0.630033                        1
# 860         0.942166      0.057834                        0
# 15795       0.392372      0.607628                        1
#
#         prediction_label_fold_1  prediction_label_fold_2           Max  pred
# 16484                         1                        1  prediction_1     1
# 27086                         1                        1  prediction_1     1
# 51630                         1                        1  prediction_1     1
# 54583                         1                        1  prediction_1     1
# 59967                         0                        0  prediction_0     0
# ...                         ...                      ...           ...   ...
# 76820                         0                        1  prediction_0     0
# 110268                        1                        1  prediction_1     1
# 103694                        1                        1  prediction_1     1
# 860                           0                        0  prediction_0     0
# 15795                         1                        1  prediction_1     1
#
# [16608 rows x 9 columns]

# %%
from sklearn.metrics import confusion_matrix
cf_matrix = confusion_matrix(test_df["label"].values, test_df["pred"].values)

print(cf_matrix)
# Out:
# [[5917 2417]
#  [2282 5992]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True, 
            fmt='.2%', cmap='Blues')

ax.set_title('NonHP vs HP \n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False(NonHP)','True(HP)'])
ax.yaxis.set_ticklabels(['False(NonHP)','True(HP)'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
from sklearn.metrics import classification_report


print(classification_report(test_df["label"].values, test_df["pred"].values))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.71      0.72      8334
#            1       0.71      0.72      0.72      8274
#
#     accuracy                           0.72     16608
#    macro avg       0.72      0.72      0.72     16608
# weighted avg       0.72      0.72      0.72     16608
