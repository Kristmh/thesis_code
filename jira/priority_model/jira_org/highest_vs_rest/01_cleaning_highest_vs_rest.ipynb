# %% [markdown]
# # Data cleaning
# We want the class with labels as numerical value and the body with clean text.
#
# This will remove:
# * duplicates
# * NaN entires
# * non english
# * url, html
#
# * make it lowercase
# * combine title and body

# %%
import pandas as pd
import sys
sys.path.append("../../../../../scripts_shared/")
from preprocess_text import preprocess_text

# %%
# Read CSV into a dataframe
df = pd.read_csv("../Jira.csv")
df
# Out:
#              id            fields.project.name fields.priority.name  \
# 0       1843729         Sourcetree for Windows                  NaN
# 1       1843575         Sourcetree for Windows                  Low
# 2       1843552         Sourcetree for Windows                  Low
# 3       1843397         Sourcetree for Windows                  Low
# 4       1842733         Sourcetree for Windows                  NaN
# ...         ...                            ...                  ...
# 274540  1777577  Jira Service Management Cloud                  NaN
# 274541  1777505  Jira Service Management Cloud                  Low
# 274542  1777387  Jira Service Management Cloud                  NaN
# 274543  1777462  Jira Service Management Cloud                  Low
# 274544  1777529  Jira Service Management Cloud               Medium
#
#                       fields.created fields.labels  \
# 0       2022-01-04T09:13:21.000+0000            []
# 1       2022-01-04T07:39:09.000+0000            []
# 2       2022-01-03T21:46:14.000+0000            []
# 3       2022-01-03T14:07:33.000+0000            []
# 4       2021-12-25T02:30:54.000+0000            []
# ...                              ...           ...
# 274540  2021-07-28T08:49:54.000+0000            []
# 274541  2021-07-28T07:18:51.000+0000            []
# 274542  2021-07-28T06:50:23.000+0000            []
# 274543  2021-07-27T18:57:59.000+0000            []
# 274544  2021-07-27T13:18:03.000+0000            []
#
#                                            fields.summary  \
# 0       Please make warning LESS SCARY about a detache...
# 1                          Bug in listing bitbucket repos
# 2                    Spaces in File path of Custom Action
# 3        Failed to start (System.BadImageFormatException)
# 4                             commit view show in branchs
# ...                                                   ...
# 274540                     Printing label tags for assets
# 274541  Having child objects with no individual attrib...
# 274542  Ability to display Insight custom field in Kan...
# 274543  Insight IQL uses timezones in a way that can b...
# 274544  Problem with the Attachment field : Extension ...
#
#                                        fields.description  \
# 0       I wanted to follow a perfectly normal and feas...
# 1       some errors show up as shown in the screenshot...
# 2       I have been using Sourcetree 3.4.4.  We use cu...
# 3       After installing SourceTree for Windows 10 64b...
# 4       When the project contains many branches and I ...
# ...                                                   ...
# 274540  Cant figure out a way to print labels on Insig...
# 274541  h3. Issue Summary\r\n\r\nCreating child object...
# 274542  h3. Problem\r\n\r\nCurrently there is no capab...
# 274543  h3. Issue Summary\r\nInsight IQL uses timezone...
# 274544  h3. Issue Summary\r\n\r\nThe intermittent issu...
#
#          fields.status.name  \
# 0        Gathering Interest
# 1       Waiting for Release
# 2              Needs Triage
# 3              Needs Triage
# 4        Gathering Interest
# ...                     ...
# 274540   Gathering Interest
# 274541    Long Term Backlog
# 274542   Gathering Interest
# 274543     Gathering Impact
# 274544               Closed
#
#                                 fields.status.description  \
# 0       This suggestion needs more unique domain votes...
# 1       A fix for this issue has been implemented and ...
# 2       This issue is waiting to be reviewed by a memb...
# 3       This issue is waiting to be reviewed by a memb...
# 4       This suggestion needs more unique domain votes...
# ...                                                   ...
# 274540  This suggestion needs more unique domain votes...
# 274541  A fix for this issue is required, but planned ...
# 274542  This suggestion needs more unique domain votes...
# 274543  This issue has been reviewed, but needs more s...
# 274544  Work on this issue is complete.\r\n\r\nIf it’s...
#
#        fields.issuetype.name  \
# 0                 Suggestion
# 1                        Bug
# 2                        Bug
# 3                        Bug
# 4                 Suggestion
# ...                      ...
# 274540            Suggestion
# 274541                   Bug
# 274542            Suggestion
# 274543                   Bug
# 274544                   Bug
#
#                              fields.issuetype.description  \
# 0                                                     NaN
# 1       A problem which impairs or prevents the functi...
# 2       A problem which impairs or prevents the functi...
# 3       A problem which impairs or prevents the functi...
# 4                                                     NaN
# ...                                                   ...
# 274540                                                NaN
# 274541  A problem which impairs or prevents the functi...
# 274542                                                NaN
# 274543  A problem which impairs or prevents the functi...
# 274544  A problem which impairs or prevents the functi...
#
#         fields.issuetype.subtask  \
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 274540                     False
# 274541                     False
# 274542                     False
# 274543                     False
# 274544                     False
#
#                                           fields.comments
# 0                                                      []
# 1       [{'self': 'https://jira.atlassian.com/rest/api...
# 2                                                      []
# 3       [{'self': 'https://jira.atlassian.com/rest/api...
# 4                                                      []
# ...                                                   ...
# 274540  [{'self': 'https://jira.atlassian.com/rest/api...
# 274541                                                 []
# 274542                                                 []
# 274543                                                 []
# 274544  [{'self': 'https://jira.atlassian.com/rest/api...
#
# [274545 rows x 13 columns]

# %%
# Count per priority
df['fields.priority.name'].value_counts()
# Out:
# fields.priority.name
# Low        76547
# Medium     43672
# High       10283
# Highest     5022
# Name: count, dtype: int64

# %%
df['fields.issuetype.name'].value_counts().to_frame()[:50]
# Out:
#                                 count
# fields.issuetype.name
# Suggestion                     138378
# Bug                            131040
# Sub-task                         2501
# Support Request                  2438
# Public Security Vulnerability      98
# Improvement                        52
# New Feature                        23
# Task                               12
# Fug                                 2
# Feedback                            1

# %%
highest = df[df['fields.priority.name'] == 'Highest']
high = df[df['fields.priority.name'] == 'High']
medium = df[df['fields.priority.name'] == 'Medium']
low = df[df['fields.priority.name'] == 'Low']
highest
# Out:
#              id                             fields.project.name  \
# 551      590001                          Sourcetree for Windows
# 566      589080                          Sourcetree for Windows
# 590      587950                          Sourcetree for Windows
# 609      587252                          Sourcetree for Windows
# 612      586936                          Sourcetree for Windows
# ...         ...                                             ...
# 273661   322571  Jira Service Management Server and Data Center
# 273813   313406  Jira Service Management Server and Data Center
# 273887   307470  Jira Service Management Server and Data Center
# 273986   301979  Jira Service Management Server and Data Center
# 274530  1777999                   Jira Service Management Cloud
#
#        fields.priority.name                fields.created  \
# 551                 Highest  2016-04-12T08:26:09.000+0000
# 566                 Highest  2016-04-08T08:53:27.000+0000
# 590                 Highest  2016-04-05T13:38:49.000+0000
# 609                 Highest  2016-04-03T13:10:22.000+0000
# 612                 Highest  2016-04-01T11:05:45.000+0000
# ...                     ...                           ...
# 273661              Highest  2014-03-14T10:58:53.000+0000
# 273813              Highest  2014-01-14T14:39:39.000+0000
# 273887              Highest  2013-11-20T16:13:59.000+0000
# 273986              Highest  2013-10-13T22:27:20.000+0000
# 274530              Highest  2021-08-02T02:09:26.000+0000
#
#                  fields.labels  \
# 551                         []
# 566                         []
# 590     ['crash', 'submodule']
# 609         ['clone', 'crash']
# 612                         []
# ...                        ...
# 273661                      []
# 273813      ['affects-server']
# 273887                      []
# 273986      ['affects-server']
# 274530                      []
#
#                                            fields.summary  \
# 551     Cannot complete the installation but get stuck...
# 566                           Crash on startup every time
# 590                  crash when git submodule has changes
# 609     SourceTree consistently crashes when opening f...
# 612     "Create patch" does not work properly on "Work...
# ...                                                   ...
# 273661       Jira Service Desk. Error with license update
# 273813  [java.lang.NullPointerException] Unable to run...
# 273887                    Request types are created twice
# 273986       Service Desk Email Notification From Address
# 274530  Insight field - unable to search on the Portal...
#
#                                        fields.description fields.status.name  \
# 551     Users cannot complete installing SourceTree bu...             Closed
# 566     Have been using sourcetree fine for some time ...             Closed
# 590     In my git project I have changes in the main p...             Closed
# 609     When performing any action that should result ...             Closed
# 612     Whatever I do or select on "Working Copy Chang...             Closed
# ...                                                   ...                ...
# 273661  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...             Closed
# 273813  Hello,\r\nwe have just test JIRA Service Desk,...             Closed
# 273887  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...             Closed
# 273986  Is the service desk using the notification ema...             Closed
# 274530  h3. Issue Summary\r\n\r\nSearch Insight object...             Closed
#
#                                 fields.status.description  \
# 551     Work on this issue is complete.\r\n\r\nIf it’s...
# 566     Work on this issue is complete.\r\n\r\nIf it’s...
# 590     Work on this issue is complete.\r\n\r\nIf it’s...
# 609     Work on this issue is complete.\r\n\r\nIf it’s...
# 612     Work on this issue is complete.\r\n\r\nIf it’s...
# ...                                                   ...
# 273661  Work on this issue is complete.\r\n\r\nIf it’s...
# 273813  Work on this issue is complete.\r\n\r\nIf it’s...
# 273887  Work on this issue is complete.\r\n\r\nIf it’s...
# 273986  Work on this issue is complete.\r\n\r\nIf it’s...
# 274530  Work on this issue is complete.\r\n\r\nIf it’s...
#
#        fields.issuetype.name  \
# 551                      Bug
# 566                      Bug
# 590                      Bug
# 609                      Bug
# 612                      Bug
# ...                      ...
# 273661                   Bug
# 273813                   Bug
# 273887                   Bug
# 273986                   Bug
# 274530                   Bug
#
#                              fields.issuetype.description  \
# 551     A problem which impairs or prevents the functi...
# 566     A problem which impairs or prevents the functi...
# 590     A problem which impairs or prevents the functi...
# 609     A problem which impairs or prevents the functi...
# 612     A problem which impairs or prevents the functi...
# ...                                                   ...
# 273661  A problem which impairs or prevents the functi...
# 273813  A problem which impairs or prevents the functi...
# 273887  A problem which impairs or prevents the functi...
# 273986  A problem which impairs or prevents the functi...
# 274530  A problem which impairs or prevents the functi...
#
#         fields.issuetype.subtask  \
# 551                        False
# 566                        False
# 590                        False
# 609                        False
# 612                        False
# ...                          ...
# 273661                     False
# 273813                     False
# 273887                     False
# 273986                     False
# 274530                     False
#
#                                           fields.comments
# 551                                                    []
# 566     [{'self': 'https://jira.atlassian.com/rest/api...
# 590     [{'self': 'https://jira.atlassian.com/rest/api...
# 609     [{'self': 'https://jira.atlassian.com/rest/api...
# 612                                                    []
# ...                                                   ...
# 273661  [{'self': 'https://jira.atlassian.com/rest/api...
# 273813  [{'self': 'https://jira.atlassian.com/rest/api...
# 273887  [{'self': 'https://jira.atlassian.com/rest/api...
# 273986  [{'self': 'https://jira.atlassian.com/rest/api...
# 274530                                                 []
#
# [5022 rows x 13 columns]

# %%
# Concat high, medium and low
rest = pd.concat([high, medium, low])
rest
# Out:
#              id            fields.project.name fields.priority.name  \
# 125     1763524         Sourcetree for Windows                 High
# 221     1709448         Sourcetree for Windows                 High
# 226      310663         Sourcetree for Windows                 High
# 516      592389         Sourcetree for Windows                 High
# 564      589187         Sourcetree for Windows                 High
# ...         ...                            ...                  ...
# 274537  1777664  Jira Service Management Cloud                  Low
# 274538  1777729  Jira Service Management Cloud                  Low
# 274539  1777711  Jira Service Management Cloud                  Low
# 274541  1777505  Jira Service Management Cloud                  Low
# 274543  1777462  Jira Service Management Cloud                  Low
#
#                       fields.created               fields.labels  \
# 125     2021-05-26T02:13:52.000+0000                          []
# 221     2021-01-27T12:23:21.000+0000                          []
# 226     2013-12-16T07:42:19.000+0000              ['DevTriaged']
# 516     2016-04-19T21:09:23.000+0000          ['authentication']
# 564     2016-04-08T16:10:09.000+0000  ['ContextMenu', 'SideBar']
# ...                              ...                         ...
# 274537  2021-07-29T01:42:19.000+0000                          []
# 274538  2021-07-28T18:57:56.000+0000                          []
# 274539  2021-07-28T12:49:57.000+0000                          []
# 274541  2021-07-28T07:18:51.000+0000                          []
# 274543  2021-07-27T18:57:59.000+0000                          []
#
#                                            fields.summary  \
# 125                              Push refspec not honored
# 221     "Run 'git lfs pull' now? is triggered on every...
# 226     Changing the remote repository path of project...
# 516                   Source tree locks accounts silently
# 564     "File Status" string is sometimes displayed in...
# ...                                                   ...
# 274537  Insight "ORDER BY Updated" IQL does not correc...
# 274538  customers page shows only 20 matched result fo...
# 274539  Clicking on the Link issue button doesn't scro...
# 274541  Having child objects with no individual attrib...
# 274543  Insight IQL uses timezones in a way that can b...
#
#                                        fields.description fields.status.name  \
# 125     I have configured my remote's push refspec for...       Needs Triage
# 221     On every startup, all git LFS repositories cur...             Closed
# 226     When changing te remote repository path throug...             Closed
# 516     *To Reproduce*\r\n{code}\r\ntry having multipl...   Gathering Impact
# 564     h3. Summary\r\n\r\n"File Status" string is som...             Closed
# ...                                                   ...                ...
# 274537  h3. Issue Summary\r\n\r\nSorting objects using...  Long Term Backlog
# 274538  h3. Issue Summary\r\n\r\nIf a service desk pro...  Long Term Backlog
# 274539  h3. Issue Summary\r\n\r\nWe have '*Link Issue*...   Gathering Impact
# 274541  h3. Issue Summary\r\n\r\nCreating child object...  Long Term Backlog
# 274543  h3. Issue Summary\r\nInsight IQL uses timezone...   Gathering Impact
#
#                                 fields.status.description  \
# 125     This issue is waiting to be reviewed by a memb...
# 221     Work on this issue is complete.\r\n\r\nIf it’s...
# 226     Work on this issue is complete.\r\n\r\nIf it’s...
# 516     This issue has been reviewed, but needs more s...
# 564     Work on this issue is complete.\r\n\r\nIf it’s...
# ...                                                   ...
# 274537  A fix for this issue is required, but planned ...
# 274538  A fix for this issue is required, but planned ...
# 274539  This issue has been reviewed, but needs more s...
# 274541  A fix for this issue is required, but planned ...
# 274543  This issue has been reviewed, but needs more s...
#
#        fields.issuetype.name  \
# 125                      Bug
# 221                      Bug
# 226                      Bug
# 516                      Bug
# 564                      Bug
# ...                      ...
# 274537                   Bug
# 274538                   Bug
# 274539                   Bug
# 274541                   Bug
# 274543                   Bug
#
#                              fields.issuetype.description  \
# 125     A problem which impairs or prevents the functi...
# 221     A problem which impairs or prevents the functi...
# 226     A problem which impairs or prevents the functi...
# 516     A problem which impairs or prevents the functi...
# 564     A problem which impairs or prevents the functi...
# ...                                                   ...
# 274537  A problem which impairs or prevents the functi...
# 274538  A problem which impairs or prevents the functi...
# 274539  A problem which impairs or prevents the functi...
# 274541  A problem which impairs or prevents the functi...
# 274543  A problem which impairs or prevents the functi...
#
#         fields.issuetype.subtask  \
# 125                        False
# 221                        False
# 226                        False
# 516                        False
# 564                        False
# ...                          ...
# 274537                     False
# 274538                     False
# 274539                     False
# 274541                     False
# 274543                     False
#
#                                           fields.comments
# 125     [{'self': 'https://jira.atlassian.com/rest/api...
# 221     [{'self': 'https://jira.atlassian.com/rest/api...
# 226     [{'self': 'https://jira.atlassian.com/rest/api...
# 516                                                    []
# 564     [{'self': 'https://jira.atlassian.com/rest/api...
# ...                                                   ...
# 274537  [{'self': 'https://jira.atlassian.com/rest/api...
# 274538                                                 []
# 274539                                                 []
# 274541                                                 []
# 274543                                                 []
#
# [130502 rows x 13 columns]

# %%
#Give each priority a label by number.
# 'Label encoding'. Makes is easier for machine learning models to work with categorical data.

highest["label"] = 1
highest["class"] = "high_priority"
highest
# Out:
# /tmp/ipykernel_454138/3261361000.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["label"] = 1
# /tmp/ipykernel_454138/3261361000.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highest["class"] = "high_priority"
#              id                             fields.project.name  \
# 551      590001                          Sourcetree for Windows
# 566      589080                          Sourcetree for Windows
# 590      587950                          Sourcetree for Windows
# 609      587252                          Sourcetree for Windows
# 612      586936                          Sourcetree for Windows
# ...         ...                                             ...
# 273661   322571  Jira Service Management Server and Data Center
# 273813   313406  Jira Service Management Server and Data Center
# 273887   307470  Jira Service Management Server and Data Center
# 273986   301979  Jira Service Management Server and Data Center
# 274530  1777999                   Jira Service Management Cloud
#
#        fields.priority.name                fields.created  \
# 551                 Highest  2016-04-12T08:26:09.000+0000
# 566                 Highest  2016-04-08T08:53:27.000+0000
# 590                 Highest  2016-04-05T13:38:49.000+0000
# 609                 Highest  2016-04-03T13:10:22.000+0000
# 612                 Highest  2016-04-01T11:05:45.000+0000
# ...                     ...                           ...
# 273661              Highest  2014-03-14T10:58:53.000+0000
# 273813              Highest  2014-01-14T14:39:39.000+0000
# 273887              Highest  2013-11-20T16:13:59.000+0000
# 273986              Highest  2013-10-13T22:27:20.000+0000
# 274530              Highest  2021-08-02T02:09:26.000+0000
#
#                  fields.labels  \
# 551                         []
# 566                         []
# 590     ['crash', 'submodule']
# 609         ['clone', 'crash']
# 612                         []
# ...                        ...
# 273661                      []
# 273813      ['affects-server']
# 273887                      []
# 273986      ['affects-server']
# 274530                      []
#
#                                            fields.summary  \
# 551     Cannot complete the installation but get stuck...
# 566                           Crash on startup every time
# 590                  crash when git submodule has changes
# 609     SourceTree consistently crashes when opening f...
# 612     "Create patch" does not work properly on "Work...
# ...                                                   ...
# 273661       Jira Service Desk. Error with license update
# 273813  [java.lang.NullPointerException] Unable to run...
# 273887                    Request types are created twice
# 273986       Service Desk Email Notification From Address
# 274530  Insight field - unable to search on the Portal...
#
#                                        fields.description fields.status.name  \
# 551     Users cannot complete installing SourceTree bu...             Closed
# 566     Have been using sourcetree fine for some time ...             Closed
# 590     In my git project I have changes in the main p...             Closed
# 609     When performing any action that should result ...             Closed
# 612     Whatever I do or select on "Working Copy Chang...             Closed
# ...                                                   ...                ...
# 273661  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...             Closed
# 273813  Hello,\r\nwe have just test JIRA Service Desk,...             Closed
# 273887  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...             Closed
# 273986  Is the service desk using the notification ema...             Closed
# 274530  h3. Issue Summary\r\n\r\nSearch Insight object...             Closed
#
#                                 fields.status.description  \
# 551     Work on this issue is complete.\r\n\r\nIf it’s...
# 566     Work on this issue is complete.\r\n\r\nIf it’s...
# 590     Work on this issue is complete.\r\n\r\nIf it’s...
# 609     Work on this issue is complete.\r\n\r\nIf it’s...
# 612     Work on this issue is complete.\r\n\r\nIf it’s...
# ...                                                   ...
# 273661  Work on this issue is complete.\r\n\r\nIf it’s...
# 273813  Work on this issue is complete.\r\n\r\nIf it’s...
# 273887  Work on this issue is complete.\r\n\r\nIf it’s...
# 273986  Work on this issue is complete.\r\n\r\nIf it’s...
# 274530  Work on this issue is complete.\r\n\r\nIf it’s...
#
#        fields.issuetype.name  \
# 551                      Bug
# 566                      Bug
# 590                      Bug
# 609                      Bug
# 612                      Bug
# ...                      ...
# 273661                   Bug
# 273813                   Bug
# 273887                   Bug
# 273986                   Bug
# 274530                   Bug
#
#                              fields.issuetype.description  \
# 551     A problem which impairs or prevents the functi...
# 566     A problem which impairs or prevents the functi...
# 590     A problem which impairs or prevents the functi...
# 609     A problem which impairs or prevents the functi...
# 612     A problem which impairs or prevents the functi...
# ...                                                   ...
# 273661  A problem which impairs or prevents the functi...
# 273813  A problem which impairs or prevents the functi...
# 273887  A problem which impairs or prevents the functi...
# 273986  A problem which impairs or prevents the functi...
# 274530  A problem which impairs or prevents the functi...
#
#         fields.issuetype.subtask  \
# 551                        False
# 566                        False
# 590                        False
# 609                        False
# 612                        False
# ...                          ...
# 273661                     False
# 273813                     False
# 273887                     False
# 273986                     False
# 274530                     False
#
#                                           fields.comments  label  \
# 551                                                    []      1
# 566     [{'self': 'https://jira.atlassian.com/rest/api...      1
# 590     [{'self': 'https://jira.atlassian.com/rest/api...      1
# 609     [{'self': 'https://jira.atlassian.com/rest/api...      1
# 612                                                    []      1
# ...                                                   ...    ...
# 273661  [{'self': 'https://jira.atlassian.com/rest/api...      1
# 273813  [{'self': 'https://jira.atlassian.com/rest/api...      1
# 273887  [{'self': 'https://jira.atlassian.com/rest/api...      1
# 273986  [{'self': 'https://jira.atlassian.com/rest/api...      1
# 274530                                                 []      1
#
#                 class
# 551     high_priority
# 566     high_priority
# 590     high_priority
# 609     high_priority
# 612     high_priority
# ...               ...
# 273661  high_priority
# 273813  high_priority
# 273887  high_priority
# 273986  high_priority
# 274530  high_priority
#
# [5022 rows x 15 columns]

# %%
rest["label"] = 0
rest["class"] = "not_high_priority"
rest
# Out:
#              id            fields.project.name fields.priority.name  \
# 125     1763524         Sourcetree for Windows                 High
# 221     1709448         Sourcetree for Windows                 High
# 226      310663         Sourcetree for Windows                 High
# 516      592389         Sourcetree for Windows                 High
# 564      589187         Sourcetree for Windows                 High
# ...         ...                            ...                  ...
# 274537  1777664  Jira Service Management Cloud                  Low
# 274538  1777729  Jira Service Management Cloud                  Low
# 274539  1777711  Jira Service Management Cloud                  Low
# 274541  1777505  Jira Service Management Cloud                  Low
# 274543  1777462  Jira Service Management Cloud                  Low
#
#                       fields.created               fields.labels  \
# 125     2021-05-26T02:13:52.000+0000                          []
# 221     2021-01-27T12:23:21.000+0000                          []
# 226     2013-12-16T07:42:19.000+0000              ['DevTriaged']
# 516     2016-04-19T21:09:23.000+0000          ['authentication']
# 564     2016-04-08T16:10:09.000+0000  ['ContextMenu', 'SideBar']
# ...                              ...                         ...
# 274537  2021-07-29T01:42:19.000+0000                          []
# 274538  2021-07-28T18:57:56.000+0000                          []
# 274539  2021-07-28T12:49:57.000+0000                          []
# 274541  2021-07-28T07:18:51.000+0000                          []
# 274543  2021-07-27T18:57:59.000+0000                          []
#
#                                            fields.summary  \
# 125                              Push refspec not honored
# 221     "Run 'git lfs pull' now? is triggered on every...
# 226     Changing the remote repository path of project...
# 516                   Source tree locks accounts silently
# 564     "File Status" string is sometimes displayed in...
# ...                                                   ...
# 274537  Insight "ORDER BY Updated" IQL does not correc...
# 274538  customers page shows only 20 matched result fo...
# 274539  Clicking on the Link issue button doesn't scro...
# 274541  Having child objects with no individual attrib...
# 274543  Insight IQL uses timezones in a way that can b...
#
#                                        fields.description fields.status.name  \
# 125     I have configured my remote's push refspec for...       Needs Triage
# 221     On every startup, all git LFS repositories cur...             Closed
# 226     When changing te remote repository path throug...             Closed
# 516     *To Reproduce*\r\n{code}\r\ntry having multipl...   Gathering Impact
# 564     h3. Summary\r\n\r\n"File Status" string is som...             Closed
# ...                                                   ...                ...
# 274537  h3. Issue Summary\r\n\r\nSorting objects using...  Long Term Backlog
# 274538  h3. Issue Summary\r\n\r\nIf a service desk pro...  Long Term Backlog
# 274539  h3. Issue Summary\r\n\r\nWe have '*Link Issue*...   Gathering Impact
# 274541  h3. Issue Summary\r\n\r\nCreating child object...  Long Term Backlog
# 274543  h3. Issue Summary\r\nInsight IQL uses timezone...   Gathering Impact
#
#                                 fields.status.description  \
# 125     This issue is waiting to be reviewed by a memb...
# 221     Work on this issue is complete.\r\n\r\nIf it’s...
# 226     Work on this issue is complete.\r\n\r\nIf it’s...
# 516     This issue has been reviewed, but needs more s...
# 564     Work on this issue is complete.\r\n\r\nIf it’s...
# ...                                                   ...
# 274537  A fix for this issue is required, but planned ...
# 274538  A fix for this issue is required, but planned ...
# 274539  This issue has been reviewed, but needs more s...
# 274541  A fix for this issue is required, but planned ...
# 274543  This issue has been reviewed, but needs more s...
#
#        fields.issuetype.name  \
# 125                      Bug
# 221                      Bug
# 226                      Bug
# 516                      Bug
# 564                      Bug
# ...                      ...
# 274537                   Bug
# 274538                   Bug
# 274539                   Bug
# 274541                   Bug
# 274543                   Bug
#
#                              fields.issuetype.description  \
# 125     A problem which impairs or prevents the functi...
# 221     A problem which impairs or prevents the functi...
# 226     A problem which impairs or prevents the functi...
# 516     A problem which impairs or prevents the functi...
# 564     A problem which impairs or prevents the functi...
# ...                                                   ...
# 274537  A problem which impairs or prevents the functi...
# 274538  A problem which impairs or prevents the functi...
# 274539  A problem which impairs or prevents the functi...
# 274541  A problem which impairs or prevents the functi...
# 274543  A problem which impairs or prevents the functi...
#
#         fields.issuetype.subtask  \
# 125                        False
# 221                        False
# 226                        False
# 516                        False
# 564                        False
# ...                          ...
# 274537                     False
# 274538                     False
# 274539                     False
# 274541                     False
# 274543                     False
#
#                                           fields.comments  label  \
# 125     [{'self': 'https://jira.atlassian.com/rest/api...      0
# 221     [{'self': 'https://jira.atlassian.com/rest/api...      0
# 226     [{'self': 'https://jira.atlassian.com/rest/api...      0
# 516                                                    []      0
# 564     [{'self': 'https://jira.atlassian.com/rest/api...      0
# ...                                                   ...    ...
# 274537  [{'self': 'https://jira.atlassian.com/rest/api...      0
# 274538                                                 []      0
# 274539                                                 []      0
# 274541                                                 []      0
# 274543                                                 []      0
#
#                     class
# 125     not_high_priority
# 221     not_high_priority
# 226     not_high_priority
# 516     not_high_priority
# 564     not_high_priority
# ...                   ...
# 274537  not_high_priority
# 274538  not_high_priority
# 274539  not_high_priority
# 274541  not_high_priority
# 274543  not_high_priority
#
# [130502 rows x 15 columns]

# %%
high_priority = highest
not_high_priority = rest

# %%
# Drop duplicates by the content of the description
high_priority = high_priority.drop_duplicates(subset=['fields.description'], keep='last')
high_priority.dropna(inplace=True)
high_priority.reset_index(inplace=True)
high_priority.drop(columns=["index"] , inplace= True)
high_priority["class"].value_counts()
# Out:
# /tmp/ipykernel_454138/1329060103.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_priority.dropna(inplace=True)
# /tmp/ipykernel_454138/1329060103.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_priority.drop(columns=["index"] , inplace= True)
# class
# high_priority    4769
# Name: count, dtype: int64

# %%
# Drop duplicates by the content of the title
not_high_priority = not_high_priority.drop_duplicates(subset=['fields.description'], keep='last')
not_high_priority.dropna(inplace=True)
not_high_priority.reset_index(inplace=True)
not_high_priority.drop(columns=["index"] , inplace= True)
not_high_priority["class"].value_counts()
# Out:
# /tmp/ipykernel_454138/2023168667.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority.dropna(inplace=True)
# /tmp/ipykernel_454138/2023168667.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_high_priority.drop(columns=["index"] , inplace= True)
# class
# not_high_priority    124296
# Name: count, dtype: int64

# %%
high_priority.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4769 entries, 0 to 4768
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            4769 non-null   int64
#  1   fields.project.name           4769 non-null   object
#  2   fields.priority.name          4769 non-null   object
#  3   fields.created                4769 non-null   object
#  4   fields.labels                 4769 non-null   object
#  5   fields.summary                4769 non-null   object
#  6   fields.description            4769 non-null   object
#  7   fields.status.name            4769 non-null   object
#  8   fields.status.description     4769 non-null   object
#  9   fields.issuetype.name         4769 non-null   object
#  10  fields.issuetype.description  4769 non-null   object
#  11  fields.issuetype.subtask      4769 non-null   bool
#  12  fields.comments               4769 non-null   object
#  13  label                         4769 non-null   int64
#  14  class                         4769 non-null   object
# dtypes: bool(1), int64(2), object(12)
# memory usage: 526.4+ KB

# %%
label_counts = high_priority["class"].value_counts()
label_counts_nhp = not_high_priority["class"].value_counts()
print(label_counts)
not_high_priority_count = label_counts_nhp["not_high_priority"]
print(not_high_priority_count)
hp_count = label_counts["high_priority"]
hp_count
# Out:
# class
# high_priority    4769
# Name: count, dtype: int64
# 124296
# 4769

# %%
not_high_priority = not_high_priority.sample(frac=hp_count/not_high_priority_count, random_state=42)
not_high_priority
# Out:
#              id                   fields.project.name fields.priority.name  \
# 33140     16963     Confluence Server and Data Center               Medium
# 93553    278078     Confluence Server and Data Center                  Low
# 114927  1723410                                Bamboo                  Low
# 79744    417129                               FishEye                  Low
# 94103   1097178  Jira Software Server and Data Center                  Low
# ...         ...                                   ...                  ...
# 32041     30385     Confluence Server and Data Center               Medium
# 41890   1387405                       Bitbucket Cloud               Medium
# 18661   1171073                            Jira Cloud               Medium
# 21079    299606                               FishEye               Medium
# 91151    408334     Confluence Server and Data Center                  Low
#
#                       fields.created  \
# 33140   2004-03-06T18:02:40.000+0000
# 93553   2013-05-26T16:16:13.000+0000
# 114927  2021-02-26T18:33:21.000+0000
# 79744   2015-04-06T18:39:23.000+0000
# 94103   2018-12-19T06:40:56.000+0000
# ...                              ...
# 32041   2005-10-18T05:25:04.000+0000
# 41890   2015-08-11T09:14:42.000+0000
# 18661   2019-05-20T20:08:40.000+0000
# 21079   2013-09-26T17:26:14.000+0000
# 91151   2015-03-06T14:57:43.000+0000
#
#                                             fields.labels  \
# 33140                                  ['affects-server']
# 93553                             ['official', 'website']
# 114927                                                 []
# 79744                              ['jac-cleanup-phase2']
# 94103                                                  []
# ...                                                   ...
# 32041                        ['affects-server', 'editor']
# 41890                                        ['migrated']
# 18661                                        ['next-gen']
# 21079                                                  []
# 91151   ['Macros-Multimedia', 'affects-cloud', 'affect...
#
#                                            fields.summary  \
# 33140                commentrss.action returning rss 0.92
# 93553   Atlassian website has incorrect line height fo...
# 114927  When a custom field is made mandatory in Jira,...
# 79744   Revisions from closed heads are considered anc...
# 94103               Misalignment of icons in Backlog view
# ...                                                   ...
# 32041   Search macro explodes if you specify a max # o...
# 41890   Issue when inviting user to a repository. (BB-...
# 18661   As a Jira admin, during the CSV External Syste...
# 21079   Fisheye restore not able to find postgresql or...
# 91151   Multimedia File Won't Display with Autoplay is...
#
#                                        fields.description fields.status.name  \
# 33140                 rss: Unsupported RSS version 0.9.2.             Closed
# 93553   {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...             Closed
# 114927  h3. Issue Summary\r\n\r\nIf a user tries to cr...  Long Term Backlog
# 79744   *Edit*: I managed to reproduce this and have r...             Closed
# 94103   h3. Summary\r\nThe 'issue type' and 'priority'...             Closed
# ...                                                   ...                ...
# 32041   IndexOutOfBoundsException when it tries to lim...             Closed
# 41890   !3555020425-Screen%20Shot%202015-08-07%20at%20...             Closed
# 18661   h3. Summary\r\n\r\n* When importing a CSV file...   Gathering Impact
# 21079   When restoring an OnDemand fisheye backup into...             Closed
# 91151   {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...             Closed
#
#                                 fields.status.description  \
# 33140   Work on this issue is complete.\r\n\r\nIf it’s...
# 93553   Work on this issue is complete.\r\n\r\nIf it’s...
# 114927  A fix for this issue is required, but planned ...
# 79744   Work on this issue is complete.\r\n\r\nIf it’s...
# 94103   Work on this issue is complete.\r\n\r\nIf it’s...
# ...                                                   ...
# 32041   Work on this issue is complete.\r\n\r\nIf it’s...
# 41890   Work on this issue is complete.\r\n\r\nIf it’s...
# 18661   This issue has been reviewed, but needs more s...
# 21079   Work on this issue is complete.\r\n\r\nIf it’s...
# 91151   Work on this issue is complete.\r\n\r\nIf it’s...
#
#        fields.issuetype.name  \
# 33140                    Bug
# 93553                    Bug
# 114927                   Bug
# 79744                    Bug
# 94103                    Bug
# ...                      ...
# 32041                    Bug
# 41890                    Bug
# 18661                    Bug
# 21079                    Bug
# 91151                    Bug
#
#                              fields.issuetype.description  \
# 33140   A problem which impairs or prevents the functi...
# 93553   A problem which impairs or prevents the functi...
# 114927  A problem which impairs or prevents the functi...
# 79744   A problem which impairs or prevents the functi...
# 94103   A problem which impairs or prevents the functi...
# ...                                                   ...
# 32041   A problem which impairs or prevents the functi...
# 41890   A problem which impairs or prevents the functi...
# 18661   A problem which impairs or prevents the functi...
# 21079   A problem which impairs or prevents the functi...
# 91151   A problem which impairs or prevents the functi...
#
#         fields.issuetype.subtask  \
# 33140                      False
# 93553                      False
# 114927                     False
# 79744                      False
# 94103                      False
# ...                          ...
# 32041                      False
# 41890                      False
# 18661                      False
# 21079                      False
# 91151                      False
#
#                                           fields.comments  label  \
# 33140                                                  []      0
# 93553   [{'self': 'https://jira.atlassian.com/rest/api...      0
# 114927                                                 []      0
# 79744   [{'self': 'https://jira.atlassian.com/rest/api...      0
# 94103                                                  []      0
# ...                                                   ...    ...
# 32041   [{'self': 'https://jira.atlassian.com/rest/api...      0
# 41890   [{'self': 'https://jira.atlassian.com/rest/api...      0
# 18661   [{'self': 'https://jira.atlassian.com/rest/api...      0
# 21079   [{'self': 'https://jira.atlassian.com/rest/api...      0
# 91151   [{'self': 'https://jira.atlassian.com/rest/api...      0
#
#                     class
# 33140   not_high_priority
# 93553   not_high_priority
# 114927  not_high_priority
# 79744   not_high_priority
# 94103   not_high_priority
# ...                   ...
# 32041   not_high_priority
# 41890   not_high_priority
# 18661   not_high_priority
# 21079   not_high_priority
# 91151   not_high_priority
#
# [4769 rows x 15 columns]

# %%
all_priority = pd.concat([high_priority,not_high_priority] , ignore_index = True)
all_priority.tail()
# Out:
#            id                fields.project.name fields.priority.name  \
# 9533    30385  Confluence Server and Data Center               Medium
# 9534  1387405                    Bitbucket Cloud               Medium
# 9535  1171073                         Jira Cloud               Medium
# 9536   299606                            FishEye               Medium
# 9537   408334  Confluence Server and Data Center                  Low
#
#                     fields.created  \
# 9533  2005-10-18T05:25:04.000+0000
# 9534  2015-08-11T09:14:42.000+0000
# 9535  2019-05-20T20:08:40.000+0000
# 9536  2013-09-26T17:26:14.000+0000
# 9537  2015-03-06T14:57:43.000+0000
#
#                                           fields.labels  \
# 9533                       ['affects-server', 'editor']
# 9534                                       ['migrated']
# 9535                                       ['next-gen']
# 9536                                                 []
# 9537  ['Macros-Multimedia', 'affects-cloud', 'affect...
#
#                                          fields.summary  \
# 9533  Search macro explodes if you specify a max # o...
# 9534  Issue when inviting user to a repository. (BB-...
# 9535  As a Jira admin, during the CSV External Syste...
# 9536  Fisheye restore not able to find postgresql or...
# 9537  Multimedia File Won't Display with Autoplay is...
#
#                                      fields.description fields.status.name  \
# 9533  IndexOutOfBoundsException when it tries to lim...             Closed
# 9534  !3555020425-Screen%20Shot%202015-08-07%20at%20...             Closed
# 9535  h3. Summary\r\n\r\n* When importing a CSV file...   Gathering Impact
# 9536  When restoring an OnDemand fisheye backup into...             Closed
# 9537  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...             Closed
#
#                               fields.status.description fields.issuetype.name  \
# 9533  Work on this issue is complete.\r\n\r\nIf it’s...                   Bug
# 9534  Work on this issue is complete.\r\n\r\nIf it’s...                   Bug
# 9535  This issue has been reviewed, but needs more s...                   Bug
# 9536  Work on this issue is complete.\r\n\r\nIf it’s...                   Bug
# 9537  Work on this issue is complete.\r\n\r\nIf it’s...                   Bug
#
#                            fields.issuetype.description  \
# 9533  A problem which impairs or prevents the functi...
# 9534  A problem which impairs or prevents the functi...
# 9535  A problem which impairs or prevents the functi...
# 9536  A problem which impairs or prevents the functi...
# 9537  A problem which impairs or prevents the functi...
#
#       fields.issuetype.subtask  \
# 9533                     False
# 9534                     False
# 9535                     False
# 9536                     False
# 9537                     False
#
#                                         fields.comments  label  \
# 9533  [{'self': 'https://jira.atlassian.com/rest/api...      0
# 9534  [{'self': 'https://jira.atlassian.com/rest/api...      0
# 9535  [{'self': 'https://jira.atlassian.com/rest/api...      0
# 9536  [{'self': 'https://jira.atlassian.com/rest/api...      0
# 9537  [{'self': 'https://jira.atlassian.com/rest/api...      0
#
#                   class
# 9533  not_high_priority
# 9534  not_high_priority
# 9535  not_high_priority
# 9536  not_high_priority
# 9537  not_high_priority

# %%
# 
all_priority["label"].value_counts()
# Out:
# label
# 1    4769
# 0    4769
# Name: count, dtype: int64

# %%
print(all_priority["fields.description"][0])
# Out:
# Users cannot complete installing SourceTree but they get stuck in account settings. See also the attached. It happens on any version of SourceTree WIN and MAC.

# %%
print(all_priority["fields.summary"][0])
# Out:
# Cannot complete the installation but get stuck in account setting

# %%
print(all_priority["fields.comments"][1])
# Out:
# [{'self': 'https://jira.atlassian.com/rest/api/2/issue/589080/comment/900034', 'id': '900034', 'author': {'self': 'https://jira.atlassian.com/rest/api/2/user?username=8504ab3b8c39', 'name': '8504ab3b8c39', 'key': 'davidjward30362923814', 'avatarUrls': {'48x48': 'https://avatar-cdn.atlassian.com/1ab0718f94e38f57961f00defc731f8c?d=mm&s=48', '24x24': 'https://avatar-cdn.atlassian.com/1ab0718f94e38f57961f00defc731f8c?d=mm&s=24', '16x16': 'https://avatar-cdn.atlassian.com/1ab0718f94e38f57961f00defc731f8c?d=mm&s=16', '32x32': 'https://avatar-cdn.atlassian.com/1ab0718f94e38f57961f00defc731f8c?d=mm&s=32'}, 'displayName': 'David Ward', 'active': True, 'timeZone': 'UTC'}, 'body': 'Finally worked out that our corporate McAfee is blocking access to the registry key change:\r\n\r\n10:32:03.2079229\tSourceTree.exe\t7764\tRegOpenKey\tHKCU\\Software\\Microsoft\\Internet Explorer\\Main\\FeatureControl\\FEATURE_BROWSER_EMULATION\tSUCCESS\tDesired Access: Read/Write\r\n', 'updateAuthor': {'self': 'https://jira.atlassian.com/rest/api/2/user?username=8504ab3b8c39', 'name': '8504ab3b8c39', 'key': 'davidjward30362923814', 'avatarUrls': {'48x48': 'https://avatar-cdn.atlassian.com/1ab0718f94e38f57961f00defc731f8c?d=mm&s=48', '24x24': 'https://avatar-cdn.atlassian.com/1ab0718f94e38f57961f00defc731f8c?d=mm&s=24', '16x16': 'https://avatar-cdn.atlassian.com/1ab0718f94e38f57961f00defc731f8c?d=mm&s=16', '32x32': 'https://avatar-cdn.atlassian.com/1ab0718f94e38f57961f00defc731f8c?d=mm&s=32'}, 'displayName': 'David Ward', 'active': True, 'timeZone': 'UTC'}, 'created': '2016-04-18T10:42:59.346+0000', 'updated': '2016-04-18T10:42:59.346+0000'}, {'self': 'https://jira.atlassian.com/rest/api/2/issue/589080/comment/982686', 'id': '982686', 'author': {'self': 'https://jira.atlassian.com/rest/api/2/user?username=e22efdec1e24', 'name': 'e22efdec1e24', 'key': 'charlwilson1522512750', 'avatarUrls': {'48x48': 'https://avatar-cdn.atlassian.com/1c9cc15fade25f39dda999b4683ff0d9?d=mm&s=48', '24x24': 'https://avatar-cdn.atlassian.com/1c9cc15fade25f39dda999b4683ff0d9?d=mm&s=24', '16x16': 'https://avatar-cdn.atlassian.com/1c9cc15fade25f39dda999b4683ff0d9?d=mm&s=16', '32x32': 'https://avatar-cdn.atlassian.com/1c9cc15fade25f39dda999b4683ff0d9?d=mm&s=32'}, 'displayName': 'Charles Wilson', 'active': True, 'timeZone': 'UTC'}, 'body': "Is there a workaround for this? I don't understand why it was resolved.", 'updateAuthor': {'self': 'https://jira.atlassian.com/rest/api/2/user?username=e22efdec1e24', 'name': 'e22efdec1e24', 'key': 'charlwilson1522512750', 'avatarUrls': {'48x48': 'https://avatar-cdn.atlassian.com/1c9cc15fade25f39dda999b4683ff0d9?d=mm&s=48', '24x24': 'https://avatar-cdn.atlassian.com/1c9cc15fade25f39dda999b4683ff0d9?d=mm&s=24', '16x16': 'https://avatar-cdn.atlassian.com/1c9cc15fade25f39dda999b4683ff0d9?d=mm&s=16', '32x32': 'https://avatar-cdn.atlassian.com/1c9cc15fade25f39dda999b4683ff0d9?d=mm&s=32'}, 'displayName': 'Charles Wilson', 'active': True, 'timeZone': 'UTC'}, 'created': '2016-11-08T00:53:20.008+0000', 'updated': '2016-11-08T00:53:20.008+0000'}, {'self': 'https://jira.atlassian.com/rest/api/2/issue/589080/comment/1062689', 'id': '1062689', 'author': {'self': 'https://jira.atlassian.com/rest/api/2/user?username=283fee5d9d91', 'name': '283fee5d9d91', 'key': 'benoit5', 'avatarUrls': {'48x48': 'https://avatar-cdn.atlassian.com/5d04723a8f0e2171de451cf78f027f82?d=mm&s=48', '24x24': 'https://avatar-cdn.atlassian.com/5d04723a8f0e2171de451cf78f027f82?d=mm&s=24', '16x16': 'https://avatar-cdn.atlassian.com/5d04723a8f0e2171de451cf78f027f82?d=mm&s=16', '32x32': 'https://avatar-cdn.atlassian.com/5d04723a8f0e2171de451cf78f027f82?d=mm&s=32'}, 'displayName': 'Benoit Heurter', 'active': True, 'timeZone': 'Europe/Brussels'}, 'body': 'Same issue here. \xa0Cannot start SourceTree. \xa0The even viewer confirms SourceTree tried to write in the registry.\r\n\r\nHow can we solved that ?', 'updateAuthor': {'self': 'https://jira.atlassian.com/rest/api/2/user?username=283fee5d9d91', 'name ...

# %%
# Make a new dataframe with only text, label and class cols.
all_priority_subset = all_priority[["fields.description" , "label" , "class"]]
all_priority_subset
# Out:
#                                      fields.description  label  \
# 0     Users cannot complete installing SourceTree bu...      1
# 1     Have been using sourcetree fine for some time ...      1
# 2     In my git project I have changes in the main p...      1
# 3     When performing any action that should result ...      1
# 4     Whatever I do or select on "Working Copy Chang...      1
# ...                                                 ...    ...
# 9533  IndexOutOfBoundsException when it tries to lim...      0
# 9534  !3555020425-Screen%20Shot%202015-08-07%20at%20...      0
# 9535  h3. Summary\r\n\r\n* When importing a CSV file...      0
# 9536  When restoring an OnDemand fisheye backup into...      0
# 9537  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...      0
#
#                   class
# 0         high_priority
# 1         high_priority
# 2         high_priority
# 3         high_priority
# 4         high_priority
# ...                 ...
# 9533  not_high_priority
# 9534  not_high_priority
# 9535  not_high_priority
# 9536  not_high_priority
# 9537  not_high_priority
#
# [9538 rows x 3 columns]

# %%
# Convert to string
all_priority_subset["text_str"] = all_priority_subset['fields.description'].astype(str)
# Out:
# /tmp/ipykernel_454138/2820995913.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_str"] = all_priority_subset['fields.description'].astype(str)

# %%
all_priority_subset
# Out:
#                                      fields.description  label  \
# 0     Users cannot complete installing SourceTree bu...      1
# 1     Have been using sourcetree fine for some time ...      1
# 2     In my git project I have changes in the main p...      1
# 3     When performing any action that should result ...      1
# 4     Whatever I do or select on "Working Copy Chang...      1
# ...                                                 ...    ...
# 9533  IndexOutOfBoundsException when it tries to lim...      0
# 9534  !3555020425-Screen%20Shot%202015-08-07%20at%20...      0
# 9535  h3. Summary\r\n\r\n* When importing a CSV file...      0
# 9536  When restoring an OnDemand fisheye backup into...      0
# 9537  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...      0
#
#                   class                                           text_str
# 0         high_priority  Users cannot complete installing SourceTree bu...
# 1         high_priority  Have been using sourcetree fine for some time ...
# 2         high_priority  In my git project I have changes in the main p...
# 3         high_priority  When performing any action that should result ...
# 4         high_priority  Whatever I do or select on "Working Copy Chang...
# ...                 ...                                                ...
# 9533  not_high_priority  IndexOutOfBoundsException when it tries to lim...
# 9534  not_high_priority  !3555020425-Screen%20Shot%202015-08-07%20at%20...
# 9535  not_high_priority  h3. Summary\r\n\r\n* When importing a CSV file...
# 9536  not_high_priority  When restoring an OnDemand fisheye backup into...
# 9537  not_high_priority  {panel:bgColor=#e7f4fa}\n  *NOTE:* This bug re...
#
# [9538 rows x 4 columns]

# %%
# Clean the data.
all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_454138/63294665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_priority_subset["text_clean"] = all_priority_subset["text_str"].map(preprocess_text)

# %%
# Make a subset with text_clean and label
priority_label_text = all_priority_subset[["text_clean" , "label"]]
priority_label_text
# Out:
#                                              text_clean  label
# 0     users cannot complete installing sourcetree bu...      1
# 1     have been using sourcetree fine for some time ...      1
# 2     in my git project i have changes in the main p...      1
# 3     when performing any action that should result ...      1
# 4     whatever i do or select on working copy change...      1
# ...                                                 ...    ...
# 9533  indexoutofboundsexception when it tries to lim...      0
# 9534                                                         0
# 9535  summary when importing a csv file using the ex...      0
# 9536  when restoring an ondemand fisheye backup into...      0
# 9537  note this bug report is for confluence server ...      0
#
# [9538 rows x 2 columns]

# %%
# Row with NaN
priority_label_text[priority_label_text.isna().any(axis=1)]
# Out:
#      text_clean  label
# 9           NaN      1
# 155         NaN      1
# 162         NaN      1
# 205         NaN      1
# 356         NaN      1
# ...         ...    ...
# 9225        NaN      0
# 9269        NaN      0
# 9317        NaN      0
# 9336        NaN      0
# 9475        NaN      0
#
# [154 rows x 2 columns]

# %%
# Need to dropna here since cleaning function returns NaN for not english text.
priority_label_text.dropna(inplace=True)
priority_label_text.reset_index(drop=True,inplace=True)

priority_label_text
# Out:
# /tmp/ipykernel_454138/2434149455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_label_text.dropna(inplace=True)
#                                              text_clean  label
# 0     users cannot complete installing sourcetree bu...      1
# 1     have been using sourcetree fine for some time ...      1
# 2     in my git project i have changes in the main p...      1
# 3     when performing any action that should result ...      1
# 4     whatever i do or select on working copy change...      1
# ...                                                 ...    ...
# 9379  indexoutofboundsexception when it tries to lim...      0
# 9380                                                         0
# 9381  summary when importing a csv file using the ex...      0
# 9382  when restoring an ondemand fisheye backup into...      0
# 9383  note this bug report is for confluence server ...      0
#
# [9384 rows x 2 columns]

# %%
# Rows with NaN
priority_label_text[priority_label_text.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [text_clean, label]
# Index: []

# %%
from sklearn.utils import resample

# Split the dataset into two based on the label
df_majority = priority_label_text[priority_label_text['label'] == 0]
df_minority = priority_label_text[priority_label_text['label'] == 1]

# Undersample the majority class
df_majority_undersampled = resample(df_majority, 
                                     replace=False,    # sample without replacement
                                     n_samples=len(df_minority),     # to match minority class
                                     random_state=123) # reproducible results

# Combine minority class with downsampled majority class
df_balanced = pd.concat([df_majority_undersampled, df_minority])

# Shuffle the dataset to avoid any ordering bias
df_balanced = df_balanced.sample(frac=1).reset_index(drop=True)
priority_label_text = df_balanced
priority_label_text["label"].value_counts()
# Out:
# label
# 1    4682
# 0    4682
# Name: count, dtype: int64

# %%
priority_label_text[priority_label_text.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [text_clean, label]
# Index: []

# %%
null_rows = priority_label_text[priority_label_text['text_clean'].isnull()]
null_rows
# Out:
# Empty DataFrame
# Columns: [text_clean, label]
# Index: []

# %%
# Clean dataset with clean text and labels.
# 0 = high priority, 1 = not high priority
file_name = f"clean_highest_vs_rest.csv"
priority_label_text.to_csv(file_name, index=False)

# %%
pri = pd.read_csv(file_name)
pri
# Out:
#                                              text_clean  label
# 0     summary when trying to edit an existing conflu...      1
# 1     i could reproduce this errorbug in sourcetree ...      1
# 2     i get an exception when the application is fir...      0
# 3     system errora system error has occurredif this...      0
# 4     summary service desk email notifications are i...      0
# ...                                                 ...    ...
# 9359  there is a erroneous notondemandcondition in t...      1
# 9360  note this bug report is for confluence server ...      1
# 9361  note this bug report is for jira server using ...      0
# 9362  app fails to start up the main windows is disp...      1
# 9363  issue summary content of a custom url field is...      0
#
# [9364 rows x 2 columns]

# %%
null_rows = pri[pri['text_clean'].isnull()]
null_rows
# Out:
#      text_clean  label
# 765         NaN      0
# 2511        NaN      0
# 4401        NaN      1
# 6928        NaN      0
# 7329        NaN      1

# %%
# Remove rows with NaN
pri = pri.dropna()
# Reset index
pri.reset_index(drop=True, inplace=True)
pri
# Out:
#                                              text_clean  label
# 0     summary when trying to edit an existing conflu...      1
# 1     i could reproduce this errorbug in sourcetree ...      1
# 2     i get an exception when the application is fir...      0
# 3     system errora system error has occurredif this...      0
# 4     summary service desk email notifications are i...      0
# ...                                                 ...    ...
# 9354  there is a erroneous notondemandcondition in t...      1
# 9355  note this bug report is for confluence server ...      1
# 9356  note this bug report is for jira server using ...      0
# 9357  app fails to start up the main windows is disp...      1
# 9358  issue summary content of a custom url field is...      0
#
# [9359 rows x 2 columns]

# %%
# save to csv
pri.to_csv(file_name, index=False)
