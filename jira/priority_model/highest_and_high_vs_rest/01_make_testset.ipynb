# %%
import pandas as pd
# Import csv file
df = pd.read_csv('mongoDB_testset_highest_high.csv')
df
# Out:
#              priority                                        description  \
# 0          Major - P3  Currently there are a number of tests in the C...
# 1          Major - P3  The following compilation notes are getting ge...
# 2          Major - P3  \nh2. [verify-datafile-from-little-endian fail...
# 3          Major - P3  h2. [spinlock-gcc-test failed on ! Ubuntu 20.0...
# 4          Major - P3  \nh2. [cppsuite-hs-cleanup-stress failed on Cp...
# ...               ...                                                ...
# 105309     Major - P3  The following command generates a plan that do...
# 105310  Critical - P2  Hi Team,\r\n\r\nI have a very weird problem, w...
# 105311  Critical - P2  Mongod crashes while running YCSB.  Log and mo...
# 105312     Major - P3  Updated yaml files for the three projects to u...
# 105313     Major - P3  that is recognized by the sharded cluster. Thi...
#
#             project          labels      issuetype collection   class  \
# 0        WiredTiger              []    Improvement    MongoDB  Medium
# 1        WiredTiger              []            Bug    MongoDB  Medium
# 2        WiredTiger              []  Build Failure    MongoDB  Medium
# 3        WiredTiger  ['CI-blocker']  Build Failure    MongoDB  Medium
# 4        WiredTiger              []  Build Failure    MongoDB  Medium
# ...             ...             ...            ...        ...     ...
# 105309  Core Server      ['neweng']            Bug    MongoDB  Medium
# 105310  Core Server              []            Bug    MongoDB    High
# 105311  Core Server              []            Bug    MongoDB    High
# 105312  Core Server   ['test-only']           Task    MongoDB  Medium
# 105313  Core Server              []           Task    MongoDB  Medium
#
#                                                  text_str  \
# 0       Currently there are a number of tests in the C...
# 1       The following compilation notes are getting ge...
# 2       \nh2. [verify-datafile-from-little-endian fail...
# 3       h2. [spinlock-gcc-test failed on ! Ubuntu 20.0...
# 4       \nh2. [cppsuite-hs-cleanup-stress failed on Cp...
# ...                                                   ...
# 105309  The following command generates a plan that do...
# 105310  Hi Team,\r\n\r\nI have a very weird problem, w...
# 105311  Mongod crashes while running YCSB.  Log and mo...
# 105312  Updated yaml files for the three projects to u...
# 105313  that is recognized by the sharded cluster. Thi...
#
#                                                text_clean
# 0       currently there are a number of tests in the c...
# 1       the following compilation notes are getting ge...
# 2       verifydatafilefromlittleendian failed on bigen...
# 3       spinlockgcctest failed on ubuntu host project ...
# 4       cppsuitehscleanupstress failed on cppsuite str...
# ...                                                   ...
# 105309  the following command generates a plan that do...
# 105310  hi team i have a very weird problem when i run...
# 105311  mongod crashes while running ycsb log and mong...
# 105312  updated yaml files for the three projects to u...
# 105313  that is recognized by the sharded cluster this...
#
# [105314 rows x 9 columns]

# %%
# Count class
df['class'].value_counts().to_frame()
# Out:
#          count
# class
# Medium   87338
# Low      12032
# High      3051
# Lowest    1965
# Highest    928

# %%
highestt = df[df['class'] == 'Highest']
high = df[df['class'] == 'High']
medium = df[df['class'] == 'Medium']
low = df[df['class'] == 'Low']
lowest = df[df['class'] == 'Lowest']

# %%
# Concat highest and high
highest = pd.concat([highestt, high], ignore_index=True)
highest["label"] = 1

# %%
# Concat all class except highest
rest = pd.concat([medium, low, lowest])
rest["label"] = 0
rest
# Out:
#             priority                                        description  \
# 0         Major - P3  Currently there are a number of tests in the C...
# 1         Major - P3  The following compilation notes are getting ge...
# 2         Major - P3  \nh2. [verify-datafile-from-little-endian fail...
# 3         Major - P3  h2. [spinlock-gcc-test failed on ! Ubuntu 20.0...
# 4         Major - P3  \nh2. [cppsuite-hs-cleanup-stress failed on Cp...
# ...              ...                                                ...
# 104920  Trivial - P5  The MSVC 2015 compiler produces the following ...
# 104952  Trivial - P5  We set the location of the minidump using the ...
# 105079  Trivial - P5  I am using this check https://github.com/mzupa...
# 105094  Trivial - P5  {code:cpp}\r\nstd::unique_ptr<Lock::ResourceLo...
# 105141  Trivial - P5  Not restoring the stream format state of an os...
#
#             project             labels      issuetype collection   class  \
# 0        WiredTiger                 []    Improvement    MongoDB  Medium
# 1        WiredTiger                 []            Bug    MongoDB  Medium
# 2        WiredTiger                 []  Build Failure    MongoDB  Medium
# 3        WiredTiger     ['CI-blocker']  Build Failure    MongoDB  Medium
# 4        WiredTiger                 []  Build Failure    MongoDB  Medium
# ...             ...                ...            ...        ...     ...
# 104920  Core Server                 []            Bug    MongoDB  Lowest
# 104952  Core Server  ['PM-372', 'stm']            Bug    MongoDB  Lowest
# 105079  Core Server                 []       Question    MongoDB  Lowest
# 105094  Core Server         ['neweng']           Task    MongoDB  Lowest
# 105141  Core Server       ['coverity']            Bug    MongoDB  Lowest
#
#                                                  text_str  \
# 0       Currently there are a number of tests in the C...
# 1       The following compilation notes are getting ge...
# 2       \nh2. [verify-datafile-from-little-endian fail...
# 3       h2. [spinlock-gcc-test failed on ! Ubuntu 20.0...
# 4       \nh2. [cppsuite-hs-cleanup-stress failed on Cp...
# ...                                                   ...
# 104920  The MSVC 2015 compiler produces the following ...
# 104952  We set the location of the minidump using the ...
# 105079  I am using this check https://github.com/mzupa...
# 105094  {code:cpp}\r\nstd::unique_ptr<Lock::ResourceLo...
# 105141  Not restoring the stream format state of an os...
#
#                                                text_clean  label
# 0       currently there are a number of tests in the c...      0
# 1       the following compilation notes are getting ge...      0
# 2       verifydatafilefromlittleendian failed on bigen...      0
# 3       spinlockgcctest failed on ubuntu host project ...      0
# 4       cppsuitehscleanupstress failed on cppsuite str...      0
# ...                                                   ...    ...
# 104920  the msvc compiler produces the following warni...      0
# 104952  we set the location of the minidump using the ...      0
# 105079  i am using this check to monitor replication l...      0
# 105094  codecpp stduniqueptr rlk if isrsthreadsafe opc...      0
# 105141  not restoring the stream format state of an os...      0
#
# [101335 rows x 10 columns]

# %%
# Value count rest class
rest['class'].value_counts().to_frame()
# Out:
#         count
# class
# Medium  87338
# Low     12032
# Lowest   1965

# %%
from sklearn.utils import shuffle
# Number of rows in the highest class
n_highest = highest.shape[0]

rest_sampled = rest.sample(n=n_highest, random_state=42)  


balanced_data = pd.concat([highest, rest_sampled])

# Shuffle the combined dataset
balanced_data = shuffle(balanced_data, random_state=42)

# %%
# class count
balanced_data['class'].value_counts().to_frame()
# Out:
#          count
# class
# Medium    3440
# High      3051
# Highest    928
# Low        446
# Lowest      93

# %%
balanced_data
# Out:
#             priority                                        description  \
# 81053     Major - P3  Right now the TenantMigrationAccessBlocker is ...
# 742     Blocker - P1  Below error is thrown while executing below li...
# 3950   Critical - P2  Use nodejs Mongo driver,\r\n\r\n1. Get a list ...
# 38145     Major - P3  As a new contributor to the driver I've often ...
# 22860     Major - P3  It is my understanding that the specs repo doe...
# ...              ...                                                ...
# 64989     Major - P3  Currently the driver tests all combinations of...
# 22524     Major - P3  As part of this work, we should validate DRIVE...
# 860     Blocker - P1  * Branch system_perf.yml for 5.0\\  ** Change ...
# 6136      Minor - P4  The getShards/getDatabases/getCollections meth...
# 22023     Minor - P4  situation jeff ran into:\n\ndoing a where clau...
#
#            project                           labels    issuetype collection  \
# 81053  Core Server          ['pm-1791_milestone-A']          Bug    MongoDB
# 742      C# Driver                     ['question']         Task    MongoDB
# 3950   Core Server                               []          Bug    MongoDB
# 38145    Go Driver                               []  New Feature    MongoDB
# 22860  Ruby Driver                               []  Improvement    MongoDB
# ...            ...                              ...          ...        ...
# 64989    C# Driver                               []  Improvement    MongoDB
# 22524  Rust Driver                  ['size-medium']  New Feature    MongoDB
# 860    Core Server  ['branch-5.0', 'during-branch']         Task    MongoDB
# 6136   Core Server                               []         Task    MongoDB
# 22023  Core Server                               []          Bug    MongoDB
#
#          class                                           text_str  \
# 81053   Medium  Right now the TenantMigrationAccessBlocker is ...
# 742    Highest  Below error is thrown while executing below li...
# 3950      High  Use nodejs Mongo driver,\r\n\r\n1. Get a list ...
# 38145   Medium  As a new contributor to the driver I've often ...
# 22860   Medium  It is my understanding that the specs repo doe...
# ...        ...                                                ...
# 64989   Medium  Currently the driver tests all combinations of...
# 22524   Medium  As part of this work, we should validate DRIVE...
# 860    Highest  * Branch system_perf.yml for 5.0\\  ** Change ...
# 6136       Low  The getShards/getDatabases/getCollections meth...
# 22023      Low  situation jeff ran into:\n\ndoing a where clau...
#
#                                               text_clean  label
# 81053  right now the tenantmigrationaccessblocker is ...      0
# 742    below error is thrown while executing below li...      1
# 3950   use nodejs mongo driver get a list of keys key...      1
# 38145  as a new contributor to the driver ive often f...      0
# 22860  it is my understanding that the specs repo doe...      0
# ...                                                  ...    ...
# 64989  currently the driver tests all combinations of...      0
# 22524            as part of this work we should validate      0
# 860    branch systemperfyml for change most reference...      1
# 6136   the getshardsgetdatabasesgetcollections method...      0
# 22023  situation jeff ran intodoing a where clause th...      0
#
# [7958 rows x 10 columns]

# %%
# Count label
balanced_data['label'].value_counts().to_frame()
# Out:
#        count
# label
# 0       3979
# 1       3979

# %%
# Unique project
balanced_data['project'].nunique()
# Out:
# 27

# %%
# Unique collection
balanced_data['collection'].nunique()
# Out:
# 1

# %%
# make a df with only text_clean and label
balanced_data = balanced_data[['text_clean', 'label']]
balanced_data
# Out:
#                                               text_clean  label
# 81053  right now the tenantmigrationaccessblocker is ...      0
# 742    below error is thrown while executing below li...      1
# 3950   use nodejs mongo driver get a list of keys key...      1
# 38145  as a new contributor to the driver ive often f...      0
# 22860  it is my understanding that the specs repo doe...      0
# ...                                                  ...    ...
# 64989  currently the driver tests all combinations of...      0
# 22524            as part of this work we should validate      0
# 860    branch systemperfyml for change most reference...      1
# 6136   the getshardsgetdatabasesgetcollections method...      0
# 22023  situation jeff ran intodoing a where clause th...      0
#
# [7958 rows x 2 columns]

# %%
# To csv
balanced_data.to_csv('clean_mongoDB_testset_highest_high.csv', index=False)

# %%
# Read csv to check the file
df = pd.read_csv('clean_mongoDB_testset_highest_high.csv')
df
# Out:
#                                              text_clean  label
# 0     right now the tenantmigrationaccessblocker is ...      0
# 1     below error is thrown while executing below li...      1
# 2     use nodejs mongo driver get a list of keys key...      1
# 3     as a new contributor to the driver ive often f...      0
# 4     it is my understanding that the specs repo doe...      0
# ...                                                 ...    ...
# 7953  currently the driver tests all combinations of...      0
# 7954            as part of this work we should validate      0
# 7955  branch systemperfyml for change most reference...      1
# 7956  the getshardsgetdatabasesgetcollections method...      0
# 7957  situation jeff ran intodoing a where clause th...      0
#
# [7958 rows x 2 columns]
