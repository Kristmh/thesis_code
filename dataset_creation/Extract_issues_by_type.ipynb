# %%
import pandas as pd

# %%
import os

# folder path
dir_path = r'../all_issue_event'

# list to store files
res = []

# Iterate directory
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        res.append(path)
print(res)
# Out:
# ['issues_all_2022-02-01.csv', 'issues_all_2022-02-02.csv', 'issues_all_2022-02-03.csv', 'issues_all_2022-02-04.csv', 'issues_all_2022-02-05.csv', 'issues_all_2022-02-06.csv', 'issues_all_2022-02-07.csv', 'issues_all_2022-02-08.csv', 'issues_all_2022-02-09.csv', 'issues_all_2022-02-10.csv', 'issues_all_2022-02-11.csv', 'issues_all_2022-02-14.csv', 'issues_all_2022-02-15.csv', 'issues_all_2022-02-16.csv', 'issues_all_2022-02-17.csv', 'issues_all_2022-02-18.csv', 'issues_all_2022-02-20.csv', 'issues_all_2022-02-21.csv', 'issues_all_2022-02-22.csv', 'issues_all_2022-02-23.csv', 'issues_all_2022-02-24.csv', 'issues_all_2022-02-25.csv', 'issues_all_2022-02-28.csv', 'issues_all_2022-03-01.csv', 'issues_all_2022-03-04.csv', 'issues_all_2022-03-05.csv', 'issues_all_2022-03-06.csv', 'issues_all_2022-03-07.csv', 'issues_all_2022-03-08.csv', 'issues_all_2022-03-09.csv', 'issues_all_2022-03-10.csv', 'issues_all_2022-03-11.csv', 'issues_all_2022-03-12.csv', 'issues_all_2022-03-13.csv', 'issues_all
# ...

# %%
import re

# %%
appended_data = []

for i in res:

    try:
        ddf = pd.read_csv(f"./all_issue_event/{i}", index_col=0)
        sub = 'bug'
        print(i)
        ddf["index"] = ddf["labels"].str.count(sub,  flags=re.IGNORECASE)
        ddf = ddf[ddf["index"] > 0]
        appended_data.append(ddf)

    except:
        continue


appended_data = pd.concat(appended_data, ignore_index=True)
# Out:
# issues_all_2022-02-01.csv
# issues_all_2022-02-02.csv
# issues_all_2022-02-03.csv
# issues_all_2022-02-04.csv
# issues_all_2022-02-05.csv
# issues_all_2022-02-06.csv
# issues_all_2022-02-07.csv
# issues_all_2022-02-08.csv
# issues_all_2022-02-09.csv
# issues_all_2022-02-10.csv
# issues_all_2022-02-11.csv
# issues_all_2022-02-14.csv
# issues_all_2022-02-15.csv
# issues_all_2022-02-18.csv
# issues_all_2022-02-20.csv
# issues_all_2022-02-21.csv
# issues_all_2022-02-22.csv
# issues_all_2022-02-23.csv
# issues_all_2022-02-24.csv
# issues_all_2022-02-25.csv
# issues_all_2022-03-01.csv
# issues_all_2022-03-04.csv
# issues_all_2022-03-05.csv
# issues_all_2022-03-06.csv
# issues_all_2022-03-07.csv
# issues_all_2022-03-08.csv
# issues_all_2022-03-09.csv
# issues_all_2022-03-10.csv
# issues_all_2022-03-11.csv
# issues_all_2022-03-12.csv
# issues_all_2022-03-13.csv
# issues_all_2022-03-14.csv
# issues_all_2022-03-15.csv
# issues_all_2022-03-16.csv
# issues_all_2022-03-17.csv
# ...

# %%
appended_data
# Out:
#                  id         type           created_at  \
# 0       20007548599  IssuesEvent  2022-02-01 00:00:01
# 1       20007548969  IssuesEvent  2022-02-01 00:00:03
# 2       20007552622  IssuesEvent  2022-02-01 00:00:20
# 3       20007554224  IssuesEvent  2022-02-01 00:00:28
# 4       20007554707  IssuesEvent  2022-02-01 00:00:31
# ...             ...          ...                  ...
# 549861  22994231341  IssuesEvent  2022-07-21 00:33:46
# 549862  22994238980  IssuesEvent  2022-07-21 00:34:31
# 549863  22994241261  IssuesEvent  2022-07-21 00:34:45
# 549864  22994248050  IssuesEvent  2022-07-21 00:35:25
# 549865  22994256842  IssuesEvent  2022-07-21 00:36:16
#
#                                           repo  \
# 0                          OpenBeta/open-tacos
# 1                    BespokeSynth/BespokeSynth
# 2                          fritz-marshal/fritz
# 3       PathOfBuildingCommunity/PathOfBuilding
# 4                                Azure/aks-hci
# ...

# %%
appended_data.to_csv("Final_Bug_dataset.csv")
