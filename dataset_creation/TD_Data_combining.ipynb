# %%
import pandas as pd

# %%
import re

# %%
TD = pd.read_csv("with_labels_priority.csv", index_col=0)

# %%
TD["repo"].unique()
# Out:
# array(['code-gambit/VT-AndroidClient',
#        'great-expectations/great_expectations',
#        'InfiniteFlightAirportEditing/Airports', ...,
#        'TestMonkeys/jEntityTest', 'brian-team/brian2cuda',
#        'Fabio-Git-dev/Programming_Languages'], dtype=object)

# %%
TD.labels.value_counts().to_frame()[:26]
# Out:
#                                                     labels
# flakybot: issue priority: p1 type: bug                1337
# high priority                                         1291
# bug high priority                                     1200
# bot human_intervention_required priority/critic...    1035
# priority.High type.Task                                796
# enhancement low priority                               784
# low priority                                           775
# Priority: High                                         759
# enhancement high priority                              712
# Priority/Normal Type/Bug                               700
# priority.High                                          685
# type: bug priority: p1 flakybot: issue                 684
# autosynth failure priority: p1 type: bug               671
# high priority task                                     655
# priority                                               649
# ...

# %%
TD["class"] = "priority"

# %%
TD
# Out:
#                   id         type           created_at  \
# 0       1.675123e+10  IssuesEvent  2021-06-12 00:05:10
# 1       1.675127e+10  IssuesEvent  2021-06-12 00:12:07
# 2       1.675127e+10  IssuesEvent  2021-06-12 00:12:57
# 3       1.675129e+10  IssuesEvent  2021-06-12 00:16:05
# 4       1.675131e+10  IssuesEvent  2021-06-12 00:20:05
# ...              ...          ...                  ...
# 168923  1.593808e+10  IssuesEvent  2021-04-14 13:12:56
# 168924  1.593811e+10  IssuesEvent  2021-04-14 13:14:48
# 168925  1.593812e+10  IssuesEvent  2021-04-14 13:15:42
# 168926  1.593812e+10  IssuesEvent  2021-04-14 13:15:49
# 168927  1.593814e+10  IssuesEvent  2021-04-14 13:16:57
#
#                                              repo  \
# 0                    code-gambit/VT-AndroidClient
# 1           great-expectations/great_expectations
# 2           InfiniteFlightAirportEditing/Airports
# 3                            MicroHealthLLC/mPATH
# ...

# %%
bug = pd.read_csv("Final_bug_dataset.csv" , index_col=0)

# %%
bug
# Out:
#                   id         type           created_at  \
# 0       2.000755e+10  IssuesEvent  2022-02-01 00:00:01
# 1       2.000755e+10  IssuesEvent  2022-02-01 00:00:03
# 2       2.000755e+10  IssuesEvent  2022-02-01 00:00:20
# 3       2.000755e+10  IssuesEvent  2022-02-01 00:00:28
# 4       2.000755e+10  IssuesEvent  2022-02-01 00:00:31
# ...              ...          ...                  ...
# 549861  2.299423e+10  IssuesEvent  2022-07-21 00:33:46
# 549862  2.299424e+10  IssuesEvent  2022-07-21 00:34:31
# 549863  2.299424e+10  IssuesEvent  2022-07-21 00:34:45
# 549864  2.299425e+10  IssuesEvent  2022-07-21 00:35:25
# 549865  2.299426e+10  IssuesEvent  2022-07-21 00:36:16
#
#                                           repo  \
# 0                          OpenBeta/open-tacos
# 1                    BespokeSynth/BespokeSynth
# 2                          fritz-marshal/fritz
# 3       PathOfBuildingCommunity/PathOfBuilding
# 4                                Azure/aks-hci
# ...

# %%
bug1 = bug[bug["labels"]=="bug"]

# %%
bug1
# Out:
#                   id         type           created_at  \
# 0       2.000755e+10  IssuesEvent  2022-02-01 00:00:01
# 1       2.000755e+10  IssuesEvent  2022-02-01 00:00:03
# 2       2.000755e+10  IssuesEvent  2022-02-01 00:00:20
# 3       2.000755e+10  IssuesEvent  2022-02-01 00:00:28
# 4       2.000755e+10  IssuesEvent  2022-02-01 00:00:31
# ...              ...          ...                  ...
# 549853  2.299422e+10  IssuesEvent  2022-07-21 00:32:20
# 549858  2.299422e+10  IssuesEvent  2022-07-21 00:32:58
# 549861  2.299423e+10  IssuesEvent  2022-07-21 00:33:46
# 549862  2.299424e+10  IssuesEvent  2022-07-21 00:34:31
# 549865  2.299426e+10  IssuesEvent  2022-07-21 00:36:16
#
#                                           repo  \
# 0                          OpenBeta/open-tacos
# 1                    BespokeSynth/BespokeSynth
# 2                          fritz-marshal/fritz
# 3       PathOfBuildingCommunity/PathOfBuilding
# 4                                Azure/aks-hci
# ...

# %%
enchancement = pd.read_csv("Final_enchancement_dataset.csv", index_col=0)

# %%
enchancement
# Out:
#                   id         type           created_at  \
# 0       2.000756e+10  IssuesEvent  2022-02-01 00:01:06
# 1       2.000757e+10  IssuesEvent  2022-02-01 00:01:37
# 2       2.000759e+10  IssuesEvent  2022-02-01 00:02:50
# 3       2.000759e+10  IssuesEvent  2022-02-01 00:02:54
# 4       2.000759e+10  IssuesEvent  2022-02-01 00:03:06
# ...              ...          ...                  ...
# 379622  2.299426e+10  IssuesEvent  2022-07-21 00:36:35
# 379623  2.299426e+10  IssuesEvent  2022-07-21 00:36:36
# 379624  2.299426e+10  IssuesEvent  2022-07-21 00:36:54
# 379625  2.299426e+10  IssuesEvent  2022-07-21 00:36:58
# 379626  2.299427e+10  IssuesEvent  2022-07-21 00:37:11
#
#                                              repo  \
# 0       MicrosoftDocs/OfficeDocs-SkypeForBusiness
# 1                               mosaicml/composer
# 2                             Ylianst/MeshCentral
# 3                              dwavesystems/dimod
# ...

# %%
enchancement1 = enchancement[enchancement["labels"]== "enhancement"]
enchancement1
# Out:
#                   id         type           created_at  \
# 1       2.000757e+10  IssuesEvent  2022-02-01 00:01:37
# 4       2.000759e+10  IssuesEvent  2022-02-01 00:03:06
# 5       2.000759e+10  IssuesEvent  2022-02-01 00:03:28
# 7       2.000761e+10  IssuesEvent  2022-02-01 00:04:45
# 8       2.000761e+10  IssuesEvent  2022-02-01 00:04:45
# ...              ...          ...                  ...
# 379621  2.299426e+10  IssuesEvent  2022-07-21 00:36:26
# 379622  2.299426e+10  IssuesEvent  2022-07-21 00:36:35
# 379623  2.299426e+10  IssuesEvent  2022-07-21 00:36:36
# 379624  2.299426e+10  IssuesEvent  2022-07-21 00:36:54
# 379626  2.299427e+10  IssuesEvent  2022-07-21 00:37:11
#
#                                    repo  \
# 1                     mosaicml/composer
# 4            DragonStuff/apts-jp-to-sql
# 5                 Thenlie/deep-thoughts
# 7                 0xnan-dev/depub.space
# 8                 0xnan-dev/depub.space
# ...                                 ...
# ...

# %%
feature = pd.read_csv("Final_feature_dataset.csv", index_col=0)

# %%
feature
# Out:
#                   id         type           created_at  \
# 0       2.000757e+10  IssuesEvent  2022-02-01 00:01:32
# 1       2.000757e+10  IssuesEvent  2022-02-01 00:01:33
# 2       2.000758e+10  IssuesEvent  2022-02-01 00:02:17
# 3       2.000758e+10  IssuesEvent  2022-02-01 00:02:35
# 4       2.000759e+10  IssuesEvent  2022-02-01 00:02:54
# ...              ...          ...                  ...
# 111706  2.299421e+10  IssuesEvent  2022-07-21 00:31:28
# 111707  2.299422e+10  IssuesEvent  2022-07-21 00:33:06
# 111708  2.299424e+10  IssuesEvent  2022-07-21 00:34:44
# 111709  2.299425e+10  IssuesEvent  2022-07-21 00:35:44
# 111710  2.299425e+10  IssuesEvent  2022-07-21 00:35:54
#
#                                        repo  \
# 0                    APSIMInitiative/ApsimX
# 1                        Koenkk/zigbee2mqtt
# 2                           flutter/flutter
# 3                           quantumlib/Cirq
# 4                        dwavesystems/dimod
# ...

# %%
feature1 = feature[feature["labels"] == "feature"]
feature1
# Out:
#                   id         type           created_at  \
# 18      2.000771e+10  IssuesEvent  2022-02-01 00:13:08
# 28      2.000774e+10  IssuesEvent  2022-02-01 00:16:17
# 37      2.000783e+10  IssuesEvent  2022-02-01 00:25:24
# 45      2.000788e+10  IssuesEvent  2022-02-01 00:29:45
# 70      2.000808e+10  IssuesEvent  2022-02-01 00:49:40
# ...              ...          ...                  ...
# 111682  2.297372e+10  IssuesEvent  2022-07-20 06:54:45
# 111695  2.299407e+10  IssuesEvent  2022-07-21 00:17:28
# 111698  2.299412e+10  IssuesEvent  2022-07-21 00:22:35
# 111703  2.299419e+10  IssuesEvent  2022-07-21 00:29:15
# 111710  2.299425e+10  IssuesEvent  2022-07-21 00:35:54
#
#                                        repo  \
# 18                    ClickHouse/ClickHouse
# 28                       Drustcraft/website
# 37                        Drustcraft/engine
# 45                      votingworks/vxsuite
# 70                    gomesluiz/Estatistica
# ...

# %%
question = pd.read_csv("Final_question_dataset.csv", index_col=0)

# %%
question
# Out:
#                  id         type           created_at  \
# 0      2.000763e+10  IssuesEvent  2022-02-01 00:06:44
# 1      2.000771e+10  IssuesEvent  2022-02-01 00:13:31
# 2      2.000771e+10  IssuesEvent  2022-02-01 00:13:39
# 3      2.000773e+10  IssuesEvent  2022-02-01 00:15:33
# 4      2.000777e+10  IssuesEvent  2022-02-01 00:19:14
# ...             ...          ...                  ...
# 55483  2.299414e+10  IssuesEvent  2022-07-21 00:24:58
# 55484  2.299417e+10  IssuesEvent  2022-07-21 00:27:34
# 55485  2.299418e+10  IssuesEvent  2022-07-21 00:28:34
# 55486  2.299419e+10  IssuesEvent  2022-07-21 00:30:04
# 55487  2.299423e+10  IssuesEvent  2022-07-21 00:33:47
#
#                                       repo  \
# 0                      AzuraCast/AzuraCast
# 1                       ultralytics/yolov5
# 2                       ultralytics/yolov5
# 3                         AllTheMods/ATM-6
# 4                           mocklets/pluto
# ...                                    ...
# ...

# %%
question1 = question[question["labels"]== "question"]
question1
# Out:
#                  id         type           created_at  \
# 5      2.000786e+10  IssuesEvent  2022-02-01 00:28:12
# 7      2.000794e+10  IssuesEvent  2022-02-01 00:35:31
# 9      2.000795e+10  IssuesEvent  2022-02-01 00:36:55
# 11     2.000800e+10  IssuesEvent  2022-02-01 00:41:36
# 15     2.000828e+10  IssuesEvent  2022-02-01 01:04:41
# ...             ...          ...                  ...
# 55466  2.299390e+10  IssuesEvent  2022-07-21 00:03:10
# 55472  2.299412e+10  IssuesEvent  2022-07-21 00:23:06
# 55483  2.299414e+10  IssuesEvent  2022-07-21 00:24:58
# 55485  2.299418e+10  IssuesEvent  2022-07-21 00:28:34
# 55487  2.299423e+10  IssuesEvent  2022-07-21 00:33:47
#
#                                                repo  \
# 5                    yaronzz/Tidal-Media-Downloader
# 7                                   borgbackup/borg
# 9       testing-library/react-hooks-testing-library
# 11                                   k0sproject/k0s
# ...

# %%
wontfix = pd.read_csv("Final_wontfix_dataset.csv" , index_col=0)

# %%
wontfix
# Out:
#                  id         type           created_at  \
# 0      2.000762e+10  IssuesEvent  2022-02-01 00:05:46
# 1      2.000763e+10  IssuesEvent  2022-02-01 00:06:09
# 2      2.000763e+10  IssuesEvent  2022-02-01 00:06:12
# 3      2.000763e+10  IssuesEvent  2022-02-01 00:06:14
# 4      2.000763e+10  IssuesEvent  2022-02-01 00:06:15
# ...             ...          ...                  ...
# 17189  2.297274e+10  IssuesEvent  2022-07-20 05:46:58
# 17190  2.297277e+10  IssuesEvent  2022-07-20 05:49:27
# 17191  2.297296e+10  IssuesEvent  2022-07-20 06:04:12
# 17192  2.297320e+10  IssuesEvent  2022-07-20 06:20:43
# 17193  2.297360e+10  IssuesEvent  2022-07-20 06:46:56
#
#                            repo  \
# 0        termux/termux-packages
# 1           AzuraCast/AzuraCast
# 2           AzuraCast/AzuraCast
# 3           AzuraCast/AzuraCast
# 4           AzuraCast/AzuraCast
# ...                         ...
# 17189         openSUSE/suse-xsl
# 17190     SamsDRGMods/SimpleQOL
# ...

# %%
wontfix1 = wontfix[wontfix["labels"] == "wontfix"]
wontfix1
# Out:
#                  id         type           created_at  \
# 29     2.000867e+10  IssuesEvent  2022-02-01 01:44:53
# 30     2.000867e+10  IssuesEvent  2022-02-01 01:44:54
# 31     2.000867e+10  IssuesEvent  2022-02-01 01:44:56
# 32     2.000867e+10  IssuesEvent  2022-02-01 01:44:56
# 34     2.000867e+10  IssuesEvent  2022-02-01 01:44:58
# ...             ...          ...                  ...
# 17182  2.297185e+10  IssuesEvent  2022-07-20 04:27:22
# 17185  2.297200e+10  IssuesEvent  2022-07-20 04:40:38
# 17186  2.297205e+10  IssuesEvent  2022-07-20 04:45:39
# 17187  2.297205e+10  IssuesEvent  2022-07-20 04:45:40
# 17191  2.297296e+10  IssuesEvent  2022-07-20 06:04:12
#
#                                  repo  \
# 29               signalapp/Signal-iOS
# 30               signalapp/Signal-iOS
# 31               signalapp/Signal-iOS
# 32               signalapp/Signal-iOS
# 34               signalapp/Signal-iOS
# ...                               ...
# 17182     LmeSzinc/AzurLaneAutoScript
# ...

# %%
documentation = pd.read_csv("Final_documentation_dataset.csv", index_col=0)
documentation
# Out:
#                  id         type           created_at  \
# 0      2.000764e+10  IssuesEvent  2022-02-01 00:06:54
# 1      2.000766e+10  IssuesEvent  2022-02-01 00:08:44
# 2      2.000766e+10  IssuesEvent  2022-02-01 00:09:03
# 3      2.000767e+10  IssuesEvent  2022-02-01 00:09:36
# 4      2.000767e+10  IssuesEvent  2022-02-01 00:09:52
# ...             ...          ...                  ...
# 63649  2.299406e+10  IssuesEvent  2022-07-21 00:17:16
# 63650  2.299411e+10  IssuesEvent  2022-07-21 00:22:02
# 63651  2.299412e+10  IssuesEvent  2022-07-21 00:23:06
# 63652  2.299413e+10  IssuesEvent  2022-07-21 00:23:25
# 63653  2.299417e+10  IssuesEvent  2022-07-21 00:27:27
#
#                                              repo  \
# 0                                       psf/black
# 1                    SBD1/grupo11-Universo-Marvel
# 2                    SBD1/grupo11-Universo-Marvel
# 3              Milena-Blaser/M226b-Esteban_Blaser
# 4              Milena-Blaser/M226b-Esteban_Blaser
# ...

# %%
documentation1 = documentation[documentation["labels"] == "documentation"]

documentation1
# Out:
#                  id         type           created_at  \
# 1      2.000766e+10  IssuesEvent  2022-02-01 00:08:44
# 2      2.000766e+10  IssuesEvent  2022-02-01 00:09:03
# 3      2.000767e+10  IssuesEvent  2022-02-01 00:09:36
# 4      2.000767e+10  IssuesEvent  2022-02-01 00:09:52
# 5      2.000767e+10  IssuesEvent  2022-02-01 00:09:58
# ...             ...          ...                  ...
# 63645  2.299393e+10  IssuesEvent  2022-07-21 00:05:04
# 63646  2.299397e+10  IssuesEvent  2022-07-21 00:08:52
# 63647  2.299398e+10  IssuesEvent  2022-07-21 00:09:20
# 63652  2.299413e+10  IssuesEvent  2022-07-21 00:23:25
# 63653  2.299417e+10  IssuesEvent  2022-07-21 00:27:27
#
#                                      repo  \
# 1            SBD1/grupo11-Universo-Marvel
# 2            SBD1/grupo11-Universo-Marvel
# 3      Milena-Blaser/M226b-Esteban_Blaser
# 4      Milena-Blaser/M226b-Esteban_Blaser
# 5      Milena-Blaser/M226b-Esteban_Blaser
# ...                                   ...
# ...

# %%
NonTD = pd.concat([bug1,enchancement1,feature1,question1,documentation1,wontfix1] , ignore_index= True)

# %%
NonTD
# Out:
#                   id         type           created_at  \
# 0       2.000755e+10  IssuesEvent  2022-02-01 00:00:01
# 1       2.000755e+10  IssuesEvent  2022-02-01 00:00:03
# 2       2.000755e+10  IssuesEvent  2022-02-01 00:00:20
# 3       2.000755e+10  IssuesEvent  2022-02-01 00:00:28
# 4       2.000755e+10  IssuesEvent  2022-02-01 00:00:31
# ...              ...          ...                  ...
# 586833  2.297185e+10  IssuesEvent  2022-07-20 04:27:22
# 586834  2.297200e+10  IssuesEvent  2022-07-20 04:40:38
# 586835  2.297205e+10  IssuesEvent  2022-07-20 04:45:39
# 586836  2.297205e+10  IssuesEvent  2022-07-20 04:45:40
# 586837  2.297296e+10  IssuesEvent  2022-07-20 06:04:12
#
#                                           repo  \
# 0                          OpenBeta/open-tacos
# 1                    BespokeSynth/BespokeSynth
# 2                          fritz-marshal/fritz
# 3       PathOfBuildingCommunity/PathOfBuilding
# 4                                Azure/aks-hci
# ...

# %%
NonTD["class"] = "not_priority"

# %%
NonTD
# Out:
#                   id         type           created_at  \
# 0       2.000755e+10  IssuesEvent  2022-02-01 00:00:01
# 1       2.000755e+10  IssuesEvent  2022-02-01 00:00:03
# 2       2.000755e+10  IssuesEvent  2022-02-01 00:00:20
# 3       2.000755e+10  IssuesEvent  2022-02-01 00:00:28
# 4       2.000755e+10  IssuesEvent  2022-02-01 00:00:31
# ...              ...          ...                  ...
# 586833  2.297185e+10  IssuesEvent  2022-07-20 04:27:22
# 586834  2.297200e+10  IssuesEvent  2022-07-20 04:40:38
# 586835  2.297205e+10  IssuesEvent  2022-07-20 04:45:39
# 586836  2.297205e+10  IssuesEvent  2022-07-20 04:45:40
# 586837  2.297296e+10  IssuesEvent  2022-07-20 06:04:12
#
#                                           repo  \
# 0                          OpenBeta/open-tacos
# 1                    BespokeSynth/BespokeSynth
# 2                          fritz-marshal/fritz
# 3       PathOfBuildingCommunity/PathOfBuilding
# 4                                Azure/aks-hci
# ...

# %%
TD
# Out:
#                   id         type           created_at  \
# 0       1.675123e+10  IssuesEvent  2021-06-12 00:05:10
# 1       1.675127e+10  IssuesEvent  2021-06-12 00:12:07
# 2       1.675127e+10  IssuesEvent  2021-06-12 00:12:57
# 3       1.675129e+10  IssuesEvent  2021-06-12 00:16:05
# 4       1.675131e+10  IssuesEvent  2021-06-12 00:20:05
# ...              ...          ...                  ...
# 168923  1.593808e+10  IssuesEvent  2021-04-14 13:12:56
# 168924  1.593811e+10  IssuesEvent  2021-04-14 13:14:48
# 168925  1.593812e+10  IssuesEvent  2021-04-14 13:15:42
# 168926  1.593812e+10  IssuesEvent  2021-04-14 13:15:49
# 168927  1.593814e+10  IssuesEvent  2021-04-14 13:16:57
#
#                                              repo  \
# 0                    code-gambit/VT-AndroidClient
# 1           great-expectations/great_expectations
# 2           InfiniteFlightAirportEditing/Airports
# 3                            MicroHealthLLC/mPATH
# ...

# %%
ALL_data = pd.concat([TD,NonTD], ignore_index=True)

# %%
ALL_data
# Out:
#                   id         type           created_at  \
# 0       1.675123e+10  IssuesEvent  2021-06-12 00:05:10
# 1       1.675127e+10  IssuesEvent  2021-06-12 00:12:07
# 2       1.675127e+10  IssuesEvent  2021-06-12 00:12:57
# 3       1.675129e+10  IssuesEvent  2021-06-12 00:16:05
# 4       1.675131e+10  IssuesEvent  2021-06-12 00:20:05
# ...              ...          ...                  ...
# 755761  2.297185e+10  IssuesEvent  2022-07-20 04:27:22
# 755762  2.297200e+10  IssuesEvent  2022-07-20 04:40:38
# 755763  2.297205e+10  IssuesEvent  2022-07-20 04:45:39
# 755764  2.297205e+10  IssuesEvent  2022-07-20 04:45:40
# 755765  2.297296e+10  IssuesEvent  2022-07-20 06:04:12
#
#                                          repo  \
# 0                code-gambit/VT-AndroidClient
# 1       great-expectations/great_expectations
# 2       InfiniteFlightAirportEditing/Airports
# 3                        MicroHealthLLC/mPATH
# 4                NoahOrtega/Blue-Coin-Tracker
# ...

# %%
ALL_data.to_csv("full_dataset_prio.csv")
