# %%
import pandas as pd
#import dataset
from pathlib import Path
import os

# %%
data = pd.read_csv("Full_Dataset.csv", index_col=0)
data
# Out:
#                   id         type           created_at  \
# 0       2.489769e+09  IssuesEvent  2015-01-01 19:10:07
# 1       2.489781e+09  IssuesEvent  2015-01-01 19:35:13
# 2       2.490036e+09  IssuesEvent  2015-01-02 05:09:39
# 3       2.490330e+09  IssuesEvent  2015-01-02 13:12:17
# 4       2.490330e+09  IssuesEvent  2015-01-02 13:12:47
# ...              ...          ...                  ...
# 667676  2.297185e+10  IssuesEvent  2022-07-20 04:27:22
# 667677  2.297200e+10  IssuesEvent  2022-07-20 04:40:38
# 667678  2.297205e+10  IssuesEvent  2022-07-20 04:45:39
# 667679  2.297205e+10  IssuesEvent  2022-07-20 04:45:40
# 667680  2.297296e+10  IssuesEvent  2022-07-20 06:04:12
#
#                                   repo  \
# 0                  travi/php-framework
# 1                  travi/php-framework
# 2                affektive/digiquatics
# 3                   bkimminich/z85-cli
# 4                   bkimminich/z85-cli
# ...                                ...
# ...

# %%
# Split the 'labels' column by space and extract unique labels
unique_labels = set()

for labels in df['labels'].dropna():
    unique_labels.update(labels.split())

unique_labels
# Out:
# {'p2-high',
#  'app-sidebar',
#  'robustness',
#  'hobnob',
#  'area/2.x',
#  'gcp_stackdriver_logging',
#  'Feature:Logins',
#  "Wont'",
#  'FE',
#  'Area-Compilers',
#  'it!',
#  'CCIssue02.06',
#  'mod:jobs',
#  'Priority/low',
#  'type/debt',
#  'TIME',
#  'biggie',
#  'area/build',
#  'Key',
#  'group/openshift',
#  'mod:genomebrowser',
#  'Database',
#  'Maintainability',
#  'Icebox',
#  '7.16',
#  'prioritisation',
#  'stalebot',
#  'service/networkfirewall',
#  'New',
#  'C-MII',
#  'udp',
#  'author',
#  'a',
#  'Admin',
#  'it-22',
#  'C-rfc',
#  'tenet:Performance',
#  'area/jib-core',
#  'mobile-device',
#  'capability',
#  'dialogue',
#  'Team:DataDiscovery',
#  'toolbars',
#  'advanced',
#  'scss',
#  'saw-core',
#  'service/sns',
#  'ui/needs-design',
#  'sys_admin_api',
#  'candidate/1.8.0',
#  'DataLake',
#  '3pt',
#  'Kong',
#  'team:WebTech',
#  'istio',
#  'A-Team',
#  'semantics',
#  'Import',
#  'Work',
#  'CHANGE',
#  'nb-golden',
#  'BC',
#  'version',
# ...

# %%
technical_debt_keywords = ["tech", "debt", "technical", "TD", "techdebt", "refactoring", "refac", "cruft"]
priority_keywords = ["prio", "priority", "critical", "high", "low", "medium", "urgent"]

# %%
def find_related_labels(label_set, keywords1, keywords2):
    matched_labels = []
    
   
    for label in label_set:
        label_lower = label.lower()
        
        primary_match = any(keyword in label_lower for keyword in keywords1)
    
        secondary_match = any(keyword in label_lower for keyword in keywords2)
        
        if primary_match and secondary_match:
            matched_labels.append(label)
    
    return matched_labels

# %%
find_related_labels(unique_labels, technical_debt_keywords, priority_keywords)
# Out:
# ['priority/important-tech-debt', 'tech-debt-high']

# %%
def find_labels(label_set, keywords):
    matched_labels = []  
    
    for label in label_set:
        label_lower = label.lower()  
        

        primary_match = any(keyword in label_lower for keyword in keywords)
        
        if primary_match:
            matched_labels.append(label)
    
    return matched_labels

# %%
TD = find_labels(unique_labels, technical_debt_keywords)
TD
# Out:
# ['type/debt',
#  'team:WebTech',
#  'kind:refactor',
#  'Type:Tech',
#  'Technical-Debt',
#  '@oumi-service/debt',
#  'techy-debt',
#  'LCB-TechDebt',
#  'state-tech-debt',
#  'topic:tech-debt',
#  'cat/techdoc',
#  'TECH',
#  'area/tech-debt',
#  'socialissues.tech',
#  'TECHNICAL',
#  'Techical',
#  'Refac',
#  'operational-design-debt',
#  'refactoring',
#  'technical-debt',
#  'area/techdebt',
#  'task:refactor',
#  'techtask',
#  'debts',
#  'tech/typescript',
#  'tech-debt-ideas',
#  'C-refactoring',
#  'techDebt',
#  '.Tech',
#  'technology',
#  '😈Tech',
#  'type:Techdebt',
#  'tech',
#  'reindebted',
#  'Debt/Refactoring',
#  'dev:tech-debt',
#  'refactoring:coverage',
#  'Type:Technical',
#  'technnical',
#  't_debt',
#  'Techinical',
#  'priority/important-tech-debt',
#  'refactoring:build-process',
#  'Techdebt',
#  'T-techdebt',
#  'eng:test-debt',
#  'tech-design',
#  'Debts',
#  'kudos-debt-sprint',
#  'type_TechnicalDebt',
#  'task:tech-debt',
#  'debt/arch',
# ...

# %%
priority = find_labels(unique_labels, priority_keywords)
priority
# Out:
# ['p2-high',
#  'Priority/low',
#  'prioritisation',
#  'Workflow',
#  'difficulty/high',
#  'Prio-1',
#  'Low-Hanging',
#  'severity/critical',
#  'priority-high',
#  'high-priority',
#  'dt-yellow-ribbon-schools-search',
#  'bug-exposure-low',
#  'Priority:',
#  'C/FLOW',
#  'critical',
#  'Normal-Priority',
#  'C/FLOW-HS',
#  'Priority:P1',
#  'Priority/critical',
#  'priority/p4',
#  'I-High',
#  'sev1-critical',
#  'priority/p1',
#  'Priority3',
#  'P-Medium',
#  'notebook-workflow',
#  'bug-quality-low',
#  'priority-4',
#  'caseflow-queue',
#  'T-beta-customer-priority',
#  'priority=1',
#  'prio-medium',
#  'priority/low',
#  'Difficulty:Medium',
#  'workflow-execution',
#  'value/medium',
#  'Cf:High',
#  'pri-High',
#  'prio-high',
#  'medium',
#  'priority:moderate',
#  'size-medium',
#  'priority-P3',
#  'Priorty/High',
#  'priority/medium',
#  'priority/2-high',
#  'Urgent',
#  'security/medium',
#  'medium_priority',
#  'p/medium',
#  'priority/important-tech-debt',
# ...
