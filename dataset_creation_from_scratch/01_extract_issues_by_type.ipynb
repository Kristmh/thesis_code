# %%
import pandas as pd

# %%
import os

# folder path
dir_path = r'all_issue_event' ## Point to the extracted folder containing all the issues csv files

# list to store files
res = []

# Iterate directory
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        res.append(path)
print(res)
# Out:
# ['issues_all_2021-06-12.csv', 'issues_all_2021-04-29.csv', 'issues_all_2021-04-23.csv', 'issues_all_2021-05-05.csv', 'issues_all_2021-03-31.csv', 'issues_all_2021-10-09.csv', 'issues_all_2021-04-30.csv', 'issues_all_2021-12-24.csv', 'issues_all_2021-06-24.csv', 'issues_all_2021-06-06.csv', 'issues_all_2021-01-09.csv', 'issues_all_2021-08-12.csv', 'issues_all_2021-04-09.csv', 'issues_all_2021-09-13.csv', 'issues_all_2021-03-21.csv', 'issues_all_2021-05-16.csv', 'issues_all_2022-01-30.csv', 'issues_all_2022-01-09.csv', 'issues_all_2021-08-08.csv', 'issues_all_2021-02-12.csv', 'issues_all_2021-05-03.csv', 'issues_all_2021-10-05.csv', 'issues_all_2021-10-31.csv', 'issues_all_2021-05-14.csv', 'issues_all_2021-09-05.csv', 'issues_all_2021-11-22.csv', 'issues_all_2021-07-19.csv', 'issues_all_2021-04-21.csv', 'issues_all_2021-06-03.csv', 'issues_all_2021-05-02.csv', 'issues_all_2021-04-06.csv', 'issues_all_2021-05-04.csv', 'issues_all_2021-10-18.csv', 'issues_all_2021-01-25.csv', 'issues_all
# ...

# %%
import re

# %%
appended_data = []

for i in res:
    try:
        ddf = pd.read_csv(f"all_issue_event/{i}", index_col=0)
        sub = 'low priority'     # Replace : Issues Labels to search in csv  replcae for security, debt , technical debt ,  priority and so on 
        print(i)
        ddf["index"] = ddf["labels"].str.count(sub,  flags=re.IGNORECASE)
        ddf = ddf[ddf["index"] > 0]
        appended_data.append(ddf)
    except:
        continue

appended_data = pd.concat(appended_data, ignore_index=True)
# Out:
# issues_all_2021-06-12.csv
# issues_all_2021-04-29.csv
# /tmp/ipykernel_131362/3929656853.py:5: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   ddf = pd.read_csv(f"all_issue_event/{i}", index_col=0)
# issues_all_2021-04-23.csv
# issues_all_2021-05-05.csv
# issues_all_2021-03-31.csv
# issues_all_2021-10-09.csv
# issues_all_2021-04-30.csv
# issues_all_2021-12-24.csv
# issues_all_2021-06-24.csv
# issues_all_2021-06-06.csv
# issues_all_2021-01-09.csv
# issues_all_2021-08-12.csv
# issues_all_2021-04-09.csv
# issues_all_2021-09-13.csv
# issues_all_2021-03-21.csv
# issues_all_2021-05-16.csv
# issues_all_2022-01-30.csv
# issues_all_2022-01-09.csv
# issues_all_2021-08-08.csv
# issues_all_2021-02-12.csv
# issues_all_2021-05-03.csv
# issues_all_2021-10-05.csv
# issues_all_2021-10-31.csv
# issues_all_2021-05-14.csv
# issues_all_2021-09-05.csv
# issues_all_2021-11-22.csv
# issues_all_2021-07-19.csv
# issues_all_2021-04-21.csv
# ...

# %%
appended_data
# Out:
#                id         type           created_at  \
# 0     16751603531  IssuesEvent  2021-06-12 01:26:20
# 1     16751648046  IssuesEvent  2021-06-12 01:37:40
# 2     16129794985  IssuesEvent  2021-04-29 01:32:47
# 3     16129802297  IssuesEvent  2021-04-29 01:34:02
# 4     16130080132  IssuesEvent  2021-04-29 02:19:14
# ...           ...          ...                  ...
# 7374  15936573640  IssuesEvent  2021-04-14 11:20:08
# 7375  15937062380  IssuesEvent  2021-04-14 11:59:33
# 7376  15937115869  IssuesEvent  2021-04-14 12:03:28
# 7377  15937124846  IssuesEvent  2021-04-14 12:04:08
# 7378  15937602488  IssuesEvent  2021-04-14 12:40:00
#
#                                 repo  \
# 0              Sequel-Ace/Sequel-Ace
# 1                       DoobDev/Doob
# 2          KingSupernova31/RulesGuru
# 3          KingSupernova31/RulesGuru
# 4     inaturalist/iNaturalistAndroid
# ...                              ...
# 7374     inf112-v21/Trivial-Solution
# ...

# %%
# Convert to csv
appended_data.to_csv("final_low_priority_dataset.csv")
