# %%
import pymongo

# %% [markdown]
# For more details refer to
#  https://zenodo.org/record/5901956

# %% [markdown]
# Command used to export the data (this command takes about 15 minutes to complete).
#
# `mongodump --db=JiraRepos --gzip --archive=mongodump-JiraRepos.archive`
#
# Accompanying command to restore the data (this command takes about 15 minutes to complete). Expanded, this data is ~60GB inside MongoDB.
#
# `mongorestore --gzip --archive=mongodump-JiraRepos.archive --nsFrom "JiraRepos.*" --nsTo "JiraRepos.*"`
#
# Change the `--nsTo` command to contain the desired name for the JiraRepos database.
# mongorestore --gzip --archive=mongodump-JiraRepos.archive --nsFrom "JiraRepos.*" --nsTo "JiraRepos.Apache"
#
#
# For more information see: https://docs.mongodb.com/manual/tutorial/backup-and-restore-tools/

# %% [markdown]
# Jira Dataset for TD filtered was extracted from https://zenodo.org/record/5901956  (https://arxiv.org/pdf/2201.08368.pdf) and adapted
#
# Montgomery, Lloyd, Lüders, Clara, & Maalej, Prof. Dr. Walid. (2022). The Public Jira Dataset [Data set]. Zenodo. https://doi.org/10.5281/zenodo.5901956

# %%
myclient = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
mydb = myclient["JiraRepos"]

# %%
myapache = mydb["Apache"]
myjiraecosystem = mydb["JiraEcosystem"]
mySonatype = mydb["Sonatype"]
mymongo = mydb["MongoDB"]

# %%
collist = mydb.list_collection_names()
collist
# Out:
# ['Apache',
#  'SecondLife',
#  'Mindville',
#  'MariaDB',
#  'JiraEcosystem',
#  'IntelDAOS',
#  'JFrog',
#  'Spring',
#  'Qt',
#  'Jira',
#  'MongoDB',
#  'Hyperledger',
#  'RedHat',
#  'Sonatype',
#  'Sakai',
#  'Mojang']

# %%
import pandas as pd

# %%
def get_keys(dictionary):
    result = []
    for key, value in dictionary.items():
        if type(value) is dict:
            new_keys = get_keys(value)
            result.append(key)
            for innerkey in new_keys:
                result.append(f'{key}/{innerkey}')
        else:
            result.append(key)
    return result

# %%
def flatten_dict(nested_dict):
    res = {}
    if isinstance(nested_dict, dict):
        for k in nested_dict:
            flattened_dict = flatten_dict(nested_dict[k])
            for key, val in flattened_dict.items():
                key = list(key)
                # print(key , k )
                key.insert(0, k)
                res[tuple(key)] = val
    else:
        res[()] = nested_dict
    return res


def nested_dict_to_df(values_dict):
    flat_dict = flatten_dict(values_dict)
    
    df = pd.DataFrame.from_dict(flat_dict, orient="index")
   
    return df

# %%
import pymongo as pm

CHUNK_SIZE = 500
client = pm.MongoClient()
coll = client.get_database('JiraRepos').get_collection('Sonatype')
cursor = coll.find({}, batch_size=CHUNK_SIZE)


def yield_rows(cursor, chunk_size):
    """
    Generator to yield chunks from cursor
    :param cursor:
    :param chunk_size:
    :return:
    """
    chunk = []
    for i, row in enumerate(cursor):
        if i % chunk_size == 0 and i > 0:
            yield chunk
            del chunk[:]
        chunk.append(row)
    yield chunk


chunks = yield_rows(cursor, CHUNK_SIZE)
for chunk in chunks:
    df = pd.json_normalize(
        chunk, errors='ignore')

    df = df[["id", "fields.project.name", "fields.created", "fields.labels", "fields.summary", "fields.description", "fields.status.name",
             "fields.status.description", "fields.issuetype.name", "fields.issuetype.description", "fields.issuetype.subtask", "fields.comments"]]

    df.to_csv(f"Sonatype-{df.id[0]}.csv")

# %%
import dask.dataframe as dd

# %%
data_Sonatype = dd.read_csv("Sonatype-*.csv")

# %%
data_Sonatype = data_Sonatype.compute()

# %%
data_Sonatype
# Out:
#      Unnamed: 0      id                                fields.project.name  \
# 0             0   10119                                   Dev - Nexus Repo
# 1             1   10118                                   Dev - Nexus Repo
# 2             2   10117                                   Dev - Nexus Repo
# 3             3   10114                                   Dev - Nexus Repo
# 4             4   10113                                   Dev - Nexus Repo
# ..          ...     ...                                                ...
# 495         495  834582  Community Support - Open Source Project Reposi...
# 496         496  834580  Community Support - Open Source Project Reposi...
# 497         497  834579  Community Support - Open Source Project Reposi...
# 498         498  834568  Community Support - Open Source Project Reposi...
# 499         499  834565  Community Support - Open Source Project Reposi...
#
#                    fields.created fields.labels  \
# 0    2008-06-24T11:47:21.000+0000            []
# 1    2008-06-23T21:21:17.000+0000            []
# 2    2008-06-23T15:45:35.000+0000            []
# 3    2008-06-23T15:34:33.000+0000            []
# 4    2008-06-23T15:14:23.000+0000            []
# ..                            ...           ...
# 495  2021-12-18T01:30:58.000+0000            []
# 496  2021-12-18T01:15:56.000+0000            []
# 497  2021-12-18T00:20:04.000+0000   ['migrate']
# 498  2021-12-17T23:41:19.000+0000            []
# 499  2021-12-17T23:00:22.000+0000   ['migrate']
#
#                                         fields.summary  \
# 0    Snapshot Remover not handling artifacts using ...
# 1    Evict Service fails to remove artifacts in Rep...
# 2                                   Repository targets
# 3                                      User Management
# 4    After Evicting all artifacts in all repositori...
# ..                                                 ...
# 495  Rule failure while trying to close staging rep...
# 496           Create new com.babylonhealth.lit project
# 497    Please migrate com.solace and com.solacesystems
# 498                         Timeout closing repository
# 499      Please migrate com.therealvan to new OSS host
#
#                                     fields.description fields.status.name  \
# 0    Currently the snapshot remover is not removing...             Closed
# 1    \r\nThe evict scheduled service does not delet...             Closed
# 2    A repository may consist of several logical ta...             Closed
# 3    The user should be able to create and manage u...             Closed
# 4    I ran an evict task for all repositories, and ...             Closed
# ..                                                 ...                ...
# 495  [信息] * 本地上演的工件上传完成。\r\n [信息] * 正在关闭 ID 为“orgmv...             Closed
# 496  I get a `Profile com.babylonhealth.lit is not ...             Closed
# 497  With the recent instability we have been unabl...             Closed
# 498  I have been unable to publish to maven central...             Closed
# 499  Attempts to close and release packages have be...             Closed
#
#                              fields.status.description fields.issuetype.name  \
# 0    The issue is considered finished, the resoluti...                   Bug
# 1    The issue is considered finished, the resoluti...                   Bug
# 2    The issue is considered finished, the resoluti...           Improvement
# 3    The issue is considered finished, the resoluti...           Improvement
# 4    The issue is considered finished, the resoluti...                   Bug
# ..                                                 ...                   ...
# 495  The issue is considered finished, the resoluti...    Publishing Support
# 496  The issue is considered finished, the resoluti...           New Project
# 497  The issue is considered finished, the resoluti...    Publishing Support
# 498  The issue is considered finished, the resoluti...    Publishing Support
# 499  The issue is considered finished, the resoluti...    Publishing Support
#
#                           fields.issuetype.description  \
# 0    A problem which impairs or prevents the functi...
# 1    A problem which impairs or prevents the functi...
# 2    An improvement or enhancement to an existing f...
# 3    An improvement or enhancement to an existing f...
# 4    A problem which impairs or prevents the functi...
# ..                                                 ...
# 495       For general OSSRH publishing support tickets
# 496                Add a new project to the repository
# 497       For general OSSRH publishing support tickets
# 498       For general OSSRH publishing support tickets
# 499       For general OSSRH publishing support tickets
#
#      fields.issuetype.subtask  \
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ..                        ...
# 495                     False
# 496                     False
# 497                     False
# 498                     False
# 499                     False
#
#                                        fields.comments
# 0    [{'self': 'https://issues.sonatype.org/rest/ap...
# 1    [{'self': 'https://issues.sonatype.org/rest/ap...
# 2    [{'self': 'https://issues.sonatype.org/rest/ap...
# 3    [{'self': 'https://issues.sonatype.org/rest/ap...
# 4    [{'self': 'https://issues.sonatype.org/rest/ap...
# ..                                                 ...
# 495  [{'self': 'https://issues.sonatype.org/rest/ap...
# 496  [{'self': 'https://issues.sonatype.org/rest/ap...
# 497  [{'self': 'https://issues.sonatype.org/rest/ap...
# 498  [{'self': 'https://issues.sonatype.org/rest/ap...
# 499  [{'self': 'https://issues.sonatype.org/rest/ap...
#
# [87284 rows x 13 columns]

# %%
data_Sonatype1 = data_Sonatype.drop(columns="Unnamed: 0")

# %%
data_Sonatype1
# Out:
#          id                                fields.project.name  \
# 0     10119                                   Dev - Nexus Repo
# 1     10118                                   Dev - Nexus Repo
# 2     10117                                   Dev - Nexus Repo
# 3     10114                                   Dev - Nexus Repo
# 4     10113                                   Dev - Nexus Repo
# ..      ...                                                ...
# 495  834582  Community Support - Open Source Project Reposi...
# 496  834580  Community Support - Open Source Project Reposi...
# 497  834579  Community Support - Open Source Project Reposi...
# 498  834568  Community Support - Open Source Project Reposi...
# 499  834565  Community Support - Open Source Project Reposi...
#
#                    fields.created fields.labels  \
# 0    2008-06-24T11:47:21.000+0000            []
# 1    2008-06-23T21:21:17.000+0000            []
# 2    2008-06-23T15:45:35.000+0000            []
# 3    2008-06-23T15:34:33.000+0000            []
# 4    2008-06-23T15:14:23.000+0000            []
# ..                            ...           ...
# 495  2021-12-18T01:30:58.000+0000            []
# 496  2021-12-18T01:15:56.000+0000            []
# 497  2021-12-18T00:20:04.000+0000   ['migrate']
# 498  2021-12-17T23:41:19.000+0000            []
# 499  2021-12-17T23:00:22.000+0000   ['migrate']
#
#                                         fields.summary  \
# 0    Snapshot Remover not handling artifacts using ...
# 1    Evict Service fails to remove artifacts in Rep...
# 2                                   Repository targets
# 3                                      User Management
# 4    After Evicting all artifacts in all repositori...
# ..                                                 ...
# 495  Rule failure while trying to close staging rep...
# 496           Create new com.babylonhealth.lit project
# 497    Please migrate com.solace and com.solacesystems
# 498                         Timeout closing repository
# 499      Please migrate com.therealvan to new OSS host
#
#                                     fields.description fields.status.name  \
# 0    Currently the snapshot remover is not removing...             Closed
# 1    \r\nThe evict scheduled service does not delet...             Closed
# 2    A repository may consist of several logical ta...             Closed
# 3    The user should be able to create and manage u...             Closed
# 4    I ran an evict task for all repositories, and ...             Closed
# ..                                                 ...                ...
# 495  [信息] * 本地上演的工件上传完成。\r\n [信息] * 正在关闭 ID 为“orgmv...             Closed
# 496  I get a `Profile com.babylonhealth.lit is not ...             Closed
# 497  With the recent instability we have been unabl...             Closed
# 498  I have been unable to publish to maven central...             Closed
# 499  Attempts to close and release packages have be...             Closed
#
#                              fields.status.description fields.issuetype.name  \
# 0    The issue is considered finished, the resoluti...                   Bug
# 1    The issue is considered finished, the resoluti...                   Bug
# 2    The issue is considered finished, the resoluti...           Improvement
# 3    The issue is considered finished, the resoluti...           Improvement
# 4    The issue is considered finished, the resoluti...                   Bug
# ..                                                 ...                   ...
# 495  The issue is considered finished, the resoluti...    Publishing Support
# 496  The issue is considered finished, the resoluti...           New Project
# 497  The issue is considered finished, the resoluti...    Publishing Support
# 498  The issue is considered finished, the resoluti...    Publishing Support
# 499  The issue is considered finished, the resoluti...    Publishing Support
#
#                           fields.issuetype.description  \
# 0    A problem which impairs or prevents the functi...
# 1    A problem which impairs or prevents the functi...
# 2    An improvement or enhancement to an existing f...
# 3    An improvement or enhancement to an existing f...
# 4    A problem which impairs or prevents the functi...
# ..                                                 ...
# 495       For general OSSRH publishing support tickets
# 496                Add a new project to the repository
# 497       For general OSSRH publishing support tickets
# 498       For general OSSRH publishing support tickets
# 499       For general OSSRH publishing support tickets
#
#      fields.issuetype.subtask  \
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ..                        ...
# 495                     False
# 496                     False
# 497                     False
# 498                     False
# 499                     False
#
#                                        fields.comments
# 0    [{'self': 'https://issues.sonatype.org/rest/ap...
# 1    [{'self': 'https://issues.sonatype.org/rest/ap...
# 2    [{'self': 'https://issues.sonatype.org/rest/ap...
# 3    [{'self': 'https://issues.sonatype.org/rest/ap...
# 4    [{'self': 'https://issues.sonatype.org/rest/ap...
# ..                                                 ...
# 495  [{'self': 'https://issues.sonatype.org/rest/ap...
# 496  [{'self': 'https://issues.sonatype.org/rest/ap...
# 497  [{'self': 'https://issues.sonatype.org/rest/ap...
# 498  [{'self': 'https://issues.sonatype.org/rest/ap...
# 499  [{'self': 'https://issues.sonatype.org/rest/ap...
#
# [87284 rows x 12 columns]

# %%
data_Sonatype1["fields.issuetype.name"].value_counts()
# Out:
# New Project           65487
# Publishing Support     9413
# Bug                    6495
# Improvement            2480
# Problem                1597
# Sub-task               1342
# Story                   271
# Task                    147
# Technical Debt           29
# New Feature               9
# Epic                      7
# Technical task            5
# Question                  2
# Name: fields.issuetype.name, dtype: int64

# %%
data_Sonatype1.reset_index(drop=True, inplace=True)

# %%
data_Sonatype1
# Out:
#            id                                fields.project.name  \
# 0       10119                                   Dev - Nexus Repo
# 1       10118                                   Dev - Nexus Repo
# 2       10117                                   Dev - Nexus Repo
# 3       10114                                   Dev - Nexus Repo
# 4       10113                                   Dev - Nexus Repo
# ...       ...                                                ...
# 87279  834582  Community Support - Open Source Project Reposi...
# 87280  834580  Community Support - Open Source Project Reposi...
# 87281  834579  Community Support - Open Source Project Reposi...
# 87282  834568  Community Support - Open Source Project Reposi...
# 87283  834565  Community Support - Open Source Project Reposi...
#
#                      fields.created fields.labels  \
# 0      2008-06-24T11:47:21.000+0000            []
# 1      2008-06-23T21:21:17.000+0000            []
# 2      2008-06-23T15:45:35.000+0000            []
# 3      2008-06-23T15:34:33.000+0000            []
# 4      2008-06-23T15:14:23.000+0000            []
# ...                             ...           ...
# 87279  2021-12-18T01:30:58.000+0000            []
# 87280  2021-12-18T01:15:56.000+0000            []
# 87281  2021-12-18T00:20:04.000+0000   ['migrate']
# 87282  2021-12-17T23:41:19.000+0000            []
# 87283  2021-12-17T23:00:22.000+0000   ['migrate']
#
#                                           fields.summary  \
# 0      Snapshot Remover not handling artifacts using ...
# 1      Evict Service fails to remove artifacts in Rep...
# 2                                     Repository targets
# 3                                        User Management
# 4      After Evicting all artifacts in all repositori...
# ...                                                  ...
# 87279  Rule failure while trying to close staging rep...
# 87280           Create new com.babylonhealth.lit project
# 87281    Please migrate com.solace and com.solacesystems
# 87282                         Timeout closing repository
# 87283      Please migrate com.therealvan to new OSS host
#
#                                       fields.description fields.status.name  \
# 0      Currently the snapshot remover is not removing...             Closed
# 1      \r\nThe evict scheduled service does not delet...             Closed
# 2      A repository may consist of several logical ta...             Closed
# 3      The user should be able to create and manage u...             Closed
# 4      I ran an evict task for all repositories, and ...             Closed
# ...                                                  ...                ...
# 87279  [信息] * 本地上演的工件上传完成。\r\n [信息] * 正在关闭 ID 为“orgmv...             Closed
# 87280  I get a `Profile com.babylonhealth.lit is not ...             Closed
# 87281  With the recent instability we have been unabl...             Closed
# 87282  I have been unable to publish to maven central...             Closed
# 87283  Attempts to close and release packages have be...             Closed
#
#                                fields.status.description  \
# 0      The issue is considered finished, the resoluti...
# 1      The issue is considered finished, the resoluti...
# 2      The issue is considered finished, the resoluti...
# 3      The issue is considered finished, the resoluti...
# 4      The issue is considered finished, the resoluti...
# ...                                                  ...
# 87279  The issue is considered finished, the resoluti...
# 87280  The issue is considered finished, the resoluti...
# 87281  The issue is considered finished, the resoluti...
# 87282  The issue is considered finished, the resoluti...
# 87283  The issue is considered finished, the resoluti...
#
#       fields.issuetype.name  \
# 0                       Bug
# 1                       Bug
# 2               Improvement
# 3               Improvement
# 4                       Bug
# ...                     ...
# 87279    Publishing Support
# 87280           New Project
# 87281    Publishing Support
# 87282    Publishing Support
# 87283    Publishing Support
#
#                             fields.issuetype.description  \
# 0      A problem which impairs or prevents the functi...
# 1      A problem which impairs or prevents the functi...
# 2      An improvement or enhancement to an existing f...
# 3      An improvement or enhancement to an existing f...
# 4      A problem which impairs or prevents the functi...
# ...                                                  ...
# 87279       For general OSSRH publishing support tickets
# 87280                Add a new project to the repository
# 87281       For general OSSRH publishing support tickets
# 87282       For general OSSRH publishing support tickets
# 87283       For general OSSRH publishing support tickets
#
#        fields.issuetype.subtask  \
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
# ...                         ...
# 87279                     False
# 87280                     False
# 87281                     False
# 87282                     False
# 87283                     False
#
#                                          fields.comments
# 0      [{'self': 'https://issues.sonatype.org/rest/ap...
# 1      [{'self': 'https://issues.sonatype.org/rest/ap...
# 2      [{'self': 'https://issues.sonatype.org/rest/ap...
# 3      [{'self': 'https://issues.sonatype.org/rest/ap...
# 4      [{'self': 'https://issues.sonatype.org/rest/ap...
# ...                                                  ...
# 87279  [{'self': 'https://issues.sonatype.org/rest/ap...
# 87280  [{'self': 'https://issues.sonatype.org/rest/ap...
# 87281  [{'self': 'https://issues.sonatype.org/rest/ap...
# 87282  [{'self': 'https://issues.sonatype.org/rest/ap...
# 87283  [{'self': 'https://issues.sonatype.org/rest/ap...
#
# [87284 rows x 12 columns]

# %%
data_Sonatype1.to_hdf('jira_all.h5', key="sonatype")
# Out:
# C:\Users\karth\AppData\Local\Temp\ipykernel_14656\2316165141.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['fields.project.name', 'fields.created', 'fields.labels',
#        'fields.summary', 'fields.description', 'fields.status.name',
#        'fields.status.description', 'fields.issuetype.name',
#        'fields.issuetype.description', 'fields.comments'],
#       dtype='object')]
#
#   data_mongo1.to_hdf('jira_all.h5', key="mongodb")

# %%
df = pd.read_hdf('jira_all.h5', key="apache")
df1 = pd.read_hdf('jira_all.h5', key="mongodb")
df2 = pd.read_hdf('jira_all.h5', key="sonatype")
df3 = pd.read_hdf('jira_all.h5', key="jiraecosystem")
